# %%
# 测试读取 PDF 【高阶】《运行手册》HO-0907 飞行运行.pdf
import fitz  
import re

def extract_text_from_pdf1(pdf_path):
    doc = fitz.open(pdf_path)
    paragraphs = []
    chapter_regex = re.compile(r'^(\d+\.){1,2}(\D|$)')
    pass_first_n_page = 4  # 跳过前几页

    for page_num in range(len(doc)):
        # 跳过前面几页
        if pass_first_n_page>0:
            pass_first_n_page -= 1
            continue    
        page = doc.load_page(page_num)
        blocks = page.get_text("dict")["blocks"] #字典形式返回结构化数据，取文本块
        page_height = page.rect.height

        for block in blocks:
            if "lines" in block:
                for line in block["lines"]:
                    # 排除页眉和页尾，假设页眉在页面的前10%部分，页尾在页面的后8%部分
                    line_bbox = line["bbox"]
                    if line_bbox[1] < page_height * 0.1 or line_bbox[1] > page_height * 0.92:
                        continue
                    text = ""
                    for span in line["spans"]:
                        text += span["text"]
                    if text.strip():
                        chapter_match = chapter_regex.match(text.strip())
                        if chapter_match:
                            chapter_number = chapter_match.group(0)
                            chapter_content = text.strip()[len(chapter_number):].strip()
                            paragraphs.append((chapter_number.strip(), chapter_content))
                        else:
                            if paragraphs:
                                paragraphs[-1] = (paragraphs[-1][0], paragraphs[-1][1] + " " + text.strip())
    return paragraphs

# %%
# 测试读取 PDF  大型飞机公共航空运输承运人运行合格审定规则.pdf
import fitz  
import re

def extract_text_from_pdf2(pdf_path):
    doc = fitz.open(pdf_path)
    paragraphs = []
    chapter_regex = re.compile(r'第([\d\.]+) 条\s+(.*)')
    chapter_regex2 = re.compile(r' (a-z)')
    pass_first_n_page = 3  # 跳过前几页

    for page_num in range(len(doc)):
        # 跳过前面几页
        if pass_first_n_page>0:
            pass_first_n_page -= 1
            continue    
        page = doc.load_page(page_num)
        blocks = page.get_text("dict")["blocks"]
        page_height = page.rect.height

        for block in blocks:
            if "lines" in block:
                for line in block["lines"]:
                    # 排除页眉和页尾，假设页眉在页面的前8%部分，页尾在页面的后8%部分
                    line_bbox = line["bbox"]
                    if line_bbox[1] < page_height * 0.08 or line_bbox[1] > page_height * 0.92:
                        continue
                    text = ""
                    for span in line["spans"]:
                        text += span["text"]
                    if text.strip():
                        chapter_match = chapter_regex.match(text.strip())
                        if chapter_match:
                            chapter_number = "第 {} 条".format(chapter_match.group(1))
                            chapter_content = text.strip()[len(chapter_number):].strip()
                            paragraphs.append((chapter_number.strip(), chapter_content))
                        else:
                            if paragraphs:
                                paragraphs[-1] = (paragraphs[-1][0], paragraphs[-1][1] + " " + text.strip())
    return paragraphs

# %%
pdf_path1 = 'source_pdf/【高阶】《运行手册》HO-0907 飞行运行.pdf'
extracted_paragraphs1 = extract_text_from_pdf1(pdf_path1)
print(len(extracted_paragraphs1))

# 打印提取结果
for paragraph_number, paragraph_content in extracted_paragraphs1:
    print(f"片段编号: {paragraph_number}")
    print(f"片段内容: {paragraph_content}")
    print("-------------------------------------")
    print()
# Out:
# 295
# 片段编号: 1.
# 片段内容: 飞行机组在开始滑行、进入滑行道和跑道、穿越滑行道和跑道以及起飞和着陆都必 须得到空中交通管制相应的许可。
# -------------------------------------
#
# 片段编号: 2.
# 片段内容: 标准操作程序
# -------------------------------------
#
# 片段编号: 2.1.
# 片段内容: 公司根据各机型手册，结合自身运行特点，为每个机型建立了标准操作程序；
# -------------------------------------
#
# 片段编号: 2.2.
# 片段内容: 飞行机组应按照公司制定的标准操作程序操纵飞机；
# -------------------------------------
#
# 片段编号: 2.3.
# 片段内容: 如需偏离标准操作程序， 飞行机组必须进行充分的沟通， 包括与其他相关机组 人员、 地面人员以及空中交通管制员等的沟通， 并评估偏离标准操作程序可能 造成的风险。
# -------------------------------------
#
# 片段编号: 3.
# 片段内容: 检查单的使用
# -------------------------------------
#
# 片段编号: 3.1.
# 片段内容: 公司为每一机型提供经批准的检查单， 并配备到公司运行的每架飞机上飞行机 组可以快速取用的位置；
# -------------------------------------
#
# 片段编号: 3.2.
# 片段内容: 飞行机组在运行过程中，必须使用公司配备的经批准的检查单；
# -------------------------------------
#
# 片段编号: 3.3.
# 片段内容: 除规定的记忆项目外，任何人不得背诵检查单；
# -------------------------------------
#
# 片段编号: 3.4.
# 片段内容: 执行检查单必须使用标准用语；
# -------------------------------------
#
# 片段编号: 3.5.
# 片段内容: 执行检查单过程中，如果某项目不能立即执行或PF 未应答时，检查单必须停 止在此项目位置，直到完成该项目或遗漏、错误得到纠正后，方可继续执行检 查单剩余项目；
# -------------------------------------
#
# 片段编号: 3.6.
# 片段内容: PF 必须喊出检查单的全称，PM 应在检查单完成后宣布“XXX 检查单完成”；
# -------------------------------------
#
# 片段编号: 3.7.
# 片段内容: 对于正常检查单的使用方法，具体详见机型SOP。
# -------------------------------------
#
# 片段编号: 4.
# 片段内容: 交叉检查
# -------------------------------------
#
# 片段编号: 4.1.
# 片段内容: 交叉检查是预防发生人为差错、及时发现系统故障的重要手段。在操纵飞机、 操作设备时，PF 和PM 应共同证实；特别是涉及到飞机关键设备（动力、液 压、电源、增压等）、飞机构型改变（襟/缝翼、起落架、减速板）、航路/航 向/高度/速度变化、计算机重置、航空器控制的交接、重要飞行数据的计算和 输入等时，飞机无论是正常、非正常、紧急情况下，均应互相证实后方可进行 操作；
# -------------------------------------
#
# 片段编号: 4.2.
# 片段内容: 飞行过程中，飞行机组在操作发动机主控电门、推力手柄、灭火手柄、IDG 电 门、惯导以及所有加保护盖的重要的电门、开关、手柄、调节旋钮时，必须由 另一名飞行机组证实后方可进行操作。
# -------------------------------------
#
# 片段编号: 5.
# 片段内容: 标准喊话
# -------------------------------------
#
# 片段编号: 5.1.
# 片段内容: 飞行过程中， 飞行机组应严格按照机型SOP 使用标准喊话， 包括喊话的时机、 标准口令和标准回答；
# -------------------------------------
#
# 片段编号: 5.2.
# 片段内容: 标准喊话应简单、清晰，并且必须按要求回答。
# -------------------------------------
#
# 片段编号: 6.
# 片段内容: 机组简令
# -------------------------------------
#
# 片段编号: 6.1.
# 片段内容: 起飞简令 PF 必须在发动机起动前完成起飞简令（非正常情况下可推迟到进跑道前完 成）；必要时，PM 应对简令的要点部分进行补充，起飞简令至少应包括以下 内容： 6.1.1. 机组分工； 6.1.2. 气象条件； 6.1.3. 飞机技术状况； 6.1.4. 预期的滑行路线（包括热点区域）； 6.1.5. 起飞性能； 6.1.6. 起飞跑道及道面状况、离场程序、所需导航设备、重要地形、过渡高 度和扇区安全高度等； 6.1.7. 低能见度起飞、起飞备降场的选择与备降预案； 6.1.8. 特殊情况处置(中断起飞、发动机失效、紧急返场)； 6.1.9. 相关通告； 6.1.10. 特殊运行程序； 6.1.11. 其他（如：对航路或机场的熟悉、危险品运输、外界环境、非标准降 噪程序等）。
# -------------------------------------
#
# 片段编号: 6.2.
# 片段内容: 进近简令 PF 必须在开始下降前完成进近简令，如ATC 进场和/或进近指令更改或着陆 跑道更改，PF 应重新完成进近简令或完成补充简令；PM 负责证实、必要时 对简令进行补充。进近简令至少应包括以下内容： 6.2.1. 机组分工； 6.2.2. 气象条件 6.2.3. 飞机技术状况； 6.2.4. 剩余油量； 6.2.5. 着陆性能； 6.2.6. 使用跑道及道面状况、进场/进近程序、所需导航设备、重要地形、过 渡高度层和扇区安全高度等； 6.2.7. II/III 类进近； 6.2.8. 备降场的选择与备降预案； 6.2.9. 终止进近/复飞； 6.2.10. 落地后预期的滑行路线（包括热点区域）。 6.2.11. 相关通告； 6.2.12. 特殊运行程序； 6.2.13. 其他（如：对航路或机场的熟悉、危险品运输、外界环境等）。
# -------------------------------------
#
# 片段编号: 7.
# 片段内容: 机组使用语言 公司机组在飞行运行中使用的工作语言为中文（普通话）或英语。使用场合包括：
# -------------------------------------
#
# 片段编号: 7.1.
# 片段内容: 驾驶舱飞行机组成员之间的沟通；
# -------------------------------------
#
# 片段编号: 7.2.
# 片段内容: 飞行机组和客舱机组、安保组、公司签派、地面勤务、ATC 之间的沟通。
# -------------------------------------
#
# 片段编号: 7.3.
# 片段内容: 在机组培训和考试时，可以使用中文（普通话）或英语作为工作语言。
# -------------------------------------
#
# 片段编号: 7.4.
# 片段内容: 有外籍飞行员作为机组必需成员的飞行中， 所有飞行机组成员之间， 以及驾驶 舱和客舱、驾驶舱和地面维修人员的沟通应使用英语。
# -------------------------------------
#
# 片段编号: 7.5.
# 片段内容: 当外站机场地面勤务/维修人员不能够用英语与外籍飞行员沟通时，中籍飞行 员可以使用中文与地面维修人员通话； 在通话结束后， 中籍飞行员必须将通话 内容准确地翻译给外籍飞行员，在未获得证实之前，不得擅自操作，在操作过 程中应做到“眼到、口到、手到”。
# -------------------------------------
#
# 片段编号: 8.
# 片段内容: 飞行关键阶段
# -------------------------------------
#
# 片段编号: 8.1.
# 片段内容: 飞行关键阶段是指滑行、起飞、着陆和除巡航以外在3000 米（10000 英尺） 以下的飞行阶段。
# -------------------------------------
#
# 片段编号: 8.2.
# 片段内容: 在飞行的关键阶段， 全体机组成员不得从事飞机安全运行所必需的工作之外的 任何其他工作，机组任何成员也不得承担这些工作。预定厨房供应品，确认旅 客的衔接航班，对旅客进行公司的广告宣传，介绍风景名胜的广播，填写与运 行无关的公司报告表、记录表等工作都不是飞机安全运行所必需的工作。
# -------------------------------------
#
# 片段编号: 8.3.
# 片段内容: 在飞行关键阶段，飞行机组成员不得从事可能分散飞行机组其他成员工作精 力， 或可能干扰其他成员正确履行职责的活动， 机长也不得允许其从事这种活 动。这些活动包括进餐、在驾驶舱无关紧要的交谈、在驾驶舱和客舱乘务员之 间无关紧要的通话、阅读与正常飞行无关的刊物等。
# -------------------------------------
#
# 片段编号: 8.4.
# 片段内容: 在飞行关键阶段， 客舱乘务员除完成保障机上人员安全的任务外， 其他时间应 当坐在其值勤位置并系好安全带和肩带。
# -------------------------------------
#
# 片段编号: 8.5.
# 片段内容: 在飞行关键阶段， 除飞机故障、 天气原因、 机组成员不正常状态等特殊情况外， 不应调换处于操纵位置的飞行机组成员。
# -------------------------------------
#
# 片段编号: 8.6.
# 片段内容: 在飞行关键阶段， 客舱乘务员应避免与驾驶舱联系或进入驾驶舱， 除非涉及飞 行安全。
# -------------------------------------
#
# 片段编号: 8.7.
# 片段内容: 在飞行关键阶段，禁止将服务舱内任何与飞行无关的电源开关处于启动位置。
# -------------------------------------
#
# 片段编号: 8.8.
# 片段内容: 在飞行关键阶段， 客舱乘务员应当尽可能地靠近飞机地板高度出口， 而且应当 在整个客舱内均匀分布，以便在应急撤离时最有效地疏散旅客。在滑行期间， 客舱乘务员除完成保障飞机和机上人员安全的任务外， 其余时间应当坐在其值 勤位置并系好安全带和肩带。
# -------------------------------------
#
# 片段编号: 9.
# 片段内容: 燃油监控 飞行机组必须对燃油消耗进行持续监控，对剩余燃油进行科学管理，确保剩余燃油 不低于完成计划飞行所需的燃油要求。
# -------------------------------------
#
# 片段编号: 9.1.
# 片段内容: 飞行机组应在EFB 中“D 计划”上记录飞行时间和已耗燃油/剩余燃油；通常 到达巡航高度后，进行第一次检查和记录，之后至少每30 分钟结合飞越的航 路点检查并记录飞行时间和已耗燃油/剩余燃油；
# -------------------------------------
#
# 片段编号: 9.2.
# 片段内容: 至少每60 分钟，将已耗燃油和剩余燃油相加，与初始总油量进行比较，同时 检查剩余燃油的合理分布；
# -------------------------------------
#
# 片段编号: 9.3.
# 片段内容: 一旦发现燃油消耗异常、 燃油指示故障等燃油不正常状态， 应立即进行分析并 视情按FCOM 以及QRH 处置， 以保证飞行在预计着陆机场着陆时的剩余油量 不低于最后储备燃油量， 努力避免飞机进入紧急油量状态， 同时立即将相关情 况报告飞行签派员。
# -------------------------------------
#
# 片段编号: 10.
# 片段内容:  仪表进近要求
# -------------------------------------
#
# 片段编号: 10.1.
# 片段内容: 起始进近高度 当按照仪表飞行规则飞往无线电导航设施做起始进近时， 飞行机组不得将飞机 下降到按该设施制定的仪表进近程序中规定的起始进近最低高度之下， 直至到 达该设施上空。
# -------------------------------------
#
# 片段编号: 10.2.
# 片段内容: 满足下列条件后，方可起始进近： 10.2.1. 最新的气象条件满足所实施进近程序对应的机场运行最低标准、 进近程 序限制、机型风速限制以及道面条件限制要求； 10.2.2. 着陆性能及复飞性能满足要求； 10.2.3. 机组资质符合要求。
# -------------------------------------
#
# 片段编号: 10.3.
# 片段内容: 继续进近的条件 10.3.1. 当报告的VIS/RVR 低于规定的最低标准时,不得飞越FAF/最后进近点 （FAP）或下降到机场标高上空300 米（1000 英尺）以下，两者取较 高值。 10.3.2. 飞越FAF/FAP 或下降到机场标高上空300 米（1000 英尺）以下后， 报告的RVR 或VIS 低于规定的最低标准，可以继续进近至DA/H 或者 MDA/H。 10.3.3. 如果进近程序没有规定FAF， 当报告的RVR 或VIS 低于规定的最低标 准时，不得开始最后进近。 注：最后进近航段从仪表进近程序规定的最后进近定位点或者设施处开始。当 一个包含程序转弯的程序没有规定最后进近定位点时， 最后进近航段在完成程 序转弯的那一点开始，并且在该点上，飞机在该程序规定距离之内在最后进近 航迹上向机场飞行。
# -------------------------------------
#
# 片段编号: 10.4.
# 片段内容: 当到达MDA/H 或DA/H，在进近复飞点之前的任何时间内，除非满足下列要 求，否则飞机不得继续进近到低MDA/H 或DA/H 并着陆： 10.4.1. 飞机持续处在正常位置， 从该位置能够使用正常机动动作以正常下降率 降落在计划着陆跑道， 并且以此下降率可以使飞机在该跑道接地区内接 地； 10.4.2. 飞行能见度不低于所用的标准仪表进近程序规定的能见度； 10.4.3. 飞行机组能清楚地看到并保持所需的目视参考； 10.4.4. 当使用具有目视下降点的非精密直接进近程序时， 飞机已到达该目视下 降点，且在该点使用正常程序或者下降率能降落到跑道上。
# -------------------------------------
#
# 片段编号: 10.5.
# 片段内容: 仪表进近着陆所需目视参考 10.5.1. 除II 类和III 类进近外，飞行机组至少能清楚地看到和辨认着陆跑道的 下列目视参考之一： 10.5.1.1. 进近灯光系统，如果飞行机组仅使用进近灯光作为参考，应 当同时清楚地看到和辨认红色终端横排灯 注或红色侧排灯，否 则不得下降到接地区标高之上30 米（100 英尺）以下； 10.5.1.2. 跑道入口； 10.5.1.3. 跑道入口标志； 10.5.1.4. 跑道入口灯； 10.5.1.5. 跑道端标识灯； 10.5.1.6. 目视进近下滑道指示灯； 10.5.1.7. 接地区或接地区标志； 10.5.1.8. 接地区灯； 10.5.1.9. 跑道或跑道标志； 10.5.1.10. 跑道灯。 注： 红色终端横排灯为ALSF-1 进近灯光系统特有灯光， 国内机场无相 应灯光系统。 10.5.2. II 类进近着陆时，除非能保持包括进近灯、接地带灯、跑道中线灯、跑 道边灯或者这些灯的组合中至少3 个连续灯的目视参考，机组不得继 续进近至决断高（DH）之下。 10.5.3. 对于IIIA 类运行， 机组不得继续进近至DH 之下， 除非获得并能够保持 包括进近灯、接地带灯、跑道中线灯或这些灯的组合中至少3 个连续 灯的目视参考。 10.5.4. 对于IIIB 类运行， 机组不得进近至DH 之下， 除非获得并能够保持包括 1 个中线灯在内的目视参考。
# -------------------------------------
#
# 片段编号: 11.
# 片段内容:  目视起落航线
# -------------------------------------
#
# 片段编号: 11.1.
# 片段内容: 目视起落航线（TRAFFIC PATTERN）：是一种航空器在机场滑行、起飞或着 陆规定的流程，由五个边组成。
# -------------------------------------
#
# 片段编号: 11.2.
# 片段内容: 在实施目视起落航线时， 机长对与其他航空器和地面障碍物之间的安全间隔负 直接责任。因此，飞行机组在执行目视起落时，必须建立合理分工，在保证正 常仪表扫视和数据监控的同时，保持对障碍物、机场、跑道以及前机的目视观 察。
# -------------------------------------
#
# 片段编号: 11.3.
# 片段内容: 实施目视起落航线时， 气象条件应满足本手册HO-0905-1 章节第10 条的要求。
# -------------------------------------
#
# 片段编号: 11.4.
# 片段内容: 实施目视起落航线前，机组需得到管制员的批准。
# -------------------------------------
#
# 片段编号: 11.5.
# 片段内容: 除在机场细则中有特别说明或ATC 另有指令外，目视起落航线的方向为左起 落。飞行机组应当采取左转弯加入起落航线并避开前方航空器的尾流。
# -------------------------------------
#
# 片段编号: 11.6.
# 片段内容: 在国内运输机场空域内， 除经塔台同意外， 飞机在进入机场实施目视起落航线 时，不得低于机场标高以上450 米。
# -------------------------------------
#
# 片段编号: 11.7.
# 片段内容: 飞机加入到目视起落航线前应减速到机型要求的起落航线速度。
# -------------------------------------
#
# 片段编号: 11.8.
# 片段内容: 机长在确定从飞机所处位置能进行稳定进近之前， 不得下降低于着陆跑道接地 区标高以上500 英尺。
# -------------------------------------
#
# 片段编号: 11.9.
# 片段内容: 在管制机场实施目视起落航线时，若气象条件低于本手册HO-0905-1 章节第 10 条的要求或者失去目视参考，应立即实施复飞，复飞后应首先保持在目视 起落航线上，并向管制员报告，根据管制员的许可实施后续飞行。在任何时候 脱离起落航线，都必须考虑对航线中其他飞机的影响。
# -------------------------------------
#
# 片段编号: 12.
# 片段内容:  客舱安全规定
# -------------------------------------
#
# 片段编号: 12.1.
# 片段内容: 为确保客舱机组自身安全，在本章节8 条的基础上，公司规定：自滑行至起飞 后20 分钟或到达巡航高度，以及落地前30 分钟至飞机发动机关车（安全带 灯灭），以上阶段客舱乘务员除完成保障飞机和机上人员安全的任务外，其他 时间应必须在规定的席位上就坐并保持安全带、 肩带系紧， 除非发生危及飞行 安全或涉及旅客的紧急情况。
# -------------------------------------
#
# 片段编号: 12.2.
# 片段内容: 起飞后20 分钟且飞机处于平稳状态时， 如 “系好安全带” 信号灯未关闭， （主 任）乘务长应主动联系机组，询问是否可以开始客舱服务。当完成客舱服务程 序后，（主任）乘务长应向飞行机组报告。
# -------------------------------------
#
# 片段编号: 13.
# 片段内容:  禁止吸烟的规定
# -------------------------------------
#
# 片段编号: 13.1.
# 片段内容: 任何人在任何阶段（包括运行阶段及非运行阶段）禁止在航空器内吸烟（包括 电子烟），飞行机组应在整个飞行阶段保持“禁止吸烟”信号灯的接通。
# -------------------------------------
#
# 片段编号: 13.2.
# 片段内容: 机上任何人不得触动、 损害或者破坏飞机厕所内安装的烟雾探测器， 机组成员 如发现此类行为应予以立即制止。 飞行运行操纵限制
# -------------------------------------
#
# 片段编号: 1.
# 片段内容: 操纵装置的控制
# -------------------------------------
#
# 片段编号: 1.1.
# 片段内容: 机长不得允许不符合下列规定之一的人员在飞行期间控制操纵装置， 任何不符 合下列规定之一的人员也不得在飞行期间控制操纵装置： 1.1.1. 公司聘任的合格的飞行员； 1.1.2. 得到机长允许， 有资格在该飞机上飞行的正在执行飞行运行检查任务的 局方监察员或者局方委任代表； 1.1.3. 得到机长允许、 有资格在该飞机上飞行并且获得了局方和公司批准的另 一公司的飞行员。
# -------------------------------------
#
# 片段编号: 1.2.
# 片段内容: 可以在左座操纵飞机的人员： 1.2.1. 飞行教员或机长； 1.2.2. 巡航机长； 1.2.3. 建立左座运行经历的副驾驶。
# -------------------------------------
#
# 片段编号: 1.3.
# 片段内容: 可以在右座操纵飞机的人员： 1.3.1. 飞行教员； 1.3.2. 已被公司聘用为机长但非本次航班的责任机长（飞行关键阶段除外） ； 1.3.3. 巡航机长（飞行关键阶段除外） ； 1.3.4. 副驾驶（操纵具体要求见《飞行技术管理手册》 ） 。
# -------------------------------------
#
# 片段编号: 1.4.
# 片段内容: 下列情况下，由机长操纵飞机： 1.4.1. 起飞重量达到本机型最大起飞重量的百分之九十（含）以上时； 1.4.2. 实施目视盘旋进近时； 1.4.3. 实施低能见度运行时； 1.4.4. 右座副驾驶在所飞机型飞行经历时间少于100 小时且左座机长不具备 飞行检查员/飞行教员资格，下列情况下由左座机长操纵飞机： 1.4.4.1. 在公司规定的特殊机场； 1.4.4.2. 机场的最新气象报告中有效能见度值等于或者小于1200 米 (3/4 英里)，或者跑道视程(RVR)等于或者小于1200 米(4000 英尺)； 1.4.4.3. 所用跑道有水、雪、雪浆等严重影响飞机性能的情况； 1.4.4.4. 所用跑道刹车效应报告低于“好”； 1.4.4.5. 所用跑道侧风分量超过7 米/秒； 1.4.4.6. 天气报告机场附近有风切变； 1.4.4.7. 机长认为需要谨慎行使机长权力的任何其它情况。
# -------------------------------------
#
# 片段编号: 1.5.
# 片段内容: 操纵权交换 1.5.1. 飞机操纵权交接由机长或PF 发布口头指令，标准用语为“我（你）操 纵”，接受操纵权的飞行机组应按照机型程序接管飞机的操纵，并在接 管后回答“我操纵”； 1.5.2. 只有确认接受操纵权的飞行机组已经接管飞机后， 交出操纵权的飞行机 组方可交出飞机操纵权。
# -------------------------------------
#
# 片段编号: 2.
# 片段内容: 低空下降率的限制
# -------------------------------------
#
# 片段编号: 2.1.
# 片段内容: 高于机场标高750 米（2500 英尺）至300 米（1000 英尺） ，下降率不得大于 1500 英尺/分钟；
# -------------------------------------
#
# 片段编号: 2.2.
# 片段内容: 高于机场标高300 米（1000 英尺）以下，下降率不得持续大于1000 英尺/分 钟。
# -------------------------------------
#
# 片段编号: 3.
# 片段内容: 空中、地面的避让规定
# -------------------------------------
#
# 片段编号: 3.1.
# 片段内容: 任何人不得驾驶飞机靠近另一架飞机达到产生碰撞危险的程度。
# -------------------------------------
#
# 片段编号: 3.2.
# 片段内容: 任何人不得驾驶航空器进行编队飞行。
# -------------------------------------
#
# 片段编号: 3.3.
# 片段内容: 当气象条件许可时， 无论是按仪表飞行规则还是按目视飞行规则飞行， 飞行机 组必须注意观察， 以便发现并避开其他航空器。 当另一架航空器享有航行优先 权时， 飞行机组必须为该航空器让出航路， 并不得以危及安全的间隔在其上方、 下方或者前方通过。
# -------------------------------------
#
# 片段编号: 3.4.
# 片段内容: 在空中，飞行机组应按下列规定进行避让： 3.4.1. 遇险的航空器享有优先于所有其他航空器的航行优先权。 3.4.2. 在同一高度对头相遇时，应各自向右避让，相互间保持500 米以上的 间隔； 3.4.3. 在同一高度交叉相遇时， 从驾驶舱左侧看到另一架航空器时， 应当下降 高度，从驾驶舱右侧看到另一架航空器时，应当上升高度； 3.4.4. 飞行员应主动避让飞艇、滑翔机、气球和拖曳物体的航空器； 3.4.5. 从一架航空器的后方，在与该航空器对称面小于70 度夹角的航线上向 其接近或者超越该航空器时， 被超越的航空器具有航行优先权。 而超越 航空器不论是在上升、 下降或者平飞时， 均应当向右改变航向给对方让 出航路。 此后二者相对位置的改变并不解除超越航空器的责任， 直至完 全飞越对方并有足够间隔时为止。 3.4.6. 当两架或者两架以上航空器为着陆向同一机场进近， 高度较高的航空器 应当为高度较低的航空器让路， 但后者不能切入另一正在进入着陆最后 阶段的航空器的前方或者超越该航空器。 已经进入最后进近或者正在着 陆的航空器优先于飞行中或者在地面运行的航空器航行。 但是， 不得强 制另一架已经着陆并将脱离跑道的航空器为其让路。 3.4.7. 当得知另一架航空器紧急着陆时，应当为其让出航路。
# -------------------------------------
#
# 片段编号: 3.5.
# 片段内容: 在地面滑行（牵引）时，应按下列规定进行避让： 3.5.1. 飞机应按指定的线路滑行（牵引） ，飞机不得对头滑行； 3.5.2. 交叉相遇时，从驾驶舱左侧看到其它航空器的飞机，应停止滑行。 3.5.3. 在地面滑行的飞机， 应避让正在或即将起飞的其它飞机以及正在着陆或 已处于着陆最后阶段的其它飞机。
# -------------------------------------
#
# 片段编号: 4.
# 片段内容: 避免可控飞行撞地（CFIT） 飞行机组应严格遵守下列规定，避免可控飞行撞地：
# -------------------------------------
#
# 片段编号: 4.1.
# 片段内容: 正确判断飞机位置以及飞机相对于地形或障碍物的安全高度裕度；
# -------------------------------------
#
# 片段编号: 4.2.
# 片段内容: 严格执行标准操作程序，正确使用自动飞行系统，合理利用机组资源；
# -------------------------------------
#
# 片段编号: 4.3.
# 片段内容: 遵守最低安全高度的规定；
# -------------------------------------
#
# 片段编号: 4.4.
# 片段内容: 正确理解空中交通管制指令，对不明确或有疑问的指令应予以证实；
# -------------------------------------
#
# 片段编号: 4.5.
# 片段内容: 对于非精密进近，只要公布的仪表进近程序适用，应使用连续下降最后进近 （CDFA）技术；
# -------------------------------------
#
# 片段编号: 4.6.
# 片段内容: 及时、正确地响应TAWS/GPWS 的警告。
# -------------------------------------
#
# 片段编号: 5.
# 片段内容: 按仪表飞行规则的起飞和着陆
# -------------------------------------
#
# 片段编号: 5.1.
# 片段内容: 除经局方批准外， 在需要仪表进近着陆时， 飞行机组必须使用为该机场制定的 标准仪表离场和进近程序。
# -------------------------------------
#
# 片段编号: 5.2.
# 片段内容: 当飞机在未公布的航路上飞行或者正在被雷达引导， 必须保持空中交通管制最 后指定的高度，直至飞机到达公布的航路或者进入仪表进近程序。此后，除非 空中交通管制另有通知，飞行机组应当按照航路内或者程序中公布的高度下 降。 航空器一旦达到最后进近阶段或者定位点， 飞行机组可以根据局方对该设 施批准的程序完成其仪表进近。
# -------------------------------------
#
# 片段编号: 5.3.
# 片段内容: 当飞机被雷达引导到最后进近航道或者最后进近定位点， 或者从等待点定时进 近，或者程序规定“禁止程序转弯(NOPT)”时，飞行机组不得进行程序转弯。 如果在这些情况下需要进行程序转弯，必须得到空中交通管制许可。
# -------------------------------------
#
# 片段编号: 5.4.
# 片段内容: 仪表着陆系统的基本地面设施应当包括航向台、 下滑台、 外指点标、 中指点标。 标准仪表进近程序中批准使用的测距仪（DME） 、甚高频全向信标（VOR） 、 无方向性信标（NDB）定位点可以用来代替外指点标。
# -------------------------------------
#
# 片段编号: 6.
# 片段内容: 飞行航道 按仪表飞行规则飞行时，飞行机组应当遵守下列规定：
# -------------------------------------
#
# 片段编号: 6.1.
# 片段内容: 在公布的航路上，沿该航路的中心线飞行。
# -------------------------------------
#
# 片段编号: 6.2.
# 片段内容: 除为避开其他航空器或者为改变飞行高度需要偏离航线的机动飞行外， 在任何 其他航线上，飞行机组应沿该航线的导航设施或者定位点之间的连线飞行。 （空白） 设备的使用
# -------------------------------------
#
# 片段编号: 1.
# 片段内容: 机载防撞系统
# -------------------------------------
#
# 片段编号: 1.1.
# 片段内容: 自飞机进入起飞跑道开始， 至着陆后完全脱离跑道为止， 飞行机组应接通机载 防撞系统（TCAS/ACAS）；除机场或飞行程序有特殊要求外，应使用TA/RA 模式，并选择适当的显示距离。
# -------------------------------------
#
# 片段编号: 1.2.
# 片段内容: 在空中和机场活动区运行时， 飞行机组应始终保持警惕， 尽早发现可能的冲突， 并对TCAS/ACAS 信息做出及时、正确的反应。反应迟缓或未按照 TCAS/ACAS 的 RA 指令调整飞行轨迹都将会严重危及飞行安全。
# -------------------------------------
#
# 片段编号: 1.3.
# 片段内容: TCAS/ACAS 的使用： 1.3.1. 交通咨询信息（TA） 1.3.1.1. 不得在未确认冲突飞机的情况下， 仅依据TA 信息而进行机动 飞行。爬升和下降过程中，小范围调整垂直速度不属于机动 飞行； 1.3.1.2. TA 信息出现后， PF 负责监控飞机， 做好执行RA 指令的准备， 循环一次“系好安全带”信号灯（通知客舱飞机可能出现大 幅度姿态变化） ；同时PM 负责参照TA 指示，目视搜索冲突 飞机，并使用时钟参考基准报出冲突飞机的相对方位和相对 高度； 1.3.1.3. TA 信息出现后，飞行机组如认为必要，可向空中交通管制通 报有关情况，并提出请求。 1.3.2. 决断咨询信息（RA） 1.3.2.1. 服从RA 指令的引导是确保安全间隔的强制手段， 除非飞行机 组确认服从该引导将影响飞行安全，否则必须及时、正确地 按照RA 指令操纵飞机； 1.3.2.2. RA 是一个指令信息，不能直接控制飞机，飞行机组必须按其 指令人工操纵飞机； 1.3.2.3. 出现RA 指令后，PF 负责指令操纵飞机或监控自动飞行系统 操纵飞机跟随RA 按照RA 指令，PM 负责确认PF 的操作符 合RA 指令的引导； 1.3.2.4. 按照RA 指令实施避让机动后，应尽快报告空中交通管制。 1.3.3. 冲突解除后，PF 应操纵飞机，以正常的垂直速度和/或转弯速率迅速、 准确地返回许可的航路和剖面后，并及时通知客舱冲突解除；PM 应向 空中交通管制报告偏离许可高度和/或航线情况以及归航情况，并请求 进一步指令。
# -------------------------------------
#
# 片段编号: 1.4.
# 片段内容: ATC 指令与TA 信息/RA 指令不一致时的处置原则： 1.4.1. TA 信息的主要目的是提醒飞行机组存在可能会触发RA 指令的冲突飞 机，并帮助飞行机组目视搜索冲突飞机。未目视确认冲突飞机时，不得 依据TA 信息实施机动飞行； 1.4.2. 当ATC 指令与RA 指令不一致时，必须按照RA 指令实施机动飞行， 然后报告空中交通管制； 1.4.3. 一旦飞机按照RA 指令偏离了当前的ATC 许可，空中交通管制保持受 影响航空器之间间隔的责任就被中止， 飞行机组负责该机与其它航空器 之间的间隔，直到飞行机组报告飞机恢复到原ATC 许可状态或空中交 通管制发布新的许可状态。
# -------------------------------------
#
# 片段编号: 1.5.
# 片段内容: 使用TCAS/ ACAS 的注意事项： 1.5.1. TCAS 无法发现未安装应答机或应答机失效的航空器； 1.5.2. 对于未安装或未使用高度报告功能的航空器，TCAS/ ACAS 只能发出 TA 信息而不能发出RA 指令； 1.5.3. RA 指令不考虑飞机所处环境的地形， 某些情况下不考虑飞机性能限制， 飞行机组必须对地形和飞机状态保持警觉； 1.5.4. 当与失速警告、风切变警告或近地警告相冲突时，RA 指令将被抑制， 仅出现TA 信息。此时，应优先处置失速、风切变或近地警告。
# -------------------------------------
#
# 片段编号: 1.6.
# 片段内容: TCAS/ ACAS 事件报告： 1.6.1. 发生RA 指令事件或其它重要TCAS/ ACAS 事件后，飞行机组应填写 “机长报告书”，并提交至公司安全质量监督管理部。 1.6.2. 内容应包括事件发生的时间、地点、当时的飞行状态、TCAS/ ACAS 的指示或语音告警、 飞行机组采取的措施、 空中交通管制员的指令以及 TCAS/ ACAS 不正常工作情况等。
# -------------------------------------
#
# 片段编号: 1.7.
# 片段内容: TCAS/ ACAS 的标准陆空通话用语详见SOP。
# -------------------------------------
#
# 片段编号: 2.
# 片段内容: 地形提示和警告系统（TAWS/GPWS）
# -------------------------------------
#
# 片段编号: 2.1.
# 片段内容: 公司所有飞机均安装了地形提示和警告系统（TAWS/GPWS），除机型手册 特殊规定外，飞行机组不得擅自抑制TAWS/GPWS。
# -------------------------------------
#
# 片段编号: 2.2.
# 片段内容: 对TAWS/GPWS 警告及时、正确的响应是避免可控飞行撞地的最后措施，飞 行机组必须正确理解TAWS/GPWS 发出的提示和警告信息，并按照机型手册 采取及时、准确的处置。
# -------------------------------------
#
# 片段编号: 3.
# 片段内容: 自动驾驶仪和自动推力的使用
# -------------------------------------
#
# 片段编号: 3.1.
# 片段内容: 除经局方批准的特殊运行（如RNP AR）与进近外，A320 系列机型起飞后高 于机场标高100 英尺以下、 B787 机型起飞后高于机场标高200 英尺以下不得 使用自动驾驶仪（如机型限制数据高于此值，执行机型标准） 。
# -------------------------------------
#
# 片段编号: 3.2.
# 片段内容: 对于进近，断开自动驾驶仪的最晚时机见各机型SOP。
# -------------------------------------
#
# 片段编号: 3.3.
# 片段内容: 公司建议尽可能多地使用自动飞行设备， 以减少工作强度， 并持续保持对自动 飞行装置工作状况的监控。
# -------------------------------------
#
# 片段编号: 3.4.
# 片段内容: 下列情况下应断开自动驾驶仪人工操纵： 3.4.1. 自动驾驶无法保持所需的飞行航径； 3.4.2. 对自动驾驶的工作不满意时； 3.4.3. 各机型手册特定的程序规定。
# -------------------------------------
#
# 片段编号: 3.5.
# 片段内容: 正常情况下自动推力始终保持接通，并持续保持对自动油门工作情况的监控。
# -------------------------------------
#
# 片段编号: 4.
# 片段内容: 飞行机组使用氧气的规定
# -------------------------------------
#
# 片段编号: 4.1.
# 片段内容: 当飞机座舱高度高于3000 米（10000 英尺）时，每一位值勤的飞行机组成员 必须使用氧气，驾驶舱内的氧气面罩必须在随手可取的位置；
# -------------------------------------
#
# 片段编号: 4.2.
# 片段内容: 当飞机发生释压时，飞行机组成员应首先戴上氧气面罩，再执行其他操作。在 释压状态下，正常人的失能时间可能为2 分钟（FL250） 、1 分钟（FL300） 、 15 秒（FL400） ；
# -------------------------------------
#
# 片段编号: 4.3.
# 片段内容: 飞行前， 飞行机组必须对氧气设备进行检查， 并确认氧气压力满足驾驶舱所有 人员用氧要求；
# -------------------------------------
#
# 片段编号: 4.4.
# 片段内容: 当要求某一飞行机组成员用氧时， 他应连续用氧， 但因正常任务所需而取下氧 气面罩或其他氧气分配器的情况除外；
# -------------------------------------
#
# 片段编号: 4.5.
# 片段内容: 应向处于待命状态的或在完成此次飞行前需在驾驶舱内值勤的其他飞行机组 成员供氧， 用氧量应与在驾驶舱内工作的飞行机组成员相同。 如果飞行机组成 员不处于待命状态， 并且在剩下的飞行中将不在驾驶舱内值勤， 就补充供氧而 言，可将其视为一名旅客。
# -------------------------------------
#
# 片段编号: 4.6.
# 片段内容: 驾驶舱固定氧气系统为应急设备， 非必要状况， 任何人不得使用此固定氧气设备。
# -------------------------------------
#
# 片段编号: 5.
# 片段内容: “系好安全带”信号灯的使用
# -------------------------------------
#
# 片段编号: 5.1.
# 片段内容: 飞机在地面的任何移动， 以及每次起飞、 着陆和机长认为必要的其他任何时间， 应当接通“系好安全带”信号灯。
# -------------------------------------
#
# 片段编号: 5.2.
# 片段内容: 飞行关键阶段，飞行机组应保持“系好安全带”信号灯开启。
# -------------------------------------
#
# 片段编号: 5.3.
# 片段内容: 起飞后20 分钟或飞机到达巡航高度且无颠簸时，飞行机组应及时将“系好安 全带”信号灯关闭，并根据实际天气情况开启/关闭“系好安全带”信号灯。
# -------------------------------------
#
# 片段编号: 5.4.
# 片段内容: 飞机到达下降顶点时，飞行机组应打开“系好安全带”信号灯并保持开启直至 发动机关车。
# -------------------------------------
#
# 片段编号: 6.
# 片段内容: 机上休息设施的使用
# -------------------------------------
#
# 片段编号: 6.1.
# 片段内容: 除《最低设备清单》有特殊要求外，飞行机组必需成员在飞行关键阶段应在值 勤位置就坐，不得使用机上休息设施。
# -------------------------------------
#
# 片段编号: 6.2.
# 片段内容: 飞行前准备过程中， 客舱乘务员应对所有机上休息设施及相关的安全设备进行 检查，确认设施完好；如未配备客舱乘务员，此项检查由机长或机长指定的人 员进行。
# -------------------------------------
#
# 片段编号: 6.3.
# 片段内容: 机组人员使用机上休息设施进行休息时，应系好安全带。
# -------------------------------------
#
# 片段编号: 6.4.
# 片段内容: B787 机型配备1 级休息设施，机组应按机型FCOM 的要求使用机上休息室。
# -------------------------------------
#
# 片段编号: 6.5.
# 片段内容: A320 系列机型公务舱座椅均可后仰20 度（从垂直位） ，符合特定机型3 级休 息设施要求。
# -------------------------------------
#
# 片段编号: 6.6.
# 片段内容: 公司优先使用公务舱最后一排C 座作为A320 系列机型3 级休息设施， 实施3 名飞行员扩编机组运行时， 此座位仅可用于飞行机组成员机上休息， 任何人不 得将此座位挪作他用，客舱乘务员应防止该座位被旅客侵占。
# -------------------------------------
#
# 片段编号: 6.7.
# 片段内容: 在使用A320 系列机型3 级休息设施的飞行人员应遵循如下要求： 6.7.1. 必须按本手册HO-0906-8 第2.7 款的要求在3 级休息设施上进行休息； 6.7.2. 在休息期间，不得影响或打扰其他旅客； 6.7.3. 达到机长确定的轮换休息时间时，应及时返回驾驶舱接替轮换； 6.7.4. 如发生特殊情况， 机组应通知乘务长， 由其告知休息人员停止休息返回 驾驶舱。
# -------------------------------------
#
# 片段编号: 6.8.
# 片段内容: A320 系列机型3 级休息设施应按以下流程要求进行座位锁定： 6.8.1. 飞行部应在每次换季前5 个工作日将下一航季实施A320 系列机型扩编 机组运行的具体航班信息提报运网部及地服部； 如在一个航季内发生计 划性新增/减少A320 系列机型扩编机组运行的情况，应至少提前3 个 日历日将需求提报商务部及地服部。 6.8.2. 运网部、 商务部及地服部应根据飞行部提报的航班计划分别在销售系统 及离港系统中锁定相应航班的公务舱最后一排C 座作为A320 系列机 型3 级休息设施。 6.8.3. 对于当日或次日的临时性变更，增加/减少A320 系列机型扩编机组运 行的航班，飞行部应立即与AOC 确认，由AOC 负责座位的临时锁定， 乘务长须将座位信息告知飞行机组。
# -------------------------------------
#
# 片段编号: 6.9.
# 片段内容: A320 系列机型3 级休息设施失效时处理程序： 6.9.1. 如客舱乘务员或维修人员在关舱前发现指定的公务舱座椅无法满足 A320 系列机型3 级休息设施要求，或因临时情况导致指定的公务舱座 椅被旅客占用，AOC 应根据“从左往右、自后向前”的原则选用公务 舱另一符合要求的空余座位作为机上3 级休息设施使用。 6.9.2. 如发生指定的公务舱座椅失效且公务舱无其他空余座位的情况时， AOC 应协调相关席位根据实际情况确定是否执行座椅修复、公务舱旅 客降舱、减客或按非扩编机组运行，以确保公务舱具备一个符合A320 系列机型3 级休息设施要求的空余座位，并通知当班乘务长。 6.9.3. 座位发生变更后，乘务长应立即将更改后的座位信息通知责任机长。 6.9.4. 责任机长应在关舱前向乘务长确认公务舱具备一个符合A320 系列机 型3 级休息设施要求的空余座位，否则不得按3 名飞行员扩编机组运 行。
# -------------------------------------
#
# 片段编号: 7.
# 片段内容: 客舱门的打开与关闭
# -------------------------------------
#
# 片段编号: 7.1.
# 片段内容: 飞机客舱门的打开与关闭， 须由完成相应机型训练并合格的飞行人员、 客舱乘 务员或机务维修人员实施操纵，其他运行人员不得自行打开与关闭客舱门。
# -------------------------------------
#
# 片段编号: 7.2.
# 片段内容: 如需从外部打开客舱门，应由完成相关训练的客舱乘务员或机务维修人员实 施。 驾驶舱的管理
# -------------------------------------
#
# 片段编号: 1.
# 片段内容: 驾驶舱值勤要求
# -------------------------------------
#
# 片段编号: 1.1.
# 片段内容: 在驾驶舱值勤的每个飞行机组必需成员， 在飞行过程中应当坐在指定的值勤位 置并系好安全带； 在飞行关键阶段， 应当坐在指定的值勤位置并系好安全带和 肩带， 但对于驾驶员座位上以外的飞行机组成员， 在履行其正常职责需要时可 以松开肩带。
# -------------------------------------
#
# 片段编号: 1.2.
# 片段内容: 飞行过程中， 如需要换座时候， 应遵守“始终有人在座监控飞机的状态”的原则， 且除紧急和特殊情况外，换座应在巡航阶段实施。
# -------------------------------------
#
# 片段编号: 1.3.
# 片段内容: 在下列情形下,飞行机组必需成员可以离开指定的值勤位置： 1.3.1. 为了完成与飞机运行有关的任务需要该机组成员离开时； 1.3.2. 机组成员的离开与生理需要有关时； 1.3.3. 达到机长确定的轮换休息时间，并按照下述规定接替工作： 1.3.3.1. 对于机长,在航路巡航飞行期间,可以由巡航机长接替; 1.3.3.2. 对于副驾驶,可以由有资格在航路飞行期间担任副驾驶的飞行 员接替。但是接替的飞行员不必满足本手册关于近期经历的 限制。
# -------------------------------------
#
# 片段编号: 2.
# 片段内容: 进入驾驶舱的规定
# -------------------------------------
#
# 片段编号: 2.1.
# 片段内容: 对于商业运行， 自旅客登机开始至所有旅客离机的时间段内， 除机组人员和经 批准人员外，任何人不得进入驾驶舱；
# -------------------------------------
#
# 片段编号: 2.2.
# 片段内容: 下列人员可以进入驾驶舱，但机长有权为了安全而要求其离开驾驶舱： 2.2.1. 机组成员； 2.2.2. 正在执行任务的局方监察员、局方委任代表或公司飞行检查员； 2.2.3. 得到机长允许并且其进入驾驶舱对于安全运行是必需或者有益的人员 包括： 2.2.3.1. 局方批准进行空中交通管制程序观察的空中交通管制员； 2.2.3.2. 经运行副总裁批准进行航线实习的公司飞行签派员、航行情 报员、航空气象员、飞机性能工程人员； 2.2.3.3. 经机长请求并核实身份的航空器维修人员； 2.2.3.4. 应急情况下实施紧急医疗救助的医护人员； 2.2.3.5. 其他因空中应急、救助、维修、飞行技术指导等需进入驾驶 舱的人员。 2.2.4. 经机长同意，并获得公司批准的其他人员。
# -------------------------------------
#
# 片段编号: 2.3.
# 片段内容: 获得公司批准的其他人员进入驾驶舱，应当持有公司总裁签发的批准书原件， 批准书应当列明姓名、证件类型、证件号码、日期、航班号、事由、批准人签 字等要素，并加盖上海吉祥航空股份有限公司公章。
# -------------------------------------
#
# 片段编号: 2.4.
# 片段内容: 被准许进入驾驶舱的非机组人员， 应当在客舱内有供该人员使用的座位， 但按 照3.1 在驾驶舱有供其使用的座位的人员除外。
# -------------------------------------
#
# 片段编号: 2.5.
# 片段内容: 对于2.2.2、 2.2.3、 2.2.4 中规定的人员进入驾驶舱的， 应当采取下列安保措施： 2.5.1. 航空安全员应当核对证件确保人证相符，同时开启执勤记录仪全程记 录人员进出情况； 2.5.2. 如驾驶舱或客舱环境不能满足安全条件时，人员应暂缓进入驾驶舱； 2.5.3. 每次进入驾驶舱的人数不得超过驾驶舱内空余的观察员座位数，最大 不超过两人； 2.5.4. 人员在驾驶舱内停留期间，在驾驶舱内的机组人员不得少于两人且确 保驾驶舱门锁闭，驾驶舱门口应当至少有一名航空安全员或客舱乘务 员值守； 2.5.5. 驾驶舱门开启期间，机组应当做好驾驶舱的保护。
# -------------------------------------
#
# 片段编号: 2.6.
# 片段内容: 局方监察员、局方委任代表或公司飞行检查员执行监察/检查任务时，出示相 应的身份证明证件后，机长必须允许该监察员/局方委任代表/公司飞行检查员 不受阻碍地进入驾驶舱。
# -------------------------------------
#
# 片段编号: 2.7.
# 片段内容: 机长允许除2.2 中规定以外的人员进入驾驶舱时，其他机组成员应予以劝阻。
# -------------------------------------
#
# 片段编号: 2.8.
# 片段内容: 在地面阶段， 客舱乘务教员在获得机长许可的情况下， 可带领客舱乘务学员进 入驾驶舱开展航线带飞教学任务。教学期间，客舱乘务教员/学员必须注意周 围环境防止误碰，除座椅外不得触动驾驶舱内任何手柄、旋钮、开关、电门或 其他设备，机长或机长指定的一名飞行人员应全程监控。
# -------------------------------------
#
# 片段编号: 3.
# 片段内容: 驾驶舱观察员座位的使用
# -------------------------------------
#
# 片段编号: 3.1.
# 片段内容: 允许使用驾驶舱观察员座位的人员范围，包括： 3.1.1. 机组成员； 3.1.2. 正在对飞行操作进行检查或者观察的局方监察员或者经授权的局方委 任代表（可优先选择任意观察员座椅） ； 3.1.3. 局方批准进行空中交通管制程序观察的空中交通管制员； 3.1.4. 公司空勤人员以及随机放行的维修工程人员； 3.1.5. 进行航线实习的公司飞行签派员、公司专职模拟机教员； 3.1.6. 其他航空公司雇用的持有执照航空人员，该人员得到公司总裁的批准； 3.1.7. 本公司雇员，其职责与飞行运作的实施或者计划、或者空中监视飞机 设备或者操作程序直接有关，此人进入驾驶舱对于完成其任务是必需 的，并且已得到公司总裁的书面批准； 3.1.8. 该飞机或者其部件的制造厂家技术代表，其职责与空中监视飞机设备 或者操作程序直接有关，进入驾驶舱对于完成其职责是必需的，并已 得到公司总裁的书面批准。
# -------------------------------------
#
# 片段编号: 3.2.
# 片段内容: 公司在驾驶舱内备有一个座位， 供局方实施航路监察时使用， 使用向前的观察 员座位或者其他座位由局方来指定，A320 系列机型一般优先使用第三观察员 座椅，B787 机型一般优先使用第一观察员座椅。
# -------------------------------------
#
# 片段编号: 4.
# 片段内容: 驾驶舱门的关闭和锁定
# -------------------------------------
#
# 片段编号: 4.1.
# 片段内容: 对于商业运行， 自旅客登机开始至全部旅客完成下机的时间段内， 应关闭并锁 定驾驶舱门；
# -------------------------------------
#
# 片段编号: 4.2.
# 片段内容: 在执行任务的机组成员或本章节2.2 及3.1 中经批准的人员有必要进入或离开 驾驶舱时， 在打开驾驶舱门之前， 驾驶舱人员应使用观察孔或电子监控装置识 别请求进入驾驶舱的人员并检查驾驶舱门周围状况；
# -------------------------------------
#
# 片段编号: 4.3.
# 片段内容: 非正常状态着陆前，可以考虑将驾驶舱门打开。
# -------------------------------------
#
# 片段编号: 5.
# 片段内容: 驾驶舱内最低机组成员人数
# -------------------------------------
#
# 片段编号: 5.1.
# 片段内容: 在航班飞行过程中，驾驶舱内应保持至少有两名机组成员。
# -------------------------------------
#
# 片段编号: 5.2.
# 片段内容: 只有由于工作或生理原因，方允许一名飞行机组必需成员离开指定的值勤位 置，但应在最短的时间内回到岗位上。
# -------------------------------------
#
# 片段编号: 5.3.
# 片段内容: 留在驾驶舱的飞行员必须保持对飞机的监控，不得从事与飞行无关的活动。
# -------------------------------------
#
# 片段编号: 5.4.
# 片段内容: 当机长离开驾驶舱时， 机长应授权副驾驶负责航空器的控制并处理任何特殊状 态下的飞行，直至机长返回后由机长行使其职权。
# -------------------------------------
#
# 片段编号: 5.5.
# 片段内容: 当仅有两名飞行员在驾驶舱内值勤时， 其中一名在值勤岗位的飞行员由于工作 或生理原因需要离开驾驶舱时， 应指定不在值勤岗位的飞行机组成员或由机长 通知乘务长指定2 号客舱乘务员进入驾驶舱，直至该名飞行员返回。
# -------------------------------------
#
# 片段编号: 5.6.
# 片段内容: 进入驾驶舱的客舱乘务员应在观察员座椅就坐并系好安全带； 同时应熟悉 《驾 驶舱-非必需机组成员简介》 。
# -------------------------------------
#
# 片段编号: 5.7.
# 片段内容: 进入驾驶舱的客舱乘务员不得参与对飞机的操作。
# -------------------------------------
#
# 片段编号: 6.
# 片段内容: 驾驶舱物品的固定 飞行机组应当确保每项设备、每件装在飞机驾驶舱的机组行李（含大件物品） ，能够 承受相应于该飞机型号合格审定应急着陆状态的载荷系数下的载荷，并保证其摆放 的稳定性，不至于因移动而造成危害。 （空白） 飞行前准备和飞行后讲评
# -------------------------------------
#
# 片段编号: 1.
# 片段内容: 概述
# -------------------------------------
#
# 片段编号: 1.1.
# 片段内容: 飞行前准备包括预先准备和直接准备两部分， 预先准备可以是集体准备或网上 准备。
# -------------------------------------
#
# 片段编号: 1.2.
# 片段内容: 飞行前准备和飞行后讲评包括所有机组成员。
# -------------------------------------
#
# 片段编号: 1.3.
# 片段内容: 飞行部、客舱部、航空安保部、江苏分公司应对所属空勤人员的预先准备以及 直接准备的完成情况和质量进行监控。
# -------------------------------------
#
# 片段编号: 1.4.
# 片段内容: 未按本章节规定完成飞行前准备的机组成员不得参加航班运行。
# -------------------------------------
#
# 片段编号: 2.
# 片段内容: 预先准备
# -------------------------------------
#
# 片段编号: 2.1.
# 片段内容: 除本章节2.4 款的要求以外， 机组成员必须在航班起飞前48 小时至起飞前12 小时之间在吉祥航空飞行/客舱准备网完成预先准备， 准备时间不少于30 分钟。
# -------------------------------------
#
# 片段编号: 2.2.
# 片段内容: 预先准备的内容至少包括：领受任务、明确任务性质、起飞时间和其他相关要 求。
# -------------------------------------
#
# 片段编号: 2.3.
# 片段内容: 对于飞行机组成员在预先准备过程中应研究起飞、 降落和备降机场、 航线或者 飞行区域有关资料， 初步了解飞机状况， 阅读公司的相关通告， 了解天气形势， 确认EFB 终端设备中航图及手册资料的有效性以及检查云执照经历信息填写 与确认情况等。
# -------------------------------------
#
# 片段编号: 2.4.
# 片段内容: 重要飞行任务如新开航线、 专机、 包机或其它特殊航班的预先准备根据需要应 进行集体准备。
# -------------------------------------
#
# 片段编号: 3.
# 片段内容: 直接准备
# -------------------------------------
#
# 片段编号: 3.1.
# 片段内容: 飞行机组成员必须在进场时间15 分钟前到达指定地点签到并进行直接准备， 进场时间由所在运行单位根据运行实际进行确定；
# -------------------------------------
#
# 片段编号: 3.2.
# 片段内容: 到达签到地点后，全体机组成员必须首先接受航前酒精测试及航前体检；
# -------------------------------------
#
# 片段编号: 3.3.
# 片段内容: 机长负责领取并核对当日及过夜（如适用）飞行任务书，确认个人信息准确， 确保所持有飞行任务书中各内容、要素齐全有效；
# -------------------------------------
#
# 片段编号: 3.4.
# 片段内容: 对于过夜或回程更换飞行机组的情况， （主任）乘务长负责打印并携带回程任 务书， 组织客舱机组与安保组成员核对个人信息， 并根据准备网核对回程飞行 机组信息；对于客舱机组、安保组单独进场的情况，应自行打印并确认个人信 息准确，任务书各要素齐全。
# -------------------------------------
#
# 片段编号: 3.5.
# 片段内容: 机长组织召开飞行机组准备会，了解机组成员的技术状况，明确机组分工，检 查并确认各类证照/文件以及飞行装具齐全有效、着装/仪表符合公司规定，检 查确认个人EFB 终端设备中软件及数据库版本最新有效。同时，机长应对每 位机组必需成员云执照中的相关信息进行检查确认；
# -------------------------------------
#
# 片段编号: 3.6.
# 片段内容: （主任）乘务长组织召开客舱机组准备会，检查并确认客舱机组各类证照、文 件及装具齐全有效、仪容仪表符合公司规定、明确号位分工、并讲解航班任务 特点及要求等；
# -------------------------------------
#
# 片段编号: 3.7.
# 片段内容: 航空安全员应检查确认各类证照/资料齐全有效，着装/仪表符合公司规定，并 领取执勤装具， 确认装具齐全有效； 对于有特殊安保要求的航线还应领取爆炸 物探测仪，由安保组组长检查探测仪及配件齐全有效；
# -------------------------------------
#
# 片段编号: 3.8.
# 片段内容: 执行国际（地区）航班时，全体机组成员还应检查核对各自护照、港澳台通行 证等证件携带情况与有效性；
# -------------------------------------
#
# 片段编号: 3.9.
# 片段内容: 飞行机组应领取/下载飞行资料，包括飞行计划、气象资料、航行通告、签派 单等，检查并确认齐全有效；
# -------------------------------------
#
# 片段编号: 3.10.
# 片段内容: 飞行机组成员应阅读气象简报，了解起飞机场、航路、目的地机场及备降场天 气实况及预报，知晓可能发生空中颠簸的区域和强度，拟订安全飞行方案；
# -------------------------------------
#
# 片段编号: 3.11.
# 片段内容: 飞行机组成员应阅读航行通告 （重点确认航路是否有变化， 导航设备是否提供 服务，跑道和进近导航是否可使用等相关信息） ；
# -------------------------------------
#
# 片段编号: 3.12.
# 片段内容: 机长应确认飞机适航状态，对于保留故障根据MEL/CDL 制定相关预案；
# -------------------------------------
#
# 片段编号: 3.13.
# 片段内容: 机长应确认飞行签派员放行讲解信息；
# -------------------------------------
#
# 片段编号: 3.14.
# 片段内容: 机长应检查运行飞行计划，根据飞机状况、天气报告等，确定飞机燃油信息， 由机长与飞行签派员共同在签派单上签字（手工或电子形式） ；
# -------------------------------------
#
# 片段编号: 3.15.
# 片段内容: 为使飞行机组和客舱机组形成一个团队概念，加强沟通和配合，统一认识，牢 记职责，保证运行安全和服务质量。机长应召集所有飞行机组、客舱乘务员及 航空安全员进行协同准备，至少包括以下内容： 3.15.1. 机组成员介绍， （主任）乘务长和航空安全员向机长报告准备完成情 况，并报告各组员的装具、证照、文件及资料携带核查情况。 3.15.2. 机长通报因公加入机组人员、 非因公加入机组人员以及该航班是否为 扩编机组运行。 3.15.3. 机组交叉检查《飞行任务书》以及《出入境飞机及员工登记表》 、 《出 入境航空器工作人员携带物品清单》 （如适用） ， 确认机组成员和加入 机组人员的信息准确有效。 3.15.4. 机长通报预计滑行时间、飞行时间、到达巡航高度时间、可用服务时 间、有无延误情况。 3.15.5. 机长通报航班运行天气状况， 是否存在恶劣天气影响， 告知客舱机组 拟执行的除防冰程序、 甩冰程序以及已获取的颠簸区域、 强度和持续 时间，协同制定相关预案。 3.15.6. 机长通报飞机状况以及客舱设备故障保留情况，协同制定应对方案。 3.15.7. 机长明确正常情况与非正常情况下机组成员间的联络要求。 3.15.8. 机长按需明确发生紧急情况时驾驶舱联系客舱的术语及指令。 3.15.9. 如发生机组失能情况下， 机上指挥权的接替次序： 责任机长→巡航机 长→副驾驶→ （主任） 乘务长→区域乘务长→客舱乘务员→航空安全 员。 （按等级排列，高者优先） 。 3.15.10. 如发生PED 以及锂电池起火情况，明确沟通关键环节，要求先处置 再报告。 3.15.11. （主任）乘务长通报要客、担架旅客以及机上用氧旅客信息，以及本 航班服务程序所需时间，按需协同保障预案。 3.15.12. 航空安全员通报航线派遣标准、押解犯罪嫌疑人（罪犯）及遣返旅客 情况、当前空防形势和重点关注事项，飞机安保检查的各项要求，复 习驾驶舱门密码。 3.15.13. 机长根据空防形势组织协同突发事件/非法干扰/扰乱航空器秩序等行 为的处置预案，明确机组分工，确定联络暗号和处置程序。 3.15.14. 需各岗位协同配合的其他事宜。
# -------------------------------------
#
# 片段编号: 3.16.
# 片段内容: 对于仅客舱机组与安保组进场的情况，在进场前， （主任）乘务长负责本章节 3.15.1 以及3.15.2 条的检查确认。
# -------------------------------------
#
# 片段编号: 3.17.
# 片段内容: 外站过夜航班，机组成员应在酒店配备的机组准备室中完成飞行前直接准备； 如酒店无相应场所，飞行机组、客舱乘务员、航空安全员可在机组车上或者机 场候机厅（通过机场安检之前）完成飞行前直接准备。
# -------------------------------------
#
# 片段编号: 3.18.
# 片段内容: 外站运行或过站更换机组成员时， 机组成员应最晚在登机后完成机组协同准备 工作。
# -------------------------------------
#
# 片段编号: 3.19.
# 片段内容: 如果航班延误超过24 小时，应重新完成飞行直接准备流程。
# -------------------------------------
#
# 片段编号: 3.20.
# 片段内容: 连续飞行时， 机组不需要进行签到。 除本章节3.9 至3.14 以及3.15.3、3.15.4 条必须执行外，可以根据实际情况、按照机型程序省略部分准备项目；除此之 外，应完成完整的飞行前直接准备。
# -------------------------------------
#
# 片段编号: 4.
# 片段内容: 机组到场时间
# -------------------------------------
#
# 片段编号: 4.1.
# 片段内容: 对于始发航班或过站时间1 小时及以上的非始发航班， 全体机组成员应在计划 /预计起飞时刻前至少1 小时到达现场，对于过站时间不足1 小时的非始发航 班，全体机组成员应不晚于前段航班开舱门时刻到达停机位。
# -------------------------------------
#
# 片段编号: 5.
# 片段内容: 机组飞行后讲评
# -------------------------------------
#
# 片段编号: 5.1.
# 片段内容: 飞行后，飞行机组应进行与飞行程序、技术、安全相关的常规讲评；客舱机组 应对客舱安全及服务方面的工作进行总结。
# -------------------------------------
#
# 片段编号: 5.2.
# 片段内容: 飞行中出现非正常情况时，应进行专项讲评；必要时，飞行机组、客舱机组、 安保组及AOC 相关人员应进行集体讲评；
# -------------------------------------
#
# 片段编号: 5.3.
# 片段内容: 对于飞行中出现的问题或事件，机长、客舱（主任）乘务长、航空安全员应按 照规定履行相应的报告职责。 （空白） 地面准备
# -------------------------------------
#
# 片段编号: 1.
# 片段内容: 应急设备检查 公司运行的所有飞行任务（包括商业运行、或本场训练、调机等非商业运行）必须 按本条要求在飞行前进行应急设备检查。
# -------------------------------------
#
# 片段编号: 1.1.
# 片段内容: 飞行机组登机后应完成驾驶舱应急设备的飞行前检查，确认应急设备数量和 位置，并确保其完好有效、易获取且可以使用。
# -------------------------------------
#
# 片段编号: 1.2.
# 片段内容: 客舱机组登机后应完成客舱应急设备的飞行前检查，确认应急设备数量和位 置，并确保其完好有效、易获取且可以使用。
# -------------------------------------
#
# 片段编号: 1.3.
# 片段内容: 当飞行机组值勤期内首次进入飞机驾驶舱，或飞行机组发生更换，或全部机 组离开航空器并再次进入时，必须按本章节1.1 的要求执行应急设备检查。
# -------------------------------------
#
# 片段编号: 1.4.
# 片段内容: 当客舱机组值勤期内首次进入客舱，或客舱机组、飞行机组发生更换，或全 部机组离开航空器并再次进入时，必须按本章节1.2 的要求执行应急设备检 查。
# -------------------------------------
#
# 片段编号: 1.5.
# 片段内容: 如无客舱机组，由责任机长指定飞行机组成员按本章节1.2 的要求对客舱应 急设备进行检查。
# -------------------------------------
#
# 片段编号: 2.
# 片段内容: 机上安保检查
# -------------------------------------
#
# 片段编号: 2.1.
# 片段内容: 旅客登机前，责任机长应组织机组成员根据各自分工对驾驶舱及客舱各部位 进行安保检查。
# -------------------------------------
#
# 片段编号: 2.2.
# 片段内容: 飞行机组应根据机型SOP 要求进行驾驶舱安保检查以及驾驶舱门的密码测 试。
# -------------------------------------
#
# 片段编号: 2.3.
# 片段内容: 客舱机组与航空安全员应按“由前往后，由上到下，由左到右”的原则，对 责任区域进行严格检查，同时相互协调配合，确保检查范围无死角，同一位 置不重复检查，具体责任区域如下： 2.3.1. 航空安全员责任区域包括： 2.3.1.1. 行李架； 2.3.1.2. 旅客座椅，包括座椅下方及周围、座椅背面书报存放处、联 排座椅之间缝隙处、座椅靠垫和坐垫、座椅下方救生衣存放 处； 2.3.1.3. 客舱过道、地板、舱顶及四周壁板； 2.3.1.4. 厕所，包括储物盒、纸巾存放处、垃圾桶、洗手池下方区 域、婴儿护理板； 2.3.1.5. 飞行机组休息室与客舱机组休息室，包括座椅及铺位周围。 2.3.2. 客舱机组责任区域包括： 2.3.2.1. 客舱乘务员座椅，包括座椅下方及周围； 2.3.2.2. 客舱内衣帽间； 2.3.2.3. 储物盒/柜； 2.3.2.4. 应急设备存放处； 2.3.2.5. 厨房（包括工作台、烤箱、储物柜、餐车、备份箱等区 域） 。
# -------------------------------------
#
# 片段编号: 2.4.
# 片段内容: 航空安全员与（主任）乘务长确认安保检查完成后，由航空安全员向责任机 长报告客舱安保检查完成。
# -------------------------------------
#
# 片段编号: 2.5.
# 片段内容: 如检查中发现可疑物品时，任何人不得触碰，应立即通知航空安全员进行核 查，确系疑似武器、爆炸物等危险违禁物品时，航空安全员应将相关情况告 知责任机长并提出报警需求，由责任机长联系机场指挥中心申请机场公安进 行现场处置，并将相关情况报告公司AOC。
# -------------------------------------
#
# 片段编号: 3.
# 片段内容: 燃油加注
# -------------------------------------
#
# 片段编号: 3.1.
# 片段内容: 责任机长应根据飞行计划与飞行签派员共同决定加油量。如需更改加油量， 责任机长应通知飞行签派员修改燃油计划，并根据本手册HO-0908-13 章节 要求执行最后一分钟修正或重新制作载重平衡舱单。
# -------------------------------------
#
# 片段编号: 3.2.
# 片段内容: 加、放（抽）燃油时，飞行机组应执行以下安全措施： 3.2.1. 所有发动机关车； 3.2.2. 机上雷达设备停止使用； 3.2.3. HF 高频发射机停止使用； 3.2.4. 不接通或断开地面电源； 3.2.5. 禁止操作燃油系统的任何跳开关； 3.2.6. “禁止吸烟”信号灯接通。
# -------------------------------------
#
# 片段编号: 3.3.
# 片段内容: 飞行机组成员应对加注燃油量进行确认、核实燃油型号、确定燃油冰点温 度，并对燃油加注过程进行持续监控。如需实施旅客登机、下机或在飞机上 时的加油程序，机长应配合燃油加注工作人员在载客加油通知单上完成签字 确认。
# -------------------------------------
#
# 片段编号: 3.4.
# 片段内容: 对于B787 机型，一般情况下由燃油加注工作人员负责加油面板的操作。如 遇工作人员无机型操作资质，则由机务人员协助其操作。对于特殊情况下加 油现场无符合资质的工作人员与机务人员时，则由责任机长或责任机长指定 的飞行机组成员进行面板操作。
# -------------------------------------
#
# 片段编号: 3.5.
# 片段内容: 一般加油程序 3.5.1. 开始加油时，飞行机组成员应通知（主任）乘务长“开始加油程序” 。 3.5.2. （主任）乘务长应确认至少打开一个门连接登机桥或客梯车，同时通 知机上乘员飞机正在加油，不要使用厕所、禁止吸烟、不要使用手机 等电子设备；客舱机组应确保客舱内至登机桥或客梯车的过道和通道 畅通，以供应急撤离。 3.5.3. 加注期间，飞行机组成员应持续监控，并与加油设备操纵人员、客舱 机组、机务维修人员保持联系，视情发布相关指令。 3.5.4. 加注完成后，飞行机组成员应通知（主任）乘务长“加油结束” ，并检 查实际总油量与要求的是否一致，确认加油口、加油面板盖好，检查 加油口附近机翼无损坏，按实际加油数据填写飞机加油单，加油单上 所列各项内容均应填写完整，并保持字迹清晰。收到飞行机组加油结 束的通知后， （主任）乘务长应通知机上乘员加油完毕，厕所、手机等 电子设备可以正常使用，禁止吸烟。
# -------------------------------------
#
# 片段编号: 3.6.
# 片段内容: 有旅客登机、下机或在飞机上时的补充程序 3.6.1. 如燃油加注过程中飞机上载有旅客（包括旅客正在登机、离机或已登 机完毕） ，在执行本章节3.5 条程序的基础上，加注期间还应补充执行 以下要求： 3.6.1.1. 开始加注时，飞行机组成员关断“系好安全带”信号灯以提 示乘客保持安全带解锁； 3.6.1.2. 客舱乘务员应广播通知旅客飞机正在加油，请旅客尽快入座 （登机时）/尽快下机（下机时）/在原位就坐（在飞机上 时） 、解开安全带、不要使用厕所、禁止吸烟、不要使用手 机等电子设备； 3.6.1.3. 同时客舱机组应均匀分布在每对应急出口处，引导旅客尽快 入座（登机时）/尽快下机（下机时）/在原位就坐（在飞机 上时） ，避免造成客舱内过道和通道拥堵； 3.6.1.4. 责任机长应指定一名飞行机组成员监控地面加油情况，并保 持与驾驶舱、加油设备操纵人员以及机务维修人员的联系。 如发生溢油、火情等意外情况时，监控加油的飞行人员应立 即通知驾驶舱以及机务维修人员进行处置。 3.6.1.5. 加油结束后，飞行机组应打开“系好安全带”信号灯。 3.6.2. 燃油加注期间，地面保障人员应控制旅客登机速度，防止廊桥或客梯 车上的旅客积压，避免在紧急情况下影响应急撤离和疏散的速度。 3.6.3. 燃油加注期间，地面保障人员应确保飞机安全门下方被指定用于快速 离机或紧急疏散的地面区域保持畅通。
# -------------------------------------
#
# 片段编号: 3.7.
# 片段内容: 如燃油加注过程中出现不正常情况，飞行机组应立即发布指令停止加油；如 发生火灾或燃油外溢，机组应立即联系在场机务维修人员以及机场当局，并 告知相关情况。
# -------------------------------------
#
# 片段编号: 4.
# 片段内容: 驾驶舱准备
# -------------------------------------
#
# 片段编号: 4.1.
# 片段内容: 飞行机组应根据各机型SOP 要求进行驾驶舱准备工作。
# -------------------------------------
#
# 片段编号: 5.
# 片段内容: 客舱准备
# -------------------------------------
#
# 片段编号: 5.1.
# 片段内容: 客舱乘务员应根据《客舱乘务员手册》及公司服务政策要求开展机上准备工 作。
# -------------------------------------
#
# 片段编号: 5.2.
# 片段内容: 准备过程中，客舱乘务员应根据机供品的标准配备数量进行检查核对，确保 摆放的机供品不得超过存放区域最大载荷标准。
# -------------------------------------
#
# 片段编号: 6.
# 片段内容: 旅客登机
# -------------------------------------
#
# 片段编号: 6.1.
# 片段内容: 仅在（主任）乘务长确认客舱准备完成以及航空安全员确认安保检查完成 后，责任机长方可允许旅客登机。
# -------------------------------------
#
# 片段编号: 6.2.
# 片段内容: 地面保障人员在获得责任机长的旅客登机指令后，方可组织旅客办理登机手 续。
# -------------------------------------
#
# 片段编号: 6.3.
# 片段内容: 旅客登机时，客舱乘务员应均匀分布在客舱每对出口附近，以便在紧急情况 下最有效地帮助旅客撤离。
# -------------------------------------
#
# 片段编号: 6.4.
# 片段内容: 登机过程中，客舱乘务员应对旅客行李的尺寸、数量进行确认，对于超规行 李应予以拦截，并通知地面保障人员进行处理。
# -------------------------------------
#
# 片段编号: 6.5.
# 片段内容: 旅客开始登机至舱门关闭期间，除正常报告程序和影响安全运行的事项外， 飞行机组与客舱机组应尽可能保持双向静默，避免互相干扰。
# -------------------------------------
#
# 片段编号: 6.6.
# 片段内容: 当发生旅客登机后要求终止行程，航空安全员应与客舱机组确认其登机后轨 迹并向责任机长进行报告。如能确定该旅客登机后只在自己座位上逗留，没 有去过客舱的其他地方时，则可执行局部安保检查，否则应重新进行全部安 保检查。
# -------------------------------------
#
# 片段编号: 6.7.
# 片段内容: 当发生以下情况时，责任机长必须指令进行全部安保检查： 6.7.1. 登机后公安、安检怀疑旅客存在漏检时； 6.7.2. 登机后机组人员对旅客的安检质量产生质疑； 6.7.3. 未经安全检查的人员和物品进入航空器； 6.7.4. 其他任何可能危及安全的情况。
# -------------------------------------
#
# 片段编号: 6.8.
# 片段内容: 如确定执行局部安保检查/全部安保检查程序，飞行机组应将相关情况报告公 司AOC。 舱门的关闭与打开
# -------------------------------------
#
# 片段编号: 1.
# 片段内容: 舱门的关闭
# -------------------------------------
#
# 片段编号: 1.1.
# 片段内容: 当飞机舱门处于打开状态时，此门通常被认为是主应急出口， （主任）乘务长 应确保廊桥/客梯车与飞机保持连接状态。
# -------------------------------------
#
# 片段编号: 1.2.
# 片段内容: 关闭舱门前，机长应确认： 1.2.1. 飞机已完成加油工作； 1.2.2. 机务人员完成放行工作，并在FLB 上签署放行； 1.2.3. 飞行必备文件齐全有效； 1.2.4. 驾驶舱内无与该次航班无关的人员。
# -------------------------------------
#
# 片段编号: 1.3.
# 片段内容: （主任）乘务长应根据《客舱乘务员手册》完成舱门关闭前各项工作后，请示 机长关门许可。得到许可后方可操纵关闭舱门。
# -------------------------------------
#
# 片段编号: 1.4.
# 片段内容: 所有舱门待命好后，机长应确认所有舱门关闭/滑梯待命情况；对不正常的舱 门状态，机长必须要求（主任）乘务长将舱门调置到正常状态。所有舱门待命 完成之前，飞机不得移动。
# -------------------------------------
#
# 片段编号: 1.5.
# 片段内容: 舱门关闭后因其他原因需重新开启舱门时， （主任）乘务长应及时将情况向机 长报告，经机长同意后，客舱机组应按《客舱乘务员手册》要求进行滑梯和舱 门开启的操作。
# -------------------------------------
#
# 片段编号: 1.6.
# 片段内容: 对于任何不载运旅客的飞行， 且未配备客舱乘务员时， 由机长负责滑梯待命和 关闭舱门操纵。机长在执行待命操纵后，副驾驶须进行交叉检查，确认滑梯已 完成待命。
# -------------------------------------
#
# 片段编号: 2.
# 片段内容: 舱门的打开
# -------------------------------------
#
# 片段编号: 2.1.
# 片段内容: 客舱灯光调节完毕后， （主任）乘务长立即组织客舱机组按《客舱乘务员手册》 要求执行舱门解除滑梯待命操作程序。
# -------------------------------------
#
# 片段编号: 2.2.
# 片段内容: 完成舱门滑梯解除待命操作程序后， （主任）乘务长应立即与机长确认滑梯已 解除待命， 机长应在驾驶舱检查确认所有舱门的滑梯状态已解除待命。 如因特 殊情况需延迟开启舱门时，机长应将相关信息立即告知（主任）乘务长。
# -------------------------------------
#
# 片段编号: 2.3.
# 片段内容: 地面保障人员在确认各地面保障设施到位后，应向客舱机组发出可以开门信 号。 地面保障人员可采取敲击客舱门等方式提供开门信号， 且舱门打开过程中 不得站在客舱门口。
# -------------------------------------
#
# 片段编号: 2.4.
# 片段内容: 客舱机组在获得地面保障人员开门信号且确认滑梯已解除待命后， 方可打开舱 门。
# -------------------------------------
#
# 片段编号: 2.5.
# 片段内容: 对于任何不载运旅客的飞行， 且未配备客舱乘务员时， 由机长负责解除滑梯待 命和开启舱门。机长在解除待命后，副驾驶须进行交叉检查，确认滑梯已解除 待命。
# -------------------------------------
#
# 片段编号: 2.6.
# 片段内容: 如舱门因结冰无法正常打开时， 机组应联系机务进行处理， 不得自行强行开启。 （空白） 离机
# -------------------------------------
#
# 片段编号: 1.
# 片段内容: 旅客全部下机前
# -------------------------------------
#
# 片段编号: 1.1.
# 片段内容: 在旅客完全离开飞机前， 机组不可以关闭音频按钮， 仍需监控塔台或地面频率。
# -------------------------------------
#
# 片段编号: 1.2.
# 片段内容: 在旅客完全离开飞机前， 机组不可以离开飞机， 如果因工作或生理的原因需要 离开，机长应根据实际情况至少安排一名航空安全员负责飞机的安全。
# -------------------------------------
#
# 片段编号: 1.3.
# 片段内容: 在旅客完全离开飞机前， 应至少打开一个与地板同高度的舱门， 并且舱门外应 有廊桥或客梯。保持飞机内、外所有撤离通道畅通。
# -------------------------------------
#
# 片段编号: 2.
# 片段内容: 记录与报告
# -------------------------------------
#
# 片段编号: 2.1.
# 片段内容: 飞行结束后，飞行机组应如实填写云执照飞行经历记录以及《飞行记录本》 。
# -------------------------------------
#
# 片段编号: 2.2.
# 片段内容: 机长应将飞行中发生的故障情况如实记入《技术记录本》 （TLB） ； （主任）乘 务长应将客舱内各类设施设备的故障、 缺陷或缺失等情况如实记入 《客舱记录 本》 （CLB） 。
# -------------------------------------
#
# 片段编号: 3.
# 片段内容: 中途过站
# -------------------------------------
#
# 片段编号: 3.1.
# 片段内容: 如地面电源车、辅助动力装置或发动机在运转中，但缺少专业人员负责时，飞 行机组成员不得离机。
# -------------------------------------
#
# 片段编号: 3.2.
# 片段内容: 任何机组成员需要离机，必须经机长同意并及时返回。
# -------------------------------------
#
# 片段编号: 3.3.
# 片段内容: 驾驶舱应始终保持至少有一名飞行机组成员，并完成下列工作： 3.3.1. 完成驾驶舱的各项准备工作； 3.3.2. 监控APU、地面电源、气源车等工作情况； 3.3.3. 禁止未经批准的人员进入驾驶舱； 3.3.4. 了解航路及目的地机场和备降机场天气状况以及航行通告等信息， 办理 放行手续； 3.3.5. 遇有不正常情况或飞机故障，应及时与机务联系，尽快处置。
# -------------------------------------
#
# 片段编号: 3.4.
# 片段内容: 中途过站经停时， 除非机场要求不得下机， 客舱机组应通知所有旅客在航空器 停靠好以后， 带好所有手提行李和个人物品离开航空器， 并配合航空安全员进 行安保检查工作，防止不明外来、遗留物品留在客舱。
# -------------------------------------
#
# 片段编号: 3.5.
# 片段内容: 在中途过站停留时， 如果乘坐该机的旅客仍停留在飞机上， 且保留在飞机上的 客舱乘务员数量少于该机型客舱乘务员最低配备数，则应遵守下列要求： 3.5.1. 保证飞机发动机关车并且至少保持打开一个地板高度出口， 供旅客下飞 机。 3.5.2. 至少保留客舱乘务员数量要求： 机型 至少保留客舱乘务员数 A320CEO/A320NEO 2 A321CEO 4 A321NEO ACF 3 B787-9 5 3.5.3. 可以用当班航空安全员代替要求的客舱乘务员。
# -------------------------------------
#
# 片段编号: 3.6.
# 片段内容: 保留在飞机上的客舱乘务员或航空安全员应当分布在客舱每对舱门附近， 以便 在紧急情况下最有效地帮助旅客撤离。
# -------------------------------------
#
# 片段编号: 4.
# 片段内容: 目的地站
# -------------------------------------
#
# 片段编号: 4.1.
# 片段内容: 机组在完成飞行任务到达目的站后， 应完成离机检查单和离机安全检查的全部 内容。
# -------------------------------------
#
# 片段编号: 4.2.
# 片段内容: 旅客全部下机后， 机组应按要求完成航后安保检查工作， 确保机上无外来物或 旅客遗留物品。
# -------------------------------------
#
# 片段编号: 4.3.
# 片段内容: 机组应清点文件并收好所有资料和用具（包括婴儿安全带、加长安全带等物 品） 。
# -------------------------------------
#
# 片段编号: 4.4.
# 片段内容: 如条件允许，当班机组可向接班机组成员介绍飞机的适航情况或飞行情况。
# -------------------------------------
#
# 片段编号: 4.5.
# 片段内容: 机组人员离开航空器时应保持清洁和整齐的环境， 以便利于下一班机组成员使 用。
# -------------------------------------
#
# 片段编号: 4.6.
# 片段内容: 如果飞机停站过夜，必须关好机舱门、风档和出口门。出于安全因素，如果需 要过夜，机组的飞行包（箱）应拿下飞机。
# -------------------------------------
#
# 片段编号: 4.7.
# 片段内容: 飞机只能向地面维修人员交接，如果地面维修人员未到，机组不得离开飞机。
# -------------------------------------
#
# 片段编号: 4.8.
# 片段内容: 仅在完成上述工作后，机组方可离开飞机。 平行跑道同时仪表运行 为了满足日益增长的空中交通流量需要，越来越多的机场建设平行跑道，而平行跑道 同时仪表运行对空中交通管制部门、飞机及机载设备和飞行机组提出了更高的要求。 为规范公司平行跑道同时仪表运行，降低运行风险，建立本章节。
# -------------------------------------
#
# 片段编号: 1.
# 片段内容: 平行跑道同时仪表运行的模式
# -------------------------------------
#
# 片段编号: 1.1.
# 片段内容: 平行跑道同时仪表运行按照跑道用于进近和离场的使用方式分为独立平行仪 表进近、相关平行仪表进近、独立平行离场、隔离平行运行等四种模式： 1.1.1. 独立平行仪表进近（Independent parallel instrument approaches） 是指在相邻的平行跑道仪表着陆系统上进近的飞机之间不需要配备规 定的雷达间隔时， 在平行跑道上同时进行的仪表着陆系统进近的运行模 式； 1.1.2. 相关平行仪表进近（Dependent parallel instrument approaches） 是指在相邻的平行跑道仪表着陆系统上进近的飞机之间需要配备规定 的雷达间隔时，在平行跑道上同时进行的仪表着陆系统进近的运行模 式； 1.1.3. 独立平行离场（Independent instrument departures） 是指离场飞机在平行跑道上沿相同方向同时起飞的运行模式。 当两条平 行跑道间距小于760 米，飞机可能受尾流影响时，平行跑道离场飞机 的放行间隔应当按照为一条跑道规定的放行间隔执行； 1.1.4. 隔离平行运行（Segregated operations on parallel runways） 是指在平行跑道上同时进行的运行， 其中一条跑道只用于离场， 另一条 跑道只用于进近。
# -------------------------------------
#
# 片段编号: 1.2.
# 片段内容: 平行跑道同时仪表运行按照上述的四种运行模式的不同组合， 也可以分为半混 合运行和混合运行： 1.2.1. 半混合运行是指下列情形之一： 1.2.1.1. 一条跑道只用于进近，另一条跑道按照独立平行仪表进近模 式或者相关平行仪表进近模式用于进近，或者按照隔离平行 运行模式用于离场； 1.2.1.2. 一条跑道只用于离场，另一条跑道按照隔离平行运行模式用 于进近，或者按照独立平行离场模式用于离场。 1.2.2. 混合运行是指两条平行跑道同时用于进近和离场。 理论研究表明， 使用 独立平行仪表进近模式可以使机场进港流量最大化， 其次是相关平行仪 表进近模式。
# -------------------------------------
#
# 片段编号: 2.
# 片段内容: 非侵入区和正常运行区
# -------------------------------------
#
# 片段编号: 2.1.
# 片段内容: 采用独立平行仪表进近模式运行时， 空中交通管制机构在两条平行跑道中心线 延长线之间划设一个非侵入区（No Transgression Zone，简称NTZ） ，并为每 条跑道划设一个正常运行区（Normal Operation Zone，简称NOZ） 。
# -------------------------------------
#
# 片段编号: 2.2.
# 片段内容: 非侵入区是指两条跑道中心线延长线之间、 宽度不小于610 米的特定空域， 在 实施平行跑道同时进近过程中， 当一架飞机进入该空域时， 管制员应当指挥另 一架受影响的正常飞行的飞机避让。
# -------------------------------------
#
# 片段编号: 2.3.
# 片段内容: 正常运行区是指仪表着陆系统航向道中心线向两侧延伸至指定范围的空域， 正 常运行区的长度从跑道入口开始， 沿进近反方向延伸至飞机加入跑道中心线延 长线的一点为止。
# -------------------------------------
#
# 片段编号: 3.
# 片段内容: 精密跑道监控
# -------------------------------------
#
# 片段编号: 3.1.
# 片段内容: 为了在间距较小的平行跑道上， 实施独立平行仪表进近模式运行， 机场应安装 精密跑道监控（Precision Runway Monitors，简称PRM）系统。该系统可以 使空中交通管制机构同时监控平行且相邻的仪表进近。管制员使用PRM 系统 监控平行仪表进近飞机的飞行轨迹， 并检查飞机是否闯入非侵入区。 如果飞机 闯入非侵入区，管制员将指令另一架平行仪表进近的飞机中断进近。
# -------------------------------------
#
# 片段编号: 3.2.
# 片段内容: 只有满足下列条件的前提下，方可实施精密跑道监控（PRM）进近： 3.2.1. 2 部VHF 工作； 3.2.2. 飞行机组完成地面理论和/或模拟机训练； 3.2.3. 进近前， 飞行机组必须复习PRM 进近航图和程序， 特别是“Attention All Users”（全体用户注意）页； 3.2.4. 飞行机组必须熟知特定的中断程序和中断术语术语并准备好执行中断 程序。
# -------------------------------------
#
# 片段编号: 3.3.
# 片段内容: 若不满足上述条件，无法实施精密跑道监控（PRM）进近，机组应在距目的 地机场至少100 海里时， 通知相应的空中交通管制单位以便获得使用其它进近 程序的许可。
# -------------------------------------
#
# 片段编号: 3.4.
# 片段内容: 为了避免通信频率卡阻，每一条跑道均有两个频率，包括主用频率和PRM 频 率。在PRM 程序要求的时间段内（详见“Attention All Users”页） ，飞行机组应 同时收听主用频率 （VHF1） 和 PRM 频率 （VHF2） ， 但仅使用主用频率 （VHF1） 发送。 为了确保能够同时守听两个频率， 两部甚高频电台的音量应调到相同水 平。
# -------------------------------------
#
# 片段编号: 3.5.
# 片段内容: 机组收到中断指令后， 必须立即断开自动驾驶仪人工操作， 以便在最短的时间 内建立避让轨迹。通常情况下，中断指令包括一个转弯指令和一个爬升/下降 指令。
# -------------------------------------
#
# 片段编号: 4.
# 片段内容: 平行跑道同时仪表运行的一般规定
# -------------------------------------
#
# 片段编号: 4.1.
# 片段内容: 实施平行跑道同时仪表运行前， 飞行机组应完成平行跑道同时仪表运行的理论 学习， 熟悉各种不同类型的运行模式， 掌握公司有关平行跑道同时仪表运行的 规定；
# -------------------------------------
#
# 片段编号: 4.2.
# 片段内容: 实施平行跑道同时仪表运行前， 飞行机组应确认飞机的机载电子设备满足使用 仪表着陆系统进行进近的要求， 并且至少一部自动驾驶仪或一部飞行指引仪工 作正常；
# -------------------------------------
#
# 片段编号: 4.3.
# 片段内容: 若飞机应答机失效， 飞行机组应提前通告空中交通管制员以便获得较大的横向 和/或纵向间隔；
# -------------------------------------
#
# 片段编号: 4.4.
# 片段内容: 当间距小于760 米的平行跑道实施独立平行离场时， 应按照一条跑道的尾流间 隔标准与前机（由同一跑道或相邻跑道起飞的飞机）保持规定的间隔；
# -------------------------------------
#
# 片段编号: 4.5.
# 片段内容: 当目的地机场实施平行跑道同时仪表进近时， 飞行机组应在首次与进近管制员 和塔台管制员联系时确认使用跑道， 并交叉检查飞行管理计算机输入的飞行计 划、仪表着陆系统的频率/航道/识别码等准确无误；
# -------------------------------------
#
# 片段编号: 4.6.
# 片段内容: 实施平行跑道同时仪表运行时， 飞行机组应严格按照程序飞行、 遵守程序限制， 并立即执行管制员发布的指令；
# -------------------------------------
#
# 片段编号: 4.7.
# 片段内容: 当目的地机场实施独立平行仪表进近以及相关平行仪表进近时， 飞行机组应使 用飞行指引仪以精确地将飞机保持在ILS 航向道上， 禁止进行无指引ILS 进近；
# -------------------------------------
#
# 片段编号: 4.8.
# 片段内容: 禁止在实施平行跑道同时仪表进近时， 使用VOR、 VOR/DME、 NDB、 NDB/DME 等程序进行进近；
# -------------------------------------
#
# 片段编号: 4.9.
# 片段内容: 当实施平行跑道同时仪表进近的目的地机场出现风切变、颠簸、下降气流、大 侧风以及雷暴等恶劣天气或由于机载设备故障影响飞机保持仪表着陆系统航 向道能力时，飞行机组应及时通告管制员，要求增加运行间隔，并参考目视和 /或TCAS 信息与相邻跑道上进近的飞机保持安全间隔。 （空白）
# -------------------------------------

# %%
pdf_path2 = 'source_pdf/大型飞机公共航空运输承运人运行合格审定规则.pdf'
extracted_paragraphs2 = extract_text_from_pdf2(pdf_path2)
print(len(extracted_paragraphs2))

# 打印提取结果
for paragraph_number, paragraph_content in extracted_paragraphs2:
    print(f"片段编号: {paragraph_number}")
    print(f"片段内容: {paragraph_content}")
    print("-------------------------------------")
    print()
# Out:
# 301
# 片段编号: 第 121.1 条
# 片段内容: 目的和依据 为了对大型飞机公共航空运输承运人进行运行合格审 定和持续监督检查，保证其达到并保持规定的运行安全水 平，根据《中华人民共和国民用航空法》和《国务院对确需 保留的行政审批项目设定行政许可的决定》 ，制定本规则。
# -------------------------------------
#
# 片段编号: 第 121.3 条
# 片段内容: 适用范围 (a)本规则适用于在中华人民共和国境内依法设立的航 空运营人实施的下列公共航空运输运行： (1)使用最大起飞重量超过5,700 千克的多发涡轮驱动飞 机实施的定期载客运输飞行； (2)使用旅客座位数超过30 座或者最大商载超过3,400 千克的多发涡轮驱动飞机实施的不定期载客运输飞行； (3)使用最大商载超过3,400 千克的多发涡轮驱动飞机实 施的全货物运输飞行。 (b)对于适用于本条(a)款规定的航空运营人， 在本规则中 称之为大型飞机公共航空运输承运人。 (c)对于应当按照本规则审定合格的大型飞机公共航空 运输承运人，中国民用航空局(以下简称中国民航局)和民用 航空地区管理局（以下简称民航地区管理局）按照审定情况 在其运行合格证及其运行规范中批准其实施下列一项或者 多项运行种类的运行： (1)国内定期载客运行，是指符合本条(a)款第(1)项规定， 在中华人民共和国境内两点之间的运行，或者一个国内地点 与另一个由局方专门指定、视为国内地点的国外地点之间的 运行； (2)国际定期载客运行，是指符合本条(a)款第(1)项规定， 在一个国内地点和一个国外地点之间，两个国外地点之间， 或者一个国内地点与另一个由局方专门指定、视为国外地点 的国内地点之间的运行； (3)补充运行，是指符合本条(a)款第(2)项、第(3)项规定 的运行。 (d)大型飞机公共航空运输承运人应当遵守其他有关的 涉及民航管理的规章，但在本规则对相应要求进行了增补或 者提出了更高标准的情况下，应当按照本规则的要求执行。 (e)大型飞机公共航空运输承运人在运行中所使用的人 员和大型飞机公共航空运输承运人所载运的人员应当遵守 本规则中的适用要求。 (f)在本规则中，对于载运邮件的飞行，视为载运货物飞 行；对于同时载运旅客和货物的飞行，视为载运旅客飞行， 但应当同时满足本规则中有关货物运输条款的要求。
# -------------------------------------
#
# 片段编号: 第 121.5 条
# 片段内容: 定义 (a)在本规则中， 局方是指中国民航局和民航地区管理局 及其派出机构。 (b)除本规则其他章中另有规定外， 本规则中用语的含义 在本规则附件A《定义》中规定。
# -------------------------------------
#
# 片段编号: 第 121.7 条
# 片段内容: 运行合格审定和持续监督 (a)中国民航局对大型飞机公共航空运输承运人的合格 审定和运行实施统一监督管理。 (b)中国民航局飞行标准职能部门依据本规则组织指导 大型飞机公共航空运输承运人的运行合格审定和持续监督 检查工作，制定必要的工作程序，规定运行合格证、运行规 范及其申请书的统一格式。 (c)民航地区管理局负责对其所辖地区内设立的大型飞 机公共航空运输承运人实施运行合格审定，颁发运行合格证 及其运行规范，并及时向中国民航局飞行标准职能部门备 案。 (d)大型飞机公共航空运输承运人取得运行合格证及其 运行规范后， 即成为本规则规定的运行合格证持有人(以下简 称合格证持有人)。 (e)民航地区管理局及其派出机构负责对其所辖地区内 设立的和(或者)在其所辖地区内运行的合格证持有人实施持 续监督检查。
# -------------------------------------
#
# 片段编号: 第 121.9 条
# 片段内容: 飞机的湿租 (a)除经中国民航局批准外，合格证持有人不得湿租境外 航空运营人或者境内未按照本规则批准运行的航空运营人 的飞机。 (b)合格证持有人在进行涉及湿租的运行前， 应当向局方 提交一份与国内外其他公共航空运营人所签订的飞机湿租 租赁合同和有关批准文件的副本。局方收到租赁合同副本 后，将确定合同中飞机的运行控制方，并根据需要，向合同 一方或者双方分别颁发运行规范的修改项，否则合格证持有 人不得进行湿租运行。 (c)合格证持有人实施湿租运行，应当提供下列需要列入 运行规范的信息： (1)合同双方的名称和合同的有效期限； (2)合同所涉及的每架飞机的国籍标志和登记标志； (3)运行种类； (4)运行的机场或者区域； (5)具体说明计划由哪一方负责运行控制和实施这种运 行控制的时间、机场或者区域。 (d)在对前款事项作出决定时，局方将考虑下列因素： (1)机组成员资格； (2)飞机的适航性和维修工作； (3)飞行签派； (4)飞机的补给服务； (5)航班计划； (6)安全运行责任； (7)局方认为有关的其他因素。 (e)经局方批准， 合格证持有人在因特殊原因取消其飞机 的飞行时，可以租用带有一名或者多名机组成员的飞机，载 运其旅客进行飞行。这种飞行应当遵守本规则中与所实施运 行有关的规定。
# -------------------------------------
#
# 片段编号: 第 121.11 条
# 片段内容: 境外运行规则 大型飞机公共航空运输承运人在中国境外运行时，应当 遵守《国际民用航空公约》附件2《空中规则》和所适用的 外国法规。 在 《民用航空器驾驶员合格审定规则》 (CCAR-61)、 《一般运行和飞行规则》(CCAR-91)和本规则的规定严于上 述附件和外国法规的规定并且不与其发生抵触时，还应当遵 守《民用航空器驾驶员合格审定规则》(CCAR-61)、 《一般运 行和飞行规则》(CCAR-91)和本规则的规定。 B 章 运行合格审定的一般规定
# -------------------------------------
#
# 片段编号: 第 121.20 条
# 片段内容: 运行合格证及其运行规范 (a)在本规则中， 运行合格证是指批准大型飞机公共航空 运输承运人从事特定公共航空运输运行的许可证书。 (b)运行规范是运行合格证的附件， 是指与运行合格证相 对应的，大型飞机公共航空运输承运人运行应当符合的批 准、条件和限制等规范。
# -------------------------------------
#
# 片段编号: 第 121.21 条
# 片段内容: 运行合格证及其运行规范的申请和颁发程 序 (a)大型飞机公共航空运输承运人实施本规则第121.3 条 规定的运行，应当向其主运行基地所在地的民航地区管理局 申请颁发运行合格证及其运行规范。民航地区管理局按照预 先申请、正式申请、文件审查、演示验证和发证五个步骤进 行审查。运行合格证及其运行规范的申请人应当按照规定的 格式和方法向其主运行基地所在地的民航地区管理局提交 申请书，申请书应当至少附有下列材料： (1)审查活动日程表； (2)本规则第121.133 条所要求的手册； (3)训练大纲及课程； (4)管理人员资历； (5)飞机及运行设施、设备的购买或者租用合同复印件； (6)说明申请人如何符合本规则所有适用条款的符合性 声明。 (b)初次申请运行合格证的申请人， 应当在提交申请书的 同时，提交说明计划运行的性质和范围的文件，包括准许申 请人从事经营活动的有关证明文件。 (c)民航地区管理局应当在收到申请书之后的5 个工作日 内书面通知申请人是否受理申请。 申请人未能按照本条(a)款 要求提交齐全的材料或者申请书格式不符合要求，需要申请 人补充申请材料的，民航地区管理局应当在该5 个工作日内 一次性告知需要补正的全部内容。 (d)民航地区管理局受理申请后， 对申请人的申请材料是 否符合本规则的要求进行审查，对申请人能否按照本规则安 全运行进行验证检查。 (e)民航地区管理局应当自受理申请之日起20 个工作日 内做出是否颁发运行合格证及其运行规范的决定，民航地区 管理局依法进行检验、组织专家评审的时间不计入前述期 限。 (f)申请人属于本规则第121.23 条(b)款规定情形的， 不予 颁发运行合格证及其运行规范。对于此种情况，民航地区管 理局应当书面通知申请人，说明理由并告知申请人享有依法 申请行政复议或者提起行政诉讼的权利。
# -------------------------------------
#
# 片段编号: 第 121.23 条
# 片段内容: 运行合格证及其运行规范的颁发条件 (a)申请人经过审查后符合下列全部条件， 可以取得大型 飞机公共航空运输承运人运行合格证及其运行规范： (1)满足本规则和涉及民航管理的规章所有适用条款的 要求； (2)按照涉及民航管理的规章的规定， 配备了合格和足够 的人员、设备、设施和资料，并且能够按照本规则的规定及 其运行规范实施安全运行； (3)具有与特定的运行性质和范围相符的完善的组织机 构、飞行运行的控制和监督方法、训练大纲以及地面服务和 维修安排； (4)符合安全保卫相关的涉及民航管理的规章的要求； (5)为代表其执行工作的第三方制定了政策和程序。 (b)申请人具有下列情形之一的，不予颁发运行合格证： (1)申请人没有配备合格的或者足够的人员、设备、设施 和资料，或者不能按照有关涉及民航管理的规章实施安全运 行； (2)申请人或者对其经营管理有控制权的人员， 存在与运 行相关的严重失信行为记录的； (3)申请人安排或者计划安排担任本规则第121.43 条(a) 款规定的主要管理职位的人员，存在与运行相关的严重失信 行为记录的。
# -------------------------------------
#
# 片段编号: 第 121.25 条
# 片段内容: 运行合格证及其运行规范的内容 经审查合格后，局方应当向申请人颁发大型飞机公共航 空运输承运人运行合格证及其运行规范。 (a)大型飞机公共航空运输承运人运行合格证包含下列 内容： (1)合格证持有人的名称； (2)合格证持有人主运行基地的地址； (3)合格证的编号； (4)合格证的生效日期和有效期； (5)负责监督该合格证持有人运行的局方机构名称和联 系方式； (6)被批准的运行种类； (7)说明经审定，该合格证持有人符合本规则的相应要 求，批准其按照所颁发的运行规范实施运行。 (b)大型飞机公共航空运输承运人的运行规范包含下列 内容： (1)主运行基地的具体地址， 作为合格证持有人与局方进 行通信联系的不同于其主运行基地地址的地址，以及其文件 收发机构的名称与通信地址； (2)对每种运行的实施规定的权利、限制和主要程序； (3)每个级别和型别的飞机在运行中需要遵守的其他程 序； (4)批准合格证持有人使用的每架飞机的型号、系列编 号、国籍标志和登记标志，定期载客运行中需要使用的每个 正常使用机场、备降机场、临时使用机场和加油机场。经批 准，这些项目可以列在现行有效的清单中，作为运行规范的 附件，并在运行规范的相应条款中注明该清单名称。合格证 持有人只能使用列在清单上的飞机和机场运行； (5)批准的运行种类； (6)批准运行的航线和区域及其限制； (7)机场的限制； (8)机体、发动机、螺旋桨、设备(包括应急设备)的维修 时限或者确定维修时限的标准； (9)批准的控制飞机重量与平衡的方法； (10)飞机互换的要求； (11)湿租飞机的有关资料； (12)按照规定颁发的豁免或者批准的偏离； (13)按照本规则需要局方批准的手册和训练大纲； (14)按照本规则实施运行所必须的管理人员和机构； (15)按照本规则需要局方批准的其他项目。
# -------------------------------------
#
# 片段编号: 第 121.27 条
# 片段内容: 运行合格证及其运行规范的有效性 (a)运行合格证在出现下列情形之一时失效： (1)合格证持有人自愿放弃，并将其交回局方； (2)局方依法暂扣、撤销或者以其他方式终止该合格证。 (b)在出现下列情形时， 运行规范全部失效或者部分条款 失效： (1)局方依法暂扣、撤销或者以其他方式终止运行合格 证，则运行规范全部失效； (2)局方依法暂停或者终止该运行规范中批准的全部运 行，则运行规范全部失效； (3)局方依法暂停或者终止该运行规范中批准的部分运 行，则运行规范中关于该部分运行的条款失效； (4)对于某一运行种类， 合格证持有人没有满足本规则第 121.47 条(a)款中规定的近期经历要求，并且没有按照第 121.47 条(b)款规定的程序恢复该种类运行时， 运行规范中关 于该种类运行的条款失效。 (c)当运行合格证或者运行规范依法被暂扣、撤销或者因 其他原因而失效时，合格证持有人应当将运行合格证或者运 行规范交还局方。
# -------------------------------------
#
# 片段编号: 第 121.29 条
# 片段内容: 运行合格证及其运行规范的检查 合格证持有人应当将其运行合格证及其运行规范保存 在主运行基地，并能随时接受局方的检查。合格证持有人的 飞机上应当携带运行合格证及其运行规范经认证的真实副 本，并保证副本与正本一致。该副本可以是纸质版，也可以 是符合局方要求的其他形式。
# -------------------------------------
#
# 片段编号: 第 121.31 条
# 片段内容: 运行合格证的修改 (a)在下列情形下，局方可以修改按照本规则颁发的运行 合格证： (1)局方认为为了安全和公众利益需要修改； (2)合格证持有人申请修改， 且局方认为安全和公众利益 允许进行此种修改。 (b)合格证持有人申请修改其运行合格证时， 适用本规则 第121.21 条(c)款至(f)款规定的程序和期限并应当遵守下列 规定： (1)合格证持有人应当在不迟于其计划的修改生效日期 前适当的时间向其主运行基地所在地的民航地区管理局提 交修改其运行合格证的申请书； (2)申请书应当按照规定的格式和方法提交。 (c)当合格证持有人对其运行合格证修改的申请被拒绝 或者对局方发出的修改决定有不同意见，请求重新考虑时， 应当在收到局方通知后20 个工作日内向局方提出重新考虑 的请求。
# -------------------------------------
#
# 片段编号: 第 121.33 条
# 片段内容: 合格证持有人保存和使用运行规范的责任 (a)合格证持有人应当在其主运行基地保存一套独立完 整且现行有效的运行规范。 (b)合格证持有人应当将其运行规范中的有关内容或者 信息，写进本规则G 章规定的手册中，并且应当清楚地写明 这些内容是其运行规范的一部分，还应当说明运行规范的每 一条要求具有强制性；或者将完整的运行规范与手册编制在 一起进行分发、携带、保存和更新。 (c)合格证持有人应当持续保证其每个参与运行工作的 人员，熟知运行规范中适用于该人员工作职责的有关规定。
# -------------------------------------
#
# 片段编号: 第 121.35 条
# 片段内容: 运行规范的修改 (a)在下列情形下，局方可以修改按照本规则颁发的运行 规范： (1)局方认为为了安全和公众利益需要修改； (2)合格证持有人申请修改， 且局方认为安全和公众利益 允许进行此种修改。 (b)除本条(e)款规定的情形外， 局方主动修改合格证持有 人的运行规范应当遵守下列程序： (1)局方以书面形式提出修改内容，通知合格证持有人； (2)局方确定一个不少于5 个工作日的合理期限， 合格证 持有人可以在此期限内对修改内容提交有关书面资料和意 见； (3)局方审查合格证持有人提交的全部材料后， 作出下列 决定之一并通知合格证持有人： (i)采用全部修改意见； (ii)采用部分修改意见； (iii)拒绝所提出的修改意见。 (4)合格证持有人收到局方颁发的修改运行规范的通知 20 个工作日后，修改项生效，但下列情况除外： (i)根据本条(e)款，需要立即生效的； (ii)合格证持有人根据本条(d)款， 请求对修改的决定重新 考虑的。 (c)合格证持有人申请修改其运行规范时， 适用本规则第 121.21 条(c)款至(f)款规定的程序和期限并应当遵守下列规 定： (1)合格证持有人应当在计划的运行规范修改生效日期 前适当时间提交修改其运行规范的申请书，但有下列情形之 一的，申请人应当在计划的运行规范修改生效日期前足够的 时间内提出申请： (i)兼并其他运营人或者增设按照本规则运行的分支机构 的； (ii)增加运行的能力、 需要通过验证试飞重新证明其能够 安全运行的； (iii)本规则第121.3 条(c)款中确定的运行种类改变的； (iv)由于破产行为而暂停运行后需要恢复运行的； (v)初次引进以前未经大型飞机公共航空运输承运人运 行验证试飞的飞机的。 (2)申请书应当以规定的格式和方法向其主运行基地所 在地的民航地区管理局提交； (3)在考虑了申请人提交的所有材料以及局方的审查情 况后，局方作出下列决定之一并通知合格证持有人： (i)接受所申请的全部修改； (ii)接受所申请的部分修改； (iii)拒绝所申请的修改。此时，合格证持有人可以按照 本条(d)款规定，请求局方对其拒绝决定进行重新考虑。 (4)局方批准修改的， 经与合格证持有人就其修改的贯彻 问题进行协调后，修改项在局方批准的日期生效； (5)如果合格证持有人守法信用信息记录中存在与运行 相关的严重失信行为记录，局方可以拒绝其申请的部分或者 全部修改。 (d)合格证持有人申请局方重新考虑运行规范修改项的 决定的，应当遵守下列程序： (1)合格证持有人应当在收到局方拒绝修改其运行规范 的通知后， 或者在收到局方提出修改其运行规范的通知后20 个工作日内，向局方提出重新考虑的请求； (2)如果重新考虑的请求是在20 个工作日内提出的，则 局方颁发的任何修改暂停生效，除非局方发现，根据本条(e) 款，存在紧急情况，为了安全，需要立即生效； (3)如果重新考虑的请求不是在20 个工作日内提出的， 按照本条(c)款规定的程序执行。 (e)如果局方发现，存在危及安全、需要立即行动的紧急 情况， 不能执行本条(b)款至(d)款规定的程序， 或者按照程序 进行将违背公众利益，则可以采取下列措施： (1)局方修改运行规范， 并使修改项在合格证持有人收到 该修改通知日期起立即生效； (2)在发给合格证持有人的通知中，局方应当说明原因， 指出存在危及安全、需要立即行动的紧急情况，或者指出修 改推迟生效将违背公众利益的情况。
# -------------------------------------
#
# 片段编号: 第 121.37 条
# 片段内容: 申请人的责任 申请人申请取得或者申请修改运行合格证及其运行规 范以及与运行合格审定有关的其他项目，应当保证申请材料 真实完整。 C 章 管理合格证持有人的一般规定
# -------------------------------------
#
# 片段编号: 第 121.41 条
# 片段内容: 监察和检查的实施 (a)合格证持有人应当接受局方在任何时间或者地点对 其进行的监察或者检查，以确定其是否符合涉及民航管理的 规章的规定，是否符合其运行合格证及其运行规范的规定。 (b)合格证持有人应当能在其主运行基地向局方提供下 列资料： (1)合格证持有人的大型飞机公共航空运输承运人运行 合格证及其运行规范； (2)一个包含有关资料存放地点和负责人员信息的现行 清单。上述资料是指合格证持有人按照适用的涉及民航管理 的规章规定，应当保存的记录、文件和报告。 (c)负责保存合格证持有人记录、文件和报告的所有人 员，应当能向局方提供这些资料。 (d)局方可以根据本条(a)款检查的结果或者任何其他适 当的材料，确定合格证持有人是否合格于继续持有其运行合 格证及其运行规范。 (e)合格证持有人如果不能按照局方要求， 提供其运行合 格证、运行规范或者任何必需的记录、文件和报告，存在安 全隐患的，局方可以暂停其运行合格证或运行规范中的部分 或者全部运行批准。
# -------------------------------------
#
# 片段编号: 第 121.42 条
# 片段内容: 安全管理体系 合格证持有人应当建立安全管理体系，并且能够按照本 规则的规定实施安全管理，该体系应当： (a)至少具备了下列功能： (1)对影响安全的危险源能够及时识别； (2)保证采取必要的纠正措施，保持可接受的安全水平； (3)对安全水平进行持续的监督和定期评估； (4)持续改进整体安全水平。 (b)明确地界定了整个组织内部的安全责任界限， 包括高 层管理者应当对安全直接承担的责任。 (c)制订并持续实施非惩罚性， 且包含保护数据及其来源 措施的飞行数据分析方案。 (d)制订供运行人员使用的飞行安全文件系统。
# -------------------------------------
#
# 片段编号: 第 121.43 条
# 片段内容: 按照本规则实施运行所必需的管理人员和 机构 (a)合格证持有人应当拥有能够有效控制和监督其整个 运行的管理机构，并拥有足够的合格管理人员和技术人员， 以保证在其运行中保持最高的安全水平。合格证持有人应当 在下列职位或者同等职位上安排合格的人员： (1)主要负责人， 对合格证持有人安全生产工作全面负责 的高级管理人员，具体责任包括： (i)建立健全并落实合格证持有人全员安全生产责任制， 遵守安全生产法律法规，组织制定并实施合格证持有人安全 生产规章制度和操作规程； (ii)组织制定并签署合格证持有人安全政策， 保证安全投 入的有效实施； (iii)对实施和保持合格证持有人安全管理体系负责，组 织建立并落实合格证持有人安全风险分级管控和隐患排查 治理双重预防工作机制，督促、检查合格证持有人的安全生 产工作，及时消除安全隐患； (iv)组织制定、 实施并签署合格证持有人生产安全事故应 急救援预案，及时、如实报告安全生产事故。 (2)安全总监， 负责独立地对合格证持有人的运行安全管 理过程进行监督，并应该直接向主要负责人报告。 (3)运行副总经理，负责合格证持有人飞行运行的管理， 使之符合本规则要求。 (4)维修副总经理，负责合格证持有人的飞机维修管理， 使之符合本规则要求。 (5)总飞行师， 负责合格证持有人的飞行人员训练和技术 管理，使之符合本规则的要求。 (6)总工程师， 负责合格证持有人的飞机维修工程技术管 理，使之符合本规则的要求。 (7)本款要求的包括主要负责人在内的上述所有管理和 技术人员不得在同一时间任职于多个按本规则运行的合格 证持有人。 (b)对于某一项具体运行，如果合格证持有人能证明，由 于所涉及的运行种类、所使用的飞机数量与型号和运行的区 域等因素，使用较少的管理人员能够完成本条(a)款规定的除 安全总监以外其他职位的全部职责并能以同等安全水平完 成运行， 局方可以认可其管理人员的配备。 除经局方批准外， 安全总监不允许由本条(a)款其余职务的人员兼任。 (c)本条(a)款要求的或者按照本条(b)款认可的职位名称 和管理人员数量，应当在合格证持有人的运行规范中明确载 明。 (d)担任本条(a)款或者(b)款要求的或者认可的职位的人 员，以及按照运行合格证实施运行的各级负责人，应当符合 下列要求： (1)在训练、经验、专业知识上保持合格水平。 (2)在其职责范围内， 理解有关合格证持有人各种运行的 下列资料： (i)有关涉及民航管理的规章； (ii)合格证持有人的运行规范； (iii)航空安全标准和安全运行常规； (iv)本规则及其他涉及民航管理的规章中所有适用的维 修和适航要求； (v)本规则第121.131 条要求的手册。 (3)严格履行其职责，以符合适用的规章要求，并保证安 全运行。 (e)合格证持有人应当在本规则G 章要求的手册内的一 般政策规定中，写明本条(a)款规定的人员的任务、职责和权 力，并写明担任这些职务人员的姓名和业务地址。合格证持 有人应当在上述所列职位上的人员变换或者空缺后10 天内 通知局方。 (f)合格证持有人应当设立由飞行、维修、签派和客舱安 全等专业人员组成的运行管理机构，负责协调各业务部门有 关运行的事项；办理运行合格审定的有关事宜；负责手册的 分发、更改和报批工作，保持其有效性。 (g)合格证持有人应当设立独立于运行的安全监督机构， 在安全总监的直接领导下，负责安全水平的持续监督和定期 评估；调查安全相关事件；就安全有关事务提出建议和组织 员工安全教育等。
# -------------------------------------
#
# 片段编号: 第 121.45 条
# 片段内容: 管理人员的合格条件 (a)自2025 年1 月1 日起，首次担任本规则第121.43 条 (a)款规定的主要负责人应当符合下列条件： (1)接受了局方认可的相关法规的培训并合格； (2)曾经担任按本规则运行的第121.43 条(a)款规定的主 要管理人员或者具备至少3 年民航安全管理工作经验； (3)熟悉合格证持有人的运行规范、 运行手册及其他相关 要求； (4)具有较强的分析解决问题能力和良好的沟通技能。 (b)担任本规则第121.43 条(a)款规定的安全总监应当符 合下列条件： (1)掌握运行安全管理知识、质量管理知识、涉及民航管 理的规章、标准及程序; (2)最近6年内在合格证持有人或者局方的安全监督岗位 工作3 年以上，或者持有下列任一专业执照并在相应岗位上 工作3 年以上： (i)航线运输驾驶员执照； (ii)民用航空器维修人员执照； (iii)飞行签派员执照。 (3)理解合格证持有人的运行规范、 运行手册及其他相关 要求; (4)具有较强的分析解决问题能力和良好的沟通技能。 (c)担任本规则第121.43 条(a)款规定的运行副总经理应 当符合下列条件： (1)持有航线运输驾驶员执照； (2)在最近6 年内， 在该合格证持有人使用相同级别飞机 按照本规则所实施的运行中具有运行控制权的职位上，至少 有3 年管理经历； (3)对于初次担任运行副总经理的人员， 在最近的6年内， 至少在该合格证持有人按照本规则运行的相同级别的飞机 上具有担任机长3 年的经历；对于具有负责运行副总经理经 历的人员，至少在该合格证持有人按照本规则运行的相同级 别的飞机上具有担任机长3 年的经历。 (d)担任本规则第121.43 条(a)款规定的维修副总经理应 当符合下列条件： (1)接受了局方认可的相关法规的培训并合格； (2)在前6 年内具有至少3 年从事合格证持有人运行的至 少一种类别和级别飞机全面的维修管理经历。 (e)担任本规则第121.43 条(a)款规定的总飞行师应当符 合下列条件： (1)持有航线运输驾驶员执照， 至少具有该合格证持有人 按照本规则运行中所用的一种飞机的合适等级； (2)对于初次担任总飞行师的人员，在最近6 年内，至少 在该合格证持有人按照本规则运行的相同级别的飞机上，具 有担任机长3 年的经历；对于具有总飞行师经历的人员，至 少在与该合格证持有人按照本规则运行的相同级别的飞机 上，具有担任机长3 年的经历。 (f)担任本规则第121.43 条(a)款规定的总工程师应当符 合下列条件： (1)持有民用航空器维修人员执照， 至少具有该合格证持 有人按照本规则运行中所用的一种飞机的机型签署经历； (2)具有维修本规则运行的飞机至少5 年的经历， 其中至 少有2 年作为维修工程技术管理人员的经历。 (g)如果合格证持有人拟选任的人员不符合本条(a)、(b)、 (c)、(d)、(e)或者(f)款规定的经历，但具有相应的经历，能够 有效履行涉及民航管理的规章要求的相应职位的职责和合 格证持有人手册规定的程序，局方可以批准对本条相应款项 规定经历的偏离。
# -------------------------------------
#
# 片段编号: 第 121.47 条
# 片段内容: 运行的近期经历 (a)合格证持有人如果连续中断其运行规范中批准实施 的某一种类的运行达30 个日历日，则在此日期之后，应当 按照本条(b)款规定恢复运行，否则不得继续实施此种运行。 (b)在本条(a)款的中断期之后， 只有符合下列条件并达到 局方要求后，方可以恢复相应种类的运行： (1)在恢复该种运行之前， 至少提前5个工作日通知局方； (2)如果局方决定重新进行全面检查， 以确定其是否保持 了合适和足够的配备，能否实施安全运行，合格证持有人应 当在前述5 个工作日期间处于能随时接受检查的状态。
# -------------------------------------
#
# 片段编号: 第 121.49 条
# 片段内容: 主运行基地、飞行基地和维修基地 (a)合格证持有人应当保持一个主运行基地。合格证持有 人还可以按照运行需要建立飞行基地和维修基地，飞行基地 和维修基地可以与主运行基地在同一地点，也可以在不同地 点。 (b)在计划建立或者变更主运行基地、 飞行基地或者维修 基地之前至少30 天，合格证持有人应当以书面形式通知局 方。
# -------------------------------------
#
# 片段编号: 第 121.51 条
# 片段内容: 合格证持有人名称的使用 (a)合格证持有人按照本规则实施运行时所使用的名称 应当与其运行规范上所列名称一致。 (b)除经局方在运行规范中批准外， 在按照本规则运行的 飞机上应当明显地标出运行该飞机的合格证持有人的名称， 否则不得运行该飞机。飞机上标示名称的方法及其可读性应 当符合局方要求。
# -------------------------------------
#
# 片段编号: 第 121.52 条
# 片段内容: 飞行数据的使用 (a)合格证持有人不得为事故或者征候调查以外的目的 使用驾驶舱话音记录器、驾驶舱音频记录系统的记录或者文 本，除非这些记录或者文本： (1)在去识别化后， 用于合格证持有人安全管理体系内不 安全事件的调查、分析、研究等，并符合《国际民用航空公 约》附件19《安全管理》关于保护安全数据和安全信息的相 关要求； (2)用于与事故或者征候调查所涉事件无关的刑事诉讼， 并符合《国际民用航空公约》附件19《安全管理》关于保护 安全数据和安全信息的相关要求； (3)用于对飞行记录器系统的检查。 (b)合格证持有人不得为事故或者征候调查以外的目的 使用飞行数据记录器、航空器数据记录系统以及本规则第 121.352 条要求的快速记录器的记录或者文本，除非这些记 录或者文本符合《国际民用航空公约》附件19《安全管理》 关于保护安全数据和安全信息的相关要求，且： (1)去识别化； (2)合格证持有人用于飞行数据分析方案； (3)用于与事故或者征候调查所涉事件无关的诉讼； (4)合格证持有人用于适航或者维修； (5)根据安全数据保护程序被公布。 (c)合格证持有人可以与另一方签订合同， 由其负责飞行 数据分析方案具体工作，但符合性责任由合格证持有人承 担。 (d)合格证持有人应当定期向负责合格证管理的民航地 区管理局职能部门报告其通过飞行数据分析方案得到的统 计数据和趋势分析报告，局方认为必要时可以随时查阅或者 分析快速存取记录器(QAR)或者等效设备的原始数据。
# -------------------------------------
#
# 片段编号: 第 121.53 条
# 片段内容: 按照军方合同实施运行的偏离批准 (a)局方可以批准合格证持有人偏离本规则的适用规定， 实施其按照军方合同确定的运行。 (b)在按照本条批准一项偏离时， 局方将对合格证持有人 的运行规范颁发相应的修改项。 (c)局方在任何时候可以终止按照本条颁发的偏离批准。
# -------------------------------------
#
# 片段编号: 第 121.55 条
# 片段内容: 实施应急运行的偏离批准 (a)在紧急情况下并满足下列条件时，局方可以批准合格 证持有人偏离本规则的适用规定： (1)在该紧急情况下为保护人员生命和财产应当采取运 送人员或者财产的行动； (2)局方认为，为了立即实施这些运行，应当偏离有关规 定。 (b)在紧急情况下，局方可以使用下列方法之一批准偏 离： (1)局方对合格证持有人的运行规范颁发相应的修改项； (2)如果情况紧急不允许及时修改运行规范， 则局方可以 用口头或者其他方式批准该偏离，但合格证持有人应当在开 始这种运行后24 小时之内，向局方提交说明这种紧急情况 性质的报告。
# -------------------------------------
#
# 片段编号: 第 121.57 条
# 片段内容: 遵守运行合格证及其运行规范的要求 合格证持有人不得违反运行合格证、运行规范和其他批 准项目实施运行，不得超越批准的偏离或者豁免。 E 章 国内、国际定期载客运行航路的批准
# -------------------------------------
#
# 片段编号: 第 121.91 条
# 片段内容: 航路批准的基本要求 (a)申请航路批准的合格证持有人应当证明符合下列条 件： (1)能在该航路上每一正常使用机场、 临时使用机场或者 加油机场之间实施满足本规则要求的运行； (2)对于计划的运行，具有满足本规则第121.95 条至第 121.105 条要求的设施与服务。 (b)在证明符合本条(a)款要求时， 如果合格证持有人在考 虑了机场、灯光、维修、通信、导航、加油、地面、机载无 线电等各种设施的可用性和充分性，以及参与运行的全体人 员的能力之后，证明能保证飞行安全，局方可以不要求在该 航路上作航路试飞。
# -------------------------------------
#
# 片段编号: 第 121.93 条
# 片段内容: 航路宽度 (a)经批准的航路、航段及固定航线具有的宽度应当至少 与这些固定航线或者航路的规定宽度相等。在局方认为有必 要对经批准的航路另行确定宽度时，将考虑下列因素： (1)地形障碍的超越； (2)最低航路高度； (3)地面和机载导航设备； (4)空中交通密度； (5)空中交通管制程序。 (b)局方对经批准的航路另行确定的宽度， 将具体规定在 该大型飞机公共航空运输承运人的运行规范中。
# -------------------------------------
#
# 片段编号: 第 121.95 条
# 片段内容: 必需的机场资料 (a)合格证持有人应当证明，所申请批准的航路上具有足 够的机场，并且这些机场装备了适合于所申请运行的设施。 其中所考虑的因素应当包括机场的等级、道面、障碍物、设 施、公众保护、灯光、导航、通信、气象设施以及空中交通 管制等。 (b)合格证持有人应当证明，对于所使用的每个机场，都 能够获得、保存现行有效的航行资料，包含但不限于航行通 告(NOTAM)、航行资料汇编(AIP)、航行资料通报(AIC)和定 期制航行通告(AIRAC)等与运行安全、规则和效率有关的信 息，并且具有将其分发给每个有关人员的经批准的资料管理 系统，以确保飞机在该机场运行的安全。这种航行资料应当 包括下列方面的内容： (1)机场 (i)基本设施； (ii)安保(空防)保护措施； (iii)机场活动区管理措施； (iv)救援和消防服务(RFFS)； (v)导航、通信、气象设施； (vi)影响起飞、着陆或者地面运行的建筑物； (vii)空中交通服务设施。 (2)跑道、停止道和净空道 (i)尺寸； (ii)道面性质； (iii)标志和灯光系统； (iv)标高和坡度。 (3)内移的跑道入口 (i)位置； (ii)尺寸； (iii)用于起飞、用于着陆或者二者兼用。 (4)障碍物 (i)影响按照本规则I 章进行起飞和着陆性能计算的障碍 物； (ii)起控制作用的障碍物。 (5)仪表飞行程序 (i)离场程序； (ii)进场程序； (iii)进近程序； (iv)复飞程序。 (6)特殊资料 (i)跑道视程(RVR)测量设备； (ii)低能见度条件下的盛行风。 (c)如果负责管理该合格证持有人的民航地区管理局发 现该合格证持有人经批准的关于收集、分发和使用航行资料 的系统应当予以改进才能恰当地继续工作，则合格证持有人 在接到该部门的通知后，应当立即对其系统进行改进。在合 格证持有人接到这样的通知之后30 天内，可以向中国民航 局飞行标准职能部门提出重新考虑的请求。重新考虑的请求 使该通知处于暂缓执行状态，直至中国民航局飞行标准职能 部门作出决定时止。但是，如果民航地区管理局认为存在关 系到航空运输安全、需要立即采取措施的紧急情况，则中国 民航局飞行标准职能部门可以根据所陈述的理由，使要求改 进的通知立即生效。
# -------------------------------------
#
# 片段编号: 第 121.97 条
# 片段内容: 通信设备 (a)合格证持有人应当证明，在正常运行条件下，在整个 航路上，所有各点都具有陆空双向无线电通信系统，能保证 每一架飞机与相应的空中交通管制单位之间，每一架飞机与 相应的运行控制中心之间，以直接的或者通过经批准的点到 点间的线路进行迅速可靠的通信联系。除遇到紧急情况外， 对于合格证持有人的所有运行，每架飞机与运行控制中心之 间的通信系统应当是空中交通管制通信系统之外的独立系 统。 (b)对于国内运行， 如合格证持有人评估所运行的航线上 存在空中交通管制通信设施不可用或者通信质量无法保证 有效语音通信的情况，运行该航线的每一架飞机与运行控制 中心之间应当保证有另一种语音通信系统可以进行替代。 (c)对于国际运行，合格证持有人应当保证每一架飞机与 相应的运行控制中心之间能够满足在正常运行条件下，在4 分钟内建立迅速可靠的语音通信联系。
# -------------------------------------
#
# 片段编号: 第 121.99 条
# 片段内容: 气象服务 (a)合格证持有人应当证明，每一条航路沿线，均有足够 的气象报告服务可以供使用，以保证提供运行所必需的气象 实况报告和气象预报。 (b)合格证持有人只能使用符合局方要求的气象服务系 统提供的气象资料。 (c)使用气象预报控制飞行活动的合格证持有人， 应当使 用依据本条(b)款规定的气象资料而编制的气象预报， 以及按 照本条(d)款规定采用的系统所批准的任何来源而编制的气 象预报。 (d)合格证持有人应当使用经局方批准的危险天气实况 报告与预报系统，以便获得可能影响所飞航路和所用机场飞 行安全的危险天气现象，如晴空颠簸、雷暴和低空风切变等 情况的实况报告和预报。
# -------------------------------------
#
# 片段编号: 第 121.101 条
# 片段内容: 航路导航设施 (a)除本条(b)款规定外， 合格证持有人应当证明， 对于每 一条计划中的航路，非目视地面导航设施符合下列要求： (1)具有足够的非目视地面导航设施， 能在空中交通管制 要求的精度之内，在整个航路上为飞机导航； (2)非目视地面导航设施的位置， 能保证在该运行所必需 的精度范围之内，引导飞机至任一正常使用机场、临时使用 机场、加油机场或者备降机场。 (b)下列运行不需要非目视地面导航设施： (1)昼间目视飞行规则运行，但合格证持有人应当证明， 能够根据地形的特征，使用地标领航而安全运行； (2)在经局方批准使用特殊导航方法导航的航段上实施 的运行。
# -------------------------------------
#
# 片段编号: 第 121.103 条
# 片段内容: 运行控制中心 (a)合格证持有人应当设立运行控制中心， 通过完备的运 行控制组织管理体系，确保对每次飞行进行恰当的运行控 制。 (b)运行控制中心可以设立若干分支机构实施运行控制， 但运行控制责任应当严格遵守本规则第121.531 条的要求。 (c)合格证持有人的运行控制体系应当在运行规范中得 到批准，并在运行手册中描述说明该体系的组织架构、授权 以及职责。
# -------------------------------------
#
# 片段编号: 第 121.105 条
# 片段内容: 地面服务 每个实施国内、国际定期载客运行的合格证持有人应当 建立相应的地面服务管理组织机构，在相关的手册中明确对 所有地面服务的培训要求、外部委托政策、管理程序、工作 标准和规范等内容，并具备足够的合格人员和适当的设施和 设备(包括备件、地面保障和材料等)，确保飞机起飞前或者 着陆后的地面服务符合本规则的相应要求。当合格证持有人 通过外部委托方式由他人提供部分或者全部地面服务时，合 格证持有人应当向相应的地面服务人员提供必要的训练，并 对其操作的安全性负责。 F 章 补充运行的区域和航路批准
# -------------------------------------
#
# 片段编号: 第 121.113 条
# 片段内容: 航路和区域要求概则 (a)实施补充运行的合格证持有人应当按照下列规定申 请运行区域和航路的批准： (1)对于国内运行， 中国境内的空域按照一个运行区域批 准，但包含高高原机场(海拔高度在2,438 米或者8,000 英尺 及以上的机场)起降点的航路还需按照航路进行批准； (2)对于国际运行，所飞机场所在的每一国家(地区)按照 一个运行区域批准，但包含高高原机场或者局方确定的特殊 机场起降点的航路还需按照航路进行批准。 (b)按照本条(a)款申请运行区域和航路批准的合格证持 有人，应当证明其具有足够的装备和能力，能够使用中国或 者外国公布航路上有关导航设施，在仪表飞行规则和夜间目 视飞行规则条件下实施安全运行。 (c)如果实施补充运行的合格证持有人可以证明， 对于运 行的航路是安全的，并且局方能够确定空中交通密度有足够 的安全水平，局方可以批准合格证持有人管制空域外的航 路。合格证持有人不可以使用没有经局方批准的，或者运行 规范中没有列出的航路。
# -------------------------------------
#
# 片段编号: 第 121.115 条
# 片段内容: 航路宽度 (a)经批准的航路、航段及固定航线具有的宽度应当至少 与这些固定航线或者航路的规定宽度相等。在局方认为有必 要对经批准的航路另行确定宽度时，将考虑下列因素： (1)地形障碍的超越； (2)最低航路高度； (3)地面和机载导航设备； (4)空中交通密度； (5)空中交通管制程序。 (b)合格证持有人运行规范中局方加以规定的任何其他 航路宽度。
# -------------------------------------
#
# 片段编号: 第 121.117 条
# 片段内容: 必需的机场资料 (a)实施补充运行的合格证持有人使用的任何机场应当 具有适当的装备并适合于所申请运行的设施。其中所考虑的 因素应当包括机场的等级、道面、障碍物、设施、公众保护、 灯光、导航、通信、气象设施以及空中交通管制等。 (b)每一实施补充运行的合格证持有人应当证明其有一 个经批准的系统，能够获得、保存和分发给每个有关人员所 使用机场现行有效的航行资料，以确保飞机在该机场运行的 安全。这种航行资料应当包括下列方面的内容： (1)机场 (i)基本设施； (ii)安保(空防)保护措施； (iii)机场活动区管理措施； (iv)救援和消防服务(RFFS)； (v)导航、通信、气象设施； (vi)影响起飞、着陆或者地面运行的建筑物； (vii)空中交通服务设施。 (2)跑道、停止道和净空道 (i)尺寸； (ii)道面性质； (iii)标志和灯光系统； (iv)标高和坡度。 (3)内移的跑道入口 (i)位置； (ii)尺寸； (iii)用于起飞、用于着陆或者二者兼用。 (4)障碍物 (i)影响按照本规则I 章进行起飞和着陆性能计算的障碍 物； (ii)起控制作用的障碍物。 (5)仪表飞行程序 (i)离场程序； (ii)进场程序； (iii)进近程序； (iv)复飞程序。 (6)特殊资料 (i)跑道视程(RVR)测量设备； (ii)低能见度条件下的盛行风。 (c)如果负责管理该合格证持有人的民航地区管理局发 现该合格证持有人经批准的关于收集、分发和使用航行资料 的系统应当予以改进才能恰当地继续工作，则合格证持有人 在接到该部门的通知后，应当立即对其系统进行改进。在合 格证持有人接到这样的通知之后30 天内，可以向中国民航 局飞行标准职能部门提出重新考虑的请求。重新考虑的请求 使该通知处于暂缓执行状态，直至中国民航局飞行标准职能 部门作出决定时止。但是，如果民航地区管理局认为存在关 系到航空运输安全、需要立即采取措施的紧急情况，则中国 民航局飞行标准职能部门可以根据所陈述的理由，使要求改 进的通知立即生效。
# -------------------------------------
#
# 片段编号: 第 121.119 条
# 片段内容: 气象服务 (a)合格证持有人应当证明，每一条航路沿线，均有足够 的气象报告服务可以供使用，以保证提供运行所必需的气象 实况报告和气象预报。 (b)合格证持有人只能使用符合局方要求的气象服务系 统提供的气象资料。 (c)使用气象预报控制飞行活动的合格证持有人， 应当使 用依据本条(b)款规定的气象资料而编制的气象预报。
# -------------------------------------
#
# 片段编号: 第 121.121 条
# 片段内容: 航路导航设施 (a)除本条(b)款规定外， 合格证持有人应当证明， 对于每 一条计划中的航路，非目视地面导航设施符合下列要求： (1)能在空中交通管制要求的精度之内， 在整个航路上为 飞机导航； (2)非目视地面导航设施的位置， 能保证在该运行所必需 的精度范围之内，引导飞机至任一目的地机场或者备降机 场。 (b)下列运行不需要非目视地面导航设施： (1)昼间目视飞行规则运行，但合格证持有人应当证明， 能够根据地形的特征，使用地标领航而安全运行； (2)在经局方批准使用特殊导航方法导航的航段上实施 的运行。
# -------------------------------------
#
# 片段编号: 第 121.123 条
# 片段内容: 地面服务 每个实施补充运行的合格证持有人应当建立相应的地 面服务管理组织机构，在相关的手册中明确对所有地面服务 的培训要求、 外委政策、 管理程序和工作标准、 规范等内容， 并具备足够的合格人员和适当的设施和设备(包括备件、 地面 保障和材料等)， 确保飞机起飞前或者着陆后的地面服务符合 本规则的相应要求。当合格证持有人通过外委方式由他人提 供部分或者全部的地面服务时，合格证持有人应当向相应的 地面服务人员提供必要的训练，并对其操作的安全性负责。
# -------------------------------------
#
# 片段编号: 第 121.125 条
# 片段内容: 飞行跟踪系统 (a)实施补充运行的合格证持有人应当证明： (1)具有符合本规则U 章要求的飞行跟踪系统， 该系统根 据所实施的运行可以对每次飞行进行有效的跟踪； (2)飞行跟踪中心应当设在适用于对下列情况实施飞行 跟踪的位置： (i)确保对每次飞行的始发机场和目的地机场的飞行进程 进行适当的监控，包括对中途停留机场和改航备降机场飞行 进程的监控，以及对在这些机场所需的维修或者机械延误进 行适当的监控； (ii)确保机长能够得到安全飞行必需的所有资料。 (b)实施补充运行的合格证持有人可以使用非所属人员 提供的飞行跟踪设施，但在这种情况下，合格证持有人应当 对每次飞行的运行控制持续负责。 (c)飞行跟踪系统不要求与空中飞行的机组建立通信联 系。 (d)在合格证持有人的运行规范中应当明确批准使用的 飞行跟踪系统和飞行跟踪中心的所在位置。
# -------------------------------------
#
# 片段编号: 第 121.127 条
# 片段内容: 飞行跟踪系统要求 (a)实施补充运行的每个合格证持有人应当证明： (1)系统具备足够的设备和合格人员， 为下列人员提供每 一次飞行的起始和安全运行所必需的信息： (i)每架飞机的飞行机组； (ii)合格证持有人指定实施运行控制的人员。 (2)飞行跟踪系统具有利用公共或者私人设施(例如电 话、电报或者无线电)获得通信的能力，以进行本规则第 121.125 条(a)款第(2)项第(i)目要求的监控。 (b)实施补充运行的合格证持有人应当证明本条(a)款所 述人员能够履行他们的职责。 G 章 手册的要求
# -------------------------------------
#
# 片段编号: 第 121.131 条
# 片段内容: 手册的制定和保存 (a)合格证持有人应当具有为实施其各种运行的全体飞 行、维修和其他地面运行工作人员制定并供其使用和指导其 操作的手册， 并且有合适的手册管理系统， 负责制定、 分发、 修订和补充手册，使其保持现行有效。 (b)本条(a)款要求的手册应当符合下列要求： (1)包含必需的政策、流程、标准和程序等指令和信息， 使有关人员能安全地完成所担负的工作职责； (2)除局方批准外，使用中文写成。如果合格证持有人在 运行中使用了不熟悉中文的人员，则应当同时为其提供相应 文字的手册，并且应当保证这些手册的一致性和同等有效 性； (3)采用易于修订的形式； (4)在有关的每一页上，标注最后一次修订的日期。对于 电子化的手册，可以以恰当的形式标注最后一次修订的日 期，使人员可以迅速确定有效性； (5)符合所有适用的涉及民航管理的规章、 该合格证持有 人的运行合格证与运行规范；对于实施国际运行的合格证持 有人，还应当符合所适用的外国规章。 (c)合格证持有人在其主运行基地至少要保存一套完整 的手册。该手册可以是纸质版的手册，也可以是符合局方要 求的其他形式。
# -------------------------------------
#
# 片段编号: 第 121.133 条
# 片段内容: 手册内容总体要求 手册应当包含下列所有内容，但可以分为两个或者两个 以上的单独分册，每一分册应当包括所有适用于该类人员的 内容： (a)概述： (1)与飞行运行有关人员工作内容和责任的说明，包括： 机组成员和飞行签派员在飞行起始、持续、改航和终止阶段 的职能； (2)飞行签派和运行控制，包括：适用的签派协调、飞行 控制、 飞行跟踪程序、 在冲突地区及附近运行风险的管理等； (3)航路飞行、导航和通信程序，包括：当任何所需的特 定设备不工作或者无法提供服务时，签派或者放行飞机继续 飞行； (4)有关机组成员疲劳管理的信息和政策，包括： (i)根据P 章，适用于飞行和客舱机组成员的飞行时间、 飞行值勤期、值勤期的限制和休息期要求的有关政策； (ii)合格证持有人的疲劳风险管理制度或者经局方批准 的疲劳风险管理系统(如适用)的有关政策和文件。 (5)机载导航设备清单， 其中包含与基于性能导航区域内 的运行有关的任何规定； (6)适用的远程导航程序、延程运行(EDTO)的发动机失 效程序和备降机场的选择与使用； (7)应持续保持无线电监听的情况； (8)确定飞行最低高度的方法； (9)确定机场运行最低标准的方法； (10)乘客在机上时实施燃油加注的安全预防措施； (11)地面操作的安排和程序； (12)机长发现有事故发生后使用的搜寻和救援程序； (13)不同类型运行中飞行机组指挥权接替次序的指定； (14)对所要装载的燃油与滑油量计算的具体说明，其中 考虑到运行中的所有情况，包括在航路上释压和一台或者多 台动力装置失效的可能性； (15)应当使用氧气的情况和按照本规则规定确定的氧气 携带量； (16)重量与平衡控制方面的操作指示； (17)地面除冰、 防冰操作的实施和控制方面的操作指示； (18)空中交通服务飞行计划的填写规范，运行飞行计划 的内容和使用方法; (19)飞行各阶段的标准操作程序(SOP)； (20)关于正常检查单的使用及其使用时机的操作指示； (21)离场应急程序； (22)保持高度意识和使用自动或者飞行机组高度喊话的 操作指示； (23)在仪表气象条件下使用自动驾驶仪与自动油门的操 作指示； (24)关于空中交通管制许可的确认与接受的操作指示， 特别是针对那些许可中包含有超越障碍物许可的情况； (25)离场与进近简令； (26)用于熟悉空域、航路和机场的程序； (27)稳定进近程序； (28)贴近地面时的大下降率限制； (29)开始或者继续仪表进近所需的条件； (30)实施非精密进近程序(NPA)、 有垂直引导的进近程序 (APV)和精密进近程序(PA)的操作指示； (31)夜间与仪表气象条件下，仪表进近与着陆运行中的 飞行机组职责分配和机组成员工作负荷管理的程序； (32)避免可控飞行撞地的操作指示与训练要求，以及近 地警告系统的使用政策； (33)避免空中相撞和使用空中交通防撞系统(ACAS)的 政策、操作指示、程序和训练要求； (34)关于拦截民用飞机方面的信息和操作指示，包括： (i)被拦截飞机的机长应当采取的程序； (ii)拦截和被拦截飞机使用的目视信号。 (35)对准备在15,000 米(49,000 英尺)以上运行的飞机， 还需要以下资料： (i)在受到太阳宇宙射线辐射时，使驾驶员能够确定应采 取的最佳行动方案的资料； (ii)决定下降后的程序，其中包括： (A)向合适的空中交通服务单位发出预先情况警告以及 获得临时下降许可所必需的程序； (B)与空中交通服务单位之间的通信不能建立或者被中 断时应采取的措施。 (36)安全管理体系的详细内容； (37)与危险品航空运输活动相关的程序和培训方案(含 未获得危险品航空运输许可的合格证持有人)； (38)安保方面的操作指示及指南； (39)根据安保部门相关规定制定的搜查程序检查单，该 检查单必须包括在发现爆炸物或者可疑物时所采取适当行 动步骤的指南以及有关飞机上最低风险爆炸位置(如适用)的 资料； (40)航空人员健康管理与健康促进的规定与程序； (41)航空食品卫生规定与程序； (42)飞机环境卫生、消毒和卫生防疫的规定与程序，突 发公共卫生事件处置预案； (43)电子飞行包(EFB)管理要求和程序(如适用)； (44)电子导航、近地警告等数据管理程序； (45)根据本规则第121.533 条制定的飞机追踪程序； (46)使用平视显示器(HUD)或者等效显示器、增强视景 系统(EVS)、增强飞行视景系统(EFVS)、合成视景系统(SVS) 和/或组合视景系统(CVS)等设备的说明和培训要求。 (b)飞机运行信息： (1)飞机型号审定限制和运行限制； (2)飞行机组使用的正常、 非正常和应急程序及有关检查 单； (3)所有发动机工作时爬升性能的操作指示和信息； (4)供飞行前和飞行中制定计划使用的飞行计划数据， 包 含不同的推力、功率和速度设定情况下的数据； (5)所用每个机型的最大侧风和顺风分量限制， 以及在考 虑了阵风、低能见、跑道道面状况、机组经历、自动驾驶使 用、非正常或者紧急情况或者其他有关运行因素影响时，对 这些限制数值进行的缩减； (6)重量与平衡计算方面的操作指示和数据； (7)飞机装载和载荷固定方面的操作指示； (8)可供每一型号飞机运行人员和飞行机组所使用的包 括与该型号飞机运行有关的正常、非正常和应急程序以及该 飞机各系统和所用检查单的详细信息在内的飞机操作手册， 手册的设计还需符合人的因素要求； (9)供所用机型和经批准的特殊运行使用的最低设备清 单和外形缺损清单，其中包含与基于性能导航区域内的运行 有关的任何规定； (10)应急和安全设备的检查单和使用说明； (11)应急撤离程序，包括与机型相关的程序、机组协调、 紧急情况下机组成员的指定位置和紧急情况下每个机组成 员的职责； (12)客舱乘务员所使用的正常、非正常和应急程序，以 及与此有关的检查单和必需的飞机系统信息，并且包括一个 用于解释这些程序是供飞行机组成员和客舱乘务员之间协 调使用的说明； (13)用于不同航路的救生和应急设备清单，以及在起飞 前验证其工作正常的必要程序，包括确定所需氧气量和可用 量的程序； (14)供幸存者使用的地空目视信号说明。 (c)航路和机场： (1)航路信息指导， 用于确保飞行机组每次飞行都能够获 得适用于该运行的通讯设施、助航设备、机场、仪表进近、 仪表进场和仪表离场方面的信息以及承运人认为正确实施 飞行运行所必需其他信息； (2)每一所飞航路的最低飞行高度； (3)可能用作目的地机场或者备降机场的每个机场的运 行最低标准； (4)确定使用平视显示器(HUD)或者等效显示器、增强视 景系统(EVS)、 增强飞行视景系统(EFVS)、 合成视景系统(SVS) 和/或组合视景系统(CVS)等设备的仪表进近机场运行最低标 准的说明； (5)在进近或者机场设施降级的情况下机场运行最低标 准的提高； (6)符合规章要求的所有飞行剖面的必需信息， 包括但不 仅限于下列确定内容： (i)干、湿和受污染情况下的起飞跑道长度要求，包括影 响起飞距离的系统失效情况； (ii)起飞爬升限制； (iii)航路爬升限制； (iv)进近爬升限制和着陆爬升限制； (v)干、湿和受污染情况下的着陆跑道长度要求，包括影 响着陆距离的系统失效情况； (vi)补充信息，如轮胎速度限制。 (d)训练： 本规则N 章规定的，包含相应地面训练、飞行训练(如 适用)等详细内容的飞行机组成员、 客舱乘务员和飞行签派员 的训练大纲，以保证参加训练的人员在上岗前对于所担负的 工作接受了充分的训练。
# -------------------------------------
#
# 片段编号: 第 121.135 条
# 片段内容: 手册的分发和可用性 (a)合格证持有人应当向下列人员提供本规则第121.131 条所要求的手册及其修改和补充，或者该手册的有关部分： (1)维修人员和有关地面运行工作人员； (2)机组成员； (3)负责管理该合格证持有人的局方人员。 (b)按照本条(a)款持有手册或者手册相关部分的每个人， 应当使用合格证持有人提供的修改和补充页，使手册内容保 持最新有效状态，并在执行指定任务时可以随时查阅。
# -------------------------------------
#
# 片段编号: 第 121.137 条
# 片段内容: 飞机飞行手册 (a)合格证持有人应当为其使用的每一型号飞机保持现 行有效的飞机飞行手册。 (b)合格证持有人的每架飞机都应当携带用机组人员所 熟悉的语言编写，且满足本条(a)款所要求的飞机飞行手册。 合格证持有人也可以携带按本规则第121.131 条要求编写的 手册， 但该手册应当包含适用本条(a)款飞机飞行手册规定的 信息。 (c)合格证持有人选择按照本规则第121.131 条编写手册 时，可以对适用本条(a)款飞机飞行手册的操作程序部分进行 修改和对性能数据的编排形式进行调整，但经修改的操作程 序和性能数据编排形式应当被局方批准。 (d)合格证持有人应当制定并执行适用的管理程序， 以保 证满足本条(a)、(b)款的手册现行有效。 H 章 飞机的要求
# -------------------------------------
#
# 片段编号: 第 121.151 条
# 片段内容: 飞机的基本要求 (a)除本条(c)款规定外， 合格证持有人运行的飞机应当符 合下列要求： (1)是在中华人民共和国登记的民用飞机， 并携带现行有 效的适航证、国籍登记证、无线电电台执照和噪声合格审定 的证明文件。噪声合格审定证明文件可以载于本规则第 121.137 条要求的飞机飞行手册中。在国际运行时，该证明 文件必须包括一份英文译文； (2)处于适航状态并符合涉及民航管理的规章适用的适 航要求，包括与标识和设备有关的要求。 (b)合格证持有人可以使用经批准的重量与平衡控制系 统来符合适用的适航要求和运行限制，该重量与平衡控制系 统可以以平均的、假定的或者估算的重量为基础。 (c)合格证持有人可以租用不含机组人员的国际民用航 空公约缔约国所属的某一国家登记的民用飞机实施本规则 运行，但应当符合下列规定： (1)该飞机带有经中国民航局审查认可的原国籍登记国 颁发的适航证和由中国民航局颁发的适航认可证书，以及无 线电电台执照和噪声合格审定的证明文件； (2)合格证持有人已将该飞机的租赁合同副本报局方。
# -------------------------------------
#
# 片段编号: 第 121.153 条
# 片段内容: 飞机的审定和设备要求 合格证持有人按照本规则运行的飞机应当是型号合格 审定为运输类的飞机，并符合本规则第121.173 条的要求， 否则不得实施本规则运行。
# -------------------------------------
#
# 片段编号: 第 121.155 条
# 片段内容: 禁止使用单台发动机飞机 合格证持有人不得使用单台发动机的飞机实施本规则 运行。
# -------------------------------------
#
# 片段编号: 第 121.157 条
# 片段内容: 飞机的航路类型限制 (a)除经依据本规则W 章的规定得到局方批准且满足合 格证持有人运行规范许可的条件下，合格证持有人不得使用 以涡轮发动机为动力的飞机实施以下运行： (1)延程运行(EDTO)； (2)在北极区域内的运行； (3)在南极区域内的运行。 (b)合格证持有人用于延伸跨水运行的陆上飞机， 应当是 按照《运输类飞机适航标准》(CCAR-25)中的水上迫降规定 审定合格或者被批准为适合于水上迫降的飞机。
# -------------------------------------
#
# 片段编号: 第 121.159 条
# 片段内容: 飞机的运行验证试飞 (a)合格证持有人使用以前未在公共航空运输运行中使 用过的飞机，应当完成局方认可的至少100 小时的运行验证 试飞，包括相当数量的进入航路机场的飞行。在运行验证试 飞过程中，如果局方认为试飞已达到令人满意的熟练水平， 则局方可以减少验证试飞时间。上述运行验证试飞至少应当 有10 小时在夜间完成。 (b)除经局方特殊批准外， 合格证持有人首次使用曾在公 共航空运输运行中使用过的某一型号飞机，或者使用在设计 上做了实质性更改的某一型号飞机，则在拟使用该飞机实施 运行之前，应当完成经局方认可的至少25 小时的运行验证 试飞，包括相当数量的进入航路机场的飞行。 (c)本条(b)款所述飞机在设计上进行了实质性更改是指 下列情形之一： (1)整套动力装置的型号与飞机合格审定时所装动力装 置的型号不相类似； (2)对飞机或者其部件进行了实质上影响其飞行特性的 更改。 (d)除了实施试飞所需的人员和局方指定的人员之外， 合 格证持有人不得在运行验证试飞的飞机上携带旅客。经局方 批准，运行验证试飞的飞机可以携带邮件、快递或者其他货 物。
# -------------------------------------
#
# 片段编号: 第 121.161 条
# 片段内容: 应急撤离程序的演示 (a)合格证持有人应当依照本规则附件C《本规则第 121.161 条规定的应急撤离程序演示准则》(a)款规定进行应 急撤离程序的实际演示，证明在载客飞行中所用的旅客座位 数大于44 座的每个型号的飞机，能够使包括机组成员在内 的满载量乘员在90 秒(含)以内撤离飞机。但是，如果该型号 飞机已被证明符合本规则附件C(a)款规定或者适用的型号合 格审定标准，可以不实施实际的演示。 (b)使用旅客座位数大于44 座的飞机实施载客运行的合 格证持有人，有下列情形之一的，应当按照本条(c)款进行应 急撤离程序的部分演示： (1)该合格证持有人新引进的某型号飞机投入载客飞行 并且该合格证持有人没有按照本条(a)款实施实际演示； (2)本规则第121.391 条所要求的客舱乘务员的人数、位 置或者其应急撤离职责、程序发生改变； (3)应急出口的数量、位置、型号或者供撤离用的应急出 口开启机构的型号发生改变。 (c)在实施本条(b)款要求的部分演示时， 合格证持有人应 当遵守下列规定： (1)实施不要求旅客参加但要在局方观察下进行的演示， 以验证其机组成员应急生存训练和应急撤离程序的有效性。 在这种演示中，该型号飞机的客舱乘务员，应当使用该合格 证持有人的航线操作程序，按照本规则第121.397 条规定的 应急撤离职责，打开50％所要求的地板高度的应急出口和 50％所要求的非地板高度的应急出口， 并放下50％的应急出 口滑梯。这些应急出口和滑梯由局方选定，并且应当在15 秒钟内准备就绪以供使用； (2)在实施这种演示之前， 向负责监督其运行的民航地区 管理局提出申请； (3)在这种演示中使用的客舱乘务员， 由局方从已经完成 合格证持有人经局方批准的该型号飞机训练大纲的训练并 已通过应急设备和应急程序考试的客舱乘务员中随机挑选； (4)在开始实施该型号飞机的运行之前， 向负责监督其运 行的民航地区管理局提出申请并获得批准。 (d)每个使用或者计划使用一架或者多架陆上飞机作延 伸跨水运行或者按照要求配备相应应急设备的合格证持有 人，应当按照本规则附件C(b)款进行模拟水上迫降，证明其 能有效地完成水上迫降程序。 (e)对于已经由其他合格证持有人进行过本条(d)款规定 的模拟水上迫降的那种型号飞机，如果每个救生筏都从其存 放处取下，其中一个救生筏被投放并充气或者一个滑梯救生 筏被充气，并且指定负责该充气救生筏或者滑梯救生筏的机 组成员表演并说明了每项必需应急设备的使用，则认为已经 符合本规则附件C(b)款第(2)项、(b)款第(4)项和(b)款第(5)项 的要求。前述待充气的救生筏或者滑梯救生筏由局方选定。 I 章 飞机性能使用限制
# -------------------------------------
#
# 片段编号: 第 121.171 条
# 片段内容: 用语定义 本章中的用语按照下述定义： (a)可用着陆距离(LDA)：是指公布的可用并适于飞机着 陆的跑道长度。 (b)飞行轨迹(flight path)：是指飞机在三维空间中的飞行 路线。 (c)航迹(track)：是指飞机飞行轨迹在地球表面上的水平 投影。
# -------------------------------------
#
# 片段编号: 第 121.173 条
# 片段内容: 概则 (a)使用涡轮发动机驱动的飞机的合格证持有人应当遵 守本规则第121.189 条至第121.197 条的规定。 (b)合格证持有人应当使用飞机飞行手册中的性能数据 来确定是否符合本规则第121.189 条至第121.197 条的规定。 当涉及的条件与这些性能数据所依据的条件不同时，如果内 插法或者计算法所得结果在实质上与直接试验的结果同样 准确，则可以用内插法或者通过计算具体变量变化的影响来 确定是否符合规定。合格证持有人在确定是否符合本规则第 121.189条至第121.197条的规定时还应当考虑到所用航图的 精度。 (c)如果在特殊的环境条件下遵守某些规定对于安全已 无必要，局方可以在运行规范中批准偏离本章的这些要求。
# -------------------------------------
#
# 片段编号: 第 121.189 条
# 片段内容: 涡轮发动机驱动的飞机的起飞限制 (a)涡轮发动机驱动的飞机不得以大于该飞机飞行手册 中对应于该机场气压高度和起飞时环境温度所确定的重量 起飞。 (b)涡轮发动机驱动的运输类飞机不得以大于该飞机飞 行手册中规定的重量起飞，该重量应当保证飞机符合下列各 项要求： (1)加速停止距离不得超过跑道长度加上停止道的长度； (2)起飞距离不得超过跑道长度加上净空道长度， 且净空 道长度不得大于跑道长度的一半； (3)起飞滑跑距离不得大于跑道长度。 (c)涡轮发动机驱动的飞机不得以大于该飞机飞行手册 中所确定的某个重量起飞，在该重量下，预定净起飞飞行轨 迹以10.7 米(35 英尺)的余度超越所有障碍物， 或者能以一个 特定距离侧向避开障碍物。该特定距离的值为下列两目中规 定值的较小值： (1)90 米(300 英尺)＋0.125D，其中D 是指飞机离可用起 飞距离末端的距离值； (2)对于目视飞行规则飞行， 预定航迹的航向变化小于15 度时，为300 米，预定航迹的航向变化大于15 度时，为600 米；对于仪表飞行规则飞行，预定航迹的航向变化小于15 度时，为600 米，预定航迹的航向变化大于15 度时，为900 米。 (d)在依据本条(a)款至(c)款确定最大重量、 最小距离和飞 行轨迹时，应当对拟用的跑道、机场的标高、有效跑道坡度 和起飞时的环境温度、风的分量进行修正。 (e)就本条而言， 假定飞机在到达15.2 米(50 英尺)高度(按 照飞机飞行手册中起飞飞行轨迹或者净起飞飞行轨迹数据 中的适用者)之前无坡度。此后，在120 米(400 英尺)高度以 下，飞机转弯坡度不超过15 度；在120 米(400 英尺)高度以 上，飞机转弯坡度不超过25 度。 (f)就本条而言， “起飞距离”“起飞滑跑距离”“净起飞飞行 轨迹”和“起飞飞行轨迹”等术语， 与对该飞机进行型号合格审 定的规章中所规定的术语具有相同的含义。
# -------------------------------------
#
# 片段编号: 第 121.191 条
# 片段内容: 涡轮发动机驱动的飞机的航路限制—— 一台发动机不工作 (a)涡轮发动机驱动的飞机不得超过某一重量起飞，在该 重量下，考虑到正常的燃油、滑油消耗和航路上预计的环境 温度，根据经批准的该飞机飞行手册确定的一台发动机不工 作时的航路净飞行轨迹数据应当能够符合下列两项要求之 一： (1)在预定航迹两侧各25 公里(13.5 海里)范围内的所有 地形和障碍物上空至少300 米(1,000 英尺)的高度上有正梯 度，并且，在发动机失效后飞机要着陆的机场上空450 米 (1,500 英尺)的高度上有正梯度； (2)净飞行轨迹允许飞机由巡航高度继续飞到可以按照 本规则第121.197 条要求进行着陆的机场，能以至少600 米 (2,000 英尺)的余度垂直超越预定航迹两侧各25 公里(13.5 海 里)范围内所有地形和障碍物， 并且在发动机失效后飞机要着 陆的机场上空450 米(1,500 英尺)的高度上有正梯度。 (b)就本条(a)款第(2)项而言，假定： (1)发动机在航路上最临界的一点失效； (2)飞机在发动机失效点之后飞越临界障碍物， 该点应当 能够使用有效的方式定位； (3)使用经批准的方法考虑了不利的风的影响； (4)如果合格证持有人证明，机组人员进行了恰当的训 练，并且采取了其他安全措施，能保证程序的安全性，则允 许应急放油； (5)在签派或者放行单中指定了备降机场， 且该备降机场 符合规定的最低气象条件； (6)发动机失效后燃油和滑油的消耗与飞机飞行手册中 经批准的净飞行轨迹数据所给定的消耗相同。
# -------------------------------------
#
# 片段编号: 第 121.193 条
# 片段内容: 三台或者三台以上涡轮发动机驱动的飞 机的航路限制——两台发动机不工作 三台或者三台以上涡轮发动机驱动的飞机沿预定航路 运行时，应当符合下列两款要求之一： (a)预定航迹上任何一点到符合本规则第121.197 条要求 的机场的飞行时间不超过所有发动机以巡航功率工作飞行 90 分钟。 (b)根据飞机飞行手册中航路上两台发动机不工作的净 飞行轨迹数据，其重量允许该飞机从假定两台发动机同时失 效的地点，飞到符合本规则第121.197 条要求的某一机场。 在这段飞行中，考虑到沿该航路的预计环境温度，其净飞行 轨迹在垂直方向上至少高出预定航迹两侧各25 公里(13.5 海 里)范围内所有地形和障碍物600 米(2,000 英尺)。就本款而 言，假定： (1)两台发动机在航路上最临界的地点失效； (2)这些发动机失效后在预定着陆的机场正上空450 米 (1,500 英尺)处，该净飞行轨迹具有正梯度； (3)如果合格证持有人证明，机组人员进行了恰当的训 练，并且采取了其他预防措施，能保证程序的安全性，则可 以批准应急放油； (4)在两台发动机失效的那一点， 该飞机重量包含有足够 的燃油，使其能继续飞到该机场正上空至少450 米(1,500 英 尺)的高度，此后还能以巡航功率或者推力飞行15 分钟； (5)发动机失效后， 燃油和滑油的消耗与飞机飞行手册中 净飞行轨迹数据所给定的消耗相同。
# -------------------------------------
#
# 片段编号: 第 121.195 条
# 片段内容: 涡轮发动机驱动的飞机的着陆限制—— 目的地机场 (a)涡轮发动机驱动的飞机起飞前， 应当在考虑到至目的 地机场或者备降机场飞行中正常的燃油和滑油消耗后，使飞 机到达时的重量不得超过该飞机飞行手册中对该目的地机 场或者备降机场的气压高度以及着陆时预计的环境温度所 确定的着陆重量。 (b)除本条(c)、(d)、(e)款规定外，涡轮发动机驱动的飞 机起飞前，应当在考虑到飞行中正常的燃油和滑油消耗后， 使该飞机到达目的地时的重量，根据飞机飞行手册中对该目 的地机场的气压高度和预计在着陆时当地风的情况所规定 的着陆距离，允许其在预定的目的地机场的跑道上，在可用 着陆距离(LDA)的60％以内作全停着陆。为确定在目的地机 场的允许着陆重量，假定： (1)飞机在最有利的跑道和方向、静风条件下着陆； (2)考虑到可能的风速、风向和该飞机的地面操纵特性， 以及考虑到诸如着陆助航设备和地形等其他条件，飞机在最 适宜的跑道上着陆。 (c)对于不能符合本条(b)款第(2)项的要求而被禁止起飞 的涡轮螺旋桨驱动的飞机，如果指定了备降机场，除允许飞 机在备降机场可用着陆距离(LDA)的70％以内完成全停着陆 外，该备降机场符合本条所有其他要求，则可以允许该飞机 起飞。 (d)对于涡轮喷气飞机， 在有关的气象报告和预报表明目 的地机场跑道在预计着陆时刻可能是湿的时，该目的地机场 跑道的可用着陆距离(LDA)应当至少为本条(b)款所要求的跑 道长度的115％，否则，该飞机不得起飞。如果在湿跑道上 的实际着陆技术证明，对特定型号的飞机，已经批准了某一 较短但绝不小于本条(b)款要求的着陆距离， 并且已经载入飞 机飞行手册，则可以按照手册的要求执行。 (e)对于涡轮喷气飞机， 在有关的气象报告和预报表明目 的地机场跑道在预计着陆时刻可能是污染的时，该目的地机 场的可用跑道长度应当至少为以下距离中的较大者： 本条(b) 款所要求的跑道长度的115%，以及根据认可的污染跑道实 际着陆距离数据确定的着陆距离的115%，否则，该飞机不 得起飞。如果上述污染跑道的道面已经进行了特殊处理，而 且实际着陆技术证明，对特定型号的飞机，已经批准了某一 较短但不小于本条(b)款要求的着陆距离， 并且已经载入飞机 飞行手册，则可以按照手册的要求执行。 (f)由于不能符合本条(b)款第(2)项而被禁止起飞的涡轮 喷气动力的飞机， 如果指定了符合本条(b)款所有要求的备降 机场，则可以起飞。
# -------------------------------------
#
# 片段编号: 第 121.197 条
# 片段内容: 涡轮发动机驱动的飞机的着陆限制—— 备降机场 在涡轮发动机驱动的飞机的签派或者放行单中列为备 降机场的机场，应当能使该飞机在到达该备降机场时以根据 本规则第121.195 条(b)款规定的假定条件预计的重量，在跑 道可用着陆距离(LDA)的70％(涡轮螺旋桨动力飞机)或者 60％(涡轮喷气动力飞机)以内完成全停着陆。对于本规则第 121.637 条所规定的起飞备降机场，在确定到达时的预计重 量时， 除正常的燃油和滑油消耗之外， 可以考虑应急放油量。 J 章 特殊适航要求
# -------------------------------------
#
# 片段编号: 第 121.211 条
# 片段内容: 概则 合格证持有人的飞机除满足相应型号合格审定要求外， 还应当符合本章的特殊适航要求。
# -------------------------------------
#
# 片段编号: 第 121.213 条
# 片段内容: 旅客座椅间距 (a)对于2006 年7 月1 日后加入合格证持有人运行规范 的任何载客运行的飞机应当满足本条(b)款的要求。 (b)合格证持有人运行的任何载客运行的飞机， 其座椅间 距应当满足下列要求： (1)任何座椅椅背与前面座椅椅背或者其他的固定结构 之间的距离不得小于660 毫米(26 英寸)； (2)任何座椅与前面的座椅或者其他的固定结构之间的 距离不得小于178 毫米(7 英寸)； (3)前后排座椅之间或者座椅与前面的任何固定结构之 间的垂直投影距离不得小于76 毫米(3 英寸)。 (c)对于本条(b)款要求的距离的测量应当满足下列要求： (1)对于(b)款第(1)项要求的距离，以椅背腰垫(没有被压 缩)76 毫米(3 英寸)高处为原点，在距地板635 毫米(25 英寸) 以下的整个座椅宽度范围内测量与前面座椅或者其他固定 结构之间的水平方向和垂直方向的距离(如下图所示)； (2)对于(b)款第(2)项要求的距离，以椅垫和扶手最前端 为原点测量水平方向和垂直方向的距离(如下图所示)； (3)对于(b)款第(3)项要求的距离，测量椅垫和扶手最前 端的投影与前面座椅或者固定结构的最后端的投影之间的 距离(如下图所示)。 (d)对于有杂志袋和小桌板的座椅， 在所有测量时杂志袋 应当正常装载有关的客舱安全说明、清洁袋和合格证持有人 提供的机上读物， 小桌板应当在正常的收起位置(起飞和着陆 位置)。 (e)所有测量应当在座椅调直和扶手放下的状态(起飞和 着陆状态)下测量。 座椅间距测量方法示意图
# -------------------------------------
#
# 片段编号: 第 121.215 条
# 片段内容: 在客舱内装货 (a)除本条(b)款或者(c)款规定之外， 按照本规则运行的合 格证持有人不得在飞机客舱内运载货物。 (b)如果货物在经批准的货箱之内且货箱满足下列要求， 货物可以装在客舱内任一位置： (1)货箱应当能承受适用于装有该货箱的飞机的旅客座 椅载荷系数和应急着陆条件1.15 倍的过载， 计算时要用货箱 重量和货箱中可以装载货物的最大重量的总重量； (2)货箱上应当清晰地标出该货箱准许装载的货物的最 大重量以及为保证货箱内正确的重量分布而必需的任何说 明； (3)货箱施加的载荷不得超过地板或者飞机其他结构件 的载荷限制； (4)货箱应当固定在座椅滑轨或者飞机地板结构件上， 其 固定点应当能承受适用于货箱安装于其上的飞机的旅客座 椅的载荷系数和应急着陆情况一定倍数的过载，该倍数为 1.15 或者为该飞机规定的座椅固定系数，二者中取较大者， 计算时要用货箱重量和在其中可能装载货物的最大重量的 总重量； (5)货箱不得装于妨碍通达或者使用任何需要的应急出 口或者客舱通道之处； (6)货箱应当为全封闭式的， 而且应当用至少为阻燃的材 料制成； (7)货箱内应当有适当的安全防护装置以防止货物在应 急着陆情况下发生移动； (8)货箱不得安装在会遮挡任一旅客观察“系好安全带” 标牌、“请勿吸烟”标牌或者任何所需要的出口标记的位置， 除非备有辅助标记或者其他经批准的可以给旅客适当通告 的措施。 (c)只要在《运输类飞机适航标准》(CCAR-25)第25.561 条(b)款第(3)项规定的载荷系数所对应的过载条件下能将货 物束缚住，并且按照下列要求装载，则货物可以装于任一客 舱内的隔框或者隔板后面： (1)货物用安全带或者其他具有足够强度的系留索适当 紧固；使货物在所有可以预计的正常飞行和地面情况下不可 能移动； (2)其包装或者覆盖方式能避免对旅客和客舱内人员可 能的伤害； (3)不会对座椅或者地板结构加上超过这些部件载荷限 制的任何载荷； (4)其位置不妨碍通达或者使用任何需要的应急出口、 正 常出口或者客舱内的通道； (5)其位置不遮拦任一旅客观察“系好安全带”标牌、“请 勿吸烟”标牌或者所需要的出口标记的视线， 除非备有辅助标 记或者其他经批准的可以给旅客适当通告的措施。
# -------------------------------------
#
# 片段编号: 第 121.217 条
# 片段内容: 在货舱内装货 当货物装在其设计要求机组从外部进入其中以扑灭飞 行中可能发生的任何火情的货舱内时，货物的装载应当使机 组人员能携带手提灭火器有效地到达舱内所有部位。 K 章 仪表和设备要求
# -------------------------------------
#
# 片段编号: 第 121.301 条
# 片段内容: 概则 (a)除具体指明适用于特定运行的条款外， 本规则关于仪 表和设备的要求适用于按照本规则实施的所有运行。 (b)本规则第121.305 条至第121.360 条所要求的仪表和 设备，应当按照适用的适航要求进行批准和安装。 (c)每个空速指示器应当以公里/小时或者海里／小时为 单位校准，并且飞机飞行手册和有关标牌中的每个空速限制 和有关资料中的空速应当相应地以公里/小时或者海里／小 时表示。 (d)除经局方批准外， 2005 年7 月1 日后首次投入运行的 飞机应当装备有以米为单位显示的高度表。如果该飞机需在 以英尺为单位确定飞行高度的国家或者地区运行，则应当同 时装备有以英尺为单位显示的高度表。 (e)除本规则第121.645 条(b)款和第121.647 条规定外， 只有当下列仪表和设备处于工作状态，方可以使飞机起飞： (1)为符合对该飞机进行型号合格审定的适航要求所要 求的仪表和设备； (2)本规则第121.305 条至第121.319 条和第121.359 条、 第121.360 条以及第121.743 条中规定的适用于所有运行的 仪表与设备，以及本规则第121.323 条至第121.351 条中规 定的适用于不同运行类型的仪表与设备，而这些仪表与设备 在本款第(1)项未作出要求。
# -------------------------------------
#
# 片段编号: 第 121.305 条
# 片段内容: 飞机仪表和设备 按照本规则运行的飞机应当装备下列飞行和导航的仪 表与设备： (a)一个空速指示系统， 带有加温空速管或者可以防止由 于结冰而失效的等效装置。对于以马赫数为单位来表示速度 限制的飞机，则还应至少装有一个马赫数指示器。 (b)一个灵敏高度表，带有以百帕斯卡(毫巴)为单位的校 正装置，并且该装置对于飞行中可能遇到的气压可以进行修 正。 (c)一个带指针和/或数字式显示的精确指示小时、 分和秒 的时钟(或者经批准的等效装置)。 (d)一个大气静温指示器。 (e)一个陀螺坡度与俯仰指示器(地平仪)。 (f)一个组合有侧滑指示器的陀螺转弯速率指示器，但在 按照本条(k)款装有第三套姿态仪表系统(可以在360°俯仰和 滚转飞行姿态中使用)时，只需要侧滑指示器。 (g)一个陀螺航向指示器(航向陀螺或者等效仪表)。 (h)一个磁罗盘。 (i)一个垂直速度指示器(升降率指示器)。 (j)当运行要求有两名驾驶员时，第二名驾驶员位置处应 具有以下参数的显示： (1)气压高度； (2)指示空速； (3)垂直速度； (4)转弯和侧滑； (5)姿态； (6)航向。 (k)除局方批准的某些涡桨飞机外，在涡轮动力飞机上， 除在每位驾驶员工作位置上各有一个陀螺坡度与俯仰指示 器(地平仪)可以供使用之外，还应当配备满足下列要求的第 三套陀螺坡度与俯仰指示器(地平仪)： (1)由独立于飞机正常发电系统的应急备用电源供电； (2)在正常发电系统全部失效之后至少能继续可靠地工 作30 分钟； (3)不依赖任何其他姿态指示系统而独立工作； (4)在正常发电系统全部失效之后无需选择就能工作； (5)位于仪表板局方认可的位置上， 使得任一驾驶员在其 工作位置上都能清楚地看见并使用； (6)在使用的所有阶段均有适当照明。 (l)对于本条要求的飞行和导航设备： (1)可以通过仪表组合或者中央飞行系统或者在电子显 示器上参数的组合来满足这些条款的各项要求，但要求每一 必需驾驶员能够获得的信息不少于本条所规定的仪表及相 应设备提供的信息； (2)可以使用其他等效符合性方法来满足这些条款的设 备要求，但要求在飞机型号审定批准过程中已表明该方法具 有等效的安全水平。
# -------------------------------------
#
# 片段编号: 第 121.307 条
# 片段内容: 发动机仪表 除局方对涡轮发动机另有规定外，按照本规则实施运行 的飞机应当按照下列要求安装发动机仪表： (a)所有涡轮发动机。 (1)每台发动机一个燃油压力警告装置， 或者所有发动机 一个总警告装置，并有分离各单独警告的措施； (2)每个燃油箱一个燃油油量表； (3)每个滑油箱一个滑油油量指示器； (4)每台发动机每个独立的滑油压力系统一个滑油压力 表； (5)每台发动机一个滑油压力警告装置， 或为所有发动机 提供一个主警告并带有将单个警告从主警告中分离开的手 段； (6)每台发动机一个滑油温度表； (7)能够提供视觉和听觉警告的火警装置； (8)每台发动机一个燃气温度表； (9)每台发动机一个燃油流量表； (10)每台发动机一个转速表(指示有转速限制转子的转 速)； (11)每台发动机一个动力装置防冰系统功能指示器。 (b)涡轮喷气发动机。除本条(a)款要求的动力装置仪表 外，还需装有下列动力装置仪表： (1)一个向飞行机组指示推力或者与推力直接有关的参 数的指示器。其指示必须以对推力或者该参数的直接测量为 依据。该指示器必须能指示发动机故障、损坏或者性能降低 所造成的推力变化； (2)当反推装置处于下列状态时， 位置指示装置向飞行机 组给出指示： (i)未处在选定位置； (ii)处在反推位置，对每台使用了反推装置的发动机。 (3)一个指示转子系统不平衡状态的指示器。 (c)涡轮螺旋桨发动机。 除本条(a)款要求的动力装置仪表 外，还需装有下列动力装置仪表： (1)每台发动机一个扭矩表； (2)每具螺旋桨一个位置指示器， 在螺旋桨桨叶角小于飞 行低距位置时向飞行机组发出指示。
# -------------------------------------
#
# 片段编号: 第 121.308 条
# 片段内容: 厕所防火 (a)除经局方批准外，按照本规则运行的载客飞机应当在 每个厕所装备烟雾探测系统或者等效装置，并能在驾驶舱提 供警告灯光，或者在客舱中提供易于客舱机组发现的警告灯 光或者音响警告。 (b)除经局方批准外， 按照本规则运行的载客飞机应当在 每个厕所每个处置纸制品或者废物的容器内装备内置式固 定灭火器。该固定灭火器应当设计成当容器内失火时，能自 动向容器内喷射灭火剂。
# -------------------------------------
#
# 片段编号: 第 121.309 条
# 片段内容: 应急设备 (a)只有装备本条和本规则第121.310 条所列的应急设备 的飞机，方可以按照本规则实施运行。 (b)本条和本规则第121.310 条和第121.339 条所列的每 项应急设备和漂浮设备应当符合下列要求： (1)依照运行规范中规定的检验周期予以定期检验， 以确 保其处于持续可用和立即工作的状态，执行其预定的应急用 途； (2)易于机组成员取用， 位于客舱的设备应当易于旅客取 用； (3)具有清楚的标识和标记，指明其使用方法，旅客取用 的设备文字说明应当至少有中文； (4)当装在某一舱室或者某一容器中时， 在该舱室或者容 器上易于观察的地方至少用中文标明其所装物品以及上次 检验的日期。 (c)在驾驶舱、 客舱、 货舱、 厨房内， 应当按照下列规定， 装备经批准型号的手提灭火器： (1)灭火剂的型号和装量应当适用于该舱室可能发生的 失火类型，并且对于客舱，应当设计成使有毒气体聚积的危 险性减到最小。 对于2018 年12 月31 日(含)或者其后首次颁 发单机适航证的飞机上配备的手提灭火器，所用各类灭火剂 都应当符合与臭氧层保护相关的环保要求，包括使用等效环 保灭火剂替代对本款第(7)项要求的Halon 1211(溴氯二氟甲 烷)灭火剂； (2)货舱。 对于飞行中机组成员能够进入的E 级货舱， 应 当配备至少一个手提灭火器，并放置于方便取用的地方； (3)厨房隔舱。对于位于客舱、货舱或者驾驶舱之外隔舱 内的厨房，应当在每个厨房内至少装备一个便于取用的手提 灭火器； (4)驾驶舱。 驾驶舱内应当至少装备一个便于飞行机组使 用的手提灭火器； (5)客舱。 在客舱使用的手提灭火器应当放置于方便的位 置上。在要求配备两个或者两个以上手提灭火器时，这些设 备应当均匀地分布于每个客舱内。应当按照下列要求配备手 提灭火器： (i)对于旅客座位数7 至30 的飞机，至少配备一个； (ii)对于旅客座位数31 至60 的飞机，至少配备两个； (iii)对于旅客座位数60 以上的飞机，至少配备下列数量 的手提灭火器： 旅客座位数 手提灭火器的最小数量 61 至200 座 3 个 201 至300 座 4 个 301 至400 座 5 个 401 至500 座 6 个 501 至600 座 7 个 601 座或者以上 8 个 (6)尽管本条(c)款第(5)项要求手提灭火器均匀分布， 如果 在客舱中有厨房，应当至少有一个手提灭火器位于方便之处 并易于在厨房中取用； (7)载客飞机所要求配备的手提灭火器中至少2个应当装 Halon 1211(溴氯二氟甲烷)或者等效的灭火剂。 客舱中应当至 少有一个这样的灭火器。 (d)载运旅客的飞机上应当配备本规则第121.743 条要求 的应急医疗设备。 (e)应急斧。每架飞机应当配备至少一把应急斧。 (f)扩音器。每架载客飞机应当配有电池供电的便携式扩 音器，放在负责指挥应急撤离的机组成员方便取用的地方， 其配备数量和位置符合下列规定： (1)在旅客座位数61 至99(含)的飞机上配备一个，安放 在客舱后部从客舱乘务员座位易于取用处。但是，如果局方 认为安放在其他位置可能对应急情况下人员的撤离更为适 合，可以批准偏离本款的要求； (2)在旅客座位数大于99的飞机客舱内配备两个扩音器， 一个安放在前部，另一个安放在后部，并且易于从客舱乘务 员座位处取用。
# -------------------------------------
#
# 片段编号: 第 121.310 条
# 片段内容: 附加应急设备 (a)应急撤离设施。当飞机停放于地面且起落架放下时， 应急出口(机翼上方的应急出口除外)距地面高度超过183 厘 米(6 英尺)的每一载客陆上飞机， 应当有经批准的可以帮助机 上人员撤到地面的设施。用于地板高度应急出口的这种辅助 设施应当符合《运输类飞机适航标准》(CCAR-25)第25.810 条的相应适航要求。能自动放出的辅助设施在滑行、起飞和 着陆期间应当处于待命状态。但是，如果局方认为这个出口 的设计使得满足这些要求不切实际，则局方可以批准偏离关 于自动放出的要求，但该辅助设施在放出时应能自动展开， 并按照本规则第121.161 条(a)款的规定对所要求的应急出口 进行应急撤离演示。 (b)机内应急出口标记。每架载客飞机应当符合下列要 求： (1)每个旅客应急出口，其通达方式及开启方法，应当有 明显易懂的标记。每个旅客应急出口本身及其位置应当能从 等同于客舱宽度的距离上认清。每个旅客应急出口的所在位 置应当用机上人员能看到的沿客舱主通道的标志指明，下述 部位应当有位置指示标志： (i)每个翼上旅客应急出口附近的通道上方，如通道高度 较低，可以放在顶棚合适位置上； (ii)在紧靠每一地板高度的旅客应急出口处， 如果一个位 置指示标志可以清楚标明两个应急出口的位置，则一个位置 指示标志可以用于两个应急出口位置的指示； (iii)在客舱每个挡住前后视线的隔框或者隔板上，用以 指示被其挡住的应急出口，若这样做不可能时，可以将标志 置于其他适当的位置。 (2)每个旅客应急出口标记和每个位置标示应当符合 《运 输类飞机适航标准》 (CCAR-25)第25.811 条的相应适航要求。 在这些飞机上，如果任一标志的发光度(亮度)降低到250 微 朗伯之下，则不可以继续使用。 (c)机内应急出口标志的照明。 每架载客飞机应当具有独 立于主照明系统的应急照明系统。但是，如果应急照明系统 的供电电源独立于主照明系统的供电电源，则客舱一般照明 的光源可以为应急照明系统和主照明系统二者所共用。应急 照明系统应当： (1)照亮每一旅客出口标志和位置标志； (2)在客舱内提供足够的一般照明； (3)具有贴近地板的应急逃生通道标志，该标志符合《运 输类飞机适航标准》(CCAR-25)第25.812 条相应适航要求或 者经局方批准的其他等效要求。 (d)应急灯的工作。除按照《运输类飞机适航标准》 (CCAR-25)第25.812 条的相应适航要求设置的仅限于一个辅 助装置使用、独立于飞机主应急照明系统、在该辅助装置放 下时能自动接通的那些灯外， 本条(c)款、(h)款所要求的每个 灯均应当满足下列要求： (1)每个灯应当： (i)能从飞行机组工作位置和客舱中客舱乘务员正常座位 易于接近处的两个地方进行人工控制； (ii)有防止人工控制装置误操作的装置； (iii)当在任一机组成员工作位置上使其处于接通或者待 命状态时，一旦飞机正常的供电电源中断时，它将保持燃亮 或者开始燃亮。 (2)在滑行、起飞和着陆期间，每个灯均应当处于待命或 者接通状态。在证明与本款相符时，无需考虑机身的横向垂 直分隔； (3)每个灯应当在应急着陆后的临界环境条件下， 提供所 要求照度水平的照明至少达10 分钟； (4)每个灯应当有驾驶舱内的控制装置，该装置具有“接 通”“断开”和“待命”三个位置。 (e)应急出口操纵手柄。 每个旅客应急出口操纵手柄的位 置和出口的开启说明应当符合《运输类飞机适航标准》 (CCAR-25)第25.811 条的相应适航要求，除非局方引用了满 足本款的其他要求。当任一操作手柄或者操作手柄外罩的发 光度(亮度)降至100 微朗伯之下时，该手柄或者手柄外罩不 得继续使用。 (f)应急出口的通道。每架载客飞机应当按照下列要求设 置至应急出口的通道： (1)各旅客区域之间的或者通向Ⅰ型或者Ⅱ型应急出口 的每条旅客通道应当无障碍物，其宽度不少于508 毫米(20 英寸)； (2)靠近每个Ⅰ型或者Ⅱ型应急出口处， 应当有足够的空 间以使机组成员能够帮助旅客撤离飞机，同时又满足本款第 (1)项所要求的通道无障碍宽度； (3)应当有从主通道至每一III 型和IV 型应急出口的通 道。从主通道至这些出口的通道应当不受座椅、卧铺或者其 他可能减小该出口效用的障碍物的阻碍。另外，该通道应当 符合《运输类飞机适航标准》(CCAR-25)第25.813 条的相应 适航要求，除非局方引用了满足本款的其他要求； (4)如果从客舱中任一座位到达任何要求的应急出口需 要经过客舱间的通道，则该通道应当无障碍，但是可以使用 不影响自由通行的布帘； (5)不得在客舱间的任何分隔板上设置门； (6)如果从任一旅客座位到达要求的应急出口需要经过 把客舱和其他区域隔开的门，则此门应当有装置将其闩在开 启位置，并且在每次起飞和着陆期间，这个门应当闩在开启 位置。此闩锁装置应当能够承受当该门相对于周围结构受到 一个《运输类飞机适航标准》(CCAR-25)第25.561 条所述的 极限惯性力时对其施加的载荷。 (g)机外出口标记。 每个旅客应急出口和从外面开启这个 出口的装置应当在飞机外部予以标记，机身侧面应当有框出 每一旅客应急出口的5 厘米(2 英寸)宽的色带。 每一外部标记 (包括这种色带)的颜色应当与周围机身表面有明显的对比而 易于区别。这些标记应当符合下列要求： (1)如果较深颜色的反射率等于或者小于15％， 则较浅颜 色的反射率应当至少为45％。 反射率是物体反射的光通量与 其接收的光通量之比； (2)如果较深颜色的反射率大于15％， 则其反射率与较浅 颜色反射率之差应当至少有30％； (3)不在机身侧面的出口应当有外部开启装置， 并用红色 醒目地标出适用的操作说明，或者，如果背景的颜色使得红 色不醒目，应当用鲜明的铬黄色作标记，并且当这种出口的 开启装置仅位于机身一侧时，应当在另一侧上作同样效果的 标记。 (h)外部应急照明和撤离路线。 (1)每架载客飞机应当装备符合《运输类飞机适航标准》 (CCAR-25)第25.812 条相应适航要求的外部照明设备； (2)每架载客飞机应当装备有符合《运输类飞机适航标 准》(CCAR-25)第25.810 条相应适航要求的防滑撤离路线。 (i)地板高度的出口。 机身侧面高等于或者大于1118 毫米 (44 英寸)、 宽等于或者大于508 毫米(20 英寸)但不到1168 毫 米(46 英寸)的每个地板高度的舱门或者出口(不包括那些不 能由客舱进入的通向货舱或者行李舱的舱门或者出口)、 每个 机身下部出口和每个尾锥出口，应当符合本条关于地板高度 应急出口的要求。但是，如果环境条件使得完全满足这些要 求不切实际，并且偏离这些要求能够达到可以接受的安全水 平，局方可以批准偏离本款的要求。 (j)额外的应急出口。客舱内超过应急出口最少数量要求 外的经批准应急出口，应当符合本条除(f)款第(1)、(2)、(3) 项以外的所有款项的要求，并且应当易于接近。 (k)在每架载客涡轮喷气动力飞机上， 每个机身下部出口 和尾锥出口应当符合下列要求： (1)设计和结构应使其在飞行中不能被打开； (2)在靠近出口开启装置明显位置上设置从762 毫米(30 英寸)的距离上即可以辨读的标牌， 说明此出口的设计和结构 使其在飞行中不能被打开。 (l)手电筒。载客飞机应当装备有从每个客舱乘务员座位 处易于接近的手电筒及其储放装置。 (m)对于按照本规则实施运行并且机身每侧配备了多个 旅客应急出口的飞机，机身同侧位于同层客舱的任何旅客应 急出口与相邻旅客应急出口之间的距离应当不超过18.3 米 (60 英尺)，该距离的测量应当平行于飞机的纵轴线测量两个 应急出口相距最近的出口边缘之间的距离。
# -------------------------------------
#
# 片段编号: 第 121.311 条
# 片段内容: 座椅、安全带和肩带装置 (a)载客飞机应当装备下列装置： (1)可以供机上每一个2周岁以上人员使用的经批准的座 椅或者卧铺； (2)可以供机上每一个2周岁以上的人员单独使用的经批 准的安全带，但在航路飞行期间，占用一个卧铺的两个人和 占用一个多座座椅或者长座椅的两个人可以共用一条经批 准的安全带。 (b)在飞机于地面移动、起飞和着陆期间，按照本规则运 行的飞机上每一个人均应当在经批准的座椅或者卧铺上就 座，并用单独的安全带适当扣紧。座椅上为该乘员配备的安 全带不得被2 周岁以上的人共用。但是： (1)对于不满2周岁的儿童可以由占有经批准座椅或者卧 铺的成年人抱着； (2)可以乘坐于经局方批准的儿童限制装置内， 该装置可 以是合格证持有人配备的，也可以是儿童父母、监护人携带 的，或者该儿童父母、监护人指定在飞行中照料其安全的护 理人员携带的，但合格证持有人应当确保： (i)儿童限制装置能够被恰当地固定在经批准的前向座椅 或者卧铺上； (ii)儿童能够被恰当地系紧在该限制装置内， 并且其体重 不超过该装置所规定的重量限制； (iii)在飞机起飞、着陆和地面移动期间，不得使用助力 式儿童限制装置、马甲式儿童限制装置、背带式儿童限制装 置和抱膝式儿童限制装置。 (c)如果儿童的父母、监护人或者指定的护理人员请求让 该儿童乘坐他们提供的儿童限制装置，当该儿童持有经批准 座位或者卧铺的机票，或者这种座位或者卧铺能够由合格证 持有人提供给该儿童使用， 并且本条(b)款第(2)项中的要求能 够满足，则该合格证持有人不得拒绝该儿童乘坐飞机。本条 并不阻止合格证持有人提供儿童限制装置，也不阻止合格证 持有人遵循安全操作常规，为儿童限制装置确定最适合的旅 客座椅位置。 (d)每一面向侧方的座椅应当符合《运输类飞机适航标 准》(CCAR-25)第25.785 条的相应适航要求。 (e)除本条(e)款第(1)项和第(2)项规定外，只有每一旅客 座椅的椅背处于竖立位置，合格证持有人方可以使飞机起飞 或者着陆。每个旅客应当遵守机组成员依照本款发出的指 令。 (1)本款不适用于为符合本规则第121.310 条(f)款第(3)项 的要求而让其处于非竖立位置的座椅靠背； (2)本款不适用于根据合格证持有人的手册中规定的程 序，在座位上载有货物或者坐有由于健康方面的原因不能直 坐的人的座椅，但其椅背不得妨碍机上乘员走向通道或者任 一应急出口。 (f)每架飞机应当在驾驶舱每一工作位置上配备有符合 《运输类飞机适航标准》(CCAR-25)第25.785 条的相应适航 要求的组合式安全带和肩带，方可以实施运行。 (g)每个客舱乘务员应当在客舱具有一个符合 《运输类飞 机适航标准》(CCAR-25)第25.785 条的相应适航要求的座椅 (含安全带和肩带)供起飞和着陆时使用。这些要求不适用于 非本规则第121.391 条要求的客舱乘务员乘坐的旅客座椅。 (h)要求装备组合式安全带和肩带装置的座椅上的每个 乘员，在起飞和着陆过程中都应当用这种组合式安全带和肩 带装置将乘员恰当扣紧，但在履行其正常职责需要时，可以 松开肩带。 (i)在每个无人乘坐的座椅上，若装有安全带或者肩带装 置，则应当将其固定好，使其不妨碍机组成员执行任务或者 紧急情况下人员的迅速撤离。 (j)实施载客运行运输类飞机的旅客和客舱机组成员的座 椅要求： (1)合格证持有人引进的按照本规则实施运行的2019 年 1 月1 日以后新制造的飞机，其所安装的旅客和客舱机组成 员的座椅必须满足1990 年7 月18 日颁布实施的《运输类飞 机适航标准》(CCAR-25)第25.562 条或者其后续修订的适用 要求，否则不得投入运行。 (2)自2019 年1 月1 日起，合格证持有人引进的按照本 规则实施运行的非中国登记注册的使用过的飞机，其所安装 的旅客和客舱机组成员的座椅必须满足1990 年7 月18 日颁 布实施的《运输类飞机适航标准》(CCAR-25)第25.562 条或 者其后续修订的适用要求，否则不得投入运行。
# -------------------------------------
#
# 片段编号: 第 121.312 条
# 片段内容: 座舱内部材料 (a)除局方另行批准外，对于按照本规则运行的飞机，其 每个座舱内的所有内部材料应当符合《运输类飞机适航标 准》(CCAR-25)第25.853 条的相应适航要求。 (b)除飞行机组成员座椅外， 机组或者旅客使用的坐垫应 当符合《运输类飞机适航标准》(CCAR-25)第25.853 条的适 用防火特性要求。
# -------------------------------------
#
# 片段编号: 第 121.313 条
# 片段内容: 其他设备 飞机只有安装下列设备，方可以实施本规则的运行： (a)如果飞机上装有保护性熔断器， 每种规格保护性熔断 器的备用数量应为该飞机批准的并在合格证持有人手册中 规定的数量。 (b)每个驾驶员工作位置上的风挡雨刷或者等效设备。 (c)符合运输类飞机型号合格审定适航要求的电源和配 电系统，或者在任一电源或者配电系统部件失效时，利用外 部电源，能为所需要的仪表和设备供电的发电和配电系统。 在系统中准许使用公共的元部件，只要局方认为其设计能合 理地防止失效。当使用由发动机驱动的多个电源时，它们应 当分装在各个发动机上。 (d)向必需飞行仪表供电的品质和充裕程度的指示装置。 (e)两个独立的静压系统，与外部大气相通，使得其受气 流变化、湿气或者其他外来物影响最小，且其安装除通气口 外均为气密的。当有装置将仪表从主工作系统转接到备用系 统上时，这一装置里应当具有一个可靠的位置控制器，且应 当予以标记，清楚地指明正在使用的系统。 (f)对于按照本规则运行的飞机，除机组成员外，如果机 上还搭载有其他乘员，则驾驶舱和乘员舱之间应当装有带锁 定装置的门(即驾驶舱门)，该锁定装置应当设计成只能从驾 驶舱内解锁，并且在使用中有效，以防止其他机上乘员未经 驾驶舱内飞行机组成员的同意将门打开，否则只有驾驶舱内 的飞行机组成员才能持有驾驶舱门的钥匙。对于从驾驶舱和 客舱都能进入的机组休息区的飞机，则该区和客舱之间应当 安装有带类似锁定装置的门。 (1)对于最大客座数大于20 人的载客飞机，其驾驶舱门 还应当满足下列要求： (i)机上应急出口的布局应当设计成使机组成员或者旅客 无需通过该舱门就能到达为他们设置的应急出口； (ii)应当有措施使飞行机组成员在该舱门被卡住的情况 下能从驾驶舱直接进入客舱； (iii)合格证持有人应当建立紧急情况下的措施，使得客 舱乘务员在飞行机组失去能力时能够进入驾驶舱。每位飞行 机组成员应当能够从其工作位置处操纵驾驶舱门锁定和解 锁装置，以及任何相关的指示信号或者身份确认系统。 (2)对于最大审定起飞重量超过45,500 千克或者客座数 超过60 人的载客飞机，驾驶舱门还应当符合下列要求： (i)能抵御未经许可人员的暴力入侵和关键部位能够承受 300 焦耳(221.3 英尺磅)的冲击，同时在旋钮和把手处能够承 受1,113 牛顿(250 磅)的拉伸载荷； (ii)能抵御轻型武器火力和爆炸装置的穿透， 符合有关适 航要求规定的标准。 (g)将客舱与设有应急出口设施的其他舱室隔开的每一 扇门应当配备钥匙，所配钥匙应当便于每个机组成员使用。 (h)在通往每一指定的旅客应急出口的每扇门上应有一 块标牌，用以指明在起飞和着陆期间此门应当处于打开状 态。 (i)对于旅客可以进入的舱室，如果舱门有可能被旅客锁 上，则应当为机组配备这些门的开锁装置，以便在紧急情况 下打开这些门。
# -------------------------------------
#
# 片段编号: 第 121.314 条
# 片段内容: 货舱和行李舱 (a)飞机中每个容积大于5.7 立方米(200 立方英尺)、 符合 《运输类飞机适航标准》 (CCAR-25)第25.857 条定义的C 级 舱，应当有下列任一材料构成的顶棚和侧墙衬板： (1)符合局方要求的玻璃纤维加强树脂； (2)符合《运输类飞机适航标准》(CCAR-25)附录F 要求 的材料； (3)经局方批准的铝衬板。 (b)为符合本条，术语“衬板”包括诸如连结处或者紧固件 这些影响衬板失火安全包容性能的任何设计细节。
# -------------------------------------
#
# 片段编号: 第 121.315 条
# 片段内容: 驾驶舱检查单 (a)合格证持有人应当为每一型号飞机提供经批准的驾 驶舱检查单。 (b)这些经批准的检查单应当至少包括在起动发动机、 起 飞或者着陆之前，以及在发动机和系统出现了紧急情况时， 飞行机组成员为确保安全应当进行的每一项检查。检查单的 设计应当使飞行机组成员无需依赖于对所要进行检查的项 目的记忆。 (c)经批准的检查单应当放置在每架飞机驾驶舱内方便 飞行机组成员使用的地方，飞行机组在操作飞机时应当遵循 检查单规定的程序。
# -------------------------------------
#
# 片段编号: 第 121.316 条
# 片段内容: 燃油箱 按照本规则运行的涡轮发动机飞机应当符合《运输类飞 机适航标准》(CCAR-25)第25.963 条的要求。
# -------------------------------------
#
# 片段编号: 第 121.317 条
# 片段内容: 旅客告示 (a)按照本规则实施运行的飞机应当装备旅客告示信号 和标牌。这些信号装置应当设计成能由机组成员接通或者断 开。 (b)飞机在地面的任何移动，以及每次起飞、着陆和机长 认为必要的其他任何时间，应当接通“系好安全带”信号。 (c)按照本规则运行的载客飞机，应当从每个旅客座位都 能看到至少一个“系好安全带”的明显信号或者标牌。这些信 号或者标牌无需符合本条(a)款的要求。 (d)当“系好安全带”信号亮时，本规则第121.311 条(b)款 要求具有座位的每位旅客，应当系好旅客座椅安全带并保持 系紧状态。 (e)飞机在运行时，应当使“禁止吸烟”的告示信号灯保持 常亮，或者出示一个或者几个符合《运输类飞机适航标准》 (CCAR-25)第25.1541 条要求的“禁止吸烟”的标牌。 若同时使 用灯光信号及标牌，则灯光信号在整个飞行航段上应当保持 常亮。 (f)每一厕所内应当有一个标志或者标牌， 其上标明“严禁 破坏厕所烟雾探测器”。该标志或者标牌无需符合本条(a)款 的要求。 (g)在飞机上的任何人应当遵守下列规定： (1)当“禁止吸烟”信号灯亮时或者“禁止吸烟”标牌出示 时，不得在客舱内吸烟； (2)不得在飞机的厕所内吸烟； (3)不得触动、 损害或者破坏飞机厕所内安装的烟雾探测 器。 (h)当飞机在地面的任何移动，在每次起飞、着陆和机长 认为必要的其他任何时间内，应当接通“禁止吸烟”信号。 (i)每个旅客应当遵守机组成员为符合本条(e)款、 (g)款第 (1)项和(f)款第(2)项要求而发出的指令。
# -------------------------------------
#
# 片段编号: 第 121.318 条
# 片段内容: 机内广播系统 (a)旅客座位数超过19 的飞机实施载客运行时，应当装 备有符合下列要求的机内广播系统： (1)除手持受话器、耳机、话筒、选择开关和信号发送装 置外，能不依赖于本规则第121.319 条所要求的机组成员机 内通话系统而独立工作； (2)依据《民用航空产品和零部件合格审定规定》 (CCAR-21)的规定获得批准或者认可。 (b)本条(a)款要求的机内广播系统应当符合下列要求： (1)从驾驶舱两个飞行机组成员的每个工作位置上易于 接近并能立即使用； (2)为每个有邻近客舱乘务员座位的地板高度旅客应急 出口配备一个话筒，使在邻近的客舱乘务员座位上就座的客 舱乘务员易于迅速使用。但若出口很接近，就座的客舱乘务 员之间能无困难地口头联络，则一个话筒可以为几个出口所 共用； (3)应当能让每一客舱内便于使用它的位置上的客舱乘 务员，在10 秒钟之内使其工作； (4)在所有旅客座位、厕所、客舱乘务员座位与工作台上 都能听见。 (c)按照本规则实施运行的1995 年12 月18 日后制造的 飞机，还应当符合《运输类飞机适航标准》(CCAR-25)第 25.1423 条的要求。
# -------------------------------------
#
# 片段编号: 第 121.319 条
# 片段内容: 机组成员机内通话系统 (a)旅客座位数超过19 的飞机应当装备有符合下列要求 的机组成员机内通话系统： (1)除手持受话器、耳机、话筒、选择开关和信号发射装 置外，能不依赖于本规则第121.318 条(a)款所要求的机内广 播系统而独立工作； (2)符合本条(b)款的要求。 (b)本条(a)款所要求的机组成员机内通话系统应当依据 《民用航空产品和零部件合格审定规定》(CCAR-21)的规定 获得批准或者认可，并且应当符合下列要求： (1)应当提供驾驶舱与下列各处的双向通信： (i)每一旅客客舱； (ii)不在主客舱地板高度上的每一厨房。 (2)应当便于在驾驶舱内两个飞行机组成员工作位置中 每一个位置上立即使用； (3)应当便于在每个客舱内至少一个客舱乘务员正常工 作位置上使用； (4)应当能让每一客舱内便于使用它的位置上的客舱乘 务员，在10 秒钟之内使其工作； (5)对于涡轮喷气动力的飞机： (i)应当便于从足够数量的客舱乘务员工作位置上使用， 使得从一个或者几个这样装备的工作位置上可以看到每一 客舱内所有地板高度的应急出口(或者当出口在厨房内时看 到通向这些出口的进口通道)； (ii)应当具有一个包括音响或者目视信号的警戒系统， 用 于飞行机组人员呼叫客舱乘务员和客舱乘务员呼叫飞行机 组成员； (iii)本款第(5)项第(ii)目所要求的警戒系统应当能使接收 到呼叫的人确定是正常的呼叫还是紧急的呼叫； (iv)当飞机停放于地面时， 它应当有装置使地面人员和驾 驶舱内至少两个飞行机组成员中的任一人之间进行双向通 话。供地面人员使用的机内通话系统位置应当使得从飞机内 看不到使用该系统的人员。
# -------------------------------------
#
# 片段编号: 第 121.320 条
# 片段内容: 高度保持和警告系统 (a)按照本规则实施运行的飞机应当安装有一个具有下 列功能的高度保持和警告系统： (1)向飞行机组指示所飞的高度； (2)自动保持所选择的高度； (3)当接近预选高度时， 能至少发出音频或者视频信号提 示飞行机组； (4)当飞机偏离预选高度时， 能向飞行机组至少发出听觉 或者视觉警告。
# -------------------------------------
#
# 片段编号: 第 121.323 条
# 片段内容: 夜间运行的仪表和设备 在夜间实施运行的飞机，除装备有本规则第121.325 条 所要求的全部仪表和设备之外，还应当加装下列设备： (a)航行灯； (b)防撞灯； (c)两个着陆灯； (d)客舱灯光。
# -------------------------------------
#
# 片段编号: 第 121.325 条
# 片段内容: 仪表飞行规则运行的仪表和设备 在仪表飞行规则条件下运行的飞机，除应装备有本规则 第121.305 条至第121.319 条、 第121.743 条所要求的仪表和 设备之外，还应当加装下列仪表和设备： (a)一个空速指示系统，带加温的空速管或者等效装置， 以防止因结冰而故障。 (b)一个灵敏型高度表。 (c)仪表灯光，能提供足够照明的仪表灯，可以使每一必 需的仪表、开关或者类似的装置清晰易读，并且其安装方式 使得光线既不会直射飞行机组成员的眼睛，也不会造成有害 的反射光线。除非无调光的仪表灯光是令人满意的，否则应 有措施控制照明的强度。
# -------------------------------------
#
# 片段编号: 第 121.329 条
# ...
# -------------------------------------
#
# 片段编号: 第 121.701 条
# 片段内容: 飞机飞行记录本 (a)合格证持有人应当对于每一架飞机建立飞机飞行记 录本，记录运行中发现的缺陷和工作不正常情况及所进行的 维修工作； 另外， 它还用于记录与飞行安全有关的运行信息、 飞行机组和维修人员需要了解的有关数据。 (b)飞机飞行记录本中应当包括飞机运行信息、 影响飞机 适航性和安全运行的任何缺陷及保留状况、要求的维修项 目、维修工作记录、飞机放行等内容。 (c)飞机飞行记录本的格式应当固定，各项内容应当使用 墨水或者不可以更改的书写工具及时填写，并且有足够的复 页以保证满足使用和保存要求。 (d)合格证持有人应当在飞机上飞行机组成员易于取用 的地方放置一份飞机飞行记录本原件，其中至少记录包括每 次飞行前三次飞行期间填写内容的连续记录，并且每次起飞 前在地面保存一份记录上一次飞行和本次飞行前填写内容 的飞机飞行记录本的复页。 (e)合格证持有人应当在维修工程管理手册中规定飞机 飞行记录本的格式及填写、使用和保存要求。
# -------------------------------------
#
# 片段编号: 第 121.702 条
# 片段内容: 燃油和滑油记录 (a)运营人必须保存燃油记录，以满足飞机使用燃油要 求。 (b)运营人必须保存滑油记录， 以便实施滑油消耗监控并 满足飞机安全飞行。 (c)燃油和滑油记录必须保存3 个月以上。
# -------------------------------------
#
# 片段编号: 第 121.703 条
# 片段内容: 通信记录 合格证持有人应当记录与其飞行机组成员之间每次航 路上使用满足本规则第121.97 条通讯设备联系的记录， 并将 该记录至少保存30 天。
# -------------------------------------
#
# 片段编号: 第 121.704 条
# 片段内容: 航空器观测和报告 (a)合格证持有人应当制定政策和程序，以保证其飞机根 据所飞越国家或者情报区(管制区)的要求完成航空器例行观 测、航空器特殊观测和其他非例行观测，记录并向空中交通 管制员报告观测到的情况。 (b)对于合格证持有人没有配备空地数据链的飞机， 可以 免除航空器例行观测。 (c)合格证持有人的飞机针对喷发前的火山活动、 火山喷 发或火山灰云所进行的航空器特殊观测情况，应当记录在火 山活动报告表上。当气象部门认为火山灰可能会影响航线上 的飞行时，合格证持有人应当在提供给飞行机组的飞行文件 中附上火山活动报告表。
# -------------------------------------
#
# 片段编号: 第 121.705 条
# 片段内容: 飞行中紧急医学事件报告 (a)合格证持有人应当记录飞行中发生的紧急医学事件， 并应当在事发后48 小时内向局方报告。紧急医学事件记录 信息应当包括： 事件发生的时间、 航班航段、 事件具体情况、 涉及人员和处置过程等。记录应当保存24 个月。 (b)飞行中发生的紧急医学事件包括： 运行中发生的人员 伤病或死亡，以及突发公共卫生事件。
# -------------------------------------
#
# 片段编号: 第 121.706 条
# 片段内容: 国际运行中对可疑传染病的报告 按照目的机场所在地的规定，当飞行中发现可疑传染病 病例时，机长应当立即报告正在通信的空中交通管制单位， 报告内容应当包括： 飞机注册号、 出发地机场、 目的地机场、 预计抵达时间、机上人数、可疑传染病病例人数、症状及风 险(如已知)等信息。
# -------------------------------------
#
# 片段编号: 第 121.707 条
# 片段内容: 使用困难报告 (a)合格证持有人应当按照局方要求的方式向局方上报 其飞机的使用困难报告。使用困难报告包括运行中出现严重 故障或者失效，或者维修中发现的危及或者可能危及飞行安 全的故障、失效或者缺陷。 (b)合格证持有人应当在24 小时之内向局方报告本条所 要求报告的情况，并至少保存报告的信息30 天，以备局方 核查。 (c)合格证持有人应当按照局方要求的方式报告本条所 要求报告的情况，报告中应当至少包括下列信息： (1)飞机的制造厂家、型号、飞机/发动机/螺旋桨的序号； (2)飞机登记号； (3)合格证持有人的名称； (4)发生或者发现日期和地点； (5)失效、故障或者缺陷的发生阶段； (6)失效、故障或者缺陷的性质； (7)适用的ATA 章节； (8)飞机、发动机、螺旋桨或者部件的总使用时间或者循 环； (9)失效、 故障或者存在缺陷的零部件的制造厂家、 件号、 名称、序号和部位； (10)采取的预防或者紧急措施； (11)为了更完整地分析失效、故障或者缺陷原因的其他 信息，包括主要部件与型号设计有关的可以提供信息和自上 次翻修、修理和检测的适用时间。 (d)即使上述要求的信息不能完全提供， 合格证持有人也 不能推迟可以提供内容的报告时间，并且应当尽快补充报告 没有提供的信息。 (e)当使用困难报告涉及设计、 制造缺陷或者持续适航文 件问题时，相关报告信息还应当及时通报相应型号合格证持 有人。
# -------------------------------------
#
# 片段编号: 第 121.709 条
# 片段内容: 机械原因中断使用汇总报告 (a)合格证持有人应当在每月10 日之前向局方报告前一 个月出现的因机械原因的下列情况的汇总报告： (1)中断飞行； (2)非计划更换飞机； (3)延误、备降或者改航； (4)因已知或者怀疑的机械原因引起的非计划换发。 (b)合格证持有人应当按照局方规定的格式和方式提交 本条所要求的报告。
# -------------------------------------
#
# 片段编号: 第 121.710 条
# 片段内容: 运行中人为差错报告 合格证持有人应当在72 小时内向局方报告运行中出现 的飞行机组成员、维修及其他运行控制人员发生的人为差 错。 W 章 延程运行(EDTO)与极地运行
# -------------------------------------
#
# 片段编号: 第 121.711 条
# 片段内容: 概则 (a)合格证持有人除经局方批准外不得实施下列运行： (1)在飞机计划运行的航路上至少存在一点到任一延程 运行(EDTO)可选备降机场的距离超过飞机在国际标准大气 和静止空气条件以经批准的一台发动机不工作时的巡航速 度飞行60 分钟对应的飞行距离(以两台涡轮发动机为动力的 飞机)或者超过180 分钟对应的飞行距离(以多于两台涡轮发 动机为动力的载客飞机)的运行； (2)在北极区域内的运行； (3)在南极区域内的运行。 (b)本章还规定了获得极地运行批准的各项要求。 (c)只有当机体发动机组合获得局方颁发的延程运行 (EDTO)型号设计批准时， 合格证持有人才有资格实施延程运 行(EDTO)。 延程运行型号设计批准通常在相应的机体发动机 组合的《飞机飞行手册》(AFM)、型号合格证(TC)或者补充 型号合格证(STC)中给出。 (d)为纠正运行中出现可能危及到所要求的可靠性水平 时，局方可以在任何时候要求修改构型、维修与程序标准。 局方将根据需要采取行动，要求对构型、维修与程序标准进 行修订， 以达到和保持所需的可靠性水平。 修订之前的构型、 维修与程序标准被认为不再适合于继续从事延程运行 (EDTO)。 (e)延程运行(EDTO)的批准通过颁发或者修改合格证持 有人的运行规范的方法进行。 (f)对于每一次延程运行(EDTO)， 签派放行单中应当包含 该次延程运行(EDTO)最大改航时间。 第121.713 附加要求 (a)对于从航路上一个点飞往一个航路备降机场的运行 超过60 分钟的情况，合格证持有人必须确保： (1)对于所有飞机： (i)指定了航路备降机场； (ii)向飞行机组提供指定航路备降机场的最新资料， 包括 工作状况与气象条件。 (2)对于双发涡轮驱动实施延程运行(EDTO)飞机，除非 根据最新的资料评估，指定的航路备降机场气象条件在预计 使用时间能够达到或高于合格证持有人运行规范批准的机 场运行最低标准，否则不得超过本规则第121.711 条(a)款第 (1)项规定的时间飞行。 如果经确定的任何条件不允许飞机在 预计的使用时间在该机场安全进近并着陆，必须确定一个备 用的运行方案。 (b)合格证持有人应当为所有已获得延程运行(EDTO)批 准的飞机制定签派放行程序，以防止将飞机被签派到改航时 间超过经局方批准的延程运行(EDTO)关键系统时间限制能 力的航路上。 (c)对于超过180 分钟的延程运行(EDTO)和极地运行， 该 次运行所指定的每个延程运行(EDTO)指定备降机场和极地 运行改航机场，都应当具备足以保障乘客和机组生存需求的 条件。 (d)合格证持有人应当在下列程序和大纲中增加本条(a) 款至(c)款的内容，以保证整体安全水平： (1)运行控制与飞行签派程序； (2)运行程序； (3)训练大纲。
# -------------------------------------
#
# 片段编号: 第 121.714 条
# 片段内容: 延程运行(EDTO)的通信设备 如果实施超过180 分钟的延程运行(EDTO)， 满足本规则 第121.97 条(c)款所规定的通信系统应当能提供基于卫星的 语音通信，通话质量与固定电话相当。该系统应当能够在飞 行机组和空管人员之间以及飞行机组和合格证持有人之间 提供通信。 合格证持有人在规划延程运行(EDTO)时， 还应当 考虑改航至延程运行(EDTO)备降机场所需的可能的航线和 海拔高度，以确定基于卫星的语音通信设备是否可用。如果 存在无法利用基于卫星的语音通信设备的情况，或者因其质 量低劣而无法进行语音通信，则应当有另一种通信系统作为 替代。
# -------------------------------------
#
# 片段编号: 第 121.715 条
# 片段内容: 延程运行(EDTO)备降机场：救援与消防 服务 (a)除本条(b)款中的规定之外， 在签派或者飞行放行单上 列明的每一个延程运行(EDTO)备降机场， 均需能够提供下列 救援和消防服务(RFFS)： (1)如果延程运行(EDTO)时间在180 分钟内，每个指定 的延程运行(EDTO)备降机场应当能够提供等效于或者高于 国际民航组织规定的第4 类救援和消防服务(RFFS)的要求； (2)如果延程运行(EDTO)时间超过180 分钟，每个指定 的延程运行(EDTO)备降机场应当能够提供等效于或者高于 国际民航组织规定的第4 类救援和消防服务(RFFS)的要求。 此外，飞机还应当保持在距能够提供等效于或者高于国际民 航组织规定的第7 类救援和消防服务(RFFS)的合适机场的一 定距离内， 以便能在依据其延程运行(EDTO)批准的改航时间 内飞抵该合适机场。 (b)如果无法直接在一个机场利用本条(a)款要求的救援 和消防设备与人员，只要该机场通过当地获得消防增援与消 防服务能力后，能够达到本条(a)款的要求，合格证持有人仍 然可以在签派或者飞行放行单上将该机场列为备降机场。在 改航的航路运行过程中如果当地资源可以及时被告知， 30 分 钟的增援响应时间应当是充足的。在改航飞机飞抵备降机场 时，增援设施与人员应当可用，另外，只要改航飞机需要救 援和消防服务，这些增援设施与人员就应当始终处于随时可 用状态。
# -------------------------------------
#
# 片段编号: 第 121.716 条
# 片段内容: 手册内容 合格证持有人的手册中应当包含下列内容： (a)对于所从事的延程运行(EDTO)， 支持所有飞行阶段的 性能数据。 (b)对于载客运行： (1)如果实施超过180 分钟的延程运行(EDTO)，应当制 订每一相应延程运行(EDTO)备降机场具体的旅客航程恢复 计划； (2)对于在北极区域和南极区域的运行， 应当制订每一相 应极地运行改航机场具体的旅客航程恢复计划。
# -------------------------------------
#
# 片段编号: 第 121.718 条
# 片段内容: 延程运行型号设计批准依据 除2015 年2 月17 日之前制造的安装两台以上发动机的 载客飞机和仅用于实施飞行时间少于或者等于75 分钟的延 程运行的双发飞机之外，合格证持有人只能在下列条件下实 施延程运行：飞机获得延程运行型号设计批准且每架用于延 程运行的飞机均符合其构型、维修和程序文件的要求。延程 运行型号设计批准通常在相应的机体发动机组合的《飞机飞 行手册》 (AFM)、 型号合格证(TC)或者补充型号合格证(STC) 中给出。
# -------------------------------------
#
# 片段编号: 第 121.719 条
# 片段内容: 延程运行持续适航性维修方案(CAMP) 为实施延程运行，合格证持有人应当制定并遵照由局方 批准的运行规范中持续适航维修方案的要求对用于延程运 行的机体发动机组合实施维修。合格证持有人可以通过对飞 机制造厂推荐的维修方案，或者对现在已获批准的持续适航 维修方案增补维修要求来制定适用于延程运行的持续适航 维修方案。这个持续适航维修方案应当包括下列内容： (a)延程运行维修文件。 合格证持有人应当制定延程运行 维修文件，供每一名延程运行相关人员使用。 (1)这个文件应当： (i)列出延程运行的所有关键系统； (ii)引用或包含所有和延程运行相关的维修要素； (iii)引用或包含所有支援项目和程序； (iv)引用或包含所有职责； (v)明确说明引用材料源于合格证持有人文件系统何处。 (b)延程运行前维修检查。 合格证持有人应当制定针对延 程运行特定要求的维修检查单并实施检查。 (1)每次延程运行前， 合格证持有人应当完成延程运行前 维修检查。 (2)这种检查应当至少包括下列各项： (i)检验(确认)所有延程运行关键系统的状态； (ii)通过核查相应的维修记录，确认飞机的总体状况； (iii)进行飞机内外检查，确定发动机和辅助动力装置的 滑油量和滑油消耗率。 (3)由具有延程运行资格并获得批准的维修人员完成并 签署特殊延程运行相关工作文件，延程运行前地面勤务检查 完成的签署应当由具有机身和发动机等级并且具有延程运 行资格的维修人员签署。 (c)双重维修项目的限制。 (1)除了本款第(2)项的规定之外， 合格证持有人应当避免 在同一次停场维修时对相同的或者本质上相同的延程运行 关键系统同时实施例行或者非例行维修工作，以防止由于不 适当的维修而导致的延程运行关键系统的失效。 (2)如果本款第(1)项所定义的双重维修不可避免， 合格证 持有人可以按照下列规定进行维修： (i)同一个延程运行关键系统的维修工作由不同的技术人 员执行； (ii)如果应当由同一名技术人员对同一延程运行关键系 统进行维修时，应加派一名资历更高的人员对其工作实施直 接的监督； (iii)在飞机实施延程运行之前，必须按照本条(d)款的要 求通过地面检验、测试方法以及在必要的情况下通过飞行试 验的方法对延程运行关键系统维修工作的有效性进行验证。 在特殊情况下，可以由同一名具备合格资质的人员，在具备 延程运行维修控制合格资质人员的监督下来实施双重维修 和地面检验、 测试方法， 但前提是必须完成相应的飞行试验。 (d)验证方案。 合格证持有人应当制定并保持一个解决方 案，以确保对延程运行关键系统采取的维修工作的有效性。 验证方案应当识别潜在的问题，并核实令人满意的纠正措 施。验证方案应当包含地面检验和空中检验策略与程序。合 格证持有人应当建立程序，明确指示启动检验行动的人员以 及必不可少的行动项。可以在取酬的延程运行中进行验证， 但要求验证工作在到达延程运行进入点之前顺利完成并且 记录所进行的验证工作。 (e)识别任务。合格证持有人应当标示出所有与延程运行 相关的任务。这些与延程运行相关的特定工作应当由经过适 当培训且具有延程运行资格的维修人员完成并签署。 (f)集中的维修控制程序。合格证持有人应当为延程运行 制定并保持集中的维修控制程序。 (g)零部件控制方案。 合格证持有人应当制定一个延程运 行零部件控制方案，以确保正确识别用于实施延程运行飞机 构型控制的零部件。 (h)可靠性方案。 合格证持有人应当制定一个延程运行可 靠性方案。该方案应当是在合格证持有人现有可靠性方案或 者其持续分析和监督系统(CASS)的基础上增补延程运行的 内容。该方案应当是以事件分析为基础的方案，并包含下列 事件的报告程序： (1)在发生下列事件后，涉及本规则第121.707 条规定项 目的，按照规定要求向局方报告；其他项目应当在96 小时 内向局方报告： (i)空中停车，但在飞行训练时计划的空中停车除外； (ii)由与飞机或者发动机系统相关的失效、 故障或缺陷引 起的改航和返航； (iii)非指令动力或者推力变化或者喘振； (iv)发动机失控或者无法获得要求的动力或者推力； (v)因疏忽产生的燃油损耗或者无燃油可用， 或者飞行中 无法纠正的燃油不平衡； (vi)与延程运行关键系统相关的失效、故障或者缺陷； (vii)任何危及实施延程运行安全飞行和着陆的事件。 (2)合格证持有人应当调查本款第(1)项中列明的每一事 件的原因，并向局方提交调查结果和纠正措施说明。纠正行 动应当被局方所接受。 (i)动力系统监控： (A)如果作为机体发动机组合一部分的发动机的空中停 车率(基于12 个月滚动平均值)超过下列数值， 合格证持有人 应当综合评审其运行，以识别任何共因影响和系统错误。 ①如果延程运行(EDTO)时间小于或者等于120 分钟， 空 中停车率为0.005 次/1,000 发动机工作小时； ②如果在北太平洋区域延程运行(EDTO)时间超过120 分钟且小于或者等于207 分钟，以及在其他区域延程运行 (EDTO)时间超过120 分钟且小于或者等于180 分钟， 空中停 车率为0.003 次/1000 发动机工作小时； ③如果在北太平洋运行区域延程运行(EDTO)时间超过 207 分钟，以及在其他区域延程运行(EDTO)时间超过180 分 钟，空中停车率为0.002 次/1000 发动机工作小时。 (B)在空中停车率超过上述数值30 天之内，合格证持有 人应当向局方提交一个调查报告以及已采取的任何必要的 纠正措施。 (j)发动机状况监控。 (1)合格证持有人应当制定一个发动机状况监控方案， 以 便在早期检测到发动机的性能恶化，并在安全运行受到影响 之前采取纠正措施； (2)该方案应当描述待监控参数、数据收集方法、数据分 析方法和采取纠正措施的流程； (3)该方案应当确保发动机极限值裕度能得以维持， 以便 在批准的动力水平、所有预期的环境条件下，实施发动机失 效状态下的延程改航，而不会超出批准的发动机限值。这包 括多种批准的限值，如转子速度和排气温度。 (k)滑油消耗量监控。 合格证持有人应当制定一个发动机 油耗监视方案，以确保飞机具有足够的滑油以完成每次的延 程运行。如果延程运行中需要使用辅助动力装置，则辅助动 力装置油耗应当包括在内。合格证持有人的油耗极限值不得 超过制造厂家的推荐值。应当对发动机油耗进行持续监控， 并将在延程运行的每一个离港机场添加的滑油包含在内。该 方案应当比较延程运行每个离港机场的加油量与运行过程 的平均油耗，以识别突然的油耗增加。 (l)辅助动力装置空中起动方案。如果飞机的取证要求辅 助动力装置，但不要求其在延程运行时工作，则合格证持有 人应当制定和保持一个局方接受的低温情况下辅助动力装 置的空中起动和工作的方案。 (m)维修培训。 对于每一种机体发动机组合， 合格证持有 人应当制定一个维修培训方案，提供充分的培训以支持延程 运行。培训项目应当包括对所有参与延程运行的维修的人员 提供与延程运行相关的培训，同时，这种培训注重延程运行 的特殊性质。该培训应当是对已接受过飞机和发动机维修培 训的维修人员的基础上的补充培训。 (n)构型、维修与程序(CMP)文件。如果一种机体发动机 组合具有一个构型、维修和程序文件，则合格证持有人应当 有适用的系统来满足经局方批准文件的要求。 (o)程序变化。 合格证持有人对延程运行相关的维修或者 培训程序所做的任何实质改变都应当提交局方审核。在局方 通知合格证持有人审核完成之前，合格证持有人不得执行已 改变的程序。
# -------------------------------------
#
# 片段编号: 第 121.720 条
# 片段内容: 机组成员与签派人员培训要求 合格证持有人应当对其机组成员和签派人员就其在合 格证持有人的旅客航程恢复计划中的职责和作用进行培训。 X 章 应急医疗设备和训练
# -------------------------------------
#
# 片段编号: 第 121.741 条
# 片段内容: 适用范围 本章规定了按照本规则实施载客运行的合格证持有人 的机载应急医疗设备和训练的要求，但并不要求合格证持有 人及其代理人提供专业的应急医疗服务。
# -------------------------------------
#
# 片段编号: 第 121.743 条
# 片段内容: 应急医疗设备 (a)按照本规则运行的合格证持有人应当在其载客飞机 上配备下列应急医疗设备： (1)急救箱； (2)应急医疗箱； (3)卫生防疫包。 (b)本条所要求的各项应急医疗设备： (1)应当附加名称标识，并有明确的使用方法提示； (2)应当放置在客舱内，便于机组成员取用； (3)应当以6个月为周期或者根据所配物品有效期和更新 要求进行定期检查更新，以确保在紧急情况下能够使用。检 查更新日期应当标注在包装外。 (c)每架飞机配备的应急医疗设备数量和医疗物品种类 应当符合本规则附件B 的要求。
# -------------------------------------
#
# 片段编号: 第 121.745 条
# 片段内容: 机组成员处置飞行中紧急医学事件的训 练 (a)合格证持有人的每一训练大纲中应当包括本条规定 的，针对每一型别、厂家、构型的飞机、每一机组必需成员、 每一运行种类的适用训练内容。 (b)训练应当包括下列内容： (1)遇有紧急医学事件时的处置程序， 包括机组成员之间 的协调； (2)应急医疗设备的存放位置、功能和使用方法； (3)急救箱、 应急医疗箱和卫生防疫包内物品和药品的用 途及使用方法； (4)每一客舱乘务员还应当训练： (i)心肺复苏和隔离消毒等知识和操作； (ii)至少每24 个月进行一次复训，包括心肺复苏的操作 练习。 (c)本条要求的机组成员实际操练和复训不需要达到或 者相当于专业急救人员的水平。 Y 章 法律责任
# -------------------------------------
#
# 片段编号: 第 121.760 条
# 片段内容: 一般规定 违反本规则规定， 《中华人民共和国民用航空法》 《中华 人民共和国安全生产法》 《中华人民共和国飞行基本规则》 等有关法律、行政法规对其处罚有明确规定的，从其规定。
# -------------------------------------
#
# 片段编号: 第 121.761 条
# 片段内容: 未取得运行合格证从事本规则规定的运 行 航空运营人未按照本规则取得运行合格证即从事本规 则第121.3 条规定的运行活动的，由其运行活动所在地的民 航地区管理局责令其停止上述运行活动，处3 万元以上10 万元以下的罚款；情节严重的，处10 万元以上20 万元以下 的罚款。
# -------------------------------------
#
# 片段编号: 第 121.762 条
# 片段内容: 提供虚假材料的处罚 对于处于运行合格审定过程中的运行合格证申请人，违 反本规则第121.37 条规定， 存在弄虚作假情况的， 局方应当 终止其运行合格审定进程，并作出不予许可的决定，自作出 不予许可决定之日起1 年内不再受理该申请人的相应申请。 对于申请人在运行合格审定过程中以欺骗、贿赂等不正 当手段取得运行合格证、运行规范和其他批准项目的，由局 方撤销相应的证件和批准，自撤销其相应证件和批准之日起 3 年内不再受理该申请人的相应申请。
# -------------------------------------
#
# 片段编号: 第 121.763 条
# 片段内容: 违反本规则规定的行为 (a)合格证持有人有下列行为之一的，局方责令其停止违 法行为，可以处警告或者1 万元以上3 万元以下的罚款；情 节严重的，处3 万元以上10 万元以下的罚款： (1)违反本规则C 章的规定， 未满足合格证持有人管理一 般规定的； (2)违反本规则G 章的规定，未落实手册要求的； (3)违反本规则H 章的规定， 使用不符合要求的飞机实施 本规则运行的； (4)违反本规则I 章的规定，超过飞机性能使用限制实施 本规则运行的； (5)违反本规则K 章的规定， 飞机的仪表和设备不符合本 规则要求的； (6)违反本规则L 章的规定，未落实其飞机适航性责任 的； (7)违反本规则N 章的规定， 使用未经局方批准的训练大 纲或者未按照经批准的训练大纲进行规定的训练而实施运 行的； (8)违反本规则M 章、O 章、R 章或者Q 章的规定，机 组成员和其他航空人员不符合规定的要求，未按照规定使用 或者搭配航空人员的； (9)违反本规则P 章或者第121.503 条的规定，未按照规 定安排航空人员的值勤期、飞行时间和休息时间的； (10)违反本规则T 章的规定，未能对飞机上的人员、货 物和设备等进行有效管理，对运行安全造成威胁的； (11)违反本规则U 章中规定的签派和飞行放行规则签派 或者放行飞机的； (12)违反本规则第121.380 条、 第121.557 条、 第121.559 条、 第121.573 条(d)款、 第121.575 条(d)款或者V 章的规定， 未按照规定的内容、时间、格式和方式报告有关情况或者未 按照规定保存有关信息的； (13)违反本规则W 章的规定， 实施延程和极地运行时造 成旅客生命安全受到威胁或者造成事故征候或者事故的； (14)违反本规则X 章的规定，未在载客飞机上配备规定 的应急医疗设备，或者未对相关机组成员实施相应培训的； (15)违反本规则S 章的规定，未按特殊运行授权和限制 实施运行的； (16)局方认定的其他可能对安全造成威胁的行为。 (b)对于未按照合格证持有人的手册或者管理规则履行 职责而导致违反本规则规定，或者其本人直接违反本规则规 定的航空人员或者其他相关人员，局方可以处警告或者500 元以上1000 元以下的罚款。
# -------------------------------------
#
# 片段编号: 第 121.764 条
# 片段内容: 违反本规则规定的行为 对合格证持有人的撤销许可、行政处罚、行政强制等处 理措施及其执行情况记入守法信用信息记录，并按照有关规 定进行公示。 Z 章 附   则
# -------------------------------------
#
# 片段编号: 第 121.771 条
# 片段内容: 施行 本规则自公布之日起施行。 交通运输部于2017 年9 月4 日以交通运输部令2017 年第29 号公布，2020 年5 月11 日 以交通运输部令2020 年第9 号、 2021 年3 月15 日以交通运 输部令2021 年第5 号修改的《大型飞机公共航空运输承运 人运行合格审定规则》同时废止。 除另有规定外，在本规则修订版施行之前已经持有按本 规则颁发的现行有效运行合格证的航空承运人应当于2026 年1 月1 日之前完全符合本次修订版的要求。 附件A 定  义 安全管理体系：是指管理安全的系统做法，包括必要的 组织机构、政策、问责制和程序。 飞行安全文件系统：是指由合格证持有人制订，用于规 定或者指导合格证持有人飞行和地面运行人员日常安全运 行所必需的相关资料， 其中应当包括本规则G 章规定的手册 及内容，手册的保存、分发、获取、修订及有效性控制的程 序和方法。 飞机飞行手册：是指经适航审定部门批准的飞机飞行手 册(如AFM)，包括确认该飞机适航所需满足的限制，以及飞 行机组成员安全操纵航空器所必需的指令和信息。根据中国 民航适航审定规章，所必须的指令和信息至少包括： (1)飞机的使用限制、使用程序、性能资料等信息； (2)由于设计、 使用或者操作特性而为安全运行所必需的 其他资料； (3)任何为了符合中国民航局有关噪声规定要求而确定 的限制、程序或者其他数据。 飞行数据分析：是指为了提高飞行运行安全而对合格证 持有人所记录的飞行数据加以分析的过程。 飞行数据分析方案：有时也被称为飞行数据监控(FDM) 或者飞行品质监控(FOQA)， 是一种系统化、 主动识别危险源 的工具，以便通过改进飞行机组情景意识、训练有效性、操 作程序、飞机维修方案等方式提升安全水平。飞行数据分析 方案还可以用于下列方面： (1)确定操作规范； (2)识别在操作程序、机队、机场等方面存在的潜在和实 际的危险源； (3)识别趋势； (4)监控风险控制或者纠正措施的有效性； (5)提供进行成本效益分析的数据； (6)优化训练大纲； (7)衡量用于风险管理的绩效。 定期载客运行：是指航空承运人或者航空运营人以取酬 或者出租为目的，通过本人或者其代理人以广告或者其他形 式提前向公众公布的，包括起飞地点、起飞时间、到达地点 和到达时间在内的任何载客运行。 最大商载： (a)对于局方在技术规范中已规定最大无油重量的飞机， 以最大无油重量减去空机重量、飞机携带的适用设备的重量 和运行载重(包括最少机组成员、 食物饮料和与这些食物饮料 有关的供应品和设备的重量， 但不包括可用燃油和滑油)所计 算出的最大商载。 (b)对于其他飞机， 以最大审定起飞重量、 较小空机重量、 较少的机载设备重量和较小的运行必需重量(运行必需重量 为最少的燃油、 滑油重量和机组成员重量之和)所计算出的最 大商载。机组成员、燃油和滑油的重量按照下列方法计算： (1)规章要求的机组成员中每一成员的体重： (i)男性飞行机组成员按照82 千克； (ii)女性飞行机组成员按照64 千克； (iii)男性客舱乘务员按照82 千克； (iv)女性客舱乘务员按照59 千克； (v)客舱乘务员不区分性别时，体重平均按照64 千克。 (2)滑油按照157 千克或者型号合格审定中规定的重量。 (3)规章规定的一次飞行运行所需携带最少燃油量。 偏离：对于规章中明确允许偏离的条款，合格证持有人 在提出恰当理由和证明能够达到同等安全水平的情况下，经 局方批准，可以不遵守相应条款的规定或者遵守替代的规 定、条件或者限制。 豁免：对于规章中没有明确允许偏离的条款，合格证持 有人在提出恰当的理由、相应的安全措施并证明这些安全措 施能保证同等安全水平的情况下，经中国民航局批准，可以 不执行相应的规章条款，而执行中国民航局在作出此项批准 时所列的规定、条件或者限制。豁免是遵守规章的一种替代 做法，遵守所颁发的豁免及其条件和限制，就是遵守规章。 运行控制：是指合格证持有人为了航空器的安全和飞行 的正常和效率，对某次飞行的起始、持续和终止行使控制权 的过程。 湿租：是指按照租赁协议，承租人租赁飞机时携带出租 人机组成员的租赁。 干租：是指不提供机组成员的航空器租赁安排。 飞机互换：是指一种由单架飞机完成两个合格证持有人 航班的运行。一个合格证持有人可以通过协议的方式在某一 交换点，让另一个合格证持有人使用同一架飞机完成其航 班，使两个合格证持有人的航班形成组合。不同的合格证持 有人使用各自的机组实施各自的航班，并对各自航班的运行 控制负责。 登记国：是指航空器登记的国家。 地面服务：是指飞机到达和离开机场时除空中交通服务 以外的必要服务。 机组成员：是指飞行期间在飞机上执行任务的航空人 员，包括飞行机组成员和客舱乘务员。 机组必需成员：是指为完成按本规则运行符合最低配置 要求的机组成员。 飞行机组成员：是指飞行期间在飞机驾驶舱内执行任务 的驾驶员和飞行机械员。 机长：是指经合格证持有人指定，在飞行时间内对飞机 的运行和安全负最终责任的驾驶员。 客舱乘务员：是指出于对旅客安全的考虑，受合格证持 有人指派在客舱执行值勤任务的机组成员。 飞行签派员：是指在公共航空运输运行中，持有按《民 用航空飞行签派员执照和训练机构管理规则》(CCAR-65FS) 颁发的飞行签派员执照，由合格证持有人指定从事飞行运行 控制和监督，承担本规则第121.531 条(c)款中所列各项责任 的人员。 飞机组类：是指为方便机组成员和飞行签派员的训练管 理，根据飞机动力装置的区别对飞机划分的种类。在本规则 中，将飞机分为两个组类：组类I，以涡轮螺旋桨发动机为 动力的飞机；组类II，以涡轮喷气发动机为动力的飞机。为 飞行机组成员训练需要，根据飞机最大起飞重量，再将组类 II 飞机分为5,700 千克(含)至136,000 千克(含)和136,000 千 克(不含)以上两个种类。 先进航空器：是指配备有对于特定起飞、进近或者着陆 运行除基本航空器所需设备之外的附加设备的航空器。 基本航空器：是指配备有实施拟进行的起飞、进近或者 着陆运行所需的最低设备的航空器。 新雇员训练：是指合格证持有人新雇佣的人员，或者已 经雇佣但没有在机组成员或者飞行签派员工作岗位上工作 过的人员，在进入机组成员或者飞行签派员工作岗位之前需 要进行的训练。新雇员训练包括基础理论教育和针对特定机 型和岗位的训练。 初始训练：是指未曾在相同组类其他飞机的相同职位上 经审定合格并服务过的机组成员和飞行签派员需要进行的 改飞机型训练。 转机型训练：是指曾在相同组类不同型别飞机的相同职 位上经审定合格并服务过的机组成员和飞行签派员需要进 行的改飞机型训练。 升级训练：是指已在某一特定型别的飞机上经审定合格 并担任副驾驶的机组成员，在该型别飞机上担任机长之前需 要进行的训练。 定期复训：是指已取得资格的机组成员和飞行签派员， 为了保持其资格和技术熟练水平，在规定的期限内按照规定 的内容进行的训练。 重新获得资格训练：是指已在特定飞机型别和特定工作 岗位上经审定合格，但因某种原因失去资格的机组成员和飞 行签派员，为恢复这一资格所应当进行的训练。 差异训练：对于已在某一特定型别的飞机上经审定合格 并服务过的机组成员和飞行签派员，当局方认为其使用的同 型别飞机与原服务过的飞机在性能、设备或者操作程序等方 面存在差异，需要进行补充性训练时应当完成的训练。 日历月：是指按照世界协调时或者当地时间划分，从本 月1 日零点到下个月1 日零点之间的时间段。 飞行时间：是指飞机为准备起飞而借自身动力开始移动 时起，直到飞行结束停止移动为止的时间。 飞行经历时间：是指机组必需成员在其值勤岗位上执行 任务的飞行时间，即在座飞行时间。 延伸跨水运行： (a)在本规则中，对于符合下述条件的飞机，延伸跨水运 行是指离适用的应急着陆机场距离超过以巡航速度飞行120 分钟的距离或者740 公里(400 海里)(以较少者为准)的跨水航 路运行： (1)对于双发飞机， 在航路或者计划改航航路上的任一点 发生临界发动机不工作的情况下，仍能够安全飞往标准着陆 机场，并且在任何一点上不会低于最低飞行高度； (2)对于具有三台或者三台以上发动机的飞机， 在航路的 任一航段飞行时，如果为保持预期的总体安全水平，其航路 备降机场的位置和总飞行持续时间的关系致使必须要考虑 第二台发动机不工作的可能性，则该飞机必须能够在两台发 动机不工作时继续飞至航路备降机场并着陆。 (b)对于其他所有飞机， 延伸跨水运行是指离适用的应急 着陆机场距离超过以巡航速度飞行30 分钟的距离或者185 公里（100 海里） （以较少者为准）的跨水航路运行。 延程运行(EDTO)：是指在飞机计划运行的航路上至少存 在一点到任一延程运行(EDTO)可选备降机场的距离超过飞 机国际标准大气和静止空气条件中以经批准的一台发动机 不工作时的巡航速度飞行60 分钟对应的飞行距离(以两台涡 轮发动机为动力的飞机)或者超过180 分钟对应的飞行距离 (以多于两台涡轮发动机为动力的载客飞机)的运行。 最大改航时间：是指从航路上一点飞往一个航路备降场 的最大容许航程(以时间表示)。 极地运行：是指在北纬78 度以北或者南纬60 度以南区 域的运行。 运行飞行计划：是指合格证持有人根据飞机性能、其他 运行限制及所飞航路与有关机场的预期条件，为安全实施飞 行所制定的计划。 最低油量：是指飞行过程中应当报告空中交通管制员采 取应急措施的一个特定燃油油量最低值，该油量是在考虑到 规定的燃油油量指示系统误差后，最 ...
# -------------------------------------

# %%
paragraph_dict1 = {}
key_prefix1 = 'file1'

for i in range(len(extracted_paragraphs1)):
    key = f'{key_prefix1}_{i}_{extracted_paragraphs1[i][0]}'.strip()
    value = extracted_paragraphs1[i][1].strip()
    paragraph_dict1[key] = value

print(len(paragraph_dict1))
# Out:
# 295

# %%
paragraph_dict1
# Out:
# {'file1_0_1.': '飞行机组在开始滑行、进入滑行道和跑道、穿越滑行道和跑道以及起飞和着陆都必 须得到空中交通管制相应的许可。',
#  'file1_1_2.': '标准操作程序',
#  'file1_2_2.1.': '公司根据各机型手册，结合自身运行特点，为每个机型建立了标准操作程序；',
#  'file1_3_2.2.': '飞行机组应按照公司制定的标准操作程序操纵飞机；',
#  'file1_4_2.3.': '如需偏离标准操作程序， 飞行机组必须进行充分的沟通， 包括与其他相关机组 人员、 地面人员以及空中交通管制员等的沟通， 并评估偏离标准操作程序可能 造成的风险。',
#  'file1_5_3.': '检查单的使用',
#  'file1_6_3.1.': '公司为每一机型提供经批准的检查单， 并配备到公司运行的每架飞机上飞行机 组可以快速取用的位置；',
#  'file1_7_3.2.': '飞行机组在运行过程中，必须使用公司配备的经批准的检查单；',
#  'file1_8_3.3.': '除规定的记忆项目外，任何人不得背诵检查单；',
#  'file1_9_3.4.': '执行检查单必须使用标准用语；',
#  'file1_10_3.5.': '执行检查单过程中，如果某项目不能立即执行或PF 未应答时，检查单必须停 止在此项目位置，直到完成该项目或遗漏、错误得到纠正后，方可继续执行检 查单剩余项目；',
#  'file1_11_3.6.': 'PF 必须喊出检查单的全称，PM 应在检查单完成后宣布“XXX 检查单完成”；',
#  'file1_12_3.7.': '对于正常检查单的使用方法，具体详见机型SOP。',
#  'file1_13_4.': '交叉检查',
#  'file1_14_4.1.': '交叉检查是预防发生人为差错、及时发现系统故障的重要手段。在操纵飞机、 操作设备时，PF 和PM 应共同证实；特别是涉及到飞机关键设备（动力、液 压、电源、增压等）、飞机构型改变（襟/缝翼、起落架、减速板）、航路/航 向/高度/速度变化、计算机重置、航空器控制的交接、重要飞行数据的计算和 输入等时，飞机无论是正常、非正常、紧急情况下，均应互相证实后方可进行 操作；',
#  'file1_15_4.2.': '飞行过程中，飞行机组在操作发动机主控电门、推力手柄、灭火手柄、IDG 电 门、惯导以及所有加保护盖的重要的电门、开关、手柄、调节旋钮时，必须由 另一名飞行机组证实后方可进行操作。',
#  'file1_16_5.': '标准喊话',
#  'file1_17_5.1.': '飞行过程中， 飞行机组应严格按照机型SOP 使用标准喊话， 包括喊话的时机、 标准口令和标准回答；',
#  'file1_18_5.2.': '标准喊话应简单、清晰，并且必须按要求回答。',
#  'file1_19_6.': '机组简令',
#  'file1_20_6.1.': '起飞简令 PF 必须在发动机起动前完成起飞简令（非正常情况下可推迟到进跑道前完 成）；必要时，PM 应对简令的要点部分进行补充，起飞简令至少应包括以下 内容： 6.1.1. 机组分工； 6.1.2. 气象条件； 6.1.3. 飞机技术状况； 6.1.4. 预期的滑行路线（包括热点区域）； 6.1.5. 起飞性能； 6.1.6. 起飞跑道及道面状况、离场程序、所需导航设备、重要地形、过渡高 度和扇区安全高度等； 6.1.7. 低能见度起飞、起飞备降场的选择与备降预案； 6.1.8. 特殊情况处置(中断起飞、发动机失效、紧急返场)； 6.1.9. 相关通告； 6.1.10. 特殊运行程序； 6.1.11. 其他（如：对航路或机场的熟悉、危险品运输、外界环境、非标准降 噪程序等）。',
#  'file1_21_6.2.': '进近简令 PF 必须在开始下降前完成进近简令，如ATC 进场和/或进近指令更改或着陆 跑道更改，PF 应重新完成进近简令或完成补充简令；PM 负责证实、必要时 对简令进行补充。进近简令至少应包括以下内容： 6.2.1. 机组分工； 6.2.2. 气象条件 6.2.3. 飞机技术状况； 6.2.4. 剩余油量； 6.2.5. 着陆性能； 6.2.6. 使用跑道及道面状况、进场/进近程序、所需导航设备、重要地形、过 渡高度层和扇区安全高度等； 6.2.7. II/III 类进近； 6.2.8. 备降场的选择与备降预案； 6.2.9. 终止进近/复飞； 6.2.10. 落地后预期的滑行路线（包括热点区域）。 6.2.11. 相关通告； 6.2.12. 特殊运行程序； 6.2.13. 其他（如：对航路或机场的熟悉、危险品运输、外界环境等）。',
#  'file1_22_7.': '机组使用语言 公司机组在飞行运行中使用的工作语言为中文（普通话）或英语。使用场合包括：',
#  'file1_23_7.1.': '驾驶舱飞行机组成员之间的沟通；',
#  'file1_24_7.2.': '飞行机组和客舱机组、安保组、公司签派、地面勤务、ATC 之间的沟通。',
#  'file1_25_7.3.': '在机组培训和考试时，可以使用中文（普通话）或英语作为工作语言。',
#  'file1_26_7.4.': '有外籍飞行员作为机组必需成员的飞行中， 所有飞行机组成员之间， 以及驾驶 舱和客舱、驾驶舱和地面维修人员的沟通应使用英语。',
#  'file1_27_7.5.': '当外站机场地面勤务/维修人员不能够用英语与外籍飞行员沟通时，中籍飞行 员可以使用中文与地面维修人员通话； 在通话结束后， 中籍飞行员必须将通话 内容准确地翻译给外籍飞行员，在未获得证实之前，不得擅自操作，在操作过 程中应做到“眼到、口到、手到”。',
#  'file1_28_8.': '飞行关键阶段',
#  'file1_29_8.1.': '飞行关键阶段是指滑行、起飞、着陆和除巡航以外在3000 米（10000 英尺） 以下的飞行阶段。',
#  'file1_30_8.2.': '在飞行的关键阶段， 全体机组成员不得从事飞机安全运行所必需的工作之外的 任何其他工作，机组任何成员也不得承担这些工作。预定厨房供应品，确认旅 客的衔接航班，对旅客进行公司的广告宣传，介绍风景名胜的广播，填写与运 行无关的公司报告表、记录表等工作都不是飞机安全运行所必需的工作。',
#  'file1_31_8.3.': '在飞行关键阶段，飞行机组成员不得从事可能分散飞行机组其他成员工作精 力， 或可能干扰其他成员正确履行职责的活动， 机长也不得允许其从事这种活 动。这些活动包括进餐、在驾驶舱无关紧要的交谈、在驾驶舱和客舱乘务员之 间无关紧要的通话、阅读与正常飞行无关的刊物等。',
#  'file1_32_8.4.': '在飞行关键阶段， 客舱乘务员除完成保障机上人员安全的任务外， 其他时间应 当坐在其值勤位置并系好安全带和肩带。',
#  'file1_33_8.5.': '在飞行关键阶段， 除飞机故障、 天气原因、 机组成员不正常状态等特殊情况外， 不应调换处于操纵位置的飞行机组成员。',
#  'file1_34_8.6.': '在飞行关键阶段， 客舱乘务员应避免与驾驶舱联系或进入驾驶舱， 除非涉及飞 行安全。',
#  'file1_35_8.7.': '在飞行关键阶段，禁止将服务舱内任何与飞行无关的电源开关处于启动位置。',
#  'file1_36_8.8.': '在飞行关键阶段， 客舱乘务员应当尽可能地靠近飞机地板高度出口， 而且应当 在整个客舱内均匀分布，以便在应急撤离时最有效地疏散旅客。在滑行期间， 客舱乘务员除完成保障飞机和机上人员安全的任务外， 其余时间应当坐在其值 勤位置并系好安全带和肩带。',
#  'file1_37_9.': '燃油监控 飞行机组必须对燃油消耗进行持续监控，对剩余燃油进行科学管理，确保剩余燃油 不低于完成计划飞行所需的燃油要求。',
#  'file1_38_9.1.': '飞行机组应在EFB 中“D 计划”上记录飞行时间和已耗燃油/剩余燃油；通常 到达巡航高度后，进行第一次检查和记录，之后至少每30 分钟结合飞越的航 路点检查并记录飞行时间和已耗燃油/剩余燃油；',
#  'file1_39_9.2.': '至少每60 分钟，将已耗燃油和剩余燃油相加，与初始总油量进行比较，同时 检查剩余燃油的合理分布；',
#  'file1_40_9.3.': '一旦发现燃油消耗异常、 燃油指示故障等燃油不正常状态， 应立即进行分析并 视情按FCOM 以及QRH 处置， 以保证飞行在预计着陆机场着陆时的剩余油量 不低于最后储备燃油量， 努力避免飞机进入紧急油量状态， 同时立即将相关情 况报告飞行签派员。',
#  'file1_41_10.': '仪表进近要求',
#  'file1_42_10.1.': '起始进近高度 当按照仪表飞行规则飞往无线电导航设施做起始进近时， 飞行机组不得将飞机 下降到按该设施制定的仪表进近程序中规定的起始进近最低高度之下， 直至到 达该设施上空。',
#  'file1_43_10.2.': '满足下列条件后，方可起始进近： 10.2.1. 最新的气象条件满足所实施进近程序对应的机场运行最低标准、 进近程 序限制、机型风速限制以及道面条件限制要求； 10.2.2. 着陆性能及复飞性能满足要求； 10.2.3. 机组资质符合要求。',
#  'file1_44_10.3.': '继续进近的条件 10.3.1. 当报告的VIS/RVR 低于规定的最低标准时,不得飞越FAF/最后进近点 （FAP）或下降到机场标高上空300 米（1000 英尺）以下，两者取较 高值。 10.3.2. 飞越FAF/FAP 或下降到机场标高上空300 米（1000 英尺）以下后， 报告的RVR 或VIS 低于规定的最低标准，可以继续进近至DA/H 或者 MDA/H。 10.3.3. 如果进近程序没有规定FAF， 当报告的RVR 或VIS 低于规定的最低标 准时，不得开始最后进近。 注：最后进近航段从仪表进近程序规定的最后进近定位点或者设施处开始。当 一个包含程序转弯的程序没有规定最后进近定位点时， 最后进近航段在完成程 序转弯的那一点开始，并且在该点上，飞机在该程序规定距离之内在最后进近 航迹上向机场飞行。',
#  'file1_45_10.4.': '当到达MDA/H 或DA/H，在进近复飞点之前的任何时间内，除非满足下列要 求，否则飞机不得继续进近到低MDA/H 或DA/H 并着陆： 10.4.1. 飞机持续处在正常位置， 从该位置能够使用正常机动动作以正常下降率 降落在计划着陆跑道， 并且以此下降率可以使飞机在该跑道接地区内接 地； 10.4.2. 飞行能见度不低于所用的标准仪表进近程序规定的能见度； 10.4.3. 飞行机组能清楚地看到并保持所需的目视参考； 10.4.4. 当使用具有目视下降点的非精密直接进近程序时， 飞机已到达该目视下 降点，且在该点使用正常程序或者下降率能降落到跑道上。',
#  'file1_46_10.5.': '仪表进近着陆所需目视参考 10.5.1. 除II 类和III 类进近外，飞行机组至少能清楚地看到和辨认着陆跑道的 下列目视参考之一： 10.5.1.1. 进近灯光系统，如果飞行机组仅使用进近灯光作为参考，应 当同时清楚地看到和辨认红色终端横排灯 注或红色侧排灯，否 则不得下降到接地区标高之上30 米（100 英尺）以下； 10.5.1.2. 跑道入口； 10.5.1.3. 跑道入口标志； 10.5.1.4. 跑道入口灯； 10.5.1.5. 跑道端标识灯； 10.5.1.6. 目视进近下滑道指示灯； 10.5.1.7. 接地区或接地区标志； 10.5.1.8. 接地区灯； 10.5.1.9. 跑道或跑道标志； 10.5.1.10. 跑道灯。 注： 红色终端横排灯为ALSF-1 进近灯光系统特有灯光， 国内机场无相 应灯光系统。 10.5.2. II 类进近着陆时，除非能保持包括进近灯、接地带灯、跑道中线灯、跑 道边灯或者这些灯的组合中至少3 个连续灯的目视参考，机组不得继 续进近至决断高（DH）之下。 10.5.3. 对于IIIA 类运行， 机组不得继续进近至DH 之下， 除非获得并能够保持 包括进近灯、接地带灯、跑道中线灯或这些灯的组合中至少3 个连续 灯的目视参考。 10.5.4. 对于IIIB 类运行， 机组不得进近至DH 之下， 除非获得并能够保持包括 1 个中线灯在内的目视参考。',
#  'file1_47_11.': '目视起落航线',
#  'file1_48_11.1.': '目视起落航线（TRAFFIC PATTERN）：是一种航空器在机场滑行、起飞或着 陆规定的流程，由五个边组成。',
#  'file1_49_11.2.': '在实施目视起落航线时， 机长对与其他航空器和地面障碍物之间的安全间隔负 直接责任。因此，飞行机组在执行目视起落时，必须建立合理分工，在保证正 常仪表扫视和数据监控的同时，保持对障碍物、机场、跑道以及前机的目视观 察。',
#  'file1_50_11.3.': '实施目视起落航线时， 气象条件应满足本手册HO-0905-1 章节第10 条的要求。',
#  'file1_51_11.4.': '实施目视起落航线前，机组需得到管制员的批准。',
#  'file1_52_11.5.': '除在机场细则中有特别说明或ATC 另有指令外，目视起落航线的方向为左起 落。飞行机组应当采取左转弯加入起落航线并避开前方航空器的尾流。',
#  'file1_53_11.6.': '在国内运输机场空域内， 除经塔台同意外， 飞机在进入机场实施目视起落航线 时，不得低于机场标高以上450 米。',
#  'file1_54_11.7.': '飞机加入到目视起落航线前应减速到机型要求的起落航线速度。',
#  'file1_55_11.8.': '机长在确定从飞机所处位置能进行稳定进近之前， 不得下降低于着陆跑道接地 区标高以上500 英尺。',
#  'file1_56_11.9.': '在管制机场实施目视起落航线时，若气象条件低于本手册HO-0905-1 章节第 10 条的要求或者失去目视参考，应立即实施复飞，复飞后应首先保持在目视 起落航线上，并向管制员报告，根据管制员的许可实施后续飞行。在任何时候 脱离起落航线，都必须考虑对航线中其他飞机的影响。',
#  'file1_57_12.': '客舱安全规定',
#  'file1_58_12.1.': '为确保客舱机组自身安全，在本章节8 条的基础上，公司规定：自滑行至起飞 后20 分钟或到达巡航高度，以及落地前30 分钟至飞机发动机关车（安全带 灯灭），以上阶段客舱乘务员除完成保障飞机和机上人员安全的任务外，其他 时间应必须在规定的席位上就坐并保持安全带、 肩带系紧， 除非发生危及飞行 安全或涉及旅客的紧急情况。',
#  'file1_59_12.2.': '起飞后20 分钟且飞机处于平稳状态时， 如 “系好安全带” 信号灯未关闭， （主 任）乘务长应主动联系机组，询问是否可以开始客舱服务。当完成客舱服务程 序后，（主任）乘务长应向飞行机组报告。',
#  'file1_60_13.': '禁止吸烟的规定',
#  'file1_61_13.1.': '任何人在任何阶段（包括运行阶段及非运行阶段）禁止在航空器内吸烟（包括 电子烟），飞行机组应在整个飞行阶段保持“禁止吸烟”信号灯的接通。',
#  'file1_62_13.2.': '机上任何人不得触动、 损害或者破坏飞机厕所内安装的烟雾探测器， 机组成员 如发现此类行为应予以立即制止。 飞行运行操纵限制',
#  'file1_63_1.': '操纵装置的控制',
#  'file1_64_1.1.': '机长不得允许不符合下列规定之一的人员在飞行期间控制操纵装置， 任何不符 合下列规定之一的人员也不得在飞行期间控制操纵装置： 1.1.1. 公司聘任的合格的飞行员； 1.1.2. 得到机长允许， 有资格在该飞机上飞行的正在执行飞行运行检查任务的 局方监察员或者局方委任代表； 1.1.3. 得到机长允许、 有资格在该飞机上飞行并且获得了局方和公司批准的另 一公司的飞行员。',
#  'file1_65_1.2.': '可以在左座操纵飞机的人员： 1.2.1. 飞行教员或机长； 1.2.2. 巡航机长； 1.2.3. 建立左座运行经历的副驾驶。',
#  'file1_66_1.3.': '可以在右座操纵飞机的人员： 1.3.1. 飞行教员； 1.3.2. 已被公司聘用为机长但非本次航班的责任机长（飞行关键阶段除外） ； 1.3.3. 巡航机长（飞行关键阶段除外） ； 1.3.4. 副驾驶（操纵具体要求见《飞行技术管理手册》 ） 。',
#  'file1_67_1.4.': '下列情况下，由机长操纵飞机： 1.4.1. 起飞重量达到本机型最大起飞重量的百分之九十（含）以上时； 1.4.2. 实施目视盘旋进近时； 1.4.3. 实施低能见度运行时； 1.4.4. 右座副驾驶在所飞机型飞行经历时间少于100 小时且左座机长不具备 飞行检查员/飞行教员资格，下列情况下由左座机长操纵飞机： 1.4.4.1. 在公司规定的特殊机场； 1.4.4.2. 机场的最新气象报告中有效能见度值等于或者小于1200 米 (3/4 英里)，或者跑道视程(RVR)等于或者小于1200 米(4000 英尺)； 1.4.4.3. 所用跑道有水、雪、雪浆等严重影响飞机性能的情况； 1.4.4.4. 所用跑道刹车效应报告低于“好”； 1.4.4.5. 所用跑道侧风分量超过7 米/秒； 1.4.4.6. 天气报告机场附近有风切变； 1.4.4.7. 机长认为需要谨慎行使机长权力的任何其它情况。',
#  'file1_68_1.5.': '操纵权交换 1.5.1. 飞机操纵权交接由机长或PF 发布口头指令，标准用语为“我（你）操 纵”，接受操纵权的飞行机组应按照机型程序接管飞机的操纵，并在接 管后回答“我操纵”； 1.5.2. 只有确认接受操纵权的飞行机组已经接管飞机后， 交出操纵权的飞行机 组方可交出飞机操纵权。',
#  'file1_69_2.': '低空下降率的限制',
#  'file1_70_2.1.': '高于机场标高750 米（2500 英尺）至300 米（1000 英尺） ，下降率不得大于 1500 英尺/分钟；',
#  'file1_71_2.2.': '高于机场标高300 米（1000 英尺）以下，下降率不得持续大于1000 英尺/分 钟。',
#  'file1_72_3.': '空中、地面的避让规定',
#  'file1_73_3.1.': '任何人不得驾驶飞机靠近另一架飞机达到产生碰撞危险的程度。',
#  'file1_74_3.2.': '任何人不得驾驶航空器进行编队飞行。',
#  'file1_75_3.3.': '当气象条件许可时， 无论是按仪表飞行规则还是按目视飞行规则飞行， 飞行机 组必须注意观察， 以便发现并避开其他航空器。 当另一架航空器享有航行优先 权时， 飞行机组必须为该航空器让出航路， 并不得以危及安全的间隔在其上方、 下方或者前方通过。',
#  'file1_76_3.4.': '在空中，飞行机组应按下列规定进行避让： 3.4.1. 遇险的航空器享有优先于所有其他航空器的航行优先权。 3.4.2. 在同一高度对头相遇时，应各自向右避让，相互间保持500 米以上的 间隔； 3.4.3. 在同一高度交叉相遇时， 从驾驶舱左侧看到另一架航空器时， 应当下降 高度，从驾驶舱右侧看到另一架航空器时，应当上升高度； 3.4.4. 飞行员应主动避让飞艇、滑翔机、气球和拖曳物体的航空器； 3.4.5. 从一架航空器的后方，在与该航空器对称面小于70 度夹角的航线上向 其接近或者超越该航空器时， 被超越的航空器具有航行优先权。 而超越 航空器不论是在上升、 下降或者平飞时， 均应当向右改变航向给对方让 出航路。 此后二者相对位置的改变并不解除超越航空器的责任， 直至完 全飞越对方并有足够间隔时为止。 3.4.6. 当两架或者两架以上航空器为着陆向同一机场进近， 高度较高的航空器 应当为高度较低的航空器让路， 但后者不能切入另一正在进入着陆最后 阶段的航空器的前方或者超越该航空器。 已经进入最后进近或者正在着 陆的航空器优先于飞行中或者在地面运行的航空器航行。 但是， 不得强 制另一架已经着陆并将脱离跑道的航空器为其让路。 3.4.7. 当得知另一架航空器紧急着陆时，应当为其让出航路。',
#  'file1_77_3.5.': '在地面滑行（牵引）时，应按下列规定进行避让： 3.5.1. 飞机应按指定的线路滑行（牵引） ，飞机不得对头滑行； 3.5.2. 交叉相遇时，从驾驶舱左侧看到其它航空器的飞机，应停止滑行。 3.5.3. 在地面滑行的飞机， 应避让正在或即将起飞的其它飞机以及正在着陆或 已处于着陆最后阶段的其它飞机。',
#  'file1_78_4.': '避免可控飞行撞地（CFIT） 飞行机组应严格遵守下列规定，避免可控飞行撞地：',
#  'file1_79_4.1.': '正确判断飞机位置以及飞机相对于地形或障碍物的安全高度裕度；',
#  'file1_80_4.2.': '严格执行标准操作程序，正确使用自动飞行系统，合理利用机组资源；',
#  'file1_81_4.3.': '遵守最低安全高度的规定；',
#  'file1_82_4.4.': '正确理解空中交通管制指令，对不明确或有疑问的指令应予以证实；',
#  'file1_83_4.5.': '对于非精密进近，只要公布的仪表进近程序适用，应使用连续下降最后进近 （CDFA）技术；',
#  'file1_84_4.6.': '及时、正确地响应TAWS/GPWS 的警告。',
#  'file1_85_5.': '按仪表飞行规则的起飞和着陆',
#  'file1_86_5.1.': '除经局方批准外， 在需要仪表进近着陆时， 飞行机组必须使用为该机场制定的 标准仪表离场和进近程序。',
#  'file1_87_5.2.': '当飞机在未公布的航路上飞行或者正在被雷达引导， 必须保持空中交通管制最 后指定的高度，直至飞机到达公布的航路或者进入仪表进近程序。此后，除非 空中交通管制另有通知，飞行机组应当按照航路内或者程序中公布的高度下 降。 航空器一旦达到最后进近阶段或者定位点， 飞行机组可以根据局方对该设 施批准的程序完成其仪表进近。',
#  'file1_88_5.3.': '当飞机被雷达引导到最后进近航道或者最后进近定位点， 或者从等待点定时进 近，或者程序规定“禁止程序转弯(NOPT)”时，飞行机组不得进行程序转弯。 如果在这些情况下需要进行程序转弯，必须得到空中交通管制许可。',
#  'file1_89_5.4.': '仪表着陆系统的基本地面设施应当包括航向台、 下滑台、 外指点标、 中指点标。 标准仪表进近程序中批准使用的测距仪（DME） 、甚高频全向信标（VOR） 、 无方向性信标（NDB）定位点可以用来代替外指点标。',
#  'file1_90_6.': '飞行航道 按仪表飞行规则飞行时，飞行机组应当遵守下列规定：',
#  'file1_91_6.1.': '在公布的航路上，沿该航路的中心线飞行。',
#  'file1_92_6.2.': '除为避开其他航空器或者为改变飞行高度需要偏离航线的机动飞行外， 在任何 其他航线上，飞行机组应沿该航线的导航设施或者定位点之间的连线飞行。 （空白） 设备的使用',
#  'file1_93_1.': '机载防撞系统',
#  'file1_94_1.1.': '自飞机进入起飞跑道开始， 至着陆后完全脱离跑道为止， 飞行机组应接通机载 防撞系统（TCAS/ACAS）；除机场或飞行程序有特殊要求外，应使用TA/RA 模式，并选择适当的显示距离。',
#  'file1_95_1.2.': '在空中和机场活动区运行时， 飞行机组应始终保持警惕， 尽早发现可能的冲突， 并对TCAS/ACAS 信息做出及时、正确的反应。反应迟缓或未按照 TCAS/ACAS 的 RA 指令调整飞行轨迹都将会严重危及飞行安全。',
#  'file1_96_1.3.': 'TCAS/ACAS 的使用： 1.3.1. 交通咨询信息（TA） 1.3.1.1. 不得在未确认冲突飞机的情况下， 仅依据TA 信息而进行机动 飞行。爬升和下降过程中，小范围调整垂直速度不属于机动 飞行； 1.3.1.2. TA 信息出现后， PF 负责监控飞机， 做好执行RA 指令的准备， 循环一次“系好安全带”信号灯（通知客舱飞机可能出现大 幅度姿态变化） ；同时PM 负责参照TA 指示，目视搜索冲突 飞机，并使用时钟参考基准报出冲突飞机的相对方位和相对 高度； 1.3.1.3. TA 信息出现后，飞行机组如认为必要，可向空中交通管制通 报有关情况，并提出请求。 1.3.2. 决断咨询信息（RA） 1.3.2.1. 服从RA 指令的引导是确保安全间隔的强制手段， 除非飞行机 组确认服从该引导将影响飞行安全，否则必须及时、正确地 按照RA 指令操纵飞机； 1.3.2.2. RA 是一个指令信息，不能直接控制飞机，飞行机组必须按其 指令人工操纵飞机； 1.3.2.3. 出现RA 指令后，PF 负责指令操纵飞机或监控自动飞行系统 操纵飞机跟随RA 按照RA 指令，PM 负责确认PF 的操作符 合RA 指令的引导； 1.3.2.4. 按照RA 指令实施避让机动后，应尽快报告空中交通管制。 1.3.3. 冲突解除后，PF 应操纵飞机，以正常的垂直速度和/或转弯速率迅速、 准确地返回许可的航路和剖面后，并及时通知客舱冲突解除；PM 应向 空中交通管制报告偏离许可高度和/或航线情况以及归航情况，并请求 进一步指令。',
#  'file1_97_1.4.': 'ATC 指令与TA 信息/RA 指令不一致时的处置原则： 1.4.1. TA 信息的主要目的是提醒飞行机组存在可能会触发RA 指令的冲突飞 机，并帮助飞行机组目视搜索冲突飞机。未目视确认冲突飞机时，不得 依据TA 信息实施机动飞行； 1.4.2. 当ATC 指令与RA 指令不一致时，必须按照RA 指令实施机动飞行， 然后报告空中交通管制； 1.4.3. 一旦飞机按照RA 指令偏离了当前的ATC 许可，空中交通管制保持受 影响航空器之间间隔的责任就被中止， 飞行机组负责该机与其它航空器 之间的间隔，直到飞行机组报告飞机恢复到原ATC 许可状态或空中交 通管制发布新的许可状态。',
#  'file1_98_1.5.': '使用TCAS/ ACAS 的注意事项： 1.5.1. TCAS 无法发现未安装应答机或应答机失效的航空器； 1.5.2. 对于未安装或未使用高度报告功能的航空器，TCAS/ ACAS 只能发出 TA 信息而不能发出RA 指令； 1.5.3. RA 指令不考虑飞机所处环境的地形， 某些情况下不考虑飞机性能限制， 飞行机组必须对地形和飞机状态保持警觉； 1.5.4. 当与失速警告、风切变警告或近地警告相冲突时，RA 指令将被抑制， 仅出现TA 信息。此时，应优先处置失速、风切变或近地警告。',
#  'file1_99_1.6.': 'TCAS/ ACAS 事件报告： 1.6.1. 发生RA 指令事件或其它重要TCAS/ ACAS 事件后，飞行机组应填写 “机长报告书”，并提交至公司安全质量监督管理部。 1.6.2. 内容应包括事件发生的时间、地点、当时的飞行状态、TCAS/ ACAS 的指示或语音告警、 飞行机组采取的措施、 空中交通管制员的指令以及 TCAS/ ACAS 不正常工作情况等。',
#  'file1_100_1.7.': 'TCAS/ ACAS 的标准陆空通话用语详见SOP。',
#  'file1_101_2.': '地形提示和警告系统（TAWS/GPWS）',
#  'file1_102_2.1.': '公司所有飞机均安装了地形提示和警告系统（TAWS/GPWS），除机型手册 特殊规定外，飞行机组不得擅自抑制TAWS/GPWS。',
#  'file1_103_2.2.': '对TAWS/GPWS 警告及时、正确的响应是避免可控飞行撞地的最后措施，飞 行机组必须正确理解TAWS/GPWS 发出的提示和警告信息，并按照机型手册 采取及时、准确的处置。',
#  'file1_104_3.': '自动驾驶仪和自动推力的使用',
#  'file1_105_3.1.': '除经局方批准的特殊运行（如RNP AR）与进近外，A320 系列机型起飞后高 于机场标高100 英尺以下、 B787 机型起飞后高于机场标高200 英尺以下不得 使用自动驾驶仪（如机型限制数据高于此值，执行机型标准） 。',
#  'file1_106_3.2.': '对于进近，断开自动驾驶仪的最晚时机见各机型SOP。',
#  'file1_107_3.3.': '公司建议尽可能多地使用自动飞行设备， 以减少工作强度， 并持续保持对自动 飞行装置工作状况的监控。',
#  'file1_108_3.4.': '下列情况下应断开自动驾驶仪人工操纵： 3.4.1. 自动驾驶无法保持所需的飞行航径； 3.4.2. 对自动驾驶的工作不满意时； 3.4.3. 各机型手册特定的程序规定。',
#  'file1_109_3.5.': '正常情况下自动推力始终保持接通，并持续保持对自动油门工作情况的监控。',
#  'file1_110_4.': '飞行机组使用氧气的规定',
#  'file1_111_4.1.': '当飞机座舱高度高于3000 米（10000 英尺）时，每一位值勤的飞行机组成员 必须使用氧气，驾驶舱内的氧气面罩必须在随手可取的位置；',
#  'file1_112_4.2.': '当飞机发生释压时，飞行机组成员应首先戴上氧气面罩，再执行其他操作。在 释压状态下，正常人的失能时间可能为2 分钟（FL250） 、1 分钟（FL300） 、 15 秒（FL400） ；',
#  'file1_113_4.3.': '飞行前， 飞行机组必须对氧气设备进行检查， 并确认氧气压力满足驾驶舱所有 人员用氧要求；',
#  'file1_114_4.4.': '当要求某一飞行机组成员用氧时， 他应连续用氧， 但因正常任务所需而取下氧 气面罩或其他氧气分配器的情况除外；',
#  'file1_115_4.5.': '应向处于待命状态的或在完成此次飞行前需在驾驶舱内值勤的其他飞行机组 成员供氧， 用氧量应与在驾驶舱内工作的飞行机组成员相同。 如果飞行机组成 员不处于待命状态， 并且在剩下的飞行中将不在驾驶舱内值勤， 就补充供氧而 言，可将其视为一名旅客。',
#  'file1_116_4.6.': '驾驶舱固定氧气系统为应急设备， 非必要状况， 任何人不得使用此固定氧气设备。',
#  'file1_117_5.': '“系好安全带”信号灯的使用',
#  'file1_118_5.1.': '飞机在地面的任何移动， 以及每次起飞、 着陆和机长认为必要的其他任何时间， 应当接通“系好安全带”信号灯。',
#  'file1_119_5.2.': '飞行关键阶段，飞行机组应保持“系好安全带”信号灯开启。',
#  'file1_120_5.3.': '起飞后20 分钟或飞机到达巡航高度且无颠簸时，飞行机组应及时将“系好安 全带”信号灯关闭，并根据实际天气情况开启/关闭“系好安全带”信号灯。',
#  'file1_121_5.4.': '飞机到达下降顶点时，飞行机组应打开“系好安全带”信号灯并保持开启直至 发动机关车。',
#  'file1_122_6.': '机上休息设施的使用',
#  'file1_123_6.1.': '除《最低设备清单》有特殊要求外，飞行机组必需成员在飞行关键阶段应在值 勤位置就坐，不得使用机上休息设施。',
#  'file1_124_6.2.': '飞行前准备过程中， 客舱乘务员应对所有机上休息设施及相关的安全设备进行 检查，确认设施完好；如未配备客舱乘务员，此项检查由机长或机长指定的人 员进行。',
#  'file1_125_6.3.': '机组人员使用机上休息设施进行休息时，应系好安全带。',
#  'file1_126_6.4.': 'B787 机型配备1 级休息设施，机组应按机型FCOM 的要求使用机上休息室。',
#  'file1_127_6.5.': 'A320 系列机型公务舱座椅均可后仰20 度（从垂直位） ，符合特定机型3 级休 息设施要求。',
#  'file1_128_6.6.': '公司优先使用公务舱最后一排C 座作为A320 系列机型3 级休息设施， 实施3 名飞行员扩编机组运行时， 此座位仅可用于飞行机组成员机上休息， 任何人不 得将此座位挪作他用，客舱乘务员应防止该座位被旅客侵占。',
#  'file1_129_6.7.': '在使用A320 系列机型3 级休息设施的飞行人员应遵循如下要求： 6.7.1. 必须按本手册HO-0906-8 第2.7 款的要求在3 级休息设施上进行休息； 6.7.2. 在休息期间，不得影响或打扰其他旅客； 6.7.3. 达到机长确定的轮换休息时间时，应及时返回驾驶舱接替轮换； 6.7.4. 如发生特殊情况， 机组应通知乘务长， 由其告知休息人员停止休息返回 驾驶舱。',
#  'file1_130_6.8.': 'A320 系列机型3 级休息设施应按以下流程要求进行座位锁定： 6.8.1. 飞行部应在每次换季前5 个工作日将下一航季实施A320 系列机型扩编 机组运行的具体航班信息提报运网部及地服部； 如在一个航季内发生计 划性新增/减少A320 系列机型扩编机组运行的情况，应至少提前3 个 日历日将需求提报商务部及地服部。 6.8.2. 运网部、 商务部及地服部应根据飞行部提报的航班计划分别在销售系统 及离港系统中锁定相应航班的公务舱最后一排C 座作为A320 系列机 型3 级休息设施。 6.8.3. 对于当日或次日的临时性变更，增加/减少A320 系列机型扩编机组运 行的航班，飞行部应立即与AOC 确认，由AOC 负责座位的临时锁定， 乘务长须将座位信息告知飞行机组。',
#  'file1_131_6.9.': 'A320 系列机型3 级休息设施失效时处理程序： 6.9.1. 如客舱乘务员或维修人员在关舱前发现指定的公务舱座椅无法满足 A320 系列机型3 级休息设施要求，或因临时情况导致指定的公务舱座 椅被旅客占用，AOC 应根据“从左往右、自后向前”的原则选用公务 舱另一符合要求的空余座位作为机上3 级休息设施使用。 6.9.2. 如发生指定的公务舱座椅失效且公务舱无其他空余座位的情况时， AOC 应协调相关席位根据实际情况确定是否执行座椅修复、公务舱旅 客降舱、减客或按非扩编机组运行，以确保公务舱具备一个符合A320 系列机型3 级休息设施要求的空余座位，并通知当班乘务长。 6.9.3. 座位发生变更后，乘务长应立即将更改后的座位信息通知责任机长。 6.9.4. 责任机长应在关舱前向乘务长确认公务舱具备一个符合A320 系列机 型3 级休息设施要求的空余座位，否则不得按3 名飞行员扩编机组运 行。',
#  'file1_132_7.': '客舱门的打开与关闭',
#  'file1_133_7.1.': '飞机客舱门的打开与关闭， 须由完成相应机型训练并合格的飞行人员、 客舱乘 务员或机务维修人员实施操纵，其他运行人员不得自行打开与关闭客舱门。',
#  'file1_134_7.2.': '如需从外部打开客舱门，应由完成相关训练的客舱乘务员或机务维修人员实 施。 驾驶舱的管理',
#  'file1_135_1.': '驾驶舱值勤要求',
#  'file1_136_1.1.': '在驾驶舱值勤的每个飞行机组必需成员， 在飞行过程中应当坐在指定的值勤位 置并系好安全带； 在飞行关键阶段， 应当坐在指定的值勤位置并系好安全带和 肩带， 但对于驾驶员座位上以外的飞行机组成员， 在履行其正常职责需要时可 以松开肩带。',
#  'file1_137_1.2.': '飞行过程中， 如需要换座时候， 应遵守“始终有人在座监控飞机的状态”的原则， 且除紧急和特殊情况外，换座应在巡航阶段实施。',
#  'file1_138_1.3.': '在下列情形下,飞行机组必需成员可以离开指定的值勤位置： 1.3.1. 为了完成与飞机运行有关的任务需要该机组成员离开时； 1.3.2. 机组成员的离开与生理需要有关时； 1.3.3. 达到机长确定的轮换休息时间，并按照下述规定接替工作： 1.3.3.1. 对于机长,在航路巡航飞行期间,可以由巡航机长接替; 1.3.3.2. 对于副驾驶,可以由有资格在航路飞行期间担任副驾驶的飞行 员接替。但是接替的飞行员不必满足本手册关于近期经历的 限制。',
#  'file1_139_2.': '进入驾驶舱的规定',
#  'file1_140_2.1.': '对于商业运行， 自旅客登机开始至所有旅客离机的时间段内， 除机组人员和经 批准人员外，任何人不得进入驾驶舱；',
#  'file1_141_2.2.': '下列人员可以进入驾驶舱，但机长有权为了安全而要求其离开驾驶舱： 2.2.1. 机组成员； 2.2.2. 正在执行任务的局方监察员、局方委任代表或公司飞行检查员； 2.2.3. 得到机长允许并且其进入驾驶舱对于安全运行是必需或者有益的人员 包括： 2.2.3.1. 局方批准进行空中交通管制程序观察的空中交通管制员； 2.2.3.2. 经运行副总裁批准进行航线实习的公司飞行签派员、航行情 报员、航空气象员、飞机性能工程人员； 2.2.3.3. 经机长请求并核实身份的航空器维修人员； 2.2.3.4. 应急情况下实施紧急医疗救助的医护人员； 2.2.3.5. 其他因空中应急、救助、维修、飞行技术指导等需进入驾驶 舱的人员。 2.2.4. 经机长同意，并获得公司批准的其他人员。',
#  'file1_142_2.3.': '获得公司批准的其他人员进入驾驶舱，应当持有公司总裁签发的批准书原件， 批准书应当列明姓名、证件类型、证件号码、日期、航班号、事由、批准人签 字等要素，并加盖上海吉祥航空股份有限公司公章。',
#  'file1_143_2.4.': '被准许进入驾驶舱的非机组人员， 应当在客舱内有供该人员使用的座位， 但按 照3.1 在驾驶舱有供其使用的座位的人员除外。',
#  'file1_144_2.5.': '对于2.2.2、 2.2.3、 2.2.4 中规定的人员进入驾驶舱的， 应当采取下列安保措施： 2.5.1. 航空安全员应当核对证件确保人证相符，同时开启执勤记录仪全程记 录人员进出情况； 2.5.2. 如驾驶舱或客舱环境不能满足安全条件时，人员应暂缓进入驾驶舱； 2.5.3. 每次进入驾驶舱的人数不得超过驾驶舱内空余的观察员座位数，最大 不超过两人； 2.5.4. 人员在驾驶舱内停留期间，在驾驶舱内的机组人员不得少于两人且确 保驾驶舱门锁闭，驾驶舱门口应当至少有一名航空安全员或客舱乘务 员值守； 2.5.5. 驾驶舱门开启期间，机组应当做好驾驶舱的保护。',
#  'file1_145_2.6.': '局方监察员、局方委任代表或公司飞行检查员执行监察/检查任务时，出示相 应的身份证明证件后，机长必须允许该监察员/局方委任代表/公司飞行检查员 不受阻碍地进入驾驶舱。',
#  'file1_146_2.7.': '机长允许除2.2 中规定以外的人员进入驾驶舱时，其他机组成员应予以劝阻。',
#  'file1_147_2.8.': '在地面阶段， 客舱乘务教员在获得机长许可的情况下， 可带领客舱乘务学员进 入驾驶舱开展航线带飞教学任务。教学期间，客舱乘务教员/学员必须注意周 围环境防止误碰，除座椅外不得触动驾驶舱内任何手柄、旋钮、开关、电门或 其他设备，机长或机长指定的一名飞行人员应全程监控。',
#  'file1_148_3.': '驾驶舱观察员座位的使用',
#  'file1_149_3.1.': '允许使用驾驶舱观察员座位的人员范围，包括： 3.1.1. 机组成员； 3.1.2. 正在对飞行操作进行检查或者观察的局方监察员或者经授权的局方委 任代表（可优先选择任意观察员座椅） ； 3.1.3. 局方批准进行空中交通管制程序观察的空中交通管制员； 3.1.4. 公司空勤人员以及随机放行的维修工程人员； 3.1.5. 进行航线实习的公司飞行签派员、公司专职模拟机教员； 3.1.6. 其他航空公司雇用的持有执照航空人员，该人员得到公司总裁的批准； 3.1.7. 本公司雇员，其职责与飞行运作的实施或者计划、或者空中监视飞机 设备或者操作程序直接有关，此人进入驾驶舱对于完成其任务是必需 的，并且已得到公司总裁的书面批准； 3.1.8. 该飞机或者其部件的制造厂家技术代表，其职责与空中监视飞机设备 或者操作程序直接有关，进入驾驶舱对于完成其职责是必需的，并已 得到公司总裁的书面批准。',
#  'file1_150_3.2.': '公司在驾驶舱内备有一个座位， 供局方实施航路监察时使用， 使用向前的观察 员座位或者其他座位由局方来指定，A320 系列机型一般优先使用第三观察员 座椅，B787 机型一般优先使用第一观察员座椅。',
#  'file1_151_4.': '驾驶舱门的关闭和锁定',
#  'file1_152_4.1.': '对于商业运行， 自旅客登机开始至全部旅客完成下机的时间段内， 应关闭并锁 定驾驶舱门；',
#  'file1_153_4.2.': '在执行任务的机组成员或本章节2.2 及3.1 中经批准的人员有必要进入或离开 驾驶舱时， 在打开驾驶舱门之前， 驾驶舱人员应使用观察孔或电子监控装置识 别请求进入驾驶舱的人员并检查驾驶舱门周围状况；',
#  'file1_154_4.3.': '非正常状态着陆前，可以考虑将驾驶舱门打开。',
#  'file1_155_5.': '驾驶舱内最低机组成员人数',
#  'file1_156_5.1.': '在航班飞行过程中，驾驶舱内应保持至少有两名机组成员。',
#  'file1_157_5.2.': '只有由于工作或生理原因，方允许一名飞行机组必需成员离开指定的值勤位 置，但应在最短的时间内回到岗位上。',
#  'file1_158_5.3.': '留在驾驶舱的飞行员必须保持对飞机的监控，不得从事与飞行无关的活动。',
#  'file1_159_5.4.': '当机长离开驾驶舱时， 机长应授权副驾驶负责航空器的控制并处理任何特殊状 态下的飞行，直至机长返回后由机长行使其职权。',
#  'file1_160_5.5.': '当仅有两名飞行员在驾驶舱内值勤时， 其中一名在值勤岗位的飞行员由于工作 或生理原因需要离开驾驶舱时， 应指定不在值勤岗位的飞行机组成员或由机长 通知乘务长指定2 号客舱乘务员进入驾驶舱，直至该名飞行员返回。',
#  'file1_161_5.6.': '进入驾驶舱的客舱乘务员应在观察员座椅就坐并系好安全带； 同时应熟悉 《驾 驶舱-非必需机组成员简介》 。',
#  'file1_162_5.7.': '进入驾驶舱的客舱乘务员不得参与对飞机的操作。',
#  'file1_163_6.': '驾驶舱物品的固定 飞行机组应当确保每项设备、每件装在飞机驾驶舱的机组行李（含大件物品） ，能够 承受相应于该飞机型号合格审定应急着陆状态的载荷系数下的载荷，并保证其摆放 的稳定性，不至于因移动而造成危害。 （空白） 飞行前准备和飞行后讲评',
#  'file1_164_1.': '概述',
#  'file1_165_1.1.': '飞行前准备包括预先准备和直接准备两部分， 预先准备可以是集体准备或网上 准备。',
#  'file1_166_1.2.': '飞行前准备和飞行后讲评包括所有机组成员。',
#  'file1_167_1.3.': '飞行部、客舱部、航空安保部、江苏分公司应对所属空勤人员的预先准备以及 直接准备的完成情况和质量进行监控。',
#  'file1_168_1.4.': '未按本章节规定完成飞行前准备的机组成员不得参加航班运行。',
#  'file1_169_2.': '预先准备',
#  'file1_170_2.1.': '除本章节2.4 款的要求以外， 机组成员必须在航班起飞前48 小时至起飞前12 小时之间在吉祥航空飞行/客舱准备网完成预先准备， 准备时间不少于30 分钟。',
#  'file1_171_2.2.': '预先准备的内容至少包括：领受任务、明确任务性质、起飞时间和其他相关要 求。',
#  'file1_172_2.3.': '对于飞行机组成员在预先准备过程中应研究起飞、 降落和备降机场、 航线或者 飞行区域有关资料， 初步了解飞机状况， 阅读公司的相关通告， 了解天气形势， 确认EFB 终端设备中航图及手册资料的有效性以及检查云执照经历信息填写 与确认情况等。',
#  'file1_173_2.4.': '重要飞行任务如新开航线、 专机、 包机或其它特殊航班的预先准备根据需要应 进行集体准备。',
#  'file1_174_3.': '直接准备',
#  'file1_175_3.1.': '飞行机组成员必须在进场时间15 分钟前到达指定地点签到并进行直接准备， 进场时间由所在运行单位根据运行实际进行确定；',
#  'file1_176_3.2.': '到达签到地点后，全体机组成员必须首先接受航前酒精测试及航前体检；',
#  'file1_177_3.3.': '机长负责领取并核对当日及过夜（如适用）飞行任务书，确认个人信息准确， 确保所持有飞行任务书中各内容、要素齐全有效；',
#  'file1_178_3.4.': '对于过夜或回程更换飞行机组的情况， （主任）乘务长负责打印并携带回程任 务书， 组织客舱机组与安保组成员核对个人信息， 并根据准备网核对回程飞行 机组信息；对于客舱机组、安保组单独进场的情况，应自行打印并确认个人信 息准确，任务书各要素齐全。',
#  'file1_179_3.5.': '机长组织召开飞行机组准备会，了解机组成员的技术状况，明确机组分工，检 查并确认各类证照/文件以及飞行装具齐全有效、着装/仪表符合公司规定，检 查确认个人EFB 终端设备中软件及数据库版本最新有效。同时，机长应对每 位机组必需成员云执照中的相关信息进行检查确认；',
#  'file1_180_3.6.': '（主任）乘务长组织召开客舱机组准备会，检查并确认客舱机组各类证照、文 件及装具齐全有效、仪容仪表符合公司规定、明确号位分工、并讲解航班任务 特点及要求等；',
#  'file1_181_3.7.': '航空安全员应检查确认各类证照/资料齐全有效，着装/仪表符合公司规定，并 领取执勤装具， 确认装具齐全有效； 对于有特殊安保要求的航线还应领取爆炸 物探测仪，由安保组组长检查探测仪及配件齐全有效；',
#  'file1_182_3.8.': '执行国际（地区）航班时，全体机组成员还应检查核对各自护照、港澳台通行 证等证件携带情况与有效性；',
#  'file1_183_3.9.': '飞行机组应领取/下载飞行资料，包括飞行计划、气象资料、航行通告、签派 单等，检查并确认齐全有效；',
#  'file1_184_3.10.': '飞行机组成员应阅读气象简报，了解起飞机场、航路、目的地机场及备降场天 气实况及预报，知晓可能发生空中颠簸的区域和强度，拟订安全飞行方案；',
#  'file1_185_3.11.': '飞行机组成员应阅读航行通告 （重点确认航路是否有变化， 导航设备是否提供 服务，跑道和进近导航是否可使用等相关信息） ；',
#  'file1_186_3.12.': '机长应确认飞机适航状态，对于保留故障根据MEL/CDL 制定相关预案；',
#  'file1_187_3.13.': '机长应确认飞行签派员放行讲解信息；',
#  'file1_188_3.14.': '机长应检查运行飞行计划，根据飞机状况、天气报告等，确定飞机燃油信息， 由机长与飞行签派员共同在签派单上签字（手工或电子形式） ；',
#  'file1_189_3.15.': '为使飞行机组和客舱机组形成一个团队概念，加强沟通和配合，统一认识，牢 记职责，保证运行安全和服务质量。机长应召集所有飞行机组、客舱乘务员及 航空安全员进行协同准备，至少包括以下内容： 3.15.1. 机组成员介绍， （主任）乘务长和航空安全员向机长报告准备完成情 况，并报告各组员的装具、证照、文件及资料携带核查情况。 3.15.2. 机长通报因公加入机组人员、 非因公加入机组人员以及该航班是否为 扩编机组运行。 3.15.3. 机组交叉检查《飞行任务书》以及《出入境飞机及员工登记表》 、 《出 入境航空器工作人员携带物品清单》 （如适用） ， 确认机组成员和加入 机组人员的信息准确有效。 3.15.4. 机长通报预计滑行时间、飞行时间、到达巡航高度时间、可用服务时 间、有无延误情况。 3.15.5. 机长通报航班运行天气状况， 是否存在恶劣天气影响， 告知客舱机组 拟执行的除防冰程序、 甩冰程序以及已获取的颠簸区域、 强度和持续 时间，协同制定相关预案。 3.15.6. 机长通报飞机状况以及客舱设备故障保留情况，协同制定应对方案。 3.15.7. 机长明确正常情况与非正常情况下机组成员间的联络要求。 3.15.8. 机长按需明确发生紧急情况时驾驶舱联系客舱的术语及指令。 3.15.9. 如发生机组失能情况下， 机上指挥权的接替次序： 责任机长→巡航机 长→副驾驶→ （主任） 乘务长→区域乘务长→客舱乘务员→航空安全 员。 （按等级排列，高者优先） 。 3.15.10. 如发生PED 以及锂电池起火情况，明确沟通关键环节，要求先处置 再报告。 3.15.11. （主任）乘务长通报要客、担架旅客以及机上用氧旅客信息，以及本 航班服务程序所需时间，按需协同保障预案。 3.15.12. 航空安全员通报航线派遣标准、押解犯罪嫌疑人（罪犯）及遣返旅客 情况、当前空防形势和重点关注事项，飞机安保检查的各项要求，复 习驾驶舱门密码。 3.15.13. 机长根据空防形势组织协同突发事件/非法干扰/扰乱航空器秩序等行 为的处置预案，明确机组分工，确定联络暗号和处置程序。 3.15.14. 需各岗位协同配合的其他事宜。',
#  'file1_190_3.16.': '对于仅客舱机组与安保组进场的情况，在进场前， （主任）乘务长负责本章节 3.15.1 以及3.15.2 条的检查确认。',
#  'file1_191_3.17.': '外站过夜航班，机组成员应在酒店配备的机组准备室中完成飞行前直接准备； 如酒店无相应场所，飞行机组、客舱乘务员、航空安全员可在机组车上或者机 场候机厅（通过机场安检之前）完成飞行前直接准备。',
#  'file1_192_3.18.': '外站运行或过站更换机组成员时， 机组成员应最晚在登机后完成机组协同准备 工作。',
#  'file1_193_3.19.': '如果航班延误超过24 小时，应重新完成飞行直接准备流程。',
#  'file1_194_3.20.': '连续飞行时， 机组不需要进行签到。 除本章节3.9 至3.14 以及3.15.3、3.15.4 条必须执行外，可以根据实际情况、按照机型程序省略部分准备项目；除此之 外，应完成完整的飞行前直接准备。',
#  'file1_195_4.': '机组到场时间',
#  'file1_196_4.1.': '对于始发航班或过站时间1 小时及以上的非始发航班， 全体机组成员应在计划 /预计起飞时刻前至少1 小时到达现场，对于过站时间不足1 小时的非始发航 班，全体机组成员应不晚于前段航班开舱门时刻到达停机位。',
#  'file1_197_5.': '机组飞行后讲评',
#  'file1_198_5.1.': '飞行后，飞行机组应进行与飞行程序、技术、安全相关的常规讲评；客舱机组 应对客舱安全及服务方面的工作进行总结。',
#  'file1_199_5.2.': '飞行中出现非正常情况时，应进行专项讲评；必要时，飞行机组、客舱机组、 安保组及AOC 相关人员应进行集体讲评；',
#  'file1_200_5.3.': '对于飞行中出现的问题或事件，机长、客舱（主任）乘务长、航空安全员应按 照规定履行相应的报告职责。 （空白） 地面准备',
#  'file1_201_1.': '应急设备检查 公司运行的所有飞行任务（包括商业运行、或本场训练、调机等非商业运行）必须 按本条要求在飞行前进行应急设备检查。',
#  'file1_202_1.1.': '飞行机组登机后应完成驾驶舱应急设备的飞行前检查，确认应急设备数量和 位置，并确保其完好有效、易获取且可以使用。',
#  'file1_203_1.2.': '客舱机组登机后应完成客舱应急设备的飞行前检查，确认应急设备数量和位 置，并确保其完好有效、易获取且可以使用。',
#  'file1_204_1.3.': '当飞行机组值勤期内首次进入飞机驾驶舱，或飞行机组发生更换，或全部机 组离开航空器并再次进入时，必须按本章节1.1 的要求执行应急设备检查。',
#  'file1_205_1.4.': '当客舱机组值勤期内首次进入客舱，或客舱机组、飞行机组发生更换，或全 部机组离开航空器并再次进入时，必须按本章节1.2 的要求执行应急设备检 查。',
#  'file1_206_1.5.': '如无客舱机组，由责任机长指定飞行机组成员按本章节1.2 的要求对客舱应 急设备进行检查。',
#  'file1_207_2.': '机上安保检查',
#  'file1_208_2.1.': '旅客登机前，责任机长应组织机组成员根据各自分工对驾驶舱及客舱各部位 进行安保检查。',
#  'file1_209_2.2.': '飞行机组应根据机型SOP 要求进行驾驶舱安保检查以及驾驶舱门的密码测 试。',
#  'file1_210_2.3.': '客舱机组与航空安全员应按“由前往后，由上到下，由左到右”的原则，对 责任区域进行严格检查，同时相互协调配合，确保检查范围无死角，同一位 置不重复检查，具体责任区域如下： 2.3.1. 航空安全员责任区域包括： 2.3.1.1. 行李架； 2.3.1.2. 旅客座椅，包括座椅下方及周围、座椅背面书报存放处、联 排座椅之间缝隙处、座椅靠垫和坐垫、座椅下方救生衣存放 处； 2.3.1.3. 客舱过道、地板、舱顶及四周壁板； 2.3.1.4. 厕所，包括储物盒、纸巾存放处、垃圾桶、洗手池下方区 域、婴儿护理板； 2.3.1.5. 飞行机组休息室与客舱机组休息室，包括座椅及铺位周围。 2.3.2. 客舱机组责任区域包括： 2.3.2.1. 客舱乘务员座椅，包括座椅下方及周围； 2.3.2.2. 客舱内衣帽间； 2.3.2.3. 储物盒/柜； 2.3.2.4. 应急设备存放处； 2.3.2.5. 厨房（包括工作台、烤箱、储物柜、餐车、备份箱等区 域） 。',
#  'file1_211_2.4.': '航空安全员与（主任）乘务长确认安保检查完成后，由航空安全员向责任机 长报告客舱安保检查完成。',
#  'file1_212_2.5.': '如检查中发现可疑物品时，任何人不得触碰，应立即通知航空安全员进行核 查，确系疑似武器、爆炸物等危险违禁物品时，航空安全员应将相关情况告 知责任机长并提出报警需求，由责任机长联系机场指挥中心申请机场公安进 行现场处置，并将相关情况报告公司AOC。',
#  'file1_213_3.': '燃油加注',
#  'file1_214_3.1.': '责任机长应根据飞行计划与飞行签派员共同决定加油量。如需更改加油量， 责任机长应通知飞行签派员修改燃油计划，并根据本手册HO-0908-13 章节 要求执行最后一分钟修正或重新制作载重平衡舱单。',
#  'file1_215_3.2.': '加、放（抽）燃油时，飞行机组应执行以下安全措施： 3.2.1. 所有发动机关车； 3.2.2. 机上雷达设备停止使用； 3.2.3. HF 高频发射机停止使用； 3.2.4. 不接通或断开地面电源； 3.2.5. 禁止操作燃油系统的任何跳开关； 3.2.6. “禁止吸烟”信号灯接通。',
#  'file1_216_3.3.': '飞行机组成员应对加注燃油量进行确认、核实燃油型号、确定燃油冰点温 度，并对燃油加注过程进行持续监控。如需实施旅客登机、下机或在飞机上 时的加油程序，机长应配合燃油加注工作人员在载客加油通知单上完成签字 确认。',
#  'file1_217_3.4.': '对于B787 机型，一般情况下由燃油加注工作人员负责加油面板的操作。如 遇工作人员无机型操作资质，则由机务人员协助其操作。对于特殊情况下加 油现场无符合资质的工作人员与机务人员时，则由责任机长或责任机长指定 的飞行机组成员进行面板操作。',
#  'file1_218_3.5.': '一般加油程序 3.5.1. 开始加油时，飞行机组成员应通知（主任）乘务长“开始加油程序” 。 3.5.2. （主任）乘务长应确认至少打开一个门连接登机桥或客梯车，同时通 知机上乘员飞机正在加油，不要使用厕所、禁止吸烟、不要使用手机 等电子设备；客舱机组应确保客舱内至登机桥或客梯车的过道和通道 畅通，以供应急撤离。 3.5.3. 加注期间，飞行机组成员应持续监控，并与加油设备操纵人员、客舱 机组、机务维修人员保持联系，视情发布相关指令。 3.5.4. 加注完成后，飞行机组成员应通知（主任）乘务长“加油结束” ，并检 查实际总油量与要求的是否一致，确认加油口、加油面板盖好，检查 加油口附近机翼无损坏，按实际加油数据填写飞机加油单，加油单上 所列各项内容均应填写完整，并保持字迹清晰。收到飞行机组加油结 束的通知后， （主任）乘务长应通知机上乘员加油完毕，厕所、手机等 电子设备可以正常使用，禁止吸烟。',
#  'file1_219_3.6.': '有旅客登机、下机或在飞机上时的补充程序 3.6.1. 如燃油加注过程中飞机上载有旅客（包括旅客正在登机、离机或已登 机完毕） ，在执行本章节3.5 条程序的基础上，加注期间还应补充执行 以下要求： 3.6.1.1. 开始加注时，飞行机组成员关断“系好安全带”信号灯以提 示乘客保持安全带解锁； 3.6.1.2. 客舱乘务员应广播通知旅客飞机正在加油，请旅客尽快入座 （登机时）/尽快下机（下机时）/在原位就坐（在飞机上 时） 、解开安全带、不要使用厕所、禁止吸烟、不要使用手 机等电子设备； 3.6.1.3. 同时客舱机组应均匀分布在每对应急出口处，引导旅客尽快 入座（登机时）/尽快下机（下机时）/在原位就坐（在飞机 上时） ，避免造成客舱内过道和通道拥堵； 3.6.1.4. 责任机长应指定一名飞行机组成员监控地面加油情况，并保 持与驾驶舱、加油设备操纵人员以及机务维修人员的联系。 如发生溢油、火情等意外情况时，监控加油的飞行人员应立 即通知驾驶舱以及机务维修人员进行处置。 3.6.1.5. 加油结束后，飞行机组应打开“系好安全带”信号灯。 3.6.2. 燃油加注期间，地面保障人员应控制旅客登机速度，防止廊桥或客梯 车上的旅客积压，避免在紧急情况下影响应急撤离和疏散的速度。 3.6.3. 燃油加注期间，地面保障人员应确保飞机安全门下方被指定用于快速 离机或紧急疏散的地面区域保持畅通。',
#  'file1_220_3.7.': '如燃油加注过程中出现不正常情况，飞行机组应立即发布指令停止加油；如 发生火灾或燃油外溢，机组应立即联系在场机务维修人员以及机场当局，并 告知相关情况。',
#  'file1_221_4.': '驾驶舱准备',
#  'file1_222_4.1.': '飞行机组应根据各机型SOP 要求进行驾驶舱准备工作。',
#  'file1_223_5.': '客舱准备',
#  'file1_224_5.1.': '客舱乘务员应根据《客舱乘务员手册》及公司服务政策要求开展机上准备工 作。',
#  'file1_225_5.2.': '准备过程中，客舱乘务员应根据机供品的标准配备数量进行检查核对，确保 摆放的机供品不得超过存放区域最大载荷标准。',
#  'file1_226_6.': '旅客登机',
#  'file1_227_6.1.': '仅在（主任）乘务长确认客舱准备完成以及航空安全员确认安保检查完成 后，责任机长方可允许旅客登机。',
#  'file1_228_6.2.': '地面保障人员在获得责任机长的旅客登机指令后，方可组织旅客办理登机手 续。',
#  'file1_229_6.3.': '旅客登机时，客舱乘务员应均匀分布在客舱每对出口附近，以便在紧急情况 下最有效地帮助旅客撤离。',
#  'file1_230_6.4.': '登机过程中，客舱乘务员应对旅客行李的尺寸、数量进行确认，对于超规行 李应予以拦截，并通知地面保障人员进行处理。',
#  'file1_231_6.5.': '旅客开始登机至舱门关闭期间，除正常报告程序和影响安全运行的事项外， 飞行机组与客舱机组应尽可能保持双向静默，避免互相干扰。',
#  'file1_232_6.6.': '当发生旅客登机后要求终止行程，航空安全员应与客舱机组确认其登机后轨 迹并向责任机长进行报告。如能确定该旅客登机后只在自己座位上逗留，没 有去过客舱的其他地方时，则可执行局部安保检查，否则应重新进行全部安 保检查。',
#  'file1_233_6.7.': '当发生以下情况时，责任机长必须指令进行全部安保检查： 6.7.1. 登机后公安、安检怀疑旅客存在漏检时； 6.7.2. 登机后机组人员对旅客的安检质量产生质疑； 6.7.3. 未经安全检查的人员和物品进入航空器； 6.7.4. 其他任何可能危及安全的情况。',
#  'file1_234_6.8.': '如确定执行局部安保检查/全部安保检查程序，飞行机组应将相关情况报告公 司AOC。 舱门的关闭与打开',
#  'file1_235_1.': '舱门的关闭',
#  'file1_236_1.1.': '当飞机舱门处于打开状态时，此门通常被认为是主应急出口， （主任）乘务长 应确保廊桥/客梯车与飞机保持连接状态。',
#  'file1_237_1.2.': '关闭舱门前，机长应确认： 1.2.1. 飞机已完成加油工作； 1.2.2. 机务人员完成放行工作，并在FLB 上签署放行； 1.2.3. 飞行必备文件齐全有效； 1.2.4. 驾驶舱内无与该次航班无关的人员。',
#  'file1_238_1.3.': '（主任）乘务长应根据《客舱乘务员手册》完成舱门关闭前各项工作后，请示 机长关门许可。得到许可后方可操纵关闭舱门。',
#  'file1_239_1.4.': '所有舱门待命好后，机长应确认所有舱门关闭/滑梯待命情况；对不正常的舱 门状态，机长必须要求（主任）乘务长将舱门调置到正常状态。所有舱门待命 完成之前，飞机不得移动。',
#  'file1_240_1.5.': '舱门关闭后因其他原因需重新开启舱门时， （主任）乘务长应及时将情况向机 长报告，经机长同意后，客舱机组应按《客舱乘务员手册》要求进行滑梯和舱 门开启的操作。',
#  'file1_241_1.6.': '对于任何不载运旅客的飞行， 且未配备客舱乘务员时， 由机长负责滑梯待命和 关闭舱门操纵。机长在执行待命操纵后，副驾驶须进行交叉检查，确认滑梯已 完成待命。',
#  'file1_242_2.': '舱门的打开',
#  'file1_243_2.1.': '客舱灯光调节完毕后， （主任）乘务长立即组织客舱机组按《客舱乘务员手册》 要求执行舱门解除滑梯待命操作程序。',
#  'file1_244_2.2.': '完成舱门滑梯解除待命操作程序后， （主任）乘务长应立即与机长确认滑梯已 解除待命， 机长应在驾驶舱检查确认所有舱门的滑梯状态已解除待命。 如因特 殊情况需延迟开启舱门时，机长应将相关信息立即告知（主任）乘务长。',
#  'file1_245_2.3.': '地面保障人员在确认各地面保障设施到位后，应向客舱机组发出可以开门信 号。 地面保障人员可采取敲击客舱门等方式提供开门信号， 且舱门打开过程中 不得站在客舱门口。',
#  'file1_246_2.4.': '客舱机组在获得地面保障人员开门信号且确认滑梯已解除待命后， 方可打开舱 门。',
#  'file1_247_2.5.': '对于任何不载运旅客的飞行， 且未配备客舱乘务员时， 由机长负责解除滑梯待 命和开启舱门。机长在解除待命后，副驾驶须进行交叉检查，确认滑梯已解除 待命。',
#  'file1_248_2.6.': '如舱门因结冰无法正常打开时， 机组应联系机务进行处理， 不得自行强行开启。 （空白） 离机',
#  'file1_249_1.': '旅客全部下机前',
#  'file1_250_1.1.': '在旅客完全离开飞机前， 机组不可以关闭音频按钮， 仍需监控塔台或地面频率。',
#  'file1_251_1.2.': '在旅客完全离开飞机前， 机组不可以离开飞机， 如果因工作或生理的原因需要 离开，机长应根据实际情况至少安排一名航空安全员负责飞机的安全。',
#  'file1_252_1.3.': '在旅客完全离开飞机前， 应至少打开一个与地板同高度的舱门， 并且舱门外应 有廊桥或客梯。保持飞机内、外所有撤离通道畅通。',
#  'file1_253_2.': '记录与报告',
#  'file1_254_2.1.': '飞行结束后，飞行机组应如实填写云执照飞行经历记录以及《飞行记录本》 。',
#  'file1_255_2.2.': '机长应将飞行中发生的故障情况如实记入《技术记录本》 （TLB） ； （主任）乘 务长应将客舱内各类设施设备的故障、 缺陷或缺失等情况如实记入 《客舱记录 本》 （CLB） 。',
#  'file1_256_3.': '中途过站',
#  'file1_257_3.1.': '如地面电源车、辅助动力装置或发动机在运转中，但缺少专业人员负责时，飞 行机组成员不得离机。',
#  'file1_258_3.2.': '任何机组成员需要离机，必须经机长同意并及时返回。',
#  'file1_259_3.3.': '驾驶舱应始终保持至少有一名飞行机组成员，并完成下列工作： 3.3.1. 完成驾驶舱的各项准备工作； 3.3.2. 监控APU、地面电源、气源车等工作情况； 3.3.3. 禁止未经批准的人员进入驾驶舱； 3.3.4. 了解航路及目的地机场和备降机场天气状况以及航行通告等信息， 办理 放行手续； 3.3.5. 遇有不正常情况或飞机故障，应及时与机务联系，尽快处置。',
#  'file1_260_3.4.': '中途过站经停时， 除非机场要求不得下机， 客舱机组应通知所有旅客在航空器 停靠好以后， 带好所有手提行李和个人物品离开航空器， 并配合航空安全员进 行安保检查工作，防止不明外来、遗留物品留在客舱。',
#  'file1_261_3.5.': '在中途过站停留时， 如果乘坐该机的旅客仍停留在飞机上， 且保留在飞机上的 客舱乘务员数量少于该机型客舱乘务员最低配备数，则应遵守下列要求： 3.5.1. 保证飞机发动机关车并且至少保持打开一个地板高度出口， 供旅客下飞 机。 3.5.2. 至少保留客舱乘务员数量要求： 机型 至少保留客舱乘务员数 A320CEO/A320NEO 2 A321CEO 4 A321NEO ACF 3 B787-9 5 3.5.3. 可以用当班航空安全员代替要求的客舱乘务员。',
#  'file1_262_3.6.': '保留在飞机上的客舱乘务员或航空安全员应当分布在客舱每对舱门附近， 以便 在紧急情况下最有效地帮助旅客撤离。',
#  'file1_263_4.': '目的地站',
#  'file1_264_4.1.': '机组在完成飞行任务到达目的站后， 应完成离机检查单和离机安全检查的全部 内容。',
#  'file1_265_4.2.': '旅客全部下机后， 机组应按要求完成航后安保检查工作， 确保机上无外来物或 旅客遗留物品。',
#  'file1_266_4.3.': '机组应清点文件并收好所有资料和用具（包括婴儿安全带、加长安全带等物 品） 。',
#  'file1_267_4.4.': '如条件允许，当班机组可向接班机组成员介绍飞机的适航情况或飞行情况。',
#  'file1_268_4.5.': '机组人员离开航空器时应保持清洁和整齐的环境， 以便利于下一班机组成员使 用。',
#  'file1_269_4.6.': '如果飞机停站过夜，必须关好机舱门、风档和出口门。出于安全因素，如果需 要过夜，机组的飞行包（箱）应拿下飞机。',
#  'file1_270_4.7.': '飞机只能向地面维修人员交接，如果地面维修人员未到，机组不得离开飞机。',
#  'file1_271_4.8.': '仅在完成上述工作后，机组方可离开飞机。 平行跑道同时仪表运行 为了满足日益增长的空中交通流量需要，越来越多的机场建设平行跑道，而平行跑道 同时仪表运行对空中交通管制部门、飞机及机载设备和飞行机组提出了更高的要求。 为规范公司平行跑道同时仪表运行，降低运行风险，建立本章节。',
#  'file1_272_1.': '平行跑道同时仪表运行的模式',
#  'file1_273_1.1.': '平行跑道同时仪表运行按照跑道用于进近和离场的使用方式分为独立平行仪 表进近、相关平行仪表进近、独立平行离场、隔离平行运行等四种模式： 1.1.1. 独立平行仪表进近（Independent parallel instrument approaches） 是指在相邻的平行跑道仪表着陆系统上进近的飞机之间不需要配备规 定的雷达间隔时， 在平行跑道上同时进行的仪表着陆系统进近的运行模 式； 1.1.2. 相关平行仪表进近（Dependent parallel instrument approaches） 是指在相邻的平行跑道仪表着陆系统上进近的飞机之间需要配备规定 的雷达间隔时，在平行跑道上同时进行的仪表着陆系统进近的运行模 式； 1.1.3. 独立平行离场（Independent instrument departures） 是指离场飞机在平行跑道上沿相同方向同时起飞的运行模式。 当两条平 行跑道间距小于760 米，飞机可能受尾流影响时，平行跑道离场飞机 的放行间隔应当按照为一条跑道规定的放行间隔执行； 1.1.4. 隔离平行运行（Segregated operations on parallel runways） 是指在平行跑道上同时进行的运行， 其中一条跑道只用于离场， 另一条 跑道只用于进近。',
#  'file1_274_1.2.': '平行跑道同时仪表运行按照上述的四种运行模式的不同组合， 也可以分为半混 合运行和混合运行： 1.2.1. 半混合运行是指下列情形之一： 1.2.1.1. 一条跑道只用于进近，另一条跑道按照独立平行仪表进近模 式或者相关平行仪表进近模式用于进近，或者按照隔离平行 运行模式用于离场； 1.2.1.2. 一条跑道只用于离场，另一条跑道按照隔离平行运行模式用 于进近，或者按照独立平行离场模式用于离场。 1.2.2. 混合运行是指两条平行跑道同时用于进近和离场。 理论研究表明， 使用 独立平行仪表进近模式可以使机场进港流量最大化， 其次是相关平行仪 表进近模式。',
#  'file1_275_2.': '非侵入区和正常运行区',
#  'file1_276_2.1.': '采用独立平行仪表进近模式运行时， 空中交通管制机构在两条平行跑道中心线 延长线之间划设一个非侵入区（No Transgression Zone，简称NTZ） ，并为每 条跑道划设一个正常运行区（Normal Operation Zone，简称NOZ） 。',
#  'file1_277_2.2.': '非侵入区是指两条跑道中心线延长线之间、 宽度不小于610 米的特定空域， 在 实施平行跑道同时进近过程中， 当一架飞机进入该空域时， 管制员应当指挥另 一架受影响的正常飞行的飞机避让。',
#  'file1_278_2.3.': '正常运行区是指仪表着陆系统航向道中心线向两侧延伸至指定范围的空域， 正 常运行区的长度从跑道入口开始， 沿进近反方向延伸至飞机加入跑道中心线延 长线的一点为止。',
#  'file1_279_3.': '精密跑道监控',
#  'file1_280_3.1.': '为了在间距较小的平行跑道上， 实施独立平行仪表进近模式运行， 机场应安装 精密跑道监控（Precision Runway Monitors，简称PRM）系统。该系统可以 使空中交通管制机构同时监控平行且相邻的仪表进近。管制员使用PRM 系统 监控平行仪表进近飞机的飞行轨迹， 并检查飞机是否闯入非侵入区。 如果飞机 闯入非侵入区，管制员将指令另一架平行仪表进近的飞机中断进近。',
#  'file1_281_3.2.': '只有满足下列条件的前提下，方可实施精密跑道监控（PRM）进近： 3.2.1. 2 部VHF 工作； 3.2.2. 飞行机组完成地面理论和/或模拟机训练； 3.2.3. 进近前， 飞行机组必须复习PRM 进近航图和程序， 特别是“Attention All Users”（全体用户注意）页； 3.2.4. 飞行机组必须熟知特定的中断程序和中断术语术语并准备好执行中断 程序。',
#  'file1_282_3.3.': '若不满足上述条件，无法实施精密跑道监控（PRM）进近，机组应在距目的 地机场至少100 海里时， 通知相应的空中交通管制单位以便获得使用其它进近 程序的许可。',
#  'file1_283_3.4.': '为了避免通信频率卡阻，每一条跑道均有两个频率，包括主用频率和PRM 频 率。在PRM 程序要求的时间段内（详见“Attention All Users”页） ，飞行机组应 同时收听主用频率 （VHF1） 和 PRM 频率 （VHF2） ， 但仅使用主用频率 （VHF1） 发送。 为了确保能够同时守听两个频率， 两部甚高频电台的音量应调到相同水 平。',
#  'file1_284_3.5.': '机组收到中断指令后， 必须立即断开自动驾驶仪人工操作， 以便在最短的时间 内建立避让轨迹。通常情况下，中断指令包括一个转弯指令和一个爬升/下降 指令。',
#  'file1_285_4.': '平行跑道同时仪表运行的一般规定',
#  'file1_286_4.1.': '实施平行跑道同时仪表运行前， 飞行机组应完成平行跑道同时仪表运行的理论 学习， 熟悉各种不同类型的运行模式， 掌握公司有关平行跑道同时仪表运行的 规定；',
#  'file1_287_4.2.': '实施平行跑道同时仪表运行前， 飞行机组应确认飞机的机载电子设备满足使用 仪表着陆系统进行进近的要求， 并且至少一部自动驾驶仪或一部飞行指引仪工 作正常；',
#  'file1_288_4.3.': '若飞机应答机失效， 飞行机组应提前通告空中交通管制员以便获得较大的横向 和/或纵向间隔；',
#  'file1_289_4.4.': '当间距小于760 米的平行跑道实施独立平行离场时， 应按照一条跑道的尾流间 隔标准与前机（由同一跑道或相邻跑道起飞的飞机）保持规定的间隔；',
#  'file1_290_4.5.': '当目的地机场实施平行跑道同时仪表进近时， 飞行机组应在首次与进近管制员 和塔台管制员联系时确认使用跑道， 并交叉检查飞行管理计算机输入的飞行计 划、仪表着陆系统的频率/航道/识别码等准确无误；',
#  'file1_291_4.6.': '实施平行跑道同时仪表运行时， 飞行机组应严格按照程序飞行、 遵守程序限制， 并立即执行管制员发布的指令；',
#  'file1_292_4.7.': '当目的地机场实施独立平行仪表进近以及相关平行仪表进近时， 飞行机组应使 用飞行指引仪以精确地将飞机保持在ILS 航向道上， 禁止进行无指引ILS 进近；',
#  'file1_293_4.8.': '禁止在实施平行跑道同时仪表进近时， 使用VOR、 VOR/DME、 NDB、 NDB/DME 等程序进行进近；',
#  'file1_294_4.9.': '当实施平行跑道同时仪表进近的目的地机场出现风切变、颠簸、下降气流、大 侧风以及雷暴等恶劣天气或由于机载设备故障影响飞机保持仪表着陆系统航 向道能力时，飞行机组应及时通告管制员，要求增加运行间隔，并参考目视和 /或TCAS 信息与相邻跑道上进近的飞机保持安全间隔。 （空白）'}

# %%
paragraph_dict2 = {}
key_prefix2 = 'file2'

for i in range(len(extracted_paragraphs2)):
    key = f'{key_prefix2}_{i}_{extracted_paragraphs2[i][0]}'.strip()
    value = extracted_paragraphs2[i][1].strip()
    paragraph_dict2[key] = value

print(len(paragraph_dict2))
# Out:
# 301

# %%
paragraph_dict2
# Out:
# {'file2_0_第 121.1 条': '目的和依据 为了对大型飞机公共航空运输承运人进行运行合格审 定和持续监督检查，保证其达到并保持规定的运行安全水 平，根据《中华人民共和国民用航空法》和《国务院对确需 保留的行政审批项目设定行政许可的决定》 ，制定本规则。',
#  'file2_1_第 121.3 条': '适用范围 (a)本规则适用于在中华人民共和国境内依法设立的航 空运营人实施的下列公共航空运输运行： (1)使用最大起飞重量超过5,700 千克的多发涡轮驱动飞 机实施的定期载客运输飞行； (2)使用旅客座位数超过30 座或者最大商载超过3,400 千克的多发涡轮驱动飞机实施的不定期载客运输飞行； (3)使用最大商载超过3,400 千克的多发涡轮驱动飞机实 施的全货物运输飞行。 (b)对于适用于本条(a)款规定的航空运营人， 在本规则中 称之为大型飞机公共航空运输承运人。 (c)对于应当按照本规则审定合格的大型飞机公共航空 运输承运人，中国民用航空局(以下简称中国民航局)和民用 航空地区管理局（以下简称民航地区管理局）按照审定情况 在其运行合格证及其运行规范中批准其实施下列一项或者 多项运行种类的运行： (1)国内定期载客运行，是指符合本条(a)款第(1)项规定， 在中华人民共和国境内两点之间的运行，或者一个国内地点 与另一个由局方专门指定、视为国内地点的国外地点之间的 运行； (2)国际定期载客运行，是指符合本条(a)款第(1)项规定， 在一个国内地点和一个国外地点之间，两个国外地点之间， 或者一个国内地点与另一个由局方专门指定、视为国外地点 的国内地点之间的运行； (3)补充运行，是指符合本条(a)款第(2)项、第(3)项规定 的运行。 (d)大型飞机公共航空运输承运人应当遵守其他有关的 涉及民航管理的规章，但在本规则对相应要求进行了增补或 者提出了更高标准的情况下，应当按照本规则的要求执行。 (e)大型飞机公共航空运输承运人在运行中所使用的人 员和大型飞机公共航空运输承运人所载运的人员应当遵守 本规则中的适用要求。 (f)在本规则中，对于载运邮件的飞行，视为载运货物飞 行；对于同时载运旅客和货物的飞行，视为载运旅客飞行， 但应当同时满足本规则中有关货物运输条款的要求。',
#  'file2_2_第 121.5 条': '定义 (a)在本规则中， 局方是指中国民航局和民航地区管理局 及其派出机构。 (b)除本规则其他章中另有规定外， 本规则中用语的含义 在本规则附件A《定义》中规定。',
#  'file2_3_第 121.7 条': '运行合格审定和持续监督 (a)中国民航局对大型飞机公共航空运输承运人的合格 审定和运行实施统一监督管理。 (b)中国民航局飞行标准职能部门依据本规则组织指导 大型飞机公共航空运输承运人的运行合格审定和持续监督 检查工作，制定必要的工作程序，规定运行合格证、运行规 范及其申请书的统一格式。 (c)民航地区管理局负责对其所辖地区内设立的大型飞 机公共航空运输承运人实施运行合格审定，颁发运行合格证 及其运行规范，并及时向中国民航局飞行标准职能部门备 案。 (d)大型飞机公共航空运输承运人取得运行合格证及其 运行规范后， 即成为本规则规定的运行合格证持有人(以下简 称合格证持有人)。 (e)民航地区管理局及其派出机构负责对其所辖地区内 设立的和(或者)在其所辖地区内运行的合格证持有人实施持 续监督检查。',
#  'file2_4_第 121.9 条': '飞机的湿租 (a)除经中国民航局批准外，合格证持有人不得湿租境外 航空运营人或者境内未按照本规则批准运行的航空运营人 的飞机。 (b)合格证持有人在进行涉及湿租的运行前， 应当向局方 提交一份与国内外其他公共航空运营人所签订的飞机湿租 租赁合同和有关批准文件的副本。局方收到租赁合同副本 后，将确定合同中飞机的运行控制方，并根据需要，向合同 一方或者双方分别颁发运行规范的修改项，否则合格证持有 人不得进行湿租运行。 (c)合格证持有人实施湿租运行，应当提供下列需要列入 运行规范的信息： (1)合同双方的名称和合同的有效期限； (2)合同所涉及的每架飞机的国籍标志和登记标志； (3)运行种类； (4)运行的机场或者区域； (5)具体说明计划由哪一方负责运行控制和实施这种运 行控制的时间、机场或者区域。 (d)在对前款事项作出决定时，局方将考虑下列因素： (1)机组成员资格； (2)飞机的适航性和维修工作； (3)飞行签派； (4)飞机的补给服务； (5)航班计划； (6)安全运行责任； (7)局方认为有关的其他因素。 (e)经局方批准， 合格证持有人在因特殊原因取消其飞机 的飞行时，可以租用带有一名或者多名机组成员的飞机，载 运其旅客进行飞行。这种飞行应当遵守本规则中与所实施运 行有关的规定。',
#  'file2_5_第 121.11 条': '境外运行规则 大型飞机公共航空运输承运人在中国境外运行时，应当 遵守《国际民用航空公约》附件2《空中规则》和所适用的 外国法规。 在 《民用航空器驾驶员合格审定规则》 (CCAR-61)、 《一般运行和飞行规则》(CCAR-91)和本规则的规定严于上 述附件和外国法规的规定并且不与其发生抵触时，还应当遵 守《民用航空器驾驶员合格审定规则》(CCAR-61)、 《一般运 行和飞行规则》(CCAR-91)和本规则的规定。 B 章 运行合格审定的一般规定',
#  'file2_6_第 121.20 条': '运行合格证及其运行规范 (a)在本规则中， 运行合格证是指批准大型飞机公共航空 运输承运人从事特定公共航空运输运行的许可证书。 (b)运行规范是运行合格证的附件， 是指与运行合格证相 对应的，大型飞机公共航空运输承运人运行应当符合的批 准、条件和限制等规范。',
#  'file2_7_第 121.21 条': '运行合格证及其运行规范的申请和颁发程 序 (a)大型飞机公共航空运输承运人实施本规则第121.3 条 规定的运行，应当向其主运行基地所在地的民航地区管理局 申请颁发运行合格证及其运行规范。民航地区管理局按照预 先申请、正式申请、文件审查、演示验证和发证五个步骤进 行审查。运行合格证及其运行规范的申请人应当按照规定的 格式和方法向其主运行基地所在地的民航地区管理局提交 申请书，申请书应当至少附有下列材料： (1)审查活动日程表； (2)本规则第121.133 条所要求的手册； (3)训练大纲及课程； (4)管理人员资历； (5)飞机及运行设施、设备的购买或者租用合同复印件； (6)说明申请人如何符合本规则所有适用条款的符合性 声明。 (b)初次申请运行合格证的申请人， 应当在提交申请书的 同时，提交说明计划运行的性质和范围的文件，包括准许申 请人从事经营活动的有关证明文件。 (c)民航地区管理局应当在收到申请书之后的5 个工作日 内书面通知申请人是否受理申请。 申请人未能按照本条(a)款 要求提交齐全的材料或者申请书格式不符合要求，需要申请 人补充申请材料的，民航地区管理局应当在该5 个工作日内 一次性告知需要补正的全部内容。 (d)民航地区管理局受理申请后， 对申请人的申请材料是 否符合本规则的要求进行审查，对申请人能否按照本规则安 全运行进行验证检查。 (e)民航地区管理局应当自受理申请之日起20 个工作日 内做出是否颁发运行合格证及其运行规范的决定，民航地区 管理局依法进行检验、组织专家评审的时间不计入前述期 限。 (f)申请人属于本规则第121.23 条(b)款规定情形的， 不予 颁发运行合格证及其运行规范。对于此种情况，民航地区管 理局应当书面通知申请人，说明理由并告知申请人享有依法 申请行政复议或者提起行政诉讼的权利。',
#  'file2_8_第 121.23 条': '运行合格证及其运行规范的颁发条件 (a)申请人经过审查后符合下列全部条件， 可以取得大型 飞机公共航空运输承运人运行合格证及其运行规范： (1)满足本规则和涉及民航管理的规章所有适用条款的 要求； (2)按照涉及民航管理的规章的规定， 配备了合格和足够 的人员、设备、设施和资料，并且能够按照本规则的规定及 其运行规范实施安全运行； (3)具有与特定的运行性质和范围相符的完善的组织机 构、飞行运行的控制和监督方法、训练大纲以及地面服务和 维修安排； (4)符合安全保卫相关的涉及民航管理的规章的要求； (5)为代表其执行工作的第三方制定了政策和程序。 (b)申请人具有下列情形之一的，不予颁发运行合格证： (1)申请人没有配备合格的或者足够的人员、设备、设施 和资料，或者不能按照有关涉及民航管理的规章实施安全运 行； (2)申请人或者对其经营管理有控制权的人员， 存在与运 行相关的严重失信行为记录的； (3)申请人安排或者计划安排担任本规则第121.43 条(a) 款规定的主要管理职位的人员，存在与运行相关的严重失信 行为记录的。',
#  'file2_9_第 121.25 条': '运行合格证及其运行规范的内容 经审查合格后，局方应当向申请人颁发大型飞机公共航 空运输承运人运行合格证及其运行规范。 (a)大型飞机公共航空运输承运人运行合格证包含下列 内容： (1)合格证持有人的名称； (2)合格证持有人主运行基地的地址； (3)合格证的编号； (4)合格证的生效日期和有效期； (5)负责监督该合格证持有人运行的局方机构名称和联 系方式； (6)被批准的运行种类； (7)说明经审定，该合格证持有人符合本规则的相应要 求，批准其按照所颁发的运行规范实施运行。 (b)大型飞机公共航空运输承运人的运行规范包含下列 内容： (1)主运行基地的具体地址， 作为合格证持有人与局方进 行通信联系的不同于其主运行基地地址的地址，以及其文件 收发机构的名称与通信地址； (2)对每种运行的实施规定的权利、限制和主要程序； (3)每个级别和型别的飞机在运行中需要遵守的其他程 序； (4)批准合格证持有人使用的每架飞机的型号、系列编 号、国籍标志和登记标志，定期载客运行中需要使用的每个 正常使用机场、备降机场、临时使用机场和加油机场。经批 准，这些项目可以列在现行有效的清单中，作为运行规范的 附件，并在运行规范的相应条款中注明该清单名称。合格证 持有人只能使用列在清单上的飞机和机场运行； (5)批准的运行种类； (6)批准运行的航线和区域及其限制； (7)机场的限制； (8)机体、发动机、螺旋桨、设备(包括应急设备)的维修 时限或者确定维修时限的标准； (9)批准的控制飞机重量与平衡的方法； (10)飞机互换的要求； (11)湿租飞机的有关资料； (12)按照规定颁发的豁免或者批准的偏离； (13)按照本规则需要局方批准的手册和训练大纲； (14)按照本规则实施运行所必须的管理人员和机构； (15)按照本规则需要局方批准的其他项目。',
#  'file2_10_第 121.27 条': '运行合格证及其运行规范的有效性 (a)运行合格证在出现下列情形之一时失效： (1)合格证持有人自愿放弃，并将其交回局方； (2)局方依法暂扣、撤销或者以其他方式终止该合格证。 (b)在出现下列情形时， 运行规范全部失效或者部分条款 失效： (1)局方依法暂扣、撤销或者以其他方式终止运行合格 证，则运行规范全部失效； (2)局方依法暂停或者终止该运行规范中批准的全部运 行，则运行规范全部失效； (3)局方依法暂停或者终止该运行规范中批准的部分运 行，则运行规范中关于该部分运行的条款失效； (4)对于某一运行种类， 合格证持有人没有满足本规则第 121.47 条(a)款中规定的近期经历要求，并且没有按照第 121.47 条(b)款规定的程序恢复该种类运行时， 运行规范中关 于该种类运行的条款失效。 (c)当运行合格证或者运行规范依法被暂扣、撤销或者因 其他原因而失效时，合格证持有人应当将运行合格证或者运 行规范交还局方。',
#  'file2_11_第 121.29 条': '运行合格证及其运行规范的检查 合格证持有人应当将其运行合格证及其运行规范保存 在主运行基地，并能随时接受局方的检查。合格证持有人的 飞机上应当携带运行合格证及其运行规范经认证的真实副 本，并保证副本与正本一致。该副本可以是纸质版，也可以 是符合局方要求的其他形式。',
#  'file2_12_第 121.31 条': '运行合格证的修改 (a)在下列情形下，局方可以修改按照本规则颁发的运行 合格证： (1)局方认为为了安全和公众利益需要修改； (2)合格证持有人申请修改， 且局方认为安全和公众利益 允许进行此种修改。 (b)合格证持有人申请修改其运行合格证时， 适用本规则 第121.21 条(c)款至(f)款规定的程序和期限并应当遵守下列 规定： (1)合格证持有人应当在不迟于其计划的修改生效日期 前适当的时间向其主运行基地所在地的民航地区管理局提 交修改其运行合格证的申请书； (2)申请书应当按照规定的格式和方法提交。 (c)当合格证持有人对其运行合格证修改的申请被拒绝 或者对局方发出的修改决定有不同意见，请求重新考虑时， 应当在收到局方通知后20 个工作日内向局方提出重新考虑 的请求。',
#  'file2_13_第 121.33 条': '合格证持有人保存和使用运行规范的责任 (a)合格证持有人应当在其主运行基地保存一套独立完 整且现行有效的运行规范。 (b)合格证持有人应当将其运行规范中的有关内容或者 信息，写进本规则G 章规定的手册中，并且应当清楚地写明 这些内容是其运行规范的一部分，还应当说明运行规范的每 一条要求具有强制性；或者将完整的运行规范与手册编制在 一起进行分发、携带、保存和更新。 (c)合格证持有人应当持续保证其每个参与运行工作的 人员，熟知运行规范中适用于该人员工作职责的有关规定。',
#  'file2_14_第 121.35 条': '运行规范的修改 (a)在下列情形下，局方可以修改按照本规则颁发的运行 规范： (1)局方认为为了安全和公众利益需要修改； (2)合格证持有人申请修改， 且局方认为安全和公众利益 允许进行此种修改。 (b)除本条(e)款规定的情形外， 局方主动修改合格证持有 人的运行规范应当遵守下列程序： (1)局方以书面形式提出修改内容，通知合格证持有人； (2)局方确定一个不少于5 个工作日的合理期限， 合格证 持有人可以在此期限内对修改内容提交有关书面资料和意 见； (3)局方审查合格证持有人提交的全部材料后， 作出下列 决定之一并通知合格证持有人： (i)采用全部修改意见； (ii)采用部分修改意见； (iii)拒绝所提出的修改意见。 (4)合格证持有人收到局方颁发的修改运行规范的通知 20 个工作日后，修改项生效，但下列情况除外： (i)根据本条(e)款，需要立即生效的； (ii)合格证持有人根据本条(d)款， 请求对修改的决定重新 考虑的。 (c)合格证持有人申请修改其运行规范时， 适用本规则第 121.21 条(c)款至(f)款规定的程序和期限并应当遵守下列规 定： (1)合格证持有人应当在计划的运行规范修改生效日期 前适当时间提交修改其运行规范的申请书，但有下列情形之 一的，申请人应当在计划的运行规范修改生效日期前足够的 时间内提出申请： (i)兼并其他运营人或者增设按照本规则运行的分支机构 的； (ii)增加运行的能力、 需要通过验证试飞重新证明其能够 安全运行的； (iii)本规则第121.3 条(c)款中确定的运行种类改变的； (iv)由于破产行为而暂停运行后需要恢复运行的； (v)初次引进以前未经大型飞机公共航空运输承运人运 行验证试飞的飞机的。 (2)申请书应当以规定的格式和方法向其主运行基地所 在地的民航地区管理局提交； (3)在考虑了申请人提交的所有材料以及局方的审查情 况后，局方作出下列决定之一并通知合格证持有人： (i)接受所申请的全部修改； (ii)接受所申请的部分修改； (iii)拒绝所申请的修改。此时，合格证持有人可以按照 本条(d)款规定，请求局方对其拒绝决定进行重新考虑。 (4)局方批准修改的， 经与合格证持有人就其修改的贯彻 问题进行协调后，修改项在局方批准的日期生效； (5)如果合格证持有人守法信用信息记录中存在与运行 相关的严重失信行为记录，局方可以拒绝其申请的部分或者 全部修改。 (d)合格证持有人申请局方重新考虑运行规范修改项的 决定的，应当遵守下列程序： (1)合格证持有人应当在收到局方拒绝修改其运行规范 的通知后， 或者在收到局方提出修改其运行规范的通知后20 个工作日内，向局方提出重新考虑的请求； (2)如果重新考虑的请求是在20 个工作日内提出的，则 局方颁发的任何修改暂停生效，除非局方发现，根据本条(e) 款，存在紧急情况，为了安全，需要立即生效； (3)如果重新考虑的请求不是在20 个工作日内提出的， 按照本条(c)款规定的程序执行。 (e)如果局方发现，存在危及安全、需要立即行动的紧急 情况， 不能执行本条(b)款至(d)款规定的程序， 或者按照程序 进行将违背公众利益，则可以采取下列措施： (1)局方修改运行规范， 并使修改项在合格证持有人收到 该修改通知日期起立即生效； (2)在发给合格证持有人的通知中，局方应当说明原因， 指出存在危及安全、需要立即行动的紧急情况，或者指出修 改推迟生效将违背公众利益的情况。',
#  'file2_15_第 121.37 条': '申请人的责任 申请人申请取得或者申请修改运行合格证及其运行规 范以及与运行合格审定有关的其他项目，应当保证申请材料 真实完整。 C 章 管理合格证持有人的一般规定',
#  'file2_16_第 121.41 条': '监察和检查的实施 (a)合格证持有人应当接受局方在任何时间或者地点对 其进行的监察或者检查，以确定其是否符合涉及民航管理的 规章的规定，是否符合其运行合格证及其运行规范的规定。 (b)合格证持有人应当能在其主运行基地向局方提供下 列资料： (1)合格证持有人的大型飞机公共航空运输承运人运行 合格证及其运行规范； (2)一个包含有关资料存放地点和负责人员信息的现行 清单。上述资料是指合格证持有人按照适用的涉及民航管理 的规章规定，应当保存的记录、文件和报告。 (c)负责保存合格证持有人记录、文件和报告的所有人 员，应当能向局方提供这些资料。 (d)局方可以根据本条(a)款检查的结果或者任何其他适 当的材料，确定合格证持有人是否合格于继续持有其运行合 格证及其运行规范。 (e)合格证持有人如果不能按照局方要求， 提供其运行合 格证、运行规范或者任何必需的记录、文件和报告，存在安 全隐患的，局方可以暂停其运行合格证或运行规范中的部分 或者全部运行批准。',
#  'file2_17_第 121.42 条': '安全管理体系 合格证持有人应当建立安全管理体系，并且能够按照本 规则的规定实施安全管理，该体系应当： (a)至少具备了下列功能： (1)对影响安全的危险源能够及时识别； (2)保证采取必要的纠正措施，保持可接受的安全水平； (3)对安全水平进行持续的监督和定期评估； (4)持续改进整体安全水平。 (b)明确地界定了整个组织内部的安全责任界限， 包括高 层管理者应当对安全直接承担的责任。 (c)制订并持续实施非惩罚性， 且包含保护数据及其来源 措施的飞行数据分析方案。 (d)制订供运行人员使用的飞行安全文件系统。',
#  'file2_18_第 121.43 条': '按照本规则实施运行所必需的管理人员和 机构 (a)合格证持有人应当拥有能够有效控制和监督其整个 运行的管理机构，并拥有足够的合格管理人员和技术人员， 以保证在其运行中保持最高的安全水平。合格证持有人应当 在下列职位或者同等职位上安排合格的人员： (1)主要负责人， 对合格证持有人安全生产工作全面负责 的高级管理人员，具体责任包括： (i)建立健全并落实合格证持有人全员安全生产责任制， 遵守安全生产法律法规，组织制定并实施合格证持有人安全 生产规章制度和操作规程； (ii)组织制定并签署合格证持有人安全政策， 保证安全投 入的有效实施； (iii)对实施和保持合格证持有人安全管理体系负责，组 织建立并落实合格证持有人安全风险分级管控和隐患排查 治理双重预防工作机制，督促、检查合格证持有人的安全生 产工作，及时消除安全隐患； (iv)组织制定、 实施并签署合格证持有人生产安全事故应 急救援预案，及时、如实报告安全生产事故。 (2)安全总监， 负责独立地对合格证持有人的运行安全管 理过程进行监督，并应该直接向主要负责人报告。 (3)运行副总经理，负责合格证持有人飞行运行的管理， 使之符合本规则要求。 (4)维修副总经理，负责合格证持有人的飞机维修管理， 使之符合本规则要求。 (5)总飞行师， 负责合格证持有人的飞行人员训练和技术 管理，使之符合本规则的要求。 (6)总工程师， 负责合格证持有人的飞机维修工程技术管 理，使之符合本规则的要求。 (7)本款要求的包括主要负责人在内的上述所有管理和 技术人员不得在同一时间任职于多个按本规则运行的合格 证持有人。 (b)对于某一项具体运行，如果合格证持有人能证明，由 于所涉及的运行种类、所使用的飞机数量与型号和运行的区 域等因素，使用较少的管理人员能够完成本条(a)款规定的除 安全总监以外其他职位的全部职责并能以同等安全水平完 成运行， 局方可以认可其管理人员的配备。 除经局方批准外， 安全总监不允许由本条(a)款其余职务的人员兼任。 (c)本条(a)款要求的或者按照本条(b)款认可的职位名称 和管理人员数量，应当在合格证持有人的运行规范中明确载 明。 (d)担任本条(a)款或者(b)款要求的或者认可的职位的人 员，以及按照运行合格证实施运行的各级负责人，应当符合 下列要求： (1)在训练、经验、专业知识上保持合格水平。 (2)在其职责范围内， 理解有关合格证持有人各种运行的 下列资料： (i)有关涉及民航管理的规章； (ii)合格证持有人的运行规范； (iii)航空安全标准和安全运行常规； (iv)本规则及其他涉及民航管理的规章中所有适用的维 修和适航要求； (v)本规则第121.131 条要求的手册。 (3)严格履行其职责，以符合适用的规章要求，并保证安 全运行。 (e)合格证持有人应当在本规则G 章要求的手册内的一 般政策规定中，写明本条(a)款规定的人员的任务、职责和权 力，并写明担任这些职务人员的姓名和业务地址。合格证持 有人应当在上述所列职位上的人员变换或者空缺后10 天内 通知局方。 (f)合格证持有人应当设立由飞行、维修、签派和客舱安 全等专业人员组成的运行管理机构，负责协调各业务部门有 关运行的事项；办理运行合格审定的有关事宜；负责手册的 分发、更改和报批工作，保持其有效性。 (g)合格证持有人应当设立独立于运行的安全监督机构， 在安全总监的直接领导下，负责安全水平的持续监督和定期 评估；调查安全相关事件；就安全有关事务提出建议和组织 员工安全教育等。',
#  'file2_19_第 121.45 条': '管理人员的合格条件 (a)自2025 年1 月1 日起，首次担任本规则第121.43 条 (a)款规定的主要负责人应当符合下列条件： (1)接受了局方认可的相关法规的培训并合格； (2)曾经担任按本规则运行的第121.43 条(a)款规定的主 要管理人员或者具备至少3 年民航安全管理工作经验； (3)熟悉合格证持有人的运行规范、 运行手册及其他相关 要求； (4)具有较强的分析解决问题能力和良好的沟通技能。 (b)担任本规则第121.43 条(a)款规定的安全总监应当符 合下列条件： (1)掌握运行安全管理知识、质量管理知识、涉及民航管 理的规章、标准及程序; (2)最近6年内在合格证持有人或者局方的安全监督岗位 工作3 年以上，或者持有下列任一专业执照并在相应岗位上 工作3 年以上： (i)航线运输驾驶员执照； (ii)民用航空器维修人员执照； (iii)飞行签派员执照。 (3)理解合格证持有人的运行规范、 运行手册及其他相关 要求; (4)具有较强的分析解决问题能力和良好的沟通技能。 (c)担任本规则第121.43 条(a)款规定的运行副总经理应 当符合下列条件： (1)持有航线运输驾驶员执照； (2)在最近6 年内， 在该合格证持有人使用相同级别飞机 按照本规则所实施的运行中具有运行控制权的职位上，至少 有3 年管理经历； (3)对于初次担任运行副总经理的人员， 在最近的6年内， 至少在该合格证持有人按照本规则运行的相同级别的飞机 上具有担任机长3 年的经历；对于具有负责运行副总经理经 历的人员，至少在该合格证持有人按照本规则运行的相同级 别的飞机上具有担任机长3 年的经历。 (d)担任本规则第121.43 条(a)款规定的维修副总经理应 当符合下列条件： (1)接受了局方认可的相关法规的培训并合格； (2)在前6 年内具有至少3 年从事合格证持有人运行的至 少一种类别和级别飞机全面的维修管理经历。 (e)担任本规则第121.43 条(a)款规定的总飞行师应当符 合下列条件： (1)持有航线运输驾驶员执照， 至少具有该合格证持有人 按照本规则运行中所用的一种飞机的合适等级； (2)对于初次担任总飞行师的人员，在最近6 年内，至少 在该合格证持有人按照本规则运行的相同级别的飞机上，具 有担任机长3 年的经历；对于具有总飞行师经历的人员，至 少在与该合格证持有人按照本规则运行的相同级别的飞机 上，具有担任机长3 年的经历。 (f)担任本规则第121.43 条(a)款规定的总工程师应当符 合下列条件： (1)持有民用航空器维修人员执照， 至少具有该合格证持 有人按照本规则运行中所用的一种飞机的机型签署经历； (2)具有维修本规则运行的飞机至少5 年的经历， 其中至 少有2 年作为维修工程技术管理人员的经历。 (g)如果合格证持有人拟选任的人员不符合本条(a)、(b)、 (c)、(d)、(e)或者(f)款规定的经历，但具有相应的经历，能够 有效履行涉及民航管理的规章要求的相应职位的职责和合 格证持有人手册规定的程序，局方可以批准对本条相应款项 规定经历的偏离。',
#  'file2_20_第 121.47 条': '运行的近期经历 (a)合格证持有人如果连续中断其运行规范中批准实施 的某一种类的运行达30 个日历日，则在此日期之后，应当 按照本条(b)款规定恢复运行，否则不得继续实施此种运行。 (b)在本条(a)款的中断期之后， 只有符合下列条件并达到 局方要求后，方可以恢复相应种类的运行： (1)在恢复该种运行之前， 至少提前5个工作日通知局方； (2)如果局方决定重新进行全面检查， 以确定其是否保持 了合适和足够的配备，能否实施安全运行，合格证持有人应 当在前述5 个工作日期间处于能随时接受检查的状态。',
#  'file2_21_第 121.49 条': '主运行基地、飞行基地和维修基地 (a)合格证持有人应当保持一个主运行基地。合格证持有 人还可以按照运行需要建立飞行基地和维修基地，飞行基地 和维修基地可以与主运行基地在同一地点，也可以在不同地 点。 (b)在计划建立或者变更主运行基地、 飞行基地或者维修 基地之前至少30 天，合格证持有人应当以书面形式通知局 方。',
#  'file2_22_第 121.51 条': '合格证持有人名称的使用 (a)合格证持有人按照本规则实施运行时所使用的名称 应当与其运行规范上所列名称一致。 (b)除经局方在运行规范中批准外， 在按照本规则运行的 飞机上应当明显地标出运行该飞机的合格证持有人的名称， 否则不得运行该飞机。飞机上标示名称的方法及其可读性应 当符合局方要求。',
#  'file2_23_第 121.52 条': '飞行数据的使用 (a)合格证持有人不得为事故或者征候调查以外的目的 使用驾驶舱话音记录器、驾驶舱音频记录系统的记录或者文 本，除非这些记录或者文本： (1)在去识别化后， 用于合格证持有人安全管理体系内不 安全事件的调查、分析、研究等，并符合《国际民用航空公 约》附件19《安全管理》关于保护安全数据和安全信息的相 关要求； (2)用于与事故或者征候调查所涉事件无关的刑事诉讼， 并符合《国际民用航空公约》附件19《安全管理》关于保护 安全数据和安全信息的相关要求； (3)用于对飞行记录器系统的检查。 (b)合格证持有人不得为事故或者征候调查以外的目的 使用飞行数据记录器、航空器数据记录系统以及本规则第 121.352 条要求的快速记录器的记录或者文本，除非这些记 录或者文本符合《国际民用航空公约》附件19《安全管理》 关于保护安全数据和安全信息的相关要求，且： (1)去识别化； (2)合格证持有人用于飞行数据分析方案； (3)用于与事故或者征候调查所涉事件无关的诉讼； (4)合格证持有人用于适航或者维修； (5)根据安全数据保护程序被公布。 (c)合格证持有人可以与另一方签订合同， 由其负责飞行 数据分析方案具体工作，但符合性责任由合格证持有人承 担。 (d)合格证持有人应当定期向负责合格证管理的民航地 区管理局职能部门报告其通过飞行数据分析方案得到的统 计数据和趋势分析报告，局方认为必要时可以随时查阅或者 分析快速存取记录器(QAR)或者等效设备的原始数据。',
#  'file2_24_第 121.53 条': '按照军方合同实施运行的偏离批准 (a)局方可以批准合格证持有人偏离本规则的适用规定， 实施其按照军方合同确定的运行。 (b)在按照本条批准一项偏离时， 局方将对合格证持有人 的运行规范颁发相应的修改项。 (c)局方在任何时候可以终止按照本条颁发的偏离批准。',
#  'file2_25_第 121.55 条': '实施应急运行的偏离批准 (a)在紧急情况下并满足下列条件时，局方可以批准合格 证持有人偏离本规则的适用规定： (1)在该紧急情况下为保护人员生命和财产应当采取运 送人员或者财产的行动； (2)局方认为，为了立即实施这些运行，应当偏离有关规 定。 (b)在紧急情况下，局方可以使用下列方法之一批准偏 离： (1)局方对合格证持有人的运行规范颁发相应的修改项； (2)如果情况紧急不允许及时修改运行规范， 则局方可以 用口头或者其他方式批准该偏离，但合格证持有人应当在开 始这种运行后24 小时之内，向局方提交说明这种紧急情况 性质的报告。',
#  'file2_26_第 121.57 条': '遵守运行合格证及其运行规范的要求 合格证持有人不得违反运行合格证、运行规范和其他批 准项目实施运行，不得超越批准的偏离或者豁免。 E 章 国内、国际定期载客运行航路的批准',
#  'file2_27_第 121.91 条': '航路批准的基本要求 (a)申请航路批准的合格证持有人应当证明符合下列条 件： (1)能在该航路上每一正常使用机场、 临时使用机场或者 加油机场之间实施满足本规则要求的运行； (2)对于计划的运行，具有满足本规则第121.95 条至第 121.105 条要求的设施与服务。 (b)在证明符合本条(a)款要求时， 如果合格证持有人在考 虑了机场、灯光、维修、通信、导航、加油、地面、机载无 线电等各种设施的可用性和充分性，以及参与运行的全体人 员的能力之后，证明能保证飞行安全，局方可以不要求在该 航路上作航路试飞。',
#  'file2_28_第 121.93 条': '航路宽度 (a)经批准的航路、航段及固定航线具有的宽度应当至少 与这些固定航线或者航路的规定宽度相等。在局方认为有必 要对经批准的航路另行确定宽度时，将考虑下列因素： (1)地形障碍的超越； (2)最低航路高度； (3)地面和机载导航设备； (4)空中交通密度； (5)空中交通管制程序。 (b)局方对经批准的航路另行确定的宽度， 将具体规定在 该大型飞机公共航空运输承运人的运行规范中。',
#  'file2_29_第 121.95 条': '必需的机场资料 (a)合格证持有人应当证明，所申请批准的航路上具有足 够的机场，并且这些机场装备了适合于所申请运行的设施。 其中所考虑的因素应当包括机场的等级、道面、障碍物、设 施、公众保护、灯光、导航、通信、气象设施以及空中交通 管制等。 (b)合格证持有人应当证明，对于所使用的每个机场，都 能够获得、保存现行有效的航行资料，包含但不限于航行通 告(NOTAM)、航行资料汇编(AIP)、航行资料通报(AIC)和定 期制航行通告(AIRAC)等与运行安全、规则和效率有关的信 息，并且具有将其分发给每个有关人员的经批准的资料管理 系统，以确保飞机在该机场运行的安全。这种航行资料应当 包括下列方面的内容： (1)机场 (i)基本设施； (ii)安保(空防)保护措施； (iii)机场活动区管理措施； (iv)救援和消防服务(RFFS)； (v)导航、通信、气象设施； (vi)影响起飞、着陆或者地面运行的建筑物； (vii)空中交通服务设施。 (2)跑道、停止道和净空道 (i)尺寸； (ii)道面性质； (iii)标志和灯光系统； (iv)标高和坡度。 (3)内移的跑道入口 (i)位置； (ii)尺寸； (iii)用于起飞、用于着陆或者二者兼用。 (4)障碍物 (i)影响按照本规则I 章进行起飞和着陆性能计算的障碍 物； (ii)起控制作用的障碍物。 (5)仪表飞行程序 (i)离场程序； (ii)进场程序； (iii)进近程序； (iv)复飞程序。 (6)特殊资料 (i)跑道视程(RVR)测量设备； (ii)低能见度条件下的盛行风。 (c)如果负责管理该合格证持有人的民航地区管理局发 现该合格证持有人经批准的关于收集、分发和使用航行资料 的系统应当予以改进才能恰当地继续工作，则合格证持有人 在接到该部门的通知后，应当立即对其系统进行改进。在合 格证持有人接到这样的通知之后30 天内，可以向中国民航 局飞行标准职能部门提出重新考虑的请求。重新考虑的请求 使该通知处于暂缓执行状态，直至中国民航局飞行标准职能 部门作出决定时止。但是，如果民航地区管理局认为存在关 系到航空运输安全、需要立即采取措施的紧急情况，则中国 民航局飞行标准职能部门可以根据所陈述的理由，使要求改 进的通知立即生效。',
#  'file2_30_第 121.97 条': '通信设备 (a)合格证持有人应当证明，在正常运行条件下，在整个 航路上，所有各点都具有陆空双向无线电通信系统，能保证 每一架飞机与相应的空中交通管制单位之间，每一架飞机与 相应的运行控制中心之间，以直接的或者通过经批准的点到 点间的线路进行迅速可靠的通信联系。除遇到紧急情况外， 对于合格证持有人的所有运行，每架飞机与运行控制中心之 间的通信系统应当是空中交通管制通信系统之外的独立系 统。 (b)对于国内运行， 如合格证持有人评估所运行的航线上 存在空中交通管制通信设施不可用或者通信质量无法保证 有效语音通信的情况，运行该航线的每一架飞机与运行控制 中心之间应当保证有另一种语音通信系统可以进行替代。 (c)对于国际运行，合格证持有人应当保证每一架飞机与 相应的运行控制中心之间能够满足在正常运行条件下，在4 分钟内建立迅速可靠的语音通信联系。',
#  'file2_31_第 121.99 条': '气象服务 (a)合格证持有人应当证明，每一条航路沿线，均有足够 的气象报告服务可以供使用，以保证提供运行所必需的气象 实况报告和气象预报。 (b)合格证持有人只能使用符合局方要求的气象服务系 统提供的气象资料。 (c)使用气象预报控制飞行活动的合格证持有人， 应当使 用依据本条(b)款规定的气象资料而编制的气象预报， 以及按 照本条(d)款规定采用的系统所批准的任何来源而编制的气 象预报。 (d)合格证持有人应当使用经局方批准的危险天气实况 报告与预报系统，以便获得可能影响所飞航路和所用机场飞 行安全的危险天气现象，如晴空颠簸、雷暴和低空风切变等 情况的实况报告和预报。',
#  'file2_32_第 121.101 条': '航路导航设施 (a)除本条(b)款规定外， 合格证持有人应当证明， 对于每 一条计划中的航路，非目视地面导航设施符合下列要求： (1)具有足够的非目视地面导航设施， 能在空中交通管制 要求的精度之内，在整个航路上为飞机导航； (2)非目视地面导航设施的位置， 能保证在该运行所必需 的精度范围之内，引导飞机至任一正常使用机场、临时使用 机场、加油机场或者备降机场。 (b)下列运行不需要非目视地面导航设施： (1)昼间目视飞行规则运行，但合格证持有人应当证明， 能够根据地形的特征，使用地标领航而安全运行； (2)在经局方批准使用特殊导航方法导航的航段上实施 的运行。',
#  'file2_33_第 121.103 条': '运行控制中心 (a)合格证持有人应当设立运行控制中心， 通过完备的运 行控制组织管理体系，确保对每次飞行进行恰当的运行控 制。 (b)运行控制中心可以设立若干分支机构实施运行控制， 但运行控制责任应当严格遵守本规则第121.531 条的要求。 (c)合格证持有人的运行控制体系应当在运行规范中得 到批准，并在运行手册中描述说明该体系的组织架构、授权 以及职责。',
#  'file2_34_第 121.105 条': '地面服务 每个实施国内、国际定期载客运行的合格证持有人应当 建立相应的地面服务管理组织机构，在相关的手册中明确对 所有地面服务的培训要求、外部委托政策、管理程序、工作 标准和规范等内容，并具备足够的合格人员和适当的设施和 设备(包括备件、地面保障和材料等)，确保飞机起飞前或者 着陆后的地面服务符合本规则的相应要求。当合格证持有人 通过外部委托方式由他人提供部分或者全部地面服务时，合 格证持有人应当向相应的地面服务人员提供必要的训练，并 对其操作的安全性负责。 F 章 补充运行的区域和航路批准',
#  'file2_35_第 121.113 条': '航路和区域要求概则 (a)实施补充运行的合格证持有人应当按照下列规定申 请运行区域和航路的批准： (1)对于国内运行， 中国境内的空域按照一个运行区域批 准，但包含高高原机场(海拔高度在2,438 米或者8,000 英尺 及以上的机场)起降点的航路还需按照航路进行批准； (2)对于国际运行，所飞机场所在的每一国家(地区)按照 一个运行区域批准，但包含高高原机场或者局方确定的特殊 机场起降点的航路还需按照航路进行批准。 (b)按照本条(a)款申请运行区域和航路批准的合格证持 有人，应当证明其具有足够的装备和能力，能够使用中国或 者外国公布航路上有关导航设施，在仪表飞行规则和夜间目 视飞行规则条件下实施安全运行。 (c)如果实施补充运行的合格证持有人可以证明， 对于运 行的航路是安全的，并且局方能够确定空中交通密度有足够 的安全水平，局方可以批准合格证持有人管制空域外的航 路。合格证持有人不可以使用没有经局方批准的，或者运行 规范中没有列出的航路。',
#  'file2_36_第 121.115 条': '航路宽度 (a)经批准的航路、航段及固定航线具有的宽度应当至少 与这些固定航线或者航路的规定宽度相等。在局方认为有必 要对经批准的航路另行确定宽度时，将考虑下列因素： (1)地形障碍的超越； (2)最低航路高度； (3)地面和机载导航设备； (4)空中交通密度； (5)空中交通管制程序。 (b)合格证持有人运行规范中局方加以规定的任何其他 航路宽度。',
#  'file2_37_第 121.117 条': '必需的机场资料 (a)实施补充运行的合格证持有人使用的任何机场应当 具有适当的装备并适合于所申请运行的设施。其中所考虑的 因素应当包括机场的等级、道面、障碍物、设施、公众保护、 灯光、导航、通信、气象设施以及空中交通管制等。 (b)每一实施补充运行的合格证持有人应当证明其有一 个经批准的系统，能够获得、保存和分发给每个有关人员所 使用机场现行有效的航行资料，以确保飞机在该机场运行的 安全。这种航行资料应当包括下列方面的内容： (1)机场 (i)基本设施； (ii)安保(空防)保护措施； (iii)机场活动区管理措施； (iv)救援和消防服务(RFFS)； (v)导航、通信、气象设施； (vi)影响起飞、着陆或者地面运行的建筑物； (vii)空中交通服务设施。 (2)跑道、停止道和净空道 (i)尺寸； (ii)道面性质； (iii)标志和灯光系统； (iv)标高和坡度。 (3)内移的跑道入口 (i)位置； (ii)尺寸； (iii)用于起飞、用于着陆或者二者兼用。 (4)障碍物 (i)影响按照本规则I 章进行起飞和着陆性能计算的障碍 物； (ii)起控制作用的障碍物。 (5)仪表飞行程序 (i)离场程序； (ii)进场程序； (iii)进近程序； (iv)复飞程序。 (6)特殊资料 (i)跑道视程(RVR)测量设备； (ii)低能见度条件下的盛行风。 (c)如果负责管理该合格证持有人的民航地区管理局发 现该合格证持有人经批准的关于收集、分发和使用航行资料 的系统应当予以改进才能恰当地继续工作，则合格证持有人 在接到该部门的通知后，应当立即对其系统进行改进。在合 格证持有人接到这样的通知之后30 天内，可以向中国民航 局飞行标准职能部门提出重新考虑的请求。重新考虑的请求 使该通知处于暂缓执行状态，直至中国民航局飞行标准职能 部门作出决定时止。但是，如果民航地区管理局认为存在关 系到航空运输安全、需要立即采取措施的紧急情况，则中国 民航局飞行标准职能部门可以根据所陈述的理由，使要求改 进的通知立即生效。',
#  'file2_38_第 121.119 条': '气象服务 (a)合格证持有人应当证明，每一条航路沿线，均有足够 的气象报告服务可以供使用，以保证提供运行所必需的气象 实况报告和气象预报。 (b)合格证持有人只能使用符合局方要求的气象服务系 统提供的气象资料。 (c)使用气象预报控制飞行活动的合格证持有人， 应当使 用依据本条(b)款规定的气象资料而编制的气象预报。',
#  'file2_39_第 121.121 条': '航路导航设施 (a)除本条(b)款规定外， 合格证持有人应当证明， 对于每 一条计划中的航路，非目视地面导航设施符合下列要求： (1)能在空中交通管制要求的精度之内， 在整个航路上为 飞机导航； (2)非目视地面导航设施的位置， 能保证在该运行所必需 的精度范围之内，引导飞机至任一目的地机场或者备降机 场。 (b)下列运行不需要非目视地面导航设施： (1)昼间目视飞行规则运行，但合格证持有人应当证明， 能够根据地形的特征，使用地标领航而安全运行； (2)在经局方批准使用特殊导航方法导航的航段上实施 的运行。',
#  'file2_40_第 121.123 条': '地面服务 每个实施补充运行的合格证持有人应当建立相应的地 面服务管理组织机构，在相关的手册中明确对所有地面服务 的培训要求、 外委政策、 管理程序和工作标准、 规范等内容， 并具备足够的合格人员和适当的设施和设备(包括备件、 地面 保障和材料等)， 确保飞机起飞前或者着陆后的地面服务符合 本规则的相应要求。当合格证持有人通过外委方式由他人提 供部分或者全部的地面服务时，合格证持有人应当向相应的 地面服务人员提供必要的训练，并对其操作的安全性负责。',
#  'file2_41_第 121.125 条': '飞行跟踪系统 (a)实施补充运行的合格证持有人应当证明： (1)具有符合本规则U 章要求的飞行跟踪系统， 该系统根 据所实施的运行可以对每次飞行进行有效的跟踪； (2)飞行跟踪中心应当设在适用于对下列情况实施飞行 跟踪的位置： (i)确保对每次飞行的始发机场和目的地机场的飞行进程 进行适当的监控，包括对中途停留机场和改航备降机场飞行 进程的监控，以及对在这些机场所需的维修或者机械延误进 行适当的监控； (ii)确保机长能够得到安全飞行必需的所有资料。 (b)实施补充运行的合格证持有人可以使用非所属人员 提供的飞行跟踪设施，但在这种情况下，合格证持有人应当 对每次飞行的运行控制持续负责。 (c)飞行跟踪系统不要求与空中飞行的机组建立通信联 系。 (d)在合格证持有人的运行规范中应当明确批准使用的 飞行跟踪系统和飞行跟踪中心的所在位置。',
#  'file2_42_第 121.127 条': '飞行跟踪系统要求 (a)实施补充运行的每个合格证持有人应当证明： (1)系统具备足够的设备和合格人员， 为下列人员提供每 一次飞行的起始和安全运行所必需的信息： (i)每架飞机的飞行机组； (ii)合格证持有人指定实施运行控制的人员。 (2)飞行跟踪系统具有利用公共或者私人设施(例如电 话、电报或者无线电)获得通信的能力，以进行本规则第 121.125 条(a)款第(2)项第(i)目要求的监控。 (b)实施补充运行的合格证持有人应当证明本条(a)款所 述人员能够履行他们的职责。 G 章 手册的要求',
#  'file2_43_第 121.131 条': '手册的制定和保存 (a)合格证持有人应当具有为实施其各种运行的全体飞 行、维修和其他地面运行工作人员制定并供其使用和指导其 操作的手册， 并且有合适的手册管理系统， 负责制定、 分发、 修订和补充手册，使其保持现行有效。 (b)本条(a)款要求的手册应当符合下列要求： (1)包含必需的政策、流程、标准和程序等指令和信息， 使有关人员能安全地完成所担负的工作职责； (2)除局方批准外，使用中文写成。如果合格证持有人在 运行中使用了不熟悉中文的人员，则应当同时为其提供相应 文字的手册，并且应当保证这些手册的一致性和同等有效 性； (3)采用易于修订的形式； (4)在有关的每一页上，标注最后一次修订的日期。对于 电子化的手册，可以以恰当的形式标注最后一次修订的日 期，使人员可以迅速确定有效性； (5)符合所有适用的涉及民航管理的规章、 该合格证持有 人的运行合格证与运行规范；对于实施国际运行的合格证持 有人，还应当符合所适用的外国规章。 (c)合格证持有人在其主运行基地至少要保存一套完整 的手册。该手册可以是纸质版的手册，也可以是符合局方要 求的其他形式。',
#  'file2_44_第 121.133 条': '手册内容总体要求 手册应当包含下列所有内容，但可以分为两个或者两个 以上的单独分册，每一分册应当包括所有适用于该类人员的 内容： (a)概述： (1)与飞行运行有关人员工作内容和责任的说明，包括： 机组成员和飞行签派员在飞行起始、持续、改航和终止阶段 的职能； (2)飞行签派和运行控制，包括：适用的签派协调、飞行 控制、 飞行跟踪程序、 在冲突地区及附近运行风险的管理等； (3)航路飞行、导航和通信程序，包括：当任何所需的特 定设备不工作或者无法提供服务时，签派或者放行飞机继续 飞行； (4)有关机组成员疲劳管理的信息和政策，包括： (i)根据P 章，适用于飞行和客舱机组成员的飞行时间、 飞行值勤期、值勤期的限制和休息期要求的有关政策； (ii)合格证持有人的疲劳风险管理制度或者经局方批准 的疲劳风险管理系统(如适用)的有关政策和文件。 (5)机载导航设备清单， 其中包含与基于性能导航区域内 的运行有关的任何规定； (6)适用的远程导航程序、延程运行(EDTO)的发动机失 效程序和备降机场的选择与使用； (7)应持续保持无线电监听的情况； (8)确定飞行最低高度的方法； (9)确定机场运行最低标准的方法； (10)乘客在机上时实施燃油加注的安全预防措施； (11)地面操作的安排和程序； (12)机长发现有事故发生后使用的搜寻和救援程序； (13)不同类型运行中飞行机组指挥权接替次序的指定； (14)对所要装载的燃油与滑油量计算的具体说明，其中 考虑到运行中的所有情况，包括在航路上释压和一台或者多 台动力装置失效的可能性； (15)应当使用氧气的情况和按照本规则规定确定的氧气 携带量； (16)重量与平衡控制方面的操作指示； (17)地面除冰、 防冰操作的实施和控制方面的操作指示； (18)空中交通服务飞行计划的填写规范，运行飞行计划 的内容和使用方法; (19)飞行各阶段的标准操作程序(SOP)； (20)关于正常检查单的使用及其使用时机的操作指示； (21)离场应急程序； (22)保持高度意识和使用自动或者飞行机组高度喊话的 操作指示； (23)在仪表气象条件下使用自动驾驶仪与自动油门的操 作指示； (24)关于空中交通管制许可的确认与接受的操作指示， 特别是针对那些许可中包含有超越障碍物许可的情况； (25)离场与进近简令； (26)用于熟悉空域、航路和机场的程序； (27)稳定进近程序； (28)贴近地面时的大下降率限制； (29)开始或者继续仪表进近所需的条件； (30)实施非精密进近程序(NPA)、 有垂直引导的进近程序 (APV)和精密进近程序(PA)的操作指示； (31)夜间与仪表气象条件下，仪表进近与着陆运行中的 飞行机组职责分配和机组成员工作负荷管理的程序； (32)避免可控飞行撞地的操作指示与训练要求，以及近 地警告系统的使用政策； (33)避免空中相撞和使用空中交通防撞系统(ACAS)的 政策、操作指示、程序和训练要求； (34)关于拦截民用飞机方面的信息和操作指示，包括： (i)被拦截飞机的机长应当采取的程序； (ii)拦截和被拦截飞机使用的目视信号。 (35)对准备在15,000 米(49,000 英尺)以上运行的飞机， 还需要以下资料： (i)在受到太阳宇宙射线辐射时，使驾驶员能够确定应采 取的最佳行动方案的资料； (ii)决定下降后的程序，其中包括： (A)向合适的空中交通服务单位发出预先情况警告以及 获得临时下降许可所必需的程序； (B)与空中交通服务单位之间的通信不能建立或者被中 断时应采取的措施。 (36)安全管理体系的详细内容； (37)与危险品航空运输活动相关的程序和培训方案(含 未获得危险品航空运输许可的合格证持有人)； (38)安保方面的操作指示及指南； (39)根据安保部门相关规定制定的搜查程序检查单，该 检查单必须包括在发现爆炸物或者可疑物时所采取适当行 动步骤的指南以及有关飞机上最低风险爆炸位置(如适用)的 资料； (40)航空人员健康管理与健康促进的规定与程序； (41)航空食品卫生规定与程序； (42)飞机环境卫生、消毒和卫生防疫的规定与程序，突 发公共卫生事件处置预案； (43)电子飞行包(EFB)管理要求和程序(如适用)； (44)电子导航、近地警告等数据管理程序； (45)根据本规则第121.533 条制定的飞机追踪程序； (46)使用平视显示器(HUD)或者等效显示器、增强视景 系统(EVS)、增强飞行视景系统(EFVS)、合成视景系统(SVS) 和/或组合视景系统(CVS)等设备的说明和培训要求。 (b)飞机运行信息： (1)飞机型号审定限制和运行限制； (2)飞行机组使用的正常、 非正常和应急程序及有关检查 单； (3)所有发动机工作时爬升性能的操作指示和信息； (4)供飞行前和飞行中制定计划使用的飞行计划数据， 包 含不同的推力、功率和速度设定情况下的数据； (5)所用每个机型的最大侧风和顺风分量限制， 以及在考 虑了阵风、低能见、跑道道面状况、机组经历、自动驾驶使 用、非正常或者紧急情况或者其他有关运行因素影响时，对 这些限制数值进行的缩减； (6)重量与平衡计算方面的操作指示和数据； (7)飞机装载和载荷固定方面的操作指示； (8)可供每一型号飞机运行人员和飞行机组所使用的包 括与该型号飞机运行有关的正常、非正常和应急程序以及该 飞机各系统和所用检查单的详细信息在内的飞机操作手册， 手册的设计还需符合人的因素要求； (9)供所用机型和经批准的特殊运行使用的最低设备清 单和外形缺损清单，其中包含与基于性能导航区域内的运行 有关的任何规定； (10)应急和安全设备的检查单和使用说明； (11)应急撤离程序，包括与机型相关的程序、机组协调、 紧急情况下机组成员的指定位置和紧急情况下每个机组成 员的职责； (12)客舱乘务员所使用的正常、非正常和应急程序，以 及与此有关的检查单和必需的飞机系统信息，并且包括一个 用于解释这些程序是供飞行机组成员和客舱乘务员之间协 调使用的说明； (13)用于不同航路的救生和应急设备清单，以及在起飞 前验证其工作正常的必要程序，包括确定所需氧气量和可用 量的程序； (14)供幸存者使用的地空目视信号说明。 (c)航路和机场： (1)航路信息指导， 用于确保飞行机组每次飞行都能够获 得适用于该运行的通讯设施、助航设备、机场、仪表进近、 仪表进场和仪表离场方面的信息以及承运人认为正确实施 飞行运行所必需其他信息； (2)每一所飞航路的最低飞行高度； (3)可能用作目的地机场或者备降机场的每个机场的运 行最低标准； (4)确定使用平视显示器(HUD)或者等效显示器、增强视 景系统(EVS)、 增强飞行视景系统(EFVS)、 合成视景系统(SVS) 和/或组合视景系统(CVS)等设备的仪表进近机场运行最低标 准的说明； (5)在进近或者机场设施降级的情况下机场运行最低标 准的提高； (6)符合规章要求的所有飞行剖面的必需信息， 包括但不 仅限于下列确定内容： (i)干、湿和受污染情况下的起飞跑道长度要求，包括影 响起飞距离的系统失效情况； (ii)起飞爬升限制； (iii)航路爬升限制； (iv)进近爬升限制和着陆爬升限制； (v)干、湿和受污染情况下的着陆跑道长度要求，包括影 响着陆距离的系统失效情况； (vi)补充信息，如轮胎速度限制。 (d)训练： 本规则N 章规定的，包含相应地面训练、飞行训练(如 适用)等详细内容的飞行机组成员、 客舱乘务员和飞行签派员 的训练大纲，以保证参加训练的人员在上岗前对于所担负的 工作接受了充分的训练。',
#  'file2_45_第 121.135 条': '手册的分发和可用性 (a)合格证持有人应当向下列人员提供本规则第121.131 条所要求的手册及其修改和补充，或者该手册的有关部分： (1)维修人员和有关地面运行工作人员； (2)机组成员； (3)负责管理该合格证持有人的局方人员。 (b)按照本条(a)款持有手册或者手册相关部分的每个人， 应当使用合格证持有人提供的修改和补充页，使手册内容保 持最新有效状态，并在执行指定任务时可以随时查阅。',
#  'file2_46_第 121.137 条': '飞机飞行手册 (a)合格证持有人应当为其使用的每一型号飞机保持现 行有效的飞机飞行手册。 (b)合格证持有人的每架飞机都应当携带用机组人员所 熟悉的语言编写，且满足本条(a)款所要求的飞机飞行手册。 合格证持有人也可以携带按本规则第121.131 条要求编写的 手册， 但该手册应当包含适用本条(a)款飞机飞行手册规定的 信息。 (c)合格证持有人选择按照本规则第121.131 条编写手册 时，可以对适用本条(a)款飞机飞行手册的操作程序部分进行 修改和对性能数据的编排形式进行调整，但经修改的操作程 序和性能数据编排形式应当被局方批准。 (d)合格证持有人应当制定并执行适用的管理程序， 以保 证满足本条(a)、(b)款的手册现行有效。 H 章 飞机的要求',
#  'file2_47_第 121.151 条': '飞机的基本要求 (a)除本条(c)款规定外， 合格证持有人运行的飞机应当符 合下列要求： (1)是在中华人民共和国登记的民用飞机， 并携带现行有 效的适航证、国籍登记证、无线电电台执照和噪声合格审定 的证明文件。噪声合格审定证明文件可以载于本规则第 121.137 条要求的飞机飞行手册中。在国际运行时，该证明 文件必须包括一份英文译文； (2)处于适航状态并符合涉及民航管理的规章适用的适 航要求，包括与标识和设备有关的要求。 (b)合格证持有人可以使用经批准的重量与平衡控制系 统来符合适用的适航要求和运行限制，该重量与平衡控制系 统可以以平均的、假定的或者估算的重量为基础。 (c)合格证持有人可以租用不含机组人员的国际民用航 空公约缔约国所属的某一国家登记的民用飞机实施本规则 运行，但应当符合下列规定： (1)该飞机带有经中国民航局审查认可的原国籍登记国 颁发的适航证和由中国民航局颁发的适航认可证书，以及无 线电电台执照和噪声合格审定的证明文件； (2)合格证持有人已将该飞机的租赁合同副本报局方。',
#  'file2_48_第 121.153 条': '飞机的审定和设备要求 合格证持有人按照本规则运行的飞机应当是型号合格 审定为运输类的飞机，并符合本规则第121.173 条的要求， 否则不得实施本规则运行。',
#  'file2_49_第 121.155 条': '禁止使用单台发动机飞机 合格证持有人不得使用单台发动机的飞机实施本规则 运行。',
#  'file2_50_第 121.157 条': '飞机的航路类型限制 (a)除经依据本规则W 章的规定得到局方批准且满足合 格证持有人运行规范许可的条件下，合格证持有人不得使用 以涡轮发动机为动力的飞机实施以下运行： (1)延程运行(EDTO)； (2)在北极区域内的运行； (3)在南极区域内的运行。 (b)合格证持有人用于延伸跨水运行的陆上飞机， 应当是 按照《运输类飞机适航标准》(CCAR-25)中的水上迫降规定 审定合格或者被批准为适合于水上迫降的飞机。',
#  'file2_51_第 121.159 条': '飞机的运行验证试飞 (a)合格证持有人使用以前未在公共航空运输运行中使 用过的飞机，应当完成局方认可的至少100 小时的运行验证 试飞，包括相当数量的进入航路机场的飞行。在运行验证试 飞过程中，如果局方认为试飞已达到令人满意的熟练水平， 则局方可以减少验证试飞时间。上述运行验证试飞至少应当 有10 小时在夜间完成。 (b)除经局方特殊批准外， 合格证持有人首次使用曾在公 共航空运输运行中使用过的某一型号飞机，或者使用在设计 上做了实质性更改的某一型号飞机，则在拟使用该飞机实施 运行之前，应当完成经局方认可的至少25 小时的运行验证 试飞，包括相当数量的进入航路机场的飞行。 (c)本条(b)款所述飞机在设计上进行了实质性更改是指 下列情形之一： (1)整套动力装置的型号与飞机合格审定时所装动力装 置的型号不相类似； (2)对飞机或者其部件进行了实质上影响其飞行特性的 更改。 (d)除了实施试飞所需的人员和局方指定的人员之外， 合 格证持有人不得在运行验证试飞的飞机上携带旅客。经局方 批准，运行验证试飞的飞机可以携带邮件、快递或者其他货 物。',
#  'file2_52_第 121.161 条': '应急撤离程序的演示 (a)合格证持有人应当依照本规则附件C《本规则第 121.161 条规定的应急撤离程序演示准则》(a)款规定进行应 急撤离程序的实际演示，证明在载客飞行中所用的旅客座位 数大于44 座的每个型号的飞机，能够使包括机组成员在内 的满载量乘员在90 秒(含)以内撤离飞机。但是，如果该型号 飞机已被证明符合本规则附件C(a)款规定或者适用的型号合 格审定标准，可以不实施实际的演示。 (b)使用旅客座位数大于44 座的飞机实施载客运行的合 格证持有人，有下列情形之一的，应当按照本条(c)款进行应 急撤离程序的部分演示： (1)该合格证持有人新引进的某型号飞机投入载客飞行 并且该合格证持有人没有按照本条(a)款实施实际演示； (2)本规则第121.391 条所要求的客舱乘务员的人数、位 置或者其应急撤离职责、程序发生改变； (3)应急出口的数量、位置、型号或者供撤离用的应急出 口开启机构的型号发生改变。 (c)在实施本条(b)款要求的部分演示时， 合格证持有人应 当遵守下列规定： (1)实施不要求旅客参加但要在局方观察下进行的演示， 以验证其机组成员应急生存训练和应急撤离程序的有效性。 在这种演示中，该型号飞机的客舱乘务员，应当使用该合格 证持有人的航线操作程序，按照本规则第121.397 条规定的 应急撤离职责，打开50％所要求的地板高度的应急出口和 50％所要求的非地板高度的应急出口， 并放下50％的应急出 口滑梯。这些应急出口和滑梯由局方选定，并且应当在15 秒钟内准备就绪以供使用； (2)在实施这种演示之前， 向负责监督其运行的民航地区 管理局提出申请； (3)在这种演示中使用的客舱乘务员， 由局方从已经完成 合格证持有人经局方批准的该型号飞机训练大纲的训练并 已通过应急设备和应急程序考试的客舱乘务员中随机挑选； (4)在开始实施该型号飞机的运行之前， 向负责监督其运 行的民航地区管理局提出申请并获得批准。 (d)每个使用或者计划使用一架或者多架陆上飞机作延 伸跨水运行或者按照要求配备相应应急设备的合格证持有 人，应当按照本规则附件C(b)款进行模拟水上迫降，证明其 能有效地完成水上迫降程序。 (e)对于已经由其他合格证持有人进行过本条(d)款规定 的模拟水上迫降的那种型号飞机，如果每个救生筏都从其存 放处取下，其中一个救生筏被投放并充气或者一个滑梯救生 筏被充气，并且指定负责该充气救生筏或者滑梯救生筏的机 组成员表演并说明了每项必需应急设备的使用，则认为已经 符合本规则附件C(b)款第(2)项、(b)款第(4)项和(b)款第(5)项 的要求。前述待充气的救生筏或者滑梯救生筏由局方选定。 I 章 飞机性能使用限制',
#  'file2_53_第 121.171 条': '用语定义 本章中的用语按照下述定义： (a)可用着陆距离(LDA)：是指公布的可用并适于飞机着 陆的跑道长度。 (b)飞行轨迹(flight path)：是指飞机在三维空间中的飞行 路线。 (c)航迹(track)：是指飞机飞行轨迹在地球表面上的水平 投影。',
#  'file2_54_第 121.173 条': '概则 (a)使用涡轮发动机驱动的飞机的合格证持有人应当遵 守本规则第121.189 条至第121.197 条的规定。 (b)合格证持有人应当使用飞机飞行手册中的性能数据 来确定是否符合本规则第121.189 条至第121.197 条的规定。 当涉及的条件与这些性能数据所依据的条件不同时，如果内 插法或者计算法所得结果在实质上与直接试验的结果同样 准确，则可以用内插法或者通过计算具体变量变化的影响来 确定是否符合规定。合格证持有人在确定是否符合本规则第 121.189条至第121.197条的规定时还应当考虑到所用航图的 精度。 (c)如果在特殊的环境条件下遵守某些规定对于安全已 无必要，局方可以在运行规范中批准偏离本章的这些要求。',
#  'file2_55_第 121.189 条': '涡轮发动机驱动的飞机的起飞限制 (a)涡轮发动机驱动的飞机不得以大于该飞机飞行手册 中对应于该机场气压高度和起飞时环境温度所确定的重量 起飞。 (b)涡轮发动机驱动的运输类飞机不得以大于该飞机飞 行手册中规定的重量起飞，该重量应当保证飞机符合下列各 项要求： (1)加速停止距离不得超过跑道长度加上停止道的长度； (2)起飞距离不得超过跑道长度加上净空道长度， 且净空 道长度不得大于跑道长度的一半； (3)起飞滑跑距离不得大于跑道长度。 (c)涡轮发动机驱动的飞机不得以大于该飞机飞行手册 中所确定的某个重量起飞，在该重量下，预定净起飞飞行轨 迹以10.7 米(35 英尺)的余度超越所有障碍物， 或者能以一个 特定距离侧向避开障碍物。该特定距离的值为下列两目中规 定值的较小值： (1)90 米(300 英尺)＋0.125D，其中D 是指飞机离可用起 飞距离末端的距离值； (2)对于目视飞行规则飞行， 预定航迹的航向变化小于15 度时，为300 米，预定航迹的航向变化大于15 度时，为600 米；对于仪表飞行规则飞行，预定航迹的航向变化小于15 度时，为600 米，预定航迹的航向变化大于15 度时，为900 米。 (d)在依据本条(a)款至(c)款确定最大重量、 最小距离和飞 行轨迹时，应当对拟用的跑道、机场的标高、有效跑道坡度 和起飞时的环境温度、风的分量进行修正。 (e)就本条而言， 假定飞机在到达15.2 米(50 英尺)高度(按 照飞机飞行手册中起飞飞行轨迹或者净起飞飞行轨迹数据 中的适用者)之前无坡度。此后，在120 米(400 英尺)高度以 下，飞机转弯坡度不超过15 度；在120 米(400 英尺)高度以 上，飞机转弯坡度不超过25 度。 (f)就本条而言， “起飞距离”“起飞滑跑距离”“净起飞飞行 轨迹”和“起飞飞行轨迹”等术语， 与对该飞机进行型号合格审 定的规章中所规定的术语具有相同的含义。',
#  'file2_56_第 121.191 条': '涡轮发动机驱动的飞机的航路限制—— 一台发动机不工作 (a)涡轮发动机驱动的飞机不得超过某一重量起飞，在该 重量下，考虑到正常的燃油、滑油消耗和航路上预计的环境 温度，根据经批准的该飞机飞行手册确定的一台发动机不工 作时的航路净飞行轨迹数据应当能够符合下列两项要求之 一： (1)在预定航迹两侧各25 公里(13.5 海里)范围内的所有 地形和障碍物上空至少300 米(1,000 英尺)的高度上有正梯 度，并且，在发动机失效后飞机要着陆的机场上空450 米 (1,500 英尺)的高度上有正梯度； (2)净飞行轨迹允许飞机由巡航高度继续飞到可以按照 本规则第121.197 条要求进行着陆的机场，能以至少600 米 (2,000 英尺)的余度垂直超越预定航迹两侧各25 公里(13.5 海 里)范围内所有地形和障碍物， 并且在发动机失效后飞机要着 陆的机场上空450 米(1,500 英尺)的高度上有正梯度。 (b)就本条(a)款第(2)项而言，假定： (1)发动机在航路上最临界的一点失效； (2)飞机在发动机失效点之后飞越临界障碍物， 该点应当 能够使用有效的方式定位； (3)使用经批准的方法考虑了不利的风的影响； (4)如果合格证持有人证明，机组人员进行了恰当的训 练，并且采取了其他安全措施，能保证程序的安全性，则允 许应急放油； (5)在签派或者放行单中指定了备降机场， 且该备降机场 符合规定的最低气象条件； (6)发动机失效后燃油和滑油的消耗与飞机飞行手册中 经批准的净飞行轨迹数据所给定的消耗相同。',
#  'file2_57_第 121.193 条': '三台或者三台以上涡轮发动机驱动的飞 机的航路限制——两台发动机不工作 三台或者三台以上涡轮发动机驱动的飞机沿预定航路 运行时，应当符合下列两款要求之一： (a)预定航迹上任何一点到符合本规则第121.197 条要求 的机场的飞行时间不超过所有发动机以巡航功率工作飞行 90 分钟。 (b)根据飞机飞行手册中航路上两台发动机不工作的净 飞行轨迹数据，其重量允许该飞机从假定两台发动机同时失 效的地点，飞到符合本规则第121.197 条要求的某一机场。 在这段飞行中，考虑到沿该航路的预计环境温度，其净飞行 轨迹在垂直方向上至少高出预定航迹两侧各25 公里(13.5 海 里)范围内所有地形和障碍物600 米(2,000 英尺)。就本款而 言，假定： (1)两台发动机在航路上最临界的地点失效； (2)这些发动机失效后在预定着陆的机场正上空450 米 (1,500 英尺)处，该净飞行轨迹具有正梯度； (3)如果合格证持有人证明，机组人员进行了恰当的训 练，并且采取了其他预防措施，能保证程序的安全性，则可 以批准应急放油； (4)在两台发动机失效的那一点， 该飞机重量包含有足够 的燃油，使其能继续飞到该机场正上空至少450 米(1,500 英 尺)的高度，此后还能以巡航功率或者推力飞行15 分钟； (5)发动机失效后， 燃油和滑油的消耗与飞机飞行手册中 净飞行轨迹数据所给定的消耗相同。',
#  'file2_58_第 121.195 条': '涡轮发动机驱动的飞机的着陆限制—— 目的地机场 (a)涡轮发动机驱动的飞机起飞前， 应当在考虑到至目的 地机场或者备降机场飞行中正常的燃油和滑油消耗后，使飞 机到达时的重量不得超过该飞机飞行手册中对该目的地机 场或者备降机场的气压高度以及着陆时预计的环境温度所 确定的着陆重量。 (b)除本条(c)、(d)、(e)款规定外，涡轮发动机驱动的飞 机起飞前，应当在考虑到飞行中正常的燃油和滑油消耗后， 使该飞机到达目的地时的重量，根据飞机飞行手册中对该目 的地机场的气压高度和预计在着陆时当地风的情况所规定 的着陆距离，允许其在预定的目的地机场的跑道上，在可用 着陆距离(LDA)的60％以内作全停着陆。为确定在目的地机 场的允许着陆重量，假定： (1)飞机在最有利的跑道和方向、静风条件下着陆； (2)考虑到可能的风速、风向和该飞机的地面操纵特性， 以及考虑到诸如着陆助航设备和地形等其他条件，飞机在最 适宜的跑道上着陆。 (c)对于不能符合本条(b)款第(2)项的要求而被禁止起飞 的涡轮螺旋桨驱动的飞机，如果指定了备降机场，除允许飞 机在备降机场可用着陆距离(LDA)的70％以内完成全停着陆 外，该备降机场符合本条所有其他要求，则可以允许该飞机 起飞。 (d)对于涡轮喷气飞机， 在有关的气象报告和预报表明目 的地机场跑道在预计着陆时刻可能是湿的时，该目的地机场 跑道的可用着陆距离(LDA)应当至少为本条(b)款所要求的跑 道长度的115％，否则，该飞机不得起飞。如果在湿跑道上 的实际着陆技术证明，对特定型号的飞机，已经批准了某一 较短但绝不小于本条(b)款要求的着陆距离， 并且已经载入飞 机飞行手册，则可以按照手册的要求执行。 (e)对于涡轮喷气飞机， 在有关的气象报告和预报表明目 的地机场跑道在预计着陆时刻可能是污染的时，该目的地机 场的可用跑道长度应当至少为以下距离中的较大者： 本条(b) 款所要求的跑道长度的115%，以及根据认可的污染跑道实 际着陆距离数据确定的着陆距离的115%，否则，该飞机不 得起飞。如果上述污染跑道的道面已经进行了特殊处理，而 且实际着陆技术证明，对特定型号的飞机，已经批准了某一 较短但不小于本条(b)款要求的着陆距离， 并且已经载入飞机 飞行手册，则可以按照手册的要求执行。 (f)由于不能符合本条(b)款第(2)项而被禁止起飞的涡轮 喷气动力的飞机， 如果指定了符合本条(b)款所有要求的备降 机场，则可以起飞。',
#  'file2_59_第 121.197 条': '涡轮发动机驱动的飞机的着陆限制—— 备降机场 在涡轮发动机驱动的飞机的签派或者放行单中列为备 降机场的机场，应当能使该飞机在到达该备降机场时以根据 本规则第121.195 条(b)款规定的假定条件预计的重量，在跑 道可用着陆距离(LDA)的70％(涡轮螺旋桨动力飞机)或者 60％(涡轮喷气动力飞机)以内完成全停着陆。对于本规则第 121.637 条所规定的起飞备降机场，在确定到达时的预计重 量时， 除正常的燃油和滑油消耗之外， 可以考虑应急放油量。 J 章 特殊适航要求',
#  'file2_60_第 121.211 条': '概则 合格证持有人的飞机除满足相应型号合格审定要求外， 还应当符合本章的特殊适航要求。',
#  'file2_61_第 121.213 条': '旅客座椅间距 (a)对于2006 年7 月1 日后加入合格证持有人运行规范 的任何载客运行的飞机应当满足本条(b)款的要求。 (b)合格证持有人运行的任何载客运行的飞机， 其座椅间 距应当满足下列要求： (1)任何座椅椅背与前面座椅椅背或者其他的固定结构 之间的距离不得小于660 毫米(26 英寸)； (2)任何座椅与前面的座椅或者其他的固定结构之间的 距离不得小于178 毫米(7 英寸)； (3)前后排座椅之间或者座椅与前面的任何固定结构之 间的垂直投影距离不得小于76 毫米(3 英寸)。 (c)对于本条(b)款要求的距离的测量应当满足下列要求： (1)对于(b)款第(1)项要求的距离，以椅背腰垫(没有被压 缩)76 毫米(3 英寸)高处为原点，在距地板635 毫米(25 英寸) 以下的整个座椅宽度范围内测量与前面座椅或者其他固定 结构之间的水平方向和垂直方向的距离(如下图所示)； (2)对于(b)款第(2)项要求的距离，以椅垫和扶手最前端 为原点测量水平方向和垂直方向的距离(如下图所示)； (3)对于(b)款第(3)项要求的距离，测量椅垫和扶手最前 端的投影与前面座椅或者固定结构的最后端的投影之间的 距离(如下图所示)。 (d)对于有杂志袋和小桌板的座椅， 在所有测量时杂志袋 应当正常装载有关的客舱安全说明、清洁袋和合格证持有人 提供的机上读物， 小桌板应当在正常的收起位置(起飞和着陆 位置)。 (e)所有测量应当在座椅调直和扶手放下的状态(起飞和 着陆状态)下测量。 座椅间距测量方法示意图',
#  'file2_62_第 121.215 条': '在客舱内装货 (a)除本条(b)款或者(c)款规定之外， 按照本规则运行的合 格证持有人不得在飞机客舱内运载货物。 (b)如果货物在经批准的货箱之内且货箱满足下列要求， 货物可以装在客舱内任一位置： (1)货箱应当能承受适用于装有该货箱的飞机的旅客座 椅载荷系数和应急着陆条件1.15 倍的过载， 计算时要用货箱 重量和货箱中可以装载货物的最大重量的总重量； (2)货箱上应当清晰地标出该货箱准许装载的货物的最 大重量以及为保证货箱内正确的重量分布而必需的任何说 明； (3)货箱施加的载荷不得超过地板或者飞机其他结构件 的载荷限制； (4)货箱应当固定在座椅滑轨或者飞机地板结构件上， 其 固定点应当能承受适用于货箱安装于其上的飞机的旅客座 椅的载荷系数和应急着陆情况一定倍数的过载，该倍数为 1.15 或者为该飞机规定的座椅固定系数，二者中取较大者， 计算时要用货箱重量和在其中可能装载货物的最大重量的 总重量； (5)货箱不得装于妨碍通达或者使用任何需要的应急出 口或者客舱通道之处； (6)货箱应当为全封闭式的， 而且应当用至少为阻燃的材 料制成； (7)货箱内应当有适当的安全防护装置以防止货物在应 急着陆情况下发生移动； (8)货箱不得安装在会遮挡任一旅客观察“系好安全带” 标牌、“请勿吸烟”标牌或者任何所需要的出口标记的位置， 除非备有辅助标记或者其他经批准的可以给旅客适当通告 的措施。 (c)只要在《运输类飞机适航标准》(CCAR-25)第25.561 条(b)款第(3)项规定的载荷系数所对应的过载条件下能将货 物束缚住，并且按照下列要求装载，则货物可以装于任一客 舱内的隔框或者隔板后面： (1)货物用安全带或者其他具有足够强度的系留索适当 紧固；使货物在所有可以预计的正常飞行和地面情况下不可 能移动； (2)其包装或者覆盖方式能避免对旅客和客舱内人员可 能的伤害； (3)不会对座椅或者地板结构加上超过这些部件载荷限 制的任何载荷； (4)其位置不妨碍通达或者使用任何需要的应急出口、 正 常出口或者客舱内的通道； (5)其位置不遮拦任一旅客观察“系好安全带”标牌、“请 勿吸烟”标牌或者所需要的出口标记的视线， 除非备有辅助标 记或者其他经批准的可以给旅客适当通告的措施。',
#  'file2_63_第 121.217 条': '在货舱内装货 当货物装在其设计要求机组从外部进入其中以扑灭飞 行中可能发生的任何火情的货舱内时，货物的装载应当使机 组人员能携带手提灭火器有效地到达舱内所有部位。 K 章 仪表和设备要求',
#  'file2_64_第 121.301 条': '概则 (a)除具体指明适用于特定运行的条款外， 本规则关于仪 表和设备的要求适用于按照本规则实施的所有运行。 (b)本规则第121.305 条至第121.360 条所要求的仪表和 设备，应当按照适用的适航要求进行批准和安装。 (c)每个空速指示器应当以公里/小时或者海里／小时为 单位校准，并且飞机飞行手册和有关标牌中的每个空速限制 和有关资料中的空速应当相应地以公里/小时或者海里／小 时表示。 (d)除经局方批准外， 2005 年7 月1 日后首次投入运行的 飞机应当装备有以米为单位显示的高度表。如果该飞机需在 以英尺为单位确定飞行高度的国家或者地区运行，则应当同 时装备有以英尺为单位显示的高度表。 (e)除本规则第121.645 条(b)款和第121.647 条规定外， 只有当下列仪表和设备处于工作状态，方可以使飞机起飞： (1)为符合对该飞机进行型号合格审定的适航要求所要 求的仪表和设备； (2)本规则第121.305 条至第121.319 条和第121.359 条、 第121.360 条以及第121.743 条中规定的适用于所有运行的 仪表与设备，以及本规则第121.323 条至第121.351 条中规 定的适用于不同运行类型的仪表与设备，而这些仪表与设备 在本款第(1)项未作出要求。',
#  'file2_65_第 121.305 条': '飞机仪表和设备 按照本规则运行的飞机应当装备下列飞行和导航的仪 表与设备： (a)一个空速指示系统， 带有加温空速管或者可以防止由 于结冰而失效的等效装置。对于以马赫数为单位来表示速度 限制的飞机，则还应至少装有一个马赫数指示器。 (b)一个灵敏高度表，带有以百帕斯卡(毫巴)为单位的校 正装置，并且该装置对于飞行中可能遇到的气压可以进行修 正。 (c)一个带指针和/或数字式显示的精确指示小时、 分和秒 的时钟(或者经批准的等效装置)。 (d)一个大气静温指示器。 (e)一个陀螺坡度与俯仰指示器(地平仪)。 (f)一个组合有侧滑指示器的陀螺转弯速率指示器，但在 按照本条(k)款装有第三套姿态仪表系统(可以在360°俯仰和 滚转飞行姿态中使用)时，只需要侧滑指示器。 (g)一个陀螺航向指示器(航向陀螺或者等效仪表)。 (h)一个磁罗盘。 (i)一个垂直速度指示器(升降率指示器)。 (j)当运行要求有两名驾驶员时，第二名驾驶员位置处应 具有以下参数的显示： (1)气压高度； (2)指示空速； (3)垂直速度； (4)转弯和侧滑； (5)姿态； (6)航向。 (k)除局方批准的某些涡桨飞机外，在涡轮动力飞机上， 除在每位驾驶员工作位置上各有一个陀螺坡度与俯仰指示 器(地平仪)可以供使用之外，还应当配备满足下列要求的第 三套陀螺坡度与俯仰指示器(地平仪)： (1)由独立于飞机正常发电系统的应急备用电源供电； (2)在正常发电系统全部失效之后至少能继续可靠地工 作30 分钟； (3)不依赖任何其他姿态指示系统而独立工作； (4)在正常发电系统全部失效之后无需选择就能工作； (5)位于仪表板局方认可的位置上， 使得任一驾驶员在其 工作位置上都能清楚地看见并使用； (6)在使用的所有阶段均有适当照明。 (l)对于本条要求的飞行和导航设备： (1)可以通过仪表组合或者中央飞行系统或者在电子显 示器上参数的组合来满足这些条款的各项要求，但要求每一 必需驾驶员能够获得的信息不少于本条所规定的仪表及相 应设备提供的信息； (2)可以使用其他等效符合性方法来满足这些条款的设 备要求，但要求在飞机型号审定批准过程中已表明该方法具 有等效的安全水平。',
#  'file2_66_第 121.307 条': '发动机仪表 除局方对涡轮发动机另有规定外，按照本规则实施运行 的飞机应当按照下列要求安装发动机仪表： (a)所有涡轮发动机。 (1)每台发动机一个燃油压力警告装置， 或者所有发动机 一个总警告装置，并有分离各单独警告的措施； (2)每个燃油箱一个燃油油量表； (3)每个滑油箱一个滑油油量指示器； (4)每台发动机每个独立的滑油压力系统一个滑油压力 表； (5)每台发动机一个滑油压力警告装置， 或为所有发动机 提供一个主警告并带有将单个警告从主警告中分离开的手 段； (6)每台发动机一个滑油温度表； (7)能够提供视觉和听觉警告的火警装置； (8)每台发动机一个燃气温度表； (9)每台发动机一个燃油流量表； (10)每台发动机一个转速表(指示有转速限制转子的转 速)； (11)每台发动机一个动力装置防冰系统功能指示器。 (b)涡轮喷气发动机。除本条(a)款要求的动力装置仪表 外，还需装有下列动力装置仪表： (1)一个向飞行机组指示推力或者与推力直接有关的参 数的指示器。其指示必须以对推力或者该参数的直接测量为 依据。该指示器必须能指示发动机故障、损坏或者性能降低 所造成的推力变化； (2)当反推装置处于下列状态时， 位置指示装置向飞行机 组给出指示： (i)未处在选定位置； (ii)处在反推位置，对每台使用了反推装置的发动机。 (3)一个指示转子系统不平衡状态的指示器。 (c)涡轮螺旋桨发动机。 除本条(a)款要求的动力装置仪表 外，还需装有下列动力装置仪表： (1)每台发动机一个扭矩表； (2)每具螺旋桨一个位置指示器， 在螺旋桨桨叶角小于飞 行低距位置时向飞行机组发出指示。',
#  'file2_67_第 121.308 条': '厕所防火 (a)除经局方批准外，按照本规则运行的载客飞机应当在 每个厕所装备烟雾探测系统或者等效装置，并能在驾驶舱提 供警告灯光，或者在客舱中提供易于客舱机组发现的警告灯 光或者音响警告。 (b)除经局方批准外， 按照本规则运行的载客飞机应当在 每个厕所每个处置纸制品或者废物的容器内装备内置式固 定灭火器。该固定灭火器应当设计成当容器内失火时，能自 动向容器内喷射灭火剂。',
#  'file2_68_第 121.309 条': '应急设备 (a)只有装备本条和本规则第121.310 条所列的应急设备 的飞机，方可以按照本规则实施运行。 (b)本条和本规则第121.310 条和第121.339 条所列的每 项应急设备和漂浮设备应当符合下列要求： (1)依照运行规范中规定的检验周期予以定期检验， 以确 保其处于持续可用和立即工作的状态，执行其预定的应急用 途； (2)易于机组成员取用， 位于客舱的设备应当易于旅客取 用； (3)具有清楚的标识和标记，指明其使用方法，旅客取用 的设备文字说明应当至少有中文； (4)当装在某一舱室或者某一容器中时， 在该舱室或者容 器上易于观察的地方至少用中文标明其所装物品以及上次 检验的日期。 (c)在驾驶舱、 客舱、 货舱、 厨房内， 应当按照下列规定， 装备经批准型号的手提灭火器： (1)灭火剂的型号和装量应当适用于该舱室可能发生的 失火类型，并且对于客舱，应当设计成使有毒气体聚积的危 险性减到最小。 对于2018 年12 月31 日(含)或者其后首次颁 发单机适航证的飞机上配备的手提灭火器，所用各类灭火剂 都应当符合与臭氧层保护相关的环保要求，包括使用等效环 保灭火剂替代对本款第(7)项要求的Halon 1211(溴氯二氟甲 烷)灭火剂； (2)货舱。 对于飞行中机组成员能够进入的E 级货舱， 应 当配备至少一个手提灭火器，并放置于方便取用的地方； (3)厨房隔舱。对于位于客舱、货舱或者驾驶舱之外隔舱 内的厨房，应当在每个厨房内至少装备一个便于取用的手提 灭火器； (4)驾驶舱。 驾驶舱内应当至少装备一个便于飞行机组使 用的手提灭火器； (5)客舱。 在客舱使用的手提灭火器应当放置于方便的位 置上。在要求配备两个或者两个以上手提灭火器时，这些设 备应当均匀地分布于每个客舱内。应当按照下列要求配备手 提灭火器： (i)对于旅客座位数7 至30 的飞机，至少配备一个； (ii)对于旅客座位数31 至60 的飞机，至少配备两个； (iii)对于旅客座位数60 以上的飞机，至少配备下列数量 的手提灭火器： 旅客座位数 手提灭火器的最小数量 61 至200 座 3 个 201 至300 座 4 个 301 至400 座 5 个 401 至500 座 6 个 501 至600 座 7 个 601 座或者以上 8 个 (6)尽管本条(c)款第(5)项要求手提灭火器均匀分布， 如果 在客舱中有厨房，应当至少有一个手提灭火器位于方便之处 并易于在厨房中取用； (7)载客飞机所要求配备的手提灭火器中至少2个应当装 Halon 1211(溴氯二氟甲烷)或者等效的灭火剂。 客舱中应当至 少有一个这样的灭火器。 (d)载运旅客的飞机上应当配备本规则第121.743 条要求 的应急医疗设备。 (e)应急斧。每架飞机应当配备至少一把应急斧。 (f)扩音器。每架载客飞机应当配有电池供电的便携式扩 音器，放在负责指挥应急撤离的机组成员方便取用的地方， 其配备数量和位置符合下列规定： (1)在旅客座位数61 至99(含)的飞机上配备一个，安放 在客舱后部从客舱乘务员座位易于取用处。但是，如果局方 认为安放在其他位置可能对应急情况下人员的撤离更为适 合，可以批准偏离本款的要求； (2)在旅客座位数大于99的飞机客舱内配备两个扩音器， 一个安放在前部，另一个安放在后部，并且易于从客舱乘务 员座位处取用。',
#  'file2_69_第 121.310 条': '附加应急设备 (a)应急撤离设施。当飞机停放于地面且起落架放下时， 应急出口(机翼上方的应急出口除外)距地面高度超过183 厘 米(6 英尺)的每一载客陆上飞机， 应当有经批准的可以帮助机 上人员撤到地面的设施。用于地板高度应急出口的这种辅助 设施应当符合《运输类飞机适航标准》(CCAR-25)第25.810 条的相应适航要求。能自动放出的辅助设施在滑行、起飞和 着陆期间应当处于待命状态。但是，如果局方认为这个出口 的设计使得满足这些要求不切实际，则局方可以批准偏离关 于自动放出的要求，但该辅助设施在放出时应能自动展开， 并按照本规则第121.161 条(a)款的规定对所要求的应急出口 进行应急撤离演示。 (b)机内应急出口标记。每架载客飞机应当符合下列要 求： (1)每个旅客应急出口，其通达方式及开启方法，应当有 明显易懂的标记。每个旅客应急出口本身及其位置应当能从 等同于客舱宽度的距离上认清。每个旅客应急出口的所在位 置应当用机上人员能看到的沿客舱主通道的标志指明，下述 部位应当有位置指示标志： (i)每个翼上旅客应急出口附近的通道上方，如通道高度 较低，可以放在顶棚合适位置上； (ii)在紧靠每一地板高度的旅客应急出口处， 如果一个位 置指示标志可以清楚标明两个应急出口的位置，则一个位置 指示标志可以用于两个应急出口位置的指示； (iii)在客舱每个挡住前后视线的隔框或者隔板上，用以 指示被其挡住的应急出口，若这样做不可能时，可以将标志 置于其他适当的位置。 (2)每个旅客应急出口标记和每个位置标示应当符合 《运 输类飞机适航标准》 (CCAR-25)第25.811 条的相应适航要求。 在这些飞机上，如果任一标志的发光度(亮度)降低到250 微 朗伯之下，则不可以继续使用。 (c)机内应急出口标志的照明。 每架载客飞机应当具有独 立于主照明系统的应急照明系统。但是，如果应急照明系统 的供电电源独立于主照明系统的供电电源，则客舱一般照明 的光源可以为应急照明系统和主照明系统二者所共用。应急 照明系统应当： (1)照亮每一旅客出口标志和位置标志； (2)在客舱内提供足够的一般照明； (3)具有贴近地板的应急逃生通道标志，该标志符合《运 输类飞机适航标准》(CCAR-25)第25.812 条相应适航要求或 者经局方批准的其他等效要求。 (d)应急灯的工作。除按照《运输类飞机适航标准》 (CCAR-25)第25.812 条的相应适航要求设置的仅限于一个辅 助装置使用、独立于飞机主应急照明系统、在该辅助装置放 下时能自动接通的那些灯外， 本条(c)款、(h)款所要求的每个 灯均应当满足下列要求： (1)每个灯应当： (i)能从飞行机组工作位置和客舱中客舱乘务员正常座位 易于接近处的两个地方进行人工控制； (ii)有防止人工控制装置误操作的装置； (iii)当在任一机组成员工作位置上使其处于接通或者待 命状态时，一旦飞机正常的供电电源中断时，它将保持燃亮 或者开始燃亮。 (2)在滑行、起飞和着陆期间，每个灯均应当处于待命或 者接通状态。在证明与本款相符时，无需考虑机身的横向垂 直分隔； (3)每个灯应当在应急着陆后的临界环境条件下， 提供所 要求照度水平的照明至少达10 分钟； (4)每个灯应当有驾驶舱内的控制装置，该装置具有“接 通”“断开”和“待命”三个位置。 (e)应急出口操纵手柄。 每个旅客应急出口操纵手柄的位 置和出口的开启说明应当符合《运输类飞机适航标准》 (CCAR-25)第25.811 条的相应适航要求，除非局方引用了满 足本款的其他要求。当任一操作手柄或者操作手柄外罩的发 光度(亮度)降至100 微朗伯之下时，该手柄或者手柄外罩不 得继续使用。 (f)应急出口的通道。每架载客飞机应当按照下列要求设 置至应急出口的通道： (1)各旅客区域之间的或者通向Ⅰ型或者Ⅱ型应急出口 的每条旅客通道应当无障碍物，其宽度不少于508 毫米(20 英寸)； (2)靠近每个Ⅰ型或者Ⅱ型应急出口处， 应当有足够的空 间以使机组成员能够帮助旅客撤离飞机，同时又满足本款第 (1)项所要求的通道无障碍宽度； (3)应当有从主通道至每一III 型和IV 型应急出口的通 道。从主通道至这些出口的通道应当不受座椅、卧铺或者其 他可能减小该出口效用的障碍物的阻碍。另外，该通道应当 符合《运输类飞机适航标准》(CCAR-25)第25.813 条的相应 适航要求，除非局方引用了满足本款的其他要求； (4)如果从客舱中任一座位到达任何要求的应急出口需 要经过客舱间的通道，则该通道应当无障碍，但是可以使用 不影响自由通行的布帘； (5)不得在客舱间的任何分隔板上设置门； (6)如果从任一旅客座位到达要求的应急出口需要经过 把客舱和其他区域隔开的门，则此门应当有装置将其闩在开 启位置，并且在每次起飞和着陆期间，这个门应当闩在开启 位置。此闩锁装置应当能够承受当该门相对于周围结构受到 一个《运输类飞机适航标准》(CCAR-25)第25.561 条所述的 极限惯性力时对其施加的载荷。 (g)机外出口标记。 每个旅客应急出口和从外面开启这个 出口的装置应当在飞机外部予以标记，机身侧面应当有框出 每一旅客应急出口的5 厘米(2 英寸)宽的色带。 每一外部标记 (包括这种色带)的颜色应当与周围机身表面有明显的对比而 易于区别。这些标记应当符合下列要求： (1)如果较深颜色的反射率等于或者小于15％， 则较浅颜 色的反射率应当至少为45％。 反射率是物体反射的光通量与 其接收的光通量之比； (2)如果较深颜色的反射率大于15％， 则其反射率与较浅 颜色反射率之差应当至少有30％； (3)不在机身侧面的出口应当有外部开启装置， 并用红色 醒目地标出适用的操作说明，或者，如果背景的颜色使得红 色不醒目，应当用鲜明的铬黄色作标记，并且当这种出口的 开启装置仅位于机身一侧时，应当在另一侧上作同样效果的 标记。 (h)外部应急照明和撤离路线。 (1)每架载客飞机应当装备符合《运输类飞机适航标准》 (CCAR-25)第25.812 条相应适航要求的外部照明设备； (2)每架载客飞机应当装备有符合《运输类飞机适航标 准》(CCAR-25)第25.810 条相应适航要求的防滑撤离路线。 (i)地板高度的出口。 机身侧面高等于或者大于1118 毫米 (44 英寸)、 宽等于或者大于508 毫米(20 英寸)但不到1168 毫 米(46 英寸)的每个地板高度的舱门或者出口(不包括那些不 能由客舱进入的通向货舱或者行李舱的舱门或者出口)、 每个 机身下部出口和每个尾锥出口，应当符合本条关于地板高度 应急出口的要求。但是，如果环境条件使得完全满足这些要 求不切实际，并且偏离这些要求能够达到可以接受的安全水 平，局方可以批准偏离本款的要求。 (j)额外的应急出口。客舱内超过应急出口最少数量要求 外的经批准应急出口，应当符合本条除(f)款第(1)、(2)、(3) 项以外的所有款项的要求，并且应当易于接近。 (k)在每架载客涡轮喷气动力飞机上， 每个机身下部出口 和尾锥出口应当符合下列要求： (1)设计和结构应使其在飞行中不能被打开； (2)在靠近出口开启装置明显位置上设置从762 毫米(30 英寸)的距离上即可以辨读的标牌， 说明此出口的设计和结构 使其在飞行中不能被打开。 (l)手电筒。载客飞机应当装备有从每个客舱乘务员座位 处易于接近的手电筒及其储放装置。 (m)对于按照本规则实施运行并且机身每侧配备了多个 旅客应急出口的飞机，机身同侧位于同层客舱的任何旅客应 急出口与相邻旅客应急出口之间的距离应当不超过18.3 米 (60 英尺)，该距离的测量应当平行于飞机的纵轴线测量两个 应急出口相距最近的出口边缘之间的距离。',
#  'file2_70_第 121.311 条': '座椅、安全带和肩带装置 (a)载客飞机应当装备下列装置： (1)可以供机上每一个2周岁以上人员使用的经批准的座 椅或者卧铺； (2)可以供机上每一个2周岁以上的人员单独使用的经批 准的安全带，但在航路飞行期间，占用一个卧铺的两个人和 占用一个多座座椅或者长座椅的两个人可以共用一条经批 准的安全带。 (b)在飞机于地面移动、起飞和着陆期间，按照本规则运 行的飞机上每一个人均应当在经批准的座椅或者卧铺上就 座，并用单独的安全带适当扣紧。座椅上为该乘员配备的安 全带不得被2 周岁以上的人共用。但是： (1)对于不满2周岁的儿童可以由占有经批准座椅或者卧 铺的成年人抱着； (2)可以乘坐于经局方批准的儿童限制装置内， 该装置可 以是合格证持有人配备的，也可以是儿童父母、监护人携带 的，或者该儿童父母、监护人指定在飞行中照料其安全的护 理人员携带的，但合格证持有人应当确保： (i)儿童限制装置能够被恰当地固定在经批准的前向座椅 或者卧铺上； (ii)儿童能够被恰当地系紧在该限制装置内， 并且其体重 不超过该装置所规定的重量限制； (iii)在飞机起飞、着陆和地面移动期间，不得使用助力 式儿童限制装置、马甲式儿童限制装置、背带式儿童限制装 置和抱膝式儿童限制装置。 (c)如果儿童的父母、监护人或者指定的护理人员请求让 该儿童乘坐他们提供的儿童限制装置，当该儿童持有经批准 座位或者卧铺的机票，或者这种座位或者卧铺能够由合格证 持有人提供给该儿童使用， 并且本条(b)款第(2)项中的要求能 够满足，则该合格证持有人不得拒绝该儿童乘坐飞机。本条 并不阻止合格证持有人提供儿童限制装置，也不阻止合格证 持有人遵循安全操作常规，为儿童限制装置确定最适合的旅 客座椅位置。 (d)每一面向侧方的座椅应当符合《运输类飞机适航标 准》(CCAR-25)第25.785 条的相应适航要求。 (e)除本条(e)款第(1)项和第(2)项规定外，只有每一旅客 座椅的椅背处于竖立位置，合格证持有人方可以使飞机起飞 或者着陆。每个旅客应当遵守机组成员依照本款发出的指 令。 (1)本款不适用于为符合本规则第121.310 条(f)款第(3)项 的要求而让其处于非竖立位置的座椅靠背； (2)本款不适用于根据合格证持有人的手册中规定的程 序，在座位上载有货物或者坐有由于健康方面的原因不能直 坐的人的座椅，但其椅背不得妨碍机上乘员走向通道或者任 一应急出口。 (f)每架飞机应当在驾驶舱每一工作位置上配备有符合 《运输类飞机适航标准》(CCAR-25)第25.785 条的相应适航 要求的组合式安全带和肩带，方可以实施运行。 (g)每个客舱乘务员应当在客舱具有一个符合 《运输类飞 机适航标准》(CCAR-25)第25.785 条的相应适航要求的座椅 (含安全带和肩带)供起飞和着陆时使用。这些要求不适用于 非本规则第121.391 条要求的客舱乘务员乘坐的旅客座椅。 (h)要求装备组合式安全带和肩带装置的座椅上的每个 乘员，在起飞和着陆过程中都应当用这种组合式安全带和肩 带装置将乘员恰当扣紧，但在履行其正常职责需要时，可以 松开肩带。 (i)在每个无人乘坐的座椅上，若装有安全带或者肩带装 置，则应当将其固定好，使其不妨碍机组成员执行任务或者 紧急情况下人员的迅速撤离。 (j)实施载客运行运输类飞机的旅客和客舱机组成员的座 椅要求： (1)合格证持有人引进的按照本规则实施运行的2019 年 1 月1 日以后新制造的飞机，其所安装的旅客和客舱机组成 员的座椅必须满足1990 年7 月18 日颁布实施的《运输类飞 机适航标准》(CCAR-25)第25.562 条或者其后续修订的适用 要求，否则不得投入运行。 (2)自2019 年1 月1 日起，合格证持有人引进的按照本 规则实施运行的非中国登记注册的使用过的飞机，其所安装 的旅客和客舱机组成员的座椅必须满足1990 年7 月18 日颁 布实施的《运输类飞机适航标准》(CCAR-25)第25.562 条或 者其后续修订的适用要求，否则不得投入运行。',
#  'file2_71_第 121.312 条': '座舱内部材料 (a)除局方另行批准外，对于按照本规则运行的飞机，其 每个座舱内的所有内部材料应当符合《运输类飞机适航标 准》(CCAR-25)第25.853 条的相应适航要求。 (b)除飞行机组成员座椅外， 机组或者旅客使用的坐垫应 当符合《运输类飞机适航标准》(CCAR-25)第25.853 条的适 用防火特性要求。',
#  'file2_72_第 121.313 条': '其他设备 飞机只有安装下列设备，方可以实施本规则的运行： (a)如果飞机上装有保护性熔断器， 每种规格保护性熔断 器的备用数量应为该飞机批准的并在合格证持有人手册中 规定的数量。 (b)每个驾驶员工作位置上的风挡雨刷或者等效设备。 (c)符合运输类飞机型号合格审定适航要求的电源和配 电系统，或者在任一电源或者配电系统部件失效时，利用外 部电源，能为所需要的仪表和设备供电的发电和配电系统。 在系统中准许使用公共的元部件，只要局方认为其设计能合 理地防止失效。当使用由发动机驱动的多个电源时，它们应 当分装在各个发动机上。 (d)向必需飞行仪表供电的品质和充裕程度的指示装置。 (e)两个独立的静压系统，与外部大气相通，使得其受气 流变化、湿气或者其他外来物影响最小，且其安装除通气口 外均为气密的。当有装置将仪表从主工作系统转接到备用系 统上时，这一装置里应当具有一个可靠的位置控制器，且应 当予以标记，清楚地指明正在使用的系统。 (f)对于按照本规则运行的飞机，除机组成员外，如果机 上还搭载有其他乘员，则驾驶舱和乘员舱之间应当装有带锁 定装置的门(即驾驶舱门)，该锁定装置应当设计成只能从驾 驶舱内解锁，并且在使用中有效，以防止其他机上乘员未经 驾驶舱内飞行机组成员的同意将门打开，否则只有驾驶舱内 的飞行机组成员才能持有驾驶舱门的钥匙。对于从驾驶舱和 客舱都能进入的机组休息区的飞机，则该区和客舱之间应当 安装有带类似锁定装置的门。 (1)对于最大客座数大于20 人的载客飞机，其驾驶舱门 还应当满足下列要求： (i)机上应急出口的布局应当设计成使机组成员或者旅客 无需通过该舱门就能到达为他们设置的应急出口； (ii)应当有措施使飞行机组成员在该舱门被卡住的情况 下能从驾驶舱直接进入客舱； (iii)合格证持有人应当建立紧急情况下的措施，使得客 舱乘务员在飞行机组失去能力时能够进入驾驶舱。每位飞行 机组成员应当能够从其工作位置处操纵驾驶舱门锁定和解 锁装置，以及任何相关的指示信号或者身份确认系统。 (2)对于最大审定起飞重量超过45,500 千克或者客座数 超过60 人的载客飞机，驾驶舱门还应当符合下列要求： (i)能抵御未经许可人员的暴力入侵和关键部位能够承受 300 焦耳(221.3 英尺磅)的冲击，同时在旋钮和把手处能够承 受1,113 牛顿(250 磅)的拉伸载荷； (ii)能抵御轻型武器火力和爆炸装置的穿透， 符合有关适 航要求规定的标准。 (g)将客舱与设有应急出口设施的其他舱室隔开的每一 扇门应当配备钥匙，所配钥匙应当便于每个机组成员使用。 (h)在通往每一指定的旅客应急出口的每扇门上应有一 块标牌，用以指明在起飞和着陆期间此门应当处于打开状 态。 (i)对于旅客可以进入的舱室，如果舱门有可能被旅客锁 上，则应当为机组配备这些门的开锁装置，以便在紧急情况 下打开这些门。',
#  'file2_73_第 121.314 条': '货舱和行李舱 (a)飞机中每个容积大于5.7 立方米(200 立方英尺)、 符合 《运输类飞机适航标准》 (CCAR-25)第25.857 条定义的C 级 舱，应当有下列任一材料构成的顶棚和侧墙衬板： (1)符合局方要求的玻璃纤维加强树脂； (2)符合《运输类飞机适航标准》(CCAR-25)附录F 要求 的材料； (3)经局方批准的铝衬板。 (b)为符合本条，术语“衬板”包括诸如连结处或者紧固件 这些影响衬板失火安全包容性能的任何设计细节。',
#  'file2_74_第 121.315 条': '驾驶舱检查单 (a)合格证持有人应当为每一型号飞机提供经批准的驾 驶舱检查单。 (b)这些经批准的检查单应当至少包括在起动发动机、 起 飞或者着陆之前，以及在发动机和系统出现了紧急情况时， 飞行机组成员为确保安全应当进行的每一项检查。检查单的 设计应当使飞行机组成员无需依赖于对所要进行检查的项 目的记忆。 (c)经批准的检查单应当放置在每架飞机驾驶舱内方便 飞行机组成员使用的地方，飞行机组在操作飞机时应当遵循 检查单规定的程序。',
#  'file2_75_第 121.316 条': '燃油箱 按照本规则运行的涡轮发动机飞机应当符合《运输类飞 机适航标准》(CCAR-25)第25.963 条的要求。',
#  'file2_76_第 121.317 条': '旅客告示 (a)按照本规则实施运行的飞机应当装备旅客告示信号 和标牌。这些信号装置应当设计成能由机组成员接通或者断 开。 (b)飞机在地面的任何移动，以及每次起飞、着陆和机长 认为必要的其他任何时间，应当接通“系好安全带”信号。 (c)按照本规则运行的载客飞机，应当从每个旅客座位都 能看到至少一个“系好安全带”的明显信号或者标牌。这些信 号或者标牌无需符合本条(a)款的要求。 (d)当“系好安全带”信号亮时，本规则第121.311 条(b)款 要求具有座位的每位旅客，应当系好旅客座椅安全带并保持 系紧状态。 (e)飞机在运行时，应当使“禁止吸烟”的告示信号灯保持 常亮，或者出示一个或者几个符合《运输类飞机适航标准》 (CCAR-25)第25.1541 条要求的“禁止吸烟”的标牌。 若同时使 用灯光信号及标牌，则灯光信号在整个飞行航段上应当保持 常亮。 (f)每一厕所内应当有一个标志或者标牌， 其上标明“严禁 破坏厕所烟雾探测器”。该标志或者标牌无需符合本条(a)款 的要求。 (g)在飞机上的任何人应当遵守下列规定： (1)当“禁止吸烟”信号灯亮时或者“禁止吸烟”标牌出示 时，不得在客舱内吸烟； (2)不得在飞机的厕所内吸烟； (3)不得触动、 损害或者破坏飞机厕所内安装的烟雾探测 器。 (h)当飞机在地面的任何移动，在每次起飞、着陆和机长 认为必要的其他任何时间内，应当接通“禁止吸烟”信号。 (i)每个旅客应当遵守机组成员为符合本条(e)款、 (g)款第 (1)项和(f)款第(2)项要求而发出的指令。',
#  'file2_77_第 121.318 条': '机内广播系统 (a)旅客座位数超过19 的飞机实施载客运行时，应当装 备有符合下列要求的机内广播系统： (1)除手持受话器、耳机、话筒、选择开关和信号发送装 置外，能不依赖于本规则第121.319 条所要求的机组成员机 内通话系统而独立工作； (2)依据《民用航空产品和零部件合格审定规定》 (CCAR-21)的规定获得批准或者认可。 (b)本条(a)款要求的机内广播系统应当符合下列要求： (1)从驾驶舱两个飞行机组成员的每个工作位置上易于 接近并能立即使用； (2)为每个有邻近客舱乘务员座位的地板高度旅客应急 出口配备一个话筒，使在邻近的客舱乘务员座位上就座的客 舱乘务员易于迅速使用。但若出口很接近，就座的客舱乘务 员之间能无困难地口头联络，则一个话筒可以为几个出口所 共用； (3)应当能让每一客舱内便于使用它的位置上的客舱乘 务员，在10 秒钟之内使其工作； (4)在所有旅客座位、厕所、客舱乘务员座位与工作台上 都能听见。 (c)按照本规则实施运行的1995 年12 月18 日后制造的 飞机，还应当符合《运输类飞机适航标准》(CCAR-25)第 25.1423 条的要求。',
#  'file2_78_第 121.319 条': '机组成员机内通话系统 (a)旅客座位数超过19 的飞机应当装备有符合下列要求 的机组成员机内通话系统： (1)除手持受话器、耳机、话筒、选择开关和信号发射装 置外，能不依赖于本规则第121.318 条(a)款所要求的机内广 播系统而独立工作； (2)符合本条(b)款的要求。 (b)本条(a)款所要求的机组成员机内通话系统应当依据 《民用航空产品和零部件合格审定规定》(CCAR-21)的规定 获得批准或者认可，并且应当符合下列要求： (1)应当提供驾驶舱与下列各处的双向通信： (i)每一旅客客舱； (ii)不在主客舱地板高度上的每一厨房。 (2)应当便于在驾驶舱内两个飞行机组成员工作位置中 每一个位置上立即使用； (3)应当便于在每个客舱内至少一个客舱乘务员正常工 作位置上使用； (4)应当能让每一客舱内便于使用它的位置上的客舱乘 务员，在10 秒钟之内使其工作； (5)对于涡轮喷气动力的飞机： (i)应当便于从足够数量的客舱乘务员工作位置上使用， 使得从一个或者几个这样装备的工作位置上可以看到每一 客舱内所有地板高度的应急出口(或者当出口在厨房内时看 到通向这些出口的进口通道)； (ii)应当具有一个包括音响或者目视信号的警戒系统， 用 于飞行机组人员呼叫客舱乘务员和客舱乘务员呼叫飞行机 组成员； (iii)本款第(5)项第(ii)目所要求的警戒系统应当能使接收 到呼叫的人确定是正常的呼叫还是紧急的呼叫； (iv)当飞机停放于地面时， 它应当有装置使地面人员和驾 驶舱内至少两个飞行机组成员中的任一人之间进行双向通 话。供地面人员使用的机内通话系统位置应当使得从飞机内 看不到使用该系统的人员。',
#  'file2_79_第 121.320 条': '高度保持和警告系统 (a)按照本规则实施运行的飞机应当安装有一个具有下 列功能的高度保持和警告系统： (1)向飞行机组指示所飞的高度； (2)自动保持所选择的高度； (3)当接近预选高度时， 能至少发出音频或者视频信号提 示飞行机组； (4)当飞机偏离预选高度时， 能向飞行机组至少发出听觉 或者视觉警告。',
#  'file2_80_第 121.323 条': '夜间运行的仪表和设备 在夜间实施运行的飞机，除装备有本规则第121.325 条 所要求的全部仪表和设备之外，还应当加装下列设备： (a)航行灯； (b)防撞灯； (c)两个着陆灯； (d)客舱灯光。',
#  'file2_81_第 121.325 条': '仪表飞行规则运行的仪表和设备 在仪表飞行规则条件下运行的飞机，除应装备有本规则 第121.305 条至第121.319 条、 第121.743 条所要求的仪表和 设备之外，还应当加装下列仪表和设备： (a)一个空速指示系统，带加温的空速管或者等效装置， 以防止因结冰而故障。 (b)一个灵敏型高度表。 (c)仪表灯光，能提供足够照明的仪表灯，可以使每一必 需的仪表、开关或者类似的装置清晰易读，并且其安装方式 使得光线既不会直射飞行机组成员的眼睛，也不会造成有害 的反射光线。除非无调光的仪表灯光是令人满意的，否则应 有措施控制照明的强度。',
#  'file2_82_第 121.329 条': '涡轮发动机飞机用于生命保障的补充氧 气要求 (a)在运行涡轮发动机驱动的飞机时，每个合格证持有人 应当根据本条的规定，在飞机上配备生命保障氧气和分配设 备以供使用： (1)所提供的氧气量应当至少是为遵守本条(b)和(c)款所 必需的量； (2)每一特定运行所需要的生命保障和急救用氧气量， 应 当根据座舱气压高度和飞行持续时间来确定，这些座舱气压 高度和飞行持续时间要与为该运行和航路制定的运行程序 一致； (3)对具有增压座舱的飞机， 氧气量应当根据座舱气压高 度和下列假设来确定：座舱增压故障发生在供氧需求临界的 飞行高度或者飞行中某点，然后飞机按照飞机飞行手册中规 定的应急程序，在不超过其使用限制的情况下，下降到一个 允许顺利结束本次飞行的飞行高度； (4)发生了这种故障之后， 座舱气压高度被视为与飞行高 度相同，除非能证明，座舱或者增压设备任何可能的故障均 不会导致座舱气压高度等于飞行高度。在这种情况下，可将 达到的最大座舱气压高度作为审定或者确定供氧量的基础。 (b)机组成员。 每个合格证持有人应当按照下列要求为机 组成员提供氧气： (1)在座舱气压高度3,000 米(10,000 英尺)以上至3,600 米(12,000 英尺)(含)时， 应当对在驾驶舱内值勤的每一飞行机 组成员提供氧气，并且他们也应当用氧，如果在这些高度上 超过30 分钟，则对于30 分钟后的那段飞行应当对其他机组 成员提供氧气； (2)在座舱气压高度3,600 米(12,000 英尺)以上时，应当 对在驾驶舱内值勤的每一飞行机组成员提供氧气，并且他们 也应当用氧，在此高度上整个飞行时间内，应当对其他机组 成员提供氧气； (3)当要求飞行机组成员用氧时，他应当连续用氧，除非 为执行其正常任务需要除去氧气面罩或者其他氧气分配器。 对那些处于待命状态的或者在完成此次飞行前肯定要在驾 驶舱内值勤的后备飞行机组成员， 视为本款第(1)、 (2)项所述 的其他机组成员。如果某一后备飞行机组成员不在待命状 态，并且在剩下的一段飞行中将不在驾驶舱内值勤，则就补 充氧气要求而言，可以将其视为一名旅客。 (c)旅客。除经局方批准外，每个合格证持有人应当按照 下列要求为旅客提供氧气： (1)对于座舱气压高度3,000 米(10,000 英尺)以上至4,000 米(13,000 英尺)(含)的飞行， 如果在这些高度上超过30 分钟， 则对于30 分钟后的那段飞行应当为10％的旅客提供足够的 氧气； (2)对于座舱气压高度4,000 米(13,000 英尺)以上的飞行， 在此高度上整个飞行时间内为机上每一旅客提供足够的氧 气。 (d)对于在特定区域运行符合本条(c)款存在困难的， 经局 方批准，可以按照以下要求实施运行： (1)对于座舱气压高度3,000 米(10,000 英尺)以上至4,300 米(14,000 英尺)(含)的飞行， 如果在这些高度上超过30 分钟， 则对于30 分钟后的那段飞行应当为10％的旅客提供足够的 氧气； (2)对于座舱气压高度4,300 米(14,000 英尺)以上至4,600 米(15,000 英尺)(含)的飞行，足以为30％的旅客在这些高度 的飞行中提供氧气； (3)对于座舱气压高度4,600 米(15,000 英尺)以上的飞行， 在此高度上整个飞行时间内为机上每一旅客提供足够的氧 气。',
# ...
#  'file2_272_第 121.696 条': '补充运行的飞行放行单 (a)飞行放行单应当至少包括每次飞行的下列信息： (1)公司或者机构的名称； (2)飞机的国籍标志、登记标志、制造厂家和型号； (3)航班或者航次和飞行日期； (4)每一飞行机组成员、客舱乘务员和机长姓名； (5)起飞机场、目的地机场、备降机场和航路； (6)运行类型说明，例如仪表飞行规则、目视飞行规则； (7)起飞最低燃油量。 (b)飞机飞行放行单应当含有或者附带目的地机场和备 降机场的最新天气实况报告、预报或者两者的组合。放行单 还可以包括机长认为必需的或者希望具有的其他天气实况 报告和预报。',
#  'file2_273_第 121.697 条': '装载舱单 装载舱单应当包含飞机在起飞时有关装载情况的下列 信息： (a)飞机、燃油和滑油、货物和行李、乘客和机组成员的 重量。 (b)该次飞行的最大允许重量， 该最大允许重量不得超过 下述重量中最小的重量： (1)对于拟使用跑道， 考虑对跑道气压高度和坡度以及起 飞时的风和温度条件的修正值之后的最大允许起飞重量； (2)考虑到预期的燃油和滑油消耗， 能够符合适用的航路 性能限制的最大起飞重量； (3)考虑到预期的燃油和滑油消耗， 能够在到达目的地机 场时符合批准的最大设计着陆重量限制的最大起飞重量； (4)考虑到预期的燃油和滑油消耗， 能够在到达目的地机 场和备降机场时符合着陆限制的最大起飞重量。 (c)按照批准的程序计算的总重量。 (d)按照批准的能够保证重心处于批准范围之内的计划， 对该飞机实施装载的证据。 (e)旅客的姓名， 除非该项内容由合格证持有人以其他方 式保存。',
#  'file2_274_第 121.699 条': '国内、国际定期载客运行装载舱单、签 派单和运行飞行计划的处置 (a)机长应当将下列文件的副本随机携带到目的地： (1)填写好的装载舱单； (2)签派或者放行单； (3)运行飞行计划。 (b)合格证持有人应当保存前款规定的文件的副本至少3 个月。',
#  'file2_275_第 121.700 条': '补充运行的装载舱单、飞行放行单和运 行飞行计划的处置 (a)实施补充运行的飞机机长应当携带下列文件的原件 或者经签署的文件副本飞行到目的地机场： (1)装载舱单； (2)飞行放行单； (3)适航放行单； (4)驾驶员航线合格证明； (5)运行飞行计划。 (b)如果飞行在合格证持有人主运行基地始发时， 应当在 其主运行基地保存本条(a)款规定的文件的原件或者副本。 (c)除本条(d)款规定外， 如果飞行在合格证持有人主运行 基地以外的机场始发时， 机长(或者合格证持有人授权的其他 运行控制人员)应当在起飞前或者起飞后立即将本条(a)款列 出的文件副本发送或者带回到主运行基地保存。 (d)如果飞行始发在合格证持有人的主运行基地以外机 场时，合格证持有人在那个机场委托他人负责管理飞行运 行，按照本条(a)款规定签署过的文件副本在送回合格证持有 人的主运行基地前在该机场的保存不得超过30 天。如果这 些文件的原件或者副本已经送回合格证持有人的主运行基 地，则这些文件不需要继续保存在该机场。 (e)实施补充运行的合格证持有人应当： (1)根据本条(d)款规定， 在其运行手册中指定专门人员负 责这些文件副本； (2)按照本条规定原始文件或者副本应当在主运行基地 保存3 个月。',
#  'file2_276_第 121.701 条': '飞机飞行记录本 (a)合格证持有人应当对于每一架飞机建立飞机飞行记 录本，记录运行中发现的缺陷和工作不正常情况及所进行的 维修工作； 另外， 它还用于记录与飞行安全有关的运行信息、 飞行机组和维修人员需要了解的有关数据。 (b)飞机飞行记录本中应当包括飞机运行信息、 影响飞机 适航性和安全运行的任何缺陷及保留状况、要求的维修项 目、维修工作记录、飞机放行等内容。 (c)飞机飞行记录本的格式应当固定，各项内容应当使用 墨水或者不可以更改的书写工具及时填写，并且有足够的复 页以保证满足使用和保存要求。 (d)合格证持有人应当在飞机上飞行机组成员易于取用 的地方放置一份飞机飞行记录本原件，其中至少记录包括每 次飞行前三次飞行期间填写内容的连续记录，并且每次起飞 前在地面保存一份记录上一次飞行和本次飞行前填写内容 的飞机飞行记录本的复页。 (e)合格证持有人应当在维修工程管理手册中规定飞机 飞行记录本的格式及填写、使用和保存要求。',
#  'file2_277_第 121.702 条': '燃油和滑油记录 (a)运营人必须保存燃油记录，以满足飞机使用燃油要 求。 (b)运营人必须保存滑油记录， 以便实施滑油消耗监控并 满足飞机安全飞行。 (c)燃油和滑油记录必须保存3 个月以上。',
#  'file2_278_第 121.703 条': '通信记录 合格证持有人应当记录与其飞行机组成员之间每次航 路上使用满足本规则第121.97 条通讯设备联系的记录， 并将 该记录至少保存30 天。',
#  'file2_279_第 121.704 条': '航空器观测和报告 (a)合格证持有人应当制定政策和程序，以保证其飞机根 据所飞越国家或者情报区(管制区)的要求完成航空器例行观 测、航空器特殊观测和其他非例行观测，记录并向空中交通 管制员报告观测到的情况。 (b)对于合格证持有人没有配备空地数据链的飞机， 可以 免除航空器例行观测。 (c)合格证持有人的飞机针对喷发前的火山活动、 火山喷 发或火山灰云所进行的航空器特殊观测情况，应当记录在火 山活动报告表上。当气象部门认为火山灰可能会影响航线上 的飞行时，合格证持有人应当在提供给飞行机组的飞行文件 中附上火山活动报告表。',
#  'file2_280_第 121.705 条': '飞行中紧急医学事件报告 (a)合格证持有人应当记录飞行中发生的紧急医学事件， 并应当在事发后48 小时内向局方报告。紧急医学事件记录 信息应当包括： 事件发生的时间、 航班航段、 事件具体情况、 涉及人员和处置过程等。记录应当保存24 个月。 (b)飞行中发生的紧急医学事件包括： 运行中发生的人员 伤病或死亡，以及突发公共卫生事件。',
#  'file2_281_第 121.706 条': '国际运行中对可疑传染病的报告 按照目的机场所在地的规定，当飞行中发现可疑传染病 病例时，机长应当立即报告正在通信的空中交通管制单位， 报告内容应当包括： 飞机注册号、 出发地机场、 目的地机场、 预计抵达时间、机上人数、可疑传染病病例人数、症状及风 险(如已知)等信息。',
#  'file2_282_第 121.707 条': '使用困难报告 (a)合格证持有人应当按照局方要求的方式向局方上报 其飞机的使用困难报告。使用困难报告包括运行中出现严重 故障或者失效，或者维修中发现的危及或者可能危及飞行安 全的故障、失效或者缺陷。 (b)合格证持有人应当在24 小时之内向局方报告本条所 要求报告的情况，并至少保存报告的信息30 天，以备局方 核查。 (c)合格证持有人应当按照局方要求的方式报告本条所 要求报告的情况，报告中应当至少包括下列信息： (1)飞机的制造厂家、型号、飞机/发动机/螺旋桨的序号； (2)飞机登记号； (3)合格证持有人的名称； (4)发生或者发现日期和地点； (5)失效、故障或者缺陷的发生阶段； (6)失效、故障或者缺陷的性质； (7)适用的ATA 章节； (8)飞机、发动机、螺旋桨或者部件的总使用时间或者循 环； (9)失效、 故障或者存在缺陷的零部件的制造厂家、 件号、 名称、序号和部位； (10)采取的预防或者紧急措施； (11)为了更完整地分析失效、故障或者缺陷原因的其他 信息，包括主要部件与型号设计有关的可以提供信息和自上 次翻修、修理和检测的适用时间。 (d)即使上述要求的信息不能完全提供， 合格证持有人也 不能推迟可以提供内容的报告时间，并且应当尽快补充报告 没有提供的信息。 (e)当使用困难报告涉及设计、 制造缺陷或者持续适航文 件问题时，相关报告信息还应当及时通报相应型号合格证持 有人。',
#  'file2_283_第 121.709 条': '机械原因中断使用汇总报告 (a)合格证持有人应当在每月10 日之前向局方报告前一 个月出现的因机械原因的下列情况的汇总报告： (1)中断飞行； (2)非计划更换飞机； (3)延误、备降或者改航； (4)因已知或者怀疑的机械原因引起的非计划换发。 (b)合格证持有人应当按照局方规定的格式和方式提交 本条所要求的报告。',
#  'file2_284_第 121.710 条': '运行中人为差错报告 合格证持有人应当在72 小时内向局方报告运行中出现 的飞行机组成员、维修及其他运行控制人员发生的人为差 错。 W 章 延程运行(EDTO)与极地运行',
#  'file2_285_第 121.711 条': '概则 (a)合格证持有人除经局方批准外不得实施下列运行： (1)在飞机计划运行的航路上至少存在一点到任一延程 运行(EDTO)可选备降机场的距离超过飞机在国际标准大气 和静止空气条件以经批准的一台发动机不工作时的巡航速 度飞行60 分钟对应的飞行距离(以两台涡轮发动机为动力的 飞机)或者超过180 分钟对应的飞行距离(以多于两台涡轮发 动机为动力的载客飞机)的运行； (2)在北极区域内的运行； (3)在南极区域内的运行。 (b)本章还规定了获得极地运行批准的各项要求。 (c)只有当机体发动机组合获得局方颁发的延程运行 (EDTO)型号设计批准时， 合格证持有人才有资格实施延程运 行(EDTO)。 延程运行型号设计批准通常在相应的机体发动机 组合的《飞机飞行手册》(AFM)、型号合格证(TC)或者补充 型号合格证(STC)中给出。 (d)为纠正运行中出现可能危及到所要求的可靠性水平 时，局方可以在任何时候要求修改构型、维修与程序标准。 局方将根据需要采取行动，要求对构型、维修与程序标准进 行修订， 以达到和保持所需的可靠性水平。 修订之前的构型、 维修与程序标准被认为不再适合于继续从事延程运行 (EDTO)。 (e)延程运行(EDTO)的批准通过颁发或者修改合格证持 有人的运行规范的方法进行。 (f)对于每一次延程运行(EDTO)， 签派放行单中应当包含 该次延程运行(EDTO)最大改航时间。 第121.713 附加要求 (a)对于从航路上一个点飞往一个航路备降机场的运行 超过60 分钟的情况，合格证持有人必须确保： (1)对于所有飞机： (i)指定了航路备降机场； (ii)向飞行机组提供指定航路备降机场的最新资料， 包括 工作状况与气象条件。 (2)对于双发涡轮驱动实施延程运行(EDTO)飞机，除非 根据最新的资料评估，指定的航路备降机场气象条件在预计 使用时间能够达到或高于合格证持有人运行规范批准的机 场运行最低标准，否则不得超过本规则第121.711 条(a)款第 (1)项规定的时间飞行。 如果经确定的任何条件不允许飞机在 预计的使用时间在该机场安全进近并着陆，必须确定一个备 用的运行方案。 (b)合格证持有人应当为所有已获得延程运行(EDTO)批 准的飞机制定签派放行程序，以防止将飞机被签派到改航时 间超过经局方批准的延程运行(EDTO)关键系统时间限制能 力的航路上。 (c)对于超过180 分钟的延程运行(EDTO)和极地运行， 该 次运行所指定的每个延程运行(EDTO)指定备降机场和极地 运行改航机场，都应当具备足以保障乘客和机组生存需求的 条件。 (d)合格证持有人应当在下列程序和大纲中增加本条(a) 款至(c)款的内容，以保证整体安全水平： (1)运行控制与飞行签派程序； (2)运行程序； (3)训练大纲。',
#  'file2_286_第 121.714 条': '延程运行(EDTO)的通信设备 如果实施超过180 分钟的延程运行(EDTO)， 满足本规则 第121.97 条(c)款所规定的通信系统应当能提供基于卫星的 语音通信，通话质量与固定电话相当。该系统应当能够在飞 行机组和空管人员之间以及飞行机组和合格证持有人之间 提供通信。 合格证持有人在规划延程运行(EDTO)时， 还应当 考虑改航至延程运行(EDTO)备降机场所需的可能的航线和 海拔高度，以确定基于卫星的语音通信设备是否可用。如果 存在无法利用基于卫星的语音通信设备的情况，或者因其质 量低劣而无法进行语音通信，则应当有另一种通信系统作为 替代。',
#  'file2_287_第 121.715 条': '延程运行(EDTO)备降机场：救援与消防 服务 (a)除本条(b)款中的规定之外， 在签派或者飞行放行单上 列明的每一个延程运行(EDTO)备降机场， 均需能够提供下列 救援和消防服务(RFFS)： (1)如果延程运行(EDTO)时间在180 分钟内，每个指定 的延程运行(EDTO)备降机场应当能够提供等效于或者高于 国际民航组织规定的第4 类救援和消防服务(RFFS)的要求； (2)如果延程运行(EDTO)时间超过180 分钟，每个指定 的延程运行(EDTO)备降机场应当能够提供等效于或者高于 国际民航组织规定的第4 类救援和消防服务(RFFS)的要求。 此外，飞机还应当保持在距能够提供等效于或者高于国际民 航组织规定的第7 类救援和消防服务(RFFS)的合适机场的一 定距离内， 以便能在依据其延程运行(EDTO)批准的改航时间 内飞抵该合适机场。 (b)如果无法直接在一个机场利用本条(a)款要求的救援 和消防设备与人员，只要该机场通过当地获得消防增援与消 防服务能力后，能够达到本条(a)款的要求，合格证持有人仍 然可以在签派或者飞行放行单上将该机场列为备降机场。在 改航的航路运行过程中如果当地资源可以及时被告知， 30 分 钟的增援响应时间应当是充足的。在改航飞机飞抵备降机场 时，增援设施与人员应当可用，另外，只要改航飞机需要救 援和消防服务，这些增援设施与人员就应当始终处于随时可 用状态。',
#  'file2_288_第 121.716 条': '手册内容 合格证持有人的手册中应当包含下列内容： (a)对于所从事的延程运行(EDTO)， 支持所有飞行阶段的 性能数据。 (b)对于载客运行： (1)如果实施超过180 分钟的延程运行(EDTO)，应当制 订每一相应延程运行(EDTO)备降机场具体的旅客航程恢复 计划； (2)对于在北极区域和南极区域的运行， 应当制订每一相 应极地运行改航机场具体的旅客航程恢复计划。',
#  'file2_289_第 121.718 条': '延程运行型号设计批准依据 除2015 年2 月17 日之前制造的安装两台以上发动机的 载客飞机和仅用于实施飞行时间少于或者等于75 分钟的延 程运行的双发飞机之外，合格证持有人只能在下列条件下实 施延程运行：飞机获得延程运行型号设计批准且每架用于延 程运行的飞机均符合其构型、维修和程序文件的要求。延程 运行型号设计批准通常在相应的机体发动机组合的《飞机飞 行手册》 (AFM)、 型号合格证(TC)或者补充型号合格证(STC) 中给出。',
#  'file2_290_第 121.719 条': '延程运行持续适航性维修方案(CAMP) 为实施延程运行，合格证持有人应当制定并遵照由局方 批准的运行规范中持续适航维修方案的要求对用于延程运 行的机体发动机组合实施维修。合格证持有人可以通过对飞 机制造厂推荐的维修方案，或者对现在已获批准的持续适航 维修方案增补维修要求来制定适用于延程运行的持续适航 维修方案。这个持续适航维修方案应当包括下列内容： (a)延程运行维修文件。 合格证持有人应当制定延程运行 维修文件，供每一名延程运行相关人员使用。 (1)这个文件应当： (i)列出延程运行的所有关键系统； (ii)引用或包含所有和延程运行相关的维修要素； (iii)引用或包含所有支援项目和程序； (iv)引用或包含所有职责； (v)明确说明引用材料源于合格证持有人文件系统何处。 (b)延程运行前维修检查。 合格证持有人应当制定针对延 程运行特定要求的维修检查单并实施检查。 (1)每次延程运行前， 合格证持有人应当完成延程运行前 维修检查。 (2)这种检查应当至少包括下列各项： (i)检验(确认)所有延程运行关键系统的状态； (ii)通过核查相应的维修记录，确认飞机的总体状况； (iii)进行飞机内外检查，确定发动机和辅助动力装置的 滑油量和滑油消耗率。 (3)由具有延程运行资格并获得批准的维修人员完成并 签署特殊延程运行相关工作文件，延程运行前地面勤务检查 完成的签署应当由具有机身和发动机等级并且具有延程运 行资格的维修人员签署。 (c)双重维修项目的限制。 (1)除了本款第(2)项的规定之外， 合格证持有人应当避免 在同一次停场维修时对相同的或者本质上相同的延程运行 关键系统同时实施例行或者非例行维修工作，以防止由于不 适当的维修而导致的延程运行关键系统的失效。 (2)如果本款第(1)项所定义的双重维修不可避免， 合格证 持有人可以按照下列规定进行维修： (i)同一个延程运行关键系统的维修工作由不同的技术人 员执行； (ii)如果应当由同一名技术人员对同一延程运行关键系 统进行维修时，应加派一名资历更高的人员对其工作实施直 接的监督； (iii)在飞机实施延程运行之前，必须按照本条(d)款的要 求通过地面检验、测试方法以及在必要的情况下通过飞行试 验的方法对延程运行关键系统维修工作的有效性进行验证。 在特殊情况下，可以由同一名具备合格资质的人员，在具备 延程运行维修控制合格资质人员的监督下来实施双重维修 和地面检验、 测试方法， 但前提是必须完成相应的飞行试验。 (d)验证方案。 合格证持有人应当制定并保持一个解决方 案，以确保对延程运行关键系统采取的维修工作的有效性。 验证方案应当识别潜在的问题，并核实令人满意的纠正措 施。验证方案应当包含地面检验和空中检验策略与程序。合 格证持有人应当建立程序，明确指示启动检验行动的人员以 及必不可少的行动项。可以在取酬的延程运行中进行验证， 但要求验证工作在到达延程运行进入点之前顺利完成并且 记录所进行的验证工作。 (e)识别任务。合格证持有人应当标示出所有与延程运行 相关的任务。这些与延程运行相关的特定工作应当由经过适 当培训且具有延程运行资格的维修人员完成并签署。 (f)集中的维修控制程序。合格证持有人应当为延程运行 制定并保持集中的维修控制程序。 (g)零部件控制方案。 合格证持有人应当制定一个延程运 行零部件控制方案，以确保正确识别用于实施延程运行飞机 构型控制的零部件。 (h)可靠性方案。 合格证持有人应当制定一个延程运行可 靠性方案。该方案应当是在合格证持有人现有可靠性方案或 者其持续分析和监督系统(CASS)的基础上增补延程运行的 内容。该方案应当是以事件分析为基础的方案，并包含下列 事件的报告程序： (1)在发生下列事件后，涉及本规则第121.707 条规定项 目的，按照规定要求向局方报告；其他项目应当在96 小时 内向局方报告： (i)空中停车，但在飞行训练时计划的空中停车除外； (ii)由与飞机或者发动机系统相关的失效、 故障或缺陷引 起的改航和返航； (iii)非指令动力或者推力变化或者喘振； (iv)发动机失控或者无法获得要求的动力或者推力； (v)因疏忽产生的燃油损耗或者无燃油可用， 或者飞行中 无法纠正的燃油不平衡； (vi)与延程运行关键系统相关的失效、故障或者缺陷； (vii)任何危及实施延程运行安全飞行和着陆的事件。 (2)合格证持有人应当调查本款第(1)项中列明的每一事 件的原因，并向局方提交调查结果和纠正措施说明。纠正行 动应当被局方所接受。 (i)动力系统监控： (A)如果作为机体发动机组合一部分的发动机的空中停 车率(基于12 个月滚动平均值)超过下列数值， 合格证持有人 应当综合评审其运行，以识别任何共因影响和系统错误。 ①如果延程运行(EDTO)时间小于或者等于120 分钟， 空 中停车率为0.005 次/1,000 发动机工作小时； ②如果在北太平洋区域延程运行(EDTO)时间超过120 分钟且小于或者等于207 分钟，以及在其他区域延程运行 (EDTO)时间超过120 分钟且小于或者等于180 分钟， 空中停 车率为0.003 次/1000 发动机工作小时； ③如果在北太平洋运行区域延程运行(EDTO)时间超过 207 分钟，以及在其他区域延程运行(EDTO)时间超过180 分 钟，空中停车率为0.002 次/1000 发动机工作小时。 (B)在空中停车率超过上述数值30 天之内，合格证持有 人应当向局方提交一个调查报告以及已采取的任何必要的 纠正措施。 (j)发动机状况监控。 (1)合格证持有人应当制定一个发动机状况监控方案， 以 便在早期检测到发动机的性能恶化，并在安全运行受到影响 之前采取纠正措施； (2)该方案应当描述待监控参数、数据收集方法、数据分 析方法和采取纠正措施的流程； (3)该方案应当确保发动机极限值裕度能得以维持， 以便 在批准的动力水平、所有预期的环境条件下，实施发动机失 效状态下的延程改航，而不会超出批准的发动机限值。这包 括多种批准的限值，如转子速度和排气温度。 (k)滑油消耗量监控。 合格证持有人应当制定一个发动机 油耗监视方案，以确保飞机具有足够的滑油以完成每次的延 程运行。如果延程运行中需要使用辅助动力装置，则辅助动 力装置油耗应当包括在内。合格证持有人的油耗极限值不得 超过制造厂家的推荐值。应当对发动机油耗进行持续监控， 并将在延程运行的每一个离港机场添加的滑油包含在内。该 方案应当比较延程运行每个离港机场的加油量与运行过程 的平均油耗，以识别突然的油耗增加。 (l)辅助动力装置空中起动方案。如果飞机的取证要求辅 助动力装置，但不要求其在延程运行时工作，则合格证持有 人应当制定和保持一个局方接受的低温情况下辅助动力装 置的空中起动和工作的方案。 (m)维修培训。 对于每一种机体发动机组合， 合格证持有 人应当制定一个维修培训方案，提供充分的培训以支持延程 运行。培训项目应当包括对所有参与延程运行的维修的人员 提供与延程运行相关的培训，同时，这种培训注重延程运行 的特殊性质。该培训应当是对已接受过飞机和发动机维修培 训的维修人员的基础上的补充培训。 (n)构型、维修与程序(CMP)文件。如果一种机体发动机 组合具有一个构型、维修和程序文件，则合格证持有人应当 有适用的系统来满足经局方批准文件的要求。 (o)程序变化。 合格证持有人对延程运行相关的维修或者 培训程序所做的任何实质改变都应当提交局方审核。在局方 通知合格证持有人审核完成之前，合格证持有人不得执行已 改变的程序。',
#  'file2_291_第 121.720 条': '机组成员与签派人员培训要求 合格证持有人应当对其机组成员和签派人员就其在合 格证持有人的旅客航程恢复计划中的职责和作用进行培训。 X 章 应急医疗设备和训练',
#  'file2_292_第 121.741 条': '适用范围 本章规定了按照本规则实施载客运行的合格证持有人 的机载应急医疗设备和训练的要求，但并不要求合格证持有 人及其代理人提供专业的应急医疗服务。',
#  'file2_293_第 121.743 条': '应急医疗设备 (a)按照本规则运行的合格证持有人应当在其载客飞机 上配备下列应急医疗设备： (1)急救箱； (2)应急医疗箱； (3)卫生防疫包。 (b)本条所要求的各项应急医疗设备： (1)应当附加名称标识，并有明确的使用方法提示； (2)应当放置在客舱内，便于机组成员取用； (3)应当以6个月为周期或者根据所配物品有效期和更新 要求进行定期检查更新，以确保在紧急情况下能够使用。检 查更新日期应当标注在包装外。 (c)每架飞机配备的应急医疗设备数量和医疗物品种类 应当符合本规则附件B 的要求。',
#  'file2_294_第 121.745 条': '机组成员处置飞行中紧急医学事件的训 练 (a)合格证持有人的每一训练大纲中应当包括本条规定 的，针对每一型别、厂家、构型的飞机、每一机组必需成员、 每一运行种类的适用训练内容。 (b)训练应当包括下列内容： (1)遇有紧急医学事件时的处置程序， 包括机组成员之间 的协调； (2)应急医疗设备的存放位置、功能和使用方法； (3)急救箱、 应急医疗箱和卫生防疫包内物品和药品的用 途及使用方法； (4)每一客舱乘务员还应当训练： (i)心肺复苏和隔离消毒等知识和操作； (ii)至少每24 个月进行一次复训，包括心肺复苏的操作 练习。 (c)本条要求的机组成员实际操练和复训不需要达到或 者相当于专业急救人员的水平。 Y 章 法律责任',
#  'file2_295_第 121.760 条': '一般规定 违反本规则规定， 《中华人民共和国民用航空法》 《中华 人民共和国安全生产法》 《中华人民共和国飞行基本规则》 等有关法律、行政法规对其处罚有明确规定的，从其规定。',
#  'file2_296_第 121.761 条': '未取得运行合格证从事本规则规定的运 行 航空运营人未按照本规则取得运行合格证即从事本规 则第121.3 条规定的运行活动的，由其运行活动所在地的民 航地区管理局责令其停止上述运行活动，处3 万元以上10 万元以下的罚款；情节严重的，处10 万元以上20 万元以下 的罚款。',
#  'file2_297_第 121.762 条': '提供虚假材料的处罚 对于处于运行合格审定过程中的运行合格证申请人，违 反本规则第121.37 条规定， 存在弄虚作假情况的， 局方应当 终止其运行合格审定进程，并作出不予许可的决定，自作出 不予许可决定之日起1 年内不再受理该申请人的相应申请。 对于申请人在运行合格审定过程中以欺骗、贿赂等不正 当手段取得运行合格证、运行规范和其他批准项目的，由局 方撤销相应的证件和批准，自撤销其相应证件和批准之日起 3 年内不再受理该申请人的相应申请。',
#  'file2_298_第 121.763 条': '违反本规则规定的行为 (a)合格证持有人有下列行为之一的，局方责令其停止违 法行为，可以处警告或者1 万元以上3 万元以下的罚款；情 节严重的，处3 万元以上10 万元以下的罚款： (1)违反本规则C 章的规定， 未满足合格证持有人管理一 般规定的； (2)违反本规则G 章的规定，未落实手册要求的； (3)违反本规则H 章的规定， 使用不符合要求的飞机实施 本规则运行的； (4)违反本规则I 章的规定，超过飞机性能使用限制实施 本规则运行的； (5)违反本规则K 章的规定， 飞机的仪表和设备不符合本 规则要求的； (6)违反本规则L 章的规定，未落实其飞机适航性责任 的； (7)违反本规则N 章的规定， 使用未经局方批准的训练大 纲或者未按照经批准的训练大纲进行规定的训练而实施运 行的； (8)违反本规则M 章、O 章、R 章或者Q 章的规定，机 组成员和其他航空人员不符合规定的要求，未按照规定使用 或者搭配航空人员的； (9)违反本规则P 章或者第121.503 条的规定，未按照规 定安排航空人员的值勤期、飞行时间和休息时间的； (10)违反本规则T 章的规定，未能对飞机上的人员、货 物和设备等进行有效管理，对运行安全造成威胁的； (11)违反本规则U 章中规定的签派和飞行放行规则签派 或者放行飞机的； (12)违反本规则第121.380 条、 第121.557 条、 第121.559 条、 第121.573 条(d)款、 第121.575 条(d)款或者V 章的规定， 未按照规定的内容、时间、格式和方式报告有关情况或者未 按照规定保存有关信息的； (13)违反本规则W 章的规定， 实施延程和极地运行时造 成旅客生命安全受到威胁或者造成事故征候或者事故的； (14)违反本规则X 章的规定，未在载客飞机上配备规定 的应急医疗设备，或者未对相关机组成员实施相应培训的； (15)违反本规则S 章的规定，未按特殊运行授权和限制 实施运行的； (16)局方认定的其他可能对安全造成威胁的行为。 (b)对于未按照合格证持有人的手册或者管理规则履行 职责而导致违反本规则规定，或者其本人直接违反本规则规 定的航空人员或者其他相关人员，局方可以处警告或者500 元以上1000 元以下的罚款。',
#  'file2_299_第 121.764 条': '违反本规则规定的行为 对合格证持有人的撤销许可、行政处罚、行政强制等处 理措施及其执行情况记入守法信用信息记录，并按照有关规 定进行公示。 Z 章 附   则',
#  'file2_300_第 121.771 条': '施行 本规则自公布之日起施行。 交通运输部于2017 年9 月4 日以交通运输部令2017 年第29 号公布，2020 年5 月11 日 以交通运输部令2020 年第9 号、 2021 年3 月15 日以交通运 输部令2021 年第5 号修改的《大型飞机公共航空运输承运 人运行合格审定规则》同时废止。 除另有规定外，在本规则修订版施行之前已经持有按本 规则颁发的现行有效运行合格证的航空承运人应当于2026 年1 月1 日之前完全符合本次修订版的要求。 附件A 定  义 安全管理体系：是指管理安全的系统做法，包括必要的 组织机构、政策、问责制和程序。 飞行安全文件系统：是指由合格证持有人制订，用于规 定或者指导合格证持有人飞行和地面运行人员日常安全运 行所必需的相关资料， 其中应当包括本规则G 章规定的手册 及内容，手册的保存、分发、获取、修订及有效性控制的程 序和方法。 飞机飞行手册：是指经适航审定部门批准的飞机飞行手 册(如AFM)，包括确认该飞机适航所需满足的限制，以及飞 行机组成员安全操纵航空器所必需的指令和信息。根据中国 民航适航审定规章，所必须的指令和信息至少包括： (1)飞机的使用限制、使用程序、性能资料等信息； (2)由于设计、 使用或者操作特性而为安全运行所必需的 其他资料； (3)任何为了符合中国民航局有关噪声规定要求而确定 的限制、程序或者其他数据。 飞行数据分析：是指为了提高飞行运行安全而对合格证 持有人所记录的飞行数据加以分析的过程。 飞行数据分析方案：有时也被称为飞行数据监控(FDM) 或者飞行品质监控(FOQA)， 是一种系统化、 主动识别危险源 的工具，以便通过改进飞行机组情景意识、训练有效性、操 作程序、飞机维修方案等方式提升安全水平。飞行数据分析 方案还可以用于下列方面： (1)确定操作规范； (2)识别在操作程序、机队、机场等方面存在的潜在和实 际的危险源； (3)识别趋势； (4)监控风险控制或者纠正措施的有效性； (5)提供进行成本效益分析的数据； (6)优化训练大纲； (7)衡量用于风险管理的绩效。 定期载客运行：是指航空承运人或者航空运营人以取酬 或者出租为目的，通过本人或者其代理人以广告或者其他形 式提前向公众公布的，包括起飞地点、起飞时间、到达地点 和到达时间在内的任何载客运行。 最大商载： (a)对于局方在技术规范中已规定最大无油重量的飞机， 以最大无油重量减去空机重量、飞机携带的适用设备的重量 和运行载重(包括最少机组成员、 食物饮料和与这些食物饮料 有关的供应品和设备的重量， 但不包括可用燃油和滑油)所计 算出的最大商载。 (b)对于其他飞机， 以最大审定起飞重量、 较小空机重量、 较少的机载设备重量和较小的运行必需重量(运行必需重量 为最少的燃油、 滑油重量和机组成员重量之和)所计算出的最 大商载。机组成员、燃油和滑油的重量按照下列方法计算： (1)规章要求的机组成员中每一成员的体重： (i)男性飞行机组成员按照82 千克； (ii)女性飞行机组成员按照64 千克； (iii)男性客舱乘务员按照82 千克； (iv)女性客舱乘务员按照59 千克； (v)客舱乘务员不区分性别时，体重平均按照64 千克。 (2)滑油按照157 千克或者型号合格审定中规定的重量。 (3)规章规定的一次飞行运行所需携带最少燃油量。 偏离：对于规章中明确允许偏离的条款，合格证持有人 在提出恰当理由和证明能够达到同等安全水平的情况下，经 局方批准，可以不遵守相应条款的规定或者遵守替代的规 定、条件或者限制。 豁免：对于规章中没有明确允许偏离的条款，合格证持 有人在提出恰当的理由、相应的安全措施并证明这些安全措 施能保证同等安全水平的情况下，经中国民航局批准，可以 不执行相应的规章条款，而执行中国民航局在作出此项批准 时所列的规定、条件或者限制。豁免是遵守规章的一种替代 做法，遵守所颁发的豁免及其条件和限制，就是遵守规章。 运行控制：是指合格证持有人为了航空器的安全和飞行 的正常和效率，对某次飞行的起始、持续和终止行使控制权 的过程。 湿租：是指按照租赁协议，承租人租赁飞机时携带出租 人机组成员的租赁。 干租：是指不提供机组成员的航空器租赁安排。 飞机互换：是指一种由单架飞机完成两个合格证持有人 航班的运行。一个合格证持有人可以通过协议的方式在某一 交换点，让另一个合格证持有人使用同一架飞机完成其航 班，使两个合格证持有人的航班形成组合。不同的合格证持 有人使用各自的机组实施各自的航班，并对各自航班的运行 控制负责。 登记国：是指航空器登记的国家。 地面服务：是指飞机到达和离开机场时除空中交通服务 以外的必要服务。 机组成员：是指飞行期间在飞机上执行任务的航空人 员，包括飞行机组成员和客舱乘务员。 机组必需成员：是指为完成按本规则运行符合最低配置 要求的机组成员。 飞行机组成员：是指飞行期间在飞机驾驶舱内执行任务 的驾驶员和飞行机械员。 机长：是指经合格证持有人指定，在飞行时间内对飞机 的运行和安全负最终责任的驾驶员。 客舱乘务员：是指出于对旅客安全的考虑，受合格证持 有人指派在客舱执行值勤任务的机组成员。 飞行签派员：是指在公共航空运输运行中，持有按《民 用航空飞行签派员执照和训练机构管理规则》(CCAR-65FS) 颁发的飞行签派员执照，由合格证持有人指定从事飞行运行 控制和监督，承担本规则第121.531 条(c)款中所列各项责任 的人员。 飞机组类：是指为方便机组成员和飞行签派员的训练管 理，根据飞机动力装置的区别对飞机划分的种类。在本规则 中，将飞机分为两个组类：组类I，以涡轮螺旋桨发动机为 动力的飞机；组类II，以涡轮喷气发动机为动力的飞机。为 飞行机组成员训练需要，根据飞机最大起飞重量，再将组类 II 飞机分为5,700 千克(含)至136,000 千克(含)和136,000 千 克(不含)以上两个种类。 先进航空器：是指配备有对于特定起飞、进近或者着陆 运行除基本航空器所需设备之外的附加设备的航空器。 基本航空器：是指配备有实施拟进行的起飞、进近或者 着陆运行所需的最低设备的航空器。 新雇员训练：是指合格证持有人新雇佣的人员，或者已 经雇佣但没有在机组成员或者飞行签派员工作岗位上工作 过的人员，在进入机组成员或者飞行签派员工作岗位之前需 要进行的训练。新雇员训练包括基础理论教育和针对特定机 型和岗位的训练。 初始训练：是指未曾在相同组类其他飞机的相同职位上 经审定合格并服务过的机组成员和飞行签派员需要进行的 改飞机型训练。 转机型训练：是指曾在相同组类不同型别飞机的相同职 位上经审定合格并服务过的机组成员和飞行签派员需要进 行的改飞机型训练。 升级训练：是指已在某一特定型别的飞机上经审定合格 并担任副驾驶的机组成员，在该型别飞机上担任机长之前需 要进行的训练。 定期复训：是指已取得资格的机组成员和飞行签派员， 为了保持其资格和技术熟练水平，在规定的期限内按照规定 的内容进行的训练。 重新获得资格训练：是指已在特定飞机型别和特定工作 岗位上经审定合格，但因某种原因失去资格的机组成员和飞 行签派员，为恢复这一资格所应当进行的训练。 差异训练：对于已在某一特定型别的飞机上经审定合格 并服务过的机组成员和飞行签派员，当局方认为其使用的同 型别飞机与原服务过的飞机在性能、设备或者操作程序等方 面存在差异，需要进行补充性训练时应当完成的训练。 日历月：是指按照世界协调时或者当地时间划分，从本 月1 日零点到下个月1 日零点之间的时间段。 飞行时间：是指飞机为准备起飞而借自身动力开始移动 时起，直到飞行结束停止移动为止的时间。 飞行经历时间：是指机组必需成员在其值勤岗位上执行 任务的飞行时间，即在座飞行时间。 延伸跨水运行： (a)在本规则中，对于符合下述条件的飞机，延伸跨水运 行是指离适用的应急着陆机场距离超过以巡航速度飞行120 分钟的距离或者740 公里(400 海里)(以较少者为准)的跨水航 路运行： (1)对于双发飞机， 在航路或者计划改航航路上的任一点 发生临界发动机不工作的情况下，仍能够安全飞往标准着陆 机场，并且在任何一点上不会低于最低飞行高度； (2)对于具有三台或者三台以上发动机的飞机， 在航路的 任一航段飞行时，如果为保持预期的总体安全水平，其航路 备降机场的位置和总飞行持续时间的关系致使必须要考虑 第二台发动机不工作的可能性，则该飞机必须能够在两台发 动机不工作时继续飞至航路备降机场并着陆。 (b)对于其他所有飞机， 延伸跨水运行是指离适用的应急 着陆机场距离超过以巡航速度飞行30 分钟的距离或者185 公里（100 海里） （以较少者为准）的跨水航路运行。 延程运行(EDTO)：是指在飞机计划运行的航路上至少存 在一点到任一延程运行(EDTO)可选备降机场的距离超过飞 机国际标准大气和静止空气条件中以经批准的一台发动机 不工作时的巡航速度飞行60 分钟对应的飞行距离(以两台涡 轮发动机为动力的飞机)或者超过180 分钟对应的飞行距离 (以多于两台涡轮发动机为动力的载客飞机)的运行。 最大改航时间：是指从航路上一点飞往一个航路备降场 的最大容许航程(以时间表示)。 极地运行：是指在北纬78 度以北或者南纬60 度以南区 域的运行。 运行飞行计划：是指合格证持有人根据飞机性能、其他 运行限制及所飞航路与有关机场的预期条件，为安全实施飞 行所制定的计划。 最低油量：是指飞行过程中应当报告空中交通管制员采 取应急措施的一个特定燃油油量最低值，该油量是 ...

# %%
# 民航总局文件拆分到a/b/c粒度
def split_paragraph_dict_lv2(paragraph_dict):
    res = {}
    for src_key in paragraph_dict:
        src_content = paragraph_dict[src_key]
        
        # 先提取所有的"(字母)"次标题
        sub_titles = re.findall(r'\s+\(([a-z])\)', src_content)
        # 提取主标题, 第一个次标题前
        first_sub_titles_start = src_content.find(f"({sub_titles[0]})", 0) if len(sub_titles) > 0 else len(src_content)
        main_title = src_content[:first_sub_titles_start]
        # 初始化内容列表和标题计数器
        contents = []
        title_counter = 1
        # 根据次标题位置分割文本，提取内容
        start_pos = 0
        for sub_title in sub_titles:
            # 查找当前次标题的位置
            title_start = src_content.find(f" ({sub_title})", start_pos)
            # 查找下一个次标题或文本结束的位置
            if title_counter < len(sub_titles):
                next_title = sub_titles[title_counter]
                next_title_start = src_content.find(f" ({next_title})", title_start)
                content = src_content[title_start+len(f" ({sub_title})"):next_title_start].strip()
            else:
                # 如果是最后一个次标题，则提取到字符串末尾
                content = src_content[title_start+len(f" ({sub_title})"):].strip()
            contents.append(content)
            start_pos = title_start + len(f"({sub_title})")
            title_counter += 1
            
        # 生成最终的字典
        # 如果不能被拆分(a), (b)...
        if len(sub_titles) == 0 or len(contents) == 0:
            res[src_key] = src_content
        else:
            split_keys = [f"{src_key}_({sub_title})" for sub_title in sub_titles]
            split_values = [f"{main_title}{content}" for content in contents]
            for sub_key, sub_value in zip(split_keys, split_values):
                res[sub_key] = sub_value
    return res

# %%
paragraph_dict2_lv2 = split_paragraph_dict_lv2(paragraph_dict2)

# %%
len(paragraph_dict2_lv2)
# Out:
# 1032

# %%
paragraph_dict2_lv2
# Out:
# {'file2_0_第 121.1 条': '目的和依据 为了对大型飞机公共航空运输承运人进行运行合格审 定和持续监督检查，保证其达到并保持规定的运行安全水 平，根据《中华人民共和国民用航空法》和《国务院对确需 保留的行政审批项目设定行政许可的决定》 ，制定本规则。',
#  'file2_1_第 121.3 条_(a)': '适用范围 本规则适用于在中华人民共和国境内依法设立的航 空运营人实施的下列公共航空运输运行： (1)使用最大起飞重量超过5,700 千克的多发涡轮驱动飞 机实施的定期载客运输飞行； (2)使用旅客座位数超过30 座或者最大商载超过3,400 千克的多发涡轮驱动飞机实施的不定期载客运输飞行； (3)使用最大商载超过3,400 千克的多发涡轮驱动飞机实 施的全货物运输飞行。',
#  'file2_1_第 121.3 条_(b)': '适用范围 对于适用于本条(a)款规定的航空运营人， 在本规则中 称之为大型飞机公共航空运输承运人。',
#  'file2_1_第 121.3 条_(c)': '适用范围 对于应当按照本规则审定合格的大型飞机公共航空 运输承运人，中国民用航空局(以下简称中国民航局)和民用 航空地区管理局（以下简称民航地区管理局）按照审定情况 在其运行合格证及其运行规范中批准其实施下列一项或者 多项运行种类的运行： (1)国内定期载客运行，是指符合本条(a)款第(1)项规定， 在中华人民共和国境内两点之间的运行，或者一个国内地点 与另一个由局方专门指定、视为国内地点的国外地点之间的 运行； (2)国际定期载客运行，是指符合本条(a)款第(1)项规定， 在一个国内地点和一个国外地点之间，两个国外地点之间， 或者一个国内地点与另一个由局方专门指定、视为国外地点 的国内地点之间的运行； (3)补充运行，是指符合本条(a)款第(2)项、第(3)项规定 的运行。',
#  'file2_1_第 121.3 条_(d)': '适用范围 大型飞机公共航空运输承运人应当遵守其他有关的 涉及民航管理的规章，但在本规则对相应要求进行了增补或 者提出了更高标准的情况下，应当按照本规则的要求执行。',
#  'file2_1_第 121.3 条_(e)': '适用范围 大型飞机公共航空运输承运人在运行中所使用的人 员和大型飞机公共航空运输承运人所载运的人员应当遵守 本规则中的适用要求。',
#  'file2_1_第 121.3 条_(f)': '适用范围 在本规则中，对于载运邮件的飞行，视为载运货物飞 行；对于同时载运旅客和货物的飞行，视为载运旅客飞行， 但应当同时满足本规则中有关货物运输条款的要求。',
#  'file2_2_第 121.5 条_(a)': '定义 在本规则中， 局方是指中国民航局和民航地区管理局 及其派出机构。',
#  'file2_2_第 121.5 条_(b)': '定义 除本规则其他章中另有规定外， 本规则中用语的含义 在本规则附件A《定义》中规定。',
#  'file2_3_第 121.7 条_(a)': '运行合格审定和持续监督 中国民航局对大型飞机公共航空运输承运人的合格 审定和运行实施统一监督管理。',
#  'file2_3_第 121.7 条_(b)': '运行合格审定和持续监督 中国民航局飞行标准职能部门依据本规则组织指导 大型飞机公共航空运输承运人的运行合格审定和持续监督 检查工作，制定必要的工作程序，规定运行合格证、运行规 范及其申请书的统一格式。',
#  'file2_3_第 121.7 条_(c)': '运行合格审定和持续监督 民航地区管理局负责对其所辖地区内设立的大型飞 机公共航空运输承运人实施运行合格审定，颁发运行合格证 及其运行规范，并及时向中国民航局飞行标准职能部门备 案。',
#  'file2_3_第 121.7 条_(d)': '运行合格审定和持续监督 大型飞机公共航空运输承运人取得运行合格证及其 运行规范后， 即成为本规则规定的运行合格证持有人(以下简 称合格证持有人)。',
#  'file2_3_第 121.7 条_(e)': '运行合格审定和持续监督 民航地区管理局及其派出机构负责对其所辖地区内 设立的和(或者)在其所辖地区内运行的合格证持有人实施持 续监督检查。',
#  'file2_4_第 121.9 条_(a)': '飞机的湿租 除经中国民航局批准外，合格证持有人不得湿租境外 航空运营人或者境内未按照本规则批准运行的航空运营人 的飞机。',
#  'file2_4_第 121.9 条_(b)': '飞机的湿租 合格证持有人在进行涉及湿租的运行前， 应当向局方 提交一份与国内外其他公共航空运营人所签订的飞机湿租 租赁合同和有关批准文件的副本。局方收到租赁合同副本 后，将确定合同中飞机的运行控制方，并根据需要，向合同 一方或者双方分别颁发运行规范的修改项，否则合格证持有 人不得进行湿租运行。',
#  'file2_4_第 121.9 条_(c)': '飞机的湿租 合格证持有人实施湿租运行，应当提供下列需要列入 运行规范的信息： (1)合同双方的名称和合同的有效期限； (2)合同所涉及的每架飞机的国籍标志和登记标志； (3)运行种类； (4)运行的机场或者区域； (5)具体说明计划由哪一方负责运行控制和实施这种运 行控制的时间、机场或者区域。',
#  'file2_4_第 121.9 条_(d)': '飞机的湿租 在对前款事项作出决定时，局方将考虑下列因素： (1)机组成员资格； (2)飞机的适航性和维修工作； (3)飞行签派； (4)飞机的补给服务； (5)航班计划； (6)安全运行责任； (7)局方认为有关的其他因素。',
#  'file2_4_第 121.9 条_(e)': '飞机的湿租 经局方批准， 合格证持有人在因特殊原因取消其飞机 的飞行时，可以租用带有一名或者多名机组成员的飞机，载 运其旅客进行飞行。这种飞行应当遵守本规则中与所实施运 行有关的规定。',
#  'file2_5_第 121.11 条': '境外运行规则 大型飞机公共航空运输承运人在中国境外运行时，应当 遵守《国际民用航空公约》附件2《空中规则》和所适用的 外国法规。 在 《民用航空器驾驶员合格审定规则》 (CCAR-61)、 《一般运行和飞行规则》(CCAR-91)和本规则的规定严于上 述附件和外国法规的规定并且不与其发生抵触时，还应当遵 守《民用航空器驾驶员合格审定规则》(CCAR-61)、 《一般运 行和飞行规则》(CCAR-91)和本规则的规定。 B 章 运行合格审定的一般规定',
#  'file2_6_第 121.20 条_(a)': '运行合格证及其运行规范 在本规则中， 运行合格证是指批准大型飞机公共航空 运输承运人从事特定公共航空运输运行的许可证书。',
#  'file2_6_第 121.20 条_(b)': '运行合格证及其运行规范 运行规范是运行合格证的附件， 是指与运行合格证相 对应的，大型飞机公共航空运输承运人运行应当符合的批 准、条件和限制等规范。',
#  'file2_7_第 121.21 条_(a)': '运行合格证及其运行规范的申请和颁发程 序 大型飞机公共航空运输承运人实施本规则第121.3 条 规定的运行，应当向其主运行基地所在地的民航地区管理局 申请颁发运行合格证及其运行规范。民航地区管理局按照预 先申请、正式申请、文件审查、演示验证和发证五个步骤进 行审查。运行合格证及其运行规范的申请人应当按照规定的 格式和方法向其主运行基地所在地的民航地区管理局提交 申请书，申请书应当至少附有下列材料： (1)审查活动日程表； (2)本规则第121.133 条所要求的手册； (3)训练大纲及课程； (4)管理人员资历； (5)飞机及运行设施、设备的购买或者租用合同复印件； (6)说明申请人如何符合本规则所有适用条款的符合性 声明。',
#  'file2_7_第 121.21 条_(b)': '运行合格证及其运行规范的申请和颁发程 序 初次申请运行合格证的申请人， 应当在提交申请书的 同时，提交说明计划运行的性质和范围的文件，包括准许申 请人从事经营活动的有关证明文件。',
#  'file2_7_第 121.21 条_(c)': '运行合格证及其运行规范的申请和颁发程 序 民航地区管理局应当在收到申请书之后的5 个工作日 内书面通知申请人是否受理申请。 申请人未能按照本条(a)款 要求提交齐全的材料或者申请书格式不符合要求，需要申请 人补充申请材料的，民航地区管理局应当在该5 个工作日内 一次性告知需要补正的全部内容。',
#  'file2_7_第 121.21 条_(d)': '运行合格证及其运行规范的申请和颁发程 序 民航地区管理局受理申请后， 对申请人的申请材料是 否符合本规则的要求进行审查，对申请人能否按照本规则安 全运行进行验证检查。',
#  'file2_7_第 121.21 条_(e)': '运行合格证及其运行规范的申请和颁发程 序 民航地区管理局应当自受理申请之日起20 个工作日 内做出是否颁发运行合格证及其运行规范的决定，民航地区 管理局依法进行检验、组织专家评审的时间不计入前述期 限。',
#  'file2_7_第 121.21 条_(f)': '运行合格证及其运行规范的申请和颁发程 序 申请人属于本规则第121.23 条(b)款规定情形的， 不予 颁发运行合格证及其运行规范。对于此种情况，民航地区管 理局应当书面通知申请人，说明理由并告知申请人享有依法 申请行政复议或者提起行政诉讼的权利。',
#  'file2_8_第 121.23 条_(a)': '运行合格证及其运行规范的颁发条件 申请人经过审查后符合下列全部条件， 可以取得大型 飞机公共航空运输承运人运行合格证及其运行规范： (1)满足本规则和涉及民航管理的规章所有适用条款的 要求； (2)按照涉及民航管理的规章的规定， 配备了合格和足够 的人员、设备、设施和资料，并且能够按照本规则的规定及 其运行规范实施安全运行； (3)具有与特定的运行性质和范围相符的完善的组织机 构、飞行运行的控制和监督方法、训练大纲以及地面服务和 维修安排； (4)符合安全保卫相关的涉及民航管理的规章的要求； (5)为代表其执行工作的第三方制定了政策和程序。',
#  'file2_8_第 121.23 条_(b)': '运行合格证及其运行规范的颁发条件 申请人具有下列情形之一的，不予颁发运行合格证： (1)申请人没有配备合格的或者足够的人员、设备、设施 和资料，或者不能按照有关涉及民航管理的规章实施安全运 行； (2)申请人或者对其经营管理有控制权的人员， 存在与运 行相关的严重失信行为记录的； (3)申请人安排或者计划安排担任本规则第121.43 条(a) 款规定的主要管理职位的人员，存在与运行相关的严重失信 行为记录的。',
#  'file2_9_第 121.25 条_(a)': '运行合格证及其运行规范的内容 经审查合格后，局方应当向申请人颁发大型飞机公共航 空运输承运人运行合格证及其运行规范。 大型飞机公共航空运输承运人运行合格证包含下列 内容： (1)合格证持有人的名称； (2)合格证持有人主运行基地的地址； (3)合格证的编号； (4)合格证的生效日期和有效期； (5)负责监督该合格证持有人运行的局方机构名称和联 系方式； (6)被批准的运行种类； (7)说明经审定，该合格证持有人符合本规则的相应要 求，批准其按照所颁发的运行规范实施运行。',
#  'file2_9_第 121.25 条_(b)': '运行合格证及其运行规范的内容 经审查合格后，局方应当向申请人颁发大型飞机公共航 空运输承运人运行合格证及其运行规范。 大型飞机公共航空运输承运人的运行规范包含下列 内容： (1)主运行基地的具体地址， 作为合格证持有人与局方进 行通信联系的不同于其主运行基地地址的地址，以及其文件 收发机构的名称与通信地址； (2)对每种运行的实施规定的权利、限制和主要程序； (3)每个级别和型别的飞机在运行中需要遵守的其他程 序； (4)批准合格证持有人使用的每架飞机的型号、系列编 号、国籍标志和登记标志，定期载客运行中需要使用的每个 正常使用机场、备降机场、临时使用机场和加油机场。经批 准，这些项目可以列在现行有效的清单中，作为运行规范的 附件，并在运行规范的相应条款中注明该清单名称。合格证 持有人只能使用列在清单上的飞机和机场运行； (5)批准的运行种类； (6)批准运行的航线和区域及其限制； (7)机场的限制； (8)机体、发动机、螺旋桨、设备(包括应急设备)的维修 时限或者确定维修时限的标准； (9)批准的控制飞机重量与平衡的方法； (10)飞机互换的要求； (11)湿租飞机的有关资料； (12)按照规定颁发的豁免或者批准的偏离； (13)按照本规则需要局方批准的手册和训练大纲； (14)按照本规则实施运行所必须的管理人员和机构； (15)按照本规则需要局方批准的其他项目。',
#  'file2_10_第 121.27 条_(a)': '运行合格证及其运行规范的有效性 运行合格证在出现下列情形之一时失效： (1)合格证持有人自愿放弃，并将其交回局方； (2)局方依法暂扣、撤销或者以其他方式终止该合格证。',
#  'file2_10_第 121.27 条_(b)': '运行合格证及其运行规范的有效性 在出现下列情形时， 运行规范全部失效或者部分条款 失效： (1)局方依法暂扣、撤销或者以其他方式终止运行合格 证，则运行规范全部失效； (2)局方依法暂停或者终止该运行规范中批准的全部运 行，则运行规范全部失效； (3)局方依法暂停或者终止该运行规范中批准的部分运 行，则运行规范中关于该部分运行的条款失效； (4)对于某一运行种类， 合格证持有人没有满足本规则第 121.47 条(a)款中规定的近期经历要求，并且没有按照第 121.47 条(b)款规定的程序恢复该种类运行时， 运行规范中关 于该种类运行的条款失效。',
#  'file2_10_第 121.27 条_(c)': '运行合格证及其运行规范的有效性 当运行合格证或者运行规范依法被暂扣、撤销或者因 其他原因而失效时，合格证持有人应当将运行合格证或者运 行规范交还局方。',
#  'file2_11_第 121.29 条': '运行合格证及其运行规范的检查 合格证持有人应当将其运行合格证及其运行规范保存 在主运行基地，并能随时接受局方的检查。合格证持有人的 飞机上应当携带运行合格证及其运行规范经认证的真实副 本，并保证副本与正本一致。该副本可以是纸质版，也可以 是符合局方要求的其他形式。',
#  'file2_12_第 121.31 条_(a)': '运行合格证的修改 在下列情形下，局方可以修改按照本规则颁发的运行 合格证： (1)局方认为为了安全和公众利益需要修改； (2)合格证持有人申请修改， 且局方认为安全和公众利益 允许进行此种修改。',
#  'file2_12_第 121.31 条_(b)': '运行合格证的修改 合格证持有人申请修改其运行合格证时， 适用本规则 第121.21 条(c)款至(f)款规定的程序和期限并应当遵守下列 规定： (1)合格证持有人应当在不迟于其计划的修改生效日期 前适当的时间向其主运行基地所在地的民航地区管理局提 交修改其运行合格证的申请书； (2)申请书应当按照规定的格式和方法提交。',
#  'file2_12_第 121.31 条_(c)': '运行合格证的修改 当合格证持有人对其运行合格证修改的申请被拒绝 或者对局方发出的修改决定有不同意见，请求重新考虑时， 应当在收到局方通知后20 个工作日内向局方提出重新考虑 的请求。',
#  'file2_13_第 121.33 条_(a)': '合格证持有人保存和使用运行规范的责任 合格证持有人应当在其主运行基地保存一套独立完 整且现行有效的运行规范。',
#  'file2_13_第 121.33 条_(b)': '合格证持有人保存和使用运行规范的责任 合格证持有人应当将其运行规范中的有关内容或者 信息，写进本规则G 章规定的手册中，并且应当清楚地写明 这些内容是其运行规范的一部分，还应当说明运行规范的每 一条要求具有强制性；或者将完整的运行规范与手册编制在 一起进行分发、携带、保存和更新。',
#  'file2_13_第 121.33 条_(c)': '合格证持有人保存和使用运行规范的责任 合格证持有人应当持续保证其每个参与运行工作的 人员，熟知运行规范中适用于该人员工作职责的有关规定。',
#  'file2_14_第 121.35 条_(a)': '运行规范的修改 在下列情形下，局方可以修改按照本规则颁发的运行 规范： (1)局方认为为了安全和公众利益需要修改； (2)合格证持有人申请修改， 且局方认为安全和公众利益 允许进行此种修改。',
#  'file2_14_第 121.35 条_(b)': '运行规范的修改 除本条(e)款规定的情形外， 局方主动修改合格证持有 人的运行规范应当遵守下列程序： (1)局方以书面形式提出修改内容，通知合格证持有人； (2)局方确定一个不少于5 个工作日的合理期限， 合格证 持有人可以在此期限内对修改内容提交有关书面资料和意 见； (3)局方审查合格证持有人提交的全部材料后， 作出下列 决定之一并通知合格证持有人：',
#  'file2_14_第 121.35 条_(i)': '运行规范的修改 接受所申请的全部修改； (ii)接受所申请的部分修改； (iii)拒绝所申请的修改。此时，合格证持有人可以按照 本条(d)款规定，请求局方对其拒绝决定进行重新考虑。 (4)局方批准修改的， 经与合格证持有人就其修改的贯彻 问题进行协调后，修改项在局方批准的日期生效； (5)如果合格证持有人守法信用信息记录中存在与运行 相关的严重失信行为记录，局方可以拒绝其申请的部分或者 全部修改。',
#  'file2_14_第 121.35 条_(c)': '运行规范的修改 合格证持有人申请修改其运行规范时， 适用本规则第 121.21 条(c)款至(f)款规定的程序和期限并应当遵守下列规 定： (1)合格证持有人应当在计划的运行规范修改生效日期 前适当时间提交修改其运行规范的申请书，但有下列情形之 一的，申请人应当在计划的运行规范修改生效日期前足够的 时间内提出申请：',
#  'file2_14_第 121.35 条_(v)': '运行规范的修改 初次引进以前未经大型飞机公共航空运输承运人运 行验证试飞的飞机的。 (2)申请书应当以规定的格式和方法向其主运行基地所 在地的民航地区管理局提交； (3)在考虑了申请人提交的所有材料以及局方的审查情 况后，局方作出下列决定之一并通知合格证持有人：',
#  'file2_14_第 121.35 条_(d)': '运行规范的修改 合格证持有人申请局方重新考虑运行规范修改项的 决定的，应当遵守下列程序： (1)合格证持有人应当在收到局方拒绝修改其运行规范 的通知后， 或者在收到局方提出修改其运行规范的通知后20 个工作日内，向局方提出重新考虑的请求； (2)如果重新考虑的请求是在20 个工作日内提出的，则 局方颁发的任何修改暂停生效，除非局方发现，根据本条(e) 款，存在紧急情况，为了安全，需要立即生效； (3)如果重新考虑的请求不是在20 个工作日内提出的， 按照本条(c)款规定的程序执行。',
#  'file2_14_第 121.35 条_(e)': '运行规范的修改 如果局方发现，存在危及安全、需要立即行动的紧急 情况， 不能执行本条(b)款至(d)款规定的程序， 或者按照程序 进行将违背公众利益，则可以采取下列措施： (1)局方修改运行规范， 并使修改项在合格证持有人收到 该修改通知日期起立即生效； (2)在发给合格证持有人的通知中，局方应当说明原因， 指出存在危及安全、需要立即行动的紧急情况，或者指出修 改推迟生效将违背公众利益的情况。',
#  'file2_15_第 121.37 条': '申请人的责任 申请人申请取得或者申请修改运行合格证及其运行规 范以及与运行合格审定有关的其他项目，应当保证申请材料 真实完整。 C 章 管理合格证持有人的一般规定',
#  'file2_16_第 121.41 条_(a)': '监察和检查的实施 合格证持有人应当接受局方在任何时间或者地点对 其进行的监察或者检查，以确定其是否符合涉及民航管理的 规章的规定，是否符合其运行合格证及其运行规范的规定。',
#  'file2_16_第 121.41 条_(b)': '监察和检查的实施 合格证持有人应当能在其主运行基地向局方提供下 列资料： (1)合格证持有人的大型飞机公共航空运输承运人运行 合格证及其运行规范； (2)一个包含有关资料存放地点和负责人员信息的现行 清单。上述资料是指合格证持有人按照适用的涉及民航管理 的规章规定，应当保存的记录、文件和报告。',
#  'file2_16_第 121.41 条_(c)': '监察和检查的实施 负责保存合格证持有人记录、文件和报告的所有人 员，应当能向局方提供这些资料。',
#  'file2_16_第 121.41 条_(d)': '监察和检查的实施 局方可以根据本条(a)款检查的结果或者任何其他适 当的材料，确定合格证持有人是否合格于继续持有其运行合 格证及其运行规范。',
#  'file2_16_第 121.41 条_(e)': '监察和检查的实施 合格证持有人如果不能按照局方要求， 提供其运行合 格证、运行规范或者任何必需的记录、文件和报告，存在安 全隐患的，局方可以暂停其运行合格证或运行规范中的部分 或者全部运行批准。',
#  'file2_17_第 121.42 条_(a)': '安全管理体系 合格证持有人应当建立安全管理体系，并且能够按照本 规则的规定实施安全管理，该体系应当： 至少具备了下列功能： (1)对影响安全的危险源能够及时识别； (2)保证采取必要的纠正措施，保持可接受的安全水平； (3)对安全水平进行持续的监督和定期评估； (4)持续改进整体安全水平。',
#  'file2_17_第 121.42 条_(b)': '安全管理体系 合格证持有人应当建立安全管理体系，并且能够按照本 规则的规定实施安全管理，该体系应当： 明确地界定了整个组织内部的安全责任界限， 包括高 层管理者应当对安全直接承担的责任。',
#  'file2_17_第 121.42 条_(c)': '安全管理体系 合格证持有人应当建立安全管理体系，并且能够按照本 规则的规定实施安全管理，该体系应当： 制订并持续实施非惩罚性， 且包含保护数据及其来源 措施的飞行数据分析方案。',
#  'file2_17_第 121.42 条_(d)': '安全管理体系 合格证持有人应当建立安全管理体系，并且能够按照本 规则的规定实施安全管理，该体系应当： 制订供运行人员使用的飞行安全文件系统。',
#  'file2_18_第 121.43 条_(a)': '按照本规则实施运行所必需的管理人员和 机构 合格证持有人应当拥有能够有效控制和监督其整个 运行的管理机构，并拥有足够的合格管理人员和技术人员， 以保证在其运行中保持最高的安全水平。合格证持有人应当 在下列职位或者同等职位上安排合格的人员： (1)主要负责人， 对合格证持有人安全生产工作全面负责 的高级管理人员，具体责任包括：',
#  'file2_18_第 121.43 条_(i)': '按照本规则实施运行所必需的管理人员和 机构 有关涉及民航管理的规章； (ii)合格证持有人的运行规范； (iii)航空安全标准和安全运行常规； (iv)本规则及其他涉及民航管理的规章中所有适用的维 修和适航要求；',
#  'file2_18_第 121.43 条_(b)': '按照本规则实施运行所必需的管理人员和 机构 对于某一项具体运行，如果合格证持有人能证明，由 于所涉及的运行种类、所使用的飞机数量与型号和运行的区 域等因素，使用较少的管理人员能够完成本条(a)款规定的除 安全总监以外其他职位的全部职责并能以同等安全水平完 成运行， 局方可以认可其管理人员的配备。 除经局方批准外， 安全总监不允许由本条(a)款其余职务的人员兼任。',
#  'file2_18_第 121.43 条_(c)': '按照本规则实施运行所必需的管理人员和 机构 本条(a)款要求的或者按照本条(b)款认可的职位名称 和管理人员数量，应当在合格证持有人的运行规范中明确载 明。',
#  'file2_18_第 121.43 条_(d)': '按照本规则实施运行所必需的管理人员和 机构 担任本条(a)款或者(b)款要求的或者认可的职位的人 员，以及按照运行合格证实施运行的各级负责人，应当符合 下列要求： (1)在训练、经验、专业知识上保持合格水平。 (2)在其职责范围内， 理解有关合格证持有人各种运行的 下列资料：',
#  'file2_18_第 121.43 条_(v)': '按照本规则实施运行所必需的管理人员和 机构 本规则第121.131 条要求的手册。 (3)严格履行其职责，以符合适用的规章要求，并保证安 全运行。',
#  'file2_18_第 121.43 条_(e)': '按照本规则实施运行所必需的管理人员和 机构 合格证持有人应当在本规则G 章要求的手册内的一 般政策规定中，写明本条(a)款规定的人员的任务、职责和权 力，并写明担任这些职务人员的姓名和业务地址。合格证持 有人应当在上述所列职位上的人员变换或者空缺后10 天内 通知局方。',
#  'file2_18_第 121.43 条_(f)': '按照本规则实施运行所必需的管理人员和 机构 合格证持有人应当设立由飞行、维修、签派和客舱安 全等专业人员组成的运行管理机构，负责协调各业务部门有 关运行的事项；办理运行合格审定的有关事宜；负责手册的 分发、更改和报批工作，保持其有效性。',
#  'file2_18_第 121.43 条_(g)': '按照本规则实施运行所必需的管理人员和 机构 合格证持有人应当设立独立于运行的安全监督机构， 在安全总监的直接领导下，负责安全水平的持续监督和定期 评估；调查安全相关事件；就安全有关事务提出建议和组织 员工安全教育等。',
#  'file2_19_第 121.45 条_(a)': '管理人员的合格条件 款规定的主要负责人应当符合下列条件： (1)接受了局方认可的相关法规的培训并合格； (2)曾经担任按本规则运行的第121.43 条(a)款规定的主 要管理人员或者具备至少3 年民航安全管理工作经验； (3)熟悉合格证持有人的运行规范、 运行手册及其他相关 要求； (4)具有较强的分析解决问题能力和良好的沟通技能。',
#  'file2_19_第 121.45 条_(b)': '管理人员的合格条件 担任本规则第121.43 条(a)款规定的安全总监应当符 合下列条件： (1)掌握运行安全管理知识、质量管理知识、涉及民航管 理的规章、标准及程序; (2)最近6年内在合格证持有人或者局方的安全监督岗位 工作3 年以上，或者持有下列任一专业执照并在相应岗位上 工作3 年以上：',
#  'file2_19_第 121.45 条_(i)': '管理人员的合格条件 航线运输驾驶员执照； (ii)民用航空器维修人员执照； (iii)飞行签派员执照。 (3)理解合格证持有人的运行规范、 运行手册及其他相关 要求; (4)具有较强的分析解决问题能力和良好的沟通技能。',
#  'file2_19_第 121.45 条_(c)': '管理人员的合格条件 、(d)、(e)或者(f)款规定的经历，但具有相应的经历，能够 有效履行涉及民航管理的规章要求的相应职位的职责和合 格证持有人手册规定的程序，局方可以批准对本条相应款项 规定经历的偏离。',
#  'file2_19_第 121.45 条_(d)': '管理人员的合格条件 担任本规则第121.43 条(a)款规定的维修副总经理应 当符合下列条件： (1)接受了局方认可的相关法规的培训并合格； (2)在前6 年内具有至少3 年从事合格证持有人运行的至 少一种类别和级别飞机全面的维修管理经历。',
#  'file2_19_第 121.45 条_(e)': '管理人员的合格条件 担任本规则第121.43 条(a)款规定的总飞行师应当符 合下列条件： (1)持有航线运输驾驶员执照， 至少具有该合格证持有人 按照本规则运行中所用的一种飞机的合适等级； (2)对于初次担任总飞行师的人员，在最近6 年内，至少 在该合格证持有人按照本规则运行的相同级别的飞机上，具 有担任机长3 年的经历；对于具有总飞行师经历的人员，至 少在与该合格证持有人按照本规则运行的相同级别的飞机 上，具有担任机长3 年的经历。',
#  'file2_19_第 121.45 条_(f)': '管理人员的合格条件 担任本规则第121.43 条(a)款规定的总工程师应当符 合下列条件： (1)持有民用航空器维修人员执照， 至少具有该合格证持 有人按照本规则运行中所用的一种飞机的机型签署经历； (2)具有维修本规则运行的飞机至少5 年的经历， 其中至 少有2 年作为维修工程技术管理人员的经历。',
#  'file2_19_第 121.45 条_(g)': '管理人员的合格条件 如果合格证持有人拟选任的人员不符合本条(a)、(b)、',
#  'file2_20_第 121.47 条_(a)': '运行的近期经历 合格证持有人如果连续中断其运行规范中批准实施 的某一种类的运行达30 个日历日，则在此日期之后，应当 按照本条(b)款规定恢复运行，否则不得继续实施此种运行。',
#  'file2_20_第 121.47 条_(b)': '运行的近期经历 在本条(a)款的中断期之后， 只有符合下列条件并达到 局方要求后，方可以恢复相应种类的运行： (1)在恢复该种运行之前， 至少提前5个工作日通知局方； (2)如果局方决定重新进行全面检查， 以确定其是否保持 了合适和足够的配备，能否实施安全运行，合格证持有人应 当在前述5 个工作日期间处于能随时接受检查的状态。',
#  'file2_21_第 121.49 条_(a)': '主运行基地、飞行基地和维修基地 合格证持有人应当保持一个主运行基地。合格证持有 人还可以按照运行需要建立飞行基地和维修基地，飞行基地 和维修基地可以与主运行基地在同一地点，也可以在不同地 点。',
#  'file2_21_第 121.49 条_(b)': '主运行基地、飞行基地和维修基地 在计划建立或者变更主运行基地、 飞行基地或者维修 基地之前至少30 天，合格证持有人应当以书面形式通知局 方。',
#  'file2_22_第 121.51 条_(a)': '合格证持有人名称的使用 合格证持有人按照本规则实施运行时所使用的名称 应当与其运行规范上所列名称一致。',
#  'file2_22_第 121.51 条_(b)': '合格证持有人名称的使用 除经局方在运行规范中批准外， 在按照本规则运行的 飞机上应当明显地标出运行该飞机的合格证持有人的名称， 否则不得运行该飞机。飞机上标示名称的方法及其可读性应 当符合局方要求。',
#  'file2_23_第 121.52 条_(a)': '飞行数据的使用 合格证持有人不得为事故或者征候调查以外的目的 使用驾驶舱话音记录器、驾驶舱音频记录系统的记录或者文 本，除非这些记录或者文本： (1)在去识别化后， 用于合格证持有人安全管理体系内不 安全事件的调查、分析、研究等，并符合《国际民用航空公 约》附件19《安全管理》关于保护安全数据和安全信息的相 关要求； (2)用于与事故或者征候调查所涉事件无关的刑事诉讼， 并符合《国际民用航空公约》附件19《安全管理》关于保护 安全数据和安全信息的相关要求； (3)用于对飞行记录器系统的检查。',
#  'file2_23_第 121.52 条_(b)': '飞行数据的使用 合格证持有人不得为事故或者征候调查以外的目的 使用飞行数据记录器、航空器数据记录系统以及本规则第 121.352 条要求的快速记录器的记录或者文本，除非这些记 录或者文本符合《国际民用航空公约》附件19《安全管理》 关于保护安全数据和安全信息的相关要求，且： (1)去识别化； (2)合格证持有人用于飞行数据分析方案； (3)用于与事故或者征候调查所涉事件无关的诉讼； (4)合格证持有人用于适航或者维修； (5)根据安全数据保护程序被公布。',
#  'file2_23_第 121.52 条_(c)': '飞行数据的使用 合格证持有人可以与另一方签订合同， 由其负责飞行 数据分析方案具体工作，但符合性责任由合格证持有人承 担。',
#  'file2_23_第 121.52 条_(d)': '飞行数据的使用 合格证持有人应当定期向负责合格证管理的民航地 区管理局职能部门报告其通过飞行数据分析方案得到的统 计数据和趋势分析报告，局方认为必要时可以随时查阅或者 分析快速存取记录器(QAR)或者等效设备的原始数据。',
#  'file2_24_第 121.53 条_(a)': '按照军方合同实施运行的偏离批准 局方可以批准合格证持有人偏离本规则的适用规定， 实施其按照军方合同确定的运行。',
#  'file2_24_第 121.53 条_(b)': '按照军方合同实施运行的偏离批准 在按照本条批准一项偏离时， 局方将对合格证持有人 的运行规范颁发相应的修改项。',
#  'file2_24_第 121.53 条_(c)': '按照军方合同实施运行的偏离批准 局方在任何时候可以终止按照本条颁发的偏离批准。',
#  'file2_25_第 121.55 条_(a)': '实施应急运行的偏离批准 在紧急情况下并满足下列条件时，局方可以批准合格 证持有人偏离本规则的适用规定： (1)在该紧急情况下为保护人员生命和财产应当采取运 送人员或者财产的行动； (2)局方认为，为了立即实施这些运行，应当偏离有关规 定。',
#  'file2_25_第 121.55 条_(b)': '实施应急运行的偏离批准 在紧急情况下，局方可以使用下列方法之一批准偏 离： (1)局方对合格证持有人的运行规范颁发相应的修改项； (2)如果情况紧急不允许及时修改运行规范， 则局方可以 用口头或者其他方式批准该偏离，但合格证持有人应当在开 始这种运行后24 小时之内，向局方提交说明这种紧急情况 性质的报告。',
#  'file2_26_第 121.57 条': '遵守运行合格证及其运行规范的要求 合格证持有人不得违反运行合格证、运行规范和其他批 准项目实施运行，不得超越批准的偏离或者豁免。 E 章 国内、国际定期载客运行航路的批准',
#  'file2_27_第 121.91 条_(a)': '航路批准的基本要求 申请航路批准的合格证持有人应当证明符合下列条 件： (1)能在该航路上每一正常使用机场、 临时使用机场或者 加油机场之间实施满足本规则要求的运行； (2)对于计划的运行，具有满足本规则第121.95 条至第 121.105 条要求的设施与服务。',
#  'file2_27_第 121.91 条_(b)': '航路批准的基本要求 在证明符合本条(a)款要求时， 如果合格证持有人在考 虑了机场、灯光、维修、通信、导航、加油、地面、机载无 线电等各种设施的可用性和充分性，以及参与运行的全体人 员的能力之后，证明能保证飞行安全，局方可以不要求在该 航路上作航路试飞。',
#  'file2_28_第 121.93 条_(a)': '航路宽度 经批准的航路、航段及固定航线具有的宽度应当至少 与这些固定航线或者航路的规定宽度相等。在局方认为有必 要对经批准的航路另行确定宽度时，将考虑下列因素： (1)地形障碍的超越； (2)最低航路高度； (3)地面和机载导航设备； (4)空中交通密度； (5)空中交通管制程序。',
#  'file2_28_第 121.93 条_(b)': '航路宽度 局方对经批准的航路另行确定的宽度， 将具体规定在 该大型飞机公共航空运输承运人的运行规范中。',
#  'file2_29_第 121.95 条_(a)': '必需的机场资料 合格证持有人应当证明，所申请批准的航路上具有足 够的机场，并且这些机场装备了适合于所申请运行的设施。 其中所考虑的因素应当包括机场的等级、道面、障碍物、设 施、公众保护、灯光、导航、通信、气象设施以及空中交通 管制等。',
#  'file2_29_第 121.95 条_(b)': '必需的机场资料 合格证持有人应当证明，对于所使用的每个机场，都 能够获得、保存现行有效的航行资料，包含但不限于航行通 告(NOTAM)、航行资料汇编(AIP)、航行资料通报(AIC)和定 期制航行通告(AIRAC)等与运行安全、规则和效率有关的信 息，并且具有将其分发给每个有关人员的经批准的资料管理 系统，以确保飞机在该机场运行的安全。这种航行资料应当 包括下列方面的内容： (1)机场',
#  'file2_29_第 121.95 条_(i)': '必需的机场资料 跑道视程(RVR)测量设备； (ii)低能见度条件下的盛行风。',
#  'file2_29_第 121.95 条_(v)': '必需的机场资料 导航、通信、气象设施； (vi)影响起飞、着陆或者地面运行的建筑物； (vii)空中交通服务设施。 (2)跑道、停止道和净空道',
#  'file2_29_第 121.95 条_(c)': '必需的机场资料 如果负责管理该合格证持有人的民航地区管理局发 现该合格证持有人经批准的关于收集、分发和使用航行资料 的系统应当予以改进才能恰当地继续工作，则合格证持有人 在接到该部门的通知后，应当立即对其系统进行改进。在合 格证持有人接到这样的通知之后30 天内，可以向中国民航 局飞行标准职能部门提出重新考虑的请求。重新考虑的请求 使该通知处于暂缓执行状态，直至中国民航局飞行标准职能 部门作出决定时止。但是，如果民航地区管理局认为存在关 系到航空运输安全、需要立即采取措施的紧急情况，则中国 民航局飞行标准职能部门可以根据所陈述的理由，使要求改 进的通知立即生效。',
#  'file2_30_第 121.97 条_(a)': '通信设备 合格证持有人应当证明，在正常运行条件下，在整个 航路上，所有各点都具有陆空双向无线电通信系统，能保证 每一架飞机与相应的空中交通管制单位之间，每一架飞机与 相应的运行控制中心之间，以直接的或者通过经批准的点到 点间的线路进行迅速可靠的通信联系。除遇到紧急情况外， 对于合格证持有人的所有运行，每架飞机与运行控制中心之 间的通信系统应当是空中交通管制通信系统之外的独立系 统。',
#  'file2_30_第 121.97 条_(b)': '通信设备 对于国内运行， 如合格证持有人评估所运行的航线上 存在空中交通管制通信设施不可用或者通信质量无法保证 有效语音通信的情况，运行该航线的每一架飞机与运行控制 中心之间应当保证有另一种语音通信系统可以进行替代。',
#  'file2_30_第 121.97 条_(c)': '通信设备 对于国际运行，合格证持有人应当保证每一架飞机与 相应的运行控制中心之间能够满足在正常运行条件下，在4 分钟内建立迅速可靠的语音通信联系。',
#  'file2_31_第 121.99 条_(a)': '气象服务 合格证持有人应当证明，每一条航路沿线，均有足够 的气象报告服务可以供使用，以保证提供运行所必需的气象 实况报告和气象预报。',
#  'file2_31_第 121.99 条_(b)': '气象服务 合格证持有人只能使用符合局方要求的气象服务系 统提供的气象资料。',
#  'file2_31_第 121.99 条_(c)': '气象服务 使用气象预报控制飞行活动的合格证持有人， 应当使 用依据本条(b)款规定的气象资料而编制的气象预报， 以及按 照本条(d)款规定采用的系统所批准的任何来源而编制的气 象预报。',
#  'file2_31_第 121.99 条_(d)': '气象服务 合格证持有人应当使用经局方批准的危险天气实况 报告与预报系统，以便获得可能影响所飞航路和所用机场飞 行安全的危险天气现象，如晴空颠簸、雷暴和低空风切变等 情况的实况报告和预报。',
#  'file2_32_第 121.101 条_(a)': '航路导航设施 除本条(b)款规定外， 合格证持有人应当证明， 对于每 一条计划中的航路，非目视地面导航设施符合下列要求： (1)具有足够的非目视地面导航设施， 能在空中交通管制 要求的精度之内，在整个航路上为飞机导航； (2)非目视地面导航设施的位置， 能保证在该运行所必需 的精度范围之内，引导飞机至任一正常使用机场、临时使用 机场、加油机场或者备降机场。',
#  'file2_32_第 121.101 条_(b)': '航路导航设施 下列运行不需要非目视地面导航设施： (1)昼间目视飞行规则运行，但合格证持有人应当证明， 能够根据地形的特征，使用地标领航而安全运行； (2)在经局方批准使用特殊导航方法导航的航段上实施 的运行。',
#  'file2_33_第 121.103 条_(a)': '运行控制中心 合格证持有人应当设立运行控制中心， 通过完备的运 行控制组织管理体系，确保对每次飞行进行恰当的运行控 制。',
#  'file2_33_第 121.103 条_(b)': '运行控制中心 运行控制中心可以设立若干分支机构实施运行控制， 但运行控制责任应当严格遵守本规则第121.531 条的要求。',
#  'file2_33_第 121.103 条_(c)': '运行控制中心 合格证持有人的运行控制体系应当在运行规范中得 到批准，并在运行手册中描述说明该体系的组织架构、授权 以及职责。',
#  'file2_34_第 121.105 条': '地面服务 每个实施国内、国际定期载客运行的合格证持有人应当 建立相应的地面服务管理组织机构，在相关的手册中明确对 所有地面服务的培训要求、外部委托政策、管理程序、工作 标准和规范等内容，并具备足够的合格人员和适当的设施和 设备(包括备件、地面保障和材料等)，确保飞机起飞前或者 着陆后的地面服务符合本规则的相应要求。当合格证持有人 通过外部委托方式由他人提供部分或者全部地面服务时，合 格证持有人应当向相应的地面服务人员提供必要的训练，并 对其操作的安全性负责。 F 章 补充运行的区域和航路批准',
#  'file2_35_第 121.113 条_(a)': '航路和区域要求概则 实施补充运行的合格证持有人应当按照下列规定申 请运行区域和航路的批准： (1)对于国内运行， 中国境内的空域按照一个运行区域批 准，但包含高高原机场(海拔高度在2,438 米或者8,000 英尺 及以上的机场)起降点的航路还需按照航路进行批准； (2)对于国际运行，所飞机场所在的每一国家(地区)按照 一个运行区域批准，但包含高高原机场或者局方确定的特殊 机场起降点的航路还需按照航路进行批准。',
#  'file2_35_第 121.113 条_(b)': '航路和区域要求概则 按照本条(a)款申请运行区域和航路批准的合格证持 有人，应当证明其具有足够的装备和能力，能够使用中国或 者外国公布航路上有关导航设施，在仪表飞行规则和夜间目 视飞行规则条件下实施安全运行。',
#  'file2_35_第 121.113 条_(c)': '航路和区域要求概则 如果实施补充运行的合格证持有人可以证明， 对于运 行的航路是安全的，并且局方能够确定空中交通密度有足够 的安全水平，局方可以批准合格证持有人管制空域外的航 路。合格证持有人不可以使用没有经局方批准的，或者运行 规范中没有列出的航路。',
#  'file2_36_第 121.115 条_(a)': '航路宽度 经批准的航路、航段及固定航线具有的宽度应当至少 与这些固定航线或者航路的规定宽度相等。在局方认为有必 要对经批准的航路另行确定宽度时，将考虑下列因素： (1)地形障碍的超越； (2)最低航路高度； (3)地面和机载导航设备； (4)空中交通密度； (5)空中交通管制程序。',
#  'file2_36_第 121.115 条_(b)': '航路宽度 合格证持有人运行规范中局方加以规定的任何其他 航路宽度。',
#  'file2_37_第 121.117 条_(a)': '必需的机场资料 实施补充运行的合格证持有人使用的任何机场应当 具有适当的装备并适合于所申请运行的设施。其中所考虑的 因素应当包括机场的等级、道面、障碍物、设施、公众保护、 灯光、导航、通信、气象设施以及空中交通管制等。',
#  'file2_37_第 121.117 条_(b)': '必需的机场资料 每一实施补充运行的合格证持有人应当证明其有一 个经批准的系统，能够获得、保存和分发给每个有关人员所 使用机场现行有效的航行资料，以确保飞机在该机场运行的 安全。这种航行资料应当包括下列方面的内容： (1)机场',
#  'file2_37_第 121.117 条_(i)': '必需的机场资料 跑道视程(RVR)测量设备； (ii)低能见度条件下的盛行风。',
#  'file2_37_第 121.117 条_(v)': '必需的机场资料 导航、通信、气象设施； (vi)影响起飞、着陆或者地面运行的建筑物； (vii)空中交通服务设施。 (2)跑道、停止道和净空道',
#  'file2_37_第 121.117 条_(c)': '必需的机场资料 如果负责管理该合格证持有人的民航地区管理局发 现该合格证持有人经批准的关于收集、分发和使用航行资料 的系统应当予以改进才能恰当地继续工作，则合格证持有人 在接到该部门的通知后，应当立即对其系统进行改进。在合 格证持有人接到这样的通知之后30 天内，可以向中国民航 局飞行标准职能部门提出重新考虑的请求。重新考虑的请求 使该通知处于暂缓执行状态，直至中国民航局飞行标准职能 部门作出决定时止。但是，如果民航地区管理局认为存在关 系到航空运输安全、需要立即采取措施的紧急情况，则中国 民航局飞行标准职能部门可以根据所陈述的理由，使要求改 进的通知立即生效。',
#  'file2_38_第 121.119 条_(a)': '气象服务 合格证持有人应当证明，每一条航路沿线，均有足够 的气象报告服务可以供使用，以保证提供运行所必需的气象 实况报告和气象预报。',
#  'file2_38_第 121.119 条_(b)': '气象服务 合格证持有人只能使用符合局方要求的气象服务系 统提供的气象资料。',
#  'file2_38_第 121.119 条_(c)': '气象服务 使用气象预报控制飞行活动的合格证持有人， 应当使 用依据本条(b)款规定的气象资料而编制的气象预报。',
#  'file2_39_第 121.121 条_(a)': '航路导航设施 除本条(b)款规定外， 合格证持有人应当证明， 对于每 一条计划中的航路，非目视地面导航设施符合下列要求： (1)能在空中交通管制要求的精度之内， 在整个航路上为 飞机导航； (2)非目视地面导航设施的位置， 能保证在该运行所必需 的精度范围之内，引导飞机至任一目的地机场或者备降机 场。',
#  'file2_39_第 121.121 条_(b)': '航路导航设施 下列运行不需要非目视地面导航设施： (1)昼间目视飞行规则运行，但合格证持有人应当证明， 能够根据地形的特征，使用地标领航而安全运行； (2)在经局方批准使用特殊导航方法导航的航段上实施 的运行。',
#  'file2_40_第 121.123 条': '地面服务 每个实施补充运行的合格证持有人应当建立相应的地 面服务管理组织机构，在相关的手册中明确对所有地面服务 的培训要求、 外委政策、 管理程序和工作标准、 规范等内容， 并具备足够的合格人员和适当的设施和设备(包括备件、 地面 保障和材料等)， 确保飞机起飞前或者着陆后的地面服务符合 本规则的相应要求。当合格证持有人通过外委方式由他人提 供部分或者全部的地面服务时，合格证持有人应当向相应的 地面服务人员提供必要的训练，并对其操作的安全性负责。',
#  'file2_41_第 121.125 条_(a)': '飞行跟踪系统 实施补充运行的合格证持有人应当证明： (1)具有符合本规则U 章要求的飞行跟踪系统， 该系统根 据所实施的运行可以对每次飞行进行有效的跟踪； (2)飞行跟踪中心应当设在适用于对下列情况实施飞行 跟踪的位置：',
#  'file2_41_第 121.125 条_(i)': '飞行跟踪系统 确保对每次飞行的始发机场和目的地机场的飞行进程 进行适当的监控，包括对中途停留机场和改航备降机场飞行 进程的监控，以及对在这些机场所需的维修或者机械延误进 行适当的监控； (ii)确保机长能够得到安全飞行必需的所有资料。',
#  'file2_41_第 121.125 条_(b)': '飞行跟踪系统 实施补充运行的合格证持有人可以使用非所属人员 提供的飞行跟踪设施，但在这种情况下，合格证持有人应当 对每次飞行的运行控制持续负责。',
#  'file2_41_第 121.125 条_(c)': '飞行跟踪系统 飞行跟踪系统不要求与空中飞行的机组建立通信联 系。',
#  'file2_41_第 121.125 条_(d)': '飞行跟踪系统 在合格证持有人的运行规范中应当明确批准使用的 飞行跟踪系统和飞行跟踪中心的所在位置。',
#  'file2_42_第 121.127 条_(a)': '飞行跟踪系统要求 实施补充运行的每个合格证持有人应当证明： (1)系统具备足够的设备和合格人员， 为下列人员提供每 一次飞行的起始和安全运行所必需的信息：',
#  'file2_42_第 121.127 条_(i)': '飞行跟踪系统要求 每架飞机的飞行机组； (ii)合格证持有人指定实施运行控制的人员。 (2)飞行跟踪系统具有利用公共或者私人设施(例如电 话、电报或者无线电)获得通信的能力，以进行本规则第 121.125 条(a)款第(2)项第(i)目要求的监控。',
#  'file2_42_第 121.127 条_(b)': '飞行跟踪系统要求 实施补充运行的合格证持有人应当证明本条(a)款所 述人员能够履行他们的职责。 G 章 手册的要求',
#  'file2_43_第 121.131 条_(a)': '手册的制定和保存 合格证持有人应当具有为实施其各种运行的全体飞 行、维修和其他地面运行工作人员制定并供其使用和指导其 操作的手册， 并且有合适的手册管理系统， 负责制定、 分发、 修订和补充手册，使其保持现行有效。',
#  'file2_43_第 121.131 条_(b)': '手册的制定和保存 本条(a)款要求的手册应当符合下列要求： (1)包含必需的政策、流程、标准和程序等指令和信息， 使有关人员能安全地完成所担负的工作职责； (2)除局方批准外，使用中文写成。如果合格证持有人在 运行中使用了不熟悉中文的人员，则应当同时为其提供相应 文字的手册，并且应当保证这些手册的一致性和同等有效 性； (3)采用易于修订的形式； (4)在有关的每一页上，标注最后一次修订的日期。对于 电子化的手册，可以以恰当的形式标注最后一次修订的日 期，使人员可以迅速确定有效性； (5)符合所有适用的涉及民航管理的规章、 该合格证持有 人的运行合格证与运行规范；对于实施国际运行的合格证持 有人，还应当符合所适用的外国规章。',
#  'file2_43_第 121.131 条_(c)': '手册的制定和保存 合格证持有人在其主运行基地至少要保存一套完整 的手册。该手册可以是纸质版的手册，也可以是符合局方要 求的其他形式。',
#  'file2_44_第 121.133 条_(a)': '手册内容总体要求 手册应当包含下列所有内容，但可以分为两个或者两个 以上的单独分册，每一分册应当包括所有适用于该类人员的 内容： 概述： (1)与飞行运行有关人员工作内容和责任的说明，包括： 机组成员和飞行签派员在飞行起始、持续、改航和终止阶段 的职能； (2)飞行签派和运行控制，包括：适用的签派协调、飞行 控制、 飞行跟踪程序、 在冲突地区及附近运行风险的管理等； (3)航路飞行、导航和通信程序，包括：当任何所需的特 定设备不工作或者无法提供服务时，签派或者放行飞机继续 飞行； (4)有关机组成员疲劳管理的信息和政策，包括：',
#  'file2_44_第 121.133 条_(i)': '手册内容总体要求 手册应当包含下列所有内容，但可以分为两个或者两个 以上的单独分册，每一分册应当包括所有适用于该类人员的 内容： 干、湿和受污染情况下的起飞跑道长度要求，包括影 响起飞距离的系统失效情况； (ii)起飞爬升限制； (iii)航路爬升限制； (iv)进近爬升限制和着陆爬升限制；',
#  'file2_44_第 121.133 条_(b)': '手册内容总体要求 手册应当包含下列所有内容，但可以分为两个或者两个 以上的单独分册，每一分册应当包括所有适用于该类人员的 内容： 飞机运行信息： (1)飞机型号审定限制和运行限制； (2)飞行机组使用的正常、 非正常和应急程序及有关检查 单； (3)所有发动机工作时爬升性能的操作指示和信息； (4)供飞行前和飞行中制定计划使用的飞行计划数据， 包 含不同的推力、功率和速度设定情况下的数据； (5)所用每个机型的最大侧风和顺风分量限制， 以及在考 虑了阵风、低能见、跑道道面状况、机组经历、自动驾驶使 用、非正常或者紧急情况或者其他有关运行因素影响时，对 这些限制数值进行的缩减； (6)重量与平衡计算方面的操作指示和数据； (7)飞机装载和载荷固定方面的操作指示； (8)可供每一型号飞机运行人员和飞行机组所使用的包 括与该型号飞机运行有关的正常、非正常和应急程序以及该 飞机各系统和所用检查单的详细信息在内的飞机操作手册， 手册的设计还需符合人的因素要求； (9)供所用机型和经批准的特殊运行使用的最低设备清 单和外形缺损清单，其中包含与基于性能导航区域内的运行 有关的任何规定； (10)应急和安全设备的检查单和使用说明； (11)应急撤离程序，包括与机型相关的程序、机组协调、 紧急情况下机组成员的指定位置和紧急情况下每个机组成 员的职责； (12)客舱乘务员所使用的正常、非正常和应急程序，以 及与此有关的检查单和必需的飞机系统信息，并且包括一个 用于解释这些程序是供飞行机组成员和客舱乘务员之间协 调使用的说明； (13)用于不同航路的救生和应急设备清单，以及在起飞 前验证其工作正常的必要程序，包括确定所需氧气量和可用 量的程序； (14)供幸存者使用的地空目视信号说明。',
#  'file2_44_第 121.133 条_(c)': '手册内容总体要求 手册应当包含下列所有内容，但可以分为两个或者两个 以上的单独分册，每一分册应当包括所有适用于该类人员的 内容： 航路和机场： (1)航路信息指导， 用于确保飞行机组每次飞行都能够获 得适用于该运行的通讯设施、助航设备、机场、仪表进近、 仪表进场和仪表离场方面的信息以及承运人认为正确实施 飞行运行所必需其他信息； (2)每一所飞航路的最低飞行高度； (3)可能用作目的地机场或者备降机场的每个机场的运 行最低标准； (4)确定使用平视显示器(HUD)或者等效显示器、增强视 景系统(EVS)、 增强飞行视景系统(EFVS)、 合成视景系统(SVS) 和/或组合视景系统(CVS)等设备的仪表进近机场运行最低标 准的说明； (5)在进近或者机场设施降级的情况下机场运行最低标 准的提高； (6)符合规章要求的所有飞行剖面的必需信息， 包括但不 仅限于下列确定内容：',
#  'file2_44_第 121.133 条_(v)': '手册内容总体要求 手册应当包含下列所有内容，但可以分为两个或者两个 以上的单独分册，每一分册应当包括所有适用于该类人员的 内容： 干、湿和受污染情况下的着陆跑道长度要求，包括影 响着陆距离的系统失效情况； (vi)补充信息，如轮胎速度限制。',
#  'file2_44_第 121.133 条_(d)': '手册内容总体要求 手册应当包含下列所有内容，但可以分为两个或者两个 以上的单独分册，每一分册应当包括所有适用于该类人员的 内容： 训练： 本规则N 章规定的，包含相应地面训练、飞行训练(如 适用)等详细内容的飞行机组成员、 客舱乘务员和飞行签派员 的训练大纲，以保证参加训练的人员在上岗前对于所担负的 工作接受了充分的训练。',
#  'file2_45_第 121.135 条_(a)': '手册的分发和可用性 合格证持有人应当向下列人员提供本规则第121.131 条所要求的手册及其修改和补充，或者该手册的有关部分： (1)维修人员和有关地面运行工作人员； (2)机组成员； (3)负责管理该合格证持有人的局方人员。',
#  'file2_45_第 121.135 条_(b)': '手册的分发和可用性 按照本条(a)款持有手册或者手册相关部分的每个人， 应当使用合格证持有人提供的修改和补充页，使手册内容保 持最新有效状态，并在执行指定任务时可以随时查阅。',
#  'file2_46_第 121.137 条_(a)': '飞机飞行手册 合格证持有人应当为其使用的每一型号飞机保持现 行有效的飞机飞行手册。',
#  'file2_46_第 121.137 条_(b)': '飞机飞行手册 合格证持有人的每架飞机都应当携带用机组人员所 熟悉的语言编写，且满足本条(a)款所要求的飞机飞行手册。 合格证持有人也可以携带按本规则第121.131 条要求编写的 手册， 但该手册应当包含适用本条(a)款飞机飞行手册规定的 信息。',
#  'file2_46_第 121.137 条_(c)': '飞机飞行手册 合格证持有人选择按照本规则第121.131 条编写手册 时，可以对适用本条(a)款飞机飞行手册的操作程序部分进行 修改和对性能数据的编排形式进行调整，但经修改的操作程 序和性能数据编排形式应当被局方批准。',
#  'file2_46_第 121.137 条_(d)': '飞机飞行手册 合格证持有人应当制定并执行适用的管理程序， 以保 证满足本条(a)、(b)款的手册现行有效。 H 章 飞机的要求',
#  'file2_47_第 121.151 条_(a)': '飞机的基本要求 除本条(c)款规定外， 合格证持有人运行的飞机应当符 合下列要求： (1)是在中华人民共和国登记的民用飞机， 并携带现行有 效的适航证、国籍登记证、无线电电台执照和噪声合格审定 的证明文件。噪声合格审定证明文件可以载于本规则第 121.137 条要求的飞机飞行手册中。在国际运行时，该证明 文件必须包括一份英文译文； (2)处于适航状态并符合涉及民航管理的规章适用的适 航要求，包括与标识和设备有关的要求。',
#  'file2_47_第 121.151 条_(b)': '飞机的基本要求 合格证持有人可以使用经批准的重量与平衡控制系 统来符合适用的适航要求和运行限制，该重量与平衡控制系 统可以以平均的、假定的或者估算的重量为基础。',
#  'file2_47_第 121.151 条_(c)': '飞机的基本要求 合格证持有人可以租用不含机组人员的国际民用航 空公约缔约国所属的某一国家登记的民用飞机实施本规则 运行，但应当符合下列规定： (1)该飞机带有经中国民航局审查认可的原国籍登记国 颁发的适航证和由中国民航局颁发的适航认可证书，以及无 线电电台执照和噪声合格审定的证明文件； (2)合格证持有人已将该飞机的租赁合同副本报局方。',
#  'file2_48_第 121.153 条': '飞机的审定和设备要求 合格证持有人按照本规则运行的飞机应当是型号合格 审定为运输类的飞机，并符合本规则第121.173 条的要求， 否则不得实施本规则运行。',
#  'file2_49_第 121.155 条': '禁止使用单台发动机飞机 合格证持有人不得使用单台发动机的飞机实施本规则 运行。',
#  'file2_50_第 121.157 条_(a)': '飞机的航路类型限制 除经依据本规则W 章的规定得到局方批准且满足合 格证持有人运行规范许可的条件下，合格证持有人不得使用 以涡轮发动机为动力的飞机实施以下运行： (1)延程运行(EDTO)； (2)在北极区域内的运行； (3)在南极区域内的运行。',
#  'file2_50_第 121.157 条_(b)': '飞机的航路类型限制 合格证持有人用于延伸跨水运行的陆上飞机， 应当是 按照《运输类飞机适航标准》(CCAR-25)中的水上迫降规定 审定合格或者被批准为适合于水上迫降的飞机。',
#  'file2_51_第 121.159 条_(a)': '飞机的运行验证试飞 合格证持有人使用以前未在公共航空运输运行中使 用过的飞机，应当完成局方认可的至少100 小时的运行验证 试飞，包括相当数量的进入航路机场的飞行。在运行验证试 飞过程中，如果局方认为试飞已达到令人满意的熟练水平， 则局方可以减少验证试飞时间。上述运行验证试飞至少应当 有10 小时在夜间完成。',
#  'file2_51_第 121.159 条_(b)': '飞机的运行验证试飞 除经局方特殊批准外， 合格证持有人首次使用曾在公 共航空运输运行中使用过的某一型号飞机，或者使用在设计 上做了实质性更改的某一型号飞机，则在拟使用该飞机实施 运行之前，应当完成经局方认可的至少25 小时的运行验证 试飞，包括相当数量的进入航路机场的飞行。',
#  'file2_51_第 121.159 条_(c)': '飞机的运行验证试飞 本条(b)款所述飞机在设计上进行了实质性更改是指 下列情形之一： (1)整套动力装置的型号与飞机合格审定时所装动力装 置的型号不相类似； (2)对飞机或者其部件进行了实质上影响其飞行特性的 更改。',
#  'file2_51_第 121.159 条_(d)': '飞机的运行验证试飞 除了实施试飞所需的人员和局方指定的人员之外， 合 格证持有人不得在运行验证试飞的飞机上携带旅客。经局方 批准，运行验证试飞的飞机可以携带邮件、快递或者其他货 物。',
#  'file2_52_第 121.161 条_(a)': '应急撤离程序的演示 合格证持有人应当依照本规则附件C《本规则第 121.161 条规定的应急撤离程序演示准则》(a)款规定进行应 急撤离程序的实际演示，证明在载客飞行中所用的旅客座位 数大于44 座的每个型号的飞机，能够使包括机组成员在内 的满载量乘员在90 秒(含)以内撤离飞机。但是，如果该型号 飞机已被证明符合本规则附件C(a)款规定或者适用的型号合 格审定标准，可以不实施实际的演示。',
#  'file2_52_第 121.161 条_(b)': '应急撤离程序的演示 使用旅客座位数大于44 座的飞机实施载客运行的合 格证持有人，有下列情形之一的，应当按照本条(c)款进行应 急撤离程序的部分演示： (1)该合格证持有人新引进的某型号飞机投入载客飞行 并且该合格证持有人没有按照本条(a)款实施实际演示； (2)本规则第121.391 条所要求的客舱乘务员的人数、位 置或者其应急撤离职责、程序发生改变； (3)应急出口的数量、位置、型号或者供撤离用的应急出 口开启机构的型号发生改变。',
#  'file2_52_第 121.161 条_(c)': '应急撤离程序的演示 在实施本条(b)款要求的部分演示时， 合格证持有人应 当遵守下列规定： (1)实施不要求旅客参加但要在局方观察下进行的演示， 以验证其机组成员应急生存训练和应急撤离程序的有效性。 在这种演示中，该型号飞机的客舱乘务员，应当使用该合格 证持有人的航线操作程序，按照本规则第121.397 条规定的 应急撤离职责，打开50％所要求的地板高度的应急出口和 50％所要求的非地板高度的应急出口， 并放下50％的应急出 口滑梯。这些应急出口和滑梯由局方选定，并且应当在15 秒钟内准备就绪以供使用； (2)在实施这种演示之前， 向负责监督其运行的民航地区 管理局提出申请； (3)在这种演示中使用的客舱乘务员， 由局方从已经完成 合格证持有人经局方批准的该型号飞机训练大纲的训练并 已通过应急设备和应急程序考试的客舱乘务员中随机挑选； (4)在开始实施该型号飞机的运行之前， 向负责监督其运 行的民航地区管理局提出申请并获得批准。',
#  'file2_52_第 121.161 条_(d)': '应急撤离程序的演示 每个使用或者计划使用一架或者多架陆上飞机作延 伸跨水运行或者按照要求配备相应应急设备的合格证持有 人，应当按照本规则附件C(b)款进行模拟水上迫降，证明其 能有效地完成水上迫降程序。',
#  'file2_52_第 121.161 条_(e)': '应急撤离程序的演示 对于已经由其他合格证持有人进行过本条(d)款规定 的模拟水上迫降的那种型号飞机，如果每个救生筏都从其存 放处取下，其中一个救生筏被投放并充气或者一个滑梯救生 筏被充气，并且指定负责该充气救生筏或者滑梯救生筏的机 组成员表演并说明了每项必需应急设备的使用，则认为已经 符合本规则附件C(b)款第(2)项、(b)款第(4)项和(b)款第(5)项 的要求。前述待充气的救生筏或者滑梯救生筏由局方选定。 I 章 飞机性能使用限制',
#  'file2_53_第 121.171 条_(a)': '用语定义 本章中的用语按照下述定义： 可用着陆距离(LDA)：是指公布的可用并适于飞机着 陆的跑道长度。',
#  'file2_53_第 121.171 条_(b)': '用语定义 本章中的用语按照下述定义： 飞行轨迹(flight path)：是指飞机在三维空间中的飞行 路线。',
#  'file2_53_第 121.171 条_(c)': '用语定义 本章中的用语按照下述定义： 航迹(track)：是指飞机飞行轨迹在地球表面上的水平 投影。',
#  'file2_54_第 121.173 条_(a)': '概则 使用涡轮发动机驱动的飞机的合格证持有人应当遵 守本规则第121.189 条至第121.197 条的规定。',
#  'file2_54_第 121.173 条_(b)': '概则 合格证持有人应当使用飞机飞行手册中的性能数据 来确定是否符合本规则第121.189 条至第121.197 条的规定。 当涉及的条件与这些性能数据所依据的条件不同时，如果内 插法或者计算法所得结果在实质上与直接试验的结果同样 准确，则可以用内插法或者通过计算具体变量变化的影响来 确定是否符合规定。合格证持有人在确定是否符合本规则第 121.189条至第121.197条的规定时还应当考虑到所用航图的 精度。',
#  'file2_54_第 121.173 条_(c)': '概则 如果在特殊的环境条件下遵守某些规定对于安全已 无必要，局方可以在运行规范中批准偏离本章的这些要求。',
#  'file2_55_第 121.189 条_(a)': '涡轮发动机驱动的飞机的起飞限制 涡轮发动机驱动的飞机不得以大于该飞机飞行手册 中对应于该机场气压高度和起飞时环境温度所确定的重量 起飞。',
#  'file2_55_第 121.189 条_(b)': '涡轮发动机驱动的飞机的起飞限制 涡轮发动机驱动的运输类飞机不得以大于该飞机飞 行手册中规定的重量起飞，该重量应当保证飞机符合下列各 项要求： (1)加速停止距离不得超过跑道长度加上停止道的长度； (2)起飞距离不得超过跑道长度加上净空道长度， 且净空 道长度不得大于跑道长度的一半； (3)起飞滑跑距离不得大于跑道长度。',
#  'file2_55_第 121.189 条_(c)': '涡轮发动机驱动的飞机的起飞限制 涡轮发动机驱动的飞机不得以大于该飞机飞行手册 中所确定的某个重量起飞，在该重量下，预定净起飞飞行轨 迹以10.7 米(35 英尺)的余度超越所有障碍物， 或者能以一个 特定距离侧向避开障碍物。该特定距离的值为下列两目中规 定值的较小值： (1)90 米(300 英尺)＋0.125D，其中D 是指飞机离可用起 飞距离末端的距离值； (2)对于目视飞行规则飞行， 预定航迹的航向变化小于15 度时，为300 米，预定航迹的航向变化大于15 度时，为600 米；对于仪表飞行规则飞行，预定航迹的航向变化小于15 度时，为600 米，预定航迹的航向变化大于15 度时，为900 米。',
#  'file2_55_第 121.189 条_(d)': '涡轮发动机驱动的飞机的起飞限制 在依据本条(a)款至(c)款确定最大重量、 最小距离和飞 行轨迹时，应当对拟用的跑道、机场的标高、有效跑道坡度 和起飞时的环境温度、风的分量进行修正。',
#  'file2_55_第 121.189 条_(e)': '涡轮发动机驱动的飞机的起飞限制 就本条而言， 假定飞机在到达15.2 米(50 英尺)高度(按 照飞机飞行手册中起飞飞行轨迹或者净起飞飞行轨迹数据 中的适用者)之前无坡度。此后，在120 米(400 英尺)高度以 下，飞机转弯坡度不超过15 度；在120 米(400 英尺)高度以 上，飞机转弯坡度不超过25 度。',
#  'file2_55_第 121.189 条_(f)': '涡轮发动机驱动的飞机的起飞限制 就本条而言， “起飞距离”“起飞滑跑距离”“净起飞飞行 轨迹”和“起飞飞行轨迹”等术语， 与对该飞机进行型号合格审 定的规章中所规定的术语具有相同的含义。',
#  'file2_56_第 121.191 条_(a)': '涡轮发动机驱动的飞机的航路限制—— 一台发动机不工作 涡轮发动机驱动的飞机不得超过某一重量起飞，在该 重量下，考虑到正常的燃油、滑油消耗和航路上预计的环境 温度，根据经批准的该飞机飞行手册确定的一台发动机不工 作时的航路净飞行轨迹数据应当能够符合下列两项要求之 一： (1)在预定航迹两侧各25 公里(13.5 海里)范围内的所有 地形和障碍物上空至少300 米(1,000 英尺)的高度上有正梯 度，并且，在发动机失效后飞机要着陆的机场上空450 米 (1,500 英尺)的高度上有正梯度； (2)净飞行轨迹允许飞机由巡航高度继续飞到可以按照 本规则第121.197 条要求进行着陆的机场，能以至少600 米 (2,000 英尺)的余度垂直超越预定航迹两侧各25 公里(13.5 海 里)范围内所有地形和障碍物， 并且在发动机失效后飞机要着 陆的机场上空450 米(1,500 英尺)的高度上有正梯度。',
#  'file2_56_第 121.191 条_(b)': '涡轮发动机驱动的飞机的航路限制—— 一台发动机不工作 就本条(a)款第(2)项而言，假定： (1)发动机在航路上最临界的一点失效； (2)飞机在发动机失效点之后飞越临界障碍物， 该点应当 能够使用有效的方式定位； (3)使用经批准的方法考虑了不利的风的影响； (4)如果合格证持有人证明，机组人员进行了恰当的训 练，并且采取了其他安全措施，能保证程序的安全性，则允 许应急放油； (5)在签派或者放行单中指定了备降机场， 且该备降机场 符合规定的最低气象条件； (6)发动机失效后燃油和滑油的消耗与飞机飞行手册中 经批准的净飞行轨迹数据所给定的消耗相同。',
#  'file2_57_第 121.193 条_(a)': '三台或者三台以上涡轮发动机驱动的飞 机的航路限制——两台发动机不工作 三台或者三台以上涡轮发动机驱动的飞机沿预定航路 运行时，应当符合下列两款要求之一： 预定航迹上任何一点到符合本规则第121.197 条要求 的机场的飞行时间不超过所有发动机以巡航功率工作飞行 90 分钟。',
#  'file2_57_第 121.193 条_(b)': '三台或者三台以上涡轮发动机驱动的飞 机的航路限制——两台发动机不工作 三台或者三台以上涡轮发动机驱动的飞机沿预定航路 运行时，应当符合下列两款要求之一： 根据飞机飞行手册中航路上两台发动机不工作的净 飞行轨迹数据，其重量允许该飞机从假定两台发动机同时失 效的地点，飞到符合本规则第121.197 条要求的某一机场。 在这段飞行中，考虑到沿该航路的预计环境温度，其净飞行 轨迹在垂直方向上至少高出预定航迹两侧各25 公里(13.5 海 里)范围内所有地形和障碍物600 米(2,000 英尺)。就本款而 言，假定： (1)两台发动机在航路上最临界的地点失效； (2)这些发动机失效后在预定着陆的机场正上空450 米 (1,500 英尺)处，该净飞行轨迹具有正梯度； (3)如果合格证持有人证明，机组人员进行了恰当的训 练，并且采取了其他预防措施，能保证程序的安全性，则可 以批准应急放油； (4)在两台发动机失效的那一点， 该飞机重量包含有足够 的燃油，使其能继续飞到该机场正上空至少450 米(1,500 英 尺)的高度，此后还能以巡航功率或者推力飞行15 分钟； (5)发动机失效后， 燃油和滑油的消耗与飞机飞行手册中 净飞行轨迹数据所给定的消耗相同。',
#  'file2_58_第 121.195 条_(a)': '涡轮发动机驱动的飞机的着陆限制—— 目的地机场 涡轮发动机驱动的飞机起飞前， 应当在考虑到至目的 地机场或者备降机场飞行中正常的燃油和滑油消耗后，使飞 机到达时的重量不得超过该飞机飞行手册中对该目的地机 场或者备降机场的气压高度以及着陆时预计的环境温度所 确定的着陆重量。',
#  'file2_58_第 121.195 条_(b)': '涡轮发动机驱动的飞机的着陆限制—— 目的地机场 除本条(c)、(d)、(e)款规定外，涡轮发动机驱动的飞 机起飞前，应当在考虑到飞行中正常的燃油和滑油消耗后， 使该飞机到达目的地时的重量，根据飞机飞行手册中对该目 的地机场的气压高度和预计在着陆时当地风的情况所规定 的着陆距离，允许其在预定的目的地机场的跑道上，在可用 着陆距离(LDA)的60％以内作全停着陆。为确定在目的地机 场的允许着陆重量，假定： (1)飞机在最有利的跑道和方向、静风条件下着陆； (2)考虑到可能的风速、风向和该飞机的地面操纵特性， 以及考虑到诸如着陆助航设备和地形等其他条件，飞机在最 适宜的跑道上着陆。',
#  'file2_58_第 121.195 条_(c)': '涡轮发动机驱动的飞机的着陆限制—— 目的地机场 对于不能符合本条(b)款第(2)项的要求而被禁止起飞 的涡轮螺旋桨驱动的飞机，如果指定了备降机场，除允许飞 机在备降机场可用着陆距离(LDA)的70％以内完成全停着陆 外，该备降机场符合本条所有其他要求，则可以允许该飞机 起飞。',
#  'file2_58_第 121.195 条_(d)': '涡轮发动机驱动的飞机的着陆限制—— 目的地机场 对于涡轮喷气飞机， 在有关的气象报告和预报表明目 的地机场跑道在预计着陆时刻可能是湿的时，该目的地机场 跑道的可用着陆距离(LDA)应当至少为本条(b)款所要求的跑 道长度的115％，否则，该飞机不得起飞。如果在湿跑道上 的实际着陆技术证明，对特定型号的飞机，已经批准了某一 较短但绝不小于本条(b)款要求的着陆距离， 并且已经载入飞 机飞行手册，则可以按照手册的要求执行。',
#  'file2_58_第 121.195 条_(e)': '涡轮发动机驱动的飞机的着陆限制—— 目的地机场 对于涡轮喷气飞机， 在有关的气象报告和预报表明目 的地机场跑道在预计着陆时刻可能是污染的时，该目的地机 场的可用跑道长度应当至少为以下距离中的较大者： 本条(b) 款所要求的跑道长度的115%，以及根据认可的污染跑道实 际着陆距离数据确定的着陆距离的115%，否则，该飞机不 得起飞。如果上述污染跑道的道面已经进行了特殊处理，而 且实际着陆技术证明，对特定型号的飞机，已经批准了某一 较短但不小于本条(b)款要求的着陆距离， 并且已经载入飞机 飞行手册，则可以按照手册的要求执行。',
#  'file2_58_第 121.195 条_(f)': '涡轮发动机驱动的飞机的着陆限制—— 目的地机场 由于不能符合本条(b)款第(2)项而被禁止起飞的涡轮 喷气动力的飞机， 如果指定了符合本条(b)款所有要求的备降 机场，则可以起飞。',
#  'file2_59_第 121.197 条': '涡轮发动机驱动的飞机的着陆限制—— 备降机场 在涡轮发动机驱动的飞机的签派或者放行单中列为备 降机场的机场，应当能使该飞机在到达该备降机场时以根据 本规则第121.195 条(b)款规定的假定条件预计的重量，在跑 道可用着陆距离(LDA)的70％(涡轮螺旋桨动力飞机)或者 60％(涡轮喷气动力飞机)以内完成全停着陆。对于本规则第 121.637 条所规定的起飞备降机场，在确定到达时的预计重 量时， 除正常的燃油和滑油消耗之外， 可以考虑应急放油量。 J 章 特殊适航要求',
#  'file2_60_第 121.211 条': '概则 合格证持有人的飞机除满足相应型号合格审定要求外， 还应当符合本章的特殊适航要求。',
#  'file2_61_第 121.213 条_(a)': '旅客座椅间距 对于2006 年7 月1 日后加入合格证持有人运行规范 的任何载客运行的飞机应当满足本条(b)款的要求。',
#  'file2_61_第 121.213 条_(b)': '旅客座椅间距 合格证持有人运行的任何载客运行的飞机， 其座椅间 距应当满足下列要求： (1)任何座椅椅背与前面座椅椅背或者其他的固定结构 之间的距离不得小于660 毫米(26 英寸)； (2)任何座椅与前面的座椅或者其他的固定结构之间的 距离不得小于178 毫米(7 英寸)； (3)前后排座椅之间或者座椅与前面的任何固定结构之 间的垂直投影距离不得小于76 毫米(3 英寸)。',
#  'file2_61_第 121.213 条_(c)': '旅客座椅间距 对于本条(b)款要求的距离的测量应当满足下列要求： (1)对于(b)款第(1)项要求的距离，以椅背腰垫(没有被压 缩)76 毫米(3 英寸)高处为原点，在距地板635 毫米(25 英寸) 以下的整个座椅宽度范围内测量与前面座椅或者其他固定 结构之间的水平方向和垂直方向的距离(如下图所示)； (2)对于(b)款第(2)项要求的距离，以椅垫和扶手最前端 为原点测量水平方向和垂直方向的距离(如下图所示)； (3)对于(b)款第(3)项要求的距离，测量椅垫和扶手最前 端的投影与前面座椅或者固定结构的最后端的投影之间的 距离(如下图所示)。',
#  'file2_61_第 121.213 条_(d)': '旅客座椅间距 对于有杂志袋和小桌板的座椅， 在所有测量时杂志袋 应当正常装载有关的客舱安全说明、清洁袋和合格证持有人 提供的机上读物， 小桌板应当在正常的收起位置(起飞和着陆 位置)。',
#  'file2_61_第 121.213 条_(e)': '旅客座椅间距 所有测量应当在座椅调直和扶手放下的状态(起飞和 着陆状态)下测量。 座椅间距测量方法示意图',
#  'file2_62_第 121.215 条_(a)': '在客舱内装货 除本条(b)款或者(c)款规定之外， 按照本规则运行的合 格证持有人不得在飞机客舱内运载货物。',
#  'file2_62_第 121.215 条_(b)': '在客舱内装货 如果货物在经批准的货箱之内且货箱满足下列要求， 货物可以装在客舱内任一位置： (1)货箱应当能承受适用于装有该货箱的飞机的旅客座 椅载荷系数和应急着陆条件1.15 倍的过载， 计算时要用货箱 重量和货箱中可以装载货物的最大重量的总重量； (2)货箱上应当清晰地标出该货箱准许装载的货物的最 大重量以及为保证货箱内正确的重量分布而必需的任何说 明； (3)货箱施加的载荷不得超过地板或者飞机其他结构件 的载荷限制； (4)货箱应当固定在座椅滑轨或者飞机地板结构件上， 其 固定点应当能承受适用于货箱安装于其上的飞机的旅客座 椅的载荷系数和应急着陆情况一定倍数的过载，该倍数为 1.15 或者为该飞机规定的座椅固定系数，二者中取较大者， 计算时要用货箱重量和在其中可能装载货物的最大重量的 总重量； (5)货箱不得装于妨碍通达或者使用任何需要的应急出 口或者客舱通道之处； (6)货箱应当为全封闭式的， 而且应当用至少为阻燃的材 料制成； (7)货箱内应当有适当的安全防护装置以防止货物在应 急着陆情况下发生移动； (8)货箱不得安装在会遮挡任一旅客观察“系好安全带” 标牌、“请勿吸烟”标牌或者任何所需要的出口标记的位置， 除非备有辅助标记或者其他经批准的可以给旅客适当通告 的措施。',
#  'file2_62_第 121.215 条_(c)': '在客舱内装货 只要在《运输类飞机适航标准》(CCAR-25)第25.561 条(b)款第(3)项规定的载荷系数所对应的过载条件下能将货 物束缚住，并且按照下列要求装载，则货物可以装于任一客 舱内的隔框或者隔板后面： (1)货物用安全带或者其他具有足够强度的系留索适当 紧固；使货物在所有可以预计的正常飞行和地面情况下不可 能移动； (2)其包装或者覆盖方式能避免对旅客和客舱内人员可 能的伤害； (3)不会对座椅或者地板结构加上超过这些部件载荷限 制的任何载荷； (4)其位置不妨碍通达或者使用任何需要的应急出口、 正 常出口或者客舱内的通道； (5)其位置不遮拦任一旅客观察“系好安全带”标牌、“请 勿吸烟”标牌或者所需要的出口标记的视线， 除非备有辅助标 记或者其他经批准的可以给旅客适当通告的措施。',
#  'file2_63_第 121.217 条': '在货舱内装货 当货物装在其设计要求机组从外部进入其中以扑灭飞 行中可能发生的任何火情的货舱内时，货物的装载应当使机 组人员能携带手提灭火器有效地到达舱内所有部位。 K 章 仪表和设备要求',
#  'file2_64_第 121.301 条_(a)': '概则 除具体指明适用于特定运行的条款外， 本规则关于仪 表和设备的要求适用于按照本规则实施的所有运行。',
#  'file2_64_第 121.301 条_(b)': '概则 本规则第121.305 条至第121.360 条所要求的仪表和 设备，应当按照适用的适航要求进行批准和安装。',
#  'file2_64_第 121.301 条_(c)': '概则 每个空速指示器应当以公里/小时或者海里／小时为 单位校准，并且飞机飞行手册和有关标牌中的每个空速限制 和有关资料中的空速应当相应地以公里/小时或者海里／小 时表示。',
#  'file2_64_第 121.301 条_(d)': '概则 除经局方批准外， 2005 年7 月1 日后首次投入运行的 飞机应当装备有以米为单位显示的高度表。如果该飞机需在 以英尺为单位确定飞行高度的国家或者地区运行，则应当同 时装备有以英尺为单位显示的高度表。',
#  'file2_64_第 121.301 条_(e)': '概则 除本规则第121.645 条(b)款和第121.647 条规定外， 只有当下列仪表和设备处于工作状态，方可以使飞机起飞： (1)为符合对该飞机进行型号合格审定的适航要求所要 求的仪表和设备； (2)本规则第121.305 条至第121.319 条和第121.359 条、 第121.360 条以及第121.743 条中规定的适用于所有运行的 仪表与设备，以及本规则第121.323 条至第121.351 条中规 定的适用于不同运行类型的仪表与设备，而这些仪表与设备 在本款第(1)项未作出要求。',
#  'file2_65_第 121.305 条_(a)': '飞机仪表和设备 按照本规则运行的飞机应当装备下列飞行和导航的仪 表与设备： 一个空速指示系统， 带有加温空速管或者可以防止由 于结冰而失效的等效装置。对于以马赫数为单位来表示速度 限制的飞机，则还应至少装有一个马赫数指示器。',
#  'file2_65_第 121.305 条_(b)': '飞机仪表和设备 按照本规则运行的飞机应当装备下列飞行和导航的仪 表与设备： 一个灵敏高度表，带有以百帕斯卡(毫巴)为单位的校 正装置，并且该装置对于飞行中可能遇到的气压可以进行修 正。',
#  'file2_65_第 121.305 条_(c)': '飞机仪表和设备 按照本规则运行的飞机应当装备下列飞行和导航的仪 表与设备： 一个带指针和/或数字式显示的精确指示小时、 分和秒 的时钟(或者经批准的等效装置)。',
#  'file2_65_第 121.305 条_(d)': '飞机仪表和设备 按照本规则运行的飞机应当装备下列飞行和导航的仪 表与设备： 一个大气静温指示器。',
#  'file2_65_第 121.305 条_(e)': '飞机仪表和设备 按照本规则运行的飞机应当装备下列飞行和导航的仪 表与设备： 一个陀螺坡度与俯仰指示器(地平仪)。',
#  'file2_65_第 121.305 条_(f)': '飞机仪表和设备 按照本规则运行的飞机应当装备下列飞行和导航的仪 表与设备： 一个组合有侧滑指示器的陀螺转弯速率指示器，但在 按照本条(k)款装有第三套姿态仪表系统(可以在360°俯仰和 滚转飞行姿态中使用)时，只需要侧滑指示器。',
#  'file2_65_第 121.305 条_(g)': '飞机仪表和设备 按照本规则运行的飞机应当装备下列飞行和导航的仪 表与设备： 一个陀螺航向指示器(航向陀螺或者等效仪表)。',
#  'file2_65_第 121.305 条_(h)': '飞机仪表和设备 按照本规则运行的飞机应当装备下列飞行和导航的仪 表与设备： 一个磁罗盘。',
#  'file2_65_第 121.305 条_(i)': '飞机仪表和设备 按照本规则运行的飞机应当装备下列飞行和导航的仪 表与设备： 一个垂直速度指示器(升降率指示器)。',
#  'file2_65_第 121.305 条_(j)': '飞机仪表和设备 按照本规则运行的飞机应当装备下列飞行和导航的仪 表与设备： 当运行要求有两名驾驶员时，第二名驾驶员位置处应 具有以下参数的显示： (1)气压高度； (2)指示空速； (3)垂直速度； (4)转弯和侧滑； (5)姿态； (6)航向。',
#  'file2_65_第 121.305 条_(k)': '飞机仪表和设备 按照本规则运行的飞机应当装备下列飞行和导航的仪 表与设备： 除局方批准的某些涡桨飞机外，在涡轮动力飞机上， 除在每位驾驶员工作位置上各有一个陀螺坡度与俯仰指示 器(地平仪)可以供使用之外，还应当配备满足下列要求的第 三套陀螺坡度与俯仰指示器(地平仪)： (1)由独立于飞机正常发电系统的应急备用电源供电； (2)在正常发电系统全部失效之后至少能继续可靠地工 作30 分钟； (3)不依赖任何其他姿态指示系统而独立工作； (4)在正常发电系统全部失效之后无需选择就能工作； (5)位于仪表板局方认可的位置上， 使得任一驾驶员在其 工作位置上都能清楚地看见并使用； (6)在使用的所有阶段均有适当照明。',
#  'file2_65_第 121.305 条_(l)': '飞机仪表和设备 按照本规则运行的飞机应当装备下列飞行和导航的仪 表与设备： 对于本条要求的飞行和导航设备： (1)可以通过仪表组合或者中央飞行系统或者在电子显 示器上参数的组合来满足这些条款的各项要求，但要求每一 必需驾驶员能够获得的信息不少于本条所规定的仪表及相 应设备提供的信息； (2)可以使用其他等效符合性方法来满足这些条款的设 备要求，但要求在飞机型号审定批准过程中已表明该方法具 有等效的安全水平。',
#  'file2_66_第 121.307 条_(a)': '发动机仪表 除局方对涡轮发动机另有规定外，按照本规则实施运行 的飞机应当按照下列要求安装发动机仪表： 所有涡轮发动机。 (1)每台发动机一个燃油压力警告装置， 或者所有发动机 一个总警告装置，并有分离各单独警告的措施； (2)每个燃油箱一个燃油油量表； (3)每个滑油箱一个滑油油量指示器； (4)每台发动机每个独立的滑油压力系统一个滑油压力 表； (5)每台发动机一个滑油压力警告装置， 或为所有发动机 提供一个主警告并带有将单个警告从主警告中分离开的手 段； (6)每台发动机一个滑油温度表； (7)能够提供视觉和听觉警告的火警装置； (8)每台发动机一个燃气温度表； (9)每台发动机一个燃油流量表； (10)每台发动机一个转速表(指示有转速限制转子的转 速)； (11)每台发动机一个动力装置防冰系统功能指示器。',
#  'file2_66_第 121.307 条_(b)': '发动机仪表 除局方对涡轮发动机另有规定外，按照本规则实施运行 的飞机应当按照下列要求安装发动机仪表： 涡轮喷气发动机。除本条(a)款要求的动力装置仪表 外，还需装有下列动力装置仪表： (1)一个向飞行机组指示推力或者与推力直接有关的参 数的指示器。其指示必须以对推力或者该参数的直接测量为 依据。该指示器必须能指示发动机故障、损坏或者性能降低 所造成的推力变化； (2)当反推装置处于下列状态时， 位置指示装置向飞行机 组给出指示：',
#  'file2_66_第 121.307 条_(i)': '发动机仪表 除局方对涡轮发动机另有规定外，按照本规则实施运行 的飞机应当按照下列要求安装发动机仪表： 未处在选定位置； (ii)处在反推位置，对每台使用了反推装置的发动机。 (3)一个指示转子系统不平衡状态的指示器。',
#  'file2_66_第 121.307 条_(c)': '发动机仪表 除局方对涡轮发动机另有规定外，按照本规则实施运行 的飞机应当按照下列要求安装发动机仪表： 涡轮螺旋桨发动机。 除本条(a)款要求的动力装置仪表 外，还需装有下列动力装置仪表： (1)每台发动机一个扭矩表； (2)每具螺旋桨一个位置指示器， 在螺旋桨桨叶角小于飞 行低距位置时向飞行机组发出指示。',
#  'file2_67_第 121.308 条_(a)': '厕所防火 除经局方批准外，按照本规则运行的载客飞机应当在 每个厕所装备烟雾探测系统或者等效装置，并能在驾驶舱提 供警告灯光，或者在客舱中提供易于客舱机组发现的警告灯 光或者音响警告。',
#  'file2_67_第 121.308 条_(b)': '厕所防火 除经局方批准外， 按照本规则运行的载客飞机应当在 每个厕所每个处置纸制品或者废物的容器内装备内置式固 定灭火器。该固定灭火器应当设计成当容器内失火时，能自 动向容器内喷射灭火剂。',
#  'file2_68_第 121.309 条_(a)': '应急设备 只有装备本条和本规则第121.310 条所列的应急设备 的飞机，方可以按照本规则实施运行。',
#  'file2_68_第 121.309 条_(b)': '应急设备 本条和本规则第121.310 条和第121.339 条所列的每 项应急设备和漂浮设备应当符合下列要求： (1)依照运行规范中规定的检验周期予以定期检验， 以确 保其处于持续可用和立即工作的状态，执行其预定的应急用 途； (2)易于机组成员取用， 位于客舱的设备应当易于旅客取 用； (3)具有清楚的标识和标记，指明其使用方法，旅客取用 的设备文字说明应当至少有中文； (4)当装在某一舱室或者某一容器中时， 在该舱室或者容 器上易于观察的地方至少用中文标明其所装物品以及上次 检验的日期。',
#  'file2_68_第 121.309 条_(c)': '应急设备 在驾驶舱、 客舱、 货舱、 厨房内， 应当按照下列规定， 装备经批准型号的手提灭火器： (1)灭火剂的型号和装量应当适用于该舱室可能发生的 失火类型，并且对于客舱，应当设计成使有毒气体聚积的危 险性减到最小。 对于2018 年12 月31 日(含)或者其后首次颁 发单机适航证的飞机上配备的手提灭火器，所用各类灭火剂 都应当符合与臭氧层保护相关的环保要求，包括使用等效环 保灭火剂替代对本款第(7)项要求的Halon 1211(溴氯二氟甲 烷)灭火剂； (2)货舱。 对于飞行中机组成员能够进入的E 级货舱， 应 当配备至少一个手提灭火器，并放置于方便取用的地方； (3)厨房隔舱。对于位于客舱、货舱或者驾驶舱之外隔舱 内的厨房，应当在每个厨房内至少装备一个便于取用的手提 灭火器； (4)驾驶舱。 驾驶舱内应当至少装备一个便于飞行机组使 用的手提灭火器； (5)客舱。 在客舱使用的手提灭火器应当放置于方便的位 置上。在要求配备两个或者两个以上手提灭火器时，这些设 备应当均匀地分布于每个客舱内。应当按照下列要求配备手 提灭火器：',
#  'file2_68_第 121.309 条_(i)': '应急设备 对于旅客座位数7 至30 的飞机，至少配备一个； (ii)对于旅客座位数31 至60 的飞机，至少配备两个； (iii)对于旅客座位数60 以上的飞机，至少配备下列数量 的手提灭火器： 旅客座位数 手提灭火器的最小数量 61 至200 座 3 个 201 至300 座 4 个 301 至400 座 5 个 401 至500 座 6 个 501 至600 座 7 个 601 座或者以上 8 个 (6)尽管本条(c)款第(5)项要求手提灭火器均匀分布， 如果 在客舱中有厨房，应当至少有一个手提灭火器位于方便之处 并易于在厨房中取用； (7)载客飞机所要求配备的手提灭火器中至少2个应当装 Halon 1211(溴氯二氟甲烷)或者等效的灭火剂。 客舱中应当至 少有一个这样的灭火器。',
#  'file2_68_第 121.309 条_(d)': '应急设备 载运旅客的飞机上应当配备本规则第121.743 条要求 的应急医疗设备。',
#  'file2_68_第 121.309 条_(e)': '应急设备 应急斧。每架飞机应当配备至少一把应急斧。',
#  'file2_68_第 121.309 条_(f)': '应急设备 扩音器。每架载客飞机应当配有电池供电的便携式扩 音器，放在负责指挥应急撤离的机组成员方便取用的地方， 其配备数量和位置符合下列规定： (1)在旅客座位数61 至99(含)的飞机上配备一个，安放 在客舱后部从客舱乘务员座位易于取用处。但是，如果局方 认为安放在其他位置可能对应急情况下人员的撤离更为适 合，可以批准偏离本款的要求； (2)在旅客座位数大于99的飞机客舱内配备两个扩音器， 一个安放在前部，另一个安放在后部，并且易于从客舱乘务 员座位处取用。',
#  'file2_69_第 121.310 条_(a)': '附加应急设备 应急撤离设施。当飞机停放于地面且起落架放下时， 应急出口(机翼上方的应急出口除外)距地面高度超过183 厘 米(6 英尺)的每一载客陆上飞机， 应当有经批准的可以帮助机 上人员撤到地面的设施。用于地板高度应急出口的这种辅助 设施应当符合《运输类飞机适航标准》(CCAR-25)第25.810 条的相应适航要求。能自动放出的辅助设施在滑行、起飞和 着陆期间应当处于待命状态。但是，如果局方认为这个出口 的设计使得满足这些要求不切实际，则局方可以批准偏离关 于自动放出的要求，但该辅助设施在放出时应能自动展开， 并按照本规则第121.161 条(a)款的规定对所要求的应急出口 进行应急撤离演示。',
#  'file2_69_第 121.310 条_(b)': '附加应急设备 机内应急出口标记。每架载客飞机应当符合下列要 求： (1)每个旅客应急出口，其通达方式及开启方法，应当有 明显易懂的标记。每个旅客应急出口本身及其位置应当能从 等同于客舱宽度的距离上认清。每个旅客应急出口的所在位 置应当用机上人员能看到的沿客舱主通道的标志指明，下述 部位应当有位置指示标志：',
#  'file2_69_第 121.310 条_(i)': '附加应急设备 地板高度的出口。 机身侧面高等于或者大于1118 毫米 (44 英寸)、 宽等于或者大于508 毫米(20 英寸)但不到1168 毫 米(46 英寸)的每个地板高度的舱门或者出口(不包括那些不 能由客舱进入的通向货舱或者行李舱的舱门或者出口)、 每个 机身下部出口和每个尾锥出口，应当符合本条关于地板高度 应急出口的要求。但是，如果环境条件使得完全满足这些要 求不切实际，并且偏离这些要求能够达到可以接受的安全水 平，局方可以批准偏离本款的要求。',
#  'file2_69_第 121.310 条_(c)': '附加应急设备 机内应急出口标志的照明。 每架载客飞机应当具有独 立于主照明系统的应急照明系统。但是，如果应急照明系统 的供电电源独立于主照明系统的供电电源，则客舱一般照明 的光源可以为应急照明系统和主照明系统二者所共用。应急 照明系统应当： (1)照亮每一旅客出口标志和位置标志； (2)在客舱内提供足够的一般照明； (3)具有贴近地板的应急逃生通道标志，该标志符合《运 输类飞机适航标准》(CCAR-25)第25.812 条相应适航要求或 者经局方批准的其他等效要求。',
#  'file2_69_第 121.310 条_(d)': '附加应急设备 应急灯的工作。除按照《运输类飞机适航标准》 (CCAR-25)第25.812 条的相应适航要求设置的仅限于一个辅 助装置使用、独立于飞机主应急照明系统、在该辅助装置放 下时能自动接通的那些灯外， 本条(c)款、(h)款所要求的每个 灯均应当满足下列要求： (1)每个灯应当：',
#  'file2_69_第 121.310 条_(e)': '附加应急设备 应急出口操纵手柄。 每个旅客应急出口操纵手柄的位 置和出口的开启说明应当符合《运输类飞机适航标准》 (CCAR-25)第25.811 条的相应适航要求，除非局方引用了满 足本款的其他要求。当任一操作手柄或者操作手柄外罩的发 光度(亮度)降至100 微朗伯之下时，该手柄或者手柄外罩不 得继续使用。',
#  'file2_69_第 121.310 条_(f)': '附加应急设备 应急出口的通道。每架载客飞机应当按照下列要求设 置至应急出口的通道： (1)各旅客区域之间的或者通向Ⅰ型或者Ⅱ型应急出口 的每条旅客通道应当无障碍物，其宽度不少于508 毫米(20 英寸)； (2)靠近每个Ⅰ型或者Ⅱ型应急出口处， 应当有足够的空 间以使机组成员能够帮助旅客撤离飞机，同时又满足本款第 (1)项所要求的通道无障碍宽度； (3)应当有从主通道至每一III 型和IV 型应急出口的通 道。从主通道至这些出口的通道应当不受座椅、卧铺或者其 他可能减小该出口效用的障碍物的阻碍。另外，该通道应当 符合《运输类飞机适航标准》(CCAR-25)第25.813 条的相应 适航要求，除非局方引用了满足本款的其他要求； (4)如果从客舱中任一座位到达任何要求的应急出口需 要经过客舱间的通道，则该通道应当无障碍，但是可以使用 不影响自由通行的布帘； (5)不得在客舱间的任何分隔板上设置门； (6)如果从任一旅客座位到达要求的应急出口需要经过 把客舱和其他区域隔开的门，则此门应当有装置将其闩在开 启位置，并且在每次起飞和着陆期间，这个门应当闩在开启 位置。此闩锁装置应当能够承受当该门相对于周围结构受到 一个《运输类飞机适航标准》(CCAR-25)第25.561 条所述的 极限惯性力时对其施加的载荷。',
#  'file2_69_第 121.310 条_(g)': '附加应急设备 机外出口标记。 每个旅客应急出口和从外面开启这个 出口的装置应当在飞机外部予以标记，机身侧面应当有框出 每一旅客应急出口的5 厘米(2 英寸)宽的色带。 每一外部标记 (包括这种色带)的颜色应当与周围机身表面有明显的对比而 易于区别。这些标记应当符合下列要求： (1)如果较深颜色的反射率等于或者小于15％， 则较浅颜 色的反射率应当至少为45％。 反射率是物体反射的光通量与 其接收的光通量之比； (2)如果较深颜色的反射率大于15％， 则其反射率与较浅 颜色反射率之差应当至少有30％； (3)不在机身侧面的出口应当有外部开启装置， 并用红色 醒目地标出适用的操作说明，或者，如果背景的颜色使得红 色不醒目，应当用鲜明的铬黄色作标记，并且当这种出口的 开启装置仅位于机身一侧时，应当在另一侧上作同样效果的 标记。',
#  'file2_69_第 121.310 条_(h)': '附加应急设备 外部应急照明和撤离路线。 (1)每架载客飞机应当装备符合《运输类飞机适航标准》 (CCAR-25)第25.812 条相应适航要求的外部照明设备； (2)每架载客飞机应当装备有符合《运输类飞机适航标 准》(CCAR-25)第25.810 条相应适航要求的防滑撤离路线。',
#  'file2_69_第 121.310 条_(j)': '附加应急设备 额外的应急出口。客舱内超过应急出口最少数量要求 外的经批准应急出口，应当符合本条除(f)款第(1)、(2)、(3) 项以外的所有款项的要求，并且应当易于接近。',
#  'file2_69_第 121.310 条_(k)': '附加应急设备 在每架载客涡轮喷气动力飞机上， 每个机身下部出口 和尾锥出口应当符合下列要求： (1)设计和结构应使其在飞行中不能被打开； (2)在靠近出口开启装置明显位置上设置从762 毫米(30 英寸)的距离上即可以辨读的标牌， 说明此出口的设计和结构 使其在飞行中不能被打开。',
#  'file2_69_第 121.310 条_(l)': '附加应急设备 手电筒。载客飞机应当装备有从每个客舱乘务员座位 处易于接近的手电筒及其储放装置。',
#  'file2_69_第 121.310 条_(m)': '附加应急设备 对于按照本规则实施运行并且机身每侧配备了多个 旅客应急出口的飞机，机身同侧位于同层客舱的任何旅客应 急出口与相邻旅客应急出口之间的距离应当不超过18.3 米 (60 英尺)，该距离的测量应当平行于飞机的纵轴线测量两个 应急出口相距最近的出口边缘之间的距离。',
#  'file2_70_第 121.311 条_(a)': '座椅、安全带和肩带装置 载客飞机应当装备下列装置： (1)可以供机上每一个2周岁以上人员使用的经批准的座 椅或者卧铺； (2)可以供机上每一个2周岁以上的人员单独使用的经批 准的安全带，但在航路飞行期间，占用一个卧铺的两个人和 占用一个多座座椅或者长座椅的两个人可以共用一条经批 准的安全带。',
#  'file2_70_第 121.311 条_(b)': '座椅、安全带和肩带装置 在飞机于地面移动、起飞和着陆期间，按照本规则运 行的飞机上每一个人均应当在经批准的座椅或者卧铺上就 座，并用单独的安全带适当扣紧。座椅上为该乘员配备的安 全带不得被2 周岁以上的人共用。但是： (1)对于不满2周岁的儿童可以由占有经批准座椅或者卧 铺的成年人抱着； (2)可以乘坐于经局方批准的儿童限制装置内， 该装置可 以是合格证持有人配备的，也可以是儿童父母、监护人携带 的，或者该儿童父母、监护人指定在飞行中照料其安全的护 理人员携带的，但合格证持有人应当确保：',
#  'file2_70_第 121.311 条_(i)': '座椅、安全带和肩带装置 在每个无人乘坐的座椅上，若装有安全带或者肩带装 置，则应当将其固定好，使其不妨碍机组成员执行任务或者 紧急情况下人员的迅速撤离。',
#  'file2_70_第 121.311 条_(c)': '座椅、安全带和肩带装置 如果儿童的父母、监护人或者指定的护理人员请求让 该儿童乘坐他们提供的儿童限制装置，当该儿童持有经批准 座位或者卧铺的机票，或者这种座位或者卧铺能够由合格证 持有人提供给该儿童使用， 并且本条(b)款第(2)项中的要求能 够满足，则该合格证持有人不得拒绝该儿童乘坐飞机。本条 并不阻止合格证持有人提供儿童限制装置，也不阻止合格证 持有人遵循安全操作常规，为儿童限制装置确定最适合的旅 客座椅位置。',
#  'file2_70_第 121.311 条_(d)': '座椅、安全带和肩带装置 每一面向侧方的座椅应当符合《运输类飞机适航标 准》(CCAR-25)第25.785 条的相应适航要求。',
#  'file2_70_第 121.311 条_(e)': '座椅、安全带和肩带装置 除本条(e)款第(1)项和第(2)项规定外，只有每一旅客 座椅的椅背处于竖立位置，合格证持有人方可以使飞机起飞 或者着陆。每个旅客应当遵守机组成员依照本款发出的指 令。 (1)本款不适用于为符合本规则第121.310 条(f)款第(3)项 的要求而让其处于非竖立位置的座椅靠背； (2)本款不适用于根据合格证持有人的手册中规定的程 序，在座位上载有货物或者坐有由于健康方面的原因不能直 坐的人的座椅，但其椅背不得妨碍机上乘员走向通道或者任 一应急出口。',
#  'file2_70_第 121.311 条_(f)': '座椅、安全带和肩带装置 每架飞机应当在驾驶舱每一工作位置上配备有符合 《运输类飞机适航标准》(CCAR-25)第25.785 条的相应适航 要求的组合式安全带和肩带，方可以实施运行。',
#  'file2_70_第 121.311 条_(g)': '座椅、安全带和肩带装置 每个客舱乘务员应当在客舱具有一个符合 《运输类飞 机适航标准》(CCAR-25)第25.785 条的相应适航要求的座椅 (含安全带和肩带)供起飞和着陆时使用。这些要求不适用于 非本规则第121.391 条要求的客舱乘务员乘坐的旅客座椅。',
#  'file2_70_第 121.311 条_(h)': '座椅、安全带和肩带装置 要求装备组合式安全带和肩带装置的座椅上的每个 乘员，在起飞和着陆过程中都应当用这种组合式安全带和肩 带装置将乘员恰当扣紧，但在履行其正常职责需要时，可以 松开肩带。',
#  'file2_70_第 121.311 条_(j)': '座椅、安全带和肩带装置 实施载客运行运输类飞机的旅客和客舱机组成员的座 椅要求： (1)合格证持有人引进的按照本规则实施运行的2019 年 1 月1 日以后新制造的飞机，其所安装的旅客和客舱机组成 员的座椅必须满足1990 年7 月18 日颁布实施的《运输类飞 机适航标准》(CCAR-25)第25.562 条或者其后续修订的适用 要求，否则不得投入运行。 (2)自2019 年1 月1 日起，合格证持有人引进的按照本 规则实施运行的非中国登记注册的使用过的飞机，其所安装 的旅客和客舱机组成员的座椅必须满足1990 年7 月18 日颁 布实施的《运输类飞机适航标准》(CCAR-25)第25.562 条或 者其后续修订的适用要求，否则不得投入运行。',
#  'file2_71_第 121.312 条_(a)': '座舱内部材料 除局方另行批准外，对于按照本规则运行的飞机，其 每个座舱内的所有内部材料应当符合《运输类飞机适航标 准》(CCAR-25)第25.853 条的相应适航要求。',
#  'file2_71_第 121.312 条_(b)': '座舱内部材料 除飞行机组成员座椅外， 机组或者旅客使用的坐垫应 当符合《运输类飞机适航标准》(CCAR-25)第25.853 条的适 用防火特性要求。',
#  'file2_72_第 121.313 条_(a)': '其他设备 飞机只有安装下列设备，方可以实施本规则的运行： 如果飞机上装有保护性熔断器， 每种规格保护性熔断 器的备用数量应为该飞机批准的并在合格证持有人手册中 规定的数量。',
#  'file2_72_第 121.313 条_(b)': '其他设备 飞机只有安装下列设备，方可以实施本规则的运行： 每个驾驶员工作位置上的风挡雨刷或者等效设备。',
#  'file2_72_第 121.313 条_(c)': '其他设备 飞机只有安装下列设备，方可以实施本规则的运行： 符合运输类飞机型号合格审定适航要求的电源和配 电系统，或者在任一电源或者配电系统部件失效时，利用外 部电源，能为所需要的仪表和设备供电的发电和配电系统。 在系统中准许使用公共的元部件，只要局方认为其设计能合 理地防止失效。当使用由发动机驱动的多个电源时，它们应 当分装在各个发动机上。',
#  'file2_72_第 121.313 条_(d)': '其他设备 飞机只有安装下列设备，方可以实施本规则的运行： 向必需飞行仪表供电的品质和充裕程度的指示装置。',
#  'file2_72_第 121.313 条_(e)': '其他设备 飞机只有安装下列设备，方可以实施本规则的运行： 两个独立的静压系统，与外部大气相通，使得其受气 流变化、湿气或者其他外来物影响最小，且其安装除通气口 外均为气密的。当有装置将仪表从主工作系统转接到备用系 统上时，这一装置里应当具有一个可靠的位置控制器，且应 当予以标记，清楚地指明正在使用的系统。',
#  'file2_72_第 121.313 条_(f)': '其他设备 飞机只有安装下列设备，方可以实施本规则的运行： 对于按照本规则运行的飞机，除机组成员外，如果机 上还搭载有其他乘员，则驾驶舱和乘员舱之间应当装有带锁 定装置的门(即驾驶舱门)，该锁定装置应当设计成只能从驾 驶舱内解锁，并且在使用中有效，以防止其他机上乘员未经 驾驶舱内飞行机组成员的同意将门打开，否则只有驾驶舱内 的飞行机组成员才能持有驾驶舱门的钥匙。对于从驾驶舱和 客舱都能进入的机组休息区的飞机，则该区和客舱之间应当 安装有带类似锁定装置的门。 (1)对于最大客座数大于20 人的载客飞机，其驾驶舱门 还应当满足下列要求：',
#  'file2_72_第 121.313 条_(i)': '其他设备 飞机只有安装下列设备，方可以实施本规则的运行： 对于旅客可以进入的舱室，如果舱门有可能被旅客锁 上，则应当为机组配备这些门的开锁装置，以便在紧急情况 下打开这些门。',
#  'file2_72_第 121.313 条_(g)': '其他设备 飞机只有安装下列设备，方可以实施本规则的运行： 将客舱与设有应急出口设施的其他舱室隔开的每一 扇门应当配备钥匙，所配钥匙应当便于每个机组成员使用。',
#  'file2_72_第 121.313 条_(h)': '其他设备 飞机只有安装下列设备，方可以实施本规则的运行： 在通往每一指定的旅客应急出口的每扇门上应有一 块标牌，用以指明在起飞和着陆期间此门应当处于打开状 态。',
#  'file2_73_第 121.314 条_(a)': '货舱和行李舱 飞机中每个容积大于5.7 立方米(200 立方英尺)、 符合 《运输类飞机适航标准》 (CCAR-25)第25.857 条定义的C 级 舱，应当有下列任一材料构成的顶棚和侧墙衬板： (1)符合局方要求的玻璃纤维加强树脂； (2)符合《运输类飞机适航标准》(CCAR-25)附录F 要求 的材料； (3)经局方批准的铝衬板。',
#  'file2_73_第 121.314 条_(b)': '货舱和行李舱 为符合本条，术语“衬板”包括诸如连结处或者紧固件 这些影响衬板失火安全包容性能的任何设计细节。',
#  'file2_74_第 121.315 条_(a)': '驾驶舱检查单 合格证持有人应当为每一型号飞机提供经批准的驾 驶舱检查单。',
#  'file2_74_第 121.315 条_(b)': '驾驶舱检查单 这些经批准的检查单应当至少包括在起动发动机、 起 飞或者着陆之前，以及在发动机和系统出现了紧急情况时， 飞行机组成员为确保安全应当进行的每一项检查。检查单的 设计应当使飞行机组成员无需依赖于对所要进行检查的项 目的记忆。',
#  'file2_74_第 121.315 条_(c)': '驾驶舱检查单 经批准的检查单应当放置在每架飞机驾驶舱内方便 飞行机组成员使用的地方，飞行机组在操作飞机时应当遵循 检查单规定的程序。',
#  'file2_75_第 121.316 条': '燃油箱 按照本规则运行的涡轮发动机飞机应当符合《运输类飞 机适航标准》(CCAR-25)第25.963 条的要求。',
#  'file2_76_第 121.317 条_(a)': '旅客告示 按照本规则实施运行的飞机应当装备旅客告示信号 和标牌。这些信号装置应当设计成能由机组成员接通或者断 开。',
#  'file2_76_第 121.317 条_(b)': '旅客告示 飞机在地面的任何移动，以及每次起飞、着陆和机长 认为必要的其他任何时间，应当接通“系好安全带”信号。',
#  'file2_76_第 121.317 条_(c)': '旅客告示 按照本规则运行的载客飞机，应当从每个旅客座位都 能看到至少一个“系好安全带”的明显信号或者标牌。这些信 号或者标牌无需符合本条(a)款的要求。',
#  'file2_76_第 121.317 条_(d)': '旅客告示 当“系好安全带”信号亮时，本规则第121.311 条(b)款 要求具有座位的每位旅客，应当系好旅客座椅安全带并保持 系紧状态。',
#  'file2_76_第 121.317 条_(e)': '旅客告示 飞机在运行时，应当使“禁止吸烟”的告示信号灯保持 常亮，或者出示一个或者几个符合《运输类飞机适航标准》 (CCAR-25)第25.1541 条要求的“禁止吸烟”的标牌。 若同时使 用灯光信号及标牌，则灯光信号在整个飞行航段上应当保持 常亮。',
#  'file2_76_第 121.317 条_(f)': '旅客告示 每一厕所内应当有一个标志或者标牌， 其上标明“严禁 破坏厕所烟雾探测器”。该标志或者标牌无需符合本条(a)款 的要求。',
#  'file2_76_第 121.317 条_(g)': '旅客告示 款第 (1)项和(f)款第(2)项要求而发出的指令。',
#  'file2_76_第 121.317 条_(h)': '旅客告示 当飞机在地面的任何移动，在每次起飞、着陆和机长 认为必要的其他任何时间内，应当接通“禁止吸烟”信号。',
#  'file2_76_第 121.317 条_(i)': '旅客告示 每个旅客应当遵守机组成员为符合本条(e)款、',
#  'file2_77_第 121.318 条_(a)': '机内广播系统 旅客座位数超过19 的飞机实施载客运行时，应当装 备有符合下列要求的机内广播系统： (1)除手持受话器、耳机、话筒、选择开关和信号发送装 置外，能不依赖于本规则第121.319 条所要求的机组成员机 内通话系统而独立工作； (2)依据《民用航空产品和零部件合格审定规定》 (CCAR-21)的规定获得批准或者认可。',
# ...
#  'file2_262_第 121.667 条_(f)': '仪表飞行规则的起飞和着陆最低标准 就本条而言，最后进近航段从仪表进近程序规定的最 后进近定位点或者设施处开始。当一个包含程序转弯的程序 没有规定最后进近定位点时，最后进近航段在完成程序转弯 的那一点开始，并且在该点上，飞机在该程序规定距离之内 在最后进近航迹上向机场飞行。',
#  'file2_262_第 121.667 条_(g)': '仪表飞行规则的起飞和着陆最低标准 除了在合格证持有人的运行规范中另有批准外， 在国 外机场按照仪表飞行规则起飞、进近或者着陆的驾驶员，应 当遵守管辖该机场所在地民航当局所规定的仪表进近程序 和最低天气标准。',
#  'file2_263_第 121.669 条_(a)': '新机长的仪表飞行规则着陆最低天气标 准 如果机长在其驾驶的某型别飞机上作为机长按照本 规则运行未满100 小时，则合格证持有人运行规范中对于正 常使用机场、临时使用机场或者加油机场规定的最低下降高 (MDH)或者决断高(DH)和着陆能见度最低标准， 分别增加30 米(100 英尺)和800 米(1/2 英里)或者等效的跑道视程(RVR)。 对于用作备降机场的机场，最低下降高(MDH)或者决断高 (DH)和能见度(VIS)最低标准无须在适用于这些机场的数值 上增加，但是任何时候，着陆最低天气标准不得小于90 米 (300 英尺)和1,600 米(1 英里)。',
#  'file2_263_第 121.669 条_(b)': '新机长的仪表飞行规则着陆最低天气标 准 如果该驾驶员在另一型别飞机上作为机长在按照本 规则实施的运行中至少已飞行100 小时，该机长可以用在本 型飞机上按照本规则实施运行中的一次着陆，去取代必需的 机长经历1 小时，减少本条(a)款所要求的100 小时的机长经 历，但取代的部分不得超过50 小时。',
#  'file2_264_第 121.671 条': '报告的最低天气条件的适用性 在按照本规则第121.665 条至第121.669 条实施运行时， 最新天气报告正文中的云高和能见度值用于控制机场所有 跑道上的目视飞行规则和仪表飞行规则起飞、着陆和仪表进 近程序。然而，如果最新天气报告，包括从管制塔台发出的 口头报告，含有针对机场某一特定跑道的跑道能见度(VIS) 或者跑道视程(RVR)等数值，这些特定值用于控制该跑道的 目视飞行规则和仪表飞行规则着陆、起飞和仪表直接进近。',
#  'file2_265_第 121.673 条_(a)': '飞行高度规则 除了起飞、着陆需要或者在考虑到地形特征、气象服 务设施的质量和数量、可用的导航设施和其他飞行条件后， 局方认为为安全实施飞行需要其他高度而对任一航路或者 航路的一部分规定了其他最低标准的情况以外，任何人不得 在本条(b)款和(c)款规定的最低高度以下运行飞机。 在中华人 民共和国之外飞行时，本条规定的最低高度标准应当起控制 作用，除非在合格证持有人运行规范中或者由飞机飞越的国 家规定了较高的最低标准。',
#  'file2_265_第 121.673 条_(b)': '飞行高度规则 按照本规则实施运行的任何飞机在昼间按照目视飞 行规则运行时不得在距地表、 山峰、 丘陵或者其他障碍物300 米(1000 英尺)的高度以下飞行。',
#  'file2_265_第 121.673 条_(c)': '飞行高度规则 按照本规则实施运行的任何飞机按照仪表飞行规则 运行时， 在距预定航道中心线两侧各25 公里(13.5 海里)水平 距离范围内，在平原地区不得在距最高障碍物400 米(1,300 英尺)的高度以下，在丘陵和山区不得在距最高障碍物600 米(2,000 英尺)的高度以下飞行。',
#  'file2_266_第 121.675 条': '起始进近高度 当按照仪表飞行规则飞往无线电导航设施作起始进近 时，任何人不得将飞机下降到按照该设施制定的仪表进近程 序中规定的起始进近最低高度之下，直至到达该设施的上 空。',
#  'file2_267_第 121.677 条': '国内、国际定期载客运行的签派责任 合格证持有人应当根据授权的飞行签派员所提供的信 息，为两个规定地点之间的每次飞行编制签派单。机长和授 权的飞行签派员应当在签派单上签字。机长和授权的飞行签 派员均认为该次飞行能安全进行时，他们才能签字。对于某 一次飞行，飞行签派员可以委托他人签署放行单，但是不得 委托他人行使其签派权。',
#  'file2_268_第 121.679 条': '装载舱单的制定 在每架飞机起飞之前，合格证持有人应当制定装载舱 单，并对其准确性负责。该舱单应当由合格证持有人负责管 理飞机舱单和装载的人员，或者由合格证持有人授权的其他 合格人员制定并签字。机长在收到并核实装载舱单后方可以 起飞飞机。 V 章 记录和报告',
#  'file2_269_第 121.691 条_(a)': '机组成员和飞行签派员记录 每个合格证持有人应当建立和保存每一机组成员和 每个飞行签派员的下列记录： (1)技术档案， 包括飞行记录簿， 各种训练和检查的记录， 事故、事故征候结论，奖励和惩罚记录等； (2)能证明该机组成员或者飞行签派员是否满足本规则 适用条款要求的记录， 包括航路检查、 飞机和航路资格审定、 健康管理，以及飞行时间、飞行值勤时间、值勤时间和休息 时间的记录等； (3)对飞行机组成员或者飞行签派员、 业务不合格情况所 采取的每一措施，该记录至少保存6 个月； (4)飞行机组成员的健康管理记录应当长期保存。',
#  'file2_269_第 121.691 条_(b)': '机组成员和飞行签派员记录 局方批准的计算机记录系统可以用于符合本条(a)款 的要求。',
#  'file2_269_第 121.691 条_(c)': '机组成员和飞行签派员记录 合格证持有人应当在机组成员和飞行签派员所服务 的基地保存本条(a)款要求的记录，以便接受局方的检查。机 组成员和飞行签派员不再服务于该合格证持有人时，合格证 持有人应当自上述人员退出运行之日起，将本条(a)款第(1) 项要求的记录保存至少24 个月，并在上述人员提出要求时 向其提供训练记录的复印件。',
#  'file2_270_第 121.693 条': '飞机记录 合格证持有人应当保持按照本规则运行的所有飞机的 清单，并应当将该记录和每次修订的副本送交负责对其运行 进行全面检查的局方机构。按照互换协议使用的另一公共航 空运输承运人的飞机可以用加注的方法包括在内。',
#  'file2_271_第 121.695 条_(a)': '国内、国际定期载客运行的签派单 签派单应当至少包括每次飞行的下列信息： (1)飞机的国籍标志、登记标志、制造厂家和型号； (2)承运人名称、航班号和计划起飞时间； (3)起飞机场、中途停留机场、目的地机场和备降机场； (4)运行类型说明，例如仪表飞行规则、目视飞行规则； (5)最低燃油量。',
#  'file2_271_第 121.695 条_(b)': '国内、国际定期载客运行的签派单 签派单应当至少包括或者附有下列文件： (1)在机长与飞行签派员签署放行单时可以获得的关于 目的地机场、中途停留机场和备降机场的最新天气实况报告 和预报。签派单还可以包括机长或者飞行签派员认为必需的 或者希望具有的其他天气实况报告和预报； (2)运行飞行计划； (3)航行通告。',
#  'file2_272_第 121.696 条_(a)': '补充运行的飞行放行单 飞行放行单应当至少包括每次飞行的下列信息： (1)公司或者机构的名称； (2)飞机的国籍标志、登记标志、制造厂家和型号； (3)航班或者航次和飞行日期； (4)每一飞行机组成员、客舱乘务员和机长姓名； (5)起飞机场、目的地机场、备降机场和航路； (6)运行类型说明，例如仪表飞行规则、目视飞行规则； (7)起飞最低燃油量。',
#  'file2_272_第 121.696 条_(b)': '补充运行的飞行放行单 飞机飞行放行单应当含有或者附带目的地机场和备 降机场的最新天气实况报告、预报或者两者的组合。放行单 还可以包括机长认为必需的或者希望具有的其他天气实况 报告和预报。',
#  'file2_273_第 121.697 条_(a)': '装载舱单 装载舱单应当包含飞机在起飞时有关装载情况的下列 信息： 飞机、燃油和滑油、货物和行李、乘客和机组成员的 重量。',
#  'file2_273_第 121.697 条_(b)': '装载舱单 装载舱单应当包含飞机在起飞时有关装载情况的下列 信息： 该次飞行的最大允许重量， 该最大允许重量不得超过 下述重量中最小的重量： (1)对于拟使用跑道， 考虑对跑道气压高度和坡度以及起 飞时的风和温度条件的修正值之后的最大允许起飞重量； (2)考虑到预期的燃油和滑油消耗， 能够符合适用的航路 性能限制的最大起飞重量； (3)考虑到预期的燃油和滑油消耗， 能够在到达目的地机 场时符合批准的最大设计着陆重量限制的最大起飞重量； (4)考虑到预期的燃油和滑油消耗， 能够在到达目的地机 场和备降机场时符合着陆限制的最大起飞重量。',
#  'file2_273_第 121.697 条_(c)': '装载舱单 装载舱单应当包含飞机在起飞时有关装载情况的下列 信息： 按照批准的程序计算的总重量。',
#  'file2_273_第 121.697 条_(d)': '装载舱单 装载舱单应当包含飞机在起飞时有关装载情况的下列 信息： 按照批准的能够保证重心处于批准范围之内的计划， 对该飞机实施装载的证据。',
#  'file2_273_第 121.697 条_(e)': '装载舱单 装载舱单应当包含飞机在起飞时有关装载情况的下列 信息： 旅客的姓名， 除非该项内容由合格证持有人以其他方 式保存。',
#  'file2_274_第 121.699 条_(a)': '国内、国际定期载客运行装载舱单、签 派单和运行飞行计划的处置 机长应当将下列文件的副本随机携带到目的地： (1)填写好的装载舱单； (2)签派或者放行单； (3)运行飞行计划。',
#  'file2_274_第 121.699 条_(b)': '国内、国际定期载客运行装载舱单、签 派单和运行飞行计划的处置 合格证持有人应当保存前款规定的文件的副本至少3 个月。',
#  'file2_275_第 121.700 条_(a)': '补充运行的装载舱单、飞行放行单和运 行飞行计划的处置 实施补充运行的飞机机长应当携带下列文件的原件 或者经签署的文件副本飞行到目的地机场： (1)装载舱单； (2)飞行放行单； (3)适航放行单； (4)驾驶员航线合格证明； (5)运行飞行计划。',
#  'file2_275_第 121.700 条_(b)': '补充运行的装载舱单、飞行放行单和运 行飞行计划的处置 如果飞行在合格证持有人主运行基地始发时， 应当在 其主运行基地保存本条(a)款规定的文件的原件或者副本。',
#  'file2_275_第 121.700 条_(c)': '补充运行的装载舱单、飞行放行单和运 行飞行计划的处置 除本条(d)款规定外， 如果飞行在合格证持有人主运行 基地以外的机场始发时， 机长(或者合格证持有人授权的其他 运行控制人员)应当在起飞前或者起飞后立即将本条(a)款列 出的文件副本发送或者带回到主运行基地保存。',
#  'file2_275_第 121.700 条_(d)': '补充运行的装载舱单、飞行放行单和运 行飞行计划的处置 如果飞行始发在合格证持有人的主运行基地以外机 场时，合格证持有人在那个机场委托他人负责管理飞行运 行，按照本条(a)款规定签署过的文件副本在送回合格证持有 人的主运行基地前在该机场的保存不得超过30 天。如果这 些文件的原件或者副本已经送回合格证持有人的主运行基 地，则这些文件不需要继续保存在该机场。',
#  'file2_275_第 121.700 条_(e)': '补充运行的装载舱单、飞行放行单和运 行飞行计划的处置 实施补充运行的合格证持有人应当： (1)根据本条(d)款规定， 在其运行手册中指定专门人员负 责这些文件副本； (2)按照本条规定原始文件或者副本应当在主运行基地 保存3 个月。',
#  'file2_276_第 121.701 条_(a)': '飞机飞行记录本 合格证持有人应当对于每一架飞机建立飞机飞行记 录本，记录运行中发现的缺陷和工作不正常情况及所进行的 维修工作； 另外， 它还用于记录与飞行安全有关的运行信息、 飞行机组和维修人员需要了解的有关数据。',
#  'file2_276_第 121.701 条_(b)': '飞机飞行记录本 飞机飞行记录本中应当包括飞机运行信息、 影响飞机 适航性和安全运行的任何缺陷及保留状况、要求的维修项 目、维修工作记录、飞机放行等内容。',
#  'file2_276_第 121.701 条_(c)': '飞机飞行记录本 飞机飞行记录本的格式应当固定，各项内容应当使用 墨水或者不可以更改的书写工具及时填写，并且有足够的复 页以保证满足使用和保存要求。',
#  'file2_276_第 121.701 条_(d)': '飞机飞行记录本 合格证持有人应当在飞机上飞行机组成员易于取用 的地方放置一份飞机飞行记录本原件，其中至少记录包括每 次飞行前三次飞行期间填写内容的连续记录，并且每次起飞 前在地面保存一份记录上一次飞行和本次飞行前填写内容 的飞机飞行记录本的复页。',
#  'file2_276_第 121.701 条_(e)': '飞机飞行记录本 合格证持有人应当在维修工程管理手册中规定飞机 飞行记录本的格式及填写、使用和保存要求。',
#  'file2_277_第 121.702 条_(a)': '燃油和滑油记录 运营人必须保存燃油记录，以满足飞机使用燃油要 求。',
#  'file2_277_第 121.702 条_(b)': '燃油和滑油记录 运营人必须保存滑油记录， 以便实施滑油消耗监控并 满足飞机安全飞行。',
#  'file2_277_第 121.702 条_(c)': '燃油和滑油记录 燃油和滑油记录必须保存3 个月以上。',
#  'file2_278_第 121.703 条': '通信记录 合格证持有人应当记录与其飞行机组成员之间每次航 路上使用满足本规则第121.97 条通讯设备联系的记录， 并将 该记录至少保存30 天。',
#  'file2_279_第 121.704 条_(a)': '航空器观测和报告 合格证持有人应当制定政策和程序，以保证其飞机根 据所飞越国家或者情报区(管制区)的要求完成航空器例行观 测、航空器特殊观测和其他非例行观测，记录并向空中交通 管制员报告观测到的情况。',
#  'file2_279_第 121.704 条_(b)': '航空器观测和报告 对于合格证持有人没有配备空地数据链的飞机， 可以 免除航空器例行观测。',
#  'file2_279_第 121.704 条_(c)': '航空器观测和报告 合格证持有人的飞机针对喷发前的火山活动、 火山喷 发或火山灰云所进行的航空器特殊观测情况，应当记录在火 山活动报告表上。当气象部门认为火山灰可能会影响航线上 的飞行时，合格证持有人应当在提供给飞行机组的飞行文件 中附上火山活动报告表。',
#  'file2_280_第 121.705 条_(a)': '飞行中紧急医学事件报告 合格证持有人应当记录飞行中发生的紧急医学事件， 并应当在事发后48 小时内向局方报告。紧急医学事件记录 信息应当包括： 事件发生的时间、 航班航段、 事件具体情况、 涉及人员和处置过程等。记录应当保存24 个月。',
#  'file2_280_第 121.705 条_(b)': '飞行中紧急医学事件报告 飞行中发生的紧急医学事件包括： 运行中发生的人员 伤病或死亡，以及突发公共卫生事件。',
#  'file2_281_第 121.706 条': '国际运行中对可疑传染病的报告 按照目的机场所在地的规定，当飞行中发现可疑传染病 病例时，机长应当立即报告正在通信的空中交通管制单位， 报告内容应当包括： 飞机注册号、 出发地机场、 目的地机场、 预计抵达时间、机上人数、可疑传染病病例人数、症状及风 险(如已知)等信息。',
#  'file2_282_第 121.707 条_(a)': '使用困难报告 合格证持有人应当按照局方要求的方式向局方上报 其飞机的使用困难报告。使用困难报告包括运行中出现严重 故障或者失效，或者维修中发现的危及或者可能危及飞行安 全的故障、失效或者缺陷。',
#  'file2_282_第 121.707 条_(b)': '使用困难报告 合格证持有人应当在24 小时之内向局方报告本条所 要求报告的情况，并至少保存报告的信息30 天，以备局方 核查。',
#  'file2_282_第 121.707 条_(c)': '使用困难报告 合格证持有人应当按照局方要求的方式报告本条所 要求报告的情况，报告中应当至少包括下列信息： (1)飞机的制造厂家、型号、飞机/发动机/螺旋桨的序号； (2)飞机登记号； (3)合格证持有人的名称； (4)发生或者发现日期和地点； (5)失效、故障或者缺陷的发生阶段； (6)失效、故障或者缺陷的性质； (7)适用的ATA 章节； (8)飞机、发动机、螺旋桨或者部件的总使用时间或者循 环； (9)失效、 故障或者存在缺陷的零部件的制造厂家、 件号、 名称、序号和部位； (10)采取的预防或者紧急措施； (11)为了更完整地分析失效、故障或者缺陷原因的其他 信息，包括主要部件与型号设计有关的可以提供信息和自上 次翻修、修理和检测的适用时间。',
#  'file2_282_第 121.707 条_(d)': '使用困难报告 即使上述要求的信息不能完全提供， 合格证持有人也 不能推迟可以提供内容的报告时间，并且应当尽快补充报告 没有提供的信息。',
#  'file2_282_第 121.707 条_(e)': '使用困难报告 当使用困难报告涉及设计、 制造缺陷或者持续适航文 件问题时，相关报告信息还应当及时通报相应型号合格证持 有人。',
#  'file2_283_第 121.709 条_(a)': '机械原因中断使用汇总报告 合格证持有人应当在每月10 日之前向局方报告前一 个月出现的因机械原因的下列情况的汇总报告： (1)中断飞行； (2)非计划更换飞机； (3)延误、备降或者改航； (4)因已知或者怀疑的机械原因引起的非计划换发。',
#  'file2_283_第 121.709 条_(b)': '机械原因中断使用汇总报告 合格证持有人应当按照局方规定的格式和方式提交 本条所要求的报告。',
#  'file2_284_第 121.710 条': '运行中人为差错报告 合格证持有人应当在72 小时内向局方报告运行中出现 的飞行机组成员、维修及其他运行控制人员发生的人为差 错。 W 章 延程运行(EDTO)与极地运行',
#  'file2_285_第 121.711 条_(a)': '概则 对于从航路上一个点飞往一个航路备降机场的运行 超过60 分钟的情况，合格证持有人必须确保： (1)对于所有飞机：',
#  'file2_285_第 121.711 条_(b)': '概则 合格证持有人应当为所有已获得延程运行(EDTO)批 准的飞机制定签派放行程序，以防止将飞机被签派到改航时 间超过经局方批准的延程运行(EDTO)关键系统时间限制能 力的航路上。',
#  'file2_285_第 121.711 条_(c)': '概则 对于超过180 分钟的延程运行(EDTO)和极地运行， 该 次运行所指定的每个延程运行(EDTO)指定备降机场和极地 运行改航机场，都应当具备足以保障乘客和机组生存需求的 条件。',
#  'file2_285_第 121.711 条_(d)': '概则 合格证持有人应当在下列程序和大纲中增加本条(a) 款至(c)款的内容，以保证整体安全水平： (1)运行控制与飞行签派程序； (2)运行程序； (3)训练大纲。',
#  'file2_285_第 121.711 条_(e)': '概则 延程运行(EDTO)的批准通过颁发或者修改合格证持 有人的运行规范的方法进行。',
#  'file2_285_第 121.711 条_(f)': '概则 对于每一次延程运行(EDTO)， 签派放行单中应当包含 该次延程运行(EDTO)最大改航时间。 第121.713 附加要求',
#  'file2_285_第 121.711 条_(i)': '概则 指定了航路备降机场； (ii)向飞行机组提供指定航路备降机场的最新资料， 包括 工作状况与气象条件。 (2)对于双发涡轮驱动实施延程运行(EDTO)飞机，除非 根据最新的资料评估，指定的航路备降机场气象条件在预计 使用时间能够达到或高于合格证持有人运行规范批准的机 场运行最低标准，否则不得超过本规则第121.711 条(a)款第 (1)项规定的时间飞行。 如果经确定的任何条件不允许飞机在 预计的使用时间在该机场安全进近并着陆，必须确定一个备 用的运行方案。',
#  'file2_286_第 121.714 条': '延程运行(EDTO)的通信设备 如果实施超过180 分钟的延程运行(EDTO)， 满足本规则 第121.97 条(c)款所规定的通信系统应当能提供基于卫星的 语音通信，通话质量与固定电话相当。该系统应当能够在飞 行机组和空管人员之间以及飞行机组和合格证持有人之间 提供通信。 合格证持有人在规划延程运行(EDTO)时， 还应当 考虑改航至延程运行(EDTO)备降机场所需的可能的航线和 海拔高度，以确定基于卫星的语音通信设备是否可用。如果 存在无法利用基于卫星的语音通信设备的情况，或者因其质 量低劣而无法进行语音通信，则应当有另一种通信系统作为 替代。',
#  'file2_287_第 121.715 条_(a)': '延程运行(EDTO)备降机场：救援与消防 服务 除本条(b)款中的规定之外， 在签派或者飞行放行单上 列明的每一个延程运行(EDTO)备降机场， 均需能够提供下列 救援和消防服务(RFFS)： (1)如果延程运行(EDTO)时间在180 分钟内，每个指定 的延程运行(EDTO)备降机场应当能够提供等效于或者高于 国际民航组织规定的第4 类救援和消防服务(RFFS)的要求； (2)如果延程运行(EDTO)时间超过180 分钟，每个指定 的延程运行(EDTO)备降机场应当能够提供等效于或者高于 国际民航组织规定的第4 类救援和消防服务(RFFS)的要求。 此外，飞机还应当保持在距能够提供等效于或者高于国际民 航组织规定的第7 类救援和消防服务(RFFS)的合适机场的一 定距离内， 以便能在依据其延程运行(EDTO)批准的改航时间 内飞抵该合适机场。',
#  'file2_287_第 121.715 条_(b)': '延程运行(EDTO)备降机场：救援与消防 服务 如果无法直接在一个机场利用本条(a)款要求的救援 和消防设备与人员，只要该机场通过当地获得消防增援与消 防服务能力后，能够达到本条(a)款的要求，合格证持有人仍 然可以在签派或者飞行放行单上将该机场列为备降机场。在 改航的航路运行过程中如果当地资源可以及时被告知， 30 分 钟的增援响应时间应当是充足的。在改航飞机飞抵备降机场 时，增援设施与人员应当可用，另外，只要改航飞机需要救 援和消防服务，这些增援设施与人员就应当始终处于随时可 用状态。',
#  'file2_288_第 121.716 条_(a)': '手册内容 合格证持有人的手册中应当包含下列内容： 对于所从事的延程运行(EDTO)， 支持所有飞行阶段的 性能数据。',
#  'file2_288_第 121.716 条_(b)': '手册内容 合格证持有人的手册中应当包含下列内容： 对于载客运行： (1)如果实施超过180 分钟的延程运行(EDTO)，应当制 订每一相应延程运行(EDTO)备降机场具体的旅客航程恢复 计划； (2)对于在北极区域和南极区域的运行， 应当制订每一相 应极地运行改航机场具体的旅客航程恢复计划。',
#  'file2_289_第 121.718 条': '延程运行型号设计批准依据 除2015 年2 月17 日之前制造的安装两台以上发动机的 载客飞机和仅用于实施飞行时间少于或者等于75 分钟的延 程运行的双发飞机之外，合格证持有人只能在下列条件下实 施延程运行：飞机获得延程运行型号设计批准且每架用于延 程运行的飞机均符合其构型、维修和程序文件的要求。延程 运行型号设计批准通常在相应的机体发动机组合的《飞机飞 行手册》 (AFM)、 型号合格证(TC)或者补充型号合格证(STC) 中给出。',
#  'file2_290_第 121.719 条_(a)': '延程运行持续适航性维修方案(CAMP) 为实施延程运行，合格证持有人应当制定并遵照由局方 批准的运行规范中持续适航维修方案的要求对用于延程运 行的机体发动机组合实施维修。合格证持有人可以通过对飞 机制造厂推荐的维修方案，或者对现在已获批准的持续适航 维修方案增补维修要求来制定适用于延程运行的持续适航 维修方案。这个持续适航维修方案应当包括下列内容： 延程运行维修文件。 合格证持有人应当制定延程运行 维修文件，供每一名延程运行相关人员使用。 (1)这个文件应当：',
#  'file2_290_第 121.719 条_(i)': '延程运行持续适航性维修方案(CAMP) 为实施延程运行，合格证持有人应当制定并遵照由局方 批准的运行规范中持续适航维修方案的要求对用于延程运 行的机体发动机组合实施维修。合格证持有人可以通过对飞 机制造厂推荐的维修方案，或者对现在已获批准的持续适航 维修方案增补维修要求来制定适用于延程运行的持续适航 维修方案。这个持续适航维修方案应当包括下列内容： 动力系统监控： (A)如果作为机体发动机组合一部分的发动机的空中停 车率(基于12 个月滚动平均值)超过下列数值， 合格证持有人 应当综合评审其运行，以识别任何共因影响和系统错误。 ①如果延程运行(EDTO)时间小于或者等于120 分钟， 空 中停车率为0.005 次/1,000 发动机工作小时； ②如果在北太平洋区域延程运行(EDTO)时间超过120 分钟且小于或者等于207 分钟，以及在其他区域延程运行 (EDTO)时间超过120 分钟且小于或者等于180 分钟， 空中停 车率为0.003 次/1000 发动机工作小时； ③如果在北太平洋运行区域延程运行(EDTO)时间超过 207 分钟，以及在其他区域延程运行(EDTO)时间超过180 分 钟，空中停车率为0.002 次/1000 发动机工作小时。 (B)在空中停车率超过上述数值30 天之内，合格证持有 人应当向局方提交一个调查报告以及已采取的任何必要的 纠正措施。',
#  'file2_290_第 121.719 条_(v)': '延程运行持续适航性维修方案(CAMP) 为实施延程运行，合格证持有人应当制定并遵照由局方 批准的运行规范中持续适航维修方案的要求对用于延程运 行的机体发动机组合实施维修。合格证持有人可以通过对飞 机制造厂推荐的维修方案，或者对现在已获批准的持续适航 维修方案增补维修要求来制定适用于延程运行的持续适航 维修方案。这个持续适航维修方案应当包括下列内容： 因疏忽产生的燃油损耗或者无燃油可用， 或者飞行中 无法纠正的燃油不平衡； (vi)与延程运行关键系统相关的失效、故障或者缺陷； (vii)任何危及实施延程运行安全飞行和着陆的事件。 (2)合格证持有人应当调查本款第(1)项中列明的每一事 件的原因，并向局方提交调查结果和纠正措施说明。纠正行 动应当被局方所接受。',
#  'file2_290_第 121.719 条_(b)': '延程运行持续适航性维修方案(CAMP) 为实施延程运行，合格证持有人应当制定并遵照由局方 批准的运行规范中持续适航维修方案的要求对用于延程运 行的机体发动机组合实施维修。合格证持有人可以通过对飞 机制造厂推荐的维修方案，或者对现在已获批准的持续适航 维修方案增补维修要求来制定适用于延程运行的持续适航 维修方案。这个持续适航维修方案应当包括下列内容： 延程运行前维修检查。 合格证持有人应当制定针对延 程运行特定要求的维修检查单并实施检查。 (1)每次延程运行前， 合格证持有人应当完成延程运行前 维修检查。 (2)这种检查应当至少包括下列各项：',
#  'file2_290_第 121.719 条_(c)': '延程运行持续适航性维修方案(CAMP) 为实施延程运行，合格证持有人应当制定并遵照由局方 批准的运行规范中持续适航维修方案的要求对用于延程运 行的机体发动机组合实施维修。合格证持有人可以通过对飞 机制造厂推荐的维修方案，或者对现在已获批准的持续适航 维修方案增补维修要求来制定适用于延程运行的持续适航 维修方案。这个持续适航维修方案应当包括下列内容： 双重维修项目的限制。 (1)除了本款第(2)项的规定之外， 合格证持有人应当避免 在同一次停场维修时对相同的或者本质上相同的延程运行 关键系统同时实施例行或者非例行维修工作，以防止由于不 适当的维修而导致的延程运行关键系统的失效。 (2)如果本款第(1)项所定义的双重维修不可避免， 合格证 持有人可以按照下列规定进行维修：',
#  'file2_290_第 121.719 条_(d)': '延程运行持续适航性维修方案(CAMP) 为实施延程运行，合格证持有人应当制定并遵照由局方 批准的运行规范中持续适航维修方案的要求对用于延程运 行的机体发动机组合实施维修。合格证持有人可以通过对飞 机制造厂推荐的维修方案，或者对现在已获批准的持续适航 维修方案增补维修要求来制定适用于延程运行的持续适航 维修方案。这个持续适航维修方案应当包括下列内容： 验证方案。 合格证持有人应当制定并保持一个解决方 案，以确保对延程运行关键系统采取的维修工作的有效性。 验证方案应当识别潜在的问题，并核实令人满意的纠正措 施。验证方案应当包含地面检验和空中检验策略与程序。合 格证持有人应当建立程序，明确指示启动检验行动的人员以 及必不可少的行动项。可以在取酬的延程运行中进行验证， 但要求验证工作在到达延程运行进入点之前顺利完成并且 记录所进行的验证工作。',
#  'file2_290_第 121.719 条_(e)': '延程运行持续适航性维修方案(CAMP) 为实施延程运行，合格证持有人应当制定并遵照由局方 批准的运行规范中持续适航维修方案的要求对用于延程运 行的机体发动机组合实施维修。合格证持有人可以通过对飞 机制造厂推荐的维修方案，或者对现在已获批准的持续适航 维修方案增补维修要求来制定适用于延程运行的持续适航 维修方案。这个持续适航维修方案应当包括下列内容： 识别任务。合格证持有人应当标示出所有与延程运行 相关的任务。这些与延程运行相关的特定工作应当由经过适 当培训且具有延程运行资格的维修人员完成并签署。',
#  'file2_290_第 121.719 条_(f)': '延程运行持续适航性维修方案(CAMP) 为实施延程运行，合格证持有人应当制定并遵照由局方 批准的运行规范中持续适航维修方案的要求对用于延程运 行的机体发动机组合实施维修。合格证持有人可以通过对飞 机制造厂推荐的维修方案，或者对现在已获批准的持续适航 维修方案增补维修要求来制定适用于延程运行的持续适航 维修方案。这个持续适航维修方案应当包括下列内容： 集中的维修控制程序。合格证持有人应当为延程运行 制定并保持集中的维修控制程序。',
#  'file2_290_第 121.719 条_(g)': '延程运行持续适航性维修方案(CAMP) 为实施延程运行，合格证持有人应当制定并遵照由局方 批准的运行规范中持续适航维修方案的要求对用于延程运 行的机体发动机组合实施维修。合格证持有人可以通过对飞 机制造厂推荐的维修方案，或者对现在已获批准的持续适航 维修方案增补维修要求来制定适用于延程运行的持续适航 维修方案。这个持续适航维修方案应当包括下列内容： 零部件控制方案。 合格证持有人应当制定一个延程运 行零部件控制方案，以确保正确识别用于实施延程运行飞机 构型控制的零部件。',
#  'file2_290_第 121.719 条_(h)': '延程运行持续适航性维修方案(CAMP) 为实施延程运行，合格证持有人应当制定并遵照由局方 批准的运行规范中持续适航维修方案的要求对用于延程运 行的机体发动机组合实施维修。合格证持有人可以通过对飞 机制造厂推荐的维修方案，或者对现在已获批准的持续适航 维修方案增补维修要求来制定适用于延程运行的持续适航 维修方案。这个持续适航维修方案应当包括下列内容： 可靠性方案。 合格证持有人应当制定一个延程运行可 靠性方案。该方案应当是在合格证持有人现有可靠性方案或 者其持续分析和监督系统(CASS)的基础上增补延程运行的 内容。该方案应当是以事件分析为基础的方案，并包含下列 事件的报告程序： (1)在发生下列事件后，涉及本规则第121.707 条规定项 目的，按照规定要求向局方报告；其他项目应当在96 小时 内向局方报告：',
#  'file2_290_第 121.719 条_(j)': '延程运行持续适航性维修方案(CAMP) 为实施延程运行，合格证持有人应当制定并遵照由局方 批准的运行规范中持续适航维修方案的要求对用于延程运 行的机体发动机组合实施维修。合格证持有人可以通过对飞 机制造厂推荐的维修方案，或者对现在已获批准的持续适航 维修方案增补维修要求来制定适用于延程运行的持续适航 维修方案。这个持续适航维修方案应当包括下列内容： 发动机状况监控。 (1)合格证持有人应当制定一个发动机状况监控方案， 以 便在早期检测到发动机的性能恶化，并在安全运行受到影响 之前采取纠正措施； (2)该方案应当描述待监控参数、数据收集方法、数据分 析方法和采取纠正措施的流程； (3)该方案应当确保发动机极限值裕度能得以维持， 以便 在批准的动力水平、所有预期的环境条件下，实施发动机失 效状态下的延程改航，而不会超出批准的发动机限值。这包 括多种批准的限值，如转子速度和排气温度。',
#  'file2_290_第 121.719 条_(k)': '延程运行持续适航性维修方案(CAMP) 为实施延程运行，合格证持有人应当制定并遵照由局方 批准的运行规范中持续适航维修方案的要求对用于延程运 行的机体发动机组合实施维修。合格证持有人可以通过对飞 机制造厂推荐的维修方案，或者对现在已获批准的持续适航 维修方案增补维修要求来制定适用于延程运行的持续适航 维修方案。这个持续适航维修方案应当包括下列内容： 滑油消耗量监控。 合格证持有人应当制定一个发动机 油耗监视方案，以确保飞机具有足够的滑油以完成每次的延 程运行。如果延程运行中需要使用辅助动力装置，则辅助动 力装置油耗应当包括在内。合格证持有人的油耗极限值不得 超过制造厂家的推荐值。应当对发动机油耗进行持续监控， 并将在延程运行的每一个离港机场添加的滑油包含在内。该 方案应当比较延程运行每个离港机场的加油量与运行过程 的平均油耗，以识别突然的油耗增加。',
#  'file2_290_第 121.719 条_(l)': '延程运行持续适航性维修方案(CAMP) 为实施延程运行，合格证持有人应当制定并遵照由局方 批准的运行规范中持续适航维修方案的要求对用于延程运 行的机体发动机组合实施维修。合格证持有人可以通过对飞 机制造厂推荐的维修方案，或者对现在已获批准的持续适航 维修方案增补维修要求来制定适用于延程运行的持续适航 维修方案。这个持续适航维修方案应当包括下列内容： 辅助动力装置空中起动方案。如果飞机的取证要求辅 助动力装置，但不要求其在延程运行时工作，则合格证持有 人应当制定和保持一个局方接受的低温情况下辅助动力装 置的空中起动和工作的方案。',
#  'file2_290_第 121.719 条_(m)': '延程运行持续适航性维修方案(CAMP) 为实施延程运行，合格证持有人应当制定并遵照由局方 批准的运行规范中持续适航维修方案的要求对用于延程运 行的机体发动机组合实施维修。合格证持有人可以通过对飞 机制造厂推荐的维修方案，或者对现在已获批准的持续适航 维修方案增补维修要求来制定适用于延程运行的持续适航 维修方案。这个持续适航维修方案应当包括下列内容： 维修培训。 对于每一种机体发动机组合， 合格证持有 人应当制定一个维修培训方案，提供充分的培训以支持延程 运行。培训项目应当包括对所有参与延程运行的维修的人员 提供与延程运行相关的培训，同时，这种培训注重延程运行 的特殊性质。该培训应当是对已接受过飞机和发动机维修培 训的维修人员的基础上的补充培训。',
#  'file2_290_第 121.719 条_(n)': '延程运行持续适航性维修方案(CAMP) 为实施延程运行，合格证持有人应当制定并遵照由局方 批准的运行规范中持续适航维修方案的要求对用于延程运 行的机体发动机组合实施维修。合格证持有人可以通过对飞 机制造厂推荐的维修方案，或者对现在已获批准的持续适航 维修方案增补维修要求来制定适用于延程运行的持续适航 维修方案。这个持续适航维修方案应当包括下列内容： 构型、维修与程序(CMP)文件。如果一种机体发动机 组合具有一个构型、维修和程序文件，则合格证持有人应当 有适用的系统来满足经局方批准文件的要求。',
#  'file2_290_第 121.719 条_(o)': '延程运行持续适航性维修方案(CAMP) 为实施延程运行，合格证持有人应当制定并遵照由局方 批准的运行规范中持续适航维修方案的要求对用于延程运 行的机体发动机组合实施维修。合格证持有人可以通过对飞 机制造厂推荐的维修方案，或者对现在已获批准的持续适航 维修方案增补维修要求来制定适用于延程运行的持续适航 维修方案。这个持续适航维修方案应当包括下列内容： 程序变化。 合格证持有人对延程运行相关的维修或者 培训程序所做的任何实质改变都应当提交局方审核。在局方 通知合格证持有人审核完成之前，合格证持有人不得执行已 改变的程序。',
#  ...}

# %%
# 民航总局文件 进一步 拆分到1/2/3粒度
def split_paragraph_dict_lv3(paragraph_dict2_lv2):
    res = {}
    for src_key in paragraph_dict2_lv2:
        src_content = paragraph_dict2_lv2[src_key]
        
        # 先提取所有的"(数字)"次标题
        sub_titles = re.findall(r"\s+\(([0-9]+)\)", src_content)
        # print(sub_titles)
        # 提取主标题, 第一个次标题前
        first_sub_titles_start = src_content.find(f"({sub_titles[0]})", 0) if len(sub_titles) > 0 else len(src_content)
        main_title = src_content[:first_sub_titles_start]
        # 初始化内容列表和标题计数器
        contents = []
        title_counter = 1
        # 根据次标题位置分割文本，提取内容
        start_pos = 0
        for sub_title in sub_titles:
            # 查找当前次标题的位置
            title_start = src_content.find(f" ({sub_title})", start_pos)
            # 查找下一个次标题或文本结束的位置
            if title_counter < len(sub_titles):
                next_title = sub_titles[title_counter]
                next_title_start = src_content.find(f" ({next_title})", title_start)
                content = src_content[title_start+len(f" ({sub_title})"):next_title_start].strip()
            else:
                # 如果是最后一个次标题，则提取到字符串末尾
                content = src_content[title_start+len(f" ({sub_title})"):].strip()
            contents.append(content)
            start_pos = title_start + len(f"({sub_title})")
            title_counter += 1
            
        # 生成最终的字典
        # 如果不能被拆分(1), (2)...
        if len(sub_titles) == 0 or len(contents) == 0:
            res[src_key] = src_content
        else:
            split_keys = [f"{src_key}_({sub_title})" for sub_title in sub_titles]
            split_values = [f"{main_title}{content}" for content in contents]
            for sub_key, sub_value in zip(split_keys, split_values):
                res[sub_key] = sub_value
    return res

# %%
paragraph_dict2_lv3 = split_paragraph_dict_lv3(paragraph_dict2_lv2)

# %%
len(paragraph_dict2_lv3)
# Out:
# 1819

# %%
paragraph_dict2_lv3
# Out:
# {'file2_0_第 121.1 条': '目的和依据 为了对大型飞机公共航空运输承运人进行运行合格审 定和持续监督检查，保证其达到并保持规定的运行安全水 平，根据《中华人民共和国民用航空法》和《国务院对确需 保留的行政审批项目设定行政许可的决定》 ，制定本规则。',
#  'file2_1_第 121.3 条_(a)_(1)': '适用范围 本规则适用于在中华人民共和国境内依法设立的航 空运营人实施的下列公共航空运输运行： 使用最大起飞重量超过5,700 千克的多发涡轮驱动飞 机实施的定期载客运输飞行；',
#  'file2_1_第 121.3 条_(a)_(2)': '适用范围 本规则适用于在中华人民共和国境内依法设立的航 空运营人实施的下列公共航空运输运行： 使用旅客座位数超过30 座或者最大商载超过3,400 千克的多发涡轮驱动飞机实施的不定期载客运输飞行；',
#  'file2_1_第 121.3 条_(a)_(3)': '适用范围 本规则适用于在中华人民共和国境内依法设立的航 空运营人实施的下列公共航空运输运行： 使用最大商载超过3,400 千克的多发涡轮驱动飞机实 施的全货物运输飞行。',
#  'file2_1_第 121.3 条_(b)': '适用范围 对于适用于本条(a)款规定的航空运营人， 在本规则中 称之为大型飞机公共航空运输承运人。',
#  'file2_1_第 121.3 条_(c)_(1)': '适用范围 对于应当按照本规则审定合格的大型飞机公共航空 运输承运人，中国民用航空局(以下简称中国民航局)和民用 航空地区管理局（以下简称民航地区管理局）按照审定情况 在其运行合格证及其运行规范中批准其实施下列一项或者 多项运行种类的运行： 国内定期载客运行，是指符合本条(a)款第(1)项规定， 在中华人民共和国境内两点之间的运行，或者一个国内地点 与另一个由局方专门指定、视为国内地点的国外地点之间的 运行；',
#  'file2_1_第 121.3 条_(c)_(2)': '适用范围 对于应当按照本规则审定合格的大型飞机公共航空 运输承运人，中国民用航空局(以下简称中国民航局)和民用 航空地区管理局（以下简称民航地区管理局）按照审定情况 在其运行合格证及其运行规范中批准其实施下列一项或者 多项运行种类的运行： 国际定期载客运行，是指符合本条(a)款第(1)项规定， 在一个国内地点和一个国外地点之间，两个国外地点之间， 或者一个国内地点与另一个由局方专门指定、视为国外地点 的国内地点之间的运行；',
#  'file2_1_第 121.3 条_(c)_(3)': '适用范围 对于应当按照本规则审定合格的大型飞机公共航空 运输承运人，中国民用航空局(以下简称中国民航局)和民用 航空地区管理局（以下简称民航地区管理局）按照审定情况 在其运行合格证及其运行规范中批准其实施下列一项或者 多项运行种类的运行： 补充运行，是指符合本条(a)款第(2)项、第(3)项规定 的运行。',
#  'file2_1_第 121.3 条_(d)': '适用范围 大型飞机公共航空运输承运人应当遵守其他有关的 涉及民航管理的规章，但在本规则对相应要求进行了增补或 者提出了更高标准的情况下，应当按照本规则的要求执行。',
#  'file2_1_第 121.3 条_(e)': '适用范围 大型飞机公共航空运输承运人在运行中所使用的人 员和大型飞机公共航空运输承运人所载运的人员应当遵守 本规则中的适用要求。',
#  'file2_1_第 121.3 条_(f)': '适用范围 在本规则中，对于载运邮件的飞行，视为载运货物飞 行；对于同时载运旅客和货物的飞行，视为载运旅客飞行， 但应当同时满足本规则中有关货物运输条款的要求。',
#  'file2_2_第 121.5 条_(a)': '定义 在本规则中， 局方是指中国民航局和民航地区管理局 及其派出机构。',
#  'file2_2_第 121.5 条_(b)': '定义 除本规则其他章中另有规定外， 本规则中用语的含义 在本规则附件A《定义》中规定。',
#  'file2_3_第 121.7 条_(a)': '运行合格审定和持续监督 中国民航局对大型飞机公共航空运输承运人的合格 审定和运行实施统一监督管理。',
#  'file2_3_第 121.7 条_(b)': '运行合格审定和持续监督 中国民航局飞行标准职能部门依据本规则组织指导 大型飞机公共航空运输承运人的运行合格审定和持续监督 检查工作，制定必要的工作程序，规定运行合格证、运行规 范及其申请书的统一格式。',
#  'file2_3_第 121.7 条_(c)': '运行合格审定和持续监督 民航地区管理局负责对其所辖地区内设立的大型飞 机公共航空运输承运人实施运行合格审定，颁发运行合格证 及其运行规范，并及时向中国民航局飞行标准职能部门备 案。',
#  'file2_3_第 121.7 条_(d)': '运行合格审定和持续监督 大型飞机公共航空运输承运人取得运行合格证及其 运行规范后， 即成为本规则规定的运行合格证持有人(以下简 称合格证持有人)。',
#  'file2_3_第 121.7 条_(e)': '运行合格审定和持续监督 民航地区管理局及其派出机构负责对其所辖地区内 设立的和(或者)在其所辖地区内运行的合格证持有人实施持 续监督检查。',
#  'file2_4_第 121.9 条_(a)': '飞机的湿租 除经中国民航局批准外，合格证持有人不得湿租境外 航空运营人或者境内未按照本规则批准运行的航空运营人 的飞机。',
#  'file2_4_第 121.9 条_(b)': '飞机的湿租 合格证持有人在进行涉及湿租的运行前， 应当向局方 提交一份与国内外其他公共航空运营人所签订的飞机湿租 租赁合同和有关批准文件的副本。局方收到租赁合同副本 后，将确定合同中飞机的运行控制方，并根据需要，向合同 一方或者双方分别颁发运行规范的修改项，否则合格证持有 人不得进行湿租运行。',
#  'file2_4_第 121.9 条_(c)_(1)': '飞机的湿租 合格证持有人实施湿租运行，应当提供下列需要列入 运行规范的信息： 合同双方的名称和合同的有效期限；',
#  'file2_4_第 121.9 条_(c)_(2)': '飞机的湿租 合格证持有人实施湿租运行，应当提供下列需要列入 运行规范的信息： 合同所涉及的每架飞机的国籍标志和登记标志；',
#  'file2_4_第 121.9 条_(c)_(3)': '飞机的湿租 合格证持有人实施湿租运行，应当提供下列需要列入 运行规范的信息： 运行种类；',
#  'file2_4_第 121.9 条_(c)_(4)': '飞机的湿租 合格证持有人实施湿租运行，应当提供下列需要列入 运行规范的信息： 运行的机场或者区域；',
#  'file2_4_第 121.9 条_(c)_(5)': '飞机的湿租 合格证持有人实施湿租运行，应当提供下列需要列入 运行规范的信息： 具体说明计划由哪一方负责运行控制和实施这种运 行控制的时间、机场或者区域。',
#  'file2_4_第 121.9 条_(d)_(1)': '飞机的湿租 在对前款事项作出决定时，局方将考虑下列因素： 机组成员资格；',
#  'file2_4_第 121.9 条_(d)_(2)': '飞机的湿租 在对前款事项作出决定时，局方将考虑下列因素： 飞机的适航性和维修工作；',
#  'file2_4_第 121.9 条_(d)_(3)': '飞机的湿租 在对前款事项作出决定时，局方将考虑下列因素： 飞行签派；',
#  'file2_4_第 121.9 条_(d)_(4)': '飞机的湿租 在对前款事项作出决定时，局方将考虑下列因素： 飞机的补给服务；',
#  'file2_4_第 121.9 条_(d)_(5)': '飞机的湿租 在对前款事项作出决定时，局方将考虑下列因素： 航班计划；',
#  'file2_4_第 121.9 条_(d)_(6)': '飞机的湿租 在对前款事项作出决定时，局方将考虑下列因素： 安全运行责任；',
#  'file2_4_第 121.9 条_(d)_(7)': '飞机的湿租 在对前款事项作出决定时，局方将考虑下列因素： 局方认为有关的其他因素。',
#  'file2_4_第 121.9 条_(e)': '飞机的湿租 经局方批准， 合格证持有人在因特殊原因取消其飞机 的飞行时，可以租用带有一名或者多名机组成员的飞机，载 运其旅客进行飞行。这种飞行应当遵守本规则中与所实施运 行有关的规定。',
#  'file2_5_第 121.11 条': '境外运行规则 大型飞机公共航空运输承运人在中国境外运行时，应当 遵守《国际民用航空公约》附件2《空中规则》和所适用的 外国法规。 在 《民用航空器驾驶员合格审定规则》 (CCAR-61)、 《一般运行和飞行规则》(CCAR-91)和本规则的规定严于上 述附件和外国法规的规定并且不与其发生抵触时，还应当遵 守《民用航空器驾驶员合格审定规则》(CCAR-61)、 《一般运 行和飞行规则》(CCAR-91)和本规则的规定。 B 章 运行合格审定的一般规定',
#  'file2_6_第 121.20 条_(a)': '运行合格证及其运行规范 在本规则中， 运行合格证是指批准大型飞机公共航空 运输承运人从事特定公共航空运输运行的许可证书。',
#  'file2_6_第 121.20 条_(b)': '运行合格证及其运行规范 运行规范是运行合格证的附件， 是指与运行合格证相 对应的，大型飞机公共航空运输承运人运行应当符合的批 准、条件和限制等规范。',
#  'file2_7_第 121.21 条_(a)_(1)': '运行合格证及其运行规范的申请和颁发程 序 大型飞机公共航空运输承运人实施本规则第121.3 条 规定的运行，应当向其主运行基地所在地的民航地区管理局 申请颁发运行合格证及其运行规范。民航地区管理局按照预 先申请、正式申请、文件审查、演示验证和发证五个步骤进 行审查。运行合格证及其运行规范的申请人应当按照规定的 格式和方法向其主运行基地所在地的民航地区管理局提交 申请书，申请书应当至少附有下列材料： 审查活动日程表；',
#  'file2_7_第 121.21 条_(a)_(2)': '运行合格证及其运行规范的申请和颁发程 序 大型飞机公共航空运输承运人实施本规则第121.3 条 规定的运行，应当向其主运行基地所在地的民航地区管理局 申请颁发运行合格证及其运行规范。民航地区管理局按照预 先申请、正式申请、文件审查、演示验证和发证五个步骤进 行审查。运行合格证及其运行规范的申请人应当按照规定的 格式和方法向其主运行基地所在地的民航地区管理局提交 申请书，申请书应当至少附有下列材料： 本规则第121.133 条所要求的手册；',
#  'file2_7_第 121.21 条_(a)_(3)': '运行合格证及其运行规范的申请和颁发程 序 大型飞机公共航空运输承运人实施本规则第121.3 条 规定的运行，应当向其主运行基地所在地的民航地区管理局 申请颁发运行合格证及其运行规范。民航地区管理局按照预 先申请、正式申请、文件审查、演示验证和发证五个步骤进 行审查。运行合格证及其运行规范的申请人应当按照规定的 格式和方法向其主运行基地所在地的民航地区管理局提交 申请书，申请书应当至少附有下列材料： 训练大纲及课程；',
#  'file2_7_第 121.21 条_(a)_(4)': '运行合格证及其运行规范的申请和颁发程 序 大型飞机公共航空运输承运人实施本规则第121.3 条 规定的运行，应当向其主运行基地所在地的民航地区管理局 申请颁发运行合格证及其运行规范。民航地区管理局按照预 先申请、正式申请、文件审查、演示验证和发证五个步骤进 行审查。运行合格证及其运行规范的申请人应当按照规定的 格式和方法向其主运行基地所在地的民航地区管理局提交 申请书，申请书应当至少附有下列材料： 管理人员资历；',
#  'file2_7_第 121.21 条_(a)_(5)': '运行合格证及其运行规范的申请和颁发程 序 大型飞机公共航空运输承运人实施本规则第121.3 条 规定的运行，应当向其主运行基地所在地的民航地区管理局 申请颁发运行合格证及其运行规范。民航地区管理局按照预 先申请、正式申请、文件审查、演示验证和发证五个步骤进 行审查。运行合格证及其运行规范的申请人应当按照规定的 格式和方法向其主运行基地所在地的民航地区管理局提交 申请书，申请书应当至少附有下列材料： 飞机及运行设施、设备的购买或者租用合同复印件；',
#  'file2_7_第 121.21 条_(a)_(6)': '运行合格证及其运行规范的申请和颁发程 序 大型飞机公共航空运输承运人实施本规则第121.3 条 规定的运行，应当向其主运行基地所在地的民航地区管理局 申请颁发运行合格证及其运行规范。民航地区管理局按照预 先申请、正式申请、文件审查、演示验证和发证五个步骤进 行审查。运行合格证及其运行规范的申请人应当按照规定的 格式和方法向其主运行基地所在地的民航地区管理局提交 申请书，申请书应当至少附有下列材料： 说明申请人如何符合本规则所有适用条款的符合性 声明。',
#  'file2_7_第 121.21 条_(b)': '运行合格证及其运行规范的申请和颁发程 序 初次申请运行合格证的申请人， 应当在提交申请书的 同时，提交说明计划运行的性质和范围的文件，包括准许申 请人从事经营活动的有关证明文件。',
#  'file2_7_第 121.21 条_(c)': '运行合格证及其运行规范的申请和颁发程 序 民航地区管理局应当在收到申请书之后的5 个工作日 内书面通知申请人是否受理申请。 申请人未能按照本条(a)款 要求提交齐全的材料或者申请书格式不符合要求，需要申请 人补充申请材料的，民航地区管理局应当在该5 个工作日内 一次性告知需要补正的全部内容。',
#  'file2_7_第 121.21 条_(d)': '运行合格证及其运行规范的申请和颁发程 序 民航地区管理局受理申请后， 对申请人的申请材料是 否符合本规则的要求进行审查，对申请人能否按照本规则安 全运行进行验证检查。',
#  'file2_7_第 121.21 条_(e)': '运行合格证及其运行规范的申请和颁发程 序 民航地区管理局应当自受理申请之日起20 个工作日 内做出是否颁发运行合格证及其运行规范的决定，民航地区 管理局依法进行检验、组织专家评审的时间不计入前述期 限。',
#  'file2_7_第 121.21 条_(f)': '运行合格证及其运行规范的申请和颁发程 序 申请人属于本规则第121.23 条(b)款规定情形的， 不予 颁发运行合格证及其运行规范。对于此种情况，民航地区管 理局应当书面通知申请人，说明理由并告知申请人享有依法 申请行政复议或者提起行政诉讼的权利。',
#  'file2_8_第 121.23 条_(a)_(1)': '运行合格证及其运行规范的颁发条件 申请人经过审查后符合下列全部条件， 可以取得大型 飞机公共航空运输承运人运行合格证及其运行规范： 满足本规则和涉及民航管理的规章所有适用条款的 要求；',
#  'file2_8_第 121.23 条_(a)_(2)': '运行合格证及其运行规范的颁发条件 申请人经过审查后符合下列全部条件， 可以取得大型 飞机公共航空运输承运人运行合格证及其运行规范： 按照涉及民航管理的规章的规定， 配备了合格和足够 的人员、设备、设施和资料，并且能够按照本规则的规定及 其运行规范实施安全运行；',
#  'file2_8_第 121.23 条_(a)_(3)': '运行合格证及其运行规范的颁发条件 申请人经过审查后符合下列全部条件， 可以取得大型 飞机公共航空运输承运人运行合格证及其运行规范： 具有与特定的运行性质和范围相符的完善的组织机 构、飞行运行的控制和监督方法、训练大纲以及地面服务和 维修安排；',
#  'file2_8_第 121.23 条_(a)_(4)': '运行合格证及其运行规范的颁发条件 申请人经过审查后符合下列全部条件， 可以取得大型 飞机公共航空运输承运人运行合格证及其运行规范： 符合安全保卫相关的涉及民航管理的规章的要求；',
#  'file2_8_第 121.23 条_(a)_(5)': '运行合格证及其运行规范的颁发条件 申请人经过审查后符合下列全部条件， 可以取得大型 飞机公共航空运输承运人运行合格证及其运行规范： 为代表其执行工作的第三方制定了政策和程序。',
#  'file2_8_第 121.23 条_(b)_(1)': '运行合格证及其运行规范的颁发条件 申请人具有下列情形之一的，不予颁发运行合格证： 申请人没有配备合格的或者足够的人员、设备、设施 和资料，或者不能按照有关涉及民航管理的规章实施安全运 行；',
#  'file2_8_第 121.23 条_(b)_(2)': '运行合格证及其运行规范的颁发条件 申请人具有下列情形之一的，不予颁发运行合格证： 申请人或者对其经营管理有控制权的人员， 存在与运 行相关的严重失信行为记录的；',
#  'file2_8_第 121.23 条_(b)_(3)': '运行合格证及其运行规范的颁发条件 申请人具有下列情形之一的，不予颁发运行合格证： 申请人安排或者计划安排担任本规则第121.43 条(a) 款规定的主要管理职位的人员，存在与运行相关的严重失信 行为记录的。',
#  'file2_9_第 121.25 条_(a)_(1)': '运行合格证及其运行规范的内容 经审查合格后，局方应当向申请人颁发大型飞机公共航 空运输承运人运行合格证及其运行规范。 大型飞机公共航空运输承运人运行合格证包含下列 内容： 合格证持有人的名称；',
#  'file2_9_第 121.25 条_(a)_(2)': '运行合格证及其运行规范的内容 经审查合格后，局方应当向申请人颁发大型飞机公共航 空运输承运人运行合格证及其运行规范。 大型飞机公共航空运输承运人运行合格证包含下列 内容： 合格证持有人主运行基地的地址；',
#  'file2_9_第 121.25 条_(a)_(3)': '运行合格证及其运行规范的内容 经审查合格后，局方应当向申请人颁发大型飞机公共航 空运输承运人运行合格证及其运行规范。 大型飞机公共航空运输承运人运行合格证包含下列 内容： 合格证的编号；',
#  'file2_9_第 121.25 条_(a)_(4)': '运行合格证及其运行规范的内容 经审查合格后，局方应当向申请人颁发大型飞机公共航 空运输承运人运行合格证及其运行规范。 大型飞机公共航空运输承运人运行合格证包含下列 内容： 合格证的生效日期和有效期；',
#  'file2_9_第 121.25 条_(a)_(5)': '运行合格证及其运行规范的内容 经审查合格后，局方应当向申请人颁发大型飞机公共航 空运输承运人运行合格证及其运行规范。 大型飞机公共航空运输承运人运行合格证包含下列 内容： 负责监督该合格证持有人运行的局方机构名称和联 系方式；',
#  'file2_9_第 121.25 条_(a)_(6)': '运行合格证及其运行规范的内容 经审查合格后，局方应当向申请人颁发大型飞机公共航 空运输承运人运行合格证及其运行规范。 大型飞机公共航空运输承运人运行合格证包含下列 内容： 被批准的运行种类；',
#  'file2_9_第 121.25 条_(a)_(7)': '运行合格证及其运行规范的内容 经审查合格后，局方应当向申请人颁发大型飞机公共航 空运输承运人运行合格证及其运行规范。 大型飞机公共航空运输承运人运行合格证包含下列 内容： 说明经审定，该合格证持有人符合本规则的相应要 求，批准其按照所颁发的运行规范实施运行。',
#  'file2_9_第 121.25 条_(b)_(1)': '运行合格证及其运行规范的内容 经审查合格后，局方应当向申请人颁发大型飞机公共航 空运输承运人运行合格证及其运行规范。 大型飞机公共航空运输承运人的运行规范包含下列 内容： 主运行基地的具体地址， 作为合格证持有人与局方进 行通信联系的不同于其主运行基地地址的地址，以及其文件 收发机构的名称与通信地址；',
#  'file2_9_第 121.25 条_(b)_(2)': '运行合格证及其运行规范的内容 经审查合格后，局方应当向申请人颁发大型飞机公共航 空运输承运人运行合格证及其运行规范。 大型飞机公共航空运输承运人的运行规范包含下列 内容： 对每种运行的实施规定的权利、限制和主要程序；',
#  'file2_9_第 121.25 条_(b)_(3)': '运行合格证及其运行规范的内容 经审查合格后，局方应当向申请人颁发大型飞机公共航 空运输承运人运行合格证及其运行规范。 大型飞机公共航空运输承运人的运行规范包含下列 内容： 每个级别和型别的飞机在运行中需要遵守的其他程 序；',
#  'file2_9_第 121.25 条_(b)_(4)': '运行合格证及其运行规范的内容 经审查合格后，局方应当向申请人颁发大型飞机公共航 空运输承运人运行合格证及其运行规范。 大型飞机公共航空运输承运人的运行规范包含下列 内容： 批准合格证持有人使用的每架飞机的型号、系列编 号、国籍标志和登记标志，定期载客运行中需要使用的每个 正常使用机场、备降机场、临时使用机场和加油机场。经批 准，这些项目可以列在现行有效的清单中，作为运行规范的 附件，并在运行规范的相应条款中注明该清单名称。合格证 持有人只能使用列在清单上的飞机和机场运行；',
#  'file2_9_第 121.25 条_(b)_(5)': '运行合格证及其运行规范的内容 经审查合格后，局方应当向申请人颁发大型飞机公共航 空运输承运人运行合格证及其运行规范。 大型飞机公共航空运输承运人的运行规范包含下列 内容： 批准的运行种类；',
#  'file2_9_第 121.25 条_(b)_(6)': '运行合格证及其运行规范的内容 经审查合格后，局方应当向申请人颁发大型飞机公共航 空运输承运人运行合格证及其运行规范。 大型飞机公共航空运输承运人的运行规范包含下列 内容： 批准运行的航线和区域及其限制；',
#  'file2_9_第 121.25 条_(b)_(7)': '运行合格证及其运行规范的内容 经审查合格后，局方应当向申请人颁发大型飞机公共航 空运输承运人运行合格证及其运行规范。 大型飞机公共航空运输承运人的运行规范包含下列 内容： 机场的限制；',
#  'file2_9_第 121.25 条_(b)_(8)': '运行合格证及其运行规范的内容 经审查合格后，局方应当向申请人颁发大型飞机公共航 空运输承运人运行合格证及其运行规范。 大型飞机公共航空运输承运人的运行规范包含下列 内容： 机体、发动机、螺旋桨、设备(包括应急设备)的维修 时限或者确定维修时限的标准；',
#  'file2_9_第 121.25 条_(b)_(9)': '运行合格证及其运行规范的内容 经审查合格后，局方应当向申请人颁发大型飞机公共航 空运输承运人运行合格证及其运行规范。 大型飞机公共航空运输承运人的运行规范包含下列 内容： 批准的控制飞机重量与平衡的方法；',
#  'file2_9_第 121.25 条_(b)_(10)': '运行合格证及其运行规范的内容 经审查合格后，局方应当向申请人颁发大型飞机公共航 空运输承运人运行合格证及其运行规范。 大型飞机公共航空运输承运人的运行规范包含下列 内容： 飞机互换的要求；',
#  'file2_9_第 121.25 条_(b)_(11)': '运行合格证及其运行规范的内容 经审查合格后，局方应当向申请人颁发大型飞机公共航 空运输承运人运行合格证及其运行规范。 大型飞机公共航空运输承运人的运行规范包含下列 内容： 湿租飞机的有关资料；',
#  'file2_9_第 121.25 条_(b)_(12)': '运行合格证及其运行规范的内容 经审查合格后，局方应当向申请人颁发大型飞机公共航 空运输承运人运行合格证及其运行规范。 大型飞机公共航空运输承运人的运行规范包含下列 内容： 按照规定颁发的豁免或者批准的偏离；',
#  'file2_9_第 121.25 条_(b)_(13)': '运行合格证及其运行规范的内容 经审查合格后，局方应当向申请人颁发大型飞机公共航 空运输承运人运行合格证及其运行规范。 大型飞机公共航空运输承运人的运行规范包含下列 内容： 按照本规则需要局方批准的手册和训练大纲；',
#  'file2_9_第 121.25 条_(b)_(14)': '运行合格证及其运行规范的内容 经审查合格后，局方应当向申请人颁发大型飞机公共航 空运输承运人运行合格证及其运行规范。 大型飞机公共航空运输承运人的运行规范包含下列 内容： 按照本规则实施运行所必须的管理人员和机构；',
#  'file2_9_第 121.25 条_(b)_(15)': '运行合格证及其运行规范的内容 经审查合格后，局方应当向申请人颁发大型飞机公共航 空运输承运人运行合格证及其运行规范。 大型飞机公共航空运输承运人的运行规范包含下列 内容： 按照本规则需要局方批准的其他项目。',
#  'file2_10_第 121.27 条_(a)_(1)': '运行合格证及其运行规范的有效性 运行合格证在出现下列情形之一时失效： 合格证持有人自愿放弃，并将其交回局方；',
#  'file2_10_第 121.27 条_(a)_(2)': '运行合格证及其运行规范的有效性 运行合格证在出现下列情形之一时失效： 局方依法暂扣、撤销或者以其他方式终止该合格证。',
#  'file2_10_第 121.27 条_(b)_(1)': '运行合格证及其运行规范的有效性 在出现下列情形时， 运行规范全部失效或者部分条款 失效： 局方依法暂扣、撤销或者以其他方式终止运行合格 证，则运行规范全部失效；',
#  'file2_10_第 121.27 条_(b)_(2)': '运行合格证及其运行规范的有效性 在出现下列情形时， 运行规范全部失效或者部分条款 失效： 局方依法暂停或者终止该运行规范中批准的全部运 行，则运行规范全部失效；',
#  'file2_10_第 121.27 条_(b)_(3)': '运行合格证及其运行规范的有效性 在出现下列情形时， 运行规范全部失效或者部分条款 失效： 局方依法暂停或者终止该运行规范中批准的部分运 行，则运行规范中关于该部分运行的条款失效；',
#  'file2_10_第 121.27 条_(b)_(4)': '运行合格证及其运行规范的有效性 在出现下列情形时， 运行规范全部失效或者部分条款 失效： 对于某一运行种类， 合格证持有人没有满足本规则第 121.47 条(a)款中规定的近期经历要求，并且没有按照第 121.47 条(b)款规定的程序恢复该种类运行时， 运行规范中关 于该种类运行的条款失效。',
#  'file2_10_第 121.27 条_(c)': '运行合格证及其运行规范的有效性 当运行合格证或者运行规范依法被暂扣、撤销或者因 其他原因而失效时，合格证持有人应当将运行合格证或者运 行规范交还局方。',
#  'file2_11_第 121.29 条': '运行合格证及其运行规范的检查 合格证持有人应当将其运行合格证及其运行规范保存 在主运行基地，并能随时接受局方的检查。合格证持有人的 飞机上应当携带运行合格证及其运行规范经认证的真实副 本，并保证副本与正本一致。该副本可以是纸质版，也可以 是符合局方要求的其他形式。',
#  'file2_12_第 121.31 条_(a)_(1)': '运行合格证的修改 在下列情形下，局方可以修改按照本规则颁发的运行 合格证： 局方认为为了安全和公众利益需要修改；',
#  'file2_12_第 121.31 条_(a)_(2)': '运行合格证的修改 在下列情形下，局方可以修改按照本规则颁发的运行 合格证： 合格证持有人申请修改， 且局方认为安全和公众利益 允许进行此种修改。',
#  'file2_12_第 121.31 条_(b)_(1)': '运行合格证的修改 合格证持有人申请修改其运行合格证时， 适用本规则 第121.21 条(c)款至(f)款规定的程序和期限并应当遵守下列 规定： 合格证持有人应当在不迟于其计划的修改生效日期 前适当的时间向其主运行基地所在地的民航地区管理局提 交修改其运行合格证的申请书；',
#  'file2_12_第 121.31 条_(b)_(2)': '运行合格证的修改 合格证持有人申请修改其运行合格证时， 适用本规则 第121.21 条(c)款至(f)款规定的程序和期限并应当遵守下列 规定： 申请书应当按照规定的格式和方法提交。',
#  'file2_12_第 121.31 条_(c)': '运行合格证的修改 当合格证持有人对其运行合格证修改的申请被拒绝 或者对局方发出的修改决定有不同意见，请求重新考虑时， 应当在收到局方通知后20 个工作日内向局方提出重新考虑 的请求。',
#  'file2_13_第 121.33 条_(a)': '合格证持有人保存和使用运行规范的责任 合格证持有人应当在其主运行基地保存一套独立完 整且现行有效的运行规范。',
#  'file2_13_第 121.33 条_(b)': '合格证持有人保存和使用运行规范的责任 合格证持有人应当将其运行规范中的有关内容或者 信息，写进本规则G 章规定的手册中，并且应当清楚地写明 这些内容是其运行规范的一部分，还应当说明运行规范的每 一条要求具有强制性；或者将完整的运行规范与手册编制在 一起进行分发、携带、保存和更新。',
#  'file2_13_第 121.33 条_(c)': '合格证持有人保存和使用运行规范的责任 合格证持有人应当持续保证其每个参与运行工作的 人员，熟知运行规范中适用于该人员工作职责的有关规定。',
#  'file2_14_第 121.35 条_(a)_(1)': '运行规范的修改 在下列情形下，局方可以修改按照本规则颁发的运行 规范： 局方认为为了安全和公众利益需要修改；',
#  'file2_14_第 121.35 条_(a)_(2)': '运行规范的修改 在下列情形下，局方可以修改按照本规则颁发的运行 规范： 合格证持有人申请修改， 且局方认为安全和公众利益 允许进行此种修改。',
#  'file2_14_第 121.35 条_(b)_(1)': '运行规范的修改 除本条(e)款规定的情形外， 局方主动修改合格证持有 人的运行规范应当遵守下列程序： 局方以书面形式提出修改内容，通知合格证持有人；',
#  'file2_14_第 121.35 条_(b)_(2)': '运行规范的修改 除本条(e)款规定的情形外， 局方主动修改合格证持有 人的运行规范应当遵守下列程序： 局方确定一个不少于5 个工作日的合理期限， 合格证 持有人可以在此期限内对修改内容提交有关书面资料和意 见；',
#  'file2_14_第 121.35 条_(b)_(3)': '运行规范的修改 除本条(e)款规定的情形外， 局方主动修改合格证持有 人的运行规范应当遵守下列程序： 局方审查合格证持有人提交的全部材料后， 作出下列 决定之一并通知合格证持有人：',
#  'file2_14_第 121.35 条_(i)_(4)': '运行规范的修改 接受所申请的全部修改； (ii)接受所申请的部分修改； (iii)拒绝所申请的修改。此时，合格证持有人可以按照 本条(d)款规定，请求局方对其拒绝决定进行重新考虑。 局方批准修改的， 经与合格证持有人就其修改的贯彻 问题进行协调后，修改项在局方批准的日期生效；',
#  'file2_14_第 121.35 条_(i)_(5)': '运行规范的修改 接受所申请的全部修改； (ii)接受所申请的部分修改； (iii)拒绝所申请的修改。此时，合格证持有人可以按照 本条(d)款规定，请求局方对其拒绝决定进行重新考虑。 如果合格证持有人守法信用信息记录中存在与运行 相关的严重失信行为记录，局方可以拒绝其申请的部分或者 全部修改。',
#  'file2_14_第 121.35 条_(c)_(1)': '运行规范的修改 合格证持有人申请修改其运行规范时， 适用本规则第 121.21 条(c)款至(f)款规定的程序和期限并应当遵守下列规 定： 合格证持有人应当在计划的运行规范修改生效日期 前适当时间提交修改其运行规范的申请书，但有下列情形之 一的，申请人应当在计划的运行规范修改生效日期前足够的 时间内提出申请：',
#  'file2_14_第 121.35 条_(v)_(2)': '运行规范的修改 初次引进以前未经大型飞机公共航空运输承运人运 行验证试飞的飞机的。 申请书应当以规定的格式和方法向其主运行基地所 在地的民航地区管理局提交；',
#  'file2_14_第 121.35 条_(v)_(3)': '运行规范的修改 初次引进以前未经大型飞机公共航空运输承运人运 行验证试飞的飞机的。 在考虑了申请人提交的所有材料以及局方的审查情 况后，局方作出下列决定之一并通知合格证持有人：',
#  'file2_14_第 121.35 条_(d)_(1)': '运行规范的修改 合格证持有人申请局方重新考虑运行规范修改项的 决定的，应当遵守下列程序： 合格证持有人应当在收到局方拒绝修改其运行规范 的通知后， 或者在收到局方提出修改其运行规范的通知后20 个工作日内，向局方提出重新考虑的请求；',
#  'file2_14_第 121.35 条_(d)_(2)': '运行规范的修改 合格证持有人申请局方重新考虑运行规范修改项的 决定的，应当遵守下列程序： 如果重新考虑的请求是在20 个工作日内提出的，则 局方颁发的任何修改暂停生效，除非局方发现，根据本条(e) 款，存在紧急情况，为了安全，需要立即生效；',
#  'file2_14_第 121.35 条_(d)_(3)': '运行规范的修改 合格证持有人申请局方重新考虑运行规范修改项的 决定的，应当遵守下列程序： 如果重新考虑的请求不是在20 个工作日内提出的， 按照本条(c)款规定的程序执行。',
#  'file2_14_第 121.35 条_(e)_(1)': '运行规范的修改 如果局方发现，存在危及安全、需要立即行动的紧急 情况， 不能执行本条(b)款至(d)款规定的程序， 或者按照程序 进行将违背公众利益，则可以采取下列措施： 局方修改运行规范， 并使修改项在合格证持有人收到 该修改通知日期起立即生效；',
#  'file2_14_第 121.35 条_(e)_(2)': '运行规范的修改 如果局方发现，存在危及安全、需要立即行动的紧急 情况， 不能执行本条(b)款至(d)款规定的程序， 或者按照程序 进行将违背公众利益，则可以采取下列措施： 在发给合格证持有人的通知中，局方应当说明原因， 指出存在危及安全、需要立即行动的紧急情况，或者指出修 改推迟生效将违背公众利益的情况。',
#  'file2_15_第 121.37 条': '申请人的责任 申请人申请取得或者申请修改运行合格证及其运行规 范以及与运行合格审定有关的其他项目，应当保证申请材料 真实完整。 C 章 管理合格证持有人的一般规定',
#  'file2_16_第 121.41 条_(a)': '监察和检查的实施 合格证持有人应当接受局方在任何时间或者地点对 其进行的监察或者检查，以确定其是否符合涉及民航管理的 规章的规定，是否符合其运行合格证及其运行规范的规定。',
#  'file2_16_第 121.41 条_(b)_(1)': '监察和检查的实施 合格证持有人应当能在其主运行基地向局方提供下 列资料： 合格证持有人的大型飞机公共航空运输承运人运行 合格证及其运行规范；',
#  'file2_16_第 121.41 条_(b)_(2)': '监察和检查的实施 合格证持有人应当能在其主运行基地向局方提供下 列资料： 一个包含有关资料存放地点和负责人员信息的现行 清单。上述资料是指合格证持有人按照适用的涉及民航管理 的规章规定，应当保存的记录、文件和报告。',
#  'file2_16_第 121.41 条_(c)': '监察和检查的实施 负责保存合格证持有人记录、文件和报告的所有人 员，应当能向局方提供这些资料。',
#  'file2_16_第 121.41 条_(d)': '监察和检查的实施 局方可以根据本条(a)款检查的结果或者任何其他适 当的材料，确定合格证持有人是否合格于继续持有其运行合 格证及其运行规范。',
#  'file2_16_第 121.41 条_(e)': '监察和检查的实施 合格证持有人如果不能按照局方要求， 提供其运行合 格证、运行规范或者任何必需的记录、文件和报告，存在安 全隐患的，局方可以暂停其运行合格证或运行规范中的部分 或者全部运行批准。',
#  'file2_17_第 121.42 条_(a)_(1)': '安全管理体系 合格证持有人应当建立安全管理体系，并且能够按照本 规则的规定实施安全管理，该体系应当： 至少具备了下列功能： 对影响安全的危险源能够及时识别；',
#  'file2_17_第 121.42 条_(a)_(2)': '安全管理体系 合格证持有人应当建立安全管理体系，并且能够按照本 规则的规定实施安全管理，该体系应当： 至少具备了下列功能： 保证采取必要的纠正措施，保持可接受的安全水平；',
#  'file2_17_第 121.42 条_(a)_(3)': '安全管理体系 合格证持有人应当建立安全管理体系，并且能够按照本 规则的规定实施安全管理，该体系应当： 至少具备了下列功能： 对安全水平进行持续的监督和定期评估；',
#  'file2_17_第 121.42 条_(a)_(4)': '安全管理体系 合格证持有人应当建立安全管理体系，并且能够按照本 规则的规定实施安全管理，该体系应当： 至少具备了下列功能： 持续改进整体安全水平。',
#  'file2_17_第 121.42 条_(b)': '安全管理体系 合格证持有人应当建立安全管理体系，并且能够按照本 规则的规定实施安全管理，该体系应当： 明确地界定了整个组织内部的安全责任界限， 包括高 层管理者应当对安全直接承担的责任。',
#  'file2_17_第 121.42 条_(c)': '安全管理体系 合格证持有人应当建立安全管理体系，并且能够按照本 规则的规定实施安全管理，该体系应当： 制订并持续实施非惩罚性， 且包含保护数据及其来源 措施的飞行数据分析方案。',
#  'file2_17_第 121.42 条_(d)': '安全管理体系 合格证持有人应当建立安全管理体系，并且能够按照本 规则的规定实施安全管理，该体系应当： 制订供运行人员使用的飞行安全文件系统。',
#  'file2_18_第 121.43 条_(a)_(1)': '按照本规则实施运行所必需的管理人员和 机构 合格证持有人应当拥有能够有效控制和监督其整个 运行的管理机构，并拥有足够的合格管理人员和技术人员， 以保证在其运行中保持最高的安全水平。合格证持有人应当 在下列职位或者同等职位上安排合格的人员： 主要负责人， 对合格证持有人安全生产工作全面负责 的高级管理人员，具体责任包括：',
#  'file2_18_第 121.43 条_(i)': '按照本规则实施运行所必需的管理人员和 机构 有关涉及民航管理的规章； (ii)合格证持有人的运行规范； (iii)航空安全标准和安全运行常规； (iv)本规则及其他涉及民航管理的规章中所有适用的维 修和适航要求；',
#  'file2_18_第 121.43 条_(b)': '按照本规则实施运行所必需的管理人员和 机构 对于某一项具体运行，如果合格证持有人能证明，由 于所涉及的运行种类、所使用的飞机数量与型号和运行的区 域等因素，使用较少的管理人员能够完成本条(a)款规定的除 安全总监以外其他职位的全部职责并能以同等安全水平完 成运行， 局方可以认可其管理人员的配备。 除经局方批准外， 安全总监不允许由本条(a)款其余职务的人员兼任。',
#  'file2_18_第 121.43 条_(c)': '按照本规则实施运行所必需的管理人员和 机构 本条(a)款要求的或者按照本条(b)款认可的职位名称 和管理人员数量，应当在合格证持有人的运行规范中明确载 明。',
#  'file2_18_第 121.43 条_(d)_(1)': '按照本规则实施运行所必需的管理人员和 机构 担任本条(a)款或者(b)款要求的或者认可的职位的人 员，以及按照运行合格证实施运行的各级负责人，应当符合 下列要求： 在训练、经验、专业知识上保持合格水平。',
#  'file2_18_第 121.43 条_(d)_(2)': '按照本规则实施运行所必需的管理人员和 机构 担任本条(a)款或者(b)款要求的或者认可的职位的人 员，以及按照运行合格证实施运行的各级负责人，应当符合 下列要求： 在其职责范围内， 理解有关合格证持有人各种运行的 下列资料：',
#  'file2_18_第 121.43 条_(v)_(3)': '按照本规则实施运行所必需的管理人员和 机构 本规则第121.131 条要求的手册。 严格履行其职责，以符合适用的规章要求，并保证安 全运行。',
#  'file2_18_第 121.43 条_(e)': '按照本规则实施运行所必需的管理人员和 机构 合格证持有人应当在本规则G 章要求的手册内的一 般政策规定中，写明本条(a)款规定的人员的任务、职责和权 力，并写明担任这些职务人员的姓名和业务地址。合格证持 有人应当在上述所列职位上的人员变换或者空缺后10 天内 通知局方。',
#  'file2_18_第 121.43 条_(f)': '按照本规则实施运行所必需的管理人员和 机构 合格证持有人应当设立由飞行、维修、签派和客舱安 全等专业人员组成的运行管理机构，负责协调各业务部门有 关运行的事项；办理运行合格审定的有关事宜；负责手册的 分发、更改和报批工作，保持其有效性。',
#  'file2_18_第 121.43 条_(g)': '按照本规则实施运行所必需的管理人员和 机构 合格证持有人应当设立独立于运行的安全监督机构， 在安全总监的直接领导下，负责安全水平的持续监督和定期 评估；调查安全相关事件；就安全有关事务提出建议和组织 员工安全教育等。',
#  'file2_19_第 121.45 条_(a)_(1)': '管理人员的合格条件 款规定的主要负责人应当符合下列条件： 接受了局方认可的相关法规的培训并合格；',
#  'file2_19_第 121.45 条_(a)_(2)': '管理人员的合格条件 款规定的主要负责人应当符合下列条件： 曾经担任按本规则运行的第121.43 条(a)款规定的主 要管理人员或者具备至少3 年民航安全管理工作经验；',
#  'file2_19_第 121.45 条_(a)_(3)': '管理人员的合格条件 款规定的主要负责人应当符合下列条件： 熟悉合格证持有人的运行规范、 运行手册及其他相关 要求；',
#  'file2_19_第 121.45 条_(a)_(4)': '管理人员的合格条件 款规定的主要负责人应当符合下列条件： 具有较强的分析解决问题能力和良好的沟通技能。',
#  'file2_19_第 121.45 条_(b)_(1)': '管理人员的合格条件 担任本规则第121.43 条(a)款规定的安全总监应当符 合下列条件： 掌握运行安全管理知识、质量管理知识、涉及民航管 理的规章、标准及程序;',
#  'file2_19_第 121.45 条_(b)_(2)': '管理人员的合格条件 担任本规则第121.43 条(a)款规定的安全总监应当符 合下列条件： 最近6年内在合格证持有人或者局方的安全监督岗位 工作3 年以上，或者持有下列任一专业执照并在相应岗位上 工作3 年以上：',
#  'file2_19_第 121.45 条_(i)_(3)': '管理人员的合格条件 航线运输驾驶员执照； (ii)民用航空器维修人员执照； (iii)飞行签派员执照。 理解合格证持有人的运行规范、 运行手册及其他相关 要求;',
#  'file2_19_第 121.45 条_(i)_(4)': '管理人员的合格条件 航线运输驾驶员执照； (ii)民用航空器维修人员执照； (iii)飞行签派员执照。 具有较强的分析解决问题能力和良好的沟通技能。',
#  'file2_19_第 121.45 条_(c)': '管理人员的合格条件 、(d)、(e)或者(f)款规定的经历，但具有相应的经历，能够 有效履行涉及民航管理的规章要求的相应职位的职责和合 格证持有人手册规定的程序，局方可以批准对本条相应款项 规定经历的偏离。',
#  'file2_19_第 121.45 条_(d)_(1)': '管理人员的合格条件 担任本规则第121.43 条(a)款规定的维修副总经理应 当符合下列条件： 接受了局方认可的相关法规的培训并合格；',
#  'file2_19_第 121.45 条_(d)_(2)': '管理人员的合格条件 担任本规则第121.43 条(a)款规定的维修副总经理应 当符合下列条件： 在前6 年内具有至少3 年从事合格证持有人运行的至 少一种类别和级别飞机全面的维修管理经历。',
#  'file2_19_第 121.45 条_(e)_(1)': '管理人员的合格条件 担任本规则第121.43 条(a)款规定的总飞行师应当符 合下列条件： 持有航线运输驾驶员执照， 至少具有该合格证持有人 按照本规则运行中所用的一种飞机的合适等级；',
#  'file2_19_第 121.45 条_(e)_(2)': '管理人员的合格条件 担任本规则第121.43 条(a)款规定的总飞行师应当符 合下列条件： 对于初次担任总飞行师的人员，在最近6 年内，至少 在该合格证持有人按照本规则运行的相同级别的飞机上，具 有担任机长3 年的经历；对于具有总飞行师经历的人员，至 少在与该合格证持有人按照本规则运行的相同级别的飞机 上，具有担任机长3 年的经历。',
#  'file2_19_第 121.45 条_(f)_(1)': '管理人员的合格条件 担任本规则第121.43 条(a)款规定的总工程师应当符 合下列条件： 持有民用航空器维修人员执照， 至少具有该合格证持 有人按照本规则运行中所用的一种飞机的机型签署经历；',
#  'file2_19_第 121.45 条_(f)_(2)': '管理人员的合格条件 担任本规则第121.43 条(a)款规定的总工程师应当符 合下列条件： 具有维修本规则运行的飞机至少5 年的经历， 其中至 少有2 年作为维修工程技术管理人员的经历。',
#  'file2_19_第 121.45 条_(g)': '管理人员的合格条件 如果合格证持有人拟选任的人员不符合本条(a)、(b)、',
#  'file2_20_第 121.47 条_(a)': '运行的近期经历 合格证持有人如果连续中断其运行规范中批准实施 的某一种类的运行达30 个日历日，则在此日期之后，应当 按照本条(b)款规定恢复运行，否则不得继续实施此种运行。',
#  'file2_20_第 121.47 条_(b)_(1)': '运行的近期经历 在本条(a)款的中断期之后， 只有符合下列条件并达到 局方要求后，方可以恢复相应种类的运行： 在恢复该种运行之前， 至少提前5个工作日通知局方；',
#  'file2_20_第 121.47 条_(b)_(2)': '运行的近期经历 在本条(a)款的中断期之后， 只有符合下列条件并达到 局方要求后，方可以恢复相应种类的运行： 如果局方决定重新进行全面检查， 以确定其是否保持 了合适和足够的配备，能否实施安全运行，合格证持有人应 当在前述5 个工作日期间处于能随时接受检查的状态。',
#  'file2_21_第 121.49 条_(a)': '主运行基地、飞行基地和维修基地 合格证持有人应当保持一个主运行基地。合格证持有 人还可以按照运行需要建立飞行基地和维修基地，飞行基地 和维修基地可以与主运行基地在同一地点，也可以在不同地 点。',
#  'file2_21_第 121.49 条_(b)': '主运行基地、飞行基地和维修基地 在计划建立或者变更主运行基地、 飞行基地或者维修 基地之前至少30 天，合格证持有人应当以书面形式通知局 方。',
#  'file2_22_第 121.51 条_(a)': '合格证持有人名称的使用 合格证持有人按照本规则实施运行时所使用的名称 应当与其运行规范上所列名称一致。',
#  'file2_22_第 121.51 条_(b)': '合格证持有人名称的使用 除经局方在运行规范中批准外， 在按照本规则运行的 飞机上应当明显地标出运行该飞机的合格证持有人的名称， 否则不得运行该飞机。飞机上标示名称的方法及其可读性应 当符合局方要求。',
#  'file2_23_第 121.52 条_(a)_(1)': '飞行数据的使用 合格证持有人不得为事故或者征候调查以外的目的 使用驾驶舱话音记录器、驾驶舱音频记录系统的记录或者文 本，除非这些记录或者文本： 在去识别化后， 用于合格证持有人安全管理体系内不 安全事件的调查、分析、研究等，并符合《国际民用航空公 约》附件19《安全管理》关于保护安全数据和安全信息的相 关要求；',
#  'file2_23_第 121.52 条_(a)_(2)': '飞行数据的使用 合格证持有人不得为事故或者征候调查以外的目的 使用驾驶舱话音记录器、驾驶舱音频记录系统的记录或者文 本，除非这些记录或者文本： 用于与事故或者征候调查所涉事件无关的刑事诉讼， 并符合《国际民用航空公约》附件19《安全管理》关于保护 安全数据和安全信息的相关要求；',
#  'file2_23_第 121.52 条_(a)_(3)': '飞行数据的使用 合格证持有人不得为事故或者征候调查以外的目的 使用驾驶舱话音记录器、驾驶舱音频记录系统的记录或者文 本，除非这些记录或者文本： 用于对飞行记录器系统的检查。',
#  'file2_23_第 121.52 条_(b)_(1)': '飞行数据的使用 合格证持有人不得为事故或者征候调查以外的目的 使用飞行数据记录器、航空器数据记录系统以及本规则第 121.352 条要求的快速记录器的记录或者文本，除非这些记 录或者文本符合《国际民用航空公约》附件19《安全管理》 关于保护安全数据和安全信息的相关要求，且： 去识别化；',
#  'file2_23_第 121.52 条_(b)_(2)': '飞行数据的使用 合格证持有人不得为事故或者征候调查以外的目的 使用飞行数据记录器、航空器数据记录系统以及本规则第 121.352 条要求的快速记录器的记录或者文本，除非这些记 录或者文本符合《国际民用航空公约》附件19《安全管理》 关于保护安全数据和安全信息的相关要求，且： 合格证持有人用于飞行数据分析方案；',
#  'file2_23_第 121.52 条_(b)_(3)': '飞行数据的使用 合格证持有人不得为事故或者征候调查以外的目的 使用飞行数据记录器、航空器数据记录系统以及本规则第 121.352 条要求的快速记录器的记录或者文本，除非这些记 录或者文本符合《国际民用航空公约》附件19《安全管理》 关于保护安全数据和安全信息的相关要求，且： 用于与事故或者征候调查所涉事件无关的诉讼；',
#  'file2_23_第 121.52 条_(b)_(4)': '飞行数据的使用 合格证持有人不得为事故或者征候调查以外的目的 使用飞行数据记录器、航空器数据记录系统以及本规则第 121.352 条要求的快速记录器的记录或者文本，除非这些记 录或者文本符合《国际民用航空公约》附件19《安全管理》 关于保护安全数据和安全信息的相关要求，且： 合格证持有人用于适航或者维修；',
#  'file2_23_第 121.52 条_(b)_(5)': '飞行数据的使用 合格证持有人不得为事故或者征候调查以外的目的 使用飞行数据记录器、航空器数据记录系统以及本规则第 121.352 条要求的快速记录器的记录或者文本，除非这些记 录或者文本符合《国际民用航空公约》附件19《安全管理》 关于保护安全数据和安全信息的相关要求，且： 根据安全数据保护程序被公布。',
#  'file2_23_第 121.52 条_(c)': '飞行数据的使用 合格证持有人可以与另一方签订合同， 由其负责飞行 数据分析方案具体工作，但符合性责任由合格证持有人承 担。',
#  'file2_23_第 121.52 条_(d)': '飞行数据的使用 合格证持有人应当定期向负责合格证管理的民航地 区管理局职能部门报告其通过飞行数据分析方案得到的统 计数据和趋势分析报告，局方认为必要时可以随时查阅或者 分析快速存取记录器(QAR)或者等效设备的原始数据。',
#  'file2_24_第 121.53 条_(a)': '按照军方合同实施运行的偏离批准 局方可以批准合格证持有人偏离本规则的适用规定， 实施其按照军方合同确定的运行。',
#  'file2_24_第 121.53 条_(b)': '按照军方合同实施运行的偏离批准 在按照本条批准一项偏离时， 局方将对合格证持有人 的运行规范颁发相应的修改项。',
#  'file2_24_第 121.53 条_(c)': '按照军方合同实施运行的偏离批准 局方在任何时候可以终止按照本条颁发的偏离批准。',
#  'file2_25_第 121.55 条_(a)_(1)': '实施应急运行的偏离批准 在紧急情况下并满足下列条件时，局方可以批准合格 证持有人偏离本规则的适用规定： 在该紧急情况下为保护人员生命和财产应当采取运 送人员或者财产的行动；',
#  'file2_25_第 121.55 条_(a)_(2)': '实施应急运行的偏离批准 在紧急情况下并满足下列条件时，局方可以批准合格 证持有人偏离本规则的适用规定： 局方认为，为了立即实施这些运行，应当偏离有关规 定。',
#  'file2_25_第 121.55 条_(b)_(1)': '实施应急运行的偏离批准 在紧急情况下，局方可以使用下列方法之一批准偏 离： 局方对合格证持有人的运行规范颁发相应的修改项；',
#  'file2_25_第 121.55 条_(b)_(2)': '实施应急运行的偏离批准 在紧急情况下，局方可以使用下列方法之一批准偏 离： 如果情况紧急不允许及时修改运行规范， 则局方可以 用口头或者其他方式批准该偏离，但合格证持有人应当在开 始这种运行后24 小时之内，向局方提交说明这种紧急情况 性质的报告。',
#  'file2_26_第 121.57 条': '遵守运行合格证及其运行规范的要求 合格证持有人不得违反运行合格证、运行规范和其他批 准项目实施运行，不得超越批准的偏离或者豁免。 E 章 国内、国际定期载客运行航路的批准',
#  'file2_27_第 121.91 条_(a)_(1)': '航路批准的基本要求 申请航路批准的合格证持有人应当证明符合下列条 件： 能在该航路上每一正常使用机场、 临时使用机场或者 加油机场之间实施满足本规则要求的运行；',
#  'file2_27_第 121.91 条_(a)_(2)': '航路批准的基本要求 申请航路批准的合格证持有人应当证明符合下列条 件： 对于计划的运行，具有满足本规则第121.95 条至第 121.105 条要求的设施与服务。',
#  'file2_27_第 121.91 条_(b)': '航路批准的基本要求 在证明符合本条(a)款要求时， 如果合格证持有人在考 虑了机场、灯光、维修、通信、导航、加油、地面、机载无 线电等各种设施的可用性和充分性，以及参与运行的全体人 员的能力之后，证明能保证飞行安全，局方可以不要求在该 航路上作航路试飞。',
#  'file2_28_第 121.93 条_(a)_(1)': '航路宽度 经批准的航路、航段及固定航线具有的宽度应当至少 与这些固定航线或者航路的规定宽度相等。在局方认为有必 要对经批准的航路另行确定宽度时，将考虑下列因素： 地形障碍的超越；',
#  'file2_28_第 121.93 条_(a)_(2)': '航路宽度 经批准的航路、航段及固定航线具有的宽度应当至少 与这些固定航线或者航路的规定宽度相等。在局方认为有必 要对经批准的航路另行确定宽度时，将考虑下列因素： 最低航路高度；',
#  'file2_28_第 121.93 条_(a)_(3)': '航路宽度 经批准的航路、航段及固定航线具有的宽度应当至少 与这些固定航线或者航路的规定宽度相等。在局方认为有必 要对经批准的航路另行确定宽度时，将考虑下列因素： 地面和机载导航设备；',
#  'file2_28_第 121.93 条_(a)_(4)': '航路宽度 经批准的航路、航段及固定航线具有的宽度应当至少 与这些固定航线或者航路的规定宽度相等。在局方认为有必 要对经批准的航路另行确定宽度时，将考虑下列因素： 空中交通密度；',
#  'file2_28_第 121.93 条_(a)_(5)': '航路宽度 经批准的航路、航段及固定航线具有的宽度应当至少 与这些固定航线或者航路的规定宽度相等。在局方认为有必 要对经批准的航路另行确定宽度时，将考虑下列因素： 空中交通管制程序。',
#  'file2_28_第 121.93 条_(b)': '航路宽度 局方对经批准的航路另行确定的宽度， 将具体规定在 该大型飞机公共航空运输承运人的运行规范中。',
#  'file2_29_第 121.95 条_(a)': '必需的机场资料 合格证持有人应当证明，所申请批准的航路上具有足 够的机场，并且这些机场装备了适合于所申请运行的设施。 其中所考虑的因素应当包括机场的等级、道面、障碍物、设 施、公众保护、灯光、导航、通信、气象设施以及空中交通 管制等。',
#  'file2_29_第 121.95 条_(b)_(1)': '必需的机场资料 合格证持有人应当证明，对于所使用的每个机场，都 能够获得、保存现行有效的航行资料，包含但不限于航行通 告(NOTAM)、航行资料汇编(AIP)、航行资料通报(AIC)和定 期制航行通告(AIRAC)等与运行安全、规则和效率有关的信 息，并且具有将其分发给每个有关人员的经批准的资料管理 系统，以确保飞机在该机场运行的安全。这种航行资料应当 包括下列方面的内容： 机场',
#  'file2_29_第 121.95 条_(i)': '必需的机场资料 跑道视程(RVR)测量设备； (ii)低能见度条件下的盛行风。',
#  'file2_29_第 121.95 条_(v)_(2)': '必需的机场资料 导航、通信、气象设施； (vi)影响起飞、着陆或者地面运行的建筑物； (vii)空中交通服务设施。 跑道、停止道和净空道',
#  'file2_29_第 121.95 条_(c)': '必需的机场资料 如果负责管理该合格证持有人的民航地区管理局发 现该合格证持有人经批准的关于收集、分发和使用航行资料 的系统应当予以改进才能恰当地继续工作，则合格证持有人 在接到该部门的通知后，应当立即对其系统进行改进。在合 格证持有人接到这样的通知之后30 天内，可以向中国民航 局飞行标准职能部门提出重新考虑的请求。重新考虑的请求 使该通知处于暂缓执行状态，直至中国民航局飞行标准职能 部门作出决定时止。但是，如果民航地区管理局认为存在关 系到航空运输安全、需要立即采取措施的紧急情况，则中国 民航局飞行标准职能部门可以根据所陈述的理由，使要求改 进的通知立即生效。',
#  'file2_30_第 121.97 条_(a)': '通信设备 合格证持有人应当证明，在正常运行条件下，在整个 航路上，所有各点都具有陆空双向无线电通信系统，能保证 每一架飞机与相应的空中交通管制单位之间，每一架飞机与 相应的运行控制中心之间，以直接的或者通过经批准的点到 点间的线路进行迅速可靠的通信联系。除遇到紧急情况外， 对于合格证持有人的所有运行，每架飞机与运行控制中心之 间的通信系统应当是空中交通管制通信系统之外的独立系 统。',
#  'file2_30_第 121.97 条_(b)': '通信设备 对于国内运行， 如合格证持有人评估所运行的航线上 存在空中交通管制通信设施不可用或者通信质量无法保证 有效语音通信的情况，运行该航线的每一架飞机与运行控制 中心之间应当保证有另一种语音通信系统可以进行替代。',
#  'file2_30_第 121.97 条_(c)': '通信设备 对于国际运行，合格证持有人应当保证每一架飞机与 相应的运行控制中心之间能够满足在正常运行条件下，在4 分钟内建立迅速可靠的语音通信联系。',
#  'file2_31_第 121.99 条_(a)': '气象服务 合格证持有人应当证明，每一条航路沿线，均有足够 的气象报告服务可以供使用，以保证提供运行所必需的气象 实况报告和气象预报。',
#  'file2_31_第 121.99 条_(b)': '气象服务 合格证持有人只能使用符合局方要求的气象服务系 统提供的气象资料。',
#  'file2_31_第 121.99 条_(c)': '气象服务 使用气象预报控制飞行活动的合格证持有人， 应当使 用依据本条(b)款规定的气象资料而编制的气象预报， 以及按 照本条(d)款规定采用的系统所批准的任何来源而编制的气 象预报。',
#  'file2_31_第 121.99 条_(d)': '气象服务 合格证持有人应当使用经局方批准的危险天气实况 报告与预报系统，以便获得可能影响所飞航路和所用机场飞 行安全的危险天气现象，如晴空颠簸、雷暴和低空风切变等 情况的实况报告和预报。',
#  'file2_32_第 121.101 条_(a)_(1)': '航路导航设施 除本条(b)款规定外， 合格证持有人应当证明， 对于每 一条计划中的航路，非目视地面导航设施符合下列要求： 具有足够的非目视地面导航设施， 能在空中交通管制 要求的精度之内，在整个航路上为飞机导航；',
#  'file2_32_第 121.101 条_(a)_(2)': '航路导航设施 除本条(b)款规定外， 合格证持有人应当证明， 对于每 一条计划中的航路，非目视地面导航设施符合下列要求： 非目视地面导航设施的位置， 能保证在该运行所必需 的精度范围之内，引导飞机至任一正常使用机场、临时使用 机场、加油机场或者备降机场。',
#  'file2_32_第 121.101 条_(b)_(1)': '航路导航设施 下列运行不需要非目视地面导航设施： 昼间目视飞行规则运行，但合格证持有人应当证明， 能够根据地形的特征，使用地标领航而安全运行；',
#  'file2_32_第 121.101 条_(b)_(2)': '航路导航设施 下列运行不需要非目视地面导航设施： 在经局方批准使用特殊导航方法导航的航段上实施 的运行。',
#  'file2_33_第 121.103 条_(a)': '运行控制中心 合格证持有人应当设立运行控制中心， 通过完备的运 行控制组织管理体系，确保对每次飞行进行恰当的运行控 制。',
#  'file2_33_第 121.103 条_(b)': '运行控制中心 运行控制中心可以设立若干分支机构实施运行控制， 但运行控制责任应当严格遵守本规则第121.531 条的要求。',
#  'file2_33_第 121.103 条_(c)': '运行控制中心 合格证持有人的运行控制体系应当在运行规范中得 到批准，并在运行手册中描述说明该体系的组织架构、授权 以及职责。',
#  'file2_34_第 121.105 条': '地面服务 每个实施国内、国际定期载客运行的合格证持有人应当 建立相应的地面服务管理组织机构，在相关的手册中明确对 所有地面服务的培训要求、外部委托政策、管理程序、工作 标准和规范等内容，并具备足够的合格人员和适当的设施和 设备(包括备件、地面保障和材料等)，确保飞机起飞前或者 着陆后的地面服务符合本规则的相应要求。当合格证持有人 通过外部委托方式由他人提供部分或者全部地面服务时，合 格证持有人应当向相应的地面服务人员提供必要的训练，并 对其操作的安全性负责。 F 章 补充运行的区域和航路批准',
#  'file2_35_第 121.113 条_(a)_(1)': '航路和区域要求概则 实施补充运行的合格证持有人应当按照下列规定申 请运行区域和航路的批准： 对于国内运行， 中国境内的空域按照一个运行区域批 准，但包含高高原机场(海拔高度在2,438 米或者8,000 英尺 及以上的机场)起降点的航路还需按照航路进行批准；',
#  'file2_35_第 121.113 条_(a)_(2)': '航路和区域要求概则 实施补充运行的合格证持有人应当按照下列规定申 请运行区域和航路的批准： 对于国际运行，所飞机场所在的每一国家(地区)按照 一个运行区域批准，但包含高高原机场或者局方确定的特殊 机场起降点的航路还需按照航路进行批准。',
#  'file2_35_第 121.113 条_(b)': '航路和区域要求概则 按照本条(a)款申请运行区域和航路批准的合格证持 有人，应当证明其具有足够的装备和能力，能够使用中国或 者外国公布航路上有关导航设施，在仪表飞行规则和夜间目 视飞行规则条件下实施安全运行。',
#  'file2_35_第 121.113 条_(c)': '航路和区域要求概则 如果实施补充运行的合格证持有人可以证明， 对于运 行的航路是安全的，并且局方能够确定空中交通密度有足够 的安全水平，局方可以批准合格证持有人管制空域外的航 路。合格证持有人不可以使用没有经局方批准的，或者运行 规范中没有列出的航路。',
#  'file2_36_第 121.115 条_(a)_(1)': '航路宽度 经批准的航路、航段及固定航线具有的宽度应当至少 与这些固定航线或者航路的规定宽度相等。在局方认为有必 要对经批准的航路另行确定宽度时，将考虑下列因素： 地形障碍的超越；',
#  'file2_36_第 121.115 条_(a)_(2)': '航路宽度 经批准的航路、航段及固定航线具有的宽度应当至少 与这些固定航线或者航路的规定宽度相等。在局方认为有必 要对经批准的航路另行确定宽度时，将考虑下列因素： 最低航路高度；',
#  'file2_36_第 121.115 条_(a)_(3)': '航路宽度 经批准的航路、航段及固定航线具有的宽度应当至少 与这些固定航线或者航路的规定宽度相等。在局方认为有必 要对经批准的航路另行确定宽度时，将考虑下列因素： 地面和机载导航设备；',
#  'file2_36_第 121.115 条_(a)_(4)': '航路宽度 经批准的航路、航段及固定航线具有的宽度应当至少 与这些固定航线或者航路的规定宽度相等。在局方认为有必 要对经批准的航路另行确定宽度时，将考虑下列因素： 空中交通密度；',
#  'file2_36_第 121.115 条_(a)_(5)': '航路宽度 经批准的航路、航段及固定航线具有的宽度应当至少 与这些固定航线或者航路的规定宽度相等。在局方认为有必 要对经批准的航路另行确定宽度时，将考虑下列因素： 空中交通管制程序。',
#  'file2_36_第 121.115 条_(b)': '航路宽度 合格证持有人运行规范中局方加以规定的任何其他 航路宽度。',
#  'file2_37_第 121.117 条_(a)': '必需的机场资料 实施补充运行的合格证持有人使用的任何机场应当 具有适当的装备并适合于所申请运行的设施。其中所考虑的 因素应当包括机场的等级、道面、障碍物、设施、公众保护、 灯光、导航、通信、气象设施以及空中交通管制等。',
#  'file2_37_第 121.117 条_(b)_(1)': '必需的机场资料 每一实施补充运行的合格证持有人应当证明其有一 个经批准的系统，能够获得、保存和分发给每个有关人员所 使用机场现行有效的航行资料，以确保飞机在该机场运行的 安全。这种航行资料应当包括下列方面的内容： 机场',
#  'file2_37_第 121.117 条_(i)': '必需的机场资料 跑道视程(RVR)测量设备； (ii)低能见度条件下的盛行风。',
#  'file2_37_第 121.117 条_(v)_(2)': '必需的机场资料 导航、通信、气象设施； (vi)影响起飞、着陆或者地面运行的建筑物； (vii)空中交通服务设施。 跑道、停止道和净空道',
#  'file2_37_第 121.117 条_(c)': '必需的机场资料 如果负责管理该合格证持有人的民航地区管理局发 现该合格证持有人经批准的关于收集、分发和使用航行资料 的系统应当予以改进才能恰当地继续工作，则合格证持有人 在接到该部门的通知后，应当立即对其系统进行改进。在合 格证持有人接到这样的通知之后30 天内，可以向中国民航 局飞行标准职能部门提出重新考虑的请求。重新考虑的请求 使该通知处于暂缓执行状态，直至中国民航局飞行标准职能 部门作出决定时止。但是，如果民航地区管理局认为存在关 系到航空运输安全、需要立即采取措施的紧急情况，则中国 民航局飞行标准职能部门可以根据所陈述的理由，使要求改 进的通知立即生效。',
#  'file2_38_第 121.119 条_(a)': '气象服务 合格证持有人应当证明，每一条航路沿线，均有足够 的气象报告服务可以供使用，以保证提供运行所必需的气象 实况报告和气象预报。',
#  'file2_38_第 121.119 条_(b)': '气象服务 合格证持有人只能使用符合局方要求的气象服务系 统提供的气象资料。',
#  'file2_38_第 121.119 条_(c)': '气象服务 使用气象预报控制飞行活动的合格证持有人， 应当使 用依据本条(b)款规定的气象资料而编制的气象预报。',
#  'file2_39_第 121.121 条_(a)_(1)': '航路导航设施 除本条(b)款规定外， 合格证持有人应当证明， 对于每 一条计划中的航路，非目视地面导航设施符合下列要求： 能在空中交通管制要求的精度之内， 在整个航路上为 飞机导航；',
#  'file2_39_第 121.121 条_(a)_(2)': '航路导航设施 除本条(b)款规定外， 合格证持有人应当证明， 对于每 一条计划中的航路，非目视地面导航设施符合下列要求： 非目视地面导航设施的位置， 能保证在该运行所必需 的精度范围之内，引导飞机至任一目的地机场或者备降机 场。',
#  'file2_39_第 121.121 条_(b)_(1)': '航路导航设施 下列运行不需要非目视地面导航设施： 昼间目视飞行规则运行，但合格证持有人应当证明， 能够根据地形的特征，使用地标领航而安全运行；',
#  'file2_39_第 121.121 条_(b)_(2)': '航路导航设施 下列运行不需要非目视地面导航设施： 在经局方批准使用特殊导航方法导航的航段上实施 的运行。',
#  'file2_40_第 121.123 条': '地面服务 每个实施补充运行的合格证持有人应当建立相应的地 面服务管理组织机构，在相关的手册中明确对所有地面服务 的培训要求、 外委政策、 管理程序和工作标准、 规范等内容， 并具备足够的合格人员和适当的设施和设备(包括备件、 地面 保障和材料等)， 确保飞机起飞前或者着陆后的地面服务符合 本规则的相应要求。当合格证持有人通过外委方式由他人提 供部分或者全部的地面服务时，合格证持有人应当向相应的 地面服务人员提供必要的训练，并对其操作的安全性负责。',
#  'file2_41_第 121.125 条_(a)_(1)': '飞行跟踪系统 实施补充运行的合格证持有人应当证明： 具有符合本规则U 章要求的飞行跟踪系统， 该系统根 据所实施的运行可以对每次飞行进行有效的跟踪；',
#  'file2_41_第 121.125 条_(a)_(2)': '飞行跟踪系统 实施补充运行的合格证持有人应当证明： 飞行跟踪中心应当设在适用于对下列情况实施飞行 跟踪的位置：',
#  'file2_41_第 121.125 条_(i)': '飞行跟踪系统 确保对每次飞行的始发机场和目的地机场的飞行进程 进行适当的监控，包括对中途停留机场和改航备降机场飞行 进程的监控，以及对在这些机场所需的维修或者机械延误进 行适当的监控； (ii)确保机长能够得到安全飞行必需的所有资料。',
#  'file2_41_第 121.125 条_(b)': '飞行跟踪系统 实施补充运行的合格证持有人可以使用非所属人员 提供的飞行跟踪设施，但在这种情况下，合格证持有人应当 对每次飞行的运行控制持续负责。',
#  'file2_41_第 121.125 条_(c)': '飞行跟踪系统 飞行跟踪系统不要求与空中飞行的机组建立通信联 系。',
#  'file2_41_第 121.125 条_(d)': '飞行跟踪系统 在合格证持有人的运行规范中应当明确批准使用的 飞行跟踪系统和飞行跟踪中心的所在位置。',
#  'file2_42_第 121.127 条_(a)_(1)': '飞行跟踪系统要求 实施补充运行的每个合格证持有人应当证明： 系统具备足够的设备和合格人员， 为下列人员提供每 一次飞行的起始和安全运行所必需的信息：',
#  'file2_42_第 121.127 条_(i)_(2)': '飞行跟踪系统要求 每架飞机的飞行机组； (ii)合格证持有人指定实施运行控制的人员。 飞行跟踪系统具有利用公共或者私人设施(例如电 话、电报或者无线电)获得通信的能力，以进行本规则第 121.125 条(a)款第(2)项第(i)目要求的监控。',
#  'file2_42_第 121.127 条_(b)': '飞行跟踪系统要求 实施补充运行的合格证持有人应当证明本条(a)款所 述人员能够履行他们的职责。 G 章 手册的要求',
#  'file2_43_第 121.131 条_(a)': '手册的制定和保存 合格证持有人应当具有为实施其各种运行的全体飞 行、维修和其他地面运行工作人员制定并供其使用和指导其 操作的手册， 并且有合适的手册管理系统， 负责制定、 分发、 修订和补充手册，使其保持现行有效。',
#  'file2_43_第 121.131 条_(b)_(1)': '手册的制定和保存 本条(a)款要求的手册应当符合下列要求： 包含必需的政策、流程、标准和程序等指令和信息， 使有关人员能安全地完成所担负的工作职责；',
#  'file2_43_第 121.131 条_(b)_(2)': '手册的制定和保存 本条(a)款要求的手册应当符合下列要求： 除局方批准外，使用中文写成。如果合格证持有人在 运行中使用了不熟悉中文的人员，则应当同时为其提供相应 文字的手册，并且应当保证这些手册的一致性和同等有效 性；',
#  'file2_43_第 121.131 条_(b)_(3)': '手册的制定和保存 本条(a)款要求的手册应当符合下列要求： 采用易于修订的形式；',
#  'file2_43_第 121.131 条_(b)_(4)': '手册的制定和保存 本条(a)款要求的手册应当符合下列要求： 在有关的每一页上，标注最后一次修订的日期。对于 电子化的手册，可以以恰当的形式标注最后一次修订的日 期，使人员可以迅速确定有效性；',
#  'file2_43_第 121.131 条_(b)_(5)': '手册的制定和保存 本条(a)款要求的手册应当符合下列要求： 符合所有适用的涉及民航管理的规章、 该合格证持有 人的运行合格证与运行规范；对于实施国际运行的合格证持 有人，还应当符合所适用的外国规章。',
#  'file2_43_第 121.131 条_(c)': '手册的制定和保存 合格证持有人在其主运行基地至少要保存一套完整 的手册。该手册可以是纸质版的手册，也可以是符合局方要 求的其他形式。',
#  'file2_44_第 121.133 条_(a)_(1)': '手册内容总体要求 手册应当包含下列所有内容，但可以分为两个或者两个 以上的单独分册，每一分册应当包括所有适用于该类人员的 内容： 概述： 与飞行运行有关人员工作内容和责任的说明，包括： 机组成员和飞行签派员在飞行起始、持续、改航和终止阶段 的职能；',
#  'file2_44_第 121.133 条_(a)_(2)': '手册内容总体要求 手册应当包含下列所有内容，但可以分为两个或者两个 以上的单独分册，每一分册应当包括所有适用于该类人员的 内容： 概述： 飞行签派和运行控制，包括：适用的签派协调、飞行 控制、 飞行跟踪程序、 在冲突地区及附近运行风险的管理等；',
#  'file2_44_第 121.133 条_(a)_(3)': '手册内容总体要求 手册应当包含下列所有内容，但可以分为两个或者两个 以上的单独分册，每一分册应当包括所有适用于该类人员的 内容： 概述： 航路飞行、导航和通信程序，包括：当任何所需的特 定设备不工作或者无法提供服务时，签派或者放行飞机继续 飞行；',
#  'file2_44_第 121.133 条_(a)_(4)': '手册内容总体要求 手册应当包含下列所有内容，但可以分为两个或者两个 以上的单独分册，每一分册应当包括所有适用于该类人员的 内容： 概述： 有关机组成员疲劳管理的信息和政策，包括：',
#  'file2_44_第 121.133 条_(i)': '手册内容总体要求 手册应当包含下列所有内容，但可以分为两个或者两个 以上的单独分册，每一分册应当包括所有适用于该类人员的 内容： 干、湿和受污染情况下的起飞跑道长度要求，包括影 响起飞距离的系统失效情况； (ii)起飞爬升限制； (iii)航路爬升限制； (iv)进近爬升限制和着陆爬升限制；',
#  'file2_44_第 121.133 条_(b)_(1)': '手册内容总体要求 手册应当包含下列所有内容，但可以分为两个或者两个 以上的单独分册，每一分册应当包括所有适用于该类人员的 内容： 飞机运行信息： 飞机型号审定限制和运行限制；',
#  'file2_44_第 121.133 条_(b)_(2)': '手册内容总体要求 手册应当包含下列所有内容，但可以分为两个或者两个 以上的单独分册，每一分册应当包括所有适用于该类人员的 内容： 飞机运行信息： 飞行机组使用的正常、 非正常和应急程序及有关检查 单；',
#  'file2_44_第 121.133 条_(b)_(3)': '手册内容总体要求 手册应当包含下列所有内容，但可以分为两个或者两个 以上的单独分册，每一分册应当包括所有适用于该类人员的 内容： 飞机运行信息： 所有发动机工作时爬升性能的操作指示和信息；',
#  'file2_44_第 121.133 条_(b)_(4)': '手册内容总体要求 手册应当包含下列所有内容，但可以分为两个或者两个 以上的单独分册，每一分册应当包括所有适用于该类人员的 内容： 飞机运行信息： 供飞行前和飞行中制定计划使用的飞行计划数据， 包 含不同的推力、功率和速度设定情况下的数据；',
#  'file2_44_第 121.133 条_(b)_(5)': '手册内容总体要求 手册应当包含下列所有内容，但可以分为两个或者两个 以上的单独分册，每一分册应当包括所有适用于该类人员的 内容： 飞机运行信息： 所用每个机型的最大侧风和顺风分量限制， 以及在考 虑了阵风、低能见、跑道道面状况、机组经历、自动驾驶使 用、非正常或者紧急情况或者其他有关运行因素影响时，对 这些限制数值进行的缩减；',
#  'file2_44_第 121.133 条_(b)_(6)': '手册内容总体要求 手册应当包含下列所有内容，但可以分为两个或者两个 以上的单独分册，每一分册应当包括所有适用于该类人员的 内容： 飞机运行信息： 重量与平衡计算方面的操作指示和数据；',
#  'file2_44_第 121.133 条_(b)_(7)': '手册内容总体要求 手册应当包含下列所有内容，但可以分为两个或者两个 以上的单独分册，每一分册应当包括所有适用于该类人员的 内容： 飞机运行信息： 飞机装载和载荷固定方面的操作指示；',
#  'file2_44_第 121.133 条_(b)_(8)': '手册内容总体要求 手册应当包含下列所有内容，但可以分为两个或者两个 以上的单独分册，每一分册应当包括所有适用于该类人员的 内容： 飞机运行信息： 可供每一型号飞机运行人员和飞行机组所使用的包 括与该型号飞机运行有关的正常、非正常和应急程序以及该 飞机各系统和所用检查单的详细信息在内的飞机操作手册， 手册的设计还需符合人的因素要求；',
#  'file2_44_第 121.133 条_(b)_(9)': '手册内容总体要求 手册应当包含下列所有内容，但可以分为两个或者两个 以上的单独分册，每一分册应当包括所有适用于该类人员的 内容： 飞机运行信息： 供所用机型和经批准的特殊运行使用的最低设备清 单和外形缺损清单，其中包含与基于性能导航区域内的运行 有关的任何规定；',
#  'file2_44_第 121.133 条_(b)_(10)': '手册内容总体要求 手册应当包含下列所有内容，但可以分为两个或者两个 以上的单独分册，每一分册应当包括所有适用于该类人员的 内容： 飞机运行信息： 应急和安全设备的检查单和使用说明；',
#  'file2_44_第 121.133 条_(b)_(11)': '手册内容总体要求 手册应当包含下列所有内容，但可以分为两个或者两个 以上的单独分册，每一分册应当包括所有适用于该类人员的 内容： 飞机运行信息： 应急撤离程序，包括与机型相关的程序、机组协调、 紧急情况下机组成员的指定位置和紧急情况下每个机组成 员的职责；',
#  'file2_44_第 121.133 条_(b)_(12)': '手册内容总体要求 手册应当包含下列所有内容，但可以分为两个或者两个 以上的单独分册，每一分册应当包括所有适用于该类人员的 内容： 飞机运行信息： 客舱乘务员所使用的正常、非正常和应急程序，以 及与此有关的检查单和必需的飞机系统信息，并且包括一个 用于解释这些程序是供飞行机组成员和客舱乘务员之间协 调使用的说明；',
#  'file2_44_第 121.133 条_(b)_(13)': '手册内容总体要求 手册应当包含下列所有内容，但可以分为两个或者两个 以上的单独分册，每一分册应当包括所有适用于该类人员的 内容： 飞机运行信息： 用于不同航路的救生和应急设备清单，以及在起飞 前验证其工作正常的必要程序，包括确定所需氧气量和可用 量的程序；',
#  'file2_44_第 121.133 条_(b)_(14)': '手册内容总体要求 手册应当包含下列所有内容，但可以分为两个或者两个 以上的单独分册，每一分册应当包括所有适用于该类人员的 内容： 飞机运行信息： 供幸存者使用的地空目视信号说明。',
#  'file2_44_第 121.133 条_(c)_(1)': '手册内容总体要求 手册应当包含下列所有内容，但可以分为两个或者两个 以上的单独分册，每一分册应当包括所有适用于该类人员的 内容： 航路和机场： 航路信息指导， 用于确保飞行机组每次飞行都能够获 得适用于该运行的通讯设施、助航设备、机场、仪表进近、 仪表进场和仪表离场方面的信息以及承运人认为正确实施 飞行运行所必需其他信息；',
#  'file2_44_第 121.133 条_(c)_(2)': '手册内容总体要求 手册应当包含下列所有内容，但可以分为两个或者两个 以上的单独分册，每一分册应当包括所有适用于该类人员的 内容： 航路和机场： 每一所飞航路的最低飞行高度；',
#  'file2_44_第 121.133 条_(c)_(3)': '手册内容总体要求 手册应当包含下列所有内容，但可以分为两个或者两个 以上的单独分册，每一分册应当包括所有适用于该类人员的 内容： 航路和机场： 可能用作目的地机场或者备降机场的每个机场的运 行最低标准；',
#  'file2_44_第 121.133 条_(c)_(4)': '手册内容总体要求 手册应当包含下列所有内容，但可以分为两个或者两个 以上的单独分册，每一分册应当包括所有适用于该类人员的 内容： 航路和机场： 确定使用平视显示器(HUD)或者等效显示器、增强视 景系统(EVS)、 增强飞行视景系统(EFVS)、 合成视景系统(SVS) 和/或组合视景系统(CVS)等设备的仪表进近机场运行最低标 准的说明；',
#  'file2_44_第 121.133 条_(c)_(5)': '手册内容总体要求 手册应当包含下列所有内容，但可以分为两个或者两个 以上的单独分册，每一分册应当包括所有适用于该类人员的 内容： 航路和机场： 在进近或者机场设施降级的情况下机场运行最低标 准的提高；',
#  'file2_44_第 121.133 条_(c)_(6)': '手册内容总体要求 手册应当包含下列所有内容，但可以分为两个或者两个 以上的单独分册，每一分册应当包括所有适用于该类人员的 内容： 航路和机场： 符合规章要求的所有飞行剖面的必需信息， 包括但不 仅限于下列确定内容：',
#  'file2_44_第 121.133 条_(v)': '手册内容总体要求 手册应当包含下列所有内容，但可以分为两个或者两个 以上的单独分册，每一分册应当包括所有适用于该类人员的 内容： 干、湿和受污染情况下的着陆跑道长度要求，包括影 响着陆距离的系统失效情况； (vi)补充信息，如轮胎速度限制。',
#  'file2_44_第 121.133 条_(d)': '手册内容总体要求 手册应当包含下列所有内容，但可以分为两个或者两个 以上的单独分册，每一分册应当包括所有适用于该类人员的 内容： 训练： 本规则N 章规定的，包含相应地面训练、飞行训练(如 适用)等详细内容的飞行机组成员、 客舱乘务员和飞行签派员 的训练大纲，以保证参加训练的人员在上岗前对于所担负的 工作接受了充分的训练。',
#  'file2_45_第 121.135 条_(a)_(1)': '手册的分发和可用性 合格证持有人应当向下列人员提供本规则第121.131 条所要求的手册及其修改和补充，或者该手册的有关部分： 维修人员和有关地面运行工作人员；',
#  'file2_45_第 121.135 条_(a)_(2)': '手册的分发和可用性 合格证持有人应当向下列人员提供本规则第121.131 条所要求的手册及其修改和补充，或者该手册的有关部分： 机组成员；',
#  'file2_45_第 121.135 条_(a)_(3)': '手册的分发和可用性 合格证持有人应当向下列人员提供本规则第121.131 条所要求的手册及其修改和补充，或者该手册的有关部分： 负责管理该合格证持有人的局方人员。',
#  'file2_45_第 121.135 条_(b)': '手册的分发和可用性 按照本条(a)款持有手册或者手册相关部分的每个人， 应当使用合格证持有人提供的修改和补充页，使手册内容保 持最新有效状态，并在执行指定任务时可以随时查阅。',
#  'file2_46_第 121.137 条_(a)': '飞机飞行手册 合格证持有人应当为其使用的每一型号飞机保持现 行有效的飞机飞行手册。',
#  'file2_46_第 121.137 条_(b)': '飞机飞行手册 合格证持有人的每架飞机都应当携带用机组人员所 熟悉的语言编写，且满足本条(a)款所要求的飞机飞行手册。 合格证持有人也可以携带按本规则第121.131 条要求编写的 手册， 但该手册应当包含适用本条(a)款飞机飞行手册规定的 信息。',
#  'file2_46_第 121.137 条_(c)': '飞机飞行手册 合格证持有人选择按照本规则第121.131 条编写手册 时，可以对适用本条(a)款飞机飞行手册的操作程序部分进行 修改和对性能数据的编排形式进行调整，但经修改的操作程 序和性能数据编排形式应当被局方批准。',
#  'file2_46_第 121.137 条_(d)': '飞机飞行手册 合格证持有人应当制定并执行适用的管理程序， 以保 证满足本条(a)、(b)款的手册现行有效。 H 章 飞机的要求',
#  'file2_47_第 121.151 条_(a)_(1)': '飞机的基本要求 除本条(c)款规定外， 合格证持有人运行的飞机应当符 合下列要求： 是在中华人民共和国登记的民用飞机， 并携带现行有 效的适航证、国籍登记证、无线电电台执照和噪声合格审定 的证明文件。噪声合格审定证明文件可以载于本规则第 121.137 条要求的飞机飞行手册中。在国际运行时，该证明 文件必须包括一份英文译文；',
#  'file2_47_第 121.151 条_(a)_(2)': '飞机的基本要求 除本条(c)款规定外， 合格证持有人运行的飞机应当符 合下列要求： 处于适航状态并符合涉及民航管理的规章适用的适 航要求，包括与标识和设备有关的要求。',
#  'file2_47_第 121.151 条_(b)': '飞机的基本要求 合格证持有人可以使用经批准的重量与平衡控制系 统来符合适用的适航要求和运行限制，该重量与平衡控制系 统可以以平均的、假定的或者估算的重量为基础。',
#  'file2_47_第 121.151 条_(c)_(1)': '飞机的基本要求 合格证持有人可以租用不含机组人员的国际民用航 空公约缔约国所属的某一国家登记的民用飞机实施本规则 运行，但应当符合下列规定： 该飞机带有经中国民航局审查认可的原国籍登记国 颁发的适航证和由中国民航局颁发的适航认可证书，以及无 线电电台执照和噪声合格审定的证明文件；',
#  'file2_47_第 121.151 条_(c)_(2)': '飞机的基本要求 合格证持有人可以租用不含机组人员的国际民用航 空公约缔约国所属的某一国家登记的民用飞机实施本规则 运行，但应当符合下列规定： 合格证持有人已将该飞机的租赁合同副本报局方。',
#  'file2_48_第 121.153 条': '飞机的审定和设备要求 合格证持有人按照本规则运行的飞机应当是型号合格 审定为运输类的飞机，并符合本规则第121.173 条的要求， 否则不得实施本规则运行。',
#  'file2_49_第 121.155 条': '禁止使用单台发动机飞机 合格证持有人不得使用单台发动机的飞机实施本规则 运行。',
#  'file2_50_第 121.157 条_(a)_(1)': '飞机的航路类型限制 除经依据本规则W 章的规定得到局方批准且满足合 格证持有人运行规范许可的条件下，合格证持有人不得使用 以涡轮发动机为动力的飞机实施以下运行： 延程运行(EDTO)；',
#  'file2_50_第 121.157 条_(a)_(2)': '飞机的航路类型限制 除经依据本规则W 章的规定得到局方批准且满足合 格证持有人运行规范许可的条件下，合格证持有人不得使用 以涡轮发动机为动力的飞机实施以下运行： 在北极区域内的运行；',
#  'file2_50_第 121.157 条_(a)_(3)': '飞机的航路类型限制 除经依据本规则W 章的规定得到局方批准且满足合 格证持有人运行规范许可的条件下，合格证持有人不得使用 以涡轮发动机为动力的飞机实施以下运行： 在南极区域内的运行。',
#  'file2_50_第 121.157 条_(b)': '飞机的航路类型限制 合格证持有人用于延伸跨水运行的陆上飞机， 应当是 按照《运输类飞机适航标准》(CCAR-25)中的水上迫降规定 审定合格或者被批准为适合于水上迫降的飞机。',
#  'file2_51_第 121.159 条_(a)': '飞机的运行验证试飞 合格证持有人使用以前未在公共航空运输运行中使 用过的飞机，应当完成局方认可的至少100 小时的运行验证 试飞，包括相当数量的进入航路机场的飞行。在运行验证试 飞过程中，如果局方认为试飞已达到令人满意的熟练水平， 则局方可以减少验证试飞时间。上述运行验证试飞至少应当 有10 小时在夜间完成。',
#  'file2_51_第 121.159 条_(b)': '飞机的运行验证试飞 除经局方特殊批准外， 合格证持有人首次使用曾在公 共航空运输运行中使用过的某一型号飞机，或者使用在设计 上做了实质性更改的某一型号飞机，则在拟使用该飞机实施 运行之前，应当完成经局方认可的至少25 小时的运行验证 试飞，包括相当数量的进入航路机场的飞行。',
#  'file2_51_第 121.159 条_(c)_(1)': '飞机的运行验证试飞 本条(b)款所述飞机在设计上进行了实质性更改是指 下列情形之一： 整套动力装置的型号与飞机合格审定时所装动力装 置的型号不相类似；',
#  'file2_51_第 121.159 条_(c)_(2)': '飞机的运行验证试飞 本条(b)款所述飞机在设计上进行了实质性更改是指 下列情形之一： 对飞机或者其部件进行了实质上影响其飞行特性的 更改。',
#  'file2_51_第 121.159 条_(d)': '飞机的运行验证试飞 除了实施试飞所需的人员和局方指定的人员之外， 合 格证持有人不得在运行验证试飞的飞机上携带旅客。经局方 批准，运行验证试飞的飞机可以携带邮件、快递或者其他货 物。',
#  'file2_52_第 121.161 条_(a)': '应急撤离程序的演示 合格证持有人应当依照本规则附件C《本规则第 121.161 条规定的应急撤离程序演示准则》(a)款规定进行应 急撤离程序的实际演示，证明在载客飞行中所用的旅客座位 数大于44 座的每个型号的飞机，能够使包括机组成员在内 的满载量乘员在90 秒(含)以内撤离飞机。但是，如果该型号 飞机已被证明符合本规则附件C(a)款规定或者适用的型号合 格审定标准，可以不实施实际的演示。',
#  'file2_52_第 121.161 条_(b)_(1)': '应急撤离程序的演示 使用旅客座位数大于44 座的飞机实施载客运行的合 格证持有人，有下列情形之一的，应当按照本条(c)款进行应 急撤离程序的部分演示： 该合格证持有人新引进的某型号飞机投入载客飞行 并且该合格证持有人没有按照本条(a)款实施实际演示；',
#  'file2_52_第 121.161 条_(b)_(2)': '应急撤离程序的演示 使用旅客座位数大于44 座的飞机实施载客运行的合 格证持有人，有下列情形之一的，应当按照本条(c)款进行应 急撤离程序的部分演示： 本规则第121.391 条所要求的客舱乘务员的人数、位 置或者其应急撤离职责、程序发生改变；',
#  'file2_52_第 121.161 条_(b)_(3)': '应急撤离程序的演示 使用旅客座位数大于44 座的飞机实施载客运行的合 格证持有人，有下列情形之一的，应当按照本条(c)款进行应 急撤离程序的部分演示： 应急出口的数量、位置、型号或者供撤离用的应急出 口开启机构的型号发生改变。',
#  'file2_52_第 121.161 条_(c)_(1)': '应急撤离程序的演示 在实施本条(b)款要求的部分演示时， 合格证持有人应 当遵守下列规定： 实施不要求旅客参加但要在局方观察下进行的演示， 以验证其机组成员应急生存训练和应急撤离程序的有效性。 在这种演示中，该型号飞机的客舱乘务员，应当使用该合格 证持有人的航线操作程序，按照本规则第121.397 条规定的 应急撤离职责，打开50％所要求的地板高度的应急出口和 50％所要求的非地板高度的应急出口， 并放下50％的应急出 口滑梯。这些应急出口和滑梯由局方选定，并且应当在15 秒钟内准备就绪以供使用；',
#  'file2_52_第 121.161 条_(c)_(2)': '应急撤离程序的演示 在实施本条(b)款要求的部分演示时， 合格证持有人应 当遵守下列规定： 在实施这种演示之前， 向负责监督其运行的民航地区 管理局提出申请；',
#  'file2_52_第 121.161 条_(c)_(3)': '应急撤离程序的演示 在实施本条(b)款要求的部分演示时， 合格证持有人应 当遵守下列规定： 在这种演示中使用的客舱乘务员， 由局方从已经完成 合格证持有人经局方批准的该型号飞机训练大纲的训练并 已通过应急设备和应急程序考试的客舱乘务员中随机挑选；',
#  'file2_52_第 121.161 条_(c)_(4)': '应急撤离程序的演示 在实施本条(b)款要求的部分演示时， 合格证持有人应 当遵守下列规定： 在开始实施该型号飞机的运行之前， 向负责监督其运 行的民航地区管理局提出申请并获得批准。',
#  'file2_52_第 121.161 条_(d)': '应急撤离程序的演示 每个使用或者计划使用一架或者多架陆上飞机作延 伸跨水运行或者按照要求配备相应应急设备的合格证持有 人，应当按照本规则附件C(b)款进行模拟水上迫降，证明其 能有效地完成水上迫降程序。',
#  'file2_52_第 121.161 条_(e)': '应急撤离程序的演示 对于已经由其他合格证持有人进行过本条(d)款规定 的模拟水上迫降的那种型号飞机，如果每个救生筏都从其存 放处取下，其中一个救生筏被投放并充气或者一个滑梯救生 筏被充气，并且指定负责该充气救生筏或者滑梯救生筏的机 组成员表演并说明了每项必需应急设备的使用，则认为已经 符合本规则附件C(b)款第(2)项、(b)款第(4)项和(b)款第(5)项 的要求。前述待充气的救生筏或者滑梯救生筏由局方选定。 I 章 飞机性能使用限制',
#  'file2_53_第 121.171 条_(a)': '用语定义 本章中的用语按照下述定义： 可用着陆距离(LDA)：是指公布的可用并适于飞机着 陆的跑道长度。',
#  'file2_53_第 121.171 条_(b)': '用语定义 本章中的用语按照下述定义： 飞行轨迹(flight path)：是指飞机在三维空间中的飞行 路线。',
#  'file2_53_第 121.171 条_(c)': '用语定义 本章中的用语按照下述定义： 航迹(track)：是指飞机飞行轨迹在地球表面上的水平 投影。',
#  'file2_54_第 121.173 条_(a)': '概则 使用涡轮发动机驱动的飞机的合格证持有人应当遵 守本规则第121.189 条至第121.197 条的规定。',
#  'file2_54_第 121.173 条_(b)': '概则 合格证持有人应当使用飞机飞行手册中的性能数据 来确定是否符合本规则第121.189 条至第121.197 条的规定。 当涉及的条件与这些性能数据所依据的条件不同时，如果内 插法或者计算法所得结果在实质上与直接试验的结果同样 准确，则可以用内插法或者通过计算具体变量变化的影响来 确定是否符合规定。合格证持有人在确定是否符合本规则第 121.189条至第121.197条的规定时还应当考虑到所用航图的 精度。',
#  'file2_54_第 121.173 条_(c)': '概则 如果在特殊的环境条件下遵守某些规定对于安全已 无必要，局方可以在运行规范中批准偏离本章的这些要求。',
#  'file2_55_第 121.189 条_(a)': '涡轮发动机驱动的飞机的起飞限制 涡轮发动机驱动的飞机不得以大于该飞机飞行手册 中对应于该机场气压高度和起飞时环境温度所确定的重量 起飞。',
#  'file2_55_第 121.189 条_(b)_(1)': '涡轮发动机驱动的飞机的起飞限制 涡轮发动机驱动的运输类飞机不得以大于该飞机飞 行手册中规定的重量起飞，该重量应当保证飞机符合下列各 项要求： 加速停止距离不得超过跑道长度加上停止道的长度；',
#  'file2_55_第 121.189 条_(b)_(2)': '涡轮发动机驱动的飞机的起飞限制 涡轮发动机驱动的运输类飞机不得以大于该飞机飞 行手册中规定的重量起飞，该重量应当保证飞机符合下列各 项要求： 起飞距离不得超过跑道长度加上净空道长度， 且净空 道长度不得大于跑道长度的一半；',
#  'file2_55_第 121.189 条_(b)_(3)': '涡轮发动机驱动的飞机的起飞限制 涡轮发动机驱动的运输类飞机不得以大于该飞机飞 行手册中规定的重量起飞，该重量应当保证飞机符合下列各 项要求： 起飞滑跑距离不得大于跑道长度。',
#  'file2_55_第 121.189 条_(c)_(1)': '涡轮发动机驱动的飞机的起飞限制 涡轮发动机驱动的飞机不得以大于该飞机飞行手册 中所确定的某个重量起飞，在该重量下，预定净起飞飞行轨 迹以10.7 米(35 英尺)的余度超越所有障碍物， 或者能以一个 特定距离侧向避开障碍物。该特定距离的值为下列两目中规 定值的较小值： 90 米(300 英尺)＋0.125D，其中D 是指飞机离可用起 飞距离末端的距离值；',
#  'file2_55_第 121.189 条_(c)_(2)': '涡轮发动机驱动的飞机的起飞限制 涡轮发动机驱动的飞机不得以大于该飞机飞行手册 中所确定的某个重量起飞，在该重量下，预定净起飞飞行轨 迹以10.7 米(35 英尺)的余度超越所有障碍物， 或者能以一个 特定距离侧向避开障碍物。该特定距离的值为下列两目中规 定值的较小值： 对于目视飞行规则飞行， 预定航迹的航向变化小于15 度时，为300 米，预定航迹的航向变化大于15 度时，为600 米；对于仪表飞行规则飞行，预定航迹的航向变化小于15 度时，为600 米，预定航迹的航向变化大于15 度时，为900 米。',
#  'file2_55_第 121.189 条_(d)': '涡轮发动机驱动的飞机的起飞限制 在依据本条(a)款至(c)款确定最大重量、 最小距离和飞 行轨迹时，应当对拟用的跑道、机场的标高、有效跑道坡度 和起飞时的环境温度、风的分量进行修正。',
#  'file2_55_第 121.189 条_(e)': '涡轮发动机驱动的飞机的起飞限制 就本条而言， 假定飞机在到达15.2 米(50 英尺)高度(按 照飞机飞行手册中起飞飞行轨迹或者净起飞飞行轨迹数据 中的适用者)之前无坡度。此后，在120 米(400 英尺)高度以 下，飞机转弯坡度不超过15 度；在120 米(400 英尺)高度以 上，飞机转弯坡度不超过25 度。',
#  'file2_55_第 121.189 条_(f)': '涡轮发动机驱动的飞机的起飞限制 就本条而言， “起飞距离”“起飞滑跑距离”“净起飞飞行 轨迹”和“起飞飞行轨迹”等术语， 与对该飞机进行型号合格审 定的规章中所规定的术语具有相同的含义。',
#  'file2_56_第 121.191 条_(a)_(1)': '涡轮发动机驱动的飞机的航路限制—— 一台发动机不工作 涡轮发动机驱动的飞机不得超过某一重量起飞，在该 重量下，考虑到正常的燃油、滑油消耗和航路上预计的环境 温度，根据经批准的该飞机飞行手册确定的一台发动机不工 作时的航路净飞行轨迹数据应当能够符合下列两项要求之 一： 在预定航迹两侧各25 公里(13.5 海里)范围内的所有 地形和障碍物上空至少300 米(1,000 英尺)的高度上有正梯 度，并且，在发动机失效后飞机要着陆的机场上空450 米 (1,500 英尺)的高度上有正梯度；',
#  'file2_56_第 121.191 条_(a)_(2)': '涡轮发动机驱动的飞机的航路限制—— 一台发动机不工作 涡轮发动机驱动的飞机不得超过某一重量起飞，在该 重量下，考虑到正常的燃油、滑油消耗和航路上预计的环境 温度，根据经批准的该飞机飞行手册确定的一台发动机不工 作时的航路净飞行轨迹数据应当能够符合下列两项要求之 一： 净飞行轨迹允许飞机由巡航高度继续飞到可以按照 本规则第121.197 条要求进行着陆的机场，能以至少600 米 (2,000 英尺)的余度垂直超越预定航迹两侧各25 公里(13.5 海 里)范围内所有地形和障碍物， 并且在发动机失效后飞机要着 陆的机场上空450 米(1,500 英尺)的高度上有正梯度。',
#  'file2_56_第 121.191 条_(b)_(1)': '涡轮发动机驱动的飞机的航路限制—— 一台发动机不工作 就本条(a)款第(2)项而言，假定： 发动机在航路上最临界的一点失效；',
#  'file2_56_第 121.191 条_(b)_(2)': '涡轮发动机驱动的飞机的航路限制—— 一台发动机不工作 就本条(a)款第(2)项而言，假定： 飞机在发动机失效点之后飞越临界障碍物， 该点应当 能够使用有效的方式定位；',
#  'file2_56_第 121.191 条_(b)_(3)': '涡轮发动机驱动的飞机的航路限制—— 一台发动机不工作 就本条(a)款第(2)项而言，假定： 使用经批准的方法考虑了不利的风的影响；',
#  'file2_56_第 121.191 条_(b)_(4)': '涡轮发动机驱动的飞机的航路限制—— 一台发动机不工作 就本条(a)款第(2)项而言，假定： 如果合格证持有人证明，机组人员进行了恰当的训 练，并且采取了其他安全措施，能保证程序的安全性，则允 许应急放油；',
#  'file2_56_第 121.191 条_(b)_(5)': '涡轮发动机驱动的飞机的航路限制—— 一台发动机不工作 就本条(a)款第(2)项而言，假定： 在签派或者放行单中指定了备降机场， 且该备降机场 符合规定的最低气象条件；',
#  'file2_56_第 121.191 条_(b)_(6)': '涡轮发动机驱动的飞机的航路限制—— 一台发动机不工作 就本条(a)款第(2)项而言，假定： 发动机失效后燃油和滑油的消耗与飞机飞行手册中 经批准的净飞行轨迹数据所给定的消耗相同。',
#  'file2_57_第 121.193 条_(a)': '三台或者三台以上涡轮发动机驱动的飞 机的航路限制——两台发动机不工作 三台或者三台以上涡轮发动机驱动的飞机沿预定航路 运行时，应当符合下列两款要求之一： 预定航迹上任何一点到符合本规则第121.197 条要求 的机场的飞行时间不超过所有发动机以巡航功率工作飞行 90 分钟。',
#  'file2_57_第 121.193 条_(b)_(1)': '三台或者三台以上涡轮发动机驱动的飞 机的航路限制——两台发动机不工作 三台或者三台以上涡轮发动机驱动的飞机沿预定航路 运行时，应当符合下列两款要求之一： 根据飞机飞行手册中航路上两台发动机不工作的净 飞行轨迹数据，其重量允许该飞机从假定两台发动机同时失 效的地点，飞到符合本规则第121.197 条要求的某一机场。 在这段飞行中，考虑到沿该航路的预计环境温度，其净飞行 轨迹在垂直方向上至少高出预定航迹两侧各25 公里(13.5 海 里)范围内所有地形和障碍物600 米(2,000 英尺)。就本款而 言，假定： 两台发动机在航路上最临界的地点失效；',
#  'file2_57_第 121.193 条_(b)_(2)': '三台或者三台以上涡轮发动机驱动的飞 机的航路限制——两台发动机不工作 三台或者三台以上涡轮发动机驱动的飞机沿预定航路 运行时，应当符合下列两款要求之一： 根据飞机飞行手册中航路上两台发动机不工作的净 飞行轨迹数据，其重量允许该飞机从假定两台发动机同时失 效的地点，飞到符合本规则第121.197 条要求的某一机场。 在这段飞行中，考虑到沿该航路的预计环境温度，其净飞行 轨迹在垂直方向上至少高出预定航迹两侧各25 公里(13.5 海 里)范围内所有地形和障碍物600 米(2,000 英尺)。就本款而 言，假定： 这些发动机失效后在预定着陆的机场正上空450 米 (1,500 英尺)处，该净飞行轨迹具有正梯度；',
#  'file2_57_第 121.193 条_(b)_(3)': '三台或者三台以上涡轮发动机驱动的飞 机的航路限制——两台发动机不工作 三台或者三台以上涡轮发动机驱动的飞机沿预定航路 运行时，应当符合下列两款要求之一： 根据飞机飞行手册中航路上两台发动机不工作的净 飞行轨迹数据，其重量允许该飞机从假定两台发动机同时失 效的地点，飞到符合本规则第121.197 条要求的某一机场。 在这段飞行中，考虑到沿该航路的预计环境温度，其净飞行 轨迹在垂直方向上至少高出预定航迹两侧各25 公里(13.5 海 里)范围内所有地形和障碍物600 米(2,000 英尺)。就本款而 言，假定： 如果合格证持有人证明，机组人员进行了恰当的训 练，并且采取了其他预防措施，能保证程序的安全性，则可 以批准应急放油；',
#  'file2_57_第 121.193 条_(b)_(4)': '三台或者三台以上涡轮发动机驱动的飞 机的航路限制——两台发动机不工作 三台或者三台以上涡轮发动机驱动的飞机沿预定航路 运行时，应当符合下列两款要求之一： 根据飞机飞行手册中航路上两台发动机不工作的净 飞行轨迹数据，其重量允许该飞机从假定两台发动机同时失 效的地点，飞到符合本规则第121.197 条要求的某一机场。 在这段飞行中，考虑到沿该航路的预计环境温度，其净飞行 轨迹在垂直方向上至少高出预定航迹两侧各25 公里(13.5 海 里)范围内所有地形和障碍物600 米(2,000 英尺)。就本款而 言，假定： 在两台发动机失效的那一点， 该飞机重量包含有足够 的燃油，使其能继续飞到该机场正上空至少450 米(1,500 英 尺)的高度，此后还能以巡航功率或者推力飞行15 分钟；',
#  'file2_57_第 121.193 条_(b)_(5)': '三台或者三台以上涡轮发动机驱动的飞 机的航路限制——两台发动机不工作 三台或者三台以上涡轮发动机驱动的飞机沿预定航路 运行时，应当符合下列两款要求之一： 根据飞机飞行手册中航路上两台发动机不工作的净 飞行轨迹数据，其重量允许该飞机从假定两台发动机同时失 效的地点，飞到符合本规则第121.197 条要求的某一机场。 在这段飞行中，考虑到沿该航路的预计环境温度，其净飞行 轨迹在垂直方向上至少高出预定航迹两侧各25 公里(13.5 海 里)范围内所有地形和障碍物600 米(2,000 英尺)。就本款而 言，假定： 发动机失效后， 燃油和滑油的消耗与飞机飞行手册中 净飞行轨迹数据所给定的消耗相同。',
#  'file2_58_第 121.195 条_(a)': '涡轮发动机驱动的飞机的着陆限制—— 目的地机场 涡轮发动机驱动的飞机起飞前， 应当在考虑到至目的 地机场或者备降机场飞行中正常的燃油和滑油消耗后，使飞 机到达时的重量不得超过该飞机飞行手册中对该目的地机 场或者备降机场的气压高度以及着陆时预计的环境温度所 确定的着陆重量。',
#  'file2_58_第 121.195 条_(b)_(1)': '涡轮发动机驱动的飞机的着陆限制—— 目的地机场 除本条(c)、(d)、(e)款规定外，涡轮发动机驱动的飞 机起飞前，应当在考虑到飞行中正常的燃油和滑油消耗后， 使该飞机到达目的地时的重量，根据飞机飞行手册中对该目 的地机场的气压高度和预计在着陆时当地风的情况所规定 的着陆距离，允许其在预定的目的地机场的跑道上，在可用 着陆距离(LDA)的60％以内作全停着陆。为确定在目的地机 场的允许着陆重量，假定： 飞机在最有利的跑道和方向、静风条件下着陆；',
#  'file2_58_第 121.195 条_(b)_(2)': '涡轮发动机驱动的飞机的着陆限制—— 目的地机场 除本条(c)、(d)、(e)款规定外，涡轮发动机驱动的飞 机起飞前，应当在考虑到飞行中正常的燃油和滑油消耗后， 使该飞机到达目的地时的重量，根据飞机飞行手册中对该目 的地机场的气压高度和预计在着陆时当地风的情况所规定 的着陆距离，允许其在预定的目的地机场的跑道上，在可用 着陆距离(LDA)的60％以内作全停着陆。为确定在目的地机 场的允许着陆重量，假定： 考虑到可能的风速、风向和该飞机的地面操纵特性， 以及考虑到诸如着陆助航设备和地形等其他条件，飞机在最 适宜的跑道上着陆。',
#  'file2_58_第 121.195 条_(c)': '涡轮发动机驱动的飞机的着陆限制—— 目的地机场 对于不能符合本条(b)款第(2)项的要求而被禁止起飞 的涡轮螺旋桨驱动的飞机，如果指定了备降机场，除允许飞 机在备降机场可用着陆距离(LDA)的70％以内完成全停着陆 外，该备降机场符合本条所有其他要求，则可以允许该飞机 起飞。',
#  'file2_58_第 121.195 条_(d)': '涡轮发动机驱动的飞机的着陆限制—— 目的地机场 对于涡轮喷气飞机， 在有关的气象报告和预报表明目 的地机场跑道在预计着陆时刻可能是湿的时，该目的地机场 跑道的可用着陆距离(LDA)应当至少为本条(b)款所要求的跑 道长度的115％，否则，该飞机不得起飞。如果在湿跑道上 的实际着陆技术证明，对特定型号的飞机，已经批准了某一 较短但绝不小于本条(b)款要求的着陆距离， 并且已经载入飞 机飞行手册，则可以按照手册的要求执行。',
#  'file2_58_第 121.195 条_(e)': '涡轮发动机驱动的飞机的着陆限制—— 目的地机场 对于涡轮喷气飞机， 在有关的气象报告和预报表明目 的地机场跑道在预计着陆时刻可能是污染的时，该目的地机 场的可用跑道长度应当至少为以下距离中的较大者： 本条(b) 款所要求的跑道长度的115%，以及根据认可的污染跑道实 际着陆距离数据确定的着陆距离的115%，否则，该飞机不 得起飞。如果上述污染跑道的道面已经进行了特殊处理，而 且实际着陆技术证明，对特定型号的飞机，已经批准了某一 较短但不小于本条(b)款要求的着陆距离， 并且已经载入飞机 飞行手册，则可以按照手册的要求执行。',
#  'file2_58_第 121.195 条_(f)': '涡轮发动机驱动的飞机的着陆限制—— 目的地机场 由于不能符合本条(b)款第(2)项而被禁止起飞的涡轮 喷气动力的飞机， 如果指定了符合本条(b)款所有要求的备降 机场，则可以起飞。',
# ...
#  'file2_146_第 121.457 条_(a)_(3)': '新机型和新职位上的运行经历要求 在飞机上担任机组必需成员的人员，应当在该型别飞 机和在该机组成员位置上，圆满完成本条要求的巩固知识与 技术所需的飞行经验、飞行次数和航线飞行经历时间，取得 规定的运行经历。但下列情况除外： 对于同一型别中的各个改型， 不要求在该改型上建立 新的运行经历。',
#  'file2_146_第 121.457 条_(b)_(1)': '新机型和新职位上的运行经历要求 在获得运行经历时，机组成员应当符合下列规定： 持有适合于该飞行机组成员职位和该飞机的执照与 等级；',
#  'file2_146_第 121.457 条_(b)_(2)': '新机型和新职位上的运行经历要求 在获得运行经历时，机组成员应当符合下列规定： 已经圆满完成有关该型别飞机和该飞行机组成员职 位的相应地面与飞行训练；',
#  'file2_146_第 121.457 条_(b)_(3)': '新机型和新职位上的运行经历要求 在获得运行经历时，机组成员应当符合下列规定： 客舱乘务员已经圆满完成有关该机型和客舱乘务员 职位的相应地面训练；',
#  'file2_146_第 121.457 条_(b)_(4)': '新机型和新职位上的运行经历要求 在获得运行经历时，机组成员应当符合下列规定： 这些经历应当在按照本规则实施的运行中获得。但 是，当某一飞机先前未曾由合格证持有人在按照本规则实施 的运行中使用过时，在该飞机验证飞行或者调机飞行中所获 得的经历可以用于满足本条的运行经历要求。',
#  'file2_146_第 121.457 条_(c)_(1)': '新机型和新职位上的运行经历要求 驾驶员应当按照下列要求获得运行经历： 待取得机长运行经历的驾驶员， 应当在飞行检查员或 者飞行教员的监视下履行机长职责。对于完成初始或者升级 训练、待取得机长运行经历的驾驶员，应当在局方监察员或 者局方委任代表的监视下完成规定的职责至少一个航段飞 行(包括起飞和着陆)。在按照本条规定取得运行经历的过程 中，飞行检查员或者飞行教员应当担任机长并坐在驾驶员座 位上；',
#  'file2_146_第 121.457 条_(c)_(2)': '新机型和新职位上的运行经历要求 驾驶员应当按照下列要求获得运行经历： 副驾驶应当在飞行检查员或者飞行教员监督下完成 其职责；',
#  'file2_146_第 121.457 条_(c)_(3)': '新机型和新职位上的运行经历要求 驾驶员应当按照下列要求获得运行经历： 运行经历所要求的飞行经历时间和飞行次数应当符 合下列规定：',
#  'file2_146_第 121.457 条_(i)': '新机型和新职位上的运行经历要求 组类Ⅰ飞机，飞行经历时间至少20 小时； (ii)组类Ⅱ飞机，飞行经历时间至少25 小时； (iii)本项要求的运行经历中，应当包括至少4 次飞行， 其中包括至少3 次作为该飞机的操作驾驶员的飞行。其中的 1 次操作应当在高度3,000 米(10,000 英尺)以下用人工飞行的 方式操作飞机。',
#  'file2_146_第 121.457 条_(d)_(1)': '新机型和新职位上的运行经历要求 飞行机械员应当在飞行机械检查员或者教员的监督 下履行飞行机械员职责至少达到下列小时数： 组类Ⅰ飞机，10 小时；',
#  'file2_146_第 121.457 条_(d)_(2)': '新机型和新职位上的运行经历要求 飞行机械员应当在飞行机械检查员或者教员的监督 下履行飞行机械员职责至少达到下列小时数： 组类Ⅱ飞机，12 小时。',
#  'file2_146_第 121.457 条_(e)_(1)': '新机型和新职位上的运行经历要求 客舱乘务员应当在航线飞行中按照下列要求获得运 行经历： 在客舱乘务教员指导下履行规定的职责；',
#  'file2_146_第 121.457 条_(e)_(2)': '新机型和新职位上的运行经历要求 客舱乘务员应当在航线飞行中按照下列要求获得运 行经历： 在客舱乘务检查员的监督下履行规定的职责至少达 到5 小时；',
#  'file2_146_第 121.457 条_(e)_(3)': '新机型和新职位上的运行经历要求 客舱乘务员应当在航线飞行中按照下列要求获得运 行经历： 正在获得运行经历的客舱乘务员不得担任机组必需 成员。',
#  'file2_146_第 121.457 条_(f)_(1)': '新机型和新职位上的运行经历要求 对于新机型、 新职位的驾驶员， 为巩固其知识与技术， 合格证持有人应当采取下列措施，保证其飞行连续性： 在完成新机型或者新职位上的训练之后的120 天之 内，应当安排航线飞行至少100 小时；',
#  'file2_146_第 121.457 条_(f)_(2)': '新机型和新职位上的运行经历要求 对于新机型、 新职位的驾驶员， 为巩固其知识与技术， 合格证持有人应当采取下列措施，保证其飞行连续性： 如果驾驶员在完成必需的100小时航线飞行经历时间 前，到该合格证持有人运行的另一型别飞机上担任驾驶员， 则该驾驶员在重新回到新机型上担任驾驶员时，应当首先在 飞行模拟机或者飞机上完成经批准的复习训练；',
#  'file2_146_第 121.457 条_(f)_(3)': '新机型和新职位上的运行经历要求 对于新机型、 新职位的驾驶员， 为巩固其知识与技术， 合格证持有人应当采取下列措施，保证其飞行连续性： 对于在120 天之内没有完成必需的100 小时航线飞行 经历时间的驾驶员，应当在飞行模拟机或者飞机上完成熟练 检查并重新建立120 天之内100 小时的航线飞行经历。',
#  'file2_147_第 121.459 条_(a)_(1)': '驾驶员的使用限制和搭配要求 如果副驾驶在所飞机型上的飞行经历时间少于100 小 时，并且机长不具备飞行检查员或者飞行教员资格，则在下 列情况下，应当由机长完成所有起飞和着陆： 在局方规定或者合格证持有人规定的特殊机场；',
#  'file2_147_第 121.459 条_(a)_(2)': '驾驶员的使用限制和搭配要求 如果副驾驶在所飞机型上的飞行经历时间少于100 小 时，并且机长不具备飞行检查员或者飞行教员资格，则在下 列情况下，应当由机长完成所有起飞和着陆： 机场的最新气象报告中有效能见度值等于或者小于 1,200 米(3/4 英里)，或者跑道视程(RVR)等于或者小于1,200 米(4,000 英尺)；',
#  'file2_147_第 121.459 条_(a)_(3)': '驾驶员的使用限制和搭配要求 如果副驾驶在所飞机型上的飞行经历时间少于100 小 时，并且机长不具备飞行检查员或者飞行教员资格，则在下 列情况下，应当由机长完成所有起飞和着陆： 所用跑道有水、雪、雪浆或者严重影响飞机性能的情 况；',
#  'file2_147_第 121.459 条_(a)_(4)': '驾驶员的使用限制和搭配要求 如果副驾驶在所飞机型上的飞行经历时间少于100 小 时，并且机长不具备飞行检查员或者飞行教员资格，则在下 列情况下，应当由机长完成所有起飞和着陆： 所用跑道的刹车效应据报告低于“好”的水平；',
#  'file2_147_第 121.459 条_(a)_(5)': '驾驶员的使用限制和搭配要求 如果副驾驶在所飞机型上的飞行经历时间少于100 小 时，并且机长不具备飞行检查员或者飞行教员资格，则在下 列情况下，应当由机长完成所有起飞和着陆： 所用跑道的侧风分量超过7 米/秒(15 海里/小时)；',
#  'file2_147_第 121.459 条_(a)_(6)': '驾驶员的使用限制和搭配要求 如果副驾驶在所飞机型上的飞行经历时间少于100 小 时，并且机长不具备飞行检查员或者飞行教员资格，则在下 列情况下，应当由机长完成所有起飞和着陆： 在机场附近据报告有风切变；',
#  'file2_147_第 121.459 条_(a)_(7)': '驾驶员的使用限制和搭配要求 如果副驾驶在所飞机型上的飞行经历时间少于100 小 时，并且机长不具备飞行检查员或者飞行教员资格，则在下 列情况下，应当由机长完成所有起飞和着陆： 机长认为需谨慎行使机长权力的任何其他情况。',
#  'file2_147_第 121.459 条_(b)_(1)': '驾驶员的使用限制和搭配要求 在安排飞行机组搭配时， 应当至少有一名驾驶员在该 型别飞机上具有100 小时的航线飞行经历时间。但在下列情 况下，局方可以根据合格证持有人的申请，使用对其运行规 范作适当增补的方法，批准偏离本款的要求： 新审定合格的合格证持有人没有雇佣任何符合本款 最低要求的驾驶员；',
#  'file2_147_第 121.459 条_(b)_(2)': '驾驶员的使用限制和搭配要求 在安排飞行机组搭配时， 应当至少有一名驾驶员在该 型别飞机上具有100 小时的航线飞行经历时间。但在下列情 况下，局方可以根据合格证持有人的申请，使用对其运行规 范作适当增补的方法，批准偏离本款的要求： 现有合格证持有人在其机群中增加了以前未在其运 行中使用过的某型飞机；',
#  'file2_147_第 121.459 条_(b)_(3)': '驾驶员的使用限制和搭配要求 在安排飞行机组搭配时， 应当至少有一名驾驶员在该 型别飞机上具有100 小时的航线飞行经历时间。但在下列情 况下，局方可以根据合格证持有人的申请，使用对其运行规 范作适当增补的方法，批准偏离本款的要求： 现有合格证持有人建立了新的基地， 指派到该基地的 驾驶员需要在该基地运行的飞机上取得资格。',
#  'file2_147_第 121.459 条_(c)_(1)': '驾驶员的使用限制和搭配要求 合格证持有人应当建立一套飞行机组排班系统，保证 科学合理地搭配飞行机组成员，安全地完成所分派的任务。 搭配飞行机组成员时应当考虑下列因素： 飞行机组成员的经历、资格满足所飞区域、航路、机 场和特殊运行的要求；',
#  'file2_147_第 121.459 条_(c)_(2)': '驾驶员的使用限制和搭配要求 合格证持有人应当建立一套飞行机组排班系统，保证 科学合理地搭配飞行机组成员，安全地完成所分派的任务。 搭配飞行机组成员时应当考虑下列因素： 飞行机组成员对所飞机型得到充分训练，使用设备、 操纵飞机的整体能力满足运行要求；',
#  'file2_147_第 121.459 条_(c)_(3)': '驾驶员的使用限制和搭配要求 合格证持有人应当建立一套飞行机组排班系统，保证 科学合理地搭配飞行机组成员，安全地完成所分派的任务。 搭配飞行机组成员时应当考虑下列因素： 飞行机组成员的年龄和性格特征；',
#  'file2_147_第 121.459 条_(c)_(4)': '驾驶员的使用限制和搭配要求 合格证持有人应当建立一套飞行机组排班系统，保证 科学合理地搭配飞行机组成员，安全地完成所分派的任务。 搭配飞行机组成员时应当考虑下列因素： 所执行的飞行任务的其他特点。',
#  'file2_148_第 121.461 条_(a)': '驾驶员的近期经历要求 合格证持有人不得使用任何驾驶员，任何驾驶员也不 应在按照本规则运行中担任飞行机组必需成员，除非该驾驶 员于前90 个日历日之内，在所服务的该型别飞机上，至少 已做过三次起飞和着陆。本款要求的起飞和着陆可以在经批 准的飞行模拟机上完成，在任一连续的90 个日历日内未能 完成要求的三次起飞和着陆的人员， 应当按照本条(b)款的规 定重新建立近期经历。',
#  'file2_148_第 121.461 条_(b)_(1)': '驾驶员的近期经历要求 除了满足本规则所有适用的训练和检查要求之外， 未 满足本条(a)款要求的驾驶员应当按照下列要求重新建立近 期经历： 在飞行检查员监视下，在所飞的该型别飞机上，或者 在经批准的飞行模拟机上，至少完成三次起飞和着陆；',
#  'file2_148_第 121.461 条_(b)_(2)': '驾驶员的近期经历要求 除了满足本规则所有适用的训练和检查要求之外， 未 满足本条(a)款要求的驾驶员应当按照下列要求重新建立近 期经历： 前述三次起飞和着陆应当包括至少一次模拟最临界 发动机失效时的起飞、至少一次使用仪表着陆系统进近到该 合格证持有人经批准的仪表着陆系统最低天气标准的着陆 以及至少一次全停着陆。',
#  'file2_148_第 121.461 条_(c)': '驾驶员的近期经历要求 当使用飞行模拟机完成本条(a)款或者(b)款的任何要 求时，飞行机组必需成员的位置应当由具有恰当资格的人员 占据，并且飞行模拟机应当严格模拟正常飞行环境，不得使 用飞行模拟机重新设定位置的特性。',
#  'file2_148_第 121.461 条_(d)': '驾驶员的近期经历要求 飞行检查员应当对被监视的人员作出鉴定， 判断其是 否熟练和是否合格于在本规则规定的运行中执行飞行任务， 并且可以决定增加他认为作出这种鉴定所需要增加的动作。',
#  'file2_149_第 121.463 条_(a)': '航线检查 机长应当在前12 个日历月内，在其所飞的一个型别 飞机上通过航线检查，在检查中圆满完成机长职责。',
#  'file2_149_第 121.463 条_(b)': '航线检查 航线检查应当由在该航路和该型别飞机两方面都合 格的飞行检查员实施，并且至少有一次检查飞行是在合格证 持有人的典型航路上进行的。',
#  'file2_150_第 121.465 条_(a)': '熟练检查 担任飞行机组必需成员的驾驶员应当在前6 个日历月 之内在所服务的机型(别)上完成熟练检查，否则不得担任飞 行机组必需成员。',
#  'file2_150_第 121.465 条_(b)': '熟练检查 熟练检查可以在定期复训中进行。 熟练检查每隔一次 可以用本规则第121.409 条(b)款中规定的飞行模拟机训练课 程代替。 按照 《民用航空器驾驶员合格审定规则》 (CCAR-61) 完成的型别等级飞行考试可以代替熟练检查。',
#  'file2_150_第 121.465 条_(c)_(1)': '熟练检查 熟练检查应当满足下列要求： 至少包括本规则附件E 所规定的程序和动作， 除非该 附件中另有特殊规定；',
#  'file2_150_第 121.465 条_(c)_(2)': '熟练检查 熟练检查应当满足下列要求： 由局方监察员、 局方委任代表或者合格证持有人的飞 行检查员进行。',
#  'file2_150_第 121.465 条_(d)_(1)': '熟练检查 对于本规则附件E 中规定可以放弃的动作与程序， 实 施熟练检查的人员可以根据自己的判断放弃检查，但应当满 足下列要求： 局方没有发布应当完成该动作或者程序的特别指令；',
#  'file2_150_第 121.465 条_(d)_(2)': '熟练检查 对于本规则附件E 中规定可以放弃的动作与程序， 实 施熟练检查的人员可以根据自己的判断放弃检查，但应当满 足下列要求： 被检查的驾驶员， 在合格证持有人的该型别飞机和飞 行机组成员职位上，具有一年以上的安全运行经历。',
#  'file2_150_第 121.465 条_(e)': '熟练检查 如果被检查的驾驶员在任一要求的动作上失败，实施 熟练检查的人员可以在熟练检查过程中，给该驾驶员增加训 练。除了重复完成曾失败的动作之外，可以要求被检查的驾 驶员，重复他认为对判断驾驶员熟练程度所必需的任何其他 动作。如果被检查的驾驶员未通过熟练检查，合格证持有人 不得在本规则运行中使用该人员，该人员也不得在本规则运 行中任职，直至其令人满意地完成熟练检查为止。',
#  'file2_151_第 121.467 条_(a)_(1)': '机长的区域、航路和机场合格要求 合格证持有人应当向机长提供所飞区域和所飞各机 场与终端区的下列各方面的最新信息，保证这些信息的完整 和正确，并且确保该机长对这些信息有足够的了解和有能力 使用： 该季节相应的气象特征；',
#  'file2_151_第 121.467 条_(a)_(2)': '机长的区域、航路和机场合格要求 合格证持有人应当向机长提供所飞区域和所飞各机 场与终端区的下列各方面的最新信息，保证这些信息的完整 和正确，并且确保该机长对这些信息有足够的了解和有能力 使用： 导航设施，包括机场目视助航设备；',
#  'file2_151_第 121.467 条_(a)_(3)': '机长的区域、航路和机场合格要求 合格证持有人应当向机长提供所飞区域和所飞各机 场与终端区的下列各方面的最新信息，保证这些信息的完整 和正确，并且确保该机长对这些信息有足够的了解和有能力 使用： 通信程序；',
#  'file2_151_第 121.467 条_(a)_(4)': '机长的区域、航路和机场合格要求 合格证持有人应当向机长提供所飞区域和所飞各机 场与终端区的下列各方面的最新信息，保证这些信息的完整 和正确，并且确保该机长对这些信息有足够的了解和有能力 使用： 地形和障碍物类型；',
#  'file2_151_第 121.467 条_(a)_(5)': '机长的区域、航路和机场合格要求 合格证持有人应当向机长提供所飞区域和所飞各机 场与终端区的下列各方面的最新信息，保证这些信息的完整 和正确，并且确保该机长对这些信息有足够的了解和有能力 使用： 最低安全飞行高度；',
#  'file2_151_第 121.467 条_(a)_(6)': '机长的区域、航路和机场合格要求 合格证持有人应当向机长提供所飞区域和所飞各机 场与终端区的下列各方面的最新信息，保证这些信息的完整 和正确，并且确保该机长对这些信息有足够的了解和有能力 使用： 航路和终端区进场与离场程序、 等待程序和有关机场 经批准的仪表进近程序；',
#  'file2_151_第 121.467 条_(a)_(7)': '机长的区域、航路和机场合格要求 合格证持有人应当向机长提供所飞区域和所飞各机 场与终端区的下列各方面的最新信息，保证这些信息的完整 和正确，并且确保该机长对这些信息有足够的了解和有能力 使用： 驾驶员将要使用的终端区的每个机场的活动拥挤区 和自然布局；',
#  'file2_151_第 121.467 条_(a)_(8)': '机长的区域、航路和机场合格要求 合格证持有人应当向机长提供所飞区域和所飞各机 场与终端区的下列各方面的最新信息，保证这些信息的完整 和正确，并且确保该机长对这些信息有足够的了解和有能力 使用： 航行通告。',
#  'file2_151_第 121.467 条_(b)': '机长的区域、航路和机场合格要求 合格证持有人应当提供一个能被局方接受的系统， 以 便将本条(a)款所要求的信息传递给机长和相应的飞行运作 人员。 该系统还应当保证合格证持有人满足本规则第121.469 条规定的要求。',
#  'file2_152_第 121.469 条_(a)': '机长的特殊区域、航路和机场合格要求 局方可以根据周围地形、障碍物、复杂的进近程序或 者离场程序等因素，将某些机场确定为特殊机场，要求机长 具有特殊的机场资格，并可以对某些区域或者航路提出特殊 类型的导航资格要求。',
#  'file2_152_第 121.469 条_(b)': '机长的特殊区域、航路和机场合格要求 合格证持有人应当保证， 在飞往或者飞离特殊机场的 运行中担任机长的驾驶员，应当在前12 个日历月之内曾作 为飞行机组成员飞过该机场(包括起飞和着陆)，或者曾使用 经局方认可的该机场图形演示设备或者飞行模拟机进行训 练并获得资格。但是，如果机场的云底高度，至少高于最低 航路高度(MEA)、最低超障高度(MOCA)或者该机场仪表进 近程序规定的起始进近高度最低者之上300 米(1,000 英尺)， 而且该机场的能见度(VIS)至少为4,800 米(3 英里)， 则进入该 机场(包括起飞或者着陆)时，可以不对机长作特殊机场资格 要求。',
#  'file2_152_第 121.469 条_(c)_(1)': '机长的特殊区域、航路和机场合格要求 在需要特殊类型导航资格的航路或者区域上两个航 站之间担任机长的驾驶员，应当在前12 个日历月之内，以 局方认可的方式，用下列方法之一证明其合格于使用该导航 系统： 使用该特殊类型导航系统， 担任机长在某一航路或者 区域上飞行；',
#  'file2_152_第 121.469 条_(c)_(2)': '机长的特殊区域、航路和机场合格要求 在需要特殊类型导航资格的航路或者区域上两个航 站之间担任机长的驾驶员，应当在前12 个日历月之内，以 局方认可的方式，用下列方法之一证明其合格于使用该导航 系统： 使用该特殊类型导航系统，在航空检查人员的监视 下，担任机长在某一航路或者区域上飞行；',
#  'file2_152_第 121.469 条_(c)_(3)': '机长的特殊区域、航路和机场合格要求 在需要特殊类型导航资格的航路或者区域上两个航 站之间担任机长的驾驶员，应当在前12 个日历月之内，以 局方认可的方式，用下列方法之一证明其合格于使用该导航 系统： 完成本规则附件I《多普勒雷达和惯性导航系统》规 定的训练。',
#  'file2_153_第 121.471 条_(a)': '飞行机械员的合格要求 在飞机上担任飞行机械员的人员，应当持有飞行机械 员执照和相应的等级，并完成《民用航空器飞行机械员合格 审定规则》(CCAR-63FS)为保持该执照和等级有效性所要求 的训练和检查以及本规则要求的训练和检查。',
#  'file2_153_第 121.471 条_(b)': '飞行机械员的合格要求 在飞机上担任飞行机械员的人员， 应当在前6 个日历 月之内，在该型别飞机上至少担任飞行机械员飞行了50 小 时，或者，合格证持有人或者局方在该型别飞机上对其进行 了检查，并认为其熟悉且掌握了所有现行重要信息和操作程 序。',
#  'file2_153_第 121.471 条_(c)': '飞行机械员的合格要求 按照本规则第121.435 条(a)款第(2)项实施的飞行检 查，满足本条(b)款的要求。',
#  'file2_154_第 121.475 条_(a)': '客舱乘务员的搭配要求 合格证持有人在按照本规则运行时，应当指定1 名客 舱乘务员为乘务长，作为客舱机组的负责人，履行客舱管理 的职责并向机长报告。乘务长的资格应当符合局方相关要 求。',
#  'file2_154_第 121.475 条_(b)_(1)': '客舱乘务员的搭配要求 合格证持有人应当建立一套客舱乘务员排班程序， 保 证科学合理地搭配客舱机组成员，安全地完成所分派的任 务。搭配客舱机组成员时应当考虑下列因素： 客舱乘务员的年龄和飞行时间经历；',
#  'file2_154_第 121.475 条_(b)_(2)': '客舱乘务员的搭配要求 合格证持有人应当建立一套客舱乘务员排班程序， 保 证科学合理地搭配客舱机组成员，安全地完成所分派的任 务。搭配客舱机组成员时应当考虑下列因素： 客舱乘务员的训练、资格满足所飞机型、区域和特殊 运行的要求。',
#  'file2_155_第 121.477 条_(a)': '客舱乘务员的合格要求 在飞机上担任客舱乘务员的人员，应当通过局方按照 本规则批准的训练大纲训练并经合格证持有人检查合格。在 按照本规则运行时，应当持有现行有效的航空人员体检合格 证和合格证持有人颁发的客舱乘务员训练合格证。',
#  'file2_155_第 121.477 条_(b)': '客舱乘务员的合格要求 客舱乘务员应当于前12 个日历月之内，在按照本规 则第121.538 条要求所批准的可服务的一种机型上，至少已 飞行2 个航段，方可以在此机型上担任客舱乘务员。',
#  'file2_156_第 121.479 条_(a)': '飞行机组成员的英语要求 合格证持有人应当对飞行机组成员进行专业英语训练， 使其能够在飞行中使用英语进行陆空通话，阅读各种英文飞 行手册、资料，使用英文填写各种飞行文件和使用英语进行 交流。 自2008 年3 月5 日起，除经局方批准外，未通过局 方组织或认可的英语语言能力4 级或者4 级以上等级评定而 其执照上低于英语语言能力4 级等级签注的，不得在使用英 语通话的航线上担任驾驶员。',
#  'file2_156_第 121.479 条_(b)': '飞行机组成员的英语要求 合格证持有人应当对飞行机组成员进行专业英语训练， 使其能够在飞行中使用英语进行陆空通话，阅读各种英文飞 行手册、资料，使用英文填写各种飞行文件和使用英语进行 交流。 1960 年1 月1 日(含)以后出生的驾驶员，英语语言能 力未达到3 级的， 不得参加组类II 飞机的初始或者升级训练。 P 章 机组成员值勤期限制、飞行时间限制和休息要求',
#  'file2_157_第 121.481 条_(a)': '概则 除本条(b)款规定外， 合格证持有人在实施本规则运行 中，应当建立用于机组成员疲劳管理和定期疗养的制度及程 序，保证其机组成员符合本章适用的值勤期限制、飞行时间 限制和休息要求。任何违反本章规定的人员不得在本规则运 行中担任机组必需成员。',
#  'file2_157_第 121.481 条_(b)_(1)': '概则 合格证持有人可以通过建立经局方批准的疲劳风险 管理系统，申请替代本章部分条款的限制和要求。合格证持 有人的疲劳风险管理系统应当在运行规范中得到批准，并能 保证不低于本章要求的安全水平。合格证持有人的疲劳风险 管理系统应当至少包括下列内容： 疲劳风险管理政策；',
#  'file2_157_第 121.481 条_(b)_(2)': '概则 合格证持有人可以通过建立经局方批准的疲劳风险 管理系统，申请替代本章部分条款的限制和要求。合格证持 有人的疲劳风险管理系统应当在运行规范中得到批准，并能 保证不低于本章要求的安全水平。合格证持有人的疲劳风险 管理系统应当至少包括下列内容： 疲劳管理及疲劳相关知识的训练；',
#  'file2_157_第 121.481 条_(b)_(3)': '概则 合格证持有人可以通过建立经局方批准的疲劳风险 管理系统，申请替代本章部分条款的限制和要求。合格证持 有人的疲劳风险管理系统应当在运行规范中得到批准，并能 保证不低于本章要求的安全水平。合格证持有人的疲劳风险 管理系统应当至少包括下列内容： 疲劳报告系统；',
#  'file2_157_第 121.481 条_(b)_(4)': '概则 合格证持有人可以通过建立经局方批准的疲劳风险 管理系统，申请替代本章部分条款的限制和要求。合格证持 有人的疲劳风险管理系统应当在运行规范中得到批准，并能 保证不低于本章要求的安全水平。合格证持有人的疲劳风险 管理系统应当至少包括下列内容： 飞行机组疲劳监控系统；',
#  'file2_157_第 121.481 条_(b)_(5)': '概则 合格证持有人可以通过建立经局方批准的疲劳风险 管理系统，申请替代本章部分条款的限制和要求。合格证持 有人的疲劳风险管理系统应当在运行规范中得到批准，并能 保证不低于本章要求的安全水平。合格证持有人的疲劳风险 管理系统应当至少包括下列内容： 疲劳相关不安全事件报告程序；',
#  'file2_157_第 121.481 条_(b)_(6)': '概则 合格证持有人可以通过建立经局方批准的疲劳风险 管理系统，申请替代本章部分条款的限制和要求。合格证持 有人的疲劳风险管理系统应当在运行规范中得到批准，并能 保证不低于本章要求的安全水平。合格证持有人的疲劳风险 管理系统应当至少包括下列内容： 系统有效性评估。',
#  'file2_157_第 121.481 条_(c)_(1)': '概则 本章中的用语定义如下： 扩编飞行机组， 是指飞行机组成员数量超过飞机机型 所要求的操纵飞机的最小值，从而可以由其他合格的飞行机 组成员替换某一飞行机组成员，被替换的飞行机组成员可以 在飞行中休息；扩编飞行机组中应当至少包含一名具备机长 资格和一名具备巡航机长或者以上资格的人员；',
#  'file2_157_第 121.481 条_(c)_(2)': '概则 本章中的用语定义如下： 机上休息设施， 是指安装在飞机内可以为机组成员提 供休息机会的铺位或者座位,其中分为：',
#  'file2_157_第 121.481 条_(i)_(3)': '概则 1 级休息设施，是指休息用的铺位或者可以平躺的其 他平面，独立于驾驶舱和客舱，机组成员可以控制温度和光 线，不受打扰和噪音的影响； (ii)2 级休息设施，是指飞机客舱内的座位，至少可以利 用隔帘与乘客分隔， 避免被乘客打扰， 可以平躺或接近平躺， 能够遮挡光线、降低噪音； (iii)3 级休息设施，是指飞机客舱内或者驾驶舱内的座 位，应可倾斜40 度，并可为脚部提供支撑，或者符合局方 要求的其他方式。 置位， 是指机组成员根据合格证持有人的要求为完成 指派的飞行任务，作为乘员乘坐飞机或者地面交通工具，但 不包括其往返当地适宜的住宿场所的交通。置位属于值勤， 置位时间不能作为休息时间。当置位计入飞行值勤期时，在 确定本章表B 中最长飞行值勤时间时，置位不视作航段；',
#  'file2_157_第 121.481 条_(i)_(4)': '概则 1 级休息设施，是指休息用的铺位或者可以平躺的其 他平面，独立于驾驶舱和客舱，机组成员可以控制温度和光 线，不受打扰和噪音的影响； (ii)2 级休息设施，是指飞机客舱内的座位，至少可以利 用隔帘与乘客分隔， 避免被乘客打扰， 可以平躺或接近平躺， 能够遮挡光线、降低噪音； (iii)3 级休息设施，是指飞机客舱内或者驾驶舱内的座 位，应可倾斜40 度，并可为脚部提供支撑，或者符合局方 要求的其他方式。 适宜的住宿场所，是指可以控制温度、降低噪音、条 件良好的场所，该场所能够控制光线亮度，使机组成员可以 在床位或者椅子上以平躺或者接近平躺姿势睡觉或者休息。 适宜的住宿住所只适用于地面设施，不适用于机上休息设 施；',
#  'file2_157_第 121.481 条_(i)_(5)': '概则 1 级休息设施，是指休息用的铺位或者可以平躺的其 他平面，独立于驾驶舱和客舱，机组成员可以控制温度和光 线，不受打扰和噪音的影响； (ii)2 级休息设施，是指飞机客舱内的座位，至少可以利 用隔帘与乘客分隔， 避免被乘客打扰， 可以平躺或接近平躺， 能够遮挡光线、降低噪音； (iii)3 级休息设施，是指飞机客舱内或者驾驶舱内的座 位，应可倾斜40 度，并可为脚部提供支撑，或者符合局方 要求的其他方式。 值勤， 是指机组成员按照合格证持有人的要求执行的 所有任务，包括但不限于飞行值勤、置位、备份(包括主备份 和其他备份)和培训等；',
#  'file2_157_第 121.481 条_(i)_(6)': '概则 1 级休息设施，是指休息用的铺位或者可以平躺的其 他平面，独立于驾驶舱和客舱，机组成员可以控制温度和光 线，不受打扰和噪音的影响； (ii)2 级休息设施，是指飞机客舱内的座位，至少可以利 用隔帘与乘客分隔， 避免被乘客打扰， 可以平躺或接近平躺， 能够遮挡光线、降低噪音； (iii)3 级休息设施，是指飞机客舱内或者驾驶舱内的座 位，应可倾斜40 度，并可为脚部提供支撑，或者符合局方 要求的其他方式。 飞行值勤期， 是指机组成员接受合格证持有人安排的 飞行任务后(包括飞行、调机或者转场等)，从为完成该次任 务而到指定地点报到时刻的开始，到飞机在最后一次飞行后 发动机关车且机组成员没有再次移动飞机的意向为止的时 间段。一个飞行值勤期还可能包括机组成员在某一航段前或 者航段之间代表合格证持有人执行的其他任务，但没有必要 休息期的情况(如置位、 主备份、 飞机或者模拟机培训发生在 某一航段前或者航段之间， 但没有安排必要的休息期)。 在一 个值勤期内，如机组成员能在适宜的住宿场所得到休息，则 该休息时间可以不计入该飞行值勤期的值勤时间；',
#  'file2_157_第 121.481 条_(i)_(7)': '概则 1 级休息设施，是指休息用的铺位或者可以平躺的其 他平面，独立于驾驶舱和客舱，机组成员可以控制温度和光 线，不受打扰和噪音的影响； (ii)2 级休息设施，是指飞机客舱内的座位，至少可以利 用隔帘与乘客分隔， 避免被乘客打扰， 可以平躺或接近平躺， 能够遮挡光线、降低噪音； (iii)3 级休息设施，是指飞机客舱内或者驾驶舱内的座 位，应可倾斜40 度，并可为脚部提供支撑，或者符合局方 要求的其他方式。 日历日， 是指按照世界协调时间或者当地时间划分的 时间段，从当日00：00 至23：59 的24 小时；',
#  'file2_157_第 121.481 条_(i)_(8)': '概则 1 级休息设施，是指休息用的铺位或者可以平躺的其 他平面，独立于驾驶舱和客舱，机组成员可以控制温度和光 线，不受打扰和噪音的影响； (ii)2 级休息设施，是指飞机客舱内的座位，至少可以利 用隔帘与乘客分隔， 避免被乘客打扰， 可以平躺或接近平躺， 能够遮挡光线、降低噪音； (iii)3 级休息设施，是指飞机客舱内或者驾驶舱内的座 位，应可倾斜40 度，并可为脚部提供支撑，或者符合局方 要求的其他方式。 主备份，是指机组成员根据合格证持有人的要求，在 机场或者合格证持有人指定的特定地点随时等待可能的任 务；',
#  'file2_157_第 121.481 条_(i)_(9)': '概则 1 级休息设施，是指休息用的铺位或者可以平躺的其 他平面，独立于驾驶舱和客舱，机组成员可以控制温度和光 线，不受打扰和噪音的影响； (ii)2 级休息设施，是指飞机客舱内的座位，至少可以利 用隔帘与乘客分隔， 避免被乘客打扰， 可以平躺或接近平躺， 能够遮挡光线、降低噪音； (iii)3 级休息设施，是指飞机客舱内或者驾驶舱内的座 位，应可倾斜40 度，并可为脚部提供支撑，或者符合局方 要求的其他方式。 休息期，是指从机组成员到达适宜的住宿场所起，到 为执行下一次任务离开适宜的住宿场所为止的连续时间段。 在该段时间内，合格证持有人不得为机组成员安排任何工作 和给予任何打扰。值勤和为完成指派的飞行任务使用交通工 具往来于适宜的住宿场所和值勤地点的时间不得计入休息 期；',
#  'file2_157_第 121.481 条_(i)_(10)': '概则 1 级休息设施，是指休息用的铺位或者可以平躺的其 他平面，独立于驾驶舱和客舱，机组成员可以控制温度和光 线，不受打扰和噪音的影响； (ii)2 级休息设施，是指飞机客舱内的座位，至少可以利 用隔帘与乘客分隔， 避免被乘客打扰， 可以平躺或接近平躺， 能够遮挡光线、降低噪音； (iii)3 级休息设施，是指飞机客舱内或者驾驶舱内的座 位，应可倾斜40 度，并可为脚部提供支撑，或者符合局方 要求的其他方式。 疲劳风险管理系统(FRMS)，是一种以科学原理和运 行经验为基础，通过数据驱动，对疲劳风险进行持续监测和 控制，保证相关人员在履行职责时保持充分警觉性的管理系 统。',
#  'file2_157_第 121.481 条_(d)': '概则 本章中时间均为北京时间， 部分地区存在较长时差的 另行规定。',
#  'file2_158_第 121.483 条_(a)_(1)': '飞行机组的飞行时间限制 在一个值勤期内，合格证持有人不得为飞行机组成员 安排、飞行机组成员也不得接受超出下列规定限制的飞行时 间： 非扩编飞行机组执行任务时， 表A 规定的飞行时间限 制； 表A--非扩编飞行机组运行最大飞行时间限制 报到时间 最大飞行时间(小时) 00:00-04:59 8 05:00-19:59 9 20:00-23:59 8',
#  'file2_158_第 121.483 条_(a)_(2)': '飞行机组的飞行时间限制 在一个值勤期内，合格证持有人不得为飞行机组成员 安排、飞行机组成员也不得接受超出下列规定限制的飞行时 间： 配备3 名驾驶员的扩编飞行机组执行任务时， 总飞行 时间13 小时；',
#  'file2_158_第 121.483 条_(a)_(3)': '飞行机组的飞行时间限制 在一个值勤期内，合格证持有人不得为飞行机组成员 安排、飞行机组成员也不得接受超出下列规定限制的飞行时 间： 配备4 名驾驶员的扩编飞行机组执行任务时， 总飞行 时间17 小时。',
#  'file2_158_第 121.483 条_(b)': '飞行机组的飞行时间限制 如果在飞机起飞后发生超出合格证持有人控制的意 外情况，为将飞机安全降落在下一个目的地机场或者备降机 场，飞行机组成员的飞行时间可以超出本条(a)款所规定的最 大飞行时间限制以及本规则第121.487 条(b)款规定的累积飞 行时间限制。',
#  'file2_158_第 121.483 条_(c)_(1)': '飞行机组的飞行时间限制 合格证持有人必须在10 天内将任何超过本条所允许 的最大飞行时间限制的情况报告局方，报告应当包括下列内 容： 对于延长飞行时间限制及本次延长情况必要的说明；',
#  'file2_158_第 121.483 条_(c)_(2)': '飞行机组的飞行时间限制 合格证持有人必须在10 天内将任何超过本条所允许 的最大飞行时间限制的情况报告局方，报告应当包括下列内 容： 合格证持有人为将此类延长控制在最小范围内而采 取的修正措施，如适用。',
#  'file2_158_第 121.483 条_(d)': '飞行机组的飞行时间限制 合格证持有人应当在延长飞行时间限制事发当天起 30 天内实施本条(c)款第(2)项所规定的修正措施。',
#  ...}

# %%
# 保存每个片段到字典文件 
import pickle

def save_dict_to_file(dict, file_path):
    with open(file_path, 'wb') as pickle_file:
        pickle.dump(dict, pickle_file)

# %%
save_dict_to_file(paragraph_dict1, '【高阶】《运行手册》HO-0907 飞行运行.pkl')
save_dict_to_file(paragraph_dict2, '大型飞机公共航空运输承运人运行合格审定规则.pkl')

# %%
save_dict_to_file(paragraph_dict2_lv2, '大型飞机公共航空运输承运人运行合格审定规则 lv2.pkl')
save_dict_to_file(paragraph_dict2_lv3, '大型飞机公共航空运输承运人运行合格审定规则 lv3.pkl')

# %%
# 测试读取定级部分的字典文件
import pickle
def read_dict_file(file_path):
    with open(file_path, 'rb') as f:
            data = pickle.load(f)
    return data

# %%
# 读取文本片段字典文件，每个文本片段调用zhipu Embedding，存储到数据库（本地pkl文件）
text_dict1 = read_dict_file('【高阶】《运行手册》HO-0907 飞行运行.pkl')
text_dict2 = read_dict_file('大型飞机公共航空运输承运人运行合格审定规则.pkl')

# %%
text_dict2_lv2 = read_dict_file('大型飞机公共航空运输承运人运行合格审定规则 lv2.pkl')
text_dict2_lv3 = read_dict_file('大型飞机公共航空运输承运人运行合格审定规则 lv3.pkl')

# %%
print(len(text_dict1))
print(len(text_dict2))
# Out:
# 295
# 301

# %%
print(len(text_dict2_lv2))
print(len(text_dict2_lv3))
# Out:
# 1032
# 1819

# %%
from zhipuai import ZhipuAI
#调用智谱AI的embedding模型
# 智谱AI Embedding长度设置为最大4096个汉字
def get_text_embedding_from_zhipu_api(input_str, max_text_length = 4096):
    input_text = input_str.replace("\n", " ")[:max_text_length] #换行符替换为空格
    client = ZhipuAI(api_key="0e059a59be0f37e58bbafe360f663b21.7G1ccHB6WZMFvfwu") 
    response = client.embeddings.create(
        model="embedding-2", #填写需要调用的模型名称
        input=input_text,
    )
    return response.data[0].embedding

# %%
# 获取PDF文件所有片段的embd
def get_paragraphs_embd(dict):
    embd_dict = {}
    for key in dict:
        text = dict[key].strip() if dict[key] is not None else ''
        if text != '':
            embd = get_text_embedding_from_zhipu_api(text)
            embd_dict[key] = embd
    return embd_dict

# %%
embd_dict1 = get_paragraphs_embd(text_dict1)
embd_dict2 = get_paragraphs_embd(text_dict2)

# %%
print(len(embd_dict1))
print(len(embd_dict2))
# Out:
# 295
# 301

# %%
embd_dict2_lv2 = get_paragraphs_embd(text_dict2_lv2)

# %%
print(len(embd_dict2_lv2))
# Out:
# 1032

# %%
# 保存embd到数据库（pkl文件）(key： (text, embd) )
import pickle
import os

def save_paragraphs_embd_into_db(dict_text, dict_embd, embd_db_file):
    # 读取数据库已有全量embd, 需判断是否第一次保存（文件不存在）
    if os.path.exists(embd_db_file):
        with open(embd_db_file, 'rb') as f:
                all_embd_data = pickle.load(f)
    else:
        all_embd_data = {}
    # 更新数据
    for key in dict_text:
        if key in dict_embd:
            all_embd_data[key] = (dict_text[key], dict_embd[key])
        else:
            all_embd_data[key] = (dict_text[key], [])
    # 保存新的embd
    save_dict_to_file(all_embd_data, embd_db_file)

# %%
save_paragraphs_embd_into_db(text_dict1, embd_dict1, 'pdf_paragraphs_embd_db.pkl')
save_paragraphs_embd_into_db(text_dict2, embd_dict2, 'pdf_paragraphs_embd_db.pkl')

# %%
save_paragraphs_embd_into_db(text_dict2_lv2, embd_dict2_lv2, 'pdf_paragraphs_embd_db.pkl')

# %%
# 验证数据库内 embd
with open('pdf_paragraphs_embd_db.pkl', 'rb') as f:
    embd_db_data = pickle.load(f)
print(len(embd_db_data))
print(embd_db_data['file2_1_第 121.3 条_(a)'])
# Out:
# 1569
# ('适用范围 本规则适用于在中华人民共和国境内依法设立的航 空运营人实施的下列公共航空运输运行： (1)使用最大起飞重量超过5,700 千克的多发涡轮驱动飞 机实施的定期载客运输飞行； (2)使用旅客座位数超过30 座或者最大商载超过3,400 千克的多发涡轮驱动飞机实施的不定期载客运输飞行； (3)使用最大商载超过3,400 千克的多发涡轮驱动飞机实 施的全货物运输飞行。', [0.034766708, 0.0060246247, -0.0039531603, -0.024886195, 0.03607047, 0.05136239, -0.027525235, 0.022351911, -0.03745202, 0.0457233, 0.00023352743, 0.025826212, -0.01571903, 0.006077772, 0.018617941, -0.01700733, -0.0073379893, -0.00041809038, -0.005350839, -0.01878856, 0.045124233, -0.0442488, 0.043247126, -0.009440781, -0.04921455, 0.0061606094, -0.012423283, 0.008467235, 0.032417953, -0.045706388, 0.018225458, 0.008091232, -0.033531107, 0.01005455, 0.044656187, 0.009874101, -0.011519151, 0.0046054367, 0.05641792, -0.059756063, 0.006692004, 0.02205091, -0.007660741, -0.012934246, 0.016211186, 0.019777104, 0.04020172, 0.032609895, -0.015292706, -0.0047163437, -0.026793092, 0.01353479, 0.017994126, -0.060111754, 0.01684339, 0.032023605, 0.027072353, 0.019292435, -0.037079293, -0.0066958154, -0.056149174, 0.027144382, -0.015483067, 0.012232939, -0.01788581, 0.00017392615, -0.033299047, 0.040866565, -0.02155218, -0.040281516, -0.015915949, -0.008292348, -0.025748229, 0.043473054, 0.032312077, -0.07624588, 0.0069283787, -0.013758918, 0.027432855, -0.0056081684, 0.06970897, 0.0075983116, 0.052099552, -0.004137793, -0.078069985, -0.067214474, -0.027858289, 0.0007610968, 0.010523643, 0.016583992, -0.0013907895, 0.035220128, -0.014560449, -0.01944096, -0.02344695, 0.06337948, 0.03166572, -0.021482171, 0.031055057, -0.012029774, 0.053103857, -0.026429256, 0.047561668, 0.02243294, 0.016065596, 0.048567817, -0.04544483, 0.013500946, 0.00052257197, 0.009096305, -0.028433282, 0.06659049, 0.026610088, 0.00031878985, -0.027158832, 0.015075548, -0.0038108102, 0.032608427, -0.008592089, -0.027846765, 0.03672992, 0.017806264, 0.030003896, -0.00018149437, -0.0077940277, -0.045990232, 0.04410094, -0.00024845926, -0.06857385, 0.0071964515, -0.0089417035, -0.045967855, 0.012445476, 0.06620548, -0.02246372, -0.002531826, -0.03548495, -0.0053403494, -0.041855857, 0.011137261, 0.03232987, -0.031933345, 0.045263913, 0.028244736, 0.016216421, 0.0124924015, 0.053282633, 0.0049162377, 0.021605013, 0.041115027, 0.01235937, 0.006627161, 7.001654e-13, -0.046281952, -0.0072652786, -0.017192712, -0.0004020647, -0.06638222, -0.032595057, 0.054023765, -0.012983748, -0.019630855, 0.012615876, 9.085814e-18, 0.01896796, -0.045015164, 0.04214828, -0.010338247, 0.035567682, -0.0013657812, 0.020773979, 0.035122693, 0.011188222, -0.044862065, 0.06325654, -0.004886594, 0.011344926, 0.0320943, -0.04225363, -0.040819902, 0.044145636, -0.01174871, 0.037717097, 0.042531896, 0.040947765, -0.044029076, 0.027980648, -0.026039455, -0.024321187, 0.019857198, -0.01808592, -0.016362084, 0.0419541, 0.01967641, 0.028238697, 0.011712558, 0.017975027, 0.044834923, -0.0028975192, 0.03405837, 0.030157037, -0.003996017, -0.012159977, -0.0055406713, 0.03301729, 0.052677903, 0.013061375, -0.0050759157, -0.034491036, -0.027247058, -0.010717915, 0.0054500382, -0.03971102, 0.024906026, 0.042599082, -0.003906563, 0.005039193, 0.03128812, 0.021728342, 0.009334314, -0.056929868, -0.018961372, 0.033374593, 0.010260665, -0.027990056, -0.023353804, -0.022637468, 0.05196916, 0.017965693, 0.00848664, -0.016437452, 0.039439566, -0.012702021, -0.014623559, 0.029579658, -0.045587737, 0.009709398, 0.03681213, -0.005227658, 0.03037298, 0.0021277731, 0.05520958, 0.0019131693, 0.019997612, 0.022187864, -0.08723858, -0.0025676165, 0.02111046, 0.005998908, 0.005067115, 0.02316586, 0.00080341304, -0.014755556, -0.048371613, -0.0030557234, -0.009877658, -0.010430672, -0.0032667215, -0.010339841, -0.03443833, 0.0006278118, 0.024703236, 0.05991915, -0.016244955, 0.019341704, 0.030583672, -0.031285506, 0.035849944, -0.0040869215, 0.033811457, 0.052351415, -0.046186365, 0.025686344, -0.011964716, 0.032909214, 0.030304931, -0.027346209, 0.06657475, 0.011417419, -0.018149827, 0.018032903, -0.0004492052, 0.034267593, 0.0670164, -0 ...

# %%
# 计算两个embd相似度
import pickle
import numpy as np

def cal_similarity(embd1, embd2):
    score = 0
    if len(embd1) != 0 and len(embd2) != 0:
        score = np.dot(embd1, embd2) / (np.linalg.norm(embd1) * np.linalg.norm(embd2))
    return score

# %%
# 上传PDF 每个片段 和 数据库内所有片段 计算相似度
def cal_paragraphs_similarity(uploaded_pdf_paragraphs_dict, db_data):
    res = {}
    for key in uploaded_pdf_paragraphs_dict:
        if key not in db_data: # 上传的PDF，拆分后 key 不在数据库（一般不会发生，以防万一，可能第二次拆分PDF片段出现BUG，导致新的key出现）
                continue
        for db_key in db_data:
            if key.split('_')[0] == db_key.split('_')[0]: # 同一个PDF 自己不和自己比较
                continue
            if len(db_data[key][1]) > 0 and len(db_data[db_key][1]) > 0: # 两个片段都能找到有效embd
                simi_score = cal_similarity(db_data[key][1], db_data[db_key][1])
                if simi_score > 0:
                    if key in res:
                        res[key].append((db_key, simi_score))
                    else:
                        res[key] = [(db_key, simi_score)]
    return res

# %%
simi_result = cal_paragraphs_similarity(text_dict1, embd_db_data)

# %%
len(simi_result)
# Out:
# 295

# %%
len(simi_result['file1_0_1.'])
# Out:
# 1274

# %%
simi_result['file1_0_1.']
# Out:
# [('file2_0_第 121.1 条', np.float64(0.6092292734149538)),
#  ('file2_1_第 121.3 条', np.float64(0.5860508299987357)),
#  ('file2_2_第 121.5 条', np.float64(0.5129576214130442)),
#  ('file2_3_第 121.7 条', np.float64(0.5877782049413514)),
#  ('file2_4_第 121.9 条', np.float64(0.578726250407278)),
#  ('file2_5_第 121.11 条', np.float64(0.6069513758483304)),
#  ('file2_6_第 121.20 条', np.float64(0.5753701762587126)),
#  ('file2_7_第 121.21 条', np.float64(0.5757351728492942)),
#  ('file2_8_第 121.23 条', np.float64(0.5860056795114403)),
#  ('file2_9_第 121.25 条', np.float64(0.5825928217897568)),
#  ('file2_10_第 121.27 条', np.float64(0.49168077741643185)),
#  ('file2_11_第 121.29 条', np.float64(0.6385049629220981)),
#  ('file2_12_第 121.31 条', np.float64(0.5385774247594263)),
#  ('file2_13_第 121.33 条', np.float64(0.4679486098788553)),
#  ('file2_14_第 121.35 条', np.float64(0.611677275508665)),
#  ('file2_15_第 121.37 条', np.float64(0.4569060260744667)),
#  ('file2_16_第 121.41 条', np.float64(0.6328976871049151)),
#  ('file2_17_第 121.42 条', np.float64(0.5357543641765928)),
#  ('file2_18_第 121.43 条', np.float64(0.6118447439218777)),
#  ('file2_19_第 121.45 条', np.float64(0.6011075475808056)),
#  ('file2_20_第 121.47 条', np.float64(0.5636767145908507)),
#  ('file2_21_第 121.49 条', np.float64(0.6036338414217005)),
#  ('file2_22_第 121.51 条', np.float64(0.5906101408590049)),
#  ('file2_23_第 121.52 条', np.float64(0.5861628944237586)),
#  ('file2_24_第 121.53 条', np.float64(0.5330859180050691)),
#  ('file2_25_第 121.55 条', np.float64(0.5438614606638361)),
#  ('file2_26_第 121.57 条', np.float64(0.6544303798919353)),
#  ('file2_27_第 121.91 条', np.float64(0.6978672528873396)),
#  ('file2_28_第 121.93 条', np.float64(0.6190446157312974)),
#  ('file2_29_第 121.95 条', np.float64(0.6415494657407069)),
#  ('file2_30_第 121.97 条', np.float64(0.604809035214245)),
#  ('file2_31_第 121.99 条', np.float64(0.6285720132451555)),
#  ('file2_32_第 121.101 条', np.float64(0.6585308818427371)),
#  ('file2_33_第 121.103 条', np.float64(0.6757154404086931)),
#  ('file2_34_第 121.105 条', np.float64(0.6279816848604496)),
#  ('file2_35_第 121.113 条', np.float64(0.64034409220118)),
#  ('file2_36_第 121.115 条', np.float64(0.6532941240169982)),
#  ('file2_37_第 121.117 条', np.float64(0.641286480240305)),
#  ('file2_38_第 121.119 条', np.float64(0.6059042307236888)),
#  ('file2_39_第 121.121 条', np.float64(0.6636260481555563)),
#  ('file2_40_第 121.123 条', np.float64(0.5946875005100478)),
#  ('file2_41_第 121.125 条', np.float64(0.6606667182997835)),
#  ('file2_42_第 121.127 条', np.float64(0.6244101249971452)),
#  ('file2_43_第 121.131 条', np.float64(0.5462345455499602)),
#  ('file2_44_第 121.133 条', np.float64(0.5538467151383254)),
#  ('file2_45_第 121.135 条', np.float64(0.5217464652604932)),
#  ('file2_46_第 121.137 条', np.float64(0.6177560662202902)),
#  ('file2_47_第 121.151 条', np.float64(0.6859337565296431)),
#  ('file2_48_第 121.153 条', np.float64(0.719481011267183)),
#  ('file2_49_第 121.155 条', np.float64(0.6101362549336236)),
#  ('file2_50_第 121.157 条', np.float64(0.6679868366905446)),
#  ('file2_51_第 121.159 条', np.float64(0.6963022151451943)),
#  ('file2_52_第 121.161 条', np.float64(0.6264085098721258)),
#  ('file2_53_第 121.171 条', np.float64(0.5489807849124937)),
#  ('file2_54_第 121.173 条', np.float64(0.6303372309629486)),
#  ('file2_55_第 121.189 条', np.float64(0.6120558913324629)),
#  ('file2_56_第 121.191 条', np.float64(0.6166402090640317)),
#  ('file2_57_第 121.193 条', np.float64(0.6028971858547636)),
#  ('file2_58_第 121.195 条', np.float64(0.6209581841597436)),
#  ('file2_59_第 121.197 条', np.float64(0.616374532894645)),
#  ('file2_60_第 121.211 条', np.float64(0.6618898250615721)),
#  ('file2_61_第 121.213 条', np.float64(0.5147656055069274)),
#  ('file2_62_第 121.215 条', np.float64(0.5908599822958679)),
#  ('file2_63_第 121.217 条', np.float64(0.5669514967333172)),
#  ('file2_64_第 121.301 条', np.float64(0.669450791866342)),
#  ('file2_65_第 121.305 条', np.float64(0.6193883744619486)),
#  ('file2_66_第 121.307 条', np.float64(0.6028392411731476)),
#  ('file2_67_第 121.308 条', np.float64(0.5657201790344392)),
#  ('file2_68_第 121.309 条', np.float64(0.591061531740828)),
#  ('file2_69_第 121.310 条', np.float64(0.5993039358795995)),
#  ('file2_70_第 121.311 条', np.float64(0.6034022813969424)),
#  ('file2_71_第 121.312 条', np.float64(0.6078433934693767)),
#  ('file2_72_第 121.313 条', np.float64(0.6616108577749238)),
#  ('file2_73_第 121.314 条', np.float64(0.511746904897448)),
#  ('file2_74_第 121.315 条', np.float64(0.6542077398419436)),
#  ('file2_75_第 121.316 条', np.float64(0.5934179399799508)),
#  ('file2_76_第 121.317 条', np.float64(0.6086174083123141)),
#  ('file2_77_第 121.318 条', np.float64(0.5998312702189446)),
#  ('file2_78_第 121.319 条', np.float64(0.6239075218502695)),
#  ('file2_79_第 121.320 条', np.float64(0.5936523552622304)),
#  ('file2_80_第 121.323 条', np.float64(0.5441362428726554)),
#  ('file2_81_第 121.325 条', np.float64(0.6080733967916991)),
#  ('file2_82_第 121.329 条', np.float64(0.4660427978508331)),
#  ('file2_83_第 121.333 条', np.float64(0.484530573956331)),
#  ('file2_84_第 121.335 条', np.float64(0.5955904689066095)),
#  ('file2_85_第 121.337 条', np.float64(0.5705045387383605)),
#  ('file2_86_第 121.339 条', np.float64(0.5777951270894613)),
#  ('file2_87_第 121.341 条', np.float64(0.5625459631228854)),
#  ('file2_88_第 121.342 条', np.float64(0.5512804285489493)),
#  ('file2_89_第 121.345 条', np.float64(0.6475347303619179)),
#  ('file2_90_第 121.346 条', np.float64(0.5900561232971642)),
#  ('file2_91_第 121.347 条', np.float64(0.6179339372445063)),
#  ('file2_92_第 121.349 条', np.float64(0.6353829877095164)),
#  ('file2_93_第 121.351 条', np.float64(0.6273077809036425)),
#  ('file2_94_第 121.352 条', np.float64(0.5785759857951415)),
#  ('file2_95_第 121.353 条', np.float64(0.605225143460912)),
#  ('file2_96_第 121.354 条', np.float64(0.6198733528075838)),
#  ('file2_97_第 121.355 条', np.float64(0.6203639743145236)),
#  ('file2_98_第 121.356 条', np.float64(0.617154190572466)),
#  ('file2_99_第 121.357 条', np.float64(0.5902432218513918)),
#  ('file2_100_第 121.358 条', np.float64(0.6437950740678521)),
#  ('file2_101_第 121.359 条', np.float64(0.6547285995027848)),
#  ('file2_102_第 121.360 条', np.float64(0.6727825254487304)),
#  ('file2_103_第 121.361 条', np.float64(0.5337286383004421)),
#  ('file2_104_第 121.362 条', np.float64(0.573635633452624)),
#  ('file2_105_第 121.363 条', np.float64(0.5938150241264762)),
#  ('file2_106_第 121.365 条', np.float64(0.5853766160177701)),
#  ('file2_107_第 121.366 条', np.float64(0.5112527488245475)),
#  ('file2_108_第 121.367 条', np.float64(0.5532647714700623)),
#  ('file2_109_第 121.368 条', np.float64(0.517116907242351)),
#  ('file2_110_第 121.371 条', np.float64(0.5333582026365943)),
#  ('file2_111_第 121.372 条', np.float64(0.4192856710189713)),
#  ('file2_112_第 121.373 条', np.float64(0.6194368145551327)),
#  ('file2_113_第 121.375 条', np.float64(0.6620603232406777)),
#  ('file2_114_第 121.379 条', np.float64(0.6440838598055109)),
#  ('file2_115_第 121.380 条', np.float64(0.5782466113944862)),
#  ('file2_116_第 121.381 条', np.float64(0.6227681741261928)),
#  ('file2_117_第 121.383 条', np.float64(0.6412421583404097)),
#  ('file2_118_第 121.385 条', np.float64(0.540393307926047)),
#  ('file2_119_第 121.391 条', np.float64(0.5838025428236774)),
#  ('file2_120_第 121.393 条', np.float64(0.6284473147624131)),
#  ('file2_121_第 121.395 条', np.float64(0.5480788948676808)),
#  ('file2_122_第 121.397 条', np.float64(0.5802339406833297)),
#  ('file2_123_第 121.401 条', np.float64(0.6303008132666311)),
#  ('file2_124_第 121.402 条', np.float64(0.6576341819163655)),
#  ('file2_125_第 121.403 条', np.float64(0.5862128771566835)),
#  ('file2_126_第 121.405 条', np.float64(0.49211102753662106)),
#  ('file2_127_第 121.407 条', np.float64(0.7166981578808186)),
#  ('file2_128_第 121.409 条', np.float64(0.6850825799237387)),
#  ('file2_129_第 121.411 条', np.float64(0.6097879934707222)),
#  ('file2_130_第 121.413 条', np.float64(0.5660346789730933)),
#  ('file2_131_第 121.415 条', np.float64(0.5970378443895098)),
#  ('file2_132_第 121.417 条', np.float64(0.5900709115049457)),
#  ('file2_133_第 121.419 条', np.float64(0.5324508244671838)),
#  ('file2_134_第 121.421 条', np.float64(0.5588836226549203)),
#  ('file2_135_第 121.422 条', np.float64(0.5825983668342378)),
#  ('file2_136_第 121.423 条', np.float64(0.5691034520803061)),
#  ('file2_137_第 121.429 条', np.float64(0.5795782810667774)),
#  ('file2_138_第 121.431 条', np.float64(0.5480786238943209)),
#  ('file2_139_第 121.433 条', np.float64(0.6564313695511836)),
#  ('file2_140_第 121.435 条', np.float64(0.5857204682935957)),
#  ('file2_141_第 121.439 条', np.float64(0.615496216622448)),
#  ('file2_142_第 121.441 条', np.float64(0.5794348038657638)),
#  ('file2_143_第 121.451 条', np.float64(0.6369739989830648)),
#  ('file2_144_第 121.453 条', np.float64(0.6104893053756113)),
#  ('file2_145_第 121.455 条', np.float64(0.6520074090011534)),
#  ('file2_146_第 121.457 条', np.float64(0.6260334709690578)),
#  ('file2_147_第 121.459 条', np.float64(0.6324628613643709)),
#  ('file2_148_第 121.461 条', np.float64(0.6500871551349066)),
#  ('file2_149_第 121.463 条', np.float64(0.6405497225981219)),
#  ('file2_150_第 121.465 条', np.float64(0.6385081865198139)),
#  ('file2_151_第 121.467 条', np.float64(0.6785349402493291)),
#  ('file2_152_第 121.469 条', np.float64(0.6441241289447939)),
#  ('file2_153_第 121.471 条', np.float64(0.5415835962758185)),
#  ('file2_154_第 121.475 条', np.float64(0.4668830174292911)),
#  ('file2_155_第 121.477 条', np.float64(0.5824483815462926)),
#  ('file2_156_第 121.479 条', np.float64(0.5958013316654174)),
#  ('file2_157_第 121.481 条', np.float64(0.6164879227678156)),
#  ('file2_158_第 121.483 条', np.float64(0.6311649217973972)),
#  ('file2_159_第 121.485 条', np.float64(0.6348326557531055)),
#  ('file2_160_第 121.487 条', np.float64(0.6018144402045547)),
#  ('file2_161_第 121.491 条', np.float64(0.5765253922815179)),
#  ('file2_162_第 121.493 条', np.float64(0.5426588820885387)),
#  ('file2_163_第 121.495 条', np.float64(0.5092834523991442)),
#  ('file2_164_第 121.501 条', np.float64(0.5866991048838276)),
#  ('file2_165_第 121.503 条', np.float64(0.49148417643151143)),
#  ('file2_166_第 121.504 条', np.float64(0.5867844534303172)),
#  ('file2_167_第 121.505 条', np.float64(0.5490431912074244)),
#  ('file2_168_第 121.506 条', np.float64(0.4013688034788704)),
#  ('file2_169_第 121.507 条', np.float64(0.48599094178113994)),
#  ('file2_170_第 121.508 条', np.float64(0.48535031904809556)),
#  ('file2_171_第 121.509 条', np.float64(0.5459808444393731)),
#  ('file2_172_第 121.510 条', np.float64(0.5509106062758888)),
#  ('file2_173_第 121.511 条', np.float64(0.528335138282099)),
#  ('file2_174_第 121.512 条', np.float64(0.6418141496307599)),
#  ('file2_175_第 121.513 条', np.float64(0.5330277037544306)),
#  ('file2_176_第 121.514 条', np.float64(0.6731329914747378)),
#  ('file2_177_第 121.515 条', np.float64(0.6182520229273543)),
#  ('file2_178_第 121.516 条', np.float64(0.4867995675595392)),
#  ('file2_179_第 121.519 条', np.float64(0.6715294694040873)),
#  ('file2_180_第 121.521 条', np.float64(0.5730017858018925)),
#  ('file2_181_第 121.523 条', np.float64(0.5945690498150379)),
#  ('file2_182_第 121.525 条', np.float64(0.5532759886483541)),
#  ('file2_183_第 121.526 条', np.float64(0.5875794092380114)),
#  ('file2_184_第 121.527 条', np.float64(0.5638844804010835)),
#  ('file2_185_第 121.529 条', np.float64(0.5753989453812463)),
#  ('file2_186_第 121.530 条', np.float64(0.6575390383714199)),
#  ('file2_187_第 121.531 条', np.float64(0.6274943330917832)),
#  ('file2_188_第 121.532 条', np.float64(0.6169174233364884)),
#  ('file2_189_第 121.533 条', np.float64(0.6618768213936101)),
#  ('file2_190_第 121.534 条', np.float64(0.6102297872975029)),
#  ('file2_191_第 121.535 条', np.float64(0.659511817767965)),
#  ('file2_192_第 121.537 条', np.float64(0.6356503755885508)),
#  ('file2_193_第 121.538 条', np.float64(0.5689553351415406)),
#  ('file2_194_第 121.539 条', np.float64(0.6086981893810114)),
#  ('file2_195_第 121.541 条', np.float64(0.6848896518565095)),
#  ('file2_196_第 121.543 条', np.float64(0.7193403400086978)),
#  ('file2_197_第 121.545 条', np.float64(0.6533772205228555)),
#  ('file2_198_第 121.547 条', np.float64(0.6344584857475143)),
#  ('file2_199_第 121.549 条', np.float64(0.5865117811605839)),
#  ('file2_200_第 121.550 条', np.float64(0.6124668213107497)),
#  ('file2_201_第 121.551 条', np.float64(0.6670720380457376)),
#  ('file2_202_第 121.552 条', np.float64(0.6726786684415397)),
#  ('file2_203_第 121.553 条', np.float64(0.6942515527991642)),
#  ('file2_204_第 121.554 条', np.float64(0.6194268906606376)),
#  ('file2_205_第 121.555 条', np.float64(0.5787606179184728)),
#  ('file2_206_第 121.556 条', np.float64(0.5921636325618229)),
#  ('file2_207_第 121.557 条', np.float64(0.5642913212653242)),
#  ('file2_208_第 121.558 条', np.float64(0.6264842731359747)),
#  ('file2_209_第 121.559 条', np.float64(0.5274366903003538)),
#  ('file2_210_第 121.561 条', np.float64(0.5616409464087733)),
#  ('file2_211_第 121.563 条', np.float64(0.5774195873413976)),
#  ('file2_212_第 121.565 条', np.float64(0.6154112166622554)),
#  ('file2_213_第 121.567 条', np.float64(0.6315790397764283)),
#  ('file2_214_第 121.569 条', np.float64(0.5622992765928191)),
#  ('file2_215_第 121.571 条', np.float64(0.5663934286291005)),
#  ('file2_216_第 121.573 条', np.float64(0.6320073252821934)),
#  ('file2_217_第 121.574 条', np.float64(0.5021633593126363)),
#  ('file2_218_第 121.575 条', np.float64(0.5748152879046244)),
#  ('file2_219_第 121.576 条', np.float64(0.5552903249477852)),
#  ('file2_220_第 121.577 条', np.float64(0.5158110436446838)),
#  ('file2_221_第 121.579 条', np.float64(0.4548056423576717)),
#  ('file2_222_第 121.581 条', np.float64(0.5950849304752898)),
#  ('file2_223_第 121.583 条', np.float64(0.6527097318133307)),
#  ('file2_224_第 121.585 条', np.float64(0.5184342491176194)),
#  ('file2_225_第 121.587 条', np.float64(0.5582485144177534)),
#  ('file2_226_第 121.588 条', np.float64(0.5069333499992822)),
#  ('file2_227_第 121.589 条', np.float64(0.6206408914142717)),
#  ('file2_228_第 121.591 条', np.float64(0.6190759292825265)),
#  ('file2_229_第 121.593 条', np.float64(0.5783635896679942)),
#  ('file2_230_第 121.595 条', np.float64(0.6181085804486097)),
#  ('file2_231_第 121.597 条', np.float64(0.5989993981535674)),
#  ('file2_232_第 121.605 条', np.float64(0.6266725124175587)),
#  ('file2_233_第 121.607 条', np.float64(0.6612163468828911)),
#  ('file2_234_第 121.609 条', np.float64(0.7083478432081751)),
#  ('file2_235_第 121.610 条', np.float64(0.6691352381975341)),
#  ('file2_236_第 121.611 条', np.float64(0.672807474884932)),
#  ('file2_237_第 121.621 条', np.float64(0.5989704838456553)),
#  ('file2_238_第 121.622 条', np.float64(0.6613638009634895)),
#  ('file2_239_第 121.623 条', np.float64(0.5600163431197377)),
#  ('file2_240_第 121.625 条', np.float64(0.5404054859140383)),
#  ('file2_241_第 121.626 条', np.float64(0.5772940827326128)),
#  ('file2_242_第 121.627 条', np.float64(0.6279239720417643)),
#  ('file2_243_第 121.629 条', np.float64(0.7217332547480871)),
#  ('file2_244_第 121.631 条', np.float64(0.568092401408654)),
#  ('file2_245_第 121.633 条', np.float64(0.5416177072172477)),
#  ('file2_246_第 121.635 条', np.float64(0.5990434173506825)),
#  ('file2_247_第 121.637 条', np.float64(0.6382465291857369)),
#  ('file2_248_第 121.639 条', np.float64(0.5774678574664378)),
#  ('file2_249_第 121.641 条', np.float64(0.6140559742087847)),
#  ('file2_250_第 121.642 条', np.float64(0.579735972020806)),
#  ('file2_251_第 121.643 条', np.float64(0.5313523289452058)),
#  ('file2_252_第 121.645 条', np.float64(0.6676851845643095)),
#  ('file2_253_第 121.647 条', np.float64(0.6211103185872494)),
#  ('file2_254_第 121.649 条', np.float64(0.6084500817655756)),
#  ('file2_255_第 121.651 条', np.float64(0.6287740054773117)),
#  ('file2_256_第 121.653 条', np.float64(0.5460125068457196)),
#  ('file2_257_第 121.655 条', np.float64(0.6414466233050911)),
#  ('file2_258_第 121.657 条', np.float64(0.5412151433759856)),
#  ('file2_259_第 121.659 条', np.float64(0.5259940279038536)),
#  ('file2_260_第 121.663 条', np.float64(0.5154288344589258)),
#  ('file2_261_第 121.665 条', np.float64(0.5794049296779532)),
#  ('file2_262_第 121.667 条', np.float64(0.6275754424511265)),
#  ('file2_263_第 121.669 条', np.float64(0.5919309442601784)),
#  ('file2_264_第 121.671 条', np.float64(0.5925045582045805)),
#  ('file2_265_第 121.673 条', np.float64(0.6481585812856198)),
#  ('file2_266_第 121.675 条', np.float64(0.6869470803979387)),
#  ('file2_267_第 121.677 条', np.float64(0.535758036515281)),
#  ('file2_268_第 121.679 条', np.float64(0.5506206047268916)),
#  ('file2_269_第 121.691 条', np.float64(0.5757990024607132)),
#  ('file2_270_第 121.693 条', np.float64(0.6077234721840153)),
#  ('file2_271_第 121.695 条', np.float64(0.5159891654463228)),
#  ('file2_272_第 121.696 条', np.float64(0.5773588935850197)),
#  ('file2_273_第 121.697 条', np.float64(0.572468657776746)),
#  ('file2_274_第 121.699 条', np.float64(0.5753793680466917)),
#  ('file2_275_第 121.700 条', np.float64(0.5912207938754785)),
#  ('file2_276_第 121.701 条', np.float64(0.5447123991656592)),
#  ('file2_277_第 121.702 条', np.float64(0.623017684997306)),
#  ('file2_278_第 121.703 条', np.float64(0.6053749200003666)),
#  ('file2_279_第 121.704 条', np.float64(0.6050575186096123)),
#  ('file2_280_第 121.705 条', np.float64(0.47448797748396737)),
#  ('file2_281_第 121.706 条', np.float64(0.5440996532973899)),
#  ('file2_282_第 121.707 条', np.float64(0.5676644604656892)),
#  ('file2_283_第 121.709 条', np.float64(0.48725768707924805)),
#  ('file2_284_第 121.710 条', np.float64(0.6194069854107372)),
#  ('file2_285_第 121.711 条', np.float64(0.6190273124727914)),
#  ('file2_286_第 121.714 条', np.float64(0.5657785228579356)),
#  ('file2_287_第 121.715 条', np.float64(0.5263885603793702)),
#  ('file2_288_第 121.716 条', np.float64(0.5570332520598211)),
#  ('file2_289_第 121.718 条', np.float64(0.5604024501365384)),
#  ('file2_290_第 121.719 条', np.float64(0.5230965053971262)),
#  ('file2_291_第 121.720 条', np.float64(0.5358068079791145)),
#  ('file2_292_第 121.741 条', np.float64(0.5572488454024571)),
#  ('file2_293_第 121.743 条', np.float64(0.5850804276354762)),
#  ('file2_294_第 121.745 条', np.float64(0.5830491269988861)),
#  ('file2_295_第 121.760 条', np.float64(0.589323055322536)),
#  ('file2_296_第 121.761 条', np.float64(0.6259626709483515)),
#  ('file2_297_第 121.762 条', np.float64(0.44847633186612895)),
#  ('file2_298_第 121.763 条', np.float64(0.6240403086643785)),
#  ('file2_299_第 121.764 条', np.float64(0.4205899979904121)),
#  ('file2_300_第 121.771 条', np.float64(0.607406562527928)),
#  ('file2_1_第 121.3 条_(a)', np.float64(0.5940769139779696)),
#  ('file2_1_第 121.3 条_(b)', np.float64(0.5842391791404825)),
#  ('file2_1_第 121.3 条_(c)', np.float64(0.6241816509688389)),
#  ('file2_1_第 121.3 条_(d)', np.float64(0.5929214128539201)),
#  ('file2_1_第 121.3 条_(e)', np.float64(0.6053029048666627)),
#  ('file2_1_第 121.3 条_(f)', np.float64(0.5130382223079591)),
#  ('file2_2_第 121.5 条_(a)', np.float64(0.5046188985412335)),
#  ('file2_2_第 121.5 条_(b)', np.float64(0.33861869757196755)),
#  ('file2_3_第 121.7 条_(a)', np.float64(0.550449752030128)),
#  ('file2_3_第 121.7 条_(b)', np.float64(0.5503631253487884)),
#  ('file2_3_第 121.7 条_(c)', np.float64(0.5535647315385378)),
#  ('file2_3_第 121.7 条_(d)', np.float64(0.6095632063711064)),
#  ('file2_3_第 121.7 条_(e)', np.float64(0.557924696265181)),
#  ('file2_4_第 121.9 条_(a)', np.float64(0.6026327849666108)),
#  ('file2_4_第 121.9 条_(b)', np.float64(0.5550737579517945)),
#  ('file2_4_第 121.9 条_(c)', np.float64(0.5643817637406233)),
#  ('file2_4_第 121.9 条_(d)', np.float64(0.47310342938586614)),
#  ('file2_4_第 121.9 条_(e)', np.float64(0.6333802407105613)),
#  ('file2_6_第 121.20 条_(a)', np.float64(0.5911142271941783)),
#  ('file2_6_第 121.20 条_(b)', np.float64(0.5723094445984592)),
#  ('file2_7_第 121.21 条_(a)', np.float64(0.5666168018627372)),
#  ('file2_7_第 121.21 条_(b)', np.float64(0.4681705410264323)),
#  ('file2_7_第 121.21 条_(c)', np.float64(0.5523858859706259)),
#  ('file2_7_第 121.21 条_(d)', np.float64(0.5927206931038442)),
#  ('file2_7_第 121.21 条_(e)', np.float64(0.5499410378203458)),
#  ('file2_7_第 121.21 条_(f)', np.float64(0.5733651123974952)),
#  ('file2_8_第 121.23 条_(a)', np.float64(0.5743280775192953)),
#  ('file2_8_第 121.23 条_(b)', np.float64(0.5851372511873124)),
#  ('file2_9_第 121.25 条_(a)', np.float64(0.5561596723177247)),
#  ('file2_9_第 121.25 条_(b)', np.float64(0.5935493459039362)),
#  ('file2_10_第 121.27 条_(a)', np.float64(0.47590509091488387)),
#  ('file2_10_第 121.27 条_(b)', np.float64(0.52420395312838)),
#  ('file2_10_第 121.27 条_(c)', np.float64(0.4934065167413097)),
#  ('file2_12_第 121.31 条_(a)', np.float64(0.501273843765774)),
#  ('file2_12_第 121.31 条_(b)', np.float64(0.5252253148292825)),
#  ('file2_12_第 121.31 条_(c)', np.float64(0.41041365104260796)),
#  ('file2_13_第 121.33 条_(a)', np.float64(0.44046752597138944)),
#  ('file2_13_第 121.33 条_(b)', np.float64(0.47433386896848817)),
#  ('file2_13_第 121.33 条_(c)', np.float64(0.4429826682260808)),
#  ('file2_14_第 121.35 条_(a)', np.float64(0.5422880984136944)),
#  ('file2_14_第 121.35 条_(b)', np.float64(0.42951249665678026)),
#  ('file2_14_第 121.35 条_(i)', np.float64(0.4290176726311117)),
#  ('file2_14_第 121.35 条_(c)', np.float64(0.4646732320175557)),
#  ('file2_14_第 121.35 条_(v)', np.float64(0.6683307537313129)),
#  ('file2_14_第 121.35 条_(d)', np.float64(0.49287476199890323)),
#  ('file2_14_第 121.35 条_(e)', np.float64(0.5146124359554849)),
#  ('file2_16_第 121.41 条_(a)', np.float64(0.6337135016179417)),
#  ('file2_16_第 121.41 条_(b)', np.float64(0.6111232294521083)),
#  ('file2_16_第 121.41 条_(c)', np.float64(0.43782831664981964)),
#  ('file2_16_第 121.41 条_(d)', np.float64(0.5574009976682145)),
#  ('file2_16_第 121.41 条_(e)', np.float64(0.5423717780646076)),
#  ('file2_17_第 121.42 条_(a)', np.float64(0.4235768971886585)),
#  ('file2_17_第 121.42 条_(b)', np.float64(0.40070747896645653)),
#  ('file2_17_第 121.42 条_(c)', np.float64(0.5814701906575168)),
#  ('file2_17_第 121.42 条_(d)', np.float64(0.5611395003174555)),
#  ('file2_18_第 121.43 条_(a)', np.float64(0.43335591973790477)),
#  ('file2_18_第 121.43 条_(i)', np.float64(0.6280973252785861)),
#  ('file2_18_第 121.43 条_(b)', np.float64(0.6476830879787541)),
#  ('file2_18_第 121.43 条_(c)', np.float64(0.4750472282415356)),
#  ('file2_18_第 121.43 条_(d)', np.float64(0.5244535443057022)),
#  ('file2_18_第 121.43 条_(v)', np.float64(0.44720699651351614)),
#  ('file2_18_第 121.43 条_(e)', np.float64(0.4558826333079449)),
#  ('file2_18_第 121.43 条_(f)', np.float64(0.5860449924723696)),
#  ('file2_18_第 121.43 条_(g)', np.float64(0.43992819732343535)),
#  ('file2_19_第 121.45 条_(a)', np.float64(0.5756492878105084)),
#  ('file2_19_第 121.45 条_(b)', np.float64(0.5324129351207698)),
#  ('file2_19_第 121.45 条_(i)', np.float64(0.5347513719988128)),
#  ('file2_19_第 121.45 条_(c)', np.float64(0.6007373411648012)),
#  ('file2_19_第 121.45 条_(d)', np.float64(0.5732070925644531)),
#  ('file2_19_第 121.45 条_(e)', np.float64(0.6172171922557137)),
#  ('file2_19_第 121.45 条_(f)', np.float64(0.5926903252909579)),
#  ('file2_19_第 121.45 条_(g)', np.float64(0.31901276450858485)),
#  ('file2_20_第 121.47 条_(a)', np.float64(0.5015774634676453)),
#  ('file2_20_第 121.47 条_(b)', np.float64(0.5792797950900207)),
#  ('file2_21_第 121.49 条_(a)', np.float64(0.6054199401809409)),
#  ('file2_21_第 121.49 条_(b)', np.float64(0.5930323386309706)),
#  ('file2_22_第 121.51 条_(a)', np.float64(0.43436130265903306)),
#  ('file2_22_第 121.51 条_(b)', np.float64(0.6347737823888358)),
#  ('file2_23_第 121.52 条_(a)', np.float64(0.5868023545046226)),
#  ('file2_23_第 121.52 条_(b)', np.float64(0.5931723070688286)),
#  ('file2_23_第 121.52 条_(c)', np.float64(0.5381908542753827)),
#  ('file2_23_第 121.52 条_(d)', np.float64(0.5387406976117148)),
#  ('file2_24_第 121.53 条_(a)', np.float64(0.5441576657313433)),
#  ('file2_24_第 121.53 条_(b)', np.float64(0.5286293995039523)),
#  ('file2_24_第 121.53 条_(c)', np.float64(0.5175318268386512)),
#  ('file2_25_第 121.55 条_(a)', np.float64(0.5460634623631303)),
#  ('file2_25_第 121.55 条_(b)', np.float64(0.5326694783083689)),
#  ('file2_27_第 121.91 条_(a)', np.float64(0.6960130477345842)),
#  ('file2_27_第 121.91 条_(b)', np.float64(0.7226489089492737)),
#  ('file2_28_第 121.93 条_(a)', np.float64(0.6255411986850604)),
#  ('file2_28_第 121.93 条_(b)', np.float64(0.5987061814614535)),
#  ('file2_29_第 121.95 条_(a)', np.float64(0.6483822678020406)),
#  ('file2_29_第 121.95 条_(b)', np.float64(0.574190036825339)),
#  ('file2_29_第 121.95 条_(i)', np.float64(0.598022025991719)),
#  ('file2_29_第 121.95 条_(v)', np.float64(0.6817114299977405)),
#  ('file2_29_第 121.95 条_(c)', np.float64(0.6069234125483541)),
#  ('file2_30_第 121.97 条_(a)', np.float64(0.6129257219112908)),
#  ('file2_30_第 121.97 条_(b)', np.float64(0.5963160688014499)),
#  ('file2_30_第 121.97 条_(c)', np.float64(0.6259223984590315)),
#  ('file2_31_第 121.99 条_(a)', np.float64(0.5374003782455019)),
#  ('file2_31_第 121.99 条_(b)', np.float64(0.43654090438968335)),
#  ('file2_31_第 121.99 条_(c)', np.float64(0.6098742431948656)),
#  ('file2_31_第 121.99 条_(d)', np.float64(0.5691298214475403)),
#  ('file2_32_第 121.101 条_(a)', np.float64(0.6408810006061586)),
#  ('file2_32_第 121.101 条_(b)', np.float64(0.6460633970996945)),
#  ('file2_33_第 121.103 条_(a)', np.float64(0.6367721796066879)),
#  ('file2_33_第 121.103 条_(b)', np.float64(0.475202035303827)),
#  ('file2_33_第 121.103 条_(c)', np.float64(0.49905824491129125)),
#  ('file2_35_第 121.113 条_(a)', np.float64(0.6296962455047481)),
#  ('file2_35_第 121.113 条_(b)', np.float64(0.6752487944430463)),
#  ('file2_35_第 121.113 条_(c)', np.float64(0.6383959583115816)),
#  ('file2_36_第 121.115 条_(a)', np.float64(0.6255411986850604)),
#  ('file2_36_第 121.115 条_(b)', np.float64(0.5760452646329437)),
#  ('file2_37_第 121.117 条_(a)', np.float64(0.6492919958693614)),
#  ('file2_37_第 121.117 条_(b)', np.float64(0.6293731048971253)),
#  ('file2_37_第 121.117 条_(i)', np.float64(0.598022025991719)),
#  ('file2_37_第 121.117 条_(v)', np.float64(0.6817114299977405)),
#  ('file2_37_第 121.117 条_(c)', np.float64(0.6069234125483541)),
#  ('file2_38_第 121.119 条_(a)', np.float64(0.5374003782455019)),
#  ('file2_38_第 121.119 条_(b)', np.float64(0.43654090438968335)),
#  ('file2_38_第 121.119 条_(c)', np.float64(0.584326011830043)),
#  ('file2_39_第 121.121 条_(a)', np.float64(0.6398560990509098)),
#  ('file2_39_第 121.121 条_(b)', np.float64(0.6460633970996945)),
#  ('file2_41_第 121.125 条_(a)', np.float64(0.6421232514021279)),
#  ('file2_41_第 121.125 条_(i)', np.float64(0.5843910765955455)),
#  ('file2_41_第 121.125 条_(b)', np.float64(0.657483972380974)),
#  ('file2_41_第 121.125 条_(c)', np.float64(0.5399579975370841)),
#  ('file2_41_第 121.125 条_(d)', np.float64(0.6684456302877618)),
#  ('file2_42_第 121.127 条_(a)', np.float64(0.6364933506237719)),
#  ('file2_42_第 121.127 条_(i)', np.float64(0.6929337175153591)),
#  ('file2_42_第 121.127 条_(b)', np.float64(0.603322785712461)),
#  ('file2_43_第 121.131 条_(a)', np.float64(0.5286179685907968)),
#  ('file2_43_第 121.131 条_(b)', np.float64(0.5395143834915516)),
#  ('file2_43_第 121.131 条_(c)', np.float64(0.40985341642465845)),
#  ('file2_44_第 121.133 条_(a)', np.float64(0.5237467759056799)),
#  ('file2_44_第 121.133 条_(i)', np.float64(0.6272173353867145)),
#  ('file2_44_第 121.133 条_(b)', np.float64(0.5666161097590656)),
#  ('file2_44_第 121.133 条_(c)', np.float64(0.5916672257993307)),
#  ('file2_44_第 121.133 条_(v)', np.float64(0.541421914654248)),
#  ('file2_44_第 121.133 条_(d)', np.float64(0.5659277787491671)),
#  ('file2_45_第 121.135 条_(a)', np.float64(0.5157324265387527)),
#  ('file2_45_第 121.135 条_(b)', np.float64(0.4082174416931051)),
#  ('file2_46_第 121.137 条_(a)', np.float64(0.5584363687743061)),
#  ('file2_46_第 121.137 条_(b)', np.float64(0.6074485838913687)),
#  ('file2_46_第 121.137 条_(c)', np.float64(0.5830070955403162)),
#  ('file2_46_第 121.137 条_(d)', np.float64(0.6131006069507131)),
#  ('file2_47_第 121.151 条_(a)', np.float64(0.6892699488843559)),
#  ('file2_47_第 121.151 条_(b)', np.float64(0.6539059851107843)),
#  ('file2_47_第 121.151 条_(c)', np.float64(0.6398677648297223)),
#  ('file2_50_第 121.157 条_(a)', np.float64(0.6855089855223231)),
#  ('file2_50_第 121.157 条_(b)', np.float64(0.6499201013422794)),
#  ('file2_51_第 121.159 条_(a)', np.float64(0.691315150687107)),
#  ('file2_51_第 121.159 条_(b)', np.float64(0.7176950404043883)),
#  ('file2_51_第 121.159 条_(c)', np.float64(0.5311111922622472)),
#  ('file2_51_第 121.159 条_(d)', np.float64(0.6378024842885038)),
#  ('file2_52_第 121.161 条_(a)', np.float64(0.5874092027628809)),
#  ('file2_52_第 121.161 条_(b)', np.float64(0.5689812769943549)),
#  ('file2_52_第 121.161 条_(c)', np.float64(0.6514856050413567)),
#  ('file2_52_第 121.161 条_(d)', np.float64(0.5366553366814797)),
#  ('file2_52_第 121.161 条_(e)', np.float64(0.5876114319372866)),
#  ('file2_53_第 121.171 条_(a)', np.float64(0.46645804726239964)),
#  ('file2_53_第 121.171 条_(b)', np.float64(0.522053640541503)),
#  ('file2_53_第 121.171 条_(c)', np.float64(0.46606631560459616)),
#  ('file2_54_第 121.173 条_(a)', np.float64(0.6211259498657097)),
#  ('file2_54_第 121.173 条_(b)', np.float64(0.5800776420098411)),
#  ('file2_54_第 121.173 条_(c)', np.float64(0.5346709899421056)),
#  ('file2_55_第 121.189 条_(a)', np.float64(0.6655231149568013)),
#  ('file2_55_第 121.189 条_(b)', np.float64(0.670465238238494)),
#  ('file2_55_第 121.189 条_(c)', np.float64(0.6064925857610838)),
#  ('file2_55_第 121.189 条_(d)', np.float64(0.628312057196933)),
#  ('file2_55_第 121.189 条_(e)', np.float64(0.6452395704346031)),
#  ('file2_55_第 121.189 条_(f)', np.float64(0.6760355275199689)),
#  ('file2_56_第 121.191 条_(a)', np.float64(0.6046464644537463)),
#  ('file2_56_第 121.191 条_(b)', np.float64(0.6209710482961854)),
#  ('file2_57_第 121.193 条_(a)', np.float64(0.6150422546210683)),
#  ('file2_57_第 121.193 条_(b)', np.float64(0.6026477124949854)),
#  ('file2_58_第 121.195 条_(a)', np.float64(0.6549443633819928)),
#  ('file2_58_第 121.195 条_(b)', np.float64(0.6218107553759314)),
#  ('file2_58_第 121.195 条_(c)', np.float64(0.6725935924332884)),
#  ('file2_58_第 121.195 条_(d)', np.float64(0.6464422769530184)),
#  ('file2_58_第 121.195 条_(e)', np.float64(0.6439841735858021)),
#  ('file2_58_第 121.195 条_(f)', np.float64(0.6884127214217032)),
#  ('file2_61_第 121.213 条_(a)', np.float64(0.5879452115153204)),
#  ('file2_61_第 121.213 条_(b)', np.float64(0.5979480377530455)),
#  ('file2_61_第 121.213 条_(c)', np.float64(0.49308717913520334)),
#  ('file2_61_第 121.213 条_(d)', np.float64(0.5573500750098771)),
#  ('file2_61_第 121.213 条_(e)', np.float64(0.45377484137538)),
#  ('file2_62_第 121.215 条_(a)', np.float64(0.5959019498932989)),
#  ('file2_62_第 121.215 条_(b)', np.float64(0.5672070327548242)),
#  ('file2_62_第 121.215 条_(c)', np.float64(0.5389313096236088)),
#  ('file2_64_第 121.301 条_(a)', np.float64(0.49873418477742765)),
#  ('file2_64_第 121.301 条_(b)', np.float64(0.6260620840040413)),
#  ('file2_64_第 121.301 条_(c)', np.float64(0.5560360420131846)),
#  ('file2_64_第 121.301 条_(d)', np.float64(0.5837083062765357)),
#  ('file2_64_第 121.301 条_(e)', np.float64(0.6705674955693616)),
#  ('file2_65_第 121.305 条_(a)', np.float64(0.5984226515923997)),
#  ('file2_65_第 121.305 条_(b)', np.float64(0.5919381094573817)),
#  ('file2_65_第 121.305 条_(c)', np.float64(0.5856837960358321)),
#  ('file2_65_第 121.305 条_(d)', np.float64(0.5290107044016926)),
#  ('file2_65_第 121.305 条_(e)', np.float64(0.5657754583564775)),
#  ('file2_65_第 121.305 条_(f)', np.float64(0.5945058477111405)),
#  ('file2_65_第 121.305 条_(g)', np.float64(0.5960439302625022)),
#  ('file2_65_第 121.305 条_(h)', np.float64(0.5172073751697874)),
#  ('file2_65_第 121.305 条_(i)', np.float64(0.5981539681282796)),
#  ('file2_65_第 121.305 条_(j)', np.float64(0.5974273765114639)),
#  ('file2_65_第 121.305 条_(k)', np.float64(0.6173034789330765)),
#  ('file2_65_第 121.305 条_(l)', np.float64(0.6322097523809246)),
#  ('file2_66_第 121.307 条_(a)', np.float64(0.5605517598945268)),
#  ('file2_66_第 121.307 条_(b)', np.float64(0.6002622054418894)),
#  ('file2_66_第 121.307 条_(i)', np.float64(0.6015058068777812)),
#  ('file2_66_第 121.307 条_(c)', np.float64(0.6104255412830477)),
#  ('file2_67_第 121.308 条_(a)', np.float64(0.5856137872447191)),
#  ('file2_67_第 121.308 条_(b)', np.float64(0.5566235306642545)),
#  ('file2_68_第 121.309 条_(a)', np.float64(0.625745601853463)),
#  ('file2_68_第 121.309 条_(b)', np.float64(0.5947484219831797)),
#  ('file2_68_第 121.309 条_(c)', np.float64(0.5393926053622827)),
#  ('file2_68_第 121.309 条_(i)', np.float64(0.5363214928913074)),
#  ('file2_68_第 121.309 条_(d)', np.float64(0.573198985798152)),
#  ('file2_68_第 121.309 条_(e)', np.float64(0.4977377871697434)),
#  ('file2_68_第 121.309 条_(f)', np.float64(0.5524913565588101)),
#  ('file2_69_第 121.310 条_(a)', np.float64(0.6013272241093307)),
#  ('file2_69_第 121.310 条_(b)', np.float64(0.5307076682728645)),
#  ('file2_69_第 121.310 条_(i)', np.float64(0.5751946288321591)),
#  ('file2_69_第 121.310 条_(c)', np.float64(0.5295217680807152)),
#  ('file2_69_第 121.310 条_(d)', np.float64(0.5289900909422249)),
#  ('file2_69_第 121.310 条_(e)', np.float64(0.5521614350060039)),
#  ('file2_69_第 121.310 条_(f)', np.float64(0.6033408698143934)),
#  ('file2_69_第 121.310 条_(g)', np.float64(0.5469411294970513)),
#  ('file2_69_第 121.310 条_(h)', np.float64(0.5939064510503312)),
#  ('file2_69_第 121.310 条_(j)', np.float64(0.5896314121765679)),
#  ('file2_69_第 121.310 条_(k)', np.float64(0.553310775448471)),
#  ('file2_69_第 121.310 条_(l)', np.float64(0.5229471170521581)),
#  ('file2_69_第 121.310 条_(m)', np.float64(0.5750146609421021)),
#  ('file2_70_第 121.311 条_(a)', np.float64(0.5848970943141577)),
#  ('file2_70_第 121.311 条_(b)', np.float64(0.6499870421391544)),
#  ('file2_70_第 121.311 条_(i)', np.float64(0.5617366023459066)),
#  ('file2_70_第 121.311 条_(c)', np.float64(0.6328680005507223)),
#  ('file2_70_第 121.311 条_(d)', np.float64(0.5299778055205222)),
#  ('file2_70_第 121.311 条_(e)', np.float64(0.6352723389236713)),
#  ('file2_70_第 121.311 条_(f)', np.float64(0.5690953346449782)),
#  ('file2_70_第 121.311 条_(g)', np.float64(0.6020077620273687)),
#  ('file2_70_第 121.311 条_(h)', np.float64(0.6155407360768339)),
#  ('file2_70_第 121.311 条_(j)', np.float64(0.5483619649673412)),
#  ('file2_71_第 121.312 条_(a)', np.float64(0.608302418956201)),
#  ('file2_71_第 121.312 条_(b)', np.float64(0.5522038134460813)),
#  ('file2_72_第 121.313 条_(a)', np.float64(0.656653636794013)),
#  ('file2_72_第 121.313 条_(b)', np.float64(0.6761481666084738)),
#  ('file2_72_第 121.313 条_(c)', np.float64(0.6531029398141308)),
#  ('file2_72_第 121.313 条_(d)', np.float64(0.6214187574413674)),
#  ('file2_72_第 121.313 条_(e)', np.float64(0.6602596682667746)),
#  ('file2_72_第 121.313 条_(f)', np.float64(0.6738087576117806)),
#  ('file2_72_第 121.313 条_(i)', np.float64(0.6639670646797198)),
#  ('file2_72_第 121.313 条_(g)', np.float64(0.63017919241414)),
#  ('file2_72_第 121.313 条_(h)', np.float64(0.670752585926346)),
#  ('file2_73_第 121.314 条_(a)', np.float64(0.4975879029501506)),
#  ('file2_73_第 121.314 条_(b)', np.float64(0.3979887648341608)),
#  ('file2_74_第 121.315 条_(a)', np.float64(0.5949785903683772)),
#  ('file2_74_第 121.315 条_(b)', np.float64(0.6402572462638758)),
#  ('file2_74_第 121.315 条_(c)', np.float64(0.6395684652745495)),
#  ('file2_76_第 121.317 条_(a)', np.float64(0.5958786615928051)),
#  ('file2_76_第 121.317 条_(b)', np.float64(0.5614153765762658)),
#  ('file2_76_第 121.317 条_(c)', np.float64(0.5941075129174017)),
#  ('file2_76_第 121.317 条_(d)', np.float64(0.47510564673646666)),
#  ('file2_76_第 121.317 条_(e)', np.float64(0.5719100507605506)),
#  ('file2_76_第 121.317 条_(f)', np.float64(0.5536319598048848)),
#  ('file2_76_第 121.317 条_(g)', np.float64(0.47531583622513324)),
#  ('file2_76_第 121.317 条_(h)', np.float64(0.5833765917962263)),
#  ('file2_76_第 121.317 条_(i)', np.float64(0.4831259102149221)),
#  ('file2_77_第 121.318 条_(a)', np.float64(0.5909728803426577)),
#  ('file2_77_第 121.318 条_(b)', np.float64(0.585940531358528)),
#  ('file2_77_第 121.318 条_(c)', np.float64(0.5777085115748093)),
#  ('file2_78_第 121.319 条_(a)', np.float64(0.585651515296442)),
#  ('file2_78_第 121.319 条_(b)', np.float64(0.6037903365679366)),
#  ('file2_78_第 121.319 条_(i)', np.float64(0.65626014305873)),
#  ('file2_79_第 121.320 条_(a)', np.float64(0.5895088729268885)),
#  ('file2_80_第 121.323 条_(a)', np.float64(0.5457758143645649)),
#  ('file2_80_第 121.323 条_(b)', np.float64(0.541496213579072)),
#  ('file2_80_第 121.323 条_(c)', np.float64(0.5328214918713761)),
#  ('file2_80_第 121.323 条_(d)', np.float64(0.5268735492784697)),
#  ('file2_81_第 121.325 条_(a)', np.float64(0.5959308061259502)),
#  ('file2_81_第 121.325 条_(b)', np.float64(0.5470014503284502)),
#  ('file2_81_第 121.325 条_(c)', np.float64(0.5921987356704801)),
#  ('file2_82_第 121.329 条_(a)', np.float64(0.4688785800473837)),
#  ('file2_82_第 121.329 条_(b)', np.float64(0.5303399963407536)),
#  ('file2_82_第 121.329 条_(c)', np.float64(0.5143504972978397)),
#  ('file2_82_第 121.329 条_(d)', np.float64(0.4631043926156476)),
#  ('file2_83_第 121.333 条_(a)', np.float64(0.501468862195277)),
#  ('file2_83_第 121.333 条_(b)', np.float64(0.5283002308073421)),
#  ('file2_83_第 121.333 条_(c)', np.float64(0.4939519700157748)),
#  ('file2_83_第 121.333 条_(i)', np.float64(0.48688644861545616)),
#  ('file2_83_第 121.333 条_(d)', np.float64(0.48873614534362897)),
#  ('file2_83_第 121.333 条_(e)', np.float64(0.45944425258574684)),
#  ('file2_83_第 121.333 条_(f)', np.float64(0.4941305360806918)),
#  ('file2_85_第 121.337 条_(a)', np.float64(0.5050703737317765)),
#  ('file2_85_第 121.337 条_(b)', np.float64(0.5936832635993985)),
#  ('file2_85_第 121.337 条_(i)', np.float64(0.5697035126986555)),
#  ('file2_85_第 121.337 条_(c)', np.float64(0.5724675062432373)),
#  ('file2_86_第 121.339 条_(a)', np.float64(0.6094809481515671)),
#  ('file2_86_第 121.339 条_(b)', np.float64(0.5830056110797621)),
#  ('file2_86_第 121.339 条_(c)', np.float64(0.5957319708007032)),
#  ('file2_86_第 121.339 条_(d)', np.float64(0.6205880541348938)),
#  ('file2_86_第 121.339 条_(e)', np.float64(0.5638250655456714)),
#  ('file2_87_第 121.341 条_(a)', np.float64(0.583919364702789)),
#  ('file2_87_第 121.341 条_(b)', np.float64(0.5534207598585301)),
#  ('file2_89_第 121.345 条_(a)', np.float64(0.6301634313894849)),
#  ('file2_89_第 121.345 条_(b)', np.float64(0.5193125098502197)),
#  ('file2_89_第 121.345 条_(c)', np.float64(0.5408650530914627)),
#  ('file2_91_第 121.347 条_(a)', np.float64(0.5991081784210495)),
#  ('file2_91_第 121.347 条_(b)', np.float64(0.6366614735049989)),
#  ('file2_91_第 121.347 条_(c)', np.float64(0.585894447762666)),
#  ('file2_91_第 121.347 条_(d)', np.float64(0.6046565322694122)),
#  ('file2_92_第 121.349 条_(a)', np.float64(0.6177942893857513)),
#  ('file2_92_第 121.349 条_(b)', np.float64(0.507980005860026)),
#  ('file2_92_第 121.349 条_(c)', np.float64(0.6497173875344199)),
#  ('file2_92_第 121.349 条_(d)', np.float64(0.6145844957105386)),
#  ('file2_93_第 121.351 条_(a)', np.float64(0.5981181629463368)),
#  ('file2_93_第 121.351 条_(b)', np.float64(0.615301228165659)),
#  ('file2_93_第 121.351 条_(c)', np.float64(0.6678485239877081)),
#  ('file2_94_第 121.352 条_(a)', np.float64(0.5788242384653074)),
#  ('file2_94_第 121.352 条_(b)', np.float64(0.5978307172580376)),
#  ('file2_94_第 121.352 条_(c)', np.float64(0.44915925066480084)),
#  ('file2_94_第 121.352 条_(d)', np.float64(0.6363984605018763)),
#  ('file2_95_第 121.353 条_(a)', np.float64(0.5921414624362191)),
#  ('file2_95_第 121.353 条_(b)', np.float64(0.5976031718747121)),
#  ('file2_95_第 121.353 条_(c)', np.float64(0.5927130002003134)),
#  ('file2_95_第 121.353 条_(d)', np.float64(0.6068740328933483)),
#  ('file2_96_第 121.354 条_(a)', np.float64(0.5416406418206476)),
#  ('file2_96_第 121.354 条_(b)', np.float64(0.5504766509592851)),
#  ('file2_96_第 121.354 条_(c)', np.float64(0.5292360714117889)),
#  ('file2_96_第 121.354 条_(d)', np.float64(0.3775206986844892)),
#  ('file2_97_第 121.355 条_(a)', np.float64(0.6129120610846424)),
#  ('file2_97_第 121.355 条_(b)', np.float64(0.6018038074452141)),
#  ('file2_98_第 121.356 条_(a)', np.float64(0.6347232909708767)),
#  ('file2_98_第 121.356 条_(b)', np.float64(0.609908978817833)),
#  ('file2_98_第 121.356 条_(c)', np.float64(0.5326174006525182)),
#  ('file2_98_第 121.356 条_(i)', np.float64(0.5967474975756215)),
#  ('file2_98_第 121.356 条_(d)', np.float64(0.4534733661140375)),
#  ('file2_99_第 121.357 条_(a)', np.float64(0.5881270336459662)),
#  ('file2_99_第 121.357 条_(b)', np.float64(0.5966877317444118)),
#  ('file2_99_第 121.357 条_(c)', np.float64(0.5904066913348791)),
#  ('file2_99_第 121.357 条_(d)', np.float64(0.2950457904950222)),
#  ('file2_101_第 121.359 条_(a)', np.float64(0.630465971737981)),
#  ('file2_101_第 121.359 条_(b)', np.float64(0.6334377270422857)),
#  ('file2_101_第 121.359 条_(c)', np.float64(0.5586502175934213)),
#  ('file2_101_第 121.359 条_(d)', np.float64(0.6147251328377497)),
#  ('file2_101_第 121.359 条_(e)', np.float64(0.6250118816178724)),
#  ('file2_101_第 121.359 条_(f)', np.float64(0.6167529614345878)),
#  ('file2_102_第 121.360 条_(a)', np.float64(0.6718466804135477)),
#  ('file2_102_第 121.360 条_(b)', np.float64(0.6442007568975102)),
#  ('file2_102_第 121.360 条_(c)', np.float64(0.6671890980319757)),
#  ('file2_102_第 121.360 条_(d)', np.float64(0.6218557885081969)),
#  ('file2_103_第 121.361 条_(a)', np.float64(0.45706944320039916)),
#  ('file2_103_第 121.361 条_(b)', np.float64(0.4524979393961223)),
#  ('file2_103_第 121.361 条_(c)', np.float64(0.5307896591087947)),
#  ('file2_104_第 121.362 条_(a)', np.float64(0.6078185796801271)),
#  ('file2_104_第 121.362 条_(b)', np.float64(0.5758971639564702)),
#  ('file2_104_第 121.362 条_(c)', np.float64(0.6189227201777839)),
#  ('file2_105_第 121.363 条_(a)', np.float64(0.6044282380407833)),
#  ('file2_105_第 121.363 条_(b)', np.float64(0.5918551110479419)),
#  ('file2_106_第 121.365 条_(a)', np.float64(0.5631485742744359)),
#  ('file2_106_第 121.365 条_(b)', np.float64(0.44591349908524114)),
#  ('file2_107_第 121.366 条_(a)', np.float64(0.3395595704588091)),
#  ('file2_107_第 121.366 条_(b)', np.float64(0.5119302919538691)),
#  ('file2_107_第 121.366 条_(c)', np.float64(0.4614640317063174)),
#  ('file2_107_第 121.366 条_(d)', np.float64(0.46382321930189546)),
#  ('file2_107_第 121.366 条_(e)', np.float64(0.3370392861118791)),
#  ('file2_108_第 121.367 条_(a)', np.float64(0.559023235778877)),
#  ('file2_108_第 121.367 条_(b)', np.float64(0.5034000429106181)),
#  ('file2_108_第 121.367 条_(c)', np.float64(0.5794835172321957)),
#  ('file2_108_第 121.367 条_(d)', np.float64(0.4606069012216613)),
#  ('file2_108_第 121.367 条_(e)', np.float64(0.5669829876969973)),
#  ('file2_108_第 121.367 条_(f)', np.float64(0.5573062065138856)),
#  ('file2_108_第 121.367 条_(g)', np.float64(0.564203390607999)),
#  ('file2_109_第 121.368 条_(a)', np.float64(0.5220102348983267)),
#  ('file2_109_第 121.368 条_(b)', np.float64(0.36155089198076157)),
#  ('file2_109_第 121.368 条_(c)', np.float64(0.527342881660065)),
#  ('file2_109_第 121.368 条_(d)', np.float64(0.3492039702529047)),
#  ('file2_109_第 121.368 条_(e)', np.float64(0.45805319136329)),
#  ('file2_110_第 121.371 条_(a)', np.float64(0.5098665111561592)),
#  ('file2_110_第 121.371 条_(b)', np.float64(0.5209738469806712)),
#  ('file2_111_第 121.372 条_(a)', np.float64(0.3832189541102336)),
#  ('file2_111_第 121.372 条_(b)', np.float64(0.4095386485200143)),
#  ('file2_111_第 121.372 条_(c)', np.float64(0.32605451230414007)),
#  ('file2_111_第 121.372 条_(d)', np.float64(0.365495362383259)),
#  ('file2_113_第 121.375 条_(a)', np.float64(0.7033963284959873)),
#  ('file2_113_第 121.375 条_(b)', np.float64(0.6545584403472235)),
#  ('file2_113_第 121.375 条_(c)', np.float64(0.6833795812794715)),
#  ('file2_113_第 121.375 条_(d)', np.float64(0.5894875382865128)),
#  ('file2_114_第 121.379 条_(a)', np.float64(0.637750674122225)),
#  ('file2_114_第 121.379 条_(b)', np.float64(0.6181697854172413)),
#  ('file2_114_第 121.379 条_(c)', np.float64(0.6731786683242594)),
#  ('file2_114_第 121.379 条_(d)', np.float64(0.6229776017675067)),
#  ('file2_115_第 121.380 条_(a)', np.float64(0.5772730009303387)),
#  ('file2_115_第 121.380 条_(i)', np.float64(0.47459975380381325)),
#  ('file2_115_第 121.380 条_(v)', np.float64(0.5289868574056112)),
#  ('file2_115_第 121.380 条_(b)', np.float64(0.595419258957488)),
#  ('file2_115_第 121.380 条_(c)', np.float64(0.3910391264682417)),
#  ('file2_115_第 121.380 条_(d)', np.float64(0.42528016591876483)),
#  ('file2_115_第 121.380 条_(e)', np.float64(0.5155210380331214)),
#  ('file2_115_第 121.380 条_(f)', np.float64(0.6103238654200032)),
#  ('file2_116_第 121.381 条_(a)', np.float64(0.6295117941188286)),
#  ('file2_116_第 121.381 条_(b)', np.float64(0.6271762818700167)),
#  ('file2_116_第 121.381 条_(c)', np.float64(0.5815054715634022)),
#  ('file2_117_第 121.383 条_(a)', np.float64(0.6587666818736118)),
#  ('file2_117_第 121.383 条_(b)', np.float64(0.6796382721430553)),
#  ('file2_117_第 121.383 条_(c)', np.float64(0.5959021263362889)),
#  ('file2_117_第 121.383 条_(d)', np.float64(0.6512234984130806)),
#  ('file2_119_第 121.391 条_(a)', np.float64(0.5110212432107649)),
#  ('file2_119_第 121.391 条_(b)', np.float64(0.569316875815575)),
#  ('file2_119_第 121.391 条_(c)', np.float64(0.5710905091057009)),
#  ('file2_119_第 121.391 条_(d)', np.float64(0.5725724465599041)),
#  ('file2_119_第 121.391 条_(e)', np.float64(0.5298463822559265)),
#  ('file2_119_第 121.391 条_(f)', np.float64(0.6091478056658771)),
#  ('file2_120_第 121.393 条_(a)', np.float64(0.6543663293292954)),
#  ('file2_120_第 121.393 条_(b)', np.float64(0.6154371731319633)),
#  ('file2_122_第 121.397 条_(a)', np.float64(0.5754469124370523)),
#  ('file2_122_第 121.397 条_(b)', np.float64(0.5527860175650188)),
#  ('file2_123_第 121.401 条_(a)', np.float64(0.6412820211003116)),
#  ('file2_123_第 121.401 条_(b)', np.float64(0.6065698667629004)),
#  ('file2_123_第 121.401 条_(c)', np.float64(0.6342462047313724)),
#  ('file2_123_第 121.401 条_(d)', np.float64(0.6334125795779776)),
#  ('file2_123_第 121.401 条_(e)', np.float64(0.5929809513382729)),
#  ('file2_124_第 121.402 条_(a)', np.float64(0.6602032373427292)),
#  ('file2_124_第 121.402 条_(b)', np.float64(0.6665995003166536)),
#  ('file2_125_第 121.403 条_(a)', np.float64(0.5749113484321667)),
#  ('file2_125_第 121.403 条_(b)', np.float64(0.527501693164252)),
#  ('file2_125_第 121.403 条_(c)', np.float64(0.5763877704736706)),
#  ('file2_126_第 121.405 条_(a)', np.float64(0.5176775402426175)),
#  ('file2_126_第 121.405 条_(b)', np.float64(0.4647365320407527)),
#  ('file2_126_第 121.405 条_(c)', np.float64(0.5046181054217184)),
#  ('file2_126_第 121.405 条_(d)', np.float64(0.4647254360809909)),
#  ('file2_126_第 121.405 条_(e)', np.float64(0.4977491989390735)),
#  ('file2_127_第 121.407 条_(a)', np.float64(0.7037078041041572)),
#  ('file2_127_第 121.407 条_(b)', np.float64(0.661425273916145)),
#  ('file2_127_第 121.407 条_(c)', np.float64(0.6915113233205595)),
#  ('file2_128_第 121.409 条_(a)', np.float64(0.6689501368792594)),
#  ('file2_128_第 121.409 条_(b)', np.float64(0.6682688283494447)),
#  ('file2_128_第 121.409 条_(c)', np.float64(0.6789120741937235)),
#  ('file2_128_第 121.409 条_(d)', np.float64(0.6580327090687144)),
#  ('file2_129_第 121.411 条_(a)', np.float64(0.5917091109492616)),
#  ('file2_129_第 121.411 条_(b)', np.float64(0.5896481622932482)),
#  ('file2_130_第 121.413 条_(a)', np.float64(0.5608296858445603)),
#  ('file2_130_第 121.413 条_(b)', np.float64(0.5508685594351114)),
#  ('file2_130_第 121.413 条_(c)', np.float64(0.6090690138284662)),
#  ('file2_130_第 121.413 条_(d)', np.float64(0.6038759185125473)),
#  ('file2_130_第 121.413 条_(e)', np.float64(0.5573310026293342)),
#  ('file2_131_第 121.415 条_(a)', np.float64(0.6149332919243944)),
#  ('file2_131_第 121.415 条_(i)', np.float64(0.5689247598698428)),
#  ('file2_131_第 121.415 条_(b)', np.float64(0.5867084190157643)),
#  ('file2_131_第 121.415 条_(c)', np.float64(0.6071215521913514)),
#  ('file2_131_第 121.415 条_(d)', np.float64(0.598853896744521)),
#  ('file2_131_第 121.415 条_(e)', np.float64(0.5735477227604746)),
#  ('file2_131_第 121.415 条_(f)', np.float64(0.5626892638094476)),
#  ('file2_131_第 121.415 条_(g)', np.float64(0.5663543066769794)),
#  ('file2_131_第 121.415 条_(h)', np.float64(0.5871773852722493)),
#  ('file2_132_第 121.417 条_(a)', np.float64(0.5981879242187272)),
#  ('file2_132_第 121.417 条_(b)', np.float64(0.6189391584078525)),
#  ('file2_132_第 121.417 条_(c)', np.float64(0.5755167795384653)),
#  ('file2_132_第 121.417 条_(i)', np.float64(0.5975826390878226)),
#  ('file2_133_第 121.419 条_(a)', np.float64(0.604792266378399)),
#  ('file2_133_第 121.419 条_(b)', np.float64(0.4415311301711305)),
#  ('file2_133_第 121.419 条_(i)', np.float64(0.5415391292873658)),
#  ('file2_133_第 121.419 条_(v)', np.float64(0.5952127988429581)),
#  ('file2_133_第 121.419 条_(c)', np.float64(0.5511487049508829)),
#  ('file2_133_第 121.419 条_(d)', np.float64(0.5194995588054602)),
#  ('file2_134_第 121.421 条_(a)', np.float64(0.52608231642668)),
#  ('file2_134_第 121.421 条_(b)', np.float64(0.561262066662829)),
#  ('file2_135_第 121.422 条_(a)', np.float64(0.5667087469370279)),
#  ('file2_135_第 121.422 条_(b)', np.float64(0.563563666075)),
#  ('file2_136_第 121.423 条_(a)', np.float64(0.49621494509674297)),
#  ('file2_136_第 121.423 条_(i)', np.float64(0.46052323327343075)),
#  ('file2_136_第 121.423 条_(v)', np.float64(0.6249402113552063)),
#  ('file2_136_第 121.423 条_(x)', np.float64(0.5628519755420991)),
#  ('file2_136_第 121.423 条_(b)', np.float64(0.5730511638905134)),
#  ('file2_137_第 121.429 条_(a)', np.float64(0.5101511413807113)),
#  ('file2_137_第 121.429 条_(i)', np.float64(0.5262257533862521)),
#  ('file2_137_第 121.429 条_(b)', np.float64(0.504485662782501)),
#  ('file2_137_第 121.429 条_(c)', np.float64(0.509260520160822)),
#  ('file2_138_第 121.431 条_(a)', np.float64(0.47895242886800937)),
#  ('file2_138_第 121.431 条_(i)', np.float64(0.49839278874256343)),
#  ('file2_138_第 121.431 条_(v)', np.float64(0.5847377988270761)),
#  ('file2_138_第 121.431 条_(b)', np.float64(0.5507897351784015)),
#  ('file2_138_第 121.431 条_(c)', np.float64(0.5012000728833378)),
#  ('file2_139_第 121.433 条_(a)', np.float64(0.6174093635844194)),
#  ('file2_139_第 121.433 条_(b)', np.float64(0.6586073763345316)),
#  ('file2_139_第 121.433 条_(c)', np.float64(0.6041371703011874)),
#  ('file2_139_第 121.433 条_(i)', np.float64(0.5325584163103587)),
#  ('file2_139_第 121.433 条_(d)', np.float64(0.6257553202607362)),
#  ('file2_140_第 121.435 条_(a)', np.float64(0.5330003229676654)),
#  ('file2_140_第 121.435 条_(i)', np.float64(0.5485349746345568)),
#  ('file2_140_第 121.435 条_(b)', np.float64(0.6157261072503472)),
#  ('file2_140_第 121.435 条_(c)', np.float64(0.5627805514548263)),
#  ('file2_141_第 121.439 条_(a)', np.float64(0.5309230603587968)),
#  ('file2_141_第 121.439 条_(b)', np.float64(0.593330983776764)),
#  ('file2_141_第 121.439 条_(c)', np.float64(0.569100419581585)),
#  ('file2_141_第 121.439 条_(i)', np.float64(0.44315181897439515)),
#  ('file2_141_第 121.439 条_(d)', np.float64(0.6276669963273791)),
#  ('file2_143_第 121.451 条_(a)', np.float64(0.576559384542691)),
#  ('file2_143_第 121.451 条_(b)', np.float64(0.679673401786292)),
#  ('file2_143_第 121.451 条_(c)', np.float64(0.6381669222797961)),
#  ('file2_144_第 121.453 条_(a)', np.float64(0.6281071329344133)),
#  ('file2_144_第 121.453 条_(b)', np.float64(0.5825016218196095)),
#  ('file2_145_第 121.455 条_(a)', np.float64(0.6418506099118205)),
#  ('file2_145_第 121.455 条_(b)', np.float64(0.6293339474743908)),
#  ('file2_145_第 121.455 条_(c)', np.float64(0.6139949602889133)),
#  ('file2_145_第 121.455 条_(d)', np.float64(0.6342928029982903)),
#  ('file2_145_第 121.455 条_(e)', np.float64(0.6446957248939926)),
#  ('file2_145_第 121.455 条_(f)', np.float64(0.6371207305016369)),
#  ('file2_145_第 121.455 条_(g)', np.float64(0.6182496833362391)),
#  ('file2_146_第 121.457 条_(a)', np.float64(0.6054775456128281)),
#  ('file2_146_第 121.457 条_(b)', np.float64(0.6469055294546048)),
#  ('file2_146_第 121.457 条_(c)', np.float64(0.6005818698229324)),
#  ('file2_146_第 121.457 条_(i)', np.float64(0.6092349366382889)),
#  ('file2_146_第 121.457 条_(d)', np.float64(0.5436059066749388)),
#  ('file2_146_第 121.457 条_(e)', np.float64(0.5673077215396977)),
#  ('file2_146_第 121.457 条_(f)', np.float64(0.5881591587497578)),
#  ('file2_147_第 121.459 条_(a)', np.float64(0.6485892378074702)),
#  ('file2_147_第 121.459 条_(b)', np.float64(0.6192602222328393)),
#  ('file2_147_第 121.459 条_(c)', np.float64(0.5575623803247289)),
#  ('file2_148_第 121.461 条_(a)', np.float64(0.6354682870957568)),
#  ('file2_148_第 121.461 条_(b)', np.float64(0.6622736902952809)),
#  ('file2_148_第 121.461 条_(c)', np.float64(0.6386527583380935)),
#  ('file2_148_第 121.461 条_(d)', np.float64(0.6109647377103785)),
#  ('file2_149_第 121.463 条_(a)', np.float64(0.610897923860382)),
#  ('file2_149_第 121.463 条_(b)', np.float64(0.6761246379950928)),
#  ('file2_150_第 121.465 条_(a)', np.float64(0.6322509912493594)),
#  ('file2_150_第 121.465 条_(b)', np.float64(0.5205679702311192)),
#  ('file2_150_第 121.465 条_(c)', np.float64(0.594658617880736)),
#  ('file2_150_第 121.465 条_(d)', np.float64(0.6416547652743264)),
#  ('file2_150_第 121.465 条_(e)', np.float64(0.49103388500800504)),
#  ('file2_151_第 121.467 条_(a)', np.float64(0.6510760336463346)),
#  ('file2_151_第 121.467 条_(b)', np.float64(0.6862762285742308)),
#  ('file2_152_第 121.469 条_(a)', np.float64(0.6317110133085724)),
#  ('file2_152_第 121.469 条_(b)', np.float64(0.6544110515768976)),
#  ('file2_152_第 121.469 条_(c)', np.float64(0.6032848003062273)),
#  ('file2_153_第 121.471 条_(a)', np.float64(0.5267583046886425)),
#  ('file2_153_第 121.471 条_(b)', np.float64(0.5356596447679184)),
#  ('file2_153_第 121.471 条_(c)', np.float64(0.5475682162008302)),
#  ('file2_154_第 121.475 条_(a)', np.float64(0.4630201678189006)),
#  ('file2_154_第 121.475 条_(b)', np.float64(0.47515467902803604)),
#  ('file2_155_第 121.477 条_(a)', np.float64(0.5766995050523548)),
#  ('file2_155_第 121.477 条_(b)', np.float64(0.535759797423102)),
#  ('file2_156_第 121.479 条_(a)', np.float64(0.5831408567240132)),
#  ('file2_156_第 121.479 条_(b)', np.float64(0.6010349189128729)),
#  ('file2_157_第 121.481 条_(a)', np.float64(0.5917845393326767)),
#  ('file2_157_第 121.481 条_(b)', np.float64(0.5471101413176249)),
#  ('file2_157_第 121.481 条_(c)', np.float64(0.5503507029326894)),
#  ('file2_157_第 121.481 条_(i)', np.float64(0.5631693282944994)),
#  ('file2_157_第 121.481 条_(d)', np.float64(0.3540225825257833)),
#  ('file2_158_第 121.483 条_(a)', np.float64(0.5674615821242548)),
#  ('file2_158_第 121.483 条_(b)', np.float64(0.6802517072349793)),
#  ('file2_158_第 121.483 条_(c)', np.float64(0.6039607776658311)),
#  ('file2_158_第 121.483 条_(d)', np.float64(0.645447423322207)),
#  ('file2_159_第 121.485 条_(a)', np.float64(0.5758972797638509)),
#  ('file2_159_第 121.485 条_(b)', np.float64(0.6084447653522973)),
#  ('file2_159_第 121.485 条_(c)', np.float64(0.6182365473068283)),
#  ('file2_159_第 121.485 条_(i)', np.float64(0.601306850991637)),
#  ('file2_159_第 121.485 条_(d)', np.float64(0.6224630842084293)),
#  ('file2_160_第 121.487 条_(a)', np.float64(0.643980789628631)),
#  ('file2_160_第 121.487 条_(b)', np.float64(0.6128519812225406)),
#  ('file2_160_第 121.487 条_(c)', np.float64(0.611371213868389)),
#  ('file2_161_第 121.491 条_(a)', np.float64(0.5162545414846298)),
#  ('file2_161_第 121.491 条_(b)', np.float64(0.5096521711147471)),
#  ('file2_161_第 121.491 条_(c)', np.float64(0.5865420522450824)),
#  ('file2_162_第 121.493 条_(a)', np.float64(0.5938026288938517)),
#  ('file2_162_第 121.493 条_(b)', np.float64(0.5133999275875808)),
#  ('file2_162_第 121.493 条_(c)', np.float64(0.5146409719364847)),
#  ('file2_162_第 121.493 条_(d)', np.float64(0.525195748043515)),
#  ('file2_163_第 121.495 条_(a)', np.float64(0.5189789966328823)),
#  ('file2_163_第 121.495 条_(b)', np.float64(0.5661355601568417)),
#  ('file2_163_第 121.495 条_(c)', np.float64(0.5583113981906627)),
#  ('file2_163_第 121.495 条_(d)', np.float64(0.6091868547367595)),
#  ('file2_163_第 121.495 条_(e)', np.float64(0.5025674902873446)),
#  ('file2_164_第 121.501 条_(a)', np.float64(0.5914852350422173)),
#  ('file2_164_第 121.501 条_(b)', np.float64(0.5367795271560546)),
#  ('file2_164_第 121.501 条_(c)', np.float64(0.5163667285362011)),
#  ('file2_164_第 121.501 条_(d)', np.float64(0.5821048927338146)),
#  ('file2_164_第 121.501 条_(e)', np.float64(0.5204504764440997)),
#  ('file2_164_第 121.501 条_(i)', np.float64(0.4951712846784845)),
#  ('file2_164_第 121.501 条_(f)', np.float64(0.6189498976840329)),
#  ('file2_165_第 121.503 条_(a)', np.float64(0.4981259955225725)),
#  ('file2_165_第 121.503 条_(b)', np.float64(0.487729710596656)),
#  ('file2_165_第 121.503 条_(c)', np.float64(0.5046696808711177)),
#  ('file2_166_第 121.504 条_(a)', np.float64(0.5886785314309481)),
#  ('file2_166_第 121.504 条_(b)', np.float64(0.489625764779863)),
#  ('file2_166_第 121.504 条_(c)', np.float64(0.4781601470393542)),
#  ('file2_167_第 121.505 条_(a)', np.float64(0.5752051851486316)),
#  ('file2_167_第 121.505 条_(b)', np.float64(0.5198296291066077)),
#  ('file2_167_第 121.505 条_(c)', np.float64(0.5802469015476968)),
#  ('file2_167_第 121.505 条_(d)', np.float64(0.4444012788821273)),
#  ('file2_167_第 121.505 条_(e)', np.float64(0.3854498850066833)),
#  ('file2_168_第 121.506 条_(a)', np.float64(0.40124950528668735)),
#  ('file2_168_第 121.506 条_(b)', np.float64(0.38496379331433067)),
#  ('file2_170_第 121.508 条_(a)', np.float64(0.42809070843963076)),
#  ('file2_170_第 121.508 条_(b)', np.float64(0.4684687294771988)),
#  ('file2_170_第 121.508 条_(i)', np.float64(0.40570051840913895)),
#  ('file2_170_第 121.508 条_(v)', np.float64(0.5174064670371638)),
#  ('file2_170_第 121.508 条_(c)', np.float64(0.4365229248880902)),
#  ('file2_170_第 121.508 条_(d)', np.float64(0.4813522566975999)),
#  ('file2_170_第 121.508 条_(e)', np.float64(0.5932151582008575)),
#  ('file2_171_第 121.509 条_(a)', np.float64(0.41517319301749805)),
#  ('file2_171_第 121.509 条_(b)', np.float64(0.5233775642296274)),
#  ('file2_171_第 121.509 条_(c)', np.float64(0.5202630018699708)),
#  ('file2_171_第 121.509 条_(d)', np.float64(0.5009184809438896)),
#  ('file2_172_第 121.510 条_(a)', np.float64(0.38421310103526285)),
#  ('file2_172_第 121.510 条_(b)', np.float64(0.5517186553835022)),
#  ('file2_172_第 121.510 条_(c)', np.float64(0.5307773682915056)),
#  ('file2_172_第 121.510 条_(d)', np.float64(0.5606522567775445)),
#  ('file2_173_第 121.511 条_(a)', np.float64(0.48462054053079107)),
#  ('file2_173_第 121.511 条_(i)', np.float64(0.5631204590398602)),
#  ('file2_173_第 121.511 条_(b)', np.float64(0.5392544794165632)),
#  ('file2_173_第 121.511 条_(c)', np.float64(0.5366403169899391)),
#  ('file2_173_第 121.511 条_(d)', np.float64(0.44136720278720765)),
#  ('file2_173_第 121.511 条_(e)', np.float64(0.5277446527768876)),
#  ('file2_175_第 121.513 条_(a)', np.float64(0.5289386550383236)),
#  ('file2_175_第 121.513 条_(b)', np.float64(0.5111063638147938)),
#  ('file2_175_第 121.513 条_(c)', np.float64(0.550248306940139)),
#  ('file2_175_第 121.513 条_(d)', np.float64(0.4982865492220892)),
#  ('file2_175_第 121.513 条_(e)', np.float64(0.5051287326177715)),
#  ('file2_176_第 121.514 条_(a)', np.float64(0.6295289233499263)),
#  ('file2_176_第 121.514 条_(b)', np.float64(0.559103172751448)),
#  ('file2_177_第 121.515 条_(a)', np.float64(0.5831956053199426)),
#  ('file2_177_第 121.515 条_(b)', np.float64(0.6625237828239965)),
#  ('file2_179_第 121.519 条_(a)', np.float64(0.6420794340461488)),
#  ('file2_179_第 121.519 条_(b)', np.float64(0.6774043199709996)),
#  ('file2_179_第 121.519 条_(c)', np.float64(0.526285609718559)),
#  ('file2_180_第 121.521 条_(a)', np.float64(0.5962264351121637)),
#  ('file2_180_第 121.521 条_(b)', np.float64(0.5322176267924281)),
#  ('file2_180_第 121.521 条_(i)', np.float64(0.5943010458665677)),
#  ('file2_180_第 121.521 条_(v)', np.float64(0.5269006566227828)),
#  ('file2_181_第 121.523 条_(a)', np.float64(0.5296409997201136)),
#  ('file2_181_第 121.523 条_(b)', np.float64(0.5491317111031608)),
#  ('file2_181_第 121.523 条_(i)', np.float64(0.5859411118952751)),
#  ('file2_181_第 121.523 条_(v)', np.float64(0.2874827313894728)),
#  ('file2_182_第 121.525 条_(a)', np.float64(0.5557793373223443)),
#  ('file2_182_第 121.525 条_(b)', np.float64(0.5305545494371563)),
#  ('file2_182_第 121.525 条_(i)', np.float64(0.5858047925522506)),
#  ('file2_182_第 121.525 条_(v)', np.float64(0.4272898170697592)),
#  ('file2_183_第 121.526 条_(a)', np.float64(0.4982199447479539)),
#  ('file2_183_第 121.526 条_(b)', np.float64(0.5572796280155439)),
#  ('file2_184_第 121.527 条_(a)', np.float64(0.5922792316957711)),
#  ('file2_184_第 121.527 条_(b)', np.float64(0.5806242073425393)),
#  ('file2_184_第 121.527 条_(c)', np.float64(0.5779733108954339)),
#  ('file2_184_第 121.527 条_(d)', np.float64(0.5778597085056689)),
#  ('file2_184_第 121.527 条_(e)', np.float64(0.5804352900675486)),
#  ('file2_184_第 121.527 条_(f)', np.float64(0.5600644918809299)),
#  ('file2_184_第 121.527 条_(g)', np.float64(0.5914335898199664)),
#  ('file2_185_第 121.529 条_(a)', np.float64(0.5904430949205282)),
#  ('file2_185_第 121.529 条_(b)', np.float64(0.5212530159823646)),
#  ('file2_186_第 121.530 条_(a)', np.float64(0.5228524945693838)),
#  ('file2_186_第 121.530 条_(b)', np.float64(0.5854941385708882)),
#  ('file2_186_第 121.530 条_(c)', np.float64(0.6107376181237703)),
#  ('file2_187_第 121.531 条_(a)', np.float64(0.5736152479026126)),
#  ('file2_187_第 121.531 条_(b)', np.float64(0.6198935549835083)),
#  ('file2_187_第 121.531 条_(c)', np.float64(0.5204352850538186)),
#  ('file2_187_第 121.531 条_(i)', np.float64(0.6621079304193765)),
#  ('file2_187_第 121.531 条_(d)', np.float64(0.5449499658761326)),
#  ('file2_187_第 121.531 条_(e)', np.float64(0.636620004545592)),
#  ('file2_187_第 121.531 条_(f)', np.float64(0.6192086508142307)),
#  ('file2_188_第 121.532 条_(a)', np.float64(0.4802615515348008)),
#  ('file2_188_第 121.532 条_(b)', np.float64(0.604287220483325)),
#  ('file2_188_第 121.532 条_(c)', np.float64(0.6036998031024443)),
#  ('file2_188_第 121.532 条_(d)', np.float64(0.626412400228344)),
#  ('file2_188_第 121.532 条_(e)', np.float64(0.6096588319473841)),
#  ('file2_188_第 121.532 条_(f)', np.float64(0.6335258726245022)),
#  ('file2_189_第 121.533 条_(a)', np.float64(0.6627781761600382)),
#  ('file2_189_第 121.533 条_(b)', np.float64(0.6962601254537681)),
#  ('file2_189_第 121.533 条_(c)', np.float64(0.5781898284393219)),
#  ('file2_194_第 121.539 条_(a)', np.float64(0.5939647560341352)),
#  ('file2_194_第 121.539 条_(b)', np.float64(0.621106627477965)),
#  ('file2_194_第 121.539 条_(c)', np.float64(0.6180504105202375)),
#  ('file2_194_第 121.539 条_(d)', np.float64(0.6337840680266047)),
#  ('file2_194_第 121.539 条_(e)', np.float64(0.6431201991942875)),
#  ('file2_195_第 121.541 条_(a)', np.float64(0.6364092910700083)),
#  ('file2_195_第 121.541 条_(b)', np.float64(0.6306342174222221)),
#  ('file2_195_第 121.541 条_(i)', np.float64(0.6147833353469329)),
#  ('file2_195_第 121.541 条_(c)', np.float64(0.6450107837185042)),
#  ('file2_196_第 121.543 条_(a)', np.float64(0.730772078551894)),
#  ('file2_196_第 121.543 条_(b)', np.float64(0.7120592740847284)),
#  ('file2_196_第 121.543 条_(c)', np.float64(0.7320239013351145)),
#  ('file2_197_第 121.545 条_(a)', np.float64(0.620380730507131)),
#  ('file2_197_第 121.545 条_(b)', np.float64(0.6787020122397315)),
#  ('file2_199_第 121.549 条_(a)', np.float64(0.6078871808055742)),
#  ('file2_199_第 121.549 条_(b)', np.float64(0.5403585912345358)),
#  ('file2_200_第 121.550 条_(a)', np.float64(0.6050484025884377)),
#  ('file2_200_第 121.550 条_(b)', np.float64(0.621931392481451)),
#  ('file2_200_第 121.550 条_(c)', np.float64(0.6480874696908063)),
#  ('file2_200_第 121.550 条_(d)', np.float64(0.5694537868624466)),
#  ('file2_200_第 121.550 条_(i)', np.float64(0.5604493222619557)),
#  ('file2_203_第 121.553 条_(a)', np.float64(0.7114789505802904)),
#  ('file2_203_第 121.553 条_(b)', np.float64(0.6914966224660419)),
#  ('file2_205_第 121.555 条_(a)', np.float64(0.602922957459238)),
#  ('file2_205_第 121.555 条_(b)', np.float64(0.5673676827254407)),
#  ('file2_205_第 121.555 条_(c)', np.float64(0.5538979453960124)),
#  ('file2_205_第 121.555 条_(d)', np.float64(0.5843577517790676)),
#  ('file2_205_第 121.555 条_(e)', np.float64(0.4826464927980347)),
#  ('file2_205_第 121.555 条_(f)', np.float64(0.536755303890293)),
#  ('file2_206_第 121.556 条_(a)', np.float64(0.5980906396783086)),
#  ('file2_206_第 121.556 条_(b)', np.float64(0.5600358821930085)),
#  ...]

# %%
# 选取Top5相似度, 且 相似度分数超过阈值
def get_top_n_simi(simi_res, n, threshold=0):
    top5_simi_res = {}
    for k in simi_res:
        tmp = [tup for tup in simi_res[k] if tup[1] >= threshold] # 超过阈值
        if len(tmp) > 0:
            top5_simi_res[k] = sorted(tmp, key=lambda x: x[1], reverse=True)[:n] # top N
    return top5_simi_res

# %%
N = 5
simi_threshold = 0.75 # 阈值经过探索，设置为0.75
top_simi_result = get_top_n_simi(simi_result, N, simi_threshold)

# %%
len(top_simi_result)
# Out:
# 105

# %%
top_simi_result
# Out:
# {'file1_4_2.3.': [('file2_252_第 121.645 条_(b)',
#    np.float64(0.7568556627714138)),
#   ('file2_208_第 121.558 条_(b)', np.float64(0.7524038057288005))],
#  'file1_6_3.1.': [('file2_241_第 121.626 条_(a)',
#    np.float64(0.7612133615855393)),
#   ('file2_41_第 121.125 条_(i)', np.float64(0.7608692729072081))],
#  'file1_7_3.2.': [('file2_74_第 121.315 条_(c)', np.float64(0.7796067931480871)),
#   ('file2_252_第 121.645 条_(b)', np.float64(0.7650739153633003)),
#   ('file2_74_第 121.315 条_(a)', np.float64(0.7615417012539096)),
#   ('file2_74_第 121.315 条', np.float64(0.7573186895695658)),
#   ('file2_149_第 121.463 条_(b)', np.float64(0.7564717334011755))],
#  'file1_15_4.2.': [('file2_196_第 121.543 条_(c)',
#    np.float64(0.7604449879889185)),
#   ('file2_196_第 121.543 条_(b)', np.float64(0.7510546607625672))],
#  'file1_30_8.2.': [('file2_194_第 121.539 条_(a)',
#    np.float64(0.8448445016424574)),
#   ('file2_194_第 121.539 条_(d)', np.float64(0.8210113699547629)),
#   ('file2_194_第 121.539 条_(b)', np.float64(0.8184732490636305)),
#   ('file2_194_第 121.539 条_(c)', np.float64(0.8165953461144893)),
#   ('file2_194_第 121.539 条', np.float64(0.7977028009516467))],
#  'file1_31_8.3.': [('file2_194_第 121.539 条_(b)',
#    np.float64(0.9272316080120245)),
#   ('file2_194_第 121.539 条_(d)', np.float64(0.8087201191878307)),
#   ('file2_194_第 121.539 条', np.float64(0.7938932212947656)),
#   ('file2_195_第 121.541 条', np.float64(0.7866607753010084)),
#   ('file2_194_第 121.539 条_(c)', np.float64(0.7618616954379221))],
#  'file1_32_8.4.': [('file2_70_第 121.311 条_(i)',
#    np.float64(0.8066416848180118)),
#   ('file2_119_第 121.391 条_(f)', np.float64(0.8038419715212602)),
#   ('file2_194_第 121.539 条_(c)', np.float64(0.7931196630428919)),
#   ('file2_195_第 121.541 条_(a)', np.float64(0.7770916459156824)),
#   ('file2_70_第 121.311 条_(h)', np.float64(0.772923643603916))],
#  'file1_34_8.6.': [('file2_194_第 121.539 条_(b)',
#    np.float64(0.750578633708929))],
#  'file1_36_8.8.': [('file2_119_第 121.391 条_(f)',
#    np.float64(0.9220491327427603)),
#   ('file2_194_第 121.539 条_(c)', np.float64(0.7778649830203069)),
#   ('file2_120_第 121.393 条_(b)', np.float64(0.7711425609473617)),
#   ('file2_70_第 121.311 条_(i)', np.float64(0.7685600080739262)),
#   ('file2_195_第 121.541 条', np.float64(0.7667023582462548))],
#  'file1_37_9.': [('file2_205_第 121.555 条_(c)', np.float64(0.837104595695654)),
#   ('file2_205_第 121.555 条_(b)', np.float64(0.8218058794169129)),
#   ('file2_41_第 121.125 条_(i)', np.float64(0.7880821448176301)),
#   ('file2_205_第 121.555 条_(d)', np.float64(0.7866600376959886)),
#   ('file2_205_第 121.555 条', np.float64(0.7636583040466002))],
#  'file1_40_9.3.': [('file2_205_第 121.555 条', np.float64(0.8134038955825915)),
#   ('file2_205_第 121.555 条_(d)', np.float64(0.8055151370384968)),
#   ('file2_205_第 121.555 条_(c)', np.float64(0.7659693696960946)),
#   ('file2_205_第 121.555 条_(b)', np.float64(0.7521904181688598))],
#  'file1_42_10.1.': [('file2_266_第 121.675 条', np.float64(0.9694591579359536)),
#   ('file2_262_第 121.667 条_(f)', np.float64(0.7802346808277423))],
#  'file1_44_10.3.': [('file2_262_第 121.667 条_(b)',
#    np.float64(0.7752545330020486)),
#   ('file2_262_第 121.667 条_(f)', np.float64(0.7654223931720726))],
#  'file1_45_10.4.': [('file2_262_第 121.667 条_(d)',
#    np.float64(0.7847620011986539)),
#   ('file2_263_第 121.669 条_(a)', np.float64(0.7685205288304858)),
#   ('file2_262_第 121.667 条_(e)', np.float64(0.7657448044127608)),
#   ('file2_262_第 121.667 条_(b)', np.float64(0.7610591676082615)),
#   ('file2_249_第 121.641 条_(i)', np.float64(0.7534628158646152))],
#  'file1_46_10.5.': [('file2_262_第 121.667 条_(i)',
#    np.float64(0.8107604754338554)),
#   ('file2_262_第 121.667 条_(e)', np.float64(0.7950562954614825)),
#   ('file2_262_第 121.667 条_(v)', np.float64(0.7608154992306467)),
#   ('file2_262_第 121.667 条_(d)', np.float64(0.7529598306583759)),
#   ('file2_262_第 121.667 条_(b)', np.float64(0.7511936045226917))],
#  'file1_53_11.6.': [('file2_265_第 121.673 条_(b)',
#    np.float64(0.7882309749996484)),
#   ('file2_265_第 121.673 条_(c)', np.float64(0.786347697812375)),
#   ('file2_257_第 121.655 条_(b)', np.float64(0.7576762821814075)),
#   ('file2_265_第 121.673 条', np.float64(0.7551816361937946))],
#  'file1_55_11.8.': [('file2_265_第 121.673 条_(c)',
#    np.float64(0.7970476382016674)),
#   ('file2_265_第 121.673 条_(b)', np.float64(0.7632535958145888)),
#   ('file2_265_第 121.673 条', np.float64(0.753940732207383))],
#  'file1_58_12.1.': [('file2_195_第 121.541 条_(a)',
#    np.float64(0.7628518430608411)),
#   ('file2_120_第 121.393 条_(a)', np.float64(0.7535644808313658))],
#  'file1_60_13.': [('file2_231_第 121.597 条_(a)', np.float64(0.813621750591323)),
#   ('file2_231_第 121.597 条_(b)', np.float64(0.759537084910664))],
#  'file1_61_13.1.': [('file2_76_第 121.317 条_(h)',
#    np.float64(0.8903787758206243)),
#   ('file2_231_第 121.597 条', np.float64(0.8635970292521777)),
#   ('file2_231_第 121.597 条_(b)', np.float64(0.8476290900907347)),
#   ('file2_76_第 121.317 条_(e)', np.float64(0.8332357784075998)),
#   ('file2_231_第 121.597 条_(a)', np.float64(0.8271688588029226))],
#  'file1_62_13.2.': [('file2_231_第 121.597 条_(c)',
#    np.float64(0.8587631630955409)),
#   ('file2_231_第 121.597 条', np.float64(0.8055975592342046)),
#   ('file2_194_第 121.539 条_(b)', np.float64(0.7848743106771543)),
#   ('file2_218_第 121.575 条_(b)', np.float64(0.782237715261888)),
#   ('file2_67_第 121.308 条_(a)', np.float64(0.7670200897829801))],
#  'file1_64_1.1.': [('file2_196_第 121.543 条_(b)',
#    np.float64(0.9577037125247999)),
#   ('file2_196_第 121.543 条', np.float64(0.9433975678019906)),
#   ('file2_196_第 121.543 条_(c)', np.float64(0.927460859277009)),
#   ('file2_196_第 121.543 条_(a)', np.float64(0.905393229841884)),
#   ('file2_197_第 121.545 条_(b)', np.float64(0.7876857832437149))],
#  'file1_67_1.4.': [('file2_147_第 121.459 条_(a)',
#    np.float64(0.8320789625967439)),
#   ('file2_196_第 121.543 条_(b)', np.float64(0.7968902918584175)),
#   ('file2_196_第 121.543 条', np.float64(0.7926528629444806)),
#   ('file2_196_第 121.543 条_(c)', np.float64(0.7875171017366828)),
#   ('file2_196_第 121.543 条_(a)', np.float64(0.769734664255791))],
#  'file1_70_2.1.': [('file2_265_第 121.673 条_(c)',
#    np.float64(0.7904161830590652)),
#   ('file2_265_第 121.673 条_(b)', np.float64(0.7623615001518502)),
#   ('file2_257_第 121.655 条_(b)', np.float64(0.7502630648327734))],
#  'file1_71_2.2.': [('file2_265_第 121.673 条_(c)',
#    np.float64(0.772135189288485)),
#   ('file2_265_第 121.673 条_(b)', np.float64(0.7716034700287134))],
#  'file1_80_4.2.': [('file2_141_第 121.439 条_(a)',
#    np.float64(0.7553684012583126))],
#  'file1_86_5.1.': [('file2_211_第 121.563 条', np.float64(0.7933188481687585)),
#   ('file2_262_第 121.667 条_(f)', np.float64(0.7870104201323836)),
#   ('file2_262_第 121.667 条_(g)', np.float64(0.777618535330974)),
#   ('file2_262_第 121.667 条_(b)', np.float64(0.7759126971685729)),
#   ('file2_262_第 121.667 条_(e)', np.float64(0.7634703712614902))],
#  'file1_87_5.2.': [('file2_266_第 121.675 条', np.float64(0.8447380338597978)),
#   ('file2_262_第 121.667 条_(f)', np.float64(0.7991538703721613)),
#   ('file2_262_第 121.667 条_(b)', np.float64(0.7745029219676723)),
#   ('file2_262_第 121.667 条_(d)', np.float64(0.772928930852772)),
#   ('file2_248_第 121.639 条_(i)', np.float64(0.7609493474323165))],
#  'file1_92_6.2.': [('file2_93_第 121.351 条_(c)',
#    np.float64(0.7809955666170357)),
#   ('file2_92_第 121.349 条_(c)', np.float64(0.7731776810908799)),
#   ('file2_243_第 121.629 条_(a)', np.float64(0.7676998360344305)),
#   ('file2_72_第 121.313 条_(e)', np.float64(0.7665706138775193)),
#   ('file2_243_第 121.629 条', np.float64(0.7620914740187534))],
#  'file1_94_1.1.': [('file2_98_第 121.356 条_(b)',
#    np.float64(0.7588347786169105)),
#   ('file2_98_第 121.356 条_(a)', np.float64(0.7538641588822084))],
#  'file1_101_2.': [('file2_96_第 121.354 条_(d)',
#    np.float64(0.7835025417158917))],
#  'file1_102_2.1.': [('file2_96_第 121.354 条', np.float64(0.7679722441501141)),
#   ('file2_96_第 121.354 条_(b)', np.float64(0.754276421730386)),
#   ('file2_96_第 121.354 条_(a)', np.float64(0.7542294495037529))],
#  'file1_103_2.2.': [('file2_96_第 121.354 条_(b)',
#    np.float64(0.7544003410692953))],
#  'file1_105_3.1.': [('file2_225_第 121.587 条_(d)',
#    np.float64(0.788148034646126)),
#   ('file2_225_第 121.587 条_(a)', np.float64(0.7864998361286005))],
#  'file1_111_4.1.': [('file2_83_第 121.333 条_(i)',
#    np.float64(0.7713923992416852)),
#   ('file2_83_第 121.333 条_(c)', np.float64(0.7657688471414136)),
#   ('file2_83_第 121.333 条_(d)', np.float64(0.7648968949067505)),
#   ('file2_82_第 121.329 条_(c)', np.float64(0.7593563085943911)),
#   ('file2_83_第 121.333 条_(b)', np.float64(0.7505524663982275))],
#  'file1_113_4.3.': [('file2_85_第 121.337 条_(i)',
#    np.float64(0.7760600804594153)),
#   ('file2_85_第 121.337 条_(c)', np.float64(0.7734443500125519)),
#   ('file2_82_第 121.329 条_(b)', np.float64(0.7709135589407602)),
#   ('file2_82_第 121.329 条_(c)', np.float64(0.7663155706337486)),
#   ('file2_83_第 121.333 条_(i)', np.float64(0.7631003920843988))],
#  'file1_114_4.4.': [('file2_82_第 121.329 条_(b)',
#    np.float64(0.7589396403144033))],
#  'file1_115_4.5.': [('file2_82_第 121.329 条_(b)',
#    np.float64(0.8112072717845501))],
#  'file1_118_5.1.': [('file2_76_第 121.317 条_(b)',
#    np.float64(0.9330142788656693)),
#   ('file2_76_第 121.317 条_(c)', np.float64(0.7692857920486341))],
#  'file1_119_5.2.': [('file2_76_第 121.317 条_(b)',
#    np.float64(0.8263225572859606))],
#  'file1_120_5.3.': [('file2_76_第 121.317 条_(b)',
#    np.float64(0.8163152470899152))],
#  'file1_121_5.4.': [('file2_76_第 121.317 条_(b)',
#    np.float64(0.7689333005797125))],
#  'file1_123_6.1.': [('file2_194_第 121.539 条_(b)',
#    np.float64(0.7896405367584383)),
#   ('file2_194_第 121.539 条_(e)', np.float64(0.7766583198467957)),
#   ('file2_194_第 121.539 条_(d)', np.float64(0.7683652606377297)),
#   ('file2_163_第 121.495 条_(d)', np.float64(0.7617996589427731))],
#  'file1_124_6.2.': [('file2_194_第 121.539 条_(c)',
#    np.float64(0.8025106733514916)),
#   ('file2_241_第 121.626 条_(a)', np.float64(0.7886116841937955)),
#   ('file2_241_第 121.626 条_(b)', np.float64(0.7860238057539645)),
#   ('file2_194_第 121.539 条_(b)', np.float64(0.7748836029268976)),
#   ('file2_74_第 121.315 条_(b)', np.float64(0.7717306133831252))],
#  'file1_133_7.1.': [('file2_232_第 121.605 条', np.float64(0.846816173120676)),
#   ('file2_232_第 121.605 条_(a)', np.float64(0.8437326274990851)),
#   ('file2_232_第 121.605 条_(b)', np.float64(0.8168549459844437)),
#   ('file2_72_第 121.313 条_(i)', np.float64(0.7841289052832712)),
#   ('file2_72_第 121.313 条_(f)', np.float64(0.7729803966664731))],
#  'file1_134_7.2.': [('file2_232_第 121.605 条_(b)',
#    np.float64(0.8099156690517682)),
#   ('file2_232_第 121.605 条', np.float64(0.7624988753902211))],
#  'file1_136_1.1.': [('file2_195_第 121.541 条_(a)',
#    np.float64(0.9207257943753462)),
#   ('file2_195_第 121.541 条', np.float64(0.8185332234799646)),
#   ('file2_70_第 121.311 条_(h)', np.float64(0.8162065681293807)),
#   ('file2_70_第 121.311 条_(i)', np.float64(0.7992773593496312)),
#   ('file2_194_第 121.539 条_(b)', np.float64(0.7700854055265832))],
#  'file1_138_1.3.': [('file2_195_第 121.541 条_(b)',
#    np.float64(0.9047506548229806)),
#   ('file2_195_第 121.541 条_(i)', np.float64(0.8652267784127148)),
#   ('file2_195_第 121.541 条', np.float64(0.8520849498266495)),
#   ('file2_194_第 121.539 条_(b)', np.float64(0.8194642637579644)),
#   ('file2_143_第 121.451 条', np.float64(0.7825898708343293))],
#  'file1_140_2.1.': [('file2_197_第 121.545 条_(b)',
#    np.float64(0.8249108824982644)),
#   ('file2_197_第 121.545 条_(a)', np.float64(0.8196249280849991)),
#   ('file2_197_第 121.545 条', np.float64(0.8027057326861677)),
#   ('file2_120_第 121.393 条_(a)', np.float64(0.7622331860906012)),
#   ('file2_194_第 121.539 条_(b)', np.float64(0.7613547815343449))],
#  'file1_141_2.2.': [('file2_197_第 121.545 条_(a)',
#    np.float64(0.9151762246494037)),
#   ('file2_197_第 121.545 条', np.float64(0.895962921156286)),
#   ('file2_197_第 121.545 条_(b)', np.float64(0.8470843717339733))],
#  'file1_143_2.4.': [('file2_197_第 121.545 条_(b)',
#    np.float64(0.8471024998309223)),
#   ('file2_197_第 121.545 条', np.float64(0.8035206886543692)),
#   ('file2_197_第 121.545 条_(a)', np.float64(0.7931685411920607)),
#   ('file2_228_第 121.591 条_(e)', np.float64(0.7790915686875)),
#   ('file2_228_第 121.591 条_(b)', np.float64(0.7649648633897356))],
#  'file1_144_2.5.': [('file2_197_第 121.545 条_(b)',
#    np.float64(0.8105038533683723)),
#   ('file2_197_第 121.545 条_(a)', np.float64(0.809385013481647)),
#   ('file2_197_第 121.545 条', np.float64(0.8084331475062757)),
#   ('file2_120_第 121.393 条_(a)', np.float64(0.7942412175091025)),
#   ('file2_232_第 121.605 条', np.float64(0.7840925390618555))],
#  'file1_145_2.6.': [('file2_198_第 121.547 条', np.float64(0.861688598519306)),
#   ('file2_197_第 121.545 条_(b)', np.float64(0.8089987196729813)),
#   ('file2_196_第 121.543 条_(b)', np.float64(0.808998461633882)),
#   ('file2_197_第 121.545 条', np.float64(0.8011453030118295)),
#   ('file2_197_第 121.545 条_(a)', np.float64(0.7985892313683282))],
#  'file1_146_2.7.': [('file2_228_第 121.591 条_(e)',
#    np.float64(0.7788496813225328)),
#   ('file2_197_第 121.545 条_(a)', np.float64(0.7506704628307667))],
#  'file1_149_3.1.': [('file2_197_第 121.545 条_(b)',
#    np.float64(0.8541066626414866)),
#   ('file2_197_第 121.545 条', np.float64(0.8173716742921158)),
#   ('file2_197_第 121.545 条_(a)', np.float64(0.7676894781835887)),
#   ('file2_227_第 121.589 条', np.float64(0.7563769729791909))],
#  'file1_150_3.2.': [('file2_227_第 121.589 条_(b)',
#    np.float64(0.8334168407282599)),
#   ('file2_227_第 121.589 条', np.float64(0.7639498898703287))],
#  'file1_152_4.1.': [('file2_232_第 121.605 条_(a)',
#    np.float64(0.8264028095642336)),
#   ('file2_232_第 121.605 条', np.float64(0.8186298530226765)),
#   ('file2_232_第 121.605 条_(b)', np.float64(0.8029567329399937)),
#   ('file2_72_第 121.313 条_(i)', np.float64(0.7845186363004863)),
#   ('file2_72_第 121.313 条_(f)', np.float64(0.7668297122563791))],
#  'file1_153_4.2.': [('file2_232_第 121.605 条', np.float64(0.8214624149370192)),
#   ('file2_232_第 121.605 条_(a)', np.float64(0.8078856293756962)),
#   ('file2_232_第 121.605 条_(b)', np.float64(0.8065406142804484)),
#   ('file2_197_第 121.545 条', np.float64(0.7903916077977735)),
#   ('file2_197_第 121.545 条_(a)', np.float64(0.7886216700015961))],
#  'file1_157_5.2.': [('file2_195_第 121.541 条_(b)',
#    np.float64(0.8077501330376765))],
#  'file1_158_5.3.': [('file2_194_第 121.539 条_(b)',
#    np.float64(0.7822049600226277)),
#   ('file2_195_第 121.541 条', np.float64(0.7535744986295632)),
#   ('file2_194_第 121.539 条_(d)', np.float64(0.7533274743009473)),
#   ('file2_194_第 121.539 条_(c)', np.float64(0.7507234685827744))],
#  'file1_159_5.4.': [('file2_187_第 121.531 条_(e)',
#    np.float64(0.8152452829799902)),
#   ('file2_188_第 121.532 条_(d)', np.float64(0.8018404634491104)),
#   ('file2_196_第 121.543 条_(b)', np.float64(0.7704812579609068)),
#   ('file2_196_第 121.543 条_(c)', np.float64(0.7698661696460595)),
#   ('file2_195_第 121.541 条_(i)', np.float64(0.7684441778330109))],
#  'file1_160_5.5.': [('file2_195_第 121.541 条_(b)',
#    np.float64(0.7894029999179474)),
#   ('file2_194_第 121.539 条_(b)', np.float64(0.7604593158653878))],
#  'file1_161_5.6.': [('file2_194_第 121.539 条_(c)',
#    np.float64(0.7753325151275612)),
#   ('file2_119_第 121.391 条_(f)', np.float64(0.7627875850553499)),
#   ('file2_197_第 121.545 条_(b)', np.float64(0.7554036366744534)),
#   ('file2_214_第 121.569 条_(v)', np.float64(0.75043732046286))],
#  'file1_162_5.7.': [('file2_228_第 121.591 条_(e)',
#    np.float64(0.755464858468882)),
#   ('file2_197_第 121.545 条_(a)', np.float64(0.7519218306421903))],
#  'file1_163_6.': [('file2_222_第 121.581 条', np.float64(0.8189051019033391)),
#   ('file2_222_第 121.581 条_(a)', np.float64(0.8029980412135473)),
#   ('file2_233_第 121.607 条', np.float64(0.78696595229926)),
#   ('file2_74_第 121.315 条_(b)', np.float64(0.7857813264228062)),
#   ('file2_233_第 121.607 条_(f)', np.float64(0.7791326307128524))],
#  'file1_168_1.4.': [('file2_228_第 121.591 条_(e)',
#    np.float64(0.757809620662579))],
#  'file1_172_2.3.': [('file2_74_第 121.315 条_(b)',
#    np.float64(0.7628933066978288))],
#  'file1_177_3.3.': [('file2_41_第 121.125 条_(i)',
#    np.float64(0.7510239520109113))],
#  'file1_179_3.5.': [('file2_41_第 121.125 条_(i)',
#    np.float64(0.7539893465068935))],
#  'file1_182_3.8.': [('file2_116_第 121.381 条_(b)',
#    np.float64(0.7566568978743996))],
#  'file1_183_3.9.': [('file2_241_第 121.626 条_(b)',
#    np.float64(0.7670077651679439)),
#   ('file2_241_第 121.626 条_(a)', np.float64(0.7503458484824093))],
#  'file1_184_3.10.': [('file2_239_第 121.623 条_(b)',
#    np.float64(0.8027620915620557)),
#   ('file2_239_第 121.623 条', np.float64(0.7692835740893668))],
#  'file1_186_3.12.': [('file2_252_第 121.645 条_(b)',
#    np.float64(0.7536076805820213))],
#  'file1_188_3.14.': [('file2_240_第 121.625 条_(a)',
#    np.float64(0.7682756568495317)),
#   ('file2_267_第 121.677 条', np.float64(0.7564253757308771)),
#   ('file2_138_第 121.431 条_(v)', np.float64(0.7549768501231616)),
#   ('file2_240_第 121.625 条_(b)', np.float64(0.7536155893728438))],
#  'file1_189_3.15.': [('file2_133_第 121.419 条',
#    np.float64(0.7512829429156497))],
#  'file1_196_4.1.': [('file2_120_第 121.393 条_(a)',
#    np.float64(0.750539799713504))],
#  'file1_200_5.3.': [('file2_187_第 121.531 条_(i)',
#    np.float64(0.8098131813634992)),
#   ('file2_241_第 121.626 条_(a)', np.float64(0.8042721493028415)),
#   ('file2_241_第 121.626 条_(b)', np.float64(0.8042435978566028)),
#   ('file2_194_第 121.539 条_(c)', np.float64(0.7935430614065128)),
#   ('file2_187_第 121.531 条_(b)', np.float64(0.785201346437316))],
#  'file1_201_1.': [('file2_133_第 121.419 条_(a)',
#    np.float64(0.7809631403152553)),
#   ('file2_149_第 121.463 条_(b)', np.float64(0.7707776875669388)),
#   ('file2_208_第 121.558 条_(b)', np.float64(0.769311186144014)),
#   ('file2_252_第 121.645 条_(b)', np.float64(0.7673944819548886)),
#   ('file2_74_第 121.315 条_(b)', np.float64(0.7621871604847708))],
#  'file1_203_1.2.': [('file2_69_第 121.310 条_(l)',
#    np.float64(0.7508440969347959))],
#  'file1_204_1.3.': [('file2_253_第 121.647 条_(i)',
#    np.float64(0.7797203480792027)),
#   ('file2_252_第 121.645 条_(b)', np.float64(0.7784499967852403)),
#   ('file2_133_第 121.419 条_(a)', np.float64(0.7783259328361598)),
#   ('file2_208_第 121.558 条_(b)', np.float64(0.7737201503368961)),
#   ('file2_195_第 121.541 条', np.float64(0.7728168055887407))],
#  'file1_205_1.4.': [('file2_68_第 121.309 条_(b)',
#    np.float64(0.772921928761783)),
#   ('file2_253_第 121.647 条_(i)', np.float64(0.7606440915433357)),
#   ('file2_133_第 121.419 条_(a)', np.float64(0.7586879071336818)),
#   ('file2_195_第 121.541 条', np.float64(0.7569381686155248)),
#   ('file2_159_第 121.485 条_(c)', np.float64(0.7551933987015963))],
#  'file1_206_1.5.': [('file2_252_第 121.645 条_(b)',
#    np.float64(0.77370947711843)),
#   ('file2_253_第 121.647 条_(i)', np.float64(0.7709348403726103)),
#   ('file2_208_第 121.558 条_(b)', np.float64(0.7520858034479868))],
#  'file1_208_2.1.': [('file2_194_第 121.539 条_(c)',
#    np.float64(0.7868013571799738)),
#   ('file2_187_第 121.531 条_(d)', np.float64(0.7599845101121634))],
#  'file1_216_3.3.': [('file2_205_第 121.555 条_(b)',
#    np.float64(0.7560985576892711)),
#   ('file2_205_第 121.555 条', np.float64(0.7514958115287466))],
#  'file1_224_5.1.': [('file2_194_第 121.539 条_(c)',
#    np.float64(0.785500230794286)),
#   ('file2_119_第 121.391 条_(f)', np.float64(0.7668679569839867)),
#   ('file2_146_第 121.457 条_(e)', np.float64(0.7657922123762126)),
#   ('file2_155_第 121.477 条_(a)', np.float64(0.758201043534547)),
#   ('file2_155_第 121.477 条', np.float64(0.7563400719604444))],
#  'file1_225_5.2.': [('file2_222_第 121.581 条', np.float64(0.7667645782769611)),
#   ('file2_222_第 121.581 条_(a)', np.float64(0.7667645755358878))],
#  'file1_227_6.1.': [('file2_228_第 121.591 条_(e)',
#    np.float64(0.7658807238046426))],
#  'file1_229_6.3.': [('file2_119_第 121.391 条_(f)',
#    np.float64(0.7739535889533409))],
#  'file1_230_6.4.': [('file2_233_第 121.607 条_(a)',
#    np.float64(0.7704360779070497))],
#  'file1_231_6.5.': [('file2_194_第 121.539 条_(b)',
#    np.float64(0.7903935099347589)),
#   ('file2_194_第 121.539 条_(c)', np.float64(0.7612113939393295)),
#   ('file2_223_第 121.583 条_(b)', np.float64(0.7506792653378863))],
#  'file1_232_6.6.': [('file2_120_第 121.393 条_(b)',
#    np.float64(0.7587156922370116)),
#   ('file2_214_第 121.569 条_(i)', np.float64(0.7562342033750469)),
#   ('file2_252_第 121.645 条', np.float64(0.7505057265466402))],
#  'file1_233_6.7.': [('file2_252_第 121.645 条_(b)',
#    np.float64(0.7510615198985641))],
#  'file1_234_6.8.': [('file2_232_第 121.605 条_(b)',
#    np.float64(0.7770580735722614))],
#  'file1_239_1.4.': [('file2_232_第 121.605 条', np.float64(0.7565489725136577)),
#   ('file2_232_第 121.605 条_(b)', np.float64(0.7505892506782426))],
#  'file1_240_1.5.': [('file2_232_第 121.605 条_(b)',
#    np.float64(0.7651424847358191))],
#  'file1_251_1.2.': [('file2_195_第 121.541 条_(b)',
#    np.float64(0.7761356170295887)),
#   ('file2_252_第 121.645 条', np.float64(0.7732229975440145)),
#   ('file2_194_第 121.539 条_(c)', np.float64(0.7653563716094244)),
#   ('file2_194_第 121.539 条_(b)', np.float64(0.7612722841123063)),
#   ('file2_223_第 121.583 条_(b)', np.float64(0.7602848810713926))],
#  'file1_254_2.1.': [('file2_278_第 121.703 条', np.float64(0.7537050878029332))],
#  'file1_257_3.1.': [('file2_195_第 121.541 条_(b)',
#    np.float64(0.7823886069336202))],
#  'file1_258_3.2.': [('file2_195_第 121.541 条_(b)',
#    np.float64(0.7563094387426129))],
#  'file1_259_3.3.': [('file2_197_第 121.545 条', np.float64(0.7603376211230543)),
#   ('file2_194_第 121.539 条_(b)', np.float64(0.757716295871616)),
#   ('file2_195_第 121.541 条', np.float64(0.7524343546709429)),
#   ('file2_197_第 121.545 条_(b)', np.float64(0.7523446003111655))],
#  'file1_260_3.4.': [('file2_120_第 121.393 条_(b)',
#    np.float64(0.8067609816313516)),
#   ('file2_120_第 121.393 条_(a)', np.float64(0.7837050739818118)),
#   ('file2_120_第 121.393 条', np.float64(0.7790150696348364))],
#  'file1_261_3.5.': [('file2_120_第 121.393 条_(a)',
#    np.float64(0.8470624438778553)),
#   ('file2_120_第 121.393 条', np.float64(0.8383010643675186)),
#   ('file2_120_第 121.393 条_(b)', np.float64(0.8189542288153808)),
#   ('file2_119_第 121.391 条', np.float64(0.7594197784661022)),
#   ('file2_119_第 121.391 条_(b)', np.float64(0.7586320557995968))],
#  'file1_262_3.6.': [('file2_119_第 121.391 条_(f)',
#    np.float64(0.7628367398652744))],
#  'file1_264_4.1.': [('file2_74_第 121.315 条_(b)',
#    np.float64(0.7768245659797415))],
#  'file1_287_4.2.': [('file2_65_第 121.305 条_(k)',
#    np.float64(0.7516512040084569))]}

# %%
# # # 保存所有相似的文本到本地 进一步分析相似度阈值该设置多少
# import pandas as pd

# def save_simi_text_to_excel(top_n_simi_res, db_data, file_path):
#     paired_data = []
#     for key1 in top_n_simi_res:
#         for tup in top_n_simi_res[key1]:
#             key2 = tup[0]
#             score = tup[1]
#             if key1 in db_data and key2 in db_data:
#                 pair_row = (key1, key2, score, db_data[key1][0], db_data[key2][0])
#                 paired_data.append(pair_row)
#     paired_df = pd.DataFrame(paired_data, 
#                      columns=['upload_pdf_paragraph_key', 'db_stored_paragraph_key', 'simi_score', 'upload_pdf_paragraph', 'db_stored_paragraph'])
#     paired_df.to_excel(file_path)

# %%
# save_simi_text_to_excel(top_simi_result, embd_db_data, 'paired_paragraphs_0.0.xlsx')

# %%
# test_text1 = ('input1','除为避开其他航空器或者为改变飞行高度需要偏离航线的机动飞行外， 在任何 其他航线上，飞行机组应沿该航线的导航设施或者定位点之间的连线飞行。 （空白） 设备的使用')
# test_text2_list=[
#     ('output1', '通信和导航设施 (a)对于定期载客运行， 除本条(b)款规定外， 在每次飞行 前，只有确认在航路批准时本规则第121.97 条和第121.101 条所要求的通信设备和导航设施处于良好工作状态，方可以 签派飞机在该航路或者航段上飞行。 (b)对于定期载客运行， 如果由于超出合格证持有人控制 能力的技术原因或者其他原因，在航路上没有本规则第 121.97 条和第121.101 条所要求的设施或者设备不可用，只 要机长和飞行签派员认为现有的设施与航路所要求的通信 和导航设施等同并处于良好的工作状态，即可签派飞机在相 应航路或者航段上飞行。 (c)对于补充运行，只有当通信设备和导航设施满足本规 则第121.121 条规定时，方可以放行飞机。'),
# ]

# %%
# test_text1 = ('input1','这个周末我会去骑行游玩')
# test_text2_list=[
#     ('output1', 'XXXXXXXX'),
#     ('output2', 'YYYYYY'),
#     ('output3', 'XXXXX')
# ]

# %%
# get_top1_from_top5(test_text1, test_text2_list)

# %%
def get_simi_id_from_chat_answer(answer_str):
    target_line = '********************'
    simi_id_line = ''
    lines = answer_str.split('\n')
    for i, line in enumerate(lines):
        if line.strip() == target_line and i + 1 < len(lines):  # 确保不是最后一行
            simi_id_line = lines[i + 1].strip()
            break
    return simi_id_line

# %%
# 对于匹配好的top5相似度片段，生成prompt，确认最终的top1

from zhipuai import ZhipuAI

# 参数tuple格式， (key, text_content)
def get_top1_from_top5(text1_tuple, text2_tuple_list):
    client = ZhipuAI(api_key="0e059a59be0f37e58bbafe360f663b21.7G1ccHB6WZMFvfwu")

    prompt_str = ""
    for i in range(len(text2_tuple_list)):
        line = f"{i+1}. ID='{text2_tuple_list[i][0]}', content='{text2_tuple_list[i][1]}' ;\n"
        prompt_str = prompt_str + line
    # print(prompt_str)
    
    response = client.chat.completions.create(
        model="glm-4",  # 填写需要调用的模型名称
        messages=[
            {"role": "system", "content": "你是一名中国民用航空部门法规制定者，非常熟悉中国民用航空的规章制度，接下来我需要你根据 [输入规章A] ，判断该规章制度的内容与 [另外一些规章B] 中的哪一条含义类似"},
            {"role": "user", "content": """
                # 输入规章A: ID='I01', content='在飞行的关键阶段，全体机组成员不得从事飞机安全运行所必需的工作之外的任何其他工作，机组任何成员也不得承担这些工作。'
                # 另外一些规章B: 
                    1. ID='L01', content='机组成员的值勤要求 (a)在飞行的关键阶段，合格证持有人不得要求飞行机组 成员完成飞机安全运行所必需的工作之外的任何其他工作， 飞行机组任何成员也不得承担这些工作。';
                    2. ID='L02', content='在驾驶舱值勤的每个飞行机组必 需成员，在飞行过程中应当坐在指定的值勤位置并系好安全 带；在起飞和着陆过程中应当坐在指定的值勤位置并系好安全带和肩带';
                # 问题: 需要你从 [另外一些规章B] 中挑选出与 [输入规章A] content最为相似的那一个
                # 要求: 如果你找到相似的内容，严格按照下面的格式输出对应的ID；如果你认为没有找到请输出'未找到相似内容'
                # 输出: 
                ********************
                L01
                """},
            {"role": "assistant", "content": "当然可以，我可以通过语义分析、计算文本之间的相似度，来帮助你找到最相似的文本。"},
            {"role": "user", "content": f"""
                # 输入规章A: ID='{text1_tuple[0]}', content='{text1_tuple[1]}'
                # 另外一些规章B: 
                {prompt_str}
                # 问题: 需要你从 [另外一些规章B] 中挑选出与 [输入规章A] content最为相似的那一个
                # 要求: 
                    1. 如果你找到相似的content，严格按照下面的[输出] 输出ID, 不需要输出任何其他内容, 输出: 
                ********************
                ID  
                    2. 如果你认为没有找到相似的内容，请直接输出'未找到相似内容', 不需要输出任何其他内容, 输出:
                ********************
                未找到相似内容
            """},
        ],
    )
    answer_str = response.choices[0].message.content
    print(answer_str)
    most_simi_id = get_simi_id_from_chat_answer(answer_str)
    return most_simi_id

# %%
# 给所有达到相似度阈值的pair，生成最终的top1 pair
def get_top1_simi_result(top_n_simi_res, db_data):
    res = []
    for key1 in top_n_simi_res:
        text1 = db_data[key1][0]
        if len(top_n_simi_res[key1]) == 1: # 只有top1没有topN
            key2 = top_n_simi_res[key1][0][0]
            simi_score = top_n_simi_res[key1][0][1]
            text2 = db_data[key2][0]
            res.append((key1, text1, key2, text2, simi_score))
            continue
        text2_tuple_list = []
        for tup in top_n_simi_res[key1]:
            key2 = tup[0]
            simi_score = tup[1]
            text2 = db_data[key2][0]
            text2_tuple_list.append((key2, text2, simi_score))
        text1_tup = (key1, text1)
        most_simi_key2 = get_top1_from_top5(text1_tup, text2_tuple_list)
        #prompt 返回的最相似的key2需要验证一下
        if most_simi_key2 in [tup[0] for tup in top_n_simi_res[key1]]:
            res.append((key1, text1, most_simi_key2, db_data[most_simi_key2][0], simi_score))
    return res

# %%
top1_simi_result = get_top1_simi_result(top_simi_result, embd_db_data)
# Out:
# ********************
# file2_208_第 121.558 条_(b)
#
# 输入规章A强调的是在偏离标准操作程序时需要进行充分的沟通和风险评估。在规章B中，file2_208_第 121.558 条_(b)提到了在紧急情况下需要通知机长，并确保理解机长的决断，这与输入规章A中提到的沟通和评估风险有相似之处。而file2_252_第 121.645 条_(b)虽然提到了在特定设备失效时遵循经批准的程序，但并没有强调沟通和风险评估，因此与输入规章A的内容不如file2_208_相似。
# ********************
# 未找到相似内容
#
# 输入规章A提到的是关于检查单的配备和可用性，而规章B中的内容分别涉及机长获取飞行前信息的要求和飞行跟踪系统的功能，这两者与输入规章A的内容并不相似。
# ********************
# file2_74_第 121.315 条_(c)
# ********************
# 未找到相似内容
#
# 输入规章A强调的是在进行某些关键操作时，必须由另一名飞行机组人员确认后才能进行。而规章B中的内容主要涉及谁被允许控制操纵装置，并没有直接提到需要另一名机组人员确认的操作步骤。因此，根据提供的信息，没有找到与输入规章A内容最为相似的规章B。
# ********************
# file2_194_第 121.539 条_(a)
# ********************
# file2_194_第 121.539 条_(b)
# ********************
# file2_119_第 121.391 条_(f)
# ********************
# file2_119_第 121.391 条_(f)
# ********************
# file2_205_第 121.555 条_(b)
# ********************
# file2_205_第 121.555 条_(c)
#
# 输入规章A主要强调的是在发现燃油不正常状态时，应立即采取措施，并报告飞行签派员，以确保剩余油量不低于最后储备燃油量。在规章B中，file2_205_第 121.555 条_(c)部分也提到了类似的燃油管理措施，即如果燃油检查结果显示可能低于特定油量，机长需要评估各种条件以确保安全着陆时的燃油量不低于最后储备燃油量。这与输入规章A的内容最为相似。其他选项虽然也与燃油管理相关，但并不像file2_205_第 121.555 条_(c)这样直接对应于异常状态下的燃油管理。
# ********************
# file2_266_第 121.675 条
# ********************
# file2_262_第 121.667 条_(b)
# ********************
# file2_262_第 121.667 条_(d)
# ********************
# file2_262_第 121.667 条_(i)
# ********************
# file2_265_第 121.673 条_(b)
# ********************
# file2_265_第 121.673 条_(b)
#
# 输入规章A中提到的“机长在确定从飞机所处位置能进行稳定进近之前，不得下降低于着陆跑道接地区标高以上500英尺”与规章B中的file2_265_第121.673条_(b)中的“在昼间按照目视飞行规则运行时不得在距地表、山峰、丘陵或者其他障碍物300米(1000英尺)的高度以下飞行”有相似之处，都是在描述飞机在进近或飞行过程中的最低高度限制。虽然具体数值和条件不同，但都是在限制飞机在特定条件下的最低飞行高度。
# ********************
# file2_195_第 121.541 条_(a)
#
# 输入规章A中提到的内容主要涉及客舱乘务员在特定飞行阶段的安全要求，特别是关于在特定时间段内在规定席位上就坐并系紧安全带和肩带的规定。在规章B中，file2_195_第 121.541 条_(a)也提到了飞行机组在飞行过程中的座位安排和安全带的使用，尤其是在起飞和着陆过程中必须坐在指定的值勤位置并系好安全带和肩带。这两条规定在内容和目的上都有相似之处，都旨在确保飞行关键阶段机组人员的安全。
# ********************
# file2_231_第 121.597 条_(a)
# ********************
#
# 这条规章B的内容与输入规章A的“禁止吸烟的规定”直接相关，明确指出了“任何人不得在按照本规则运行的飞机上吸烟”，与输入规章A的含义非常相似。而另一条规章B则更多地描述了关于“禁止吸烟”告示信号灯的规定，虽然也与吸烟有关，但并不像第一条那样直接与输入规章A的内容相匹配。
# ********************
# file2_231_第 121.597 条
# ********************
# file2_231_第 121.597 条_(b)
#
# 输入规章A中提到的“禁止在航空器内吸烟”和“飞行机组应保持‘禁止吸烟’信号灯的接通”与规章B中的file2_231_第 121.597 条及其子条款(b)非常相似，都强调了飞机运行期间禁止吸烟的规定和必须保持“禁止吸烟”信号灯常亮的要求。由于两个子条款(a)和(b)都与输入规章A内容相关，可以选择其中一个作为最相似的，这里选择了(b)因为它直接提到了信号灯的保持常亮，与输入规章A的内容更为接近。
# ********************
# file2_231_第 121.597 条_(c)
# ********************
# file2_196_第 121.543 条
# ********************
# file2_147_第 121.459 条_(a)
# ********************
# 未找到相似内容
#
# 输入规章A涉及的是特定高度范围内的下降率限制，而规章B中的内容主要涉及飞行高度规则、起飞条件等，与输入规章A的内容并不直接相关，因此没有找到相似的内容。
# ********************
# file2_265_第 121.673 条_(b)
# ********************
# file2_262_第 121.667 条_(g)
# ********************
# file2_266_第 121.675 条
#
# 输入规章A描述了飞机在未公布航路上飞行或被雷达引导时，必须保持指定高度，并在进入仪表进近程序后按照公布的高度下降。而file2_266_第 121.675 条则提到了在按照仪表飞行规则进行起始进近时，不得低于仪表进近程序中规定的起始进近最低高度。两者都涉及到仪表飞行规则和按照程序下降的要求，因此我认为这条规章与输入规章A的内容最为相似。
# ********************
# file2_92_第 121.349 条_(c)
#
# 输入规章A主要讲述的是飞行机组在特定情况下应如何沿着航线飞行，而规章B中的file2_92_第 121.349 条_(c)提到了关于仪表飞行规则运行或非地标领航的航路上所需的无线电设备，特别是VOR导航接收机和测距设备(DME)，这与飞行沿航线导航有关。其他规章B中的内容与飞行航线导航的直接要求不太相似，因此，file2_92_第 121.349 条_(c)与输入规章A的内容最为相似。
# ********************
# 未找到相似内容
#
# 输入规章A主要涉及飞机在起飞到着陆期间应使用机载防撞系统（TCAS/ACAS）的具体操作要求，包括使用TA/RA模式和选择适当的显示距离。而规章B中的内容主要涉及飞机应当配备经批准的ACAS II机载防撞系统的要求，但没有具体到操作阶段和使用模式，因此与输入规章A的内容并不相似。
# ********************
# file2_96_第 121.354 条_(a)
#
# 输入规章A主要强调飞机必须安装TAWS/GPWS，并且飞行机组不得擅自抑制该系统。在规章B中，file2_96_第121.354条(a)部分提到所有飞机应当装备具有前视地形避让功能的地形感知和警告系统(TAWS)，这与输入规章A的内容最为相似，都在强调飞机必须装备TAWS系统。其他部分虽然也提到了TAWS系统的功能和使用，但没有直接涉及到不得擅自抑制TAWS/GPWS的规定。
# ********************
# file2_225_第 121.587 条_(a)
# ********************
# L01
# *********************
#
#
# 根据输入规章A的内容，它主要规定了飞机座舱高度高于3000米时，飞行机组成员必须使用氧气，并且氧气面罩必须在随手可取的位置。在规章B中，ID为L01的条款提到了在飞行的关键阶段，机组成员不得完成除了飞机安全运行所必需的工作之外的其他工作，这与输入规章A中关于飞行机组成员在特定高度必须使用氧气的规定有一定的相似性，因为它都涉及到飞行安全相关的操作要求。
#
# 然而，如果更准确地根据氧气使用的要求来比较，规章B中的ID为file2_83_第121.333条_(c)的条款与输入规章A的内容更为相似，因为它具体规定了在飞行高度7600米以上时，驾驶舱内值勤的每一飞行机组成员必须配备并使用氧气面罩，这与输入规章A中关于3000米高度以上使用氧气面罩的要求是一致的。
#
# 但是，根据您提供的格式要求，我选择了与输入规章A最相似的内容，即L01。如果需要更精确的匹配，请告知我，我将重新评估并给出正确的ID。
# ********************
# file2_85_第 121.337 条_(c)
# ********************
# file2_76_第 121.317 条_(b)
# ********************
# file2_194_第 121.539 条_(e)
#
# 输入规章A强调的是飞行机组必需成员在飞行关键阶段应在值勤位置就坐，不得使用机上休息设施。而规章B中的file2_194_第121.539条_(e)定义了飞行关键阶段的具体内容，这与输入规章A的上下文和语境是相似的，因为它涉及到飞行关键阶段的行为要求。其他选项与飞行机组在关键阶段的就坐要求或休息设施的使用没有直接关联，因此，file2_194_第121.539条_(e)与输入规章A的内容最为相似。
# ********************
# 未找到相似内容
#
# 输入规章A涉及客舱乘务员在飞行前准备过程中对机上休息设施及安全设备的检查，而规章B中的内容主要涉及机组成员的值勤要求、飞行安全相关的信息获取、以及驾驶舱检查单等，没有直接对应的内容涉及到客舱乘务员对设施的检查。因此，根据提供的信息，没有找到与输入规章A内容最为相似的规章。
# ********************
# file2_72_第 121.313 条_(f)
#
# 输入规章A主要讲述的是关于飞机客舱门的打开与关闭必须由特定人员进行操作，而规章B中的file2_72_第 121.313 条_(f)也涉及到飞机门的锁定和操作，特别是关于驾驶舱门和客舱门之间的锁定装置，以及只有飞行机组成员才能持有驾驶舱门的钥匙。这与输入规章A中提到的对特定人员进行操作的要求相似，因此我认为这是最为相似的内容。
# ********************
# file2_232_第 121.605 条_(b)
#
# 输入规章A中提到的“如需从外部打开客舱门，应由完成相关训练的客舱乘务员或机务维修人员实施”与规章B中的file2_232_第 121.605 条_(b)中的内容有关客舱乘务员在特定情况下进入驾驶舱的相关规定，虽然不是完全相同，但在涉及人员和舱门操作方面有相似之处。其他规章B的内容则与输入规章A的内容不太相似。
# ********************
# file2_195_第 121.541 条_(a)
# ********************
# file2_195_第 121.541 条_(b)
# ********************
# file2_197_第 121.545 条_(a)
#
# 输入规章A主要规定了在商业运行中，旅客登机至离机期间，除了机组人员和经批准人员外，其他人不得进入驾驶舱。在规章B中，file2_197_第 121.545 条_(a)部分提到了哪些人员可以进入驾驶舱，这与输入规章A的内容最为相似，因为它涉及到了对进入驾驶舱人员的限制。其他选项与进入驾驶舱的限制没有直接关联，因此不是最相似的规章。
# ********************
# file2_197_第 121.545 条_(a)
# ********************
# file2_197_第 121.545 条_(b)
# ********************
# file2_197_第 121.545 条
#
# 输入规章A主要涉及的是进入驾驶舱的人员限制和相关的安全措施。在提供的规章B中，file2_197_第 121.545 条同样涉及了进入驾驶舱的人员限制，包括哪些人员可以进入驾驶舱以及相关的条件。因此，这个规章与输入规章A的内容最为相似。
# 根据输入规章A的内容，我们需要在规章B中找到与之最为相似的那一条。规章A强调的是在特定情况下，机长必须允许某些人员进入驾驶舱，并且不受阻碍。
#
# 在规章B中，有几条与进入驾驶舱的限制和条件有关。通过比较，可以看出第2条中的内容与规章A最为相似，因为它也提到了局方监察员或局方委任代表在出示证件后应当被允许进入驾驶舱，而且没有提到任何额外的限制。
#
# 因此，输出结果为：
#
# ********************
# ID: file2_198_第 121.547 条
# ********************
# file2_198_第 121.547 条的内容与输入规章A相似，因为它同样强调了局方监察员在出示证件后应被允许进入驾驶舱的条件。其他条款包含了更多的细节和条件，因此不是最相似的。
# ********************
# file2_197_第 121.545 条_(a)
# ********************
# file2_197_第 121.545 条_(b)
# 从您提供的规章B中的两个选项来看，与输入规章A内容最为相似的是：
#
# 1. 规章B中的ID='L01'的内容，它提到“在飞行的关键阶段，合格证持有人不得要求飞行机组成员完成飞机安全运行所必需的工作之外的任何其他工作，飞行机组任何成员也不得承担这些工作。”
#
# 这个规章与输入规章A的内容非常接近，都是强调在飞行的关键阶段，机组成员不得进行与飞机安全运行无关的工作。
#
# 因此，如果需要从规章B中挑选出与规章A最相似的内容，应选择ID='L01'的规章。
#
# 至于您的输出格式要求，以下是按照您的要求输出的结果：
#
# ********************
# 相似内容ID: L01
# ********************
# 未找到相似内容。
# ********************
# ID
# L01
# ********************
# 未找到相似内容。
# ********************
# ID
# L01
# ********************
# 未找到相似内容。
# ********************
# ID
# L01
# ********************
# 未找到相似内容。
# ********************
# ID
# L01
# ********************
# 未找到相似内容。
# ********************
# 2. 如果没有找到相似内容，则输出“未找到相似内容”。
# ********************
# file2_232_第 121.605 条_(a)
# 根据输入规章A的内容，它主要涉及机组成员或经批准的人员在进入或离开驾驶舱前需要进行的操作，包括使用观察孔或电子监控装置来识别请求进入驾驶舱的人员并检查驾驶舱门周围状况。
#
# 从规章B中，ID为`file2_197_第 121.545 条`的规章内容与输入规章A最为相似，因为它详细描述了哪些人员可以进入驾驶舱以及相关的条件和限制。虽然它没有直接提到使用观察孔或电子监控装置，但它涉及了进入驾驶舱的人员的识别和批准过程。
#
# 因此，根据相似度判断，以下是输出：
#
# ********************
# ID
# file2_197_第 121.545 条
# ********************
# file2_194_第 121.539 条_(b)
# ********************
# file2_195_第 121.541 条_(i)
# ********************
# file2_195_第 121.541 条_(b)
#
# 输入规章A描述了当驾驶舱内只有两名飞行员时，如果其中一名需要离开，应该如何安排替代人员。而规章B中的file2_195_第 121.541 条_(b)提到了飞行机组必需成员可以离开指定值勤位置的情况，这与输入规章A中的情景有相似之处，尤其是在提到机组成员因工作或生理原因需要离开的情况下。因此，file2_195_第 121.541 条_(b)与输入规章A的内容最为相似。
# ********************
# file2_197_第 121.545 条_(b)
# ********************
# 未找到相似内容
#
# 输入规章A强调的是客舱乘务员不得参与对飞机的操作，而规章B中的内容更多地是关于哪些人可以进入驾驶舱以及机长对于进入驾驶舱人员的权限。虽然规章B中提到了进入驾驶舱的人员，但并没有直接提到客舱乘务员不得参与飞机操作的内容，因此没有找到与输入规章A内容最为相似的规章。
# ********************
# file2_222_第 121.581 条
#
# 输入规章A与file2_222_第121.581条的内容最为相似，都涉及到驾驶舱内物品的固定及其在应急着陆状态下的载荷承受能力，以及避免因移动造成安全危害的要求。其他规章B中的内容与输入规章A的相似度较低，主要涉及手提行李的固定和客舱行李的处理，而未特别强调驾驶舱内物品的固定要求。
# ********************
# file2_241_第 121.626 条_(a)
# ********************
# file2_239_第 121.623 条_(b)
# ********************
# file2_267_第 121.677 条
#
# 输入规章A中提到的机长与飞行签派员共同在签派单上签字的内容与规章B中的第2条（file2_267_第 121.677 条）最为相似，该条规章提到了机长和授权的飞行签派员在签派单上签字的责任，并且强调了他们共同认为飞行能安全进行时才能签字。其他规章B中的内容虽然涉及到飞行签派员的信息提供和飞行计划，但没有直接提到签字这一具体行为。
# ********************
# file2_194_第 121.539 条_(c)
#
# 输入规章A强调的是机长、客舱（主任）乘务长、航空安全员在飞行中出现的问题或事件时应履行报告职责。在规章B中，file2_194_第 121.539 条_(c)提到的是机组成员在飞行期间不得因服务程序而影响履行安全职责，这与输入规章A中提到的履行安全相关职责的内容相似。其他选项更多地涉及飞行计划、运行控制责任、设施和服务的信息提供，与输入规章A的内容不是特别相似。
# ********************
# 未找到相似内容
#
# 输入规章A涉及的是应急设备的检查，而规章B中的内容主要涉及应急生存训练、航线检查、紧急情况处理、不安全状况下的飞行和驾驶舱检查单等方面，没有直接对应于应急设备检查的内容。因此，根据提供的信息，没有找到与输入规章A内容最为相似的规章B条款。
# ********************
# 未找到相似内容
#
# 输入规章A涉及的是飞行机组在特定情况下执行应急设备检查的要求，而规章B中的内容主要涉及仪表或设备失效、机组成员的应急生存训练、紧急情况下的运行程序等，没有直接与规章A中提到的“飞行机组值勤期内首次进入飞机驾驶舱，或飞行机组发生更换，或全部机组离开航空器并再次进入时执行应急设备检查”相似的内容。
# ********************
# 未找到相似内容
#
# 输入规章A涉及的是客舱机组值勤期内进行应急设备检查的要求，而规章B中的内容主要涉及应急设备的检验、机组成员的应急生存训练、飞行值勤期限制等，没有直接对应的内容提到值勤期内的应急设备检查。因此，根据提供的信息，没有找到与输入规章A内容最为相似的规章B条款。
# ********************
# 未找到相似内容
#
# 输入规章A涉及的是客舱应急设备的检查责任分配，而规章B中的内容主要涉及仪表或设备失效时的程序和紧急情况下的运行处理。这些内容与输入规章A的主题不太相似，因此没有找到直接相关的类似内容。
# ********************
# 未找到相似内容
#
# 输入规章A涉及的是机组成员在旅客登机前进行的安保检查，而规章B中的内容主要涉及机组成员的值勤要求、飞行期间的责任和职责，没有直接提到安保检查的相关内容。因此，根据提供的规章内容，没有找到与输入规章A内容最为相似的规章。
# ********************
# file2_205_第 121.555 条_(b)
#
# 输入规章A主要涉及飞行机组成员对燃油加注过程的监控和确认，以及机长在特定情况下的签字确认。规章B中的file2_205_第 121.555 条_(b)部分也提到了机长确保机上剩余燃油量的要求，这与输入规章A中关于燃油监控的内容相似。虽然它们并不完全相同，但它们都涉及到燃油管理和机长的责任，因此这个选项是与输入规章A最相似的内容。其他选项则更多地涉及飞行中燃油管理的政策和程序，以及紧急情况下的燃油宣布，与输入规章A的内容不太相符。
# ********************
# file2_194_第 121.539 条_(c)
#
# 输入规章A提到的是客舱乘务员根据手册和公司政策进行机上准备工作，而规章B中的file2_194_第 121.539 条_(c)提到的是机组成员的服务程序不得影响客舱乘务员履行安全职责，两者都涉及到客舱乘务员的职责和工作要求，因此这个选项与输入规章A的内容最为相似。其他选项更多地涉及到客舱乘务员的合格要求、运行经历和具体的安全操作，与输入规章A的内容相比较，相似度较低。
# ********************
# file2_222_第 121.581 条
#
# 输入规章A主要强调的是客舱乘务员在准备过程中检查机供品数量，确保不超过存放区域的最大载荷标准。而规章B中的file2_222_第 121.581 条涉及到的是客舱和驾驶舱内行李和物品的固定及其承受的载荷，其中(a)小节提到了承受相应于该飞机型号合格审定应急着陆状态的载荷系数下的载荷，这与输入规章A中提到的“最大载荷标准”有一定的相似性，都是在强调对物品载荷的限制和安全性检查。因此，我选择了这个ID作为最相似的规章。如果这个解释不符合您的预期，请告知我以便进行进一步的讨论。
# ********************
# file2_194_第 121.539 条_(b)
#
# 输入规章A强调的是在旅客登机至舱门关闭期间，飞行机组与客舱机组应保持静默，避免互相干扰，而规章B中的file2_194_第 121.539 条_(b)也提到了飞行机组成员在关键阶段不得从事可能分散其他成员工作精力或干扰其他成员活动的行为。虽然具体情境不同，但两者都强调了避免在关键时段内的非必要交流或活动，以保证飞行安全。因此，file2_194_第 121.539 条_(b)与输入规章A的内容最为相似。
# ********************
# 未找到相似内容
#
# 输入规章A主要涉及旅客登机后要求终止行程时的安全检查程序，特别是关于旅客在机上活动轨迹的确认。而规章B中的内容主要涉及机组成员在中途过站停留时的要求、起飞前对旅客的简介以及在不安全状况中继续飞行的规定，这些与输入规章A的内容并不相似。因此，根据提供的信息，未找到与输入规章A内容相似的规章B条款。
# ********************
# 未找到相似内容
#
# 输入规章A主要强调的是机长确认所有舱门关闭/滑梯待命情况，并且要求在所有舱门待命完成之前，飞机不得移动。而规章B中的内容主要集中在驾驶舱门的关闭与锁定，以及相关的安全程序和应急情况处理，并没有直接提及所有舱门的关闭状态和飞机移动的直接关系。因此，根据提供的信息，没有找到与输入规章A内容最为相似的规章B内容。
# ********************
# 未找到相似内容
#
# 输入规章A主要强调的是在旅客完全离开飞机前，机组不能离开飞机，并且如果因特定原因需要离开，必须安排人员负责飞机安全。而规章B中的内容主要涉及飞行机组成员的值勤要求、飞行安全、服务程序等，没有直接对应到输入规章A中提到的特定情境。因此，从提供的规章B中没有找到与输入规章A内容最为相似的那一个。
# ********************
# file2_195_第 121.541 条
#
# 输入规章A主要强调的是驾驶舱内至少要有一名飞行机组成员，并且负责一系列工作。在提供的规章B中，file2_195_第 121.541 条涉及到在操作位置上的飞行机组成员的要求，包括坐在指定的值勤位置并系好安全带，这与输入规章A中关于驾驶舱内必须有一名机组成员的要求相似。其他规章B的内容更多地涉及到进入驾驶舱的人员限制、机组成员的值勤要求等，与输入规章A的内容不太相似。
# ********************
# file2_120_第 121.393 条_(b)
#
# 输入规章A主要讲述的是中途过站经停时，客舱机组应通知旅客带好个人物品离开航空器，并配合进行安保检查。在规章B中，file2_120_第 121.393 条_(b)部分提到了在中途过站停留时，如果旅客仍停留在飞机上，对于客舱乘务员的特定要求，这与输入规章A的内容在情境上相似，都涉及到经停时对客舱机组和旅客的安排和要求。其他两个选项更多关注于客舱乘务员的数量和位置安排，与输入规章A的内容不是特别相似。
# ********************
# file2_120_第 121.393 条_(a)

# %%
len(top1_simi_result)
# Out:
# 87

# %%
for key1, text1, key2, text2, simi_score in top1_simi_result:
    print(key1)
    print(text1)
    print(key2)
    print(text2)
    print(simi_score)
    print('------------------------------------------')
# Out:
# file1_4_2.3.
# 如需偏离标准操作程序， 飞行机组必须进行充分的沟通， 包括与其他相关机组 人员、 地面人员以及空中交通管制员等的沟通， 并评估偏离标准操作程序可能 造成的风险。
# file2_208_第 121.558 条_(b)
# 补充运行的紧急情况 在使用飞行跟踪系统实施运行控制的飞行期间， 合格 证持有人的相关管理人员发现需要其立即决断和处置的紧 急情况时， 应当将紧急情况通知机长， 确实弄清机长的决断， 并且应当将该决断作出记录。如果在上述情况下，该管理人 员不能与飞行人员取得联系，则应当宣布进入应急状态，并 采取他认为在此种情况下为保证飞行安全应当采取的任何 行动。
# 0.7524038057288005
# ------------------------------------------
# file1_7_3.2.
# 飞行机组在运行过程中，必须使用公司配备的经批准的检查单；
# file2_74_第 121.315 条_(c)
# 驾驶舱检查单 经批准的检查单应当放置在每架飞机驾驶舱内方便 飞行机组成员使用的地方，飞行机组在操作飞机时应当遵循 检查单规定的程序。
# 0.7564717334011755
# ------------------------------------------
# file1_30_8.2.
# 在飞行的关键阶段， 全体机组成员不得从事飞机安全运行所必需的工作之外的 任何其他工作，机组任何成员也不得承担这些工作。预定厨房供应品，确认旅 客的衔接航班，对旅客进行公司的广告宣传，介绍风景名胜的广播，填写与运 行无关的公司报告表、记录表等工作都不是飞机安全运行所必需的工作。
# file2_194_第 121.539 条_(a)
# 机组成员的值勤要求 在飞行的关键阶段， 合格证持有人不得要求飞行机组 成员完成飞机安全运行所必需的工作之外的任何其他工作， 飞行机组任何成员也不得承担这些工作。预定厨房供应品， 确认旅客的衔接航班，对旅客进行合格证持有人的广告宣 传，介绍风景名胜的广播，填写与运行无关的公司报告表、 记录表等工作都不是飞机安全运行所必需的工作。
# 0.7977028009516467
# ------------------------------------------
# file1_31_8.3.
# 在飞行关键阶段，飞行机组成员不得从事可能分散飞行机组其他成员工作精 力， 或可能干扰其他成员正确履行职责的活动， 机长也不得允许其从事这种活 动。这些活动包括进餐、在驾驶舱无关紧要的交谈、在驾驶舱和客舱乘务员之 间无关紧要的通话、阅读与正常飞行无关的刊物等。
# file2_194_第 121.539 条_(b)
# 机组成员的值勤要求 在飞行的关键阶段， 飞行机组成员不得从事可能分散 飞行机组其他成员工作精力，或者可能干扰其他成员正确完 成这些工作的活动，机长也不得允许其从事此种活动。这些 活动包括进餐、在驾驶舱无关紧要的交谈、在驾驶舱和客舱 乘务员之间无关紧要的通话、阅读与正常飞行无关的刊物 等。
# 0.7618616954379221
# ------------------------------------------
# file1_32_8.4.
# 在飞行关键阶段， 客舱乘务员除完成保障机上人员安全的任务外， 其他时间应 当坐在其值勤位置并系好安全带和肩带。
# file2_119_第 121.391 条_(f)
# 客舱乘务员 在起飞和着陆过程中，本条要求的客舱乘务员应当尽 可能地靠近所要求的地板高度出口，而且应当在整个客舱内 均匀分布，以便在应急撤离时最有效地疏散旅客。在滑行期 间，本条要求的客舱乘务员，除完成保障飞机和机上人员安 全的任务外，其他时间应当坐在其值勤位置并系好安全带和 肩带。
# 0.772923643603916
# ------------------------------------------
# file1_34_8.6.
# 在飞行关键阶段， 客舱乘务员应避免与驾驶舱联系或进入驾驶舱， 除非涉及飞 行安全。
# file2_194_第 121.539 条_(b)
# 机组成员的值勤要求 在飞行的关键阶段， 飞行机组成员不得从事可能分散 飞行机组其他成员工作精力，或者可能干扰其他成员正确完 成这些工作的活动，机长也不得允许其从事此种活动。这些 活动包括进餐、在驾驶舱无关紧要的交谈、在驾驶舱和客舱 乘务员之间无关紧要的通话、阅读与正常飞行无关的刊物 等。
# 0.750578633708929
# ------------------------------------------
# file1_36_8.8.
# 在飞行关键阶段， 客舱乘务员应当尽可能地靠近飞机地板高度出口， 而且应当 在整个客舱内均匀分布，以便在应急撤离时最有效地疏散旅客。在滑行期间， 客舱乘务员除完成保障飞机和机上人员安全的任务外， 其余时间应当坐在其值 勤位置并系好安全带和肩带。
# file2_119_第 121.391 条_(f)
# 客舱乘务员 在起飞和着陆过程中，本条要求的客舱乘务员应当尽 可能地靠近所要求的地板高度出口，而且应当在整个客舱内 均匀分布，以便在应急撤离时最有效地疏散旅客。在滑行期 间，本条要求的客舱乘务员，除完成保障飞机和机上人员安 全的任务外，其他时间应当坐在其值勤位置并系好安全带和 肩带。
# 0.7667023582462548
# ------------------------------------------
# file1_37_9.
# 燃油监控 飞行机组必须对燃油消耗进行持续监控，对剩余燃油进行科学管理，确保剩余燃油 不低于完成计划飞行所需的燃油要求。
# file2_205_第 121.555 条_(b)
# 飞行中燃油管理 机长必须随时确保机上剩余可用燃油量， 不低于飞往 可以安全着陆的机场的所需油量与计划最后储备油量之和。
# 0.7636583040466002
# ------------------------------------------
# file1_40_9.3.
# 一旦发现燃油消耗异常、 燃油指示故障等燃油不正常状态， 应立即进行分析并 视情按FCOM 以及QRH 处置， 以保证飞行在预计着陆机场着陆时的剩余油量 不低于最后储备燃油量， 努力避免飞机进入紧急油量状态， 同时立即将相关情 况报告飞行签派员。
# file2_205_第 121.555 条_(c)
# 飞行中燃油管理 如果飞行中燃油检查的结果表明，在目的地机场着陆 时的机载剩余可用燃油量可能低于备降油量与计划最后储 备燃油量之和时，机长必须评估目的地机场、备降机场与航 路的空中交通情况和天气趋势、导航设备开放状况等运行条 件，以确保安全着陆时的机载剩余可用燃油量不低于最后储 备燃油量。
# 0.7521904181688598
# ------------------------------------------
# file1_42_10.1.
# 起始进近高度 当按照仪表飞行规则飞往无线电导航设施做起始进近时， 飞行机组不得将飞机 下降到按该设施制定的仪表进近程序中规定的起始进近最低高度之下， 直至到 达该设施上空。
# file2_266_第 121.675 条
# 起始进近高度 当按照仪表飞行规则飞往无线电导航设施作起始进近 时，任何人不得将飞机下降到按照该设施制定的仪表进近程 序中规定的起始进近最低高度之下，直至到达该设施的上 空。
# 0.7802346808277423
# ------------------------------------------
# file1_44_10.3.
# 继续进近的条件 10.3.1. 当报告的VIS/RVR 低于规定的最低标准时,不得飞越FAF/最后进近点 （FAP）或下降到机场标高上空300 米（1000 英尺）以下，两者取较 高值。 10.3.2. 飞越FAF/FAP 或下降到机场标高上空300 米（1000 英尺）以下后， 报告的RVR 或VIS 低于规定的最低标准，可以继续进近至DA/H 或者 MDA/H。 10.3.3. 如果进近程序没有规定FAF， 当报告的RVR 或VIS 低于规定的最低标 准时，不得开始最后进近。 注：最后进近航段从仪表进近程序规定的最后进近定位点或者设施处开始。当 一个包含程序转弯的程序没有规定最后进近定位点时， 最后进近航段在完成程 序转弯的那一点开始，并且在该点上，飞机在该程序规定距离之内在最后进近 航迹上向机场飞行。
# file2_262_第 121.667 条_(b)
# 仪表飞行规则的起飞和着陆最低标准 除本条(e)款规定外，飞机不得飞越最后进近定位点 (FAF 或者FAP)继续进近，或者在不使用最后进近定位点 (FAF 或者FAP)的机场， 进入仪表进近程序的最后进近航段， 除非由局方批准的系统为该机场发布了最新的天气报告，报 告该机场的能见度(VIS)或者跑道视程(RVR)等于或者高于仪 表进近程序规定的最低标准。在可以同时获得能见度(VIS) 和跑道视程(RVR)时，以跑道视程为准。
# 0.7654223931720726
# ------------------------------------------
# file1_45_10.4.
# 当到达MDA/H 或DA/H，在进近复飞点之前的任何时间内，除非满足下列要 求，否则飞机不得继续进近到低MDA/H 或DA/H 并着陆： 10.4.1. 飞机持续处在正常位置， 从该位置能够使用正常机动动作以正常下降率 降落在计划着陆跑道， 并且以此下降率可以使飞机在该跑道接地区内接 地； 10.4.2. 飞行能见度不低于所用的标准仪表进近程序规定的能见度； 10.4.3. 飞行机组能清楚地看到并保持所需的目视参考； 10.4.4. 当使用具有目视下降点的非精密直接进近程序时， 飞机已到达该目视下 降点，且在该点使用正常程序或者下降率能降落到跑道上。
# file2_262_第 121.667 条_(d)
# 仪表飞行规则的起飞和着陆最低标准 如果驾驶员根据本条(b)款已经开始实施仪表进近程 序的最后进近，并在此后收到了较新的天气报告，报告的天 气条件低于最低天气标准，该驾驶员仍可以继续进近至决断 高或者最低下降高。当到达决断高或者最低下降高，在进近 复飞点之前的任何时间内，除非符合下列条件或者满足增强 飞行视景系统(EFVS)的相关运行要求，不得继续进近到低于 决断高或者最低下降高并着陆： (1)该飞机持续处在正常位置， 从该位置能使用正常机动 动作以正常下降率下降到计划着陆的跑道上着陆，并且以此 下降率可以使飞机在计划着陆的跑道的接地区内接地； (2)飞行能见度不低于所用的标准仪表进近程序规定的 能见度； (3)除Ⅱ类和Ⅲ类进近(在这些进近中，必需的目视参考 由局方在批准时具体规定)外， 驾驶员至少能清楚地看到和辨 认计划着陆跑道的下列目视参考之一：
# 0.7534628158646152
# ------------------------------------------
# file1_46_10.5.
# 仪表进近着陆所需目视参考 10.5.1. 除II 类和III 类进近外，飞行机组至少能清楚地看到和辨认着陆跑道的 下列目视参考之一： 10.5.1.1. 进近灯光系统，如果飞行机组仅使用进近灯光作为参考，应 当同时清楚地看到和辨认红色终端横排灯 注或红色侧排灯，否 则不得下降到接地区标高之上30 米（100 英尺）以下； 10.5.1.2. 跑道入口； 10.5.1.3. 跑道入口标志； 10.5.1.4. 跑道入口灯； 10.5.1.5. 跑道端标识灯； 10.5.1.6. 目视进近下滑道指示灯； 10.5.1.7. 接地区或接地区标志； 10.5.1.8. 接地区灯； 10.5.1.9. 跑道或跑道标志； 10.5.1.10. 跑道灯。 注： 红色终端横排灯为ALSF-1 进近灯光系统特有灯光， 国内机场无相 应灯光系统。 10.5.2. II 类进近着陆时，除非能保持包括进近灯、接地带灯、跑道中线灯、跑 道边灯或者这些灯的组合中至少3 个连续灯的目视参考，机组不得继 续进近至决断高（DH）之下。 10.5.3. 对于IIIA 类运行， 机组不得继续进近至DH 之下， 除非获得并能够保持 包括进近灯、接地带灯、跑道中线灯或这些灯的组合中至少3 个连续 灯的目视参考。 10.5.4. 对于IIIB 类运行， 机组不得进近至DH 之下， 除非获得并能够保持包括 1 个中线灯在内的目视参考。
# file2_262_第 121.667 条_(i)
# 仪表飞行规则的起飞和着陆最低标准 进近灯光系统，但是如果驾驶员仅使用进近灯光作为 参考，除非能同时看到和辨认侧边短排灯，否则不得下降到 接地区标高之上30 米(100 英尺)以下； (ii)跑道入口； (iii)跑道入口标志； (iv)跑道入口灯；
# 0.7511936045226917
# ------------------------------------------
# file1_53_11.6.
# 在国内运输机场空域内， 除经塔台同意外， 飞机在进入机场实施目视起落航线 时，不得低于机场标高以上450 米。
# file2_265_第 121.673 条_(b)
# 飞行高度规则 按照本规则实施运行的任何飞机在昼间按照目视飞 行规则运行时不得在距地表、 山峰、 丘陵或者其他障碍物300 米(1000 英尺)的高度以下飞行。
# 0.7551816361937946
# ------------------------------------------
# file1_55_11.8.
# 机长在确定从飞机所处位置能进行稳定进近之前， 不得下降低于着陆跑道接地 区标高以上500 英尺。
# file2_265_第 121.673 条_(b)
# 飞行高度规则 按照本规则实施运行的任何飞机在昼间按照目视飞 行规则运行时不得在距地表、 山峰、 丘陵或者其他障碍物300 米(1000 英尺)的高度以下飞行。
# 0.753940732207383
# ------------------------------------------
# file1_58_12.1.
# 为确保客舱机组自身安全，在本章节8 条的基础上，公司规定：自滑行至起飞 后20 分钟或到达巡航高度，以及落地前30 分钟至飞机发动机关车（安全带 灯灭），以上阶段客舱乘务员除完成保障飞机和机上人员安全的任务外，其他 时间应必须在规定的席位上就坐并保持安全带、 肩带系紧， 除非发生危及飞行 安全或涉及旅客的紧急情况。
# file2_195_第 121.541 条_(a)
# 在操作位置上的飞行机组成员 除本条(b)款规定外， 在驾驶舱值勤的每个飞行机组必 需成员，在飞行过程中应当坐在指定的值勤位置并系好安全 带；在起飞和着陆过程中应当坐在指定的值勤位置并系好安 全带和肩带。对于驾驶员之外的飞行机组成员，除肩带妨碍 执行任务时可以松开肩带以外(但必须系紧座椅安全带)，在 起飞和着陆阶段也应当始终系好肩带。
# 0.7535644808313658
# ------------------------------------------
# file1_60_13.
# 禁止吸烟的规定
# file2_231_第 121.597 条_(a)
# 禁止吸烟的规定 任何人不得在按照本规则运行的飞机上吸烟。
# 0.759537084910664
# ------------------------------------------
# file1_61_13.1.
# 任何人在任何阶段（包括运行阶段及非运行阶段）禁止在航空器内吸烟（包括 电子烟），飞行机组应在整个飞行阶段保持“禁止吸烟”信号灯的接通。
# file2_231_第 121.597 条
# 禁止吸烟的规定 (a)任何人不得在按照本规则运行的飞机上吸烟。 (b)飞机在运行时，应当使“禁止吸烟”的告示信号灯保持 常亮。 (c)在飞机上的任何人不得触动、损害或者破坏飞机厕所 内安装的烟雾探测器。
# 0.8271688588029226
# ------------------------------------------
# file1_62_13.2.
# 机上任何人不得触动、 损害或者破坏飞机厕所内安装的烟雾探测器， 机组成员 如发现此类行为应予以立即制止。 飞行运行操纵限制
# file2_231_第 121.597 条_(c)
# 禁止吸烟的规定 在飞机上的任何人不得触动、损害或者破坏飞机厕所 内安装的烟雾探测器。
# 0.7670200897829801
# ------------------------------------------
# file1_64_1.1.
# 机长不得允许不符合下列规定之一的人员在飞行期间控制操纵装置， 任何不符 合下列规定之一的人员也不得在飞行期间控制操纵装置： 1.1.1. 公司聘任的合格的飞行员； 1.1.2. 得到机长允许， 有资格在该飞机上飞行的正在执行飞行运行检查任务的 局方监察员或者局方委任代表； 1.1.3. 得到机长允许、 有资格在该飞机上飞行并且获得了局方和公司批准的另 一公司的飞行员。
# file2_196_第 121.543 条
# 操纵装置的控制 机长不得允许不符合下列规定之一的人员在飞行期间 控制操纵装置，任何不符合下列规定之一的人员也不得在飞 行期间控制操纵装置： (a)运行该飞机的合格证持有人的合格驾驶员； (b)得到机长允许、 有资格在该飞机上飞行的正在执行飞 行运行检查任务的局方监察员或者局方委任代表； (c)得到机长允许、有资格在该飞机上飞行并且获得了局 方和运行该飞机的合格证持有人批准的另一合格证持有人 的驾驶员。
# 0.7876857832437149
# ------------------------------------------
# file1_67_1.4.
# 下列情况下，由机长操纵飞机： 1.4.1. 起飞重量达到本机型最大起飞重量的百分之九十（含）以上时； 1.4.2. 实施目视盘旋进近时； 1.4.3. 实施低能见度运行时； 1.4.4. 右座副驾驶在所飞机型飞行经历时间少于100 小时且左座机长不具备 飞行检查员/飞行教员资格，下列情况下由左座机长操纵飞机： 1.4.4.1. 在公司规定的特殊机场； 1.4.4.2. 机场的最新气象报告中有效能见度值等于或者小于1200 米 (3/4 英里)，或者跑道视程(RVR)等于或者小于1200 米(4000 英尺)； 1.4.4.3. 所用跑道有水、雪、雪浆等严重影响飞机性能的情况； 1.4.4.4. 所用跑道刹车效应报告低于“好”； 1.4.4.5. 所用跑道侧风分量超过7 米/秒； 1.4.4.6. 天气报告机场附近有风切变； 1.4.4.7. 机长认为需要谨慎行使机长权力的任何其它情况。
# file2_147_第 121.459 条_(a)
# 驾驶员的使用限制和搭配要求 如果副驾驶在所飞机型上的飞行经历时间少于100 小 时，并且机长不具备飞行检查员或者飞行教员资格，则在下 列情况下，应当由机长完成所有起飞和着陆： (1)在局方规定或者合格证持有人规定的特殊机场； (2)机场的最新气象报告中有效能见度值等于或者小于 1,200 米(3/4 英里)，或者跑道视程(RVR)等于或者小于1,200 米(4,000 英尺)； (3)所用跑道有水、雪、雪浆或者严重影响飞机性能的情 况； (4)所用跑道的刹车效应据报告低于“好”的水平； (5)所用跑道的侧风分量超过7 米/秒(15 海里/小时)； (6)在机场附近据报告有风切变； (7)机长认为需谨慎行使机长权力的任何其他情况。
# 0.769734664255791
# ------------------------------------------
# file1_71_2.2.
# 高于机场标高300 米（1000 英尺）以下，下降率不得持续大于1000 英尺/分 钟。
# file2_265_第 121.673 条_(b)
# 飞行高度规则 按照本规则实施运行的任何飞机在昼间按照目视飞 行规则运行时不得在距地表、 山峰、 丘陵或者其他障碍物300 米(1000 英尺)的高度以下飞行。
# 0.7716034700287134
# ------------------------------------------
# file1_80_4.2.
# 严格执行标准操作程序，正确使用自动飞行系统，合理利用机组资源；
# file2_141_第 121.439 条_(a)
# 定期复训 定期复训应当以每12 个日历月为一周期安排，保证 每一机组成员或者飞行签派员，获得关于该型别飞机和所涉 及的机组成员工作位置的充分训练并保持近期熟练水平。
# 0.7553684012583126
# ------------------------------------------
# file1_86_5.1.
# 除经局方批准外， 在需要仪表进近着陆时， 飞行机组必须使用为该机场制定的 标准仪表离场和进近程序。
# file2_262_第 121.667 条_(g)
# 仪表飞行规则的起飞和着陆最低标准 除了在合格证持有人的运行规范中另有批准外， 在国 外机场按照仪表飞行规则起飞、进近或者着陆的驾驶员，应 当遵守管辖该机场所在地民航当局所规定的仪表进近程序 和最低天气标准。
# 0.7634703712614902
# ------------------------------------------
# file1_87_5.2.
# 当飞机在未公布的航路上飞行或者正在被雷达引导， 必须保持空中交通管制最 后指定的高度，直至飞机到达公布的航路或者进入仪表进近程序。此后，除非 空中交通管制另有通知，飞行机组应当按照航路内或者程序中公布的高度下 降。 航空器一旦达到最后进近阶段或者定位点， 飞行机组可以根据局方对该设 施批准的程序完成其仪表进近。
# file2_266_第 121.675 条
# 起始进近高度 当按照仪表飞行规则飞往无线电导航设施作起始进近 时，任何人不得将飞机下降到按照该设施制定的仪表进近程 序中规定的起始进近最低高度之下，直至到达该设施的上 空。
# 0.7609493474323165
# ------------------------------------------
# file1_92_6.2.
# 除为避开其他航空器或者为改变飞行高度需要偏离航线的机动飞行外， 在任何 其他航线上，飞行机组应沿该航线的导航设施或者定位点之间的连线飞行。 （空白） 设备的使用
# file2_92_第 121.349 条_(c)
# 仪表飞行规则运行或者非地标领航的航 路上目视飞行规则运行的无线电设备 当本条(a)款或者(b)款要求有VOR 导航接收机时，在 每架飞机上应当至少安装一套经批准的能接收并指示距离 信息的测距设备(DME)。
# 0.7620914740187534
# ------------------------------------------
# file1_101_2.
# 地形提示和警告系统（TAWS/GPWS）
# file2_96_第 121.354 条_(d)
# 地形感知和警告系统(TAWS) 运营人必须建立数据库管理程序， 确保及时更新地形 感知和警告系统(TAWS)的地形和障碍物数据。
# 0.7835025417158917
# ------------------------------------------
# file1_102_2.1.
# 公司所有飞机均安装了地形提示和警告系统（TAWS/GPWS），除机型手册 特殊规定外，飞行机组不得擅自抑制TAWS/GPWS。
# file2_96_第 121.354 条_(a)
# 地形感知和警告系统(TAWS) 按照本规则实施运行的所有飞机应当装备具有前视 地形避让功能的地形感知和警告系统(TAWS)。
# 0.7542294495037529
# ------------------------------------------
# file1_103_2.2.
# 对TAWS/GPWS 警告及时、正确的响应是避免可控飞行撞地的最后措施，飞 行机组必须正确理解TAWS/GPWS 发出的提示和警告信息，并按照机型手册 采取及时、准确的处置。
# file2_96_第 121.354 条_(b)
# 地形感知和警告系统(TAWS) 地形感知和警告系统(TAWS)应当能自动向飞行机组 发出及时和清楚的下列警告： (1)下降率过大； (2)接近地形速率过大； (3)起飞或者复飞后的高度损失过大； (4)未处于着陆形态时距地形过近， 包括起落架未处于放 下锁定位或者襟翼未处于着陆位； (5)低于仪表下滑道时下降过多。
# 0.7544003410692953
# ------------------------------------------
# file1_105_3.1.
# 除经局方批准的特殊运行（如RNP AR）与进近外，A320 系列机型起飞后高 于机场标高100 英尺以下、 B787 机型起飞后高于机场标高200 英尺以下不得 使用自动驾驶仪（如机型限制数据高于此值，执行机型标准） 。
# file2_225_第 121.587 条_(a)
# 使用自动驾驶仪的最低高度 对于航路上飞行， 除本条(b)款和(c)款规定外， 在离地 高度低于飞机飞行手册中注明的巡航状态下自动驾驶仪故 障时最大高度损失的2 倍，或者低于150 米(500 英尺)(取两 者之中较高者)时， 任何人不得在航路上， 包括上升和下降阶 段，使用自动驾驶仪。
# 0.7864998361286005
# ------------------------------------------
# file1_113_4.3.
# 飞行前， 飞行机组必须对氧气设备进行检查， 并确认氧气压力满足驾驶舱所有 人员用氧要求；
# file2_85_第 121.337 条_(c)
# 防护式呼吸装置 设备的飞行前检查。 (1)每次飞行前， 将使用防护式呼吸装置的飞行机组成员 应当对其值勤位置上的防护式呼吸装置进行检查，以确保该 设备：
# 0.7631003920843988
# ------------------------------------------
# file1_114_4.4.
# 当要求某一飞行机组成员用氧时， 他应连续用氧， 但因正常任务所需而取下氧 气面罩或其他氧气分配器的情况除外；
# file2_82_第 121.329 条_(b)
# 涡轮发动机飞机用于生命保障的补充氧 气要求 机组成员。 每个合格证持有人应当按照下列要求为机 组成员提供氧气： (1)在座舱气压高度3,000 米(10,000 英尺)以上至3,600 米(12,000 英尺)(含)时， 应当对在驾驶舱内值勤的每一飞行机 组成员提供氧气，并且他们也应当用氧，如果在这些高度上 超过30 分钟，则对于30 分钟后的那段飞行应当对其他机组 成员提供氧气； (2)在座舱气压高度3,600 米(12,000 英尺)以上时，应当 对在驾驶舱内值勤的每一飞行机组成员提供氧气，并且他们 也应当用氧，在此高度上整个飞行时间内，应当对其他机组 成员提供氧气； (3)当要求飞行机组成员用氧时，他应当连续用氧，除非 为执行其正常任务需要除去氧气面罩或者其他氧气分配器。 对那些处于待命状态的或者在完成此次飞行前肯定要在驾 驶舱内值勤的后备飞行机组成员， 视为本款第(1)、 (2)项所述 的其他机组成员。如果某一后备飞行机组成员不在待命状 态，并且在剩下的一段飞行中将不在驾驶舱内值勤，则就补 充氧气要求而言，可以将其视为一名旅客。
# 0.7589396403144033
# ------------------------------------------
# file1_115_4.5.
# 应向处于待命状态的或在完成此次飞行前需在驾驶舱内值勤的其他飞行机组 成员供氧， 用氧量应与在驾驶舱内工作的飞行机组成员相同。 如果飞行机组成 员不处于待命状态， 并且在剩下的飞行中将不在驾驶舱内值勤， 就补充供氧而 言，可将其视为一名旅客。
# file2_82_第 121.329 条_(b)
# 涡轮发动机飞机用于生命保障的补充氧 气要求 机组成员。 每个合格证持有人应当按照下列要求为机 组成员提供氧气： (1)在座舱气压高度3,000 米(10,000 英尺)以上至3,600 米(12,000 英尺)(含)时， 应当对在驾驶舱内值勤的每一飞行机 组成员提供氧气，并且他们也应当用氧，如果在这些高度上 超过30 分钟，则对于30 分钟后的那段飞行应当对其他机组 成员提供氧气； (2)在座舱气压高度3,600 米(12,000 英尺)以上时，应当 对在驾驶舱内值勤的每一飞行机组成员提供氧气，并且他们 也应当用氧，在此高度上整个飞行时间内，应当对其他机组 成员提供氧气； (3)当要求飞行机组成员用氧时，他应当连续用氧，除非 为执行其正常任务需要除去氧气面罩或者其他氧气分配器。 对那些处于待命状态的或者在完成此次飞行前肯定要在驾 驶舱内值勤的后备飞行机组成员， 视为本款第(1)、 (2)项所述 的其他机组成员。如果某一后备飞行机组成员不在待命状 态，并且在剩下的一段飞行中将不在驾驶舱内值勤，则就补 充氧气要求而言，可以将其视为一名旅客。
# 0.8112072717845501
# ------------------------------------------
# file1_118_5.1.
# 飞机在地面的任何移动， 以及每次起飞、 着陆和机长认为必要的其他任何时间， 应当接通“系好安全带”信号灯。
# file2_76_第 121.317 条_(b)
# 旅客告示 飞机在地面的任何移动，以及每次起飞、着陆和机长 认为必要的其他任何时间，应当接通“系好安全带”信号。
# 0.7692857920486341
# ------------------------------------------
# file1_119_5.2.
# 飞行关键阶段，飞行机组应保持“系好安全带”信号灯开启。
# file2_76_第 121.317 条_(b)
# 旅客告示 飞机在地面的任何移动，以及每次起飞、着陆和机长 认为必要的其他任何时间，应当接通“系好安全带”信号。
# 0.8263225572859606
# ------------------------------------------
# file1_120_5.3.
# 起飞后20 分钟或飞机到达巡航高度且无颠簸时，飞行机组应及时将“系好安 全带”信号灯关闭，并根据实际天气情况开启/关闭“系好安全带”信号灯。
# file2_76_第 121.317 条_(b)
# 旅客告示 飞机在地面的任何移动，以及每次起飞、着陆和机长 认为必要的其他任何时间，应当接通“系好安全带”信号。
# 0.8163152470899152
# ------------------------------------------
# file1_121_5.4.
# 飞机到达下降顶点时，飞行机组应打开“系好安全带”信号灯并保持开启直至 发动机关车。
# file2_76_第 121.317 条_(b)
# 旅客告示 飞机在地面的任何移动，以及每次起飞、着陆和机长 认为必要的其他任何时间，应当接通“系好安全带”信号。
# 0.7689333005797125
# ------------------------------------------
# file1_123_6.1.
# 除《最低设备清单》有特殊要求外，飞行机组必需成员在飞行关键阶段应在值 勤位置就坐，不得使用机上休息设施。
# file2_194_第 121.539 条_(e)
# 机组成员的值勤要求 在本条中， 飞行关键阶段是指滑行、 起飞、 着陆阶段， 以及除巡航飞行以外在起飞或目的地机场标高以上3,000 米 (10,000 英尺)以下的飞行阶段。
# 0.7617996589427731
# ------------------------------------------
# file1_133_7.1.
# 飞机客舱门的打开与关闭， 须由完成相应机型训练并合格的飞行人员、 客舱乘 务员或机务维修人员实施操纵，其他运行人员不得自行打开与关闭客舱门。
# file2_72_第 121.313 条_(f)
# 其他设备 飞机只有安装下列设备，方可以实施本规则的运行： 对于按照本规则运行的飞机，除机组成员外，如果机 上还搭载有其他乘员，则驾驶舱和乘员舱之间应当装有带锁 定装置的门(即驾驶舱门)，该锁定装置应当设计成只能从驾 驶舱内解锁，并且在使用中有效，以防止其他机上乘员未经 驾驶舱内飞行机组成员的同意将门打开，否则只有驾驶舱内 的飞行机组成员才能持有驾驶舱门的钥匙。对于从驾驶舱和 客舱都能进入的机组休息区的飞机，则该区和客舱之间应当 安装有带类似锁定装置的门。 (1)对于最大客座数大于20 人的载客飞机，其驾驶舱门 还应当满足下列要求：
# 0.7729803966664731
# ------------------------------------------
# file1_134_7.2.
# 如需从外部打开客舱门，应由完成相关训练的客舱乘务员或机务维修人员实 施。 驾驶舱的管理
# file2_232_第 121.605 条_(b)
# 驾驶舱门的关闭与锁定 合格证持有人应当制定程序或者方法， 以便客舱乘务 员： (1)在客舱有可疑活动或者安保措施被突破时能够有效 地通知飞行机组； (2)在飞行机组失去能力时能够进入驾驶舱。
# 0.7624988753902211
# ------------------------------------------
# file1_136_1.1.
# 在驾驶舱值勤的每个飞行机组必需成员， 在飞行过程中应当坐在指定的值勤位 置并系好安全带； 在飞行关键阶段， 应当坐在指定的值勤位置并系好安全带和 肩带， 但对于驾驶员座位上以外的飞行机组成员， 在履行其正常职责需要时可 以松开肩带。
# file2_195_第 121.541 条_(a)
# 在操作位置上的飞行机组成员 除本条(b)款规定外， 在驾驶舱值勤的每个飞行机组必 需成员，在飞行过程中应当坐在指定的值勤位置并系好安全 带；在起飞和着陆过程中应当坐在指定的值勤位置并系好安 全带和肩带。对于驾驶员之外的飞行机组成员，除肩带妨碍 执行任务时可以松开肩带以外(但必须系紧座椅安全带)，在 起飞和着陆阶段也应当始终系好肩带。
# 0.7700854055265832
# ------------------------------------------
# file1_138_1.3.
# 在下列情形下,飞行机组必需成员可以离开指定的值勤位置： 1.3.1. 为了完成与飞机运行有关的任务需要该机组成员离开时； 1.3.2. 机组成员的离开与生理需要有关时； 1.3.3. 达到机长确定的轮换休息时间，并按照下述规定接替工作： 1.3.3.1. 对于机长,在航路巡航飞行期间,可以由巡航机长接替; 1.3.3.2. 对于副驾驶,可以由有资格在航路飞行期间担任副驾驶的飞行 员接替。但是接替的飞行员不必满足本手册关于近期经历的 限制。
# file2_195_第 121.541 条_(b)
# 在操作位置上的飞行机组成员 在下列情形下， 飞行机组必需成员可以离开指定的值 勤位置： (1)为了完成与飞机运行有关的任务需要该机组成员离 开时； (2)机组成员的离开与生理需要有关时； (3)机组成员到了轮换休息时间， 并按照下列规定有人接 替工作时：
# 0.7825898708343293
# ------------------------------------------
# file1_140_2.1.
# 对于商业运行， 自旅客登机开始至所有旅客离机的时间段内， 除机组人员和经 批准人员外，任何人不得进入驾驶舱；
# file2_197_第 121.545 条_(a)
# 进入驾驶舱的人员的限制 下列人员可以进入飞机驾驶舱， 但并不限制机长为了 安全而要求其离开驾驶舱的应急决定权： (1)机组成员； (2)正在执行任务的局方监察员或者局方委任代表； (3)得到机长允许并且其进入驾驶舱对于安全运行是必 需或者有益的人员； (4)经机长同意，并经合格证持有人特别批准的其他人 员。
# 0.7613547815343449
# ------------------------------------------
# file1_141_2.2.
# 下列人员可以进入驾驶舱，但机长有权为了安全而要求其离开驾驶舱： 2.2.1. 机组成员； 2.2.2. 正在执行任务的局方监察员、局方委任代表或公司飞行检查员； 2.2.3. 得到机长允许并且其进入驾驶舱对于安全运行是必需或者有益的人员 包括： 2.2.3.1. 局方批准进行空中交通管制程序观察的空中交通管制员； 2.2.3.2. 经运行副总裁批准进行航线实习的公司飞行签派员、航行情 报员、航空气象员、飞机性能工程人员； 2.2.3.3. 经机长请求并核实身份的航空器维修人员； 2.2.3.4. 应急情况下实施紧急医疗救助的医护人员； 2.2.3.5. 其他因空中应急、救助、维修、飞行技术指导等需进入驾驶 舱的人员。 2.2.4. 经机长同意，并获得公司批准的其他人员。
# file2_197_第 121.545 条_(a)
# 进入驾驶舱的人员的限制 下列人员可以进入飞机驾驶舱， 但并不限制机长为了 安全而要求其离开驾驶舱的应急决定权： (1)机组成员； (2)正在执行任务的局方监察员或者局方委任代表； (3)得到机长允许并且其进入驾驶舱对于安全运行是必 需或者有益的人员； (4)经机长同意，并经合格证持有人特别批准的其他人 员。
# 0.8470843717339733
# ------------------------------------------
# file1_143_2.4.
# 被准许进入驾驶舱的非机组人员， 应当在客舱内有供该人员使用的座位， 但按 照3.1 在驾驶舱有供其使用的座位的人员除外。
# file2_197_第 121.545 条_(b)
# 进入驾驶舱的人员的限制 被准许进入驾驶舱的非机组人员， 应当在客舱内有供 该人员使用的座位，但下列人员在驾驶舱有供其使用的座位 时除外： (1)正在对飞行操作进行检查或者观察的局方监察员或 者经授权的局方委任代表； (2)局方批准进行空中交通管制程序观察的空中交通管 制员； (3)合格证持有人雇用的持有执照的航空人员； (4)其他合格证持有人雇用的持有执照的航空人员， 该人 员得到运行该飞机的合格证持有人的批准； (5)运行该飞机的合格证持有人的雇员， 其职责与飞行运 作的实施或者计划、或者空中监视飞机设备或者操作程序直 接有关，此人进入驾驶舱对于完成其任务是必需的，并且已 得到在运行手册中列出的有批准权的主管人员的书面批准； (6)该飞机或者其部件的制造厂家技术代表， 其职责与空 中监视飞机设备或者操作程序直接有关，进入驾驶舱对于完 成其职责是必需的，并已得到该合格证持有人在运行手册中 列出的有批准权的运行部门负责人的书面批准。
# 0.7649648633897356
# ------------------------------------------
# file1_144_2.5.
# 对于2.2.2、 2.2.3、 2.2.4 中规定的人员进入驾驶舱的， 应当采取下列安保措施： 2.5.1. 航空安全员应当核对证件确保人证相符，同时开启执勤记录仪全程记 录人员进出情况； 2.5.2. 如驾驶舱或客舱环境不能满足安全条件时，人员应暂缓进入驾驶舱； 2.5.3. 每次进入驾驶舱的人数不得超过驾驶舱内空余的观察员座位数，最大 不超过两人； 2.5.4. 人员在驾驶舱内停留期间，在驾驶舱内的机组人员不得少于两人且确 保驾驶舱门锁闭，驾驶舱门口应当至少有一名航空安全员或客舱乘务 员值守； 2.5.5. 驾驶舱门开启期间，机组应当做好驾驶舱的保护。
# file2_197_第 121.545 条
# 进入驾驶舱的人员的限制 (a)下列人员可以进入飞机驾驶舱， 但并不限制机长为了 安全而要求其离开驾驶舱的应急决定权： (1)机组成员； (2)正在执行任务的局方监察员或者局方委任代表； (3)得到机长允许并且其进入驾驶舱对于安全运行是必 需或者有益的人员； (4)经机长同意，并经合格证持有人特别批准的其他人 员。 (b)被准许进入驾驶舱的非机组人员， 应当在客舱内有供 该人员使用的座位，但下列人员在驾驶舱有供其使用的座位 时除外： (1)正在对飞行操作进行检查或者观察的局方监察员或 者经授权的局方委任代表； (2)局方批准进行空中交通管制程序观察的空中交通管 制员； (3)合格证持有人雇用的持有执照的航空人员； (4)其他合格证持有人雇用的持有执照的航空人员， 该人 员得到运行该飞机的合格证持有人的批准； (5)运行该飞机的合格证持有人的雇员， 其职责与飞行运 作的实施或者计划、或者空中监视飞机设备或者操作程序直 接有关，此人进入驾驶舱对于完成其任务是必需的，并且已 得到在运行手册中列出的有批准权的主管人员的书面批准； (6)该飞机或者其部件的制造厂家技术代表， 其职责与空 中监视飞机设备或者操作程序直接有关，进入驾驶舱对于完 成其职责是必需的，并已得到该合格证持有人在运行手册中 列出的有批准权的运行部门负责人的书面批准。
# 0.7840925390618555
# ------------------------------------------
# file1_146_2.7.
# 机长允许除2.2 中规定以外的人员进入驾驶舱时，其他机组成员应予以劝阻。
# file2_197_第 121.545 条_(a)
# 进入驾驶舱的人员的限制 下列人员可以进入飞机驾驶舱， 但并不限制机长为了 安全而要求其离开驾驶舱的应急决定权： (1)机组成员； (2)正在执行任务的局方监察员或者局方委任代表； (3)得到机长允许并且其进入驾驶舱对于安全运行是必 需或者有益的人员； (4)经机长同意，并经合格证持有人特别批准的其他人 员。
# 0.7506704628307667
# ------------------------------------------
# file1_149_3.1.
# 允许使用驾驶舱观察员座位的人员范围，包括： 3.1.1. 机组成员； 3.1.2. 正在对飞行操作进行检查或者观察的局方监察员或者经授权的局方委 任代表（可优先选择任意观察员座椅） ； 3.1.3. 局方批准进行空中交通管制程序观察的空中交通管制员； 3.1.4. 公司空勤人员以及随机放行的维修工程人员； 3.1.5. 进行航线实习的公司飞行签派员、公司专职模拟机教员； 3.1.6. 其他航空公司雇用的持有执照航空人员，该人员得到公司总裁的批准； 3.1.7. 本公司雇员，其职责与飞行运作的实施或者计划、或者空中监视飞机 设备或者操作程序直接有关，此人进入驾驶舱对于完成其任务是必需 的，并且已得到公司总裁的书面批准； 3.1.8. 该飞机或者其部件的制造厂家技术代表，其职责与空中监视飞机设备 或者操作程序直接有关，进入驾驶舱对于完成其职责是必需的，并已 得到公司总裁的书面批准。
# file2_197_第 121.545 条_(b)
# 进入驾驶舱的人员的限制 被准许进入驾驶舱的非机组人员， 应当在客舱内有供 该人员使用的座位，但下列人员在驾驶舱有供其使用的座位 时除外： (1)正在对飞行操作进行检查或者观察的局方监察员或 者经授权的局方委任代表； (2)局方批准进行空中交通管制程序观察的空中交通管 制员； (3)合格证持有人雇用的持有执照的航空人员； (4)其他合格证持有人雇用的持有执照的航空人员， 该人 员得到运行该飞机的合格证持有人的批准； (5)运行该飞机的合格证持有人的雇员， 其职责与飞行运 作的实施或者计划、或者空中监视飞机设备或者操作程序直 接有关，此人进入驾驶舱对于完成其任务是必需的，并且已 得到在运行手册中列出的有批准权的主管人员的书面批准； (6)该飞机或者其部件的制造厂家技术代表， 其职责与空 中监视飞机设备或者操作程序直接有关，进入驾驶舱对于完 成其职责是必需的，并已得到该合格证持有人在运行手册中 列出的有批准权的运行部门负责人的书面批准。
# 0.7563769729791909
# ------------------------------------------
# file1_152_4.1.
# 对于商业运行， 自旅客登机开始至全部旅客完成下机的时间段内， 应关闭并锁 定驾驶舱门；
# file2_232_第 121.605 条_(a)
# 驾驶舱门的关闭与锁定 载客飞机的机长应当保证， 如果驾驶舱和客舱有门分 隔的话，在飞行期间关闭并锁定该门。但下列情况除外： (1)起飞和着陆期间， 如果驾驶舱门是通往必需的旅客应 急出口或者地板高度出口的通道； (2)在执行任务的机组成员需要进入客舱或者驾驶舱时， 或者按照本规定第121.545 条规定准许进入驾驶舱的人有必 要进入驾驶舱时。
# 0.7668297122563791
# ------------------------------------------
# file1_157_5.2.
# 只有由于工作或生理原因，方允许一名飞行机组必需成员离开指定的值勤位 置，但应在最短的时间内回到岗位上。
# file2_195_第 121.541 条_(b)
# 在操作位置上的飞行机组成员 在下列情形下， 飞行机组必需成员可以离开指定的值 勤位置： (1)为了完成与飞机运行有关的任务需要该机组成员离 开时； (2)机组成员的离开与生理需要有关时； (3)机组成员到了轮换休息时间， 并按照下列规定有人接 替工作时：
# 0.8077501330376765
# ------------------------------------------
# file1_158_5.3.
# 留在驾驶舱的飞行员必须保持对飞机的监控，不得从事与飞行无关的活动。
# file2_194_第 121.539 条_(b)
# 机组成员的值勤要求 在飞行的关键阶段， 飞行机组成员不得从事可能分散 飞行机组其他成员工作精力，或者可能干扰其他成员正确完 成这些工作的活动，机长也不得允许其从事此种活动。这些 活动包括进餐、在驾驶舱无关紧要的交谈、在驾驶舱和客舱 乘务员之间无关紧要的通话、阅读与正常飞行无关的刊物 等。
# 0.7507234685827744
# ------------------------------------------
# file1_159_5.4.
# 当机长离开驾驶舱时， 机长应授权副驾驶负责航空器的控制并处理任何特殊状 态下的飞行，直至机长返回后由机长行使其职权。
# file2_195_第 121.541 条_(i)
# 在操作位置上的飞行机组成员 对于指定的机长，在航路巡航飞行期间，可以由符合 本规则第121.451 条(a)款规定条件的巡航机长接替； (ii)对于指定的副驾驶， 可以由有资格在航路飞行期间担 任副驾驶的驾驶员接替。但是，接替的驾驶员不必满足本规 则第121.461 条(b)款中关于近期经历的要求。
# 0.7684441778330109
# ------------------------------------------
# file1_160_5.5.
# 当仅有两名飞行员在驾驶舱内值勤时， 其中一名在值勤岗位的飞行员由于工作 或生理原因需要离开驾驶舱时， 应指定不在值勤岗位的飞行机组成员或由机长 通知乘务长指定2 号客舱乘务员进入驾驶舱，直至该名飞行员返回。
# file2_195_第 121.541 条_(b)
# 在操作位置上的飞行机组成员 在下列情形下， 飞行机组必需成员可以离开指定的值 勤位置： (1)为了完成与飞机运行有关的任务需要该机组成员离 开时； (2)机组成员的离开与生理需要有关时； (3)机组成员到了轮换休息时间， 并按照下列规定有人接 替工作时：
# 0.7604593158653878
# ------------------------------------------
# file1_161_5.6.
# 进入驾驶舱的客舱乘务员应在观察员座椅就坐并系好安全带； 同时应熟悉 《驾 驶舱-非必需机组成员简介》 。
# file2_197_第 121.545 条_(b)
# 进入驾驶舱的人员的限制 被准许进入驾驶舱的非机组人员， 应当在客舱内有供 该人员使用的座位，但下列人员在驾驶舱有供其使用的座位 时除外： (1)正在对飞行操作进行检查或者观察的局方监察员或 者经授权的局方委任代表； (2)局方批准进行空中交通管制程序观察的空中交通管 制员； (3)合格证持有人雇用的持有执照的航空人员； (4)其他合格证持有人雇用的持有执照的航空人员， 该人 员得到运行该飞机的合格证持有人的批准； (5)运行该飞机的合格证持有人的雇员， 其职责与飞行运 作的实施或者计划、或者空中监视飞机设备或者操作程序直 接有关，此人进入驾驶舱对于完成其任务是必需的，并且已 得到在运行手册中列出的有批准权的主管人员的书面批准； (6)该飞机或者其部件的制造厂家技术代表， 其职责与空 中监视飞机设备或者操作程序直接有关，进入驾驶舱对于完 成其职责是必需的，并已得到该合格证持有人在运行手册中 列出的有批准权的运行部门负责人的书面批准。
# 0.75043732046286
# ------------------------------------------
# file1_163_6.
# 驾驶舱物品的固定 飞行机组应当确保每项设备、每件装在飞机驾驶舱的机组行李（含大件物品） ，能够 承受相应于该飞机型号合格审定应急着陆状态的载荷系数下的载荷，并保证其摆放 的稳定性，不至于因移动而造成危害。 （空白） 飞行前准备和飞行后讲评
# file2_222_第 121.581 条
# 客舱和驾驶舱内行李和物品的固定 合格证持有人应当提供手段并采取措施，使厨房内每项 设备、停用的服务车、每件装在客舱或者驾驶舱的机组行李 和物品能够： (a)承受相应于该飞机型号合格审定应急着陆状态的载 荷系数下的载荷； (b)不至于因移动而造成对安全的危害。
# 0.7791326307128524
# ------------------------------------------
# file1_168_1.4.
# 未按本章节规定完成飞行前准备的机组成员不得参加航班运行。
# file2_228_第 121.591 条_(e)
# 无需符合本规则载客要求载运的人员 机长可以批准本条(a)款所述的乘员进入飞机驾驶舱。
# 0.757809620662579
# ------------------------------------------
# file1_172_2.3.
# 对于飞行机组成员在预先准备过程中应研究起飞、 降落和备降机场、 航线或者 飞行区域有关资料， 初步了解飞机状况， 阅读公司的相关通告， 了解天气形势， 确认EFB 终端设备中航图及手册资料的有效性以及检查云执照经历信息填写 与确认情况等。
# file2_74_第 121.315 条_(b)
# 驾驶舱检查单 这些经批准的检查单应当至少包括在起动发动机、 起 飞或者着陆之前，以及在发动机和系统出现了紧急情况时， 飞行机组成员为确保安全应当进行的每一项检查。检查单的 设计应当使飞行机组成员无需依赖于对所要进行检查的项 目的记忆。
# 0.7628933066978288
# ------------------------------------------
# file1_177_3.3.
# 机长负责领取并核对当日及过夜（如适用）飞行任务书，确认个人信息准确， 确保所持有飞行任务书中各内容、要素齐全有效；
# file2_41_第 121.125 条_(i)
# 飞行跟踪系统 确保对每次飞行的始发机场和目的地机场的飞行进程 进行适当的监控，包括对中途停留机场和改航备降机场飞行 进程的监控，以及对在这些机场所需的维修或者机械延误进 行适当的监控； (ii)确保机长能够得到安全飞行必需的所有资料。
# 0.7510239520109113
# ------------------------------------------
# file1_179_3.5.
# 机长组织召开飞行机组准备会，了解机组成员的技术状况，明确机组分工，检 查并确认各类证照/文件以及飞行装具齐全有效、着装/仪表符合公司规定，检 查确认个人EFB 终端设备中软件及数据库版本最新有效。同时，机长应对每 位机组必需成员云执照中的相关信息进行检查确认；
# file2_41_第 121.125 条_(i)
# 飞行跟踪系统 确保对每次飞行的始发机场和目的地机场的飞行进程 进行适当的监控，包括对中途停留机场和改航备降机场飞行 进程的监控，以及对在这些机场所需的维修或者机械延误进 行适当的监控； (ii)确保机长能够得到安全飞行必需的所有资料。
# 0.7539893465068935
# ------------------------------------------
# file1_182_3.8.
# 执行国际（地区）航班时，全体机组成员还应检查核对各自护照、港澳台通行 证等证件携带情况与有效性；
# file2_116_第 121.381 条_(b)
# 航空人员的条件及限制 按照要求携带证件的每个航空人员， 应当在局方检查 时出示证件。
# 0.7566568978743996
# ------------------------------------------
# file1_183_3.9.
# 飞行机组应领取/下载飞行资料，包括飞行计划、气象资料、航行通告、签派 单等，检查并确认齐全有效；
# file2_241_第 121.626 条_(a)
# 补充运行的设施和服务 开始飞行前， 每个机长应当获得所有可能影响飞行安 全的有关机场条件和导航设施不正常情况的最新报告或者 信息。
# 0.7503458484824093
# ------------------------------------------
# file1_184_3.10.
# 飞行机组成员应阅读气象简报，了解起飞机场、航路、目的地机场及备降场天 气实况及预报，知晓可能发生空中颠簸的区域和强度，拟订安全飞行方案；
# file2_239_第 121.623 条_(b)
# 气象条件的熟悉 对于补充运行，机长应当完全熟悉所飞航路、机场的 气象实况报告和预报，否则不得开始该次飞行。
# 0.7692835740893668
# ------------------------------------------
# file1_186_3.12.
# 机长应确认飞机适航状态，对于保留故障根据MEL/CDL 制定相关预案；
# file2_252_第 121.645 条_(b)
# 在不安全状况中继续飞行 如果用于该种运行的任何仪表或者某一设备在航路 上失效，机长应当遵循在合格证持有人手册中规定的适用于 该情况的经批准程序。
# 0.7536076805820213
# ------------------------------------------
# file1_188_3.14.
# 机长应检查运行飞行计划，根据飞机状况、天气报告等，确定飞机燃油信息， 由机长与飞行签派员共同在签派单上签字（手工或电子形式） ；
# file2_267_第 121.677 条
# 国内、国际定期载客运行的签派责任 合格证持有人应当根据授权的飞行签派员所提供的信 息，为两个规定地点之间的每次飞行编制签派单。机长和授 权的飞行签派员应当在签派单上签字。机长和授权的飞行签 派员均认为该次飞行能安全进行时，他们才能签字。对于某 一次飞行，飞行签派员可以委托他人签署放行单，但是不得 委托他人行使其签派权。
# 0.7536155893728438
# ------------------------------------------
# file1_189_3.15.
# 为使飞行机组和客舱机组形成一个团队概念，加强沟通和配合，统一认识，牢 记职责，保证运行安全和服务质量。机长应召集所有飞行机组、客舱乘务员及 航空安全员进行协同准备，至少包括以下内容： 3.15.1. 机组成员介绍， （主任）乘务长和航空安全员向机长报告准备完成情 况，并报告各组员的装具、证照、文件及资料携带核查情况。 3.15.2. 机长通报因公加入机组人员、 非因公加入机组人员以及该航班是否为 扩编机组运行。 3.15.3. 机组交叉检查《飞行任务书》以及《出入境飞机及员工登记表》 、 《出 入境航空器工作人员携带物品清单》 （如适用） ， 确认机组成员和加入 机组人员的信息准确有效。 3.15.4. 机长通报预计滑行时间、飞行时间、到达巡航高度时间、可用服务时 间、有无延误情况。 3.15.5. 机长通报航班运行天气状况， 是否存在恶劣天气影响， 告知客舱机组 拟执行的除防冰程序、 甩冰程序以及已获取的颠簸区域、 强度和持续 时间，协同制定相关预案。 3.15.6. 机长通报飞机状况以及客舱设备故障保留情况，协同制定应对方案。 3.15.7. 机长明确正常情况与非正常情况下机组成员间的联络要求。 3.15.8. 机长按需明确发生紧急情况时驾驶舱联系客舱的术语及指令。 3.15.9. 如发生机组失能情况下， 机上指挥权的接替次序： 责任机长→巡航机 长→副驾驶→ （主任） 乘务长→区域乘务长→客舱乘务员→航空安全 员。 （按等级排列，高者优先） 。 3.15.10. 如发生PED 以及锂电池起火情况，明确沟通关键环节，要求先处置 再报告。 3.15.11. （主任）乘务长通报要客、担架旅客以及机上用氧旅客信息，以及本 航班服务程序所需时间，按需协同保障预案。 3.15.12. 航空安全员通报航线派遣标准、押解犯罪嫌疑人（罪犯）及遣返旅客 情况、当前空防形势和重点关注事项，飞机安保检查的各项要求，复 习驾驶舱门密码。 3.15.13. 机长根据空防形势组织协同突发事件/非法干扰/扰乱航空器秩序等行 为的处置预案，明确机组分工，确定联络暗号和处置程序。 3.15.14. 需各岗位协同配合的其他事宜。
# file2_133_第 121.419 条
# 机组成员的应急生存训练 (a)机组必需成员应当针对所飞飞机的型别、布局及所实 施的每种运行，完成本条规定的应急生存训练，以保证机组 成员在紧急情况下或者出现要求应急撤离、水上迫降的情况 时能够胜任所担负的任务与职责。 (b)应急生存训练应当包括下列内容： (1)机组成员在发生紧急情况时其他机组成员的分工和 职责，包括机组成员之间的协调配合； (2)下列应急设备的所在位置、功能和使用方法： (i)用于水上迫降和撤离的设备； (ii)急救设备； (iii)手提灭火器，重点是适用不同类型失火的灭火器型 号； (iv)配有撤离滑梯或者滑梯救生筏的应急出口， 重点是不 利情况下应急出口的操作； (v)氧气设备。 (3)紧急情况的处理，包括下列内容： (i)急剧释压； (ii)空中或者地面的失火和烟雾控制程序， 重点是找到客 舱区域(包括所有厨房、服务舱、升降机、盥洗室和放置电影 屏幕处)内的电气设备和相关的断路器； (iii)水上迫降或者其他形式的撤离，包括在紧急情况下， 撤离那些需要由别人帮助才能迅速移至某一出口的人员； (iv)旅客或者机组人员生病、受伤等非正常情况的处置， 包括熟悉应急医疗设备； (v)劫机和其他非法干扰情况的处理。 (4)回顾和讨论以前与实际紧急情况有关的飞行事故和 事件； (5)客舱乘务员还应当掌握下列内容： (i)在客舱里允许和禁止装载的危险品种类； (ii)与客舱安全职责相关的有关人的行为能力的知识， 包 括飞行机组和客舱机组成员之间的配合。 (c)每一机组成员应当在规定的训练期限内，使用配置在 其所服务的每一型别飞机上的应急设备，完成下列应急演 练： (1)一次性应急演练。在初次转入该机型的训练中，每个 机组成员应当完成下列一次性应急演练： (i)至少一次佩戴防护式呼吸装置(PBE)的演练。 在该次演 练中，该员应当佩戴该型飞机机载防护式呼吸装置(PBE)或 者经批准的模拟设备，使用一个型号的机载手提灭火器或者 经批准的灭火器去扑灭实际或者模拟的失火，该灭火器应当 适合所扑灭的失火的类型； (ii)至少一次经批准的灭火演练。在该次演练中，该员至 少应当使用一个型号的机载手提灭火器或者经批准的灭火 器去扑灭实际或者模拟的失火，该灭火器应当适合所扑灭的 失火的类型。如果该机组成员在上述(i)目的防护式呼吸装置 (PBE)演练中扑灭的是实际失火，则本目规定的灭火演练不 必再进行； (iii)每人使用至少一种机载或者经批准的用于训练的应 急撤离滑梯进行撤出飞机的应急撤离演练。机组成员可以观 察飞机出口在应急方式下被打开以及与之相连的出口滑梯 或者滑梯救生筏被放出并充气的过程，或者亲自操作设备完 成这些动作。 (2)附加的应急演练。 下列训练应当在该机型初次训练时 完成，以后每24 个日历月定期复训一次。在训练中应当完 成下列第(i)至(v)目的应急演练和设备操作练习，并完成对第 (vi)至(ⅸ)目演练的观察： (i)每种类型应急出口的正常和应急方式操作，包括放出 应急撤离滑梯所要求的动作和力量； (ii)安装的每种型号手提灭火器； (iii)每种类型的应急氧气系统，包括防护式呼吸装置 (PBE)； (iv)个人漂浮装置的穿戴、使用和充气(如适用)； (v)水上迫降(如适用)，至少包括驾驶舱的准备工作和程 序、 机组的协调配合、 对旅客的简要说明和客舱的准备工作、 救生衣的穿戴和充气、救生绳的使用、组织旅客和机组登上 救生筏或者滑梯救生筏； (vi)从飞机(或者训练设施)上取出每种型号的救生筏并 充气(如适用)； (vii)将每种型号的滑梯救生筏从一舱门转移到另一舱 门； (viii)将每种型号的滑梯救生筏展开、充气和从飞机或者 训练设施上脱开； (ⅸ)应急撤离，包括机组的准备工作和程序、滑梯的使 用。 (d)在3,000 米(10,000 英尺)以上高度的飞行中服务的机 组成员，应当具有缺氧影响以及增压飞机释压后所产生的生 理现象等方面的知识。 对于在7,600 米(25,000 英尺)以上高度 的飞行中服务的机组成员，还应当接受下列内容的教育： (1)呼吸原理； (2)生理组织缺氧； (3)高空不供氧情况下的有知觉持续时间； (4)气体膨胀； (5)气泡的形成； (6)减压的物理现象和事件。
# 0.7512829429156497
# ------------------------------------------
# file1_196_4.1.
# 对于始发航班或过站时间1 小时及以上的非始发航班， 全体机组成员应在计划 /预计起飞时刻前至少1 小时到达现场，对于过站时间不足1 小时的非始发航 班，全体机组成员应不晚于前段航班开舱门时刻到达停机位。
# file2_120_第 121.393 条_(a)
# 在经停站旅客不下飞机时对机组成员的 要求 在中途过站停留时，如果乘坐该机的旅客仍停留在飞机 上，合格证持有人应当遵守下列规定： 如果保留在飞机上的客舱乘务员数量少于本规则第 121.391 条(a)款要求的数量，则合格证持有人应当采取下列 措施： (1)保证飞机发动机关车并且至少保持打开一个地板高 度出口，供旅客下飞机； (2)保留在飞机上的客舱乘务员数量应当至少是本规则 第121.391 条(a)款要求数量的一半，有小数时，舍去小数， 但至少为1 人； (3)可以用其他人员代替要求的客舱乘务员， 代替客舱乘 务员的人员应当是符合本规则第121.419 条应急撤离训练要 求的合格人员且应当能够为旅客所识别。
# 0.750539799713504
# ------------------------------------------
# file1_200_5.3.
# 对于飞行中出现的问题或事件，机长、客舱（主任）乘务长、航空安全员应按 照规定履行相应的报告职责。 （空白） 地面准备
# file2_194_第 121.539 条_(c)
# 机组成员的值勤要求 在飞行期间， 合格证持有人制定的服务程序不得影响 客舱乘务员履行安全职责。
# 0.785201346437316
# ------------------------------------------
# file1_203_1.2.
# 客舱机组登机后应完成客舱应急设备的飞行前检查，确认应急设备数量和位 置，并确保其完好有效、易获取且可以使用。
# file2_69_第 121.310 条_(l)
# 附加应急设备 手电筒。载客飞机应当装备有从每个客舱乘务员座位 处易于接近的手电筒及其储放装置。
# 0.7508440969347959
# ------------------------------------------
# file1_216_3.3.
# 飞行机组成员应对加注燃油量进行确认、核实燃油型号、确定燃油冰点温 度，并对燃油加注过程进行持续监控。如需实施旅客登机、下机或在飞机上 时的加油程序，机长应配合燃油加注工作人员在载客加油通知单上完成签字 确认。
# file2_205_第 121.555 条_(b)
# 飞行中燃油管理 机长必须随时确保机上剩余可用燃油量， 不低于飞往 可以安全着陆的机场的所需油量与计划最后储备油量之和。
# 0.7514958115287466
# ------------------------------------------
# file1_224_5.1.
# 客舱乘务员应根据《客舱乘务员手册》及公司服务政策要求开展机上准备工 作。
# file2_194_第 121.539 条_(c)
# 机组成员的值勤要求 在飞行期间， 合格证持有人制定的服务程序不得影响 客舱乘务员履行安全职责。
# 0.7563400719604444
# ------------------------------------------
# file1_225_5.2.
# 准备过程中，客舱乘务员应根据机供品的标准配备数量进行检查核对，确保 摆放的机供品不得超过存放区域最大载荷标准。
# file2_222_第 121.581 条
# 客舱和驾驶舱内行李和物品的固定 合格证持有人应当提供手段并采取措施，使厨房内每项 设备、停用的服务车、每件装在客舱或者驾驶舱的机组行李 和物品能够： (a)承受相应于该飞机型号合格审定应急着陆状态的载 荷系数下的载荷； (b)不至于因移动而造成对安全的危害。
# 0.7667645755358878
# ------------------------------------------
# file1_227_6.1.
# 仅在（主任）乘务长确认客舱准备完成以及航空安全员确认安保检查完成 后，责任机长方可允许旅客登机。
# file2_228_第 121.591 条_(e)
# 无需符合本规则载客要求载运的人员 机长可以批准本条(a)款所述的乘员进入飞机驾驶舱。
# 0.7658807238046426
# ------------------------------------------
# file1_229_6.3.
# 旅客登机时，客舱乘务员应均匀分布在客舱每对出口附近，以便在紧急情况 下最有效地帮助旅客撤离。
# file2_119_第 121.391 条_(f)
# 客舱乘务员 在起飞和着陆过程中，本条要求的客舱乘务员应当尽 可能地靠近所要求的地板高度出口，而且应当在整个客舱内 均匀分布，以便在应急撤离时最有效地疏散旅客。在滑行期 间，本条要求的客舱乘务员，除完成保障飞机和机上人员安 全的任务外，其他时间应当坐在其值勤位置并系好安全带和 肩带。
# 0.7739535889533409
# ------------------------------------------
# file1_230_6.4.
# 登机过程中，客舱乘务员应对旅客行李的尺寸、数量进行确认，对于超规行 李应予以拦截，并通知地面保障人员进行处理。
# file2_233_第 121.607 条_(a)
# 手提行李 合格证持有人允许旅客携带手提行李登机时， 应当按 照其运行规范内规定的手提行李程序，对每个旅客的手提行 李进行检查，以控制其尺寸、重量和数量。如果旅客的手提 行李超过合格证持有人运行规范内手提行李程序规定的允 许量，则该旅客不得登机。
# 0.7704360779070497
# ------------------------------------------
# file1_231_6.5.
# 旅客开始登机至舱门关闭期间，除正常报告程序和影响安全运行的事项外， 飞行机组与客舱机组应尽可能保持双向静默，避免互相干扰。
# file2_194_第 121.539 条_(b)
# 机组成员的值勤要求 在飞行的关键阶段， 飞行机组成员不得从事可能分散 飞行机组其他成员工作精力，或者可能干扰其他成员正确完 成这些工作的活动，机长也不得允许其从事此种活动。这些 活动包括进餐、在驾驶舱无关紧要的交谈、在驾驶舱和客舱 乘务员之间无关紧要的通话、阅读与正常飞行无关的刊物 等。
# 0.7506792653378863
# ------------------------------------------
# file1_233_6.7.
# 当发生以下情况时，责任机长必须指令进行全部安保检查： 6.7.1. 登机后公安、安检怀疑旅客存在漏检时； 6.7.2. 登机后机组人员对旅客的安检质量产生质疑； 6.7.3. 未经安全检查的人员和物品进入航空器； 6.7.4. 其他任何可能危及安全的情况。
# file2_252_第 121.645 条_(b)
# 在不安全状况中继续飞行 如果用于该种运行的任何仪表或者某一设备在航路 上失效，机长应当遵循在合格证持有人手册中规定的适用于 该情况的经批准程序。
# 0.7510615198985641
# ------------------------------------------
# file1_234_6.8.
# 如确定执行局部安保检查/全部安保检查程序，飞行机组应将相关情况报告公 司AOC。 舱门的关闭与打开
# file2_232_第 121.605 条_(b)
# 驾驶舱门的关闭与锁定 合格证持有人应当制定程序或者方法， 以便客舱乘务 员： (1)在客舱有可疑活动或者安保措施被突破时能够有效 地通知飞行机组； (2)在飞行机组失去能力时能够进入驾驶舱。
# 0.7770580735722614
# ------------------------------------------
# file1_240_1.5.
# 舱门关闭后因其他原因需重新开启舱门时， （主任）乘务长应及时将情况向机 长报告，经机长同意后，客舱机组应按《客舱乘务员手册》要求进行滑梯和舱 门开启的操作。
# file2_232_第 121.605 条_(b)
# 驾驶舱门的关闭与锁定 合格证持有人应当制定程序或者方法， 以便客舱乘务 员： (1)在客舱有可疑活动或者安保措施被突破时能够有效 地通知飞行机组； (2)在飞行机组失去能力时能够进入驾驶舱。
# 0.7651424847358191
# ------------------------------------------
# file1_254_2.1.
# 飞行结束后，飞行机组应如实填写云执照飞行经历记录以及《飞行记录本》 。
# file2_278_第 121.703 条
# 通信记录 合格证持有人应当记录与其飞行机组成员之间每次航 路上使用满足本规则第121.97 条通讯设备联系的记录， 并将 该记录至少保存30 天。
# 0.7537050878029332
# ------------------------------------------
# file1_257_3.1.
# 如地面电源车、辅助动力装置或发动机在运转中，但缺少专业人员负责时，飞 行机组成员不得离机。
# file2_195_第 121.541 条_(b)
# 在操作位置上的飞行机组成员 在下列情形下， 飞行机组必需成员可以离开指定的值 勤位置： (1)为了完成与飞机运行有关的任务需要该机组成员离 开时； (2)机组成员的离开与生理需要有关时； (3)机组成员到了轮换休息时间， 并按照下列规定有人接 替工作时：
# 0.7823886069336202
# ------------------------------------------
# file1_258_3.2.
# 任何机组成员需要离机，必须经机长同意并及时返回。
# file2_195_第 121.541 条_(b)
# 在操作位置上的飞行机组成员 在下列情形下， 飞行机组必需成员可以离开指定的值 勤位置： (1)为了完成与飞机运行有关的任务需要该机组成员离 开时； (2)机组成员的离开与生理需要有关时； (3)机组成员到了轮换休息时间， 并按照下列规定有人接 替工作时：
# 0.7563094387426129
# ------------------------------------------
# file1_259_3.3.
# 驾驶舱应始终保持至少有一名飞行机组成员，并完成下列工作： 3.3.1. 完成驾驶舱的各项准备工作； 3.3.2. 监控APU、地面电源、气源车等工作情况； 3.3.3. 禁止未经批准的人员进入驾驶舱； 3.3.4. 了解航路及目的地机场和备降机场天气状况以及航行通告等信息， 办理 放行手续； 3.3.5. 遇有不正常情况或飞机故障，应及时与机务联系，尽快处置。
# file2_195_第 121.541 条
# 在操作位置上的飞行机组成员 (a)除本条(b)款规定外， 在驾驶舱值勤的每个飞行机组必 需成员，在飞行过程中应当坐在指定的值勤位置并系好安全 带；在起飞和着陆过程中应当坐在指定的值勤位置并系好安 全带和肩带。对于驾驶员之外的飞行机组成员，除肩带妨碍 执行任务时可以松开肩带以外(但必须系紧座椅安全带)，在 起飞和着陆阶段也应当始终系好肩带。 (b)在下列情形下， 飞行机组必需成员可以离开指定的值 勤位置： (1)为了完成与飞机运行有关的任务需要该机组成员离 开时； (2)机组成员的离开与生理需要有关时； (3)机组成员到了轮换休息时间， 并按照下列规定有人接 替工作时： (i)对于指定的机长，在航路巡航飞行期间，可以由符合 本规则第121.451 条(a)款规定条件的巡航机长接替； (ii)对于指定的副驾驶， 可以由有资格在航路飞行期间担 任副驾驶的驾驶员接替。但是，接替的驾驶员不必满足本规 则第121.461 条(b)款中关于近期经历的要求。 (c)对于执行起飞和落地任务飞行机组成员在过渡高度 (或者高)以下，应当通过吊杆式或者喉式麦克风进行通信。
# 0.7523446003111655
# ------------------------------------------
# file1_260_3.4.
# 中途过站经停时， 除非机场要求不得下机， 客舱机组应通知所有旅客在航空器 停靠好以后， 带好所有手提行李和个人物品离开航空器， 并配合航空安全员进 行安保检查工作，防止不明外来、遗留物品留在客舱。
# file2_120_第 121.393 条_(b)
# 在经停站旅客不下飞机时对机组成员的 要求 在中途过站停留时，如果乘坐该机的旅客仍停留在飞机 上，合格证持有人应当遵守下列规定： 如果在过站时该飞机上只保留1名客舱乘务员或者其 他合格人员，则该客舱乘务员或者其他合格人员所在的位置 应当符合经局方批准的该合格证持有人运行程序的规定。如 果在飞机上保留1 名以上客舱乘务员或者其他合格人员，这 些客舱乘务员或者其他合格人员应当均匀分布在飞机客舱 内，以便在紧急情况下最有效地帮助旅客撤离。
# 0.7790150696348364
# ------------------------------------------
# file1_261_3.5.
# 在中途过站停留时， 如果乘坐该机的旅客仍停留在飞机上， 且保留在飞机上的 客舱乘务员数量少于该机型客舱乘务员最低配备数，则应遵守下列要求： 3.5.1. 保证飞机发动机关车并且至少保持打开一个地板高度出口， 供旅客下飞 机。 3.5.2. 至少保留客舱乘务员数量要求： 机型 至少保留客舱乘务员数 A320CEO/A320NEO 2 A321CEO 4 A321NEO ACF 3 B787-9 5 3.5.3. 可以用当班航空安全员代替要求的客舱乘务员。
# file2_120_第 121.393 条_(a)
# 在经停站旅客不下飞机时对机组成员的 要求 在中途过站停留时，如果乘坐该机的旅客仍停留在飞机 上，合格证持有人应当遵守下列规定： 如果保留在飞机上的客舱乘务员数量少于本规则第 121.391 条(a)款要求的数量，则合格证持有人应当采取下列 措施： (1)保证飞机发动机关车并且至少保持打开一个地板高 度出口，供旅客下飞机； (2)保留在飞机上的客舱乘务员数量应当至少是本规则 第121.391 条(a)款要求数量的一半，有小数时，舍去小数， 但至少为1 人； (3)可以用其他人员代替要求的客舱乘务员， 代替客舱乘 务员的人员应当是符合本规则第121.419 条应急撤离训练要 求的合格人员且应当能够为旅客所识别。
# 0.7586320557995968
# ------------------------------------------
# file1_262_3.6.
# 保留在飞机上的客舱乘务员或航空安全员应当分布在客舱每对舱门附近， 以便 在紧急情况下最有效地帮助旅客撤离。
# file2_119_第 121.391 条_(f)
# 客舱乘务员 在起飞和着陆过程中，本条要求的客舱乘务员应当尽 可能地靠近所要求的地板高度出口，而且应当在整个客舱内 均匀分布，以便在应急撤离时最有效地疏散旅客。在滑行期 间，本条要求的客舱乘务员，除完成保障飞机和机上人员安 全的任务外，其他时间应当坐在其值勤位置并系好安全带和 肩带。
# 0.7628367398652744
# ------------------------------------------
# file1_264_4.1.
# 机组在完成飞行任务到达目的站后， 应完成离机检查单和离机安全检查的全部 内容。
# file2_74_第 121.315 条_(b)
# 驾驶舱检查单 这些经批准的检查单应当至少包括在起动发动机、 起 飞或者着陆之前，以及在发动机和系统出现了紧急情况时， 飞行机组成员为确保安全应当进行的每一项检查。检查单的 设计应当使飞行机组成员无需依赖于对所要进行检查的项 目的记忆。
# 0.7768245659797415
# ------------------------------------------
# file1_287_4.2.
# 实施平行跑道同时仪表运行前， 飞行机组应确认飞机的机载电子设备满足使用 仪表着陆系统进行进近的要求， 并且至少一部自动驾驶仪或一部飞行指引仪工 作正常；
# file2_65_第 121.305 条_(k)
# 飞机仪表和设备 按照本规则运行的飞机应当装备下列飞行和导航的仪 表与设备： 除局方批准的某些涡桨飞机外，在涡轮动力飞机上， 除在每位驾驶员工作位置上各有一个陀螺坡度与俯仰指示 器(地平仪)可以供使用之外，还应当配备满足下列要求的第 三套陀螺坡度与俯仰指示器(地平仪)： (1)由独立于飞机正常发电系统的应急备用电源供电； (2)在正常发电系统全部失效之后至少能继续可靠地工 作30 分钟； (3)不依赖任何其他姿态指示系统而独立工作； (4)在正常发电系统全部失效之后无需选择就能工作； (5)位于仪表板局方认可的位置上， 使得任一驾驶员在其 工作位置上都能清楚地看见并使用； (6)在使用的所有阶段均有适当照明。
# 0.7516512040084569
# ------------------------------------------
